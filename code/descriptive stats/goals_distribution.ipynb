# %%
import pandas as pd
from getpass import getuser
import matplotlib.pyplot as plt

# %%
# Get the current user's name
user = getuser()

# %%
 # Path to the dataset
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\eu_goals_men.xlsx'

# Read the dataset with a different encoding
goals_eu = pd.read_excel(data_path)
display(goals_eu.head())
# Out:
#          stage  year   time home_team   away_team score      stadium_name  \
# 0  Semi-finals  1960  20:00    France  Yugoslavia   4–5  Parc des Princes
# 1  Semi-finals  1960  20:00    France  Yugoslavia   4–5  Parc des Princes
# 2  Semi-finals  1960  20:00    France  Yugoslavia   4–5  Parc des Princes
# 3  Semi-finals  1960  20:00    France  Yugoslavia   4–5  Parc des Princes
# 4  Semi-finals  1960  20:00    France  Yugoslavia   4–5  Parc des Princes
#
#   stadium_city  stadium_attendance     referee_name  ... goal_minute  \
# 0        Paris               26370  Gaston Grandain  ...          12
# 1        Paris               26370  Gaston Grandain  ...          43
# 2        Paris               26370  Gaston Grandain  ...          62
# 3        Paris               26370  Gaston Grandain  ...          53
# 4        Paris               26370  Gaston Grandain  ...          11
#
#   extra_time goals_home  goals_away  own_goal  penalty  goal_minute_et  \
# 0          0          4           5         0        0               0
# 1          0          4           5         0        0               0
# 2          0          4           5         0        0               0
# 3          0          4           5         0        0               0
# 4          0          4           5         0        0               0
#
#    goal_et  short_date    long_date
# 0        0  1960-07-06  6 July 1960
# 1        0  1960-07-06  6 July 1960
# 2        0  1960-07-06  6 July 1960
# 3        0  1960-07-06  6 July 1960
# 4        0  1960-07-06  6 July 1960
#
# [5 rows x 23 columns]

# %%
# Create the histogram
plt.figure(figsize=(10, 6))
plt.hist(goals_eu['goal_minute'], bins=90, range=(1, 90), density=True, color='black', edgecolor='white')

# Set titles and labels
plt.title("Goal Frequency by Minute Men European Championships", fontsize=16)
plt.xlabel("Minute", fontsize=14)
plt.ylabel("Frequency (%)", fontsize=14)

# Adjust the y-axis to show percentages
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y * 100:.1f}%'))

# Show grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
 # Path to the dataset
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\fifa.xlsx'

# Read the dataset with a different encoding
goals_wc = pd.read_excel(data_path)

# Assuming `df_goals_wc` is the dataset name after loading
goals_wc['goal_minute'] = goals_wc['minute_regulation'] + goals_wc['minute_stoppage']

# %%
# Create the histogram
plt.figure(figsize=(10, 6))
plt.hist(goals_wc['goal_minute'], bins=90, range=(1, 90), density=True, color='black', edgecolor='white')

# Set titles and labels
plt.title("Goal Frequency by Minute Men World Cup", fontsize=16)
plt.xlabel("Minute", fontsize=14)
plt.ylabel("Frequency (%)", fontsize=14)

# Adjust the y-axis to show percentages
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y * 100:.1f}%'))

# Show grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()
