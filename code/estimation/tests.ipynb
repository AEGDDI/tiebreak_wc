# %% [markdown]
# # Libraries

# %%
import pandas as pd
from getpass import getuser
import numpy as np
from scipy.stats import ttest_rel, wilcoxon  
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Optional
import os

# %%
# Get the current user's name
user = getuser()
save_dir = rf"C:\Users\{user}\Documents\GitHub\tb_football\png"
os.makedirs(save_dir, exist_ok=True)

# %% [markdown]
# # Load Data

# %%
# ---- EURO datasets ----
data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\wiki\men\uefa\eu\goals_eu_uefa.xlsx'
goals_eu_uefa = pd.read_excel(data_path)

data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\wiki\men\fifa\eu\goals_eu_fifa.xlsx'
goals_eu_fifa = pd.read_excel(data_path)

data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\wiki\men\uefa\eu\mbm_eu_uefa.xlsx'
mbm_eu_uefa = pd.read_excel(data_path)

data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\wiki\men\fifa\eu\mbm_eu_fifa.xlsx'
mbm_eu_fifa = pd.read_excel(data_path)

# ---- WORLD CUP datasets ----
data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\wiki\men\uefa\wc\goals_wc_uefa.xlsx'
goals_wc_uefa = pd.read_excel(data_path)

data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\wiki\men\fifa\wc\goals_wc_fifa.xlsx'
goals_wc_fifa = pd.read_excel(data_path)

data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\wiki\men\uefa\wc\mbm_wc_uefa.xlsx'
mbm_wc_uefa = pd.read_excel(data_path)

data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\wiki\men\fifa\wc\mbm_wc_fifa.xlsx'
mbm_wc_fifa = pd.read_excel(data_path)

# ---- Elo files ----
data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\in\elo_eu.xlsx'
elo_eu = pd.read_excel(data_path)

data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\in\elo_wc.xlsx'
elo_wc = pd.read_excel(data_path)

# ---- shock, suspense, surprise ----
data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\wiki\men\uefa\eu\tab_prob_eu_uefa.xlsx'
sss_eu = pd.read_excel(data_path)

data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\wiki\men\fifa\wc\tab_prob_fifa_wc.xlsx'
sss_wc= pd.read_excel(data_path)

# ---- shock, suspense, surprise csato ----
data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\wiki\men\uefa\eu\tab_prob_eu_uefa_csato.xlsx'
sss_eu_csato = pd.read_excel(data_path)

data_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\wiki\men\fifa\wc\tab_prob_fifa_wc_csato.xlsx'
sss_wc_csato= pd.read_excel(data_path)

# %%
# Dictionary of replacements
replacements = {
    "Republic of Ireland": "Ireland",
    "CIS": "Commonwealth of Independent States",
    "FR Yugoslavia": "Yugoslavia"
}

# List of all relevant DataFrames
datasets = [
    goals_eu_uefa, goals_eu_fifa, mbm_eu_uefa, mbm_eu_fifa,
    goals_wc_uefa, goals_wc_fifa, mbm_wc_uefa, mbm_wc_fifa
]

# Apply replacements to each dataset
for df in datasets:
    df['home_team'] = df['home_team'].replace(replacements)
    df['away_team'] = df['away_team'].replace(replacements)

# Optional: show one updated DataFrame
display(goals_eu_uefa)
# Out:
#      year    stage        date   time  goal_minute  half_time       home_team  \
# 0    1984  Group 1  1984-06-19  20:30            0        NaN             NaN
# 1    1984  Group 1  1984-06-19  20:30           26        1.0         Denmark
# 2    1984  Group 1  1984-06-19  20:30           32        1.0          France
# 3    1984  Group 1  1984-06-19  20:30           39        1.0         Denmark
# 4    1984  Group 1  1984-06-19  20:30           41        1.0         Denmark
# ..    ...      ...         ...    ...          ...        ...             ...
# 265  2024  Group F  2024-06-26  21:00            2        1.0         Georgia
# 266  2024  Group F  2024-06-26  21:00           51        2.0  Czech Republic
# 267  2024  Group F  2024-06-26  21:00           57        2.0         Georgia
# 268  2024  Group F  2024-06-26  21:00           66        2.0  Czech Republic
# 269  2024  Group F  2024-06-26  21:00           94        2.0  Czech Republic
#
#       away_team     scorer_team                      new_top_teams  ...  \
# 0           NaN             NaN              ['France', 'Denmark']  ...
# 1       Belgium         Belgium              ['France', 'Belgium']  ...
# 2    Yugoslavia      Yugoslavia              ['France', 'Belgium']  ...
# 3       Belgium         Belgium              ['France', 'Belgium']  ...
# 4       Belgium         Denmark              ['France', 'Belgium']  ...
# ..          ...             ...                                ...  ...
# 265    Portugal         Georgia  ['Turkey', 'Portugal', 'Georgia']  ...
# 266      Turkey          Turkey  ['Turkey', 'Portugal', 'Georgia']  ...
# 267    Portugal         Georgia  ['Turkey', 'Portugal', 'Georgia']  ...
# 268      Turkey  Czech Republic  ['Turkey', 'Portugal', 'Georgia']  ...
# 269      Turkey          Turkey  ['Turkey', 'Portugal', 'Georgia']  ...
#
#     third_qualify                    qualified_teams  qual_changed  \
# 0               0              ['France', 'Denmark']             0
# 1               0              ['France', 'Belgium']             1
# 2               0              ['France', 'Belgium']             0
# 3               0              ['France', 'Belgium']             0
# 4               0              ['France', 'Belgium']             0
# ..            ...                                ...           ...
# 265             1  ['Portugal', 'Turkey', 'Georgia']             1
# 266             1  ['Portugal', 'Turkey', 'Georgia']             0
# 267             1  ['Portugal', 'Turkey', 'Georgia']             0
# 268             1  ['Portugal', 'Turkey', 'Georgia']             0
# 269             1  ['Portugal', 'Turkey', 'Georgia']             0
#
#      qual_count  pts_diff  gls_diff elo_home  elo_away  h2h  suspense
# 0             0         0        -7      NaN       NaN    1         1
# 1             1        -2         5   1809.0    1898.0    1         1
# 2             1        -2         5   1960.0    1890.0    1         1
# 3             1        -2         3   1809.0    1898.0    1         0
# 4             1        -2         5   1809.0    1898.0    1         1
# ..          ...       ...       ...      ...       ...  ...       ...
# 265           1        -2         0   1666.0    2002.0    0         1
# 266           1        -3        -1   1777.0    1749.0    0         0
# 267           1        -3        -2   1666.0    2002.0    0         0
# 268           1        -2        -1   1777.0    1749.0    0         1
# 269           1        -3        -2   1777.0    1749.0    0         0
#
# [270 rows x 44 columns]

# %% [markdown]
# # aggregate measure for elo, suspense, and changes

# %%
def compute_aggregated_metrics(goals_df, elo_df):
    """
    Merges Elo ratings for home and away teams, computes average Elo per match,
    and aggregates average Elo, Elo standard deviation, qual_count, and suspense by year and stage.

    Parameters:
    - goals_df: DataFrame containing match data with 'home_team', 'away_team', 'year', 'stage', 'qual_count', and 'suspense'.
    - elo_df: DataFrame containing Elo ratings with 'team', 'year', and 'elo_rating'.

    Returns:
    - aggregated_df: DataFrame with aggregated metrics by year and group (formerly 'stage').
    """
    # Merge Elo rating for home_team
    merged_df = goals_df.merge(
        elo_df[['year', 'team', 'elo_rating']].rename(columns={'team': 'home_team', 'elo_rating': 'home_elo'}),
        on=['year', 'home_team'],
        how='left'
    )

    # Merge Elo rating for away_team
    merged_df = merged_df.merge(
        elo_df[['year', 'team', 'elo_rating']].rename(columns={'team': 'away_team', 'elo_rating': 'away_elo'}),
        on=['year', 'away_team'],
        how='left'
    )

    # Compute average Elo per match
    merged_df['elo_avg'] = merged_df[['home_elo', 'away_elo']].mean(axis=1)

    # Group and compute aggregate metrics
    aggregated_df = merged_df.groupby(['year', 'stage']).agg(
        elo_avg=('elo_avg', 'mean'),
        elo_std=('elo_avg', 'std'),
        avg_qual_count=('qual_count', 'mean'),
        avg_suspense=('suspense', 'mean')
    ).reset_index()

    # Rename 'stage' to 'group'
    aggregated_df = aggregated_df.rename(columns={'stage': 'group'})
    return aggregated_df[['year', 'group', 'elo_avg', 'elo_std', 'avg_qual_count', 'avg_suspense']]

# %%
agg_goals_eu_uefa = compute_aggregated_metrics(goals_eu_uefa, elo_eu)
agg_goals_eu_fifa = compute_aggregated_metrics(goals_eu_fifa, elo_eu)
agg_mbm_eu_uefa = compute_aggregated_metrics(mbm_eu_uefa, elo_eu)
agg_mbm_eu_fifa = compute_aggregated_metrics(mbm_eu_fifa, elo_eu)

# %%
# ---- Compute aggregated metrics for World Cup datasets ----
agg_goals_wc_uefa = compute_aggregated_metrics(goals_wc_uefa, elo_wc)
agg_goals_wc_fifa = compute_aggregated_metrics(goals_wc_fifa, elo_wc)
agg_mbm_wc_uefa   = compute_aggregated_metrics(mbm_wc_uefa, elo_wc)
agg_mbm_wc_fifa   = compute_aggregated_metrics(mbm_wc_fifa, elo_wc)

# %% [markdown]
# ## add manually elo_avg for 2024 Group C where no goal was scored

# %%
# Filter rows where elo_avg is NaN
missing_elo = agg_mbm_eu_uefa[agg_mbm_eu_uefa['elo_avg'].isna()]

# Display the result
print(missing_elo)
# Out:
#     year    group  elo_avg  elo_std  avg_qual_count  avg_suspense
# 40  2024  Group C      NaN      NaN             0.0           1.0

# %%
def patch_group_c_elo(agg_df, elo_df):
    group_c_teams = ['England', 'Denmark', 'Slovenia', 'Serbia']

    # Filter Elo ratings for the group in 2024
    group_c_elos = elo_df[
        (elo_df['year'] == 2024) & (elo_df['team'].isin(group_c_teams))
    ]['elo_rating']

    # Calculate average and std
    group_c_elo_avg = group_c_elos.mean()
    group_c_elo_std = group_c_elos.std()

    # Patch both elo_avg and elo_std
    agg_df.loc[
        (agg_df['year'] == 2024) & (agg_df['group'] == 'Group C'),
        ['elo_avg', 'elo_std']
    ] = [group_c_elo_avg, group_c_elo_std]

    return agg_df

# %%
agg_goals_eu_uefa = patch_group_c_elo(agg_goals_eu_uefa, elo_eu)
agg_goals_eu_fifa = patch_group_c_elo(agg_goals_eu_fifa, elo_eu)
agg_mbm_eu_uefa = patch_group_c_elo(agg_mbm_eu_uefa, elo_eu)
agg_mbm_eu_fifa = patch_group_c_elo(agg_mbm_eu_fifa, elo_eu)

# %%
# Filter rows where elo_avg is NaN
missing_elo = agg_mbm_wc_fifa[agg_mbm_wc_fifa['elo_avg'].isna()]

# Display the result
print(missing_elo)
# Out:
# Empty DataFrame
# Columns: [year, group, elo_avg, elo_std, avg_qual_count, avg_suspense]
# Index: []

# %% [markdown]
# ## add manually elo std when zero

# %%
# Filter rows where elo_std is exactly 0
zero_elo_std = agg_mbm_eu_uefa[agg_mbm_eu_uefa['elo_std'] == 0]

# Display the result
print(zero_elo_std)
# Out:
#     year    group  elo_avg  elo_std  avg_qual_count  avg_suspense
# 8   1996  Group C   1920.0      0.0        0.098901      0.461538
# 12  2000  Group C   1981.5      0.0        0.010417      0.708333
# 26  2016  Group A   1687.5      0.0        0.527473      1.000000
# 27  2016  Group B   1707.5      0.0        0.000000      0.000000
# 42  2024  Group E   1659.0      0.0        1.329670      1.000000

# %%
def patch_group_elo_std(agg_df, goals_df, elo_df):
    """
    Patch elo_std in agg_df using team-level ratings from elo_df.

    Parameters
    ----------
    agg_df : pd.DataFrame
        Aggregated dataset with columns ['year', 'group', 'elo_std'].
    goals_df : pd.DataFrame
        Match-level dataset with columns ['year', 'stage', 'home_team', 'away_team'].
    elo_df : pd.DataFrame
        Team-level Elo ratings with columns ['year', 'team', 'elo_rating'].

    Returns
    -------
    pd.DataFrame
        agg_df with corrected elo_std values.
    """
    agg_df = agg_df.copy()

    for idx, row in agg_df.iterrows():
        if np.isclose(row["elo_std"], 0.0) or pd.isna(row["elo_std"]):
            year, group = row["year"], row["group"]

            # find teams in this group from goals_df
            teams = set(
                goals_df.loc[
                    (goals_df["year"] == year) & (goals_df["stage"] == group),
                    "home_team"
                ]
            ).union(
                set(
                    goals_df.loc[
                        (goals_df["year"] == year) & (goals_df["stage"] == group),
                        "away_team"
                    ]
                )
            )

            # get their elo ratings from elo_df
            team_elos = elo_df.loc[
                (elo_df["year"] == year) & (elo_df["team"].isin(teams)),
                "elo_rating"
            ]

            if not team_elos.empty:
                agg_df.at[idx, "elo_std"] = team_elos.std()

    return agg_df

# %%
agg_goals_eu_uefa = patch_group_elo_std(agg_goals_eu_uefa, goals_eu_uefa, elo_eu)
agg_goals_eu_fifa = patch_group_elo_std(agg_goals_eu_fifa, goals_eu_fifa, elo_eu)
agg_mbm_eu_uefa   = patch_group_elo_std(agg_mbm_eu_uefa,   mbm_eu_uefa,   elo_eu)
agg_mbm_eu_fifa   = patch_group_elo_std(agg_mbm_eu_fifa,   mbm_eu_fifa,   elo_eu)

# %% [markdown]
# # correlation analysis

# %%
def show_correlations(df, dataset_name):
    # Select only numeric columns of interest
    corr_matrix = df[['elo_std', 'avg_qual_count', 'avg_suspense']].corr()

    print(f"\nCorrelation matrix for {dataset_name}:\n")
    print(corr_matrix)

# %%
# ---- Apply to EURO datasets ----
show_correlations(agg_goals_eu_uefa, 'agg_goals_eu_uefa')
show_correlations(agg_goals_eu_fifa, 'agg_goals_eu_fifa')
show_correlations(agg_mbm_eu_uefa, 'agg_mbm_eu_uefa')
show_correlations(agg_mbm_eu_fifa, 'agg_mbm_eu_fifa')
# Out:
# Correlation matrix for agg_goals_eu_uefa:
#
#                  elo_std  avg_qual_count  avg_suspense
# elo_std         1.000000       -0.088930      0.251678
# avg_qual_count -0.088930        1.000000      0.391333
# avg_suspense    0.251678        0.391333      1.000000
#
# Correlation matrix for agg_goals_eu_fifa:
#
#                  elo_std  avg_qual_count  avg_suspense
# elo_std         1.000000       -0.060990      0.264044
# avg_qual_count -0.060990        1.000000      0.406422
# avg_suspense    0.264044        0.406422      1.000000
#
# Correlation matrix for agg_mbm_eu_uefa:
#
#                  elo_std  avg_qual_count  avg_suspense
# elo_std         1.000000       -0.102521      0.174856
# avg_qual_count -0.102521        1.000000      0.299446
# avg_suspense    0.174856        0.299446      1.000000
#
# Correlation matrix for agg_mbm_eu_fifa:
#
#                  elo_std  avg_qual_count  avg_suspense
# elo_std         1.000000       -0.035867      0.153476
# avg_qual_count -0.035867        1.000000      0.351528
# avg_suspense    0.153476        0.351528      1.000000

# %%
# ---- Apply to WORLD CUP datasets ----
show_correlations(agg_goals_wc_uefa, 'agg_goals_wc_uefa')
show_correlations(agg_goals_wc_fifa, 'agg_goals_wc_fifa')
show_correlations(agg_mbm_wc_uefa, 'agg_mbm_wc_uefa')
show_correlations(agg_mbm_wc_fifa, 'agg_mbm_wc_fifa')
# Out:
# Correlation matrix for agg_goals_wc_uefa:
#
#                  elo_std  avg_qual_count  avg_suspense
# elo_std         1.000000       -0.064525     -0.183590
# avg_qual_count -0.064525        1.000000      0.456403
# avg_suspense   -0.183590        0.456403      1.000000
#
# Correlation matrix for agg_goals_wc_fifa:
#
#                  elo_std  avg_qual_count  avg_suspense
# elo_std         1.000000       -0.060573     -0.278325
# avg_qual_count -0.060573        1.000000      0.588245
# avg_suspense   -0.278325        0.588245      1.000000
#
# Correlation matrix for agg_mbm_wc_uefa:
#
#                  elo_std  avg_qual_count  avg_suspense
# elo_std         1.000000       -0.006821     -0.222385
# avg_qual_count -0.006821        1.000000      0.403051
# avg_suspense   -0.222385        0.403051      1.000000
#
# Correlation matrix for agg_mbm_wc_fifa:
#
#                  elo_std  avg_qual_count  avg_suspense
# elo_std         1.000000       -0.005871     -0.276092
# avg_qual_count -0.005871        1.000000      0.475994
# avg_suspense   -0.276092        0.475994      1.000000

# %% [markdown]
# # aggregate difference UEFA vs FIFA

# %% [markdown]
# ## Paired t-test and Wilcoxon test

# %% [markdown]
# ### Euro

# %%
# Merge only on identifiers (not elo_avg/elo_std to avoid float mismatch)
merged = pd.merge(
    agg_goals_eu_uefa, agg_goals_eu_fifa,
    on=['year', 'group'], suffixes=('_uefa', '_fifa'), how='inner'
)

# Add flags for differences
merged['diff_qual_count'] = merged['avg_qual_count_uefa'] != merged['avg_qual_count_fifa']
merged['diff_suspense'] = merged['avg_suspense_uefa'] != merged['avg_suspense_fifa']

# If you want an overall flag
merged['any_diff'] = merged['diff_qual_count'] | merged['diff_suspense']

# Display everything, both differing and identical cases
display(merged[[
    'year','group',
    'elo_avg_uefa','elo_std_uefa',
    'avg_qual_count_uefa','avg_qual_count_fifa','diff_qual_count',
    'avg_suspense_uefa','avg_suspense_fifa','diff_suspense',
    'any_diff'
]])
# Out:
#     year    group  elo_avg_uefa  elo_std_uefa  avg_qual_count_uefa  \
# 0   1984  Group 1   1889.250000     37.683809             1.363636
# 1   1984  Group 2   1883.250000     83.792154             1.000000
# 2   1988  Group 1   1924.500000     13.279056             0.000000
# 3   1988  Group 2   1966.400000     46.063000             0.166667
# 4   1992  Group 1   1920.750000      3.012474             1.571429
# 5   1992  Group 2   1945.928571     89.265255             0.000000
# 6   1996  Group A   1882.083333     47.560926             0.428571
# 7   1996  Group B   1925.857143     14.164846             2.500000
# 8   1996  Group C   1920.000000     18.384776             0.428571
# 9   1996  Group D   1873.250000      9.037422             0.000000
# 10  2000  Group A   1889.750000      7.245688             1.666667
# 11  2000  Group B   1861.200000     79.145910             0.666667
# 12  2000  Group C   1981.500000     53.033009             0.125000
# 13  2000  Group D   1976.642857     62.945555             0.000000
# 14  2004  Group A   1829.375000     85.750000             0.200000
# 15  2004  Group B   1885.700000      3.614784             1.545455
# 16  2004  Group C   1843.214286      9.621405             0.000000
# 17  2004  Group D   1829.250000     92.291251             0.571429
# 18  2008  Group A   1855.214286     19.274026             0.125000
# 19  2008  Group B   1804.500000     33.941125             0.000000
# 20  2008  Group C   1981.250000     44.744646             0.800000
# 21  2008  Group D   1862.500000     65.726707             0.833333
# 22  2012  Group A   1785.000000     42.426407             1.000000
# 23  2012  Group B   1946.500000     18.074844             2.571429
# 24  2012  Group C   1885.333333     99.304246             0.750000
# 25  2012  Group D   1870.833333     13.279056             0.000000
# 26  2016  Group A   1687.500000    101.116270             0.500000
# 27  2016  Group B   1707.500000     74.246212             0.000000
# 28  2016  Group C   1815.500000     19.798990             0.000000
# 29  2016  Group D   1860.100000     62.166510             0.333333
# 30  2016  Group E   1829.750000     18.738330             0.333333
# 31  2016  Group F   1776.333333     40.750000             3.200000
# 32  2021  Group A   1861.100000     34.882660             0.833333
# 33  2021  Group B   1868.071429     16.346326             2.750000
# 34  2021  Group C   1777.125000      2.250000             0.800000
# 35  2021  Group D   1776.200000     55.230879             1.500000
# 36  2021  Group E   1833.750000     11.331495             0.818182
# 37  2021  Group F   1951.000000    120.267559             2.555556
# 38  2024  Group A   1842.000000     35.507042             0.250000
# 39  2024  Group B   1913.166667     79.385662             0.750000
# 40  2024  Group C   1837.250000    104.652998             0.000000
# 41  2024  Group D   1916.857143      3.659625             0.000000
# 42  2024  Group E   1659.000000     16.970563             1.000000
# 43  2024  Group F   1791.400000     38.888302             0.833333
#
#     avg_qual_count_fifa  diff_qual_count  avg_suspense_uefa  \
# 0              1.363636            False           0.818182
# 1              1.000000            False           1.000000
# 2              0.000000            False           0.000000
# 3              0.166667            False           0.833333
# 4              1.571429            False           0.857143
# 5              0.000000            False           0.250000
# 6              0.428571            False           0.571429
# 7              2.500000            False           1.000000
# 8              1.285714             True           0.571429
# 9              0.000000            False           0.000000
# 10             1.666667            False           0.777778
# 11             0.666667            False           0.500000
# 12             3.375000             True           0.625000
# 13             0.000000            False           0.000000
# 14             1.000000             True           1.000000
# 15             1.545455            False           0.454545
# 16             0.000000            False           0.375000
# 17             0.571429            False           0.571429
# 18             0.125000            False           0.750000
# 19             0.000000            False           0.333333
# 20             0.800000            False           0.600000
# 21             0.833333            False           0.500000
# 22             1.000000            False           1.000000
# 23             2.571429            False           0.714286
# 24             0.500000             True           1.000000
# 25             0.000000            False           0.250000
# 26             0.500000            False           1.000000
# 27             0.000000            False           0.000000
# 28             0.000000            False           0.000000
# 29             0.333333            False           0.166667
# 30             0.333333            False           0.333333
# 31             3.200000            False           0.300000
# 32             0.833333            False           0.000000
# 33             2.750000            False           1.000000
# 34             0.800000            False           0.800000
# 35             1.500000            False           0.000000
# 36             0.818182            False           0.181818
# 37             2.555556            False           1.000000
# 38             0.250000            False           0.250000
# 39             0.750000            False           0.500000
# 40             0.000000            False           1.000000
# 41             0.000000            False           0.000000
# 42             1.000000            False           1.000000
# 43             0.833333            False           0.500000
#
#     avg_suspense_fifa  diff_suspense  any_diff
# 0            0.818182          False     False
# 1            1.000000          False     False
# 2            0.200000           True      True
# 3            1.000000           True      True
# 4            1.000000           True      True
# 5            0.250000          False     False
# 6            0.571429          False     False
# 7            1.000000          False     False
# 8            0.714286           True      True
# 9            0.000000          False     False
# 10           0.777778          False     False
# 11           0.500000          False     False
# 12           1.000000           True      True
# 13           0.000000          False     False
# 14           1.000000          False      True
# 15           0.454545          False     False
# 16           0.375000          False     False
# 17           0.571429          False     False
# 18           0.750000          False     False
# 19           0.333333          False     False
# 20           0.600000          False     False
# 21           0.500000          False     False
# 22           0.666667           True      True
# 23           0.714286          False     False
# 24           1.000000          False      True
# 25           0.250000          False     False
# 26           1.000000          False     False
# 27           0.000000          False     False
# 28           0.000000          False     False
# 29           0.166667          False     False
# 30           0.333333          False     False
# 31           0.300000          False     False
# 32           0.000000          False     False
# 33           0.625000           True      True
# 34           0.800000          False     False
# 35           0.000000          False     False
# 36           0.272727           True      True
# 37           1.000000          False     False
# 38           0.250000          False     False
# 39           0.750000           True      True
# 40           1.000000          False     False
# 41           0.000000          False     False
# 42           1.000000          False     False
# 43           0.500000          False     False

# %%
# Check where the value columns differ
same = merged[
    (merged['avg_qual_count_uefa'] == merged['avg_qual_count_fifa']) |
    (merged['avg_suspense_uefa'] == merged['avg_suspense_fifa'])
]

display(same)
# Out:
#     year    group  elo_avg_uefa  elo_std_uefa  avg_qual_count_uefa  \
# 0   1984  Group 1   1889.250000     37.683809             1.363636
# 1   1984  Group 2   1883.250000     83.792154             1.000000
# 2   1988  Group 1   1924.500000     13.279056             0.000000
# 3   1988  Group 2   1966.400000     46.063000             0.166667
# 4   1992  Group 1   1920.750000      3.012474             1.571429
# 5   1992  Group 2   1945.928571     89.265255             0.000000
# 6   1996  Group A   1882.083333     47.560926             0.428571
# 7   1996  Group B   1925.857143     14.164846             2.500000
# 9   1996  Group D   1873.250000      9.037422             0.000000
# 10  2000  Group A   1889.750000      7.245688             1.666667
# 11  2000  Group B   1861.200000     79.145910             0.666667
# 13  2000  Group D   1976.642857     62.945555             0.000000
# 14  2004  Group A   1829.375000     85.750000             0.200000
# 15  2004  Group B   1885.700000      3.614784             1.545455
# 16  2004  Group C   1843.214286      9.621405             0.000000
# 17  2004  Group D   1829.250000     92.291251             0.571429
# 18  2008  Group A   1855.214286     19.274026             0.125000
# 19  2008  Group B   1804.500000     33.941125             0.000000
# 20  2008  Group C   1981.250000     44.744646             0.800000
# 21  2008  Group D   1862.500000     65.726707             0.833333
# 22  2012  Group A   1785.000000     42.426407             1.000000
# 23  2012  Group B   1946.500000     18.074844             2.571429
# 24  2012  Group C   1885.333333     99.304246             0.750000
# 25  2012  Group D   1870.833333     13.279056             0.000000
# 26  2016  Group A   1687.500000    101.116270             0.500000
# 27  2016  Group B   1707.500000     74.246212             0.000000
# 28  2016  Group C   1815.500000     19.798990             0.000000
# 29  2016  Group D   1860.100000     62.166510             0.333333
# 30  2016  Group E   1829.750000     18.738330             0.333333
# 31  2016  Group F   1776.333333     40.750000             3.200000
# 32  2021  Group A   1861.100000     34.882660             0.833333
# 33  2021  Group B   1868.071429     16.346326             2.750000
# 34  2021  Group C   1777.125000      2.250000             0.800000
# 35  2021  Group D   1776.200000     55.230879             1.500000
# 36  2021  Group E   1833.750000     11.331495             0.818182
# 37  2021  Group F   1951.000000    120.267559             2.555556
# 38  2024  Group A   1842.000000     35.507042             0.250000
# 39  2024  Group B   1913.166667     79.385662             0.750000
# 40  2024  Group C   1837.250000    104.652998             0.000000
# 41  2024  Group D   1916.857143      3.659625             0.000000
# 42  2024  Group E   1659.000000     16.970563             1.000000
# 43  2024  Group F   1791.400000     38.888302             0.833333
#
#     avg_suspense_uefa  elo_avg_fifa  elo_std_fifa  avg_qual_count_fifa  \
# 0            0.818182   1889.250000     37.683809             1.363636
# 1            1.000000   1883.250000     83.792154             1.000000
# 2            0.000000   1924.500000     13.279056             0.000000
# 3            0.833333   1966.400000     46.063000             0.166667
# 4            0.857143   1920.750000      3.012474             1.571429
# 5            0.250000   1945.928571     89.265255             0.000000
# 6            0.571429   1882.083333     47.560926             0.428571
# 7            1.000000   1925.857143     14.164846             2.500000
# 9            0.000000   1873.250000      9.037422             0.000000
# 10           0.777778   1889.750000      7.245688             1.666667
# 11           0.500000   1861.200000     79.145910             0.666667
# 13           0.000000   1976.642857     62.945555             0.000000
# 14           1.000000   1829.375000     85.750000             1.000000
# 15           0.454545   1885.700000      3.614784             1.545455
# 16           0.375000   1843.214286      9.621405             0.000000
# 17           0.571429   1829.250000     92.291251             0.571429
# 18           0.750000   1855.214286     19.274026             0.125000
# 19           0.333333   1804.500000     33.941125             0.000000
# 20           0.600000   1981.250000     44.744646             0.800000
# 21           0.500000   1862.500000     65.726707             0.833333
# 22           1.000000   1785.000000     42.426407             1.000000
# 23           0.714286   1946.500000     18.074844             2.571429
# 24           1.000000   1885.333333     99.304246             0.500000
# 25           0.250000   1870.833333     13.279056             0.000000
# 26           1.000000   1687.500000    101.116270             0.500000
# 27           0.000000   1707.500000     74.246212             0.000000
# 28           0.000000   1815.500000     19.798990             0.000000
# 29           0.166667   1860.100000     62.166510             0.333333
# 30           0.333333   1829.750000     18.738330             0.333333
# 31           0.300000   1776.333333     40.750000             3.200000
# 32           0.000000   1861.100000     34.882660             0.833333
# 33           1.000000   1868.071429     16.346326             2.750000
# 34           0.800000   1777.125000      2.250000             0.800000
# 35           0.000000   1776.200000     55.230879             1.500000
# 36           0.181818   1833.750000     11.331495             0.818182
# 37           1.000000   1951.000000    120.267559             2.555556
# 38           0.250000   1842.000000     35.507042             0.250000
# 39           0.500000   1913.166667     79.385662             0.750000
# 40           1.000000   1837.250000    104.652998             0.000000
# 41           0.000000   1916.857143      3.659625             0.000000
# 42           1.000000   1659.000000     16.970563             1.000000
# 43           0.500000   1791.400000     38.888302             0.833333
#
#     avg_suspense_fifa  diff_qual_count  diff_suspense  any_diff
# 0            0.818182            False          False     False
# 1            1.000000            False          False     False
# 2            0.200000            False           True      True
# 3            1.000000            False           True      True
# 4            1.000000            False           True      True
# 5            0.250000            False          False     False
# 6            0.571429            False          False     False
# 7            1.000000            False          False     False
# 9            0.000000            False          False     False
# 10           0.777778            False          False     False
# 11           0.500000            False          False     False
# 13           0.000000            False          False     False
# 14           1.000000             True          False      True
# 15           0.454545            False          False     False
# 16           0.375000            False          False     False
# 17           0.571429            False          False     False
# 18           0.750000            False          False     False
# 19           0.333333            False          False     False
# 20           0.600000            False          False     False
# 21           0.500000            False          False     False
# 22           0.666667            False           True      True
# 23           0.714286            False          False     False
# 24           1.000000             True          False      True
# 25           0.250000            False          False     False
# 26           1.000000            False          False     False
# 27           0.000000            False          False     False
# 28           0.000000            False          False     False
# 29           0.166667            False          False     False
# 30           0.333333            False          False     False
# 31           0.300000            False          False     False
# 32           0.000000            False          False     False
# 33           0.625000            False           True      True
# 34           0.800000            False          False     False
# 35           0.000000            False          False     False
# 36           0.272727            False           True      True
# 37           1.000000            False          False     False
# 38           0.250000            False          False     False
# 39           0.750000            False           True      True
# 40           1.000000            False          False     False
# 41           0.000000            False          False     False
# 42           1.000000            False          False     False
# 43           0.500000            False          False     False

# %%
# All groups are included — no filter applied.
# Previously this cell filtered to groups where metrics differ;
# that selection was removed to avoid conditioning on the outcome.
differences = merged.copy()
# Out:
#     year    group  elo_avg_uefa  elo_std_uefa  avg_qual_count_uefa  \
# 2   1988  Group 1   1924.500000     13.279056             0.000000
# 3   1988  Group 2   1966.400000     46.063000             0.166667
# 4   1992  Group 1   1920.750000      3.012474             1.571429
# 8   1996  Group C   1920.000000     18.384776             0.428571
# 12  2000  Group C   1981.500000     53.033009             0.125000
# 14  2004  Group A   1829.375000     85.750000             0.200000
# 22  2012  Group A   1785.000000     42.426407             1.000000
# 24  2012  Group C   1885.333333     99.304246             0.750000
# 33  2021  Group B   1868.071429     16.346326             2.750000
# 36  2021  Group E   1833.750000     11.331495             0.818182
# 39  2024  Group B   1913.166667     79.385662             0.750000
#
#     avg_suspense_uefa  elo_avg_fifa  elo_std_fifa  avg_qual_count_fifa  \
# 2            0.000000   1924.500000     13.279056             0.000000
# 3            0.833333   1966.400000     46.063000             0.166667
# 4            0.857143   1920.750000      3.012474             1.571429
# 8            0.571429   1920.000000     18.384776             1.285714
# 12           0.625000   1981.500000     53.033009             3.375000
# 14           1.000000   1829.375000     85.750000             1.000000
# 22           1.000000   1785.000000     42.426407             1.000000
# 24           1.000000   1885.333333     99.304246             0.500000
# 33           1.000000   1868.071429     16.346326             2.750000
# 36           0.181818   1833.750000     11.331495             0.818182
# 39           0.500000   1913.166667     79.385662             0.750000
#
#     avg_suspense_fifa  diff_qual_count  diff_suspense  any_diff
# 2            0.200000            False           True      True
# 3            1.000000            False           True      True
# 4            1.000000            False           True      True
# 8            0.714286             True           True      True
# 12           1.000000             True           True      True
# 14           1.000000             True          False      True
# 22           0.666667            False           True      True
# 24           1.000000             True          False      True
# 33           0.625000            False           True      True
# 36           0.272727            False           True      True
# 39           0.750000            False           True      True

# %%
# Compute differences (UEFA - FIFA) over all groups
qual_diff = differences['avg_qual_count_uefa'] - differences['avg_qual_count_fifa']
suspense_diff = differences['avg_suspense_uefa'] - differences['avg_suspense_fifa']

print("N groups:", len(differences))
print("Mean suspense difference (UEFA - FIFA):", suspense_diff.mean())
print("Mean qualification count difference (UEFA - FIFA):", qual_diff.mean())

# Paired t-test
ttest_qual = ttest_rel(differences['avg_qual_count_uefa'], differences['avg_qual_count_fifa'])
ttest_suspense = ttest_rel(differences['avg_suspense_uefa'], differences['avg_suspense_fifa'])

# Wilcoxon signed-rank test (zero differences excluded — standard practice)
wilcoxon_qual = wilcoxon(qual_diff[qual_diff != 0])
wilcoxon_suspense = wilcoxon(suspense_diff[suspense_diff != 0])

# Display results
print("Paired t-test (Qualification Count):", ttest_qual)
print("Wilcoxon (Qualification Count):", wilcoxon_qual)
print("Paired t-test (Suspense):", ttest_suspense)
print("Wilcoxon (Suspense):", wilcoxon_suspense)

# %% [markdown]
# | Metric              | Significance | Interpretation                                                                        |
# | ------------------- | -------------------------- | ------------------------------------------------------------------------------------- |
# | Qualification Count | No (p > 0.10)       | We fail to detect a difference between FIFA and UEFA in the number of qualification composition changes.|
# | Suspense            | Weak (10% level)             | Weak evidence that FIFA rules generate higher suspense than UEFA rules.                    |

# %% [markdown]
# ## WC

# %%
# Merge only on identifiers (not elo_avg/elo_std to avoid float mismatch)
merged = pd.merge(
    agg_goals_wc_uefa, agg_goals_wc_fifa,
    on=['year', 'group'], suffixes=('_uefa', '_fifa'), how='inner'
)

# Add flags for differences
merged['diff_qual_count'] = merged['avg_qual_count_uefa'] != merged['avg_qual_count_fifa']
merged['diff_suspense'] = merged['avg_suspense_uefa'] != merged['avg_suspense_fifa']

# If you want an overall flag
merged['any_diff'] = merged['diff_qual_count'] | merged['diff_suspense']

# Display everything, both differing and identical cases
display(merged[[
    'year','group',
    'elo_avg_uefa','elo_std_uefa',
    'avg_qual_count_uefa','avg_qual_count_fifa','diff_qual_count',
    'avg_suspense_uefa','avg_suspense_fifa','diff_suspense',
    'any_diff'
]])
# Out:
#     year    group  elo_avg_uefa  elo_std_uefa  avg_qual_count_uefa  \
# 0   1986  Group A   1783.214286     50.746804             0.000000
# 1   1986  Group B   1800.100000     38.907583             0.000000
# 2   1986  Group C   1885.300000     79.693632             0.833333
# 3   1986  Group D   1821.250000     67.643736             1.571429
# 4   1986  Group E   1916.000000      0.000000             0.000000
# ..   ...      ...           ...           ...                  ...
# 69  2022  Group D   1850.500000      7.778175             0.000000
# 70  2022  Group E   1874.833333     32.000000             3.100000
# 71  2022  Group F   1771.000000      0.000000             0.000000
# 72  2022  Group G   1898.666667      4.490731             1.000000
# 73  2022  Group H   1838.200000     79.145910             0.833333
#
#     avg_qual_count_fifa  diff_qual_count  avg_suspense_uefa  \
# 0              0.000000            False           0.625000
# 1              0.000000            False           0.000000
# 2              0.833333            False           0.000000
# 3              1.571429            False           0.285714
# 4              0.000000            False           1.000000
# ..                  ...              ...                ...
# 69             1.000000             True           0.666667
# 70             2.300000             True           0.700000
# 71             0.000000            False           1.000000
# 72             1.000000            False           0.142857
# 73             0.833333            False           0.666667
#
#     avg_suspense_fifa  diff_suspense  any_diff
# 0            0.625000          False     False
# 1            0.000000          False     False
# 2            0.000000          False     False
# 3            0.285714          False     False
# 4            1.000000          False     False
# ..                ...            ...       ...
# 69           1.000000           True      True
# 70           0.700000          False      True
# 71           1.000000          False     False
# 72           0.714286           True      True
# 73           0.833333           True      True
#
# [74 rows x 11 columns]

# %%
# Check where the value columns differ
same = merged[
    (merged['avg_qual_count_uefa'] == merged['avg_qual_count_fifa']) |
    (merged['avg_suspense_uefa'] == merged['avg_suspense_fifa'])
]

display(same)
# Out:
#     year    group  elo_avg_uefa  elo_std_uefa  avg_qual_count_uefa  \
# 0   1986  Group A   1783.214286     50.746804             0.000000
# 1   1986  Group B   1800.100000     38.907583             0.000000
# 2   1986  Group C   1885.300000     79.693632             0.833333
# 3   1986  Group D   1821.250000     67.643736             1.571429
# 4   1986  Group E   1916.000000      0.000000             0.000000
# ..   ...      ...           ...           ...                  ...
# 68  2022  Group C   1824.600000    140.490836             0.833333
# 70  2022  Group E   1874.833333     32.000000             3.100000
# 71  2022  Group F   1771.000000      0.000000             0.000000
# 72  2022  Group G   1898.666667      4.490731             1.000000
# 73  2022  Group H   1838.200000     79.145910             0.833333
#
#     avg_suspense_uefa  elo_avg_fifa  elo_std_fifa  avg_qual_count_fifa  \
# 0            0.625000   1783.214286     50.746804             0.000000
# 1            0.000000   1800.100000     38.907583             0.000000
# 2            0.000000   1885.300000     79.693632             0.833333
# 3            0.285714   1821.250000     67.643736             1.571429
# 4            1.000000   1916.000000      0.000000             0.000000
# ..                ...           ...           ...                  ...
# 68           0.833333   1824.600000    140.490836             0.000000
# 70           0.700000   1874.833333     32.000000             2.300000
# 71           1.000000   1771.000000      0.000000             0.000000
# 72           0.142857   1898.666667      4.490731             1.000000
# 73           0.666667   1838.200000     79.145910             0.833333
#
#     avg_suspense_fifa  diff_qual_count  diff_suspense  any_diff
# 0            0.625000            False          False     False
# 1            0.000000            False          False     False
# 2            0.000000            False          False     False
# 3            0.285714            False          False     False
# 4            1.000000            False          False     False
# ..                ...              ...            ...       ...
# 68           0.833333             True          False      True
# 70           0.700000             True          False      True
# 71           1.000000            False          False     False
# 72           0.714286            False           True      True
# 73           0.833333            False           True      True
#
# [65 rows x 13 columns]

# %%
# All groups are included — no filter applied.
# Previously this cell filtered to groups where metrics differ;
# that selection was removed to avoid conditioning on the outcome.
differences = merged.copy()
# Out:
#     year    group  elo_avg_uefa  elo_std_uefa  avg_qual_count_uefa  \
# 5   1986  Group F   1800.500000     91.670606             2.250000
# 7   1990  Group B   1807.833333     29.176475             0.000000
# 8   1990  Group C   1803.500000     42.000000             1.800000
# 16  1994  Group E   1920.500000      0.000000             1.666667
# 17  1994  Group F   1808.125000     50.750000             0.000000
# 26  2002  Group A   1812.000000    101.840211             0.000000
# 29  2002  Group D   1788.300000     38.683976             0.000000
# 32  2002  Group G   1881.166667     66.395281             0.500000
# 38  2006  Group E   1819.700000    126.250050             0.000000
# 43  2010  Group B   1769.666667     45.184806             1.571429
# 45  2010  Group D   1812.250000      7.500000             0.800000
# 49  2010  Group H   1999.000000      0.000000             0.750000
# 54  2014  Group E   1762.500000      0.000000             0.000000
# 56  2014  Group G   1861.125000     69.250000             0.000000
# 61  2018  Group D   1821.500000     14.240786             1.857143
# 63  2018  Group F   1851.500000     39.709885             0.833333
# 65  2018  Group H   1798.000000     57.275649             0.333333
# 68  2022  Group C   1824.600000    140.490836             0.833333
# 69  2022  Group D   1850.500000      7.778175             0.000000
# 70  2022  Group E   1874.833333     32.000000             3.100000
# 72  2022  Group G   1898.666667      4.490731             1.000000
# 73  2022  Group H   1838.200000     79.145910             0.833333
#
#     avg_suspense_uefa  elo_avg_fifa  elo_std_fifa  avg_qual_count_fifa  \
# 5            0.375000   1800.500000     91.670606             2.250000
# 7            0.000000   1807.833333     29.176475             0.428571
# 8            0.200000   1803.500000     42.000000             1.800000
# 16           0.666667   1920.500000      0.000000             1.000000
# 17           0.400000   1808.125000     50.750000             0.000000
# 26           0.222222   1812.000000    101.840211             0.000000
# 29           0.666667   1788.300000     38.683976             1.166667
# 32           0.500000   1881.166667     66.395281             1.250000
# 38           0.333333   1819.700000    126.250050             0.833333
# 43           0.428571   1769.666667     45.184806             1.571429
# 45           0.400000   1812.250000      7.500000             0.000000
# 49           0.250000   1999.000000      0.000000             0.000000
# 54           0.250000   1762.500000      0.000000             0.750000
# 56           0.000000   1861.125000     69.250000             0.000000
# 61           0.571429   1821.500000     14.240786             1.857143
# 63           0.166667   1851.500000     39.709885             0.833333
# 65           1.000000   1798.000000     57.275649             1.000000
# 68           0.833333   1824.600000    140.490836             0.000000
# 69           0.666667   1850.500000      7.778175             1.000000
# 70           0.700000   1874.833333     32.000000             2.300000
# 72           0.142857   1898.666667      4.490731             1.000000
# 73           0.666667   1838.200000     79.145910             0.833333
#
#     avg_suspense_fifa  diff_qual_count  diff_suspense  any_diff
# 5            0.500000            False           True      True
# 7            0.428571             True           True      True
# 8            0.800000            False           True      True
# 16           1.000000             True           True      True
# 17           0.600000            False           True      True
# 26           0.333333            False           True      True
# 29           1.000000             True           True      True
# 32           0.750000             True           True      True
# 38           0.500000             True           True      True
# 43           0.857143            False           True      True
# 45           0.600000             True           True      True
# 49           0.500000             True           True      True
# 54           0.750000             True           True      True
# 56           0.200000            False           True      True
# 61           0.857143            False           True      True
# 63           0.500000            False           True      True
# 65           1.000000             True          False      True
# 68           0.833333             True          False      True
# 69           1.000000             True           True      True
# 70           0.700000             True          False      True
# 72           0.714286            False           True      True
# 73           0.833333            False           True      True

# %%
# Compute differences (UEFA - FIFA) over all groups
qual_diff = differences['avg_qual_count_uefa'] - differences['avg_qual_count_fifa']
suspense_diff = differences['avg_suspense_uefa'] - differences['avg_suspense_fifa']

print("N groups:", len(differences))
print("Mean suspense difference (UEFA - FIFA):", suspense_diff.mean())
print("Mean qualification count difference (UEFA - FIFA):", qual_diff.mean())

# Paired t-test
ttest_qual = ttest_rel(differences['avg_qual_count_uefa'], differences['avg_qual_count_fifa'])
ttest_suspense = ttest_rel(differences['avg_suspense_uefa'], differences['avg_suspense_fifa'])

# Wilcoxon signed-rank test (zero differences excluded — standard practice)
wilcoxon_qual = wilcoxon(qual_diff[qual_diff != 0])
wilcoxon_suspense = wilcoxon(suspense_diff[suspense_diff != 0])

# Display results
print("Paired t-test (Qualification Count):", ttest_qual)
print("Wilcoxon (Qualification Count):", wilcoxon_qual)
print("Paired t-test (Suspense):", ttest_suspense)
print("Wilcoxon (Suspense):", wilcoxon_suspense)

# %% [markdown]
# | Metric              | Significance | Interpretation                                                                        |
# | ------------------- | -------------------------- | ------------------------------------------------------------------------------------- |
# | Qualification Count | No (p > 0.10)       | We fail to detect a difference between FIFA and UEFA in the number of qualification composition changes.|
# | Suspense            | Yes (1% level)             | Strong evidence that FIFA rules generate higher suspense than UEFA rules.                    |

# %% [markdown]
# Both tests clearly indicate no statistically significant difference in average qualification count between the FIFA and UEFA variants of the group compositions.

# %% [markdown]
# # Plots

# %% [markdown]
# ## goals distribution

# %%
# Filter out zero-minute goals
goals_eu_uefa_filtered = goals_eu_uefa[goals_eu_uefa['goal_minute'] > 0]
goals_wc_fifa_filtered = goals_wc_fifa[goals_wc_fifa['goal_minute'] > 0]

# Plot setup
fig, axes = plt.subplots(1, 2, figsize=(16, 5), sharey=True)

# UEFA European Championships
axes[0].hist(goals_eu_uefa_filtered['goal_minute'], bins=90, density=True, color='steelblue', edgecolor='black')
axes[0].set_title('UEFA European Championships')
axes[0].set_xlabel('Minute of Goal')
axes[0].set_ylabel('Density')
axes[0].grid(True)

# FIFA World Cups
axes[1].hist(goals_wc_fifa_filtered['goal_minute'], bins=90, density=True, color='darkorange', edgecolor='black')
axes[1].set_title('FIFA World Cups')
axes[1].set_xlabel('Minute of Goal')
axes[1].grid(True)

# Add suptitle and adjust spacing
fig.suptitle('Relative Frequency of Goal Times by Minute of Match (Excluding Minute 0)', fontsize=16, y=1.05)
plt.tight_layout()
plt.subplots_adjust(top=0.8)  # Add more vertical spacing between suptitle and plots
plt.show()

# %%
# Filter out zero-minute goals
goals_eu_uefa_filtered = goals_eu_uefa[goals_eu_uefa['goal_minute'] > 0]
goals_wc_fifa_filtered = goals_wc_fifa[goals_wc_fifa['goal_minute'] > 0]

# Plot setup
fig, axes = plt.subplots(1, 2, figsize=(16, 5), sharey=True)

# UEFA European Championships
axes[0].hist(goals_eu_uefa_filtered['goal_minute'], bins=90, density=True, 
             color='0.5', edgecolor='black')  # medium grey
axes[0].set_title('UEFA European Championships')
axes[0].set_xlabel('Minute of Goal')
axes[0].set_ylabel('Density')
axes[0].grid(True)

# FIFA World Cups
axes[1].hist(goals_wc_fifa_filtered['goal_minute'], bins=90, density=True, 
             color='0.7', edgecolor='black')  # lighter grey
axes[1].set_title('FIFA World Cups')
axes[1].set_xlabel('Minute of Goal')
axes[1].grid(True)

# Add suptitle and adjust spacing
fig.suptitle('Relative Frequency of Goal Times by Minute of Match (Excluding Minute 0)', 
             fontsize=16, y=1.05)
plt.tight_layout()
plt.subplots_adjust(top=0.8)  # Add more vertical spacing between suptitle and plots
plt.show()

# %%
# Define 5-minute bins from 0 to 100
bins = list(range(0, 101, 5))

# Filter out zero-minute goals
goals_eu_uefa_filtered = goals_eu_uefa[goals_eu_uefa['goal_minute'] > 0]
goals_wc_fifa_filtered = goals_wc_fifa[goals_wc_fifa['goal_minute'] > 0]

# Plot setup
fig, axes = plt.subplots(1, 2, figsize=(16, 5), sharey=True)

# UEFA European Championships
axes[0].hist(goals_eu_uefa_filtered['goal_minute'], bins=bins, density=True,
             color='0.5', edgecolor='black')  # medium grey
axes[0].set_title('UEFA European Championships')
axes[0].set_xlabel('Minute of Goal (5-min intervals)')
axes[0].set_ylabel('Density')
axes[0].grid(True)

# FIFA World Cups
axes[1].hist(goals_wc_fifa_filtered['goal_minute'], bins=bins, density=True,
             color='0.7', edgecolor='black')  # lighter grey
axes[1].set_title('FIFA World Cups')
axes[1].set_xlabel('Minute of Goal (5-min intervals)')
axes[1].grid(True)

# Add suptitle and adjust spacing
fig.suptitle('Relative Frequency of Goal Times by 5-Minute Intervals (Excluding Minute 0)',
             fontsize=16, y=1.05)
plt.tight_layout()
plt.subplots_adjust(top=0.8)
plt.savefig(os.path.join(save_dir, "gls_dist.png"), dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Suspense Trajectory Analysis (Stable vs Volatile Groups)

# %%
def plot_suspense_trajectory(goals_df, mbm_df, title="Suspense Trajectory", save_path=None):
    """
    Plots suspense trajectories for 'Stable' vs 'Volatile' groups based on avg_qual_count.

    Parameters:
    - goals_df: DataFrame with group-level info (must include 'year', 'group', 'avg_qual_count')
    - mbm_df:   Minute-by-minute dataset (must include 'year', 'stage', 'match_minute', 'suspense')
    - title:    Title of the plot (string)

    Output:
    - A matplotlib plot showing average suspense trajectories by group volatility
    """
    
    # Define volatility threshold (median of qualification changes)
    volatility_threshold = goals_df['avg_qual_count'].median()
    goals_df = goals_df.copy()
    goals_df['volatility'] = goals_df['avg_qual_count'].apply(
        lambda x: 'Volatile' if x > volatility_threshold else 'Stable'
    )

    # Merge volatility classification into minute-level data
    mbm_merged = mbm_df.merge(
        goals_df[['year', 'group', 'volatility']].rename(columns={'group': 'stage'}),
        on=['year', 'stage'],
        how='left'
    )

    # Compute average suspense by minute and volatility type
    suspense_trajectory = (
        mbm_merged.groupby(['match_minute', 'volatility'])['suspense']
        .mean()
        .reset_index()
    )

    # Plot
    plt.figure(figsize=(10, 6))
    colors = {'Stable': '0.3', 'Volatile': '0.6'}  # greyscale

    for label, df_group in suspense_trajectory.groupby('volatility'):
        plt.plot(df_group['match_minute'], df_group['suspense'],
                 label=label, color=colors[label], linewidth=2)

    plt.title(title)
    plt.xlabel("Minute")
    plt.ylabel("Average Suspense")
    plt.legend(title="Group Type")
    plt.grid(True, linestyle="--", linewidth=0.5, color="0.8")
    plt.tight_layout()
    if save_path is not None:
        plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show()

# %%
# UEFA example
plot_suspense_trajectory(
    agg_goals_eu_uefa, mbm_eu_uefa,
    title="Average Suspense by Volatility - Europe Championship (UEFA)",
    save_path=os.path.join(save_dir, "susp_traj_eu_uefa.png"))

# FIFA example
plot_suspense_trajectory(
    agg_goals_eu_fifa, mbm_eu_fifa,
    title="Average Suspense by Volatility - Europe Championship (FIFA)",
    save_path=os.path.join(save_dir, "susp_traj_eu_fifa.png"))

# %%
# UEFA example
plot_suspense_trajectory(
    agg_goals_wc_uefa, mbm_wc_uefa,
    title="Average Suspense by Volatility - World Cup (UEFA)",
    save_path=os.path.join(save_dir, "susp_traj_wc_uefa.png"))

# FIFA example
plot_suspense_trajectory(
    agg_goals_wc_fifa, mbm_wc_fifa,
    title="Average Suspense by Volatility - World Cup (FIFA)",
    save_path=os.path.join(save_dir, "susp_traj_wc_fifa.png"))

# %% [markdown]
# In this analysis, each minute-by-minute observation is labeled as belonging to either a "stable" or "volatile" group based on the average number of qualification changes (`avg_qual_count`) observed in its group (defined by year and stage). Groups with an `avg_qual_count` above the median are classified as volatile, while those below are considered stable. This classification is then merged into the minute-level dataset, allowing us to track how suspense evolves over time for the two types of groups. For each minute of play, we compute the average suspense separately for all observations in stable and volatile groups, creating two suspense trajectories.

# %% [markdown]
# ## Avg suspense per minute UEFA vs FIFA

# %%
# Group and compute average suspense per minute
suspense_fifa = mbm_eu_fifa.groupby('match_minute')['suspense'].mean().reset_index(name='suspense_fifa')
suspense_uefa = mbm_eu_uefa.groupby('match_minute')['suspense'].mean().reset_index(name='suspense_uefa')

# Merge on match_minute
suspense_comparison = pd.merge(suspense_uefa, suspense_fifa, on='match_minute')

# %%
plt.figure(figsize=(10, 6))
plt.plot(suspense_comparison['match_minute'], suspense_comparison['suspense_uefa'], label='UEFA Rules', linewidth=2)
plt.plot(suspense_comparison['match_minute'], suspense_comparison['suspense_fifa'], label='FIFA Rules', linewidth=2)
plt.xlabel('Minute')
plt.ylabel('Average Suspense')
plt.title('Suspense Trajectory in the European Championship: FIFA vs UEFA Tie-breaking Criteria')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot in greyscale
plt.figure(figsize=(10, 6))
plt.plot(
    suspense_comparison['match_minute'], suspense_comparison['suspense_uefa'],
    label='UEFA Rules', color='0.3', linewidth=2  
)
plt.plot(
    suspense_comparison['match_minute'], suspense_comparison['suspense_fifa'],
    label='FIFA Rules', color='0.6', linewidth=2
)

plt.xlabel('Minute')
plt.ylabel('Average Suspense')
plt.title('Suspense Trajectory by minute in the European Championship')
plt.legend()
plt.grid(True, linestyle='--', linewidth=0.5, color='0.8')
plt.tight_layout()
plt.savefig(os.path.join(save_dir, "susp_minute_eu.png"), dpi=300, bbox_inches="tight")
plt.show()

# %%
# Group and compute average suspense per minute
suspense_fifa_wc = mbm_wc_fifa.groupby('match_minute')['suspense'].mean().reset_index(name='suspense_fifa')
suspense_uefa_wc = mbm_wc_uefa.groupby('match_minute')['suspense'].mean().reset_index(name='suspense_uefa')

# Merge on match_minute
suspense_comparison_wc = pd.merge(suspense_uefa_wc, suspense_fifa_wc, on='match_minute')

# %%
plt.figure(figsize=(10, 6))
plt.plot(suspense_comparison_wc['match_minute'], suspense_comparison_wc['suspense_uefa'], label='UEFA Rules', linewidth=2)
plt.plot(suspense_comparison_wc['match_minute'], suspense_comparison_wc['suspense_fifa'], label='FIFA Rules', linewidth=2)
plt.xlabel('Minute')
plt.ylabel('Average Suspense')
plt.title('Suspense Trajectory in the World Cup: FIFA vs UEFA Tie-breaking Criteria')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot in greyscale
plt.figure(figsize=(10, 6))
plt.plot(
    suspense_comparison_wc['match_minute'], suspense_comparison_wc['suspense_uefa'],
    label='UEFA Rules', color='0.3', linewidth=2  
)
plt.plot(
    suspense_comparison_wc['match_minute'], suspense_comparison_wc['suspense_fifa'],
    label='FIFA Rules', color='0.6', linewidth=2
)

plt.xlabel('Minute')
plt.ylabel('Average Suspense')
plt.title('Suspense Trajectory by minute in the World Cup')
plt.legend()
plt.grid(True, linestyle='--', linewidth=0.5, color='0.8')
plt.tight_layout()
plt.savefig(os.path.join(save_dir, "susp_minute_wc.png"), dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Suspense, Surpise, Shock as defined in literature

# %%
def plot_sss_comparison(
    eu_df: pd.DataFrame,
    wc_df: pd.DataFrame,
    eu_label: str = "UEFA",
    wc_label: str = "FIFA",
    save_dir: Optional[str] = None,    
    file_prefix: str = "sss_compare",
    greyscale: bool = True,
    linewidth: float = 2.0,
    figsize=(10, 5),
):
    """
    Compare per-minute Shock/Surprise/Suspense between two datasets (e.g., sss_eu vs sss_wc),
    where each dataset has columns: ['minute','suspense','shock','surprise', 'year','stage', ...].

    Parameters
    ----------
    eu_df : DataFrame
        First dataset (e.g., sss_eu or sss_eu_csato).
    wc_df : DataFrame
        Second dataset (e.g., sss_wc or sss_wc_csato).
    eu_label : str
        Legend label for the first dataset (default "UEFA").
    wc_label : str
        Legend label for the second dataset (default "FIFA").
    save_dir : str | None
        If provided, figures will be saved into this directory as PNGs.
    file_prefix : str
        Prefix for saved filenames (e.g., "elo" or "csato").
    greyscale : bool
        If True, use greyscale lines; otherwise use default matplotlib colors.
    linewidth : float
        Line width for plots.
    figsize : tuple
        Figure size for each plot.

    Returns
    -------
    out : dict
        {
            'eu_agg': DataFrame of group-level aggregates for EU dataset,
            'wc_agg': DataFrame of group-level aggregates for WC dataset,
            'minute': {
                'shock': merged per-minute DataFrame,
                'surprise': merged per-minute DataFrame,
                'suspense': merged per-minute DataFrame,
            }
        }
    """

    # Ensure save dir exists if requested
    if save_dir is not None:
        os.makedirs(save_dir, exist_ok=True)

    # 1) Drop rows with all-zero sss columns
    sss_cols = ['shock', 'surprise', 'suspense']
    eu = eu_df.loc[~(eu_df[sss_cols] == 0).all(axis=1)].copy()
    wc = wc_df.loc[~(wc_df[sss_cols] == 0).all(axis=1)].copy()

    # 2) Group-level aggregates (useful to report in tables)
    eu_agg = eu.groupby(['year', 'stage'], as_index=False).agg(
        avg_suspense=('suspense', 'mean'),
        avg_surprise=('surprise', 'mean'),
        avg_shock=('shock', 'mean'),
    )
    wc_agg = wc.groupby(['year', 'stage'], as_index=False).agg(
        avg_suspense=('suspense', 'mean'),
        avg_surprise=('surprise', 'mean'),
        avg_shock=('shock', 'mean'),
    )

    # 3) Per-minute means
    suspense_eu = eu.groupby('minute', as_index=False)['suspense'].mean().rename(columns={'suspense': f'suspense_{eu_label.lower()}'})
    shock_eu    = eu.groupby('minute', as_index=False)['shock'].mean().rename(columns={'shock': f'shock_{eu_label.lower()}'})
    surprise_eu = eu.groupby('minute', as_index=False)['surprise'].mean().rename(columns={'surprise': f'surprise_{eu_label.lower()}'})

    suspense_wc = wc.groupby('minute', as_index=False)['suspense'].mean().rename(columns={'suspense': f'suspense_{wc_label.lower()}'})
    shock_wc    = wc.groupby('minute', as_index=False)['shock'].mean().rename(columns={'shock': f'shock_{wc_label.lower()}'})
    surprise_wc = wc.groupby('minute', as_index=False)['surprise'].mean().rename(columns={'surprise': f'surprise_{wc_label.lower()}'})

    # Merge per-minute series
    shock_df    = pd.merge(shock_eu,    shock_wc,    on='minute', how='inner')
    surprise_df = pd.merge(surprise_eu, surprise_wc, on='minute', how='inner')
    suspense_df = pd.merge(suspense_eu, suspense_wc, on='minute', how='inner')

    # 4) Plotting helper
    if greyscale:
        col1, col2 = '0.3', '0.6'  # dark grey, light grey
    else:
        col1, col2 = None, None    # matplotlib defaults

    def _plot_line(df, y1, y2, title, ylab, fname):
        plt.figure(figsize=figsize)
        plt.plot(df['minute'], df[y1], label=f'{eu_label} {ylab}', color=col1, linewidth=linewidth)
        plt.plot(df['minute'], df[y2], label=f'{wc_label} {ylab}', color=col2, linewidth=linewidth)
        plt.title(f'Average {ylab} Tilted per Minute : {eu_label} vs {wc_label}')
        plt.xlabel('Minute')
        plt.ylabel(f'Average {ylab}')
        plt.legend()
        plt.grid(True, linestyle='--', linewidth=0.5, color='0.8' if greyscale else None)
        plt.tight_layout()
        if save_dir is not None:
            path = os.path.join(save_dir, f"{file_prefix}_{fname}.png")
            plt.savefig(path, dpi=300, bbox_inches='tight')
        plt.show()

    # 5) Make the three plots
    _plot_line(
        shock_df,
        y1=f'shock_{eu_label.lower()}',
        y2=f'shock_{wc_label.lower()}',
        title='Average Shock per Minute',
        ylab='Shock',
        fname='shock'
    )

    _plot_line(
        surprise_df,
        y1=f'surprise_{eu_label.lower()}',
        y2=f'surprise_{wc_label.lower()}',
        title='Average Surprise per Minute',
        ylab='Surprise',
        fname='surprise'
    )

    _plot_line(
        suspense_df,
        y1=f'suspense_{eu_label.lower()}',
        y2=f'suspense_{wc_label.lower()}',
        title='Average Suspense per Minute',
        ylab='Suspense',
        fname='suspense'
    )

    # 6) Return useful data
    return {
        'eu_agg': eu_agg,
        'wc_agg': wc_agg,
        'minute': {
            'shock': shock_df,
            'surprise': surprise_df,
            'suspense': suspense_df,
        }
    }

# %%
out_elo = plot_sss_comparison(
    sss_eu, sss_wc,
    eu_label="UEFA", wc_label="FIFA",
    save_dir=save_dir, file_prefix="elo", greyscale=True
)

# %%
out_csato = plot_sss_comparison(
    sss_eu_csato, sss_wc_csato,
    eu_label="UEFA", wc_label="FIFA",
    save_dir=save_dir, file_prefix="csato", greyscale=True
)

# %% [markdown]
# # merge suspsense at match level with group level

# %%
# Keep only the needed columns and rename suspense -> suspense_group
goals_subset_eu = goals_eu_uefa[['goal_minute', 'year', 'stage', 'home_team','away_team', 'suspense','2nd', '3rd','4th', 'third_qualify']].rename(
    columns={'suspense': 'suspense_group'}
)

# Merge with sss_eu
sss_agg_eu = goals_subset_eu.merge(
    sss_eu,
    left_on=['goal_minute', 'year', 'stage', 'home_team', 'away_team'],
    right_on=['minute', 'year', 'stage', 'home_team', 'away_team'],
    how='left'
)

# %%
# Keep only the needed columns and rename suspense -> suspense_group
goals_subset_wc = goals_wc_fifa[['goal_minute', 'year', 'stage', 'home_team','away_team', 'suspense','2nd', '3rd','4th', 'third_qualify']].rename(
    columns={'suspense': 'suspense_group'}
)

# Merge with sss_eu
sss_agg_wc = goals_subset_wc.merge(
    sss_wc,
    left_on=['goal_minute', 'year', 'stage', 'home_team', 'away_team'],
    right_on=['minute', 'year', 'stage', 'home_team', 'away_team'],
    how='left'
)

# %% [markdown]
# # Combine suspense at match level with group level

# %%
def _adjust_group_motivation(row, boost=0.20, gamma=0.7):
    """
    Row-wise softmax tilt applied whenever suspense_group == 1.

    Identifies the 'bubble' team - the one on the qualifying boundary that is
    motivated to win - and shifts its win probability up and loss probability
    down, leaving draw approximately unchanged (before renormalisation).

    third_qualify == 0 (boundary: 2nd vs 3rd):
      - Standard case:       3rd threatens 2nd  -> motivated = 3rd team.
      - Outside-threat case: 4th threatens 2nd  -> motivated = 4th team.
      We pick whichever of {3rd, 4th} is actually playing in this match.
      This covers the audit_suspense0_where_4th_threatens_2nd rows whose
      suspense flag was manually set to 1 in the tb_eu / tb_wc notebooks.

    third_qualify == 1 (boundary: 3rd vs 4th):
      motivated = 4th team (standard lagging team).

    Parameters
    ----------
    boost : float
        Raw magnitude of the motivation effect in log-odds space (default 0.20).
    gamma : float
        Discount on boost; only the product gamma*boost matters (default 0.7,
        giving an effective tilt of 0.14).
    """
    ph  = row.get('P_home')
    pd_ = row.get('P_draw')
    pa  = row.get('P_away')

    if any(x is None or (isinstance(x, float) and np.isnan(x)) for x in [ph, pd_, pa]):
        return ph, pd_, pa

    p = np.array([ph, pd_, pa], dtype=float)
    p = np.clip(p, 1e-12, 1.0)
    p /= p.sum()

    if int(row.get('suspense_group', 0)) != 1:
        return p[0], p[1], p[2]

    home = row.get('home_team')
    away = row.get('away_team')

    motivated = None
    if row.get('third_qualify') == 0:
        third  = row.get('3rd')
        fourth = row.get('4th')
        # Standard boundary: 3rd threatens 2nd.
        # Outside-threat:    4th threatens 2nd (manually-corrected suspense rows).
        # Tilt whichever bubble team is participating in this specific match.
        if third in (home, away):
            motivated = third
        elif fourth in (home, away):
            motivated = fourth
    elif row.get('third_qualify') == 1:
        motivated = row.get('4th')

    favor_idx = None
    if isinstance(motivated, str):
        if motivated == home:
            favor_idx = 0
        elif motivated == away:
            favor_idx = 2

    if favor_idx is None:
        return p[0], p[1], p[2]

    # softmax tilt: push win up, loss down (draw weight = exp(0) = 1, neutral)
    direction = np.array([+1.0, 0.0, -1.0]) if favor_idx == 0 else np.array([-1.0, 0.0, +1.0])
    weights   = np.exp(gamma * boost * direction)
    p_tilt    = p * weights
    p_tilt   /= p_tilt.sum()
    return p_tilt[0], p_tilt[1], p_tilt[2]

# %%
def _compute_sss_from_adjusted(curr_vec, prev_vec, lam=1.0):
    """
    curr_vec, prev_vec: length-3 arrays (P_home_adj, P_draw_adj, P_away_adj).
    suspense uses your SUM definition scaled by lam.
    """
    curr = np.asarray(curr_vec, dtype=float)
    prev = np.asarray(prev_vec, dtype=float)

    dP = curr - prev
    surprise = float(np.abs(dP).sum())
    shock    = float(np.abs(dP).max())

    # your original SUM form:
    suspense = float(lam * ((curr[0]*(1-curr[0])) + (curr[1]*(1-curr[1])) + (curr[2]*(1-curr[2]))))

    return {
        'dP_home_adj': dP[0],
        'dP_draw_adj': dP[1],
        'dP_away_adj': dP[2],
        'surprise_adj': surprise,
        'shock_adj': shock,
        'suspense_adj': suspense,
    }

# %%
def update_probs_and_sss(
    merged_df: pd.DataFrame,
    boost: float = 0.20,
    gamma: float = 0.7,
    lam_value: float = None,
    lam_col: str = None,
):
    """
    Update probabilities and SSS using the group-motivation logic.

    Inputs
    ------
    merged_df : DataFrame containing at least:
        ['year','stage','home_team','away_team','goal_minute',
         'P_home','P_draw','P_away','suspense_group','third_qualify','3rd','4th']
        (plus optional lam column if lam_col is provided)
    boost, gamma : tilt parameters for the motivation effect.
    lam_value : if provided, use this constant lam everywhere.
    lam_col   : if provided, read lam per-row from merged_df[lam_col].
                If both are None, lam defaults to 1.0.

    Returns
    -------
    DataFrame with added columns:
        ['P_home_adj','P_draw_adj','P_away_adj',
         'dP_home_adj','dP_draw_adj','dP_away_adj',
         'surprise_adj','shock_adj','suspense_adj']
    """
    df = merged_df.copy()

    # process match-by-match, minute order
    key_cols = ['year', 'stage', 'home_team', 'away_team']
    out = []

    for _, match in df.sort_values('goal_minute').groupby(key_cols, sort=False):
        match = match.sort_values('goal_minute').copy()

        # minute 0 (or first row) â€” compute adjusted start probs
        ph0, pd0, pa0 = _adjust_group_motivation(match.iloc[0], boost=boost, gamma=gamma)
        match.loc[match.index[0], 'P_home_adj'] = ph0
        match.loc[match.index[0], 'P_draw_adj'] = pd0
        match.loc[match.index[0], 'P_away_adj'] = pa0

        lam0 = (
            float(match.iloc[0][lam_col]) if (lam_col and lam_col in match.columns) else
            (float(lam_value) if lam_value is not None else 1.0)
        )
        sss0 = _compute_sss_from_adjusted([ph0, pd0, pa0], [ph0, pd0, pa0], lam=lam0)
        for k, v in sss0.items():
            match.loc[match.index[0], k] = v

        prev_vec = np.array([ph0, pd0, pa0], dtype=float)

        # subsequent rows
        for ridx in match.index[1:]:
            row = match.loc[ridx]
            ph, pd_, pa = _adjust_group_motivation(row, boost=boost, gamma=gamma)
            match.loc[ridx, 'P_home_adj'] = ph
            match.loc[ridx, 'P_draw_adj'] = pd_
            match.loc[ridx, 'P_away_adj'] = pa

            lam_here = (
                float(row[lam_col]) if (lam_col and lam_col in match.columns) else
                (float(lam_value) if lam_value is not None else 1.0)
            )

            sss = _compute_sss_from_adjusted([ph, pd_, pa], prev_vec, lam=lam_here)
            for k, v in sss.items():
                match.loc[ridx, k] = v

            prev_vec = np.array([ph, pd_, pa], dtype=float)

        out.append(match)

    return pd.concat(out, ignore_index=True)

# %%
# Minimal use (no external Î»): lam defaults to 1.0
sss_agg_eu = update_probs_and_sss(sss_agg_eu)

# If you have a per-row lambda column (e.g., 'lam'):
sss_agg_eu = update_probs_and_sss(sss_agg_eu, lam_col='lam')

# Or a constant scaler for this run:
sss_agg_eu = update_probs_and_sss(sss_agg_eu, lam_value=0.013)

# %%
# Minimal use (no external Î»): lam defaults to 1.0
sss_agg_wc = update_probs_and_sss(sss_agg_wc)

# If you have a per-row lambda column (e.g., 'lam'):
sss_agg_wc = update_probs_and_sss(sss_agg_wc, lam_col='lam')

# Or a constant scaler for this run:
sss_agg_wc = update_probs_and_sss(sss_agg_wc, lam_value=0.013)

# %%
# # Exporting final df
# file_path = rf'C:\Users\{user}\Documents\GitHub\tb_football\data\out\sss_agg_eu.xlsx'
# sss_agg_eu.to_excel(file_path, index=False)

# %%
out_agg = plot_sss_comparison(
    sss_agg_eu, sss_agg_wc,
    eu_label="UEFA", wc_label="FIFA",
    save_dir=save_dir, file_prefix="agg", greyscale=True
)
