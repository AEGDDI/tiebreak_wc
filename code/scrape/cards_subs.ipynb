# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from getpass import getuser
import re

# %%
user = getuser()

# %%
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\cards_subs_wc.xlsx'

# %%
# Years and group stages
world_cup_years = list(range(1986, 2023, 4))
group_letters = ['Group_' + chr(i) for i in range(ord('A'), ord('H') + 1)]
base_url = 'https://en.wikipedia.org/wiki/{}_FIFA_World_Cup_{}'

event_rows = []

# %%
# === MAIN SCRAPER ===
for year in world_cup_years:
    print(f"\n=== {year} ===")
    for group in group_letters:
        page_url = base_url.format(year, group)
        try:
            response = requests.get(page_url)
            if response.status_code != 200:
                print(f"  Skipping {group} (not found)")
                continue

            soup = BeautifulSoup(response.content, 'html.parser')
            print(f"  Scraping {group}...")

            for fevent_table in soup.find_all('table', class_='fevent'):
                tbody = fevent_table.find('tbody')
                if not tbody:
                    continue

                # === HOME & AWAY TEAMS ===
                home_th = tbody.find('th', class_='fhome')
                away_th = tbody.find('th', class_='faway')
                home_span = home_th.find('span', itemprop='name') if home_th else None
                away_span = away_th.find('span', itemprop='name') if away_th else None
                home_team = home_span.get_text(strip=True) if home_span else None
                away_team = away_span.get_text(strip=True) if away_span else None
                print(f"🔍 Processing match: {home_team} vs {away_team} ({match_date})")


                # === MATCH DATE & TIME ===
                footballbox = fevent_table.find_previous('div', class_='footballbox')
                match_date = footballbox.find('div', class_='fdate').get_text(strip=True) if footballbox and footballbox.find('div', class_='fdate') else None
                match_time = footballbox.find('div', class_='ftime').get_text(strip=True).replace("\xa0", "") if footballbox and footballbox.find('div', class_='ftime') else None

                # === FIND EVENT TABLE ===
                event_table = fevent_table.find_next('table', attrs={'width': '100%'})
                if not event_table:
                    continue
                event_tbody = event_table.find('tbody')
                if not event_tbody:
                    continue

                for row in event_tbody.find_all('tr'):
                    tds = [td for td in row.find_all('td', attrs={'valign': 'top'}) if td.get('width') in ['50%', '40%']]
                    if len(tds) == 2:
                        td_pairs = [(tds[0], 'home'), (tds[1], 'away')]
                    elif len(tds) == 3:
                        td_pairs = [(tds[0], 'home'), (tds[2], 'away')]
                    else:
                        continue  # Skip if unexpected format

                    # Make sure exactly one home and one away (no repeats)
                    team_sides = [side for _, side in td_pairs]
                    if team_sides != ['home', 'away']:
                        continue

                    for td, team_side in td_pairs:
                        nested_table = td.find('table')
                        if not nested_table:
                            continue
                        nested_body = nested_table.find('tbody')
                        if not nested_body:
                            continue

                        for event_row in nested_body.find_all('tr'):
                            for event_td in event_row.find_all('td'):
                                spans = event_td.find_all('span', title=True)
                                titles = [s['title'].strip() for s in spans]

                                if not any(t in titles for t in ['Booked', 'Sent off (second booking)', 'Sent off (straight red)', 'Substituted in']):
                                    continue

                                raw_text = event_td.get_text(strip=True)
                                minute_match = re.search(r'\d{1,4}', raw_text)
                                if not minute_match:
                                    continue
                                raw_minute = minute_match.group()

                                booked_added = False

                                for title in titles:
                                    minute_texts = re.findall(r'\d{1,3}\+?\d{0,2}', raw_text)

                                    if title == 'Booked' and not booked_added:
                                        if minute_texts:
                                            raw_minute_str = minute_texts[0]
                                            if '+' in raw_minute_str:
                                                base, extra = raw_minute_str.split('+')
                                                minute = int(base) + int(extra)
                                            else:
                                                minute = int(raw_minute_str)
                                            event_type = 'Yellow card'
                                            booked_added = True

                                    elif title == 'Sent off (second booking)':
                                        if len(minute_texts) >= 2:
                                            raw_minute_str = minute_texts[1]
                                        elif minute_texts:
                                            raw_minute_str = minute_texts[-1]
                                        else:
                                            continue
                                        if '+' in raw_minute_str:
                                            base, extra = raw_minute_str.split('+')
                                            minute = int(base) + int(extra)
                                        else:
                                            minute = int(raw_minute_str)
                                        event_type = 'Red card (second yellow)'

                                    elif title == 'Sent off (straight red)':
                                        if len(minute_texts) >= 2:
                                            raw_minute_str = minute_texts[1]
                                        elif minute_texts:
                                            raw_minute_str = minute_texts[-1]
                                        else:
                                            continue
                                        if '+' in raw_minute_str:
                                            base, extra = raw_minute_str.split('+')
                                            minute = int(base) + int(extra)
                                        else:
                                            minute = int(raw_minute_str)
                                        event_type = 'Red card (straight)'

                                    elif title == 'Substituted in':
                                        if minute_texts:
                                            raw_minute_str = minute_texts[0]
                                            if '+' in raw_minute_str:
                                                base, extra = raw_minute_str.split('+')
                                                minute = int(base) + int(extra)
                                            else:
                                                minute = int(raw_minute_str)
                                            event_type = 'Substitution'

                                    else:
                                        continue

                                    event_rows.append({
                                        'year': year,
                                        'stage': group.replace('_', ' '),
                                        'home_team': home_team,
                                        'away_team': away_team,
                                        'date': match_date,
                                        'time': match_time,
                                        'event_type': event_type,
                                        'minute': minute,
                                        'team_side': team_side
                                    })

            time.sleep(1)

        except Exception as e:
            print(f"  Error for {group}: {e}")

# === SAVE TO EXCEL ===
df = pd.DataFrame(event_rows)
# df.drop_duplicates(inplace=True)

if df.empty:
    print("\n⚠️ No data collected.")
else:
    expected_cols = ['year', 'stage', 'home_team', 'away_team', 'date', 'time', 'event_type', 'minute', 'team_side']
    missing = [col for col in expected_cols if col not in df.columns]

    if missing:
        print(f"\n❌ Missing columns: {missing}")
        print(df.head())
    else:
        df = df[expected_cols]
        df.to_excel(data_path, index=False)
        print(f"\n✅ Clean Excel file saved to: {data_path}")
# Out:
# === 1986 ===
#   Scraping Group_A...
# 🔍 Processing match: Bulgaria vs Italy (2 December 2022(2022-12-02))
# 🔍 Processing match: Argentina vs South Korea (31 May 1986)
# 🔍 Processing match: Italy vs Argentina (2 June 1986)
# 🔍 Processing match: South Korea vs Bulgaria (5 June 1986)
# 🔍 Processing match: South Korea vs Italy (5 June 1986)
# 🔍 Processing match: Argentina vs Bulgaria (10 June 1986)
#   Scraping Group_B...
# 🔍 Processing match: Belgium vs Mexico (10 June 1986)
# 🔍 Processing match: Paraguay vs Iraq (3 June 1986)
# 🔍 Processing match: Mexico vs Paraguay (4 June 1986)
# 🔍 Processing match: Iraq vs Belgium (7 June 1986)
# 🔍 Processing match: Paraguay vs Belgium (8 June 1986)
# 🔍 Processing match: Iraq vs Mexico (11 June 1986)
#   Scraping Group_C...
# 🔍 Processing match: Canada vs France (11 June 1986)
# 🔍 Processing match: Soviet Union vs Hungary (1 June 1986)
# 🔍 Processing match: France vs Soviet Union (2 June 1986)
# 🔍 Processing match: Hungary vs Canada (5 June 1986)
# 🔍 Processing match: Hungary vs France (6 June 1986)
# 🔍 Processing match: Soviet Union vs Canada (9 June 1986)
#   Scraping Group_D...
# 🔍 Processing match: Spain vs Brazil (9 June 1986)
# 🔍 Processing match: Algeria vs Northern Ireland (1 June 1986)
# 🔍 Processing match: Brazil vs Algeria (3 June 1986)
# 🔍 Processing match: Northern Ireland vs Spain (6 June 1986)
# 🔍 Processing match: Northern Ireland vs Brazil (7 June 1986)
# 🔍 Processing match: Algeria vs Spain (12 June 1986)
#   Scraping Group_E...
# 🔍 Processing match: Uruguay vs West Germany (12 June 1986)
# 🔍 Processing match: Scotland vs Denmark (4 June 1986)
# 🔍 Processing match: West Germany vs Scotland (4 June 1986)
# 🔍 Processing match: Denmark vs Uruguay (8 June 1986)
# 🔍 Processing match: Denmark vs West Germany (8 June 1986)
# 🔍 Processing match: Scotland vs Uruguay (13 June 1986)
#   Scraping Group_F...
# 🔍 Processing match: Morocco vs Poland (13 June 1986)
# 🔍 Processing match: Portugal vs England (2 June 1986)
# 🔍 Processing match: England vs Morocco (3 June 1986)
# 🔍 Processing match: Poland vs Portugal (6 June 1986)
# 🔍 Processing match: England vs Poland (7 June 1986)
# 🔍 Processing match: Portugal vs Morocco (11 June 1986)
#   Skipping Group_G (not found)
#   Skipping Group_H (not found)
#
# === 1990 ===
#   Scraping Group_A...
# 🔍 Processing match: Italy vs Austria (11 June 1986)
# 🔍 Processing match: United States vs Czechoslovakia (9 June 1990)
# 🔍 Processing match: Italy vs United States (10 June 1990)
# 🔍 Processing match: Austria vs Czechoslovakia (14 June 1990)
# 🔍 Processing match: Italy vs Czechoslovakia (15 June 1990)
# 🔍 Processing match: Austria vs United States (19 June 1990)
#   Scraping Group_B...
# 🔍 Processing match: Argentina vs Cameroon (19 June 1990)
# 🔍 Processing match: Soviet Union vs Romania (8 June 1990)
# 🔍 Processing match: Argentina vs Soviet Union (9 June 1990)
# 🔍 Processing match: Cameroon vs Romania (13 June 1990)
# 🔍 Processing match: Argentina vs Romania (14 June 1990)
# 🔍 Processing match: Cameroon vs Soviet Union (18 June 1990)
#   Scraping Group_C...
# 🔍 Processing match: Brazil vs Sweden (18 June 1990)
# 🔍 Processing match: Costa Rica vs Scotland (10 June 1990)
# 🔍 Processing match: Brazil vs Costa Rica (11 June 1990)
# 🔍 Processing match: Sweden vs Scotland (16 June 1990)
# 🔍 Processing match: Brazil vs Scotland (16 June 1990)
# 🔍 Processing match: Sweden vs Costa Rica (20 June 1990)
#   Scraping Group_D...
# 🔍 Processing match: United Arab Emirates vs Colombia (20 June 1990)
# 🔍 Processing match: West Germany vs Yugoslavia (9 June 1990)
# 🔍 Processing match: Yugoslavia vs Colombia (10 June 1990)
# 🔍 Processing match: West Germany vs United Arab Emirates (14 June 1990)
# 🔍 Processing match: West Germany vs Colombia (15 June 1990)
# 🔍 Processing match: Yugoslavia vs United Arab Emirates (19 June 1990)
#   Scraping Group_E...
# 🔍 Processing match: Belgium vs South Korea (19 June 1990)
# 🔍 Processing match: Uruguay vs Spain (12 June 1990)
# 🔍 Processing match: Belgium vs Uruguay (13 June 1990)
# 🔍 Processing match: South Korea vs Spain (17 June 1990)
# 🔍 Processing match: Belgium vs Spain (17 June 1990)
# 🔍 Processing match: South Korea vs Uruguay (21 June 1990)
#   Scraping Group_F...
# 🔍 Processing match: England vs Republic of Ireland (21 June 1990)
# 🔍 Processing match: Netherlands vs Egypt (11 June 1990)
# 🔍 Processing match: England vs Netherlands (12 June 1990)
# 🔍 Processing match: Republic of Ireland vs Egypt (16 June 1990)
# 🔍 Processing match: England vs Egypt (17 June 1990)
# 🔍 Processing match: Republic of Ireland vs Netherlands (21 June 1990)
#   Skipping Group_G (not found)
#   Skipping Group_H (not found)
#
# === 1994 ===
#   Scraping Group_A...
# 🔍 Processing match: United States vs Switzerland (21 June 1990)
# 🔍 Processing match: Colombia vs Romania (June 18, 1994)
# 🔍 Processing match: Romania vs Switzerland (June 18, 1994)
# 🔍 Processing match: United States vs Colombia (June 22, 1994)
# 🔍 Processing match: Switzerland vs Colombia (June 22, 1994)
# 🔍 Processing match: United States vs Romania (June 26, 1994)
#   Scraping Group_B...
# 🔍 Processing match: Cameroon vs Sweden (June 26, 1994)
# 🔍 Processing match: Brazil vs Russia (June 19, 1994)
# 🔍 Processing match: Brazil vs Cameroon (June 20, 1994)
# 🔍 Processing match: Sweden vs Russia (June 24, 1994)
# 🔍 Processing match: Russia vs Cameroon (June 24, 1994)
# 🔍 Processing match: Brazil vs Sweden (June 28, 1994)
#   Scraping Group_C...
# 🔍 Processing match: Germany vs Bolivia (June 28, 1994)
# 🔍 Processing match: Spain vs South Korea (June 17, 1994)
# 🔍 Processing match: Germany vs Spain (June 17, 1994)
# 🔍 Processing match: South Korea vs Bolivia (June 21, 1994)
# 🔍 Processing match: Bolivia vs Spain (June 23, 1994)
# 🔍 Processing match: Germany vs South Korea (June 27, 1994)
#   Scraping Group_D...
# 🔍 Processing match: Argentina vs Greece (June 27, 1994)
# 🔍 Processing match: Nigeria vs Bulgaria (June 21, 1994)
# 🔍 Processing match: Argentina vs Nigeria (June 21, 1994)
# 🔍 Processing match: Bulgaria vs Greece (June 25, 1994)
# 🔍 Processing match: Argentina vs Bulgaria (June 26, 1994)
# 🔍 Processing match: Greece vs Nigeria (June 30, 1994)
#   Scraping Group_E...
# 🔍 Processing match: Italy vs Republic of Ireland (June 30, 1994)
# 🔍 Processing match: Norway vs Mexico (June 18, 1994)
# 🔍 Processing match: Italy vs Norway (June 19, 1994)
# 🔍 Processing match: Mexico vs Republic of Ireland (June 23, 1994)
# 🔍 Processing match: Italy vs Mexico (June 24, 1994)
# 🔍 Processing match: Republic of Ireland vs Norway (June 28, 1994)
#   Scraping Group_F...
# 🔍 Processing match: Belgium vs Morocco (June 28, 1994)
# 🔍 Processing match: Netherlands vs Saudi Arabia (June 19, 1994)
# 🔍 Processing match: Belgium vs Netherlands (June 20, 1994)
# 🔍 Processing match: Saudi Arabia vs Morocco (June 25, 1994)
# 🔍 Processing match: Belgium vs Saudi Arabia (June 25, 1994)
# 🔍 Processing match: Morocco vs Netherlands (June 29, 1994)
#   Skipping Group_G (not found)
#   Skipping Group_H (not found)
#
# === 1998 ===
#   Scraping Group_A...
# 🔍 Processing match: Brazil vs Scotland (June 29, 1994)
# 🔍 Processing match: Morocco vs Norway (10 June 1998)
# 🔍 Processing match: Scotland vs Norway (10 June 1998)
# 🔍 Processing match: Brazil vs Morocco (16 June 1998)
# 🔍 Processing match: Scotland vs Morocco (16 June 1998)
# 🔍 Processing match: Brazil vs Norway (23 June 1998)
#   Scraping Group_B...
# 🔍 Processing match: Italy vs Chile (23 June 1998)
# 🔍 Processing match: Cameroon vs Austria (11 June 1998)
# 🔍 Processing match: Chile vs Austria (11 June 1998)
# 🔍 Processing match: Italy vs Cameroon (17 June 1998)
# 🔍 Processing match: Italy vs Austria (17 June 1998)
# 🔍 Processing match: Chile vs Cameroon (23 June 1998)
#   Scraping Group_C...
# 🔍 Processing match: Saudi Arabia vs Denmark (23 June 1998)
# 🔍 Processing match: France vs South Africa (12 June 1998)
# 🔍 Processing match: South Africa vs Denmark (12 June 1998)
# 🔍 Processing match: France vs Saudi Arabia (18 June 1998)
# 🔍 Processing match: France vs Denmark (18 June 1998)
# 🔍 Processing match: South Africa vs Saudi Arabia (24 June 1998)
#   Scraping Group_D...
# 🔍 Processing match: Paraguay vs Bulgaria (24 June 1998)
# 🔍 Processing match: Spain vs Nigeria (12 June 1998)
# 🔍 Processing match: Nigeria vs Bulgaria (13 June 1998)
# 🔍 Processing match: Spain vs Paraguay (19 June 1998)
# 🔍 Processing match: Nigeria vs Paraguay (19 June 1998)
# 🔍 Processing match: Spain vs Bulgaria (24 June 1998)
#   Scraping Group_E...
# 🔍 Processing match: South Korea vs Mexico (24 June 1998)
# 🔍 Processing match: Netherlands vs Belgium (13 June 1998)
# 🔍 Processing match: Belgium vs Mexico (13 June 1998)
# 🔍 Processing match: Netherlands vs South Korea (20 June 1998)
# 🔍 Processing match: Netherlands vs Mexico (20 June 1998)
# 🔍 Processing match: Belgium vs South Korea (25 June 1998)
#   Scraping Group_F...
# 🔍 Processing match: FR Yugoslavia vs Iran (25 June 1998)
# 🔍 Processing match: Germany vs United States (14 June 1998)
# 🔍 Processing match: Germany vs FR Yugoslavia (15 June 1998)
# 🔍 Processing match: United States vs Iran (21 June 1998)
# 🔍 Processing match: Germany vs Iran (21 June 1998)
# 🔍 Processing match: United States vs FR Yugoslavia (25 June 1998)
#   Scraping Group_G...
# 🔍 Processing match: England vs Tunisia (25 June 1998)
# 🔍 Processing match: Romania vs Colombia (15 June 1998)
# 🔍 Processing match: Colombia vs Tunisia (15 June 1998)
# 🔍 Processing match: Romania vs England (22 June 1998)
# 🔍 Processing match: Colombia vs England (22 June 1998)
# 🔍 Processing match: Romania vs Tunisia (26 June 1998)
#   Scraping Group_H...
# 🔍 Processing match: Argentina vs Japan (26 June 1998)
# 🔍 Processing match: Jamaica vs Croatia (14 June 1998)
# 🔍 Processing match: Japan vs Croatia (14 June 1998)
# 🔍 Processing match: Argentina vs Jamaica (20 June 1998)
# 🔍 Processing match: Argentina vs Croatia (21 June 1998)
# 🔍 Processing match: Japan vs Jamaica (26 June 1998)
#
# === 2002 ===
#   Scraping Group_A...
# 🔍 Processing match: France vs Senegal (26 June 1998)
# 🔍 Processing match: Uruguay vs Denmark (31 May 2002)
# 🔍 Processing match: Denmark vs Senegal (1 June 2002)
# 🔍 Processing match: France vs Uruguay (6 June 2002)
# 🔍 Processing match: Denmark vs France (6 June 2002)
# 🔍 Processing match: Senegal vs Uruguay (11 June 2002)
#   Scraping Group_B...
# 🔍 Processing match: Paraguay vs South Africa (11 June 2002)
# 🔍 Processing match: Spain vs Slovenia (2 June 2002)
# 🔍 Processing match: Spain vs Paraguay (2 June 2002)
# 🔍 Processing match: South Africa vs Slovenia (7 June 2002)
# 🔍 Processing match: South Africa vs Spain (8 June 2002)
# 🔍 Processing match: Slovenia vs Paraguay (12 June 2002)
#   Scraping Group_C...
# 🔍 Processing match: Brazil vs Turkey (12 June 2002)
# 🔍 Processing match: China vs Costa Rica (3 June 2002)
# 🔍 Processing match: Brazil vs China (4 June 2002)
# 🔍 Processing match: Costa Rica vs Turkey (8 June 2002)
# 🔍 Processing match: Costa Rica vs Brazil (9 June 2002)
# 🔍 Processing match: Turkey vs China (13 June 2002)
#   Scraping Group_D...
# 🔍 Processing match: South Korea vs Poland (13 June 2002)
# 🔍 Processing match: United States vs Portugal (4 June 2002)
# 🔍 Processing match: South Korea vs United States (5 June 2002)
# 🔍 Processing match: Portugal vs Poland (10 June 2002)
# 🔍 Processing match: Portugal vs South Korea (10 June 2002)
# 🔍 Processing match: Poland vs United States (14 June 2002)
#   Scraping Group_E...
# 🔍 Processing match: Republic of Ireland vs Cameroon (14 June 2002)
# 🔍 Processing match: Germany vs Saudi Arabia (1 June 2002)
# 🔍 Processing match: Germany vs Republic of Ireland (1 June 2002)
# 🔍 Processing match: Cameroon vs Saudi Arabia (5 June 2002)
# 🔍 Processing match: Cameroon vs Germany (6 June 2002)
# 🔍 Processing match: Saudi Arabia vs Republic of Ireland (11 June 2002)
#   Scraping Group_F...
# 🔍 Processing match: Argentina vs Nigeria (11 June 2002)
# 🔍 Processing match: England vs Sweden (2 June 2002)
# 🔍 Processing match: Sweden vs Nigeria (2 June 2002)
# 🔍 Processing match: Argentina vs England (7 June 2002)
# 🔍 Processing match: Sweden vs Argentina (7 June 2002)
# 🔍 Processing match: Nigeria vs England (12 June 2002)
#   Scraping Group_G...
# 🔍 Processing match: Croatia vs Mexico (12 June 2002)
# 🔍 Processing match: Italy vs Ecuador (3 June 2002)
# 🔍 Processing match: Italy vs Croatia (3 June 2002)
# 🔍 Processing match: Mexico vs Ecuador (8 June 2002)
# 🔍 Processing match: Mexico vs Italy (9 June 2002)
# 🔍 Processing match: Ecuador vs Croatia (13 June 2002)
#   Scraping Group_H...
# 🔍 Processing match: Japan vs Belgium (13 June 2002)
# 🔍 Processing match: Russia vs Tunisia (4 June 2002)
# 🔍 Processing match: Japan vs Russia (5 June 2002)
# 🔍 Processing match: Tunisia vs Belgium (9 June 2002)
# 🔍 Processing match: Tunisia vs Japan (10 June 2002)
# 🔍 Processing match: Belgium vs Russia (14 June 2002)
#
# === 2006 ===
#   Scraping Group_A...
# 🔍 Processing match: Germany vs Costa Rica (14 June 2002)
# 🔍 Processing match: Poland vs Ecuador (9 June 2006)
# 🔍 Processing match: Germany vs Poland (9 June 2006)
# 🔍 Processing match: Ecuador vs Costa Rica (14 June 2006)
# 🔍 Processing match: Ecuador vs Germany (15 June 2006)
# 🔍 Processing match: Costa Rica vs Poland (20 June 2006)
#   Scraping Group_B...
# 🔍 Processing match: England vs Paraguay (20 June 2006)
# 🔍 Processing match: Trinidad and Tobago vs Sweden (10 June 2006)
# 🔍 Processing match: England vs Trinidad and Tobago (10 June 2006)
# 🔍 Processing match: Sweden vs Paraguay (15 June 2006)
# 🔍 Processing match: Sweden vs England (15 June 2006)
# 🔍 Processing match: Paraguay vs Trinidad and Tobago (20 June 2006)
#   Scraping Group_C...
# 🔍 Processing match: Argentina vs Ivory Coast (20 June 2006)
# 🔍 Processing match: Serbia and Montenegro vs Netherlands (10 June 2006)
# 🔍 Processing match: Argentina vs Serbia and Montenegro (11 June 2006)
# 🔍 Processing match: Netherlands vs Ivory Coast (16 June 2006)
# 🔍 Processing match: Netherlands vs Argentina (16 June 2006)
# 🔍 Processing match: Ivory Coast vs Serbia and Montenegro (21 June 2006)
#   Scraping Group_D...
# 🔍 Processing match: Mexico vs Iran (21 June 2006)
# 🔍 Processing match: Angola vs Portugal (11 June 2006)
# 🔍 Processing match: Mexico vs Angola (11 June 2006)
# 🔍 Processing match: Portugal vs Iran (16 June 2006)
# 🔍 Processing match: Portugal vs Mexico (17 June 2006)
# 🔍 Processing match: Iran vs Angola (21 June 2006)
#   Scraping Group_E...
# 🔍 Processing match: United States vs Czech Republic (21 June 2006)
# 🔍 Processing match: Italy vs Ghana (12 June 2006)
# 🔍 Processing match: Czech Republic vs Ghana (12 June 2006)
# 🔍 Processing match: Italy vs United States (17 June 2006)
# 🔍 Processing match: Czech Republic vs Italy (17 June 2006)
# 🔍 Processing match: Ghana vs United States (22 June 2006)
#   Scraping Group_F...
# 🔍 Processing match: Australia vs Japan (22 June 2006)
# 🔍 Processing match: Brazil vs Croatia (12 June 2006)
# 🔍 Processing match: Japan vs Croatia (13 June 2006)
# 🔍 Processing match: Brazil vs Australia (18 June 2006)
# 🔍 Processing match: Japan vs Brazil (18 June 2006)
# 🔍 Processing match: Croatia vs Australia (22 June 2006)
#   Scraping Group_G...
# 🔍 Processing match: South Korea vs Togo (22 June 2006)
# 🔍 Processing match: France vs Switzerland (13 June 2006)
# 🔍 Processing match: France vs South Korea (13 June 2006)
# 🔍 Processing match: Togo vs Switzerland (18 June 2006)
# 🔍 Processing match: Togo vs France (19 June 2006)
# 🔍 Processing match: Switzerland vs South Korea (23 June 2006)
#   Scraping Group_H...
# 🔍 Processing match: Spain vs Ukraine (23 June 2006)
# 🔍 Processing match: Tunisia vs Saudi Arabia (14 June 2006)
# 🔍 Processing match: Saudi Arabia vs Ukraine (14 June 2006)
# 🔍 Processing match: Spain vs Tunisia (19 June 2006)
# 🔍 Processing match: Saudi Arabia vs Spain (19 June 2006)
# 🔍 Processing match: Ukraine vs Tunisia (23 June 2006)
#
# === 2010 ===
#   Scraping Group_A...
# 🔍 Processing match: South Africa vs Mexico (23 June 2006)
# 🔍 Processing match: Uruguay vs France (11 June 2010)
# 🔍 Processing match: South Africa vs Uruguay (11 June 2010)
# 🔍 Processing match: France vs Mexico (16 June 2010)
# 🔍 Processing match: Mexico vs Uruguay (17 June 2010)
# 🔍 Processing match: France vs South Africa (22 June 2010)
#   Scraping Group_B...
# 🔍 Processing match: South Korea vs Greece (22 June 2010)
# 🔍 Processing match: Argentina vs Nigeria (12 June 2010)
# 🔍 Processing match: Argentina vs South Korea (12 June 2010)
# 🔍 Processing match: Greece vs Nigeria (17 June 2010)
# 🔍 Processing match: Nigeria vs South Korea (17 June 2010)
# 🔍 Processing match: Greece vs Argentina (22 June 2010)
#   Scraping Group_C...
# 🔍 Processing match: England vs United States (22 June 2010)
# 🔍 Processing match: Algeria vs Slovenia (12 June 2010)
# 🔍 Processing match: Slovenia vs United States (13 June 2010)
# 🔍 Processing match: England vs Algeria (18 June 2010)
# 🔍 Processing match: Slovenia vs England (18 June 2010)
# 🔍 Processing match: United States vs Algeria (23 June 2010)
#   Scraping Group_D...
# 🔍 Processing match: Serbia vs Ghana (23 June 2010)
# 🔍 Processing match: Germany vs Australia (13 June 2010)
# 🔍 Processing match: Germany vs Serbia (13 June 2010)
# 🔍 Processing match: Ghana vs Australia (18 June 2010)
# 🔍 Processing match: Ghana vs Germany (19 June 2010)
# 🔍 Processing match: Australia vs Serbia (23 June 2010)
#   Scraping Group_E...
# 🔍 Processing match: Netherlands vs Denmark (23 June 2010)
# 🔍 Processing match: Japan vs Cameroon (14 June 2010)
# 🔍 Processing match: Netherlands vs Japan (14 June 2010)
# 🔍 Processing match: Cameroon vs Denmark (19 June 2010)
# 🔍 Processing match: Denmark vs Japan (19 June 2010)
# 🔍 Processing match: Cameroon vs Netherlands (24 June 2010)
#   Scraping Group_F...
# 🔍 Processing match: Italy vs Paraguay (24 June 2010)
# 🔍 Processing match: New Zealand vs Slovakia (14 June 2010)
# 🔍 Processing match: Slovakia vs Paraguay (15 June 2010)
# 🔍 Processing match: Italy vs New Zealand (20 June 2010)
# 🔍 Processing match: Slovakia vs Italy (20 June 2010)
# 🔍 Processing match: Paraguay vs New Zealand (24 June 2010)
#   Scraping Group_G...
# 🔍 Processing match: Ivory Coast vs Portugal (24 June 2010)
# 🔍 Processing match: Brazil vs North Korea (15 June 2010)
# 🔍 Processing match: Brazil vs Ivory Coast (15 June 2010)
# 🔍 Processing match: Portugal vs North Korea (20 June 2010)
# 🔍 Processing match: Portugal vs Brazil (21 June 2010)
# 🔍 Processing match: North Korea vs Ivory Coast (25 June 2010)
#   Scraping Group_H...
# 🔍 Processing match: Honduras vs Chile (25 June 2010)
# 🔍 Processing match: Spain vs Switzerland (16 June 2010)
# 🔍 Processing match: Chile vs Switzerland (16 June 2010)
# 🔍 Processing match: Spain vs Honduras (21 June 2010)
# 🔍 Processing match: Chile vs Spain (21 June 2010)
# 🔍 Processing match: Switzerland vs Honduras (25 June 2010)
#
# === 2014 ===
#   Scraping Group_A...
# 🔍 Processing match: Brazil vs Croatia (25 June 2010)
# 🔍 Processing match: Mexico vs Cameroon (12 June 2014)
# 🔍 Processing match: Brazil vs Mexico (13 June 2014)
# 🔍 Processing match: Cameroon vs Croatia (17 June 2014)
# 🔍 Processing match: Cameroon vs Brazil (18 June 2014)
# 🔍 Processing match: Croatia vs Mexico (23 June 2014)
#   Scraping Group_B...
# 🔍 Processing match: Spain vs Netherlands (23 June 2014)
# 🔍 Processing match: Chile vs Australia (13 June 2014)
# 🔍 Processing match: Australia vs Netherlands (13 June 2014)
# 🔍 Processing match: Spain vs Chile (18 June 2014)
# 🔍 Processing match: Australia vs Spain (18 June 2014)
# 🔍 Processing match: Netherlands vs Chile (23 June 2014)
#   Scraping Group_C...
# 🔍 Processing match: Colombia vs Greece (23 June 2014)
# 🔍 Processing match: Ivory Coast vs Japan (14 June 2014)
# 🔍 Processing match: Colombia vs Ivory Coast (14 June 2014)
# 🔍 Processing match: Japan vs Greece (19 June 2014)
# 🔍 Processing match: Japan vs Colombia (19 June 2014)
# 🔍 Processing match: Greece vs Ivory Coast (24 June 2014)
#   Scraping Group_D...
# 🔍 Processing match: Uruguay vs Costa Rica (24 June 2014)
# 🔍 Processing match: England vs Italy (14 June 2014)
# 🔍 Processing match: Uruguay vs England (14 June 2014)
# 🔍 Processing match: Italy vs Costa Rica (19 June 2014)
# 🔍 Processing match: Italy vs Uruguay (20 June 2014)
# 🔍 Processing match: Costa Rica vs England (24 June 2014)
#   Scraping Group_E...
# 🔍 Processing match: Switzerland vs Ecuador (24 June 2014)
# 🔍 Processing match: France vs Honduras (15 June 2014)
# 🔍 Processing match: Switzerland vs France (15 June 2014)
# 🔍 Processing match: Honduras vs Ecuador (20 June 2014)
# 🔍 Processing match: Honduras vs Switzerland (20 June 2014)
# 🔍 Processing match: Ecuador vs France (25 June 2014)
#   Scraping Group_F...
# 🔍 Processing match: Argentina vs Bosnia and Herzegovina (25 June 2014)
# 🔍 Processing match: Iran vs Nigeria (15 June 2014)
# 🔍 Processing match: Argentina vs Iran (16 June 2014)
# 🔍 Processing match: Nigeria vs Bosnia and Herzegovina (21 June 2014)
# 🔍 Processing match: Nigeria vs Argentina (21 June 2014)
# 🔍 Processing match: Bosnia and Herzegovina vs Iran (25 June 2014)
#   Scraping Group_G...
# 🔍 Processing match: Germany vs Portugal (25 June 2014)
# 🔍 Processing match: Ghana vs United States (16 June 2014)
# 🔍 Processing match: Germany vs Ghana (16 June 2014)
# 🔍 Processing match: United States vs Portugal (21 June 2014)
# 🔍 Processing match: United States vs Germany (22 June 2014)
# 🔍 Processing match: Portugal vs Ghana (26 June 2014)
#   Scraping Group_H...
# 🔍 Processing match: Belgium vs Algeria (26 June 2014)
# 🔍 Processing match: Russia vs South Korea (17 June 2014)
# 🔍 Processing match: Belgium vs Russia (17 June 2014)
# 🔍 Processing match: South Korea vs Algeria (22 June 2014)
# 🔍 Processing match: South Korea vs Belgium (22 June 2014)
# 🔍 Processing match: Algeria vs Russia (26 June 2014)
#
# === 2018 ===
#   Scraping Group_A...
# 🔍 Processing match: Russia vs Saudi Arabia (26 June 2014)
# 🔍 Processing match: Egypt vs Uruguay (14 June 2018(2018-06-14))
# 🔍 Processing match: Russia vs Egypt (15 June 2018(2018-06-15))
# 🔍 Processing match: Uruguay vs Saudi Arabia (19 June 2018(2018-06-19))
# 🔍 Processing match: Uruguay vs Russia (20 June 2018(2018-06-20))
# 🔍 Processing match: Saudi Arabia vs Egypt (25 June 2018(2018-06-25))
#   Scraping Group_B...
# 🔍 Processing match: Morocco vs Iran (25 June 2018(2018-06-25))
# 🔍 Processing match: Portugal vs Spain (15 June 2018(2018-06-15))
# 🔍 Processing match: Portugal vs Morocco (15 June 2018(2018-06-15))
# 🔍 Processing match: Iran vs Spain (20 June 2018(2018-06-20))
# 🔍 Processing match: Iran vs Portugal (20 June 2018(2018-06-20))
# 🔍 Processing match: Spain vs Morocco (25 June 2018(2018-06-25))
#   Scraping Group_C...
# 🔍 Processing match: France vs Australia (25 June 2018(2018-06-25))
# 🔍 Processing match: Peru vs Denmark (16 June 2018(2018-06-16))
# 🔍 Processing match: Denmark vs Australia (16 June 2018(2018-06-16))
# 🔍 Processing match: France vs Peru (21 June 2018(2018-06-21))
# 🔍 Processing match: Denmark vs France (21 June 2018(2018-06-21))
# 🔍 Processing match: Australia vs Peru (26 June 2018(2018-06-26))
#   Scraping Group_D...
# 🔍 Processing match: Argentina vs Iceland (26 June 2018(2018-06-26))
# 🔍 Processing match: Croatia vs Nigeria (16 June 2018(2018-06-16))
# 🔍 Processing match: Argentina vs Croatia (16 June 2018(2018-06-16))
# 🔍 Processing match: Nigeria vs Iceland (21 June 2018(2018-06-21))
# 🔍 Processing match: Nigeria vs Argentina (22 June 2018(2018-06-22))
# 🔍 Processing match: Iceland vs Croatia (26 June 2018(2018-06-26))
#   Scraping Group_E...
# 🔍 Processing match: Costa Rica vs Serbia (26 June 2018(2018-06-26))
# 🔍 Processing match: Brazil vs Switzerland (17 June 2018(2018-06-17))
# 🔍 Processing match: Brazil vs Costa Rica (17 June 2018(2018-06-17))
# 🔍 Processing match: Serbia vs Switzerland (22 June 2018(2018-06-22))
# 🔍 Processing match: Serbia vs Brazil (22 June 2018(2018-06-22))
# 🔍 Processing match: Switzerland vs Costa Rica (27 June 2018(2018-06-27))
#   Scraping Group_F...
# 🔍 Processing match: Germany vs Mexico (27 June 2018(2018-06-27))
# 🔍 Processing match: Sweden vs South Korea (17 June 2018(2018-06-17))
# 🔍 Processing match: South Korea vs Mexico (18 June 2018(2018-06-18))
# 🔍 Processing match: Germany vs Sweden (23 June 2018(2018-06-23))
# 🔍 Processing match: South Korea vs Germany (23 June 2018(2018-06-23))
# 🔍 Processing match: Mexico vs Sweden (27 June 2018(2018-06-27))
#   Scraping Group_G...
# 🔍 Processing match: Belgium vs Panama (27 June 2018(2018-06-27))
# 🔍 Processing match: Tunisia vs England (18 June 2018(2018-06-18))
# 🔍 Processing match: Belgium vs Tunisia (18 June 2018(2018-06-18))
# 🔍 Processing match: England vs Panama (23 June 2018(2018-06-23))
# 🔍 Processing match: England vs Belgium (24 June 2018(2018-06-24))
# 🔍 Processing match: Panama vs Tunisia (28 June 2018(2018-06-28))
#   Scraping Group_H...
# 🔍 Processing match: Colombia vs Japan (28 June 2018(2018-06-28))
# 🔍 Processing match: Poland vs Senegal (19 June 2018(2018-06-19))
# 🔍 Processing match: Japan vs Senegal (19 June 2018(2018-06-19))
# 🔍 Processing match: Poland vs Colombia (24 June 2018(2018-06-24))
# 🔍 Processing match: Japan vs Poland (24 June 2018(2018-06-24))
# 🔍 Processing match: Senegal vs Colombia (28 June 2018(2018-06-28))
#
# === 2022 ===
#   Scraping Group_A...
# 🔍 Processing match: Qatar vs Ecuador (28 June 2018(2018-06-28))
# 🔍 Processing match: Senegal vs Netherlands (20 November 2022(2022-11-20))
# 🔍 Processing match: Qatar vs Senegal (21 November 2022(2022-11-21))
# 🔍 Processing match: Netherlands vs Ecuador (25 November 2022(2022-11-25))
# 🔍 Processing match: Ecuador vs Senegal (25 November 2022(2022-11-25))
# 🔍 Processing match: Netherlands vs Qatar (29 November 2022(2022-11-29))
#   Scraping Group_B...
# 🔍 Processing match: England vs Iran (29 November 2022(2022-11-29))
# 🔍 Processing match: United States vs Wales (21 November 2022(2022-11-21))
# 🔍 Processing match: Wales vs Iran (21 November 2022(2022-11-21))
# 🔍 Processing match: England vs United States (25 November 2022(2022-11-25))
# 🔍 Processing match: Wales vs England (25 November 2022(2022-11-25))
# 🔍 Processing match: Iran vs United States (29 November 2022(2022-11-29))
#   Scraping Group_C...
# 🔍 Processing match: Argentina vs Saudi Arabia (29 November 2022(2022-11-29))
# 🔍 Processing match: Mexico vs Poland (22 November 2022(2022-11-22))
# 🔍 Processing match: Poland vs Saudi Arabia (22 November 2022(2022-11-22))
# 🔍 Processing match: Argentina vs Mexico (26 November 2022(2022-11-26))
# 🔍 Processing match: Poland vs Argentina (26 November 2022(2022-11-26))
# 🔍 Processing match: Saudi Arabia vs Mexico (30 November 2022(2022-11-30))
#   Scraping Group_D...
# 🔍 Processing match: Denmark vs Tunisia (30 November 2022(2022-11-30))
# 🔍 Processing match: France vs Australia (22 November 2022(2022-11-22))
# 🔍 Processing match: Tunisia vs Australia (22 November 2022(2022-11-22))
# 🔍 Processing match: France vs Denmark (26 November 2022(2022-11-26))
# 🔍 Processing match: Australia vs Denmark (26 November 2022(2022-11-26))
# 🔍 Processing match: Tunisia vs France (30 November 2022(2022-11-30))
#   Scraping Group_E...
# 🔍 Processing match: Germany vs Japan (30 November 2022(2022-11-30))
# 🔍 Processing match: Spain vs Costa Rica (23 November 2022(2022-11-23))
# 🔍 Processing match: Japan vs Costa Rica (23 November 2022(2022-11-23))
# 🔍 Processing match: Spain vs Germany (27 November 2022(2022-11-27))
# 🔍 Processing match: Japan vs Spain (27 November 2022(2022-11-27))
# 🔍 Processing match: Costa Rica vs Germany (1 December 2022(2022-12-01))
#   Scraping Group_F...
# 🔍 Processing match: Morocco vs Croatia (1 December 2022(2022-12-01))
# 🔍 Processing match: Belgium vs Canada (23 November 2022(2022-11-23))
# 🔍 Processing match: Belgium vs Morocco (23 November 2022(2022-11-23))
# 🔍 Processing match: Croatia vs Canada (27 November 2022(2022-11-27))
# 🔍 Processing match: Croatia vs Belgium (27 November 2022(2022-11-27))
# 🔍 Processing match: Canada vs Morocco (1 December 2022(2022-12-01))
#   Scraping Group_G...
# 🔍 Processing match: Switzerland vs Cameroon (1 December 2022(2022-12-01))
# 🔍 Processing match: Brazil vs Serbia (24 November 2022(2022-11-24))
# 🔍 Processing match: Cameroon vs Serbia (24 November 2022(2022-11-24))
# 🔍 Processing match: Brazil vs Switzerland (28 November 2022(2022-11-28))
# 🔍 Processing match: Serbia vs Switzerland (28 November 2022(2022-11-28))
# 🔍 Processing match: Cameroon vs Brazil (2 December 2022(2022-12-02))
#   Scraping Group_H...
# 🔍 Processing match: Uruguay vs South Korea (2 December 2022(2022-12-02))
# 🔍 Processing match: Portugal vs Ghana (24 November 2022(2022-11-24))
# 🔍 Processing match: South Korea vs Ghana (24 November 2022(2022-11-24))
# 🔍 Processing match: Portugal vs Uruguay (28 November 2022(2022-11-28))
# 🔍 Processing match: Ghana vs Uruguay (28 November 2022(2022-11-28))
# 🔍 Processing match: South Korea vs Portugal (2 December 2022(2022-12-02))
#
# ✅ Clean Excel file saved to: C:\Users\aldi\Documents\GitHub\tiebreak_wc\data\in\cards_subs_wc.xlsx
