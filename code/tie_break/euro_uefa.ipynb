# %% [markdown]
# # Libraries

# %%
import pandas as pd
from getpass import getuser
from collections import defaultdict
from datetime import datetime, timedelta

# %% [markdown]
# # Load and inspect dataset

# %%
# Get the current user's name
user = getuser()

# Path to the dataset
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\euro_goals.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(data_path)

# Display the first few rows of the DataFrame to verify the import
display(df.head())
# Out:
#      stage   time home_team   away_team score           stadium_name  \
# 0  Group 1  20:30    France     Denmark   1–0       Parc des Princes
# 1  Group 1  20:30   Belgium  Yugoslavia   2–0   Stade Félix-Bollaert
# 2  Group 1  20:30   Belgium  Yugoslavia   2–0   Stade Félix-Bollaert
# 3  Group 1  17:15    France     Belgium   5–0  Stade de la Beaujoire
# 4  Group 1  17:15    France     Belgium   5–0  Stade de la Beaujoire
#
#   stadium_city  stadium_attendance      referee_name referee_nationality  ...  \
# 0        Paris               47570       Volker Roth        West Germany  ...
# 1         Lens               41525  Erik Fredriksson              Sweden  ...
# 2         Lens               41525  Erik Fredriksson              Sweden  ...
# 3       Nantes               51359     Bob Valentine            Scotland  ...
# 4       Nantes               51359     Bob Valentine            Scotland  ...
#
#   goal_minute extra_time  goals_home  goals_away  own_goal  penalty  \
# 0          78          0           1           0         0        0
# 1          28          0           2           0         0        0
# 2          45          0           2           0         0        0
# 3           4          0           5           0         0        0
# 4          74          0           5           0         0        1
#
#    goal_minute_et  goal_et  short_date     long_date
# 0               0        0  1984-06-12  12 June 1984
# 1               0        0  1984-06-13  13 June 1984
# 2               0        0  1984-06-13  13 June 1984
# 3               0        0  1984-06-16  16 June 1984
# 4               0        0  1984-06-16  16 June 1984
#
# [5 rows x 22 columns]

# %% [markdown]
# # Clean and transfrom variables

# %% [markdown]
# ## time

# %%
# Step 1: Clean time variable by removing any letters (e.g., EEST, PST) if they exist
df['time_cleaned'] = df['time'].str.replace(r'[A-Za-z]+', '', regex=True).str.strip()

# Step 2: Split time where there are parentheses into local time and UTC offset
df['local_time'] = df['time_cleaned'].str.extract(r'(\d{2}:\d{2})')  # extract the part before parentheses
df['utc_time_offset'] = df['time_cleaned'].str.extract(r'\((.*?)\)')  # extract the part inside parentheses

# %% [markdown]
# ## date

# %%
# Convert 'short_date' column to datetime if it's not already
df['short_date'] = pd.to_datetime(df['short_date'])

# Extract the year from 'short_date' and create a new column 'year'
df['year'] = df['short_date'].dt.year

# %% [markdown]
# # Extract relevant columns

# %%
# Filter out the knockout stages
df = df[~df['stage'].isin(['Quarter-finals', 'Round of 16', 'Semi-finals', 'Final'])]

# Extract relevant columns for goal events and match results
goals_df = df[['year', 'stage', 'home_team', 'away_team', 'scorer_nationality', 'goal_minute', 'short_date','local_time', 'score']]

display(goals_df.head())
# Out:
#    year    stage home_team   away_team scorer_nationality  goal_minute  \
# 0  1984  Group 1    France     Denmark             France           78
# 1  1984  Group 1   Belgium  Yugoslavia            Belgium           28
# 2  1984  Group 1   Belgium  Yugoslavia            Belgium           45
# 3  1984  Group 1    France     Belgium             France            4
# 4  1984  Group 1    France     Belgium             France           74
#
#   short_date local_time score
# 0 1984-06-12      20:30   1–0
# 1 1984-06-13      20:30   2–0
# 2 1984-06-13      20:30   2–0
# 3 1984-06-16      17:15   5–0
# 4 1984-06-16      17:15   5–0

# %% [markdown]
# # Recreate Leauge Table after first two matchdays

# %% [markdown]
# ### Filter out the matches from the last match day in the goals_df DataFrame.

# %%
# Step 1: Find the last match date for each tournament and group
last_dates = goals_df.groupby(['year', 'stage'])['short_date'].max().reset_index()

# Step 2: Create the dataset with all games excluding the last match day (goals_before_last_day)
# Performing a left merge and keeping only rows not present in the last_dates
goals_before_last_day = goals_df.merge(last_dates, on=['year', 'stage', 'short_date'], how='left', indicator=True)
goals_before_last_day = goals_before_last_day[goals_before_last_day['_merge'] == 'left_only'].drop(columns=['_merge'])

# Step 3: Create the dataset with only the last match day games (goals_last_day)
goals_last_day = goals_df.merge(last_dates, on=['year', 'stage', 'short_date'], how='inner')

# Step 4: Sort the DataFrame by 'goal_minute'
goals_last_day_sorted = goals_last_day.sort_values(by=['short_date','goal_minute'], ascending=True)

# Ensure that goals_last_day_sorted has no duplicates
goals_last_day_sorted = goals_last_day_sorted.drop_duplicates()

# %%
goals_last_day_sorted
# Out:
#      year    stage       home_team   away_team scorer_nationality  \
# 8    1984  Group 1         Denmark     Belgium            Belgium
# 3    1984  Group 1          France  Yugoslavia         Yugoslavia
# 9    1984  Group 1         Denmark     Belgium            Belgium
# 5    1984  Group 1         Denmark     Belgium            Denmark
# 0    1984  Group 1          France  Yugoslavia             France
# ..    ...      ...             ...         ...                ...
# 224  2024  Group E        Slovakia     Romania            Romania
# 228  2024  Group F  Czech Republic      Turkey             Turkey
# 226  2024  Group F         Georgia    Portugal            Georgia
# 227  2024  Group F  Czech Republic      Turkey     Czech Republic
# 229  2024  Group F  Czech Republic      Turkey             Turkey
#
#      goal_minute short_date local_time score
# 8             26 1984-06-19      20:30   3–2
# 3             32 1984-06-19      20:30   3–2
# 9             39 1984-06-19      20:30   3–2
# 5             41 1984-06-19      20:30   3–2
# 0             59 1984-06-19      20:30   3–2
# ..           ...        ...        ...   ...
# 224           37 2024-06-26      18:00   1–1
# 228           51 2024-06-26      21:00   1–2
# 226           57 2024-06-26      21:00   2–0
# 227           66 2024-06-26      21:00   1–2
# 229           94 2024-06-26      21:00   1–2
#
# [229 rows x 9 columns]

# %% [markdown]
# ## create df  of aggregate data for each match

# %%
# Initialize an empty list to store the results
results = []

# Iterate over each match in the dataset
for match_id, group in goals_before_last_day.groupby(['year', 'stage', 'home_team', 'away_team']):
    # Initialize goals_home and goals_away for each match
    goals_home = 0
    goals_away = 0
    
    # Extract the local_time and the score from the first row in the group
    local_time = group.iloc[0]['local_time']
    score = group.iloc[0]['score']  # Assuming score is stored with a longer dash like '2–0'
    
    # Extract short_date from local_time (assuming local_time is a datetime object or string convertible to date)
    short_date = pd.to_datetime(local_time).date()  # Convert local_time to a short date (YYYY-MM-DD)
    
    # Loop through each row in the group to count goals for home and away teams
    for _, row in group.iterrows():
        # Check if the scorer's nationality matches the home team
        if row['home_team'] == row['scorer_nationality']:
            goals_home += 1
        # If the scorer's nationality matches the away team, increment goals_away
        elif row['away_team'] == row['scorer_nationality']:
            goals_away += 1

    # Calculate the expected score from goals_home and goals_away (using a standard hyphen)
    calculated_score = f"{goals_home}-{goals_away}"
    
    # Normalize both scores by replacing any long dash (en-dash or em-dash) with a standard hyphen
    normalized_score = score.replace("–", "-").replace("—", "-")
    
    # Check if the normalized score matches the calculated score
    score_match = normalized_score == calculated_score
    
    # Append the results to the list, including local_time, short_date, and score match flag
    results.append({
        'year': match_id[0],
        'stage': match_id[1],
        'home_team': match_id[2],
        'away_team': match_id[3],
        'local_time': local_time,
        'short_date': short_date,  # New column for the short date
        'goals_home': goals_home,
        'goals_away': goals_away,
        'original_score': score,  # Keep the original score with long dash
        'calculated_score': calculated_score,
        'score_match': score_match  # True if score matches, False otherwise
    })

# Convert the list into a DataFrame
agg_goals_before_last_day = pd.DataFrame(results)

# Add a new column 'won' based on the comparison of goals_home and goals_away
agg_goals_before_last_day['won'] = agg_goals_before_last_day.apply(
    lambda row: 1 if row['goals_home'] > row['goals_away'] else (-1 if row['goals_home'] < row['goals_away'] else 0), 
    axis=1
)

# %%
agg_goals_before_last_day
# Out:
#      year    stage home_team       away_team local_time  short_date  \
# 0    1984  Group 1   Belgium      Yugoslavia      20:30  2024-10-31
# 1    1984  Group 1   Denmark      Yugoslavia      20:30  2024-10-31
# 2    1984  Group 1    France         Belgium      17:15  2024-10-31
# 3    1984  Group 1    France         Denmark      20:30  2024-10-31
# 4    1984  Group 2  Portugal           Spain      20:30  2024-10-31
# ..    ...      ...       ...             ...        ...         ...
# 153  2024  Group E  Slovakia         Ukraine      15:00  2024-10-31
# 154  2024  Group F   Georgia  Czech Republic      15:00  2024-10-31
# 155  2024  Group F  Portugal  Czech Republic      21:00  2024-10-31
# 156  2024  Group F    Turkey         Georgia      18:00  2024-10-31
# 157  2024  Group F    Turkey        Portugal      18:00  2024-10-31
#
#      goals_home  goals_away original_score calculated_score  score_match  won
# 0             2           0            2–0              2-0         True    1
# 1             5           0            5–0              5-0         True    1
# 2             5           0            5–0              5-0         True    1
# 3             1           0            1–0              1-0         True    1
# 4             1           1            1–1              1-1         True    0
# ..          ...         ...            ...              ...          ...  ...
# 153           1           2            1–2              1-2         True   -1
# 154           1           1            1–1              1-1         True    0
# 155           2           1            2–1              2-1         True    1
# 156           3           1            3–1              3-1         True    1
# 157           0           3            0–3              0-3         True   -1
#
# [158 rows x 12 columns]

# %% [markdown]
# ## aggregate data for home and away games

# %%
def calculate_points(results, years, win_result):
    points = []
    for result, year in zip(results, years):
        if result == win_result:  # Win condition (1 for home, -1 for away)
            points.append(2 if year <= 1992 else 3)
        elif result == 0:  # Draw condition
            points.append(1)
        else:  # Loss condition
            points.append(0)
    return sum(points)

# %%
# Step 1: Home games aggregation with match count and conditional points based on year
home_games = agg_goals_before_last_day.groupby(['year', 'stage', 'home_team']).agg(
    goals_scored=('goals_home', 'sum'),
    goals_conceded=('goals_away', 'sum'),
    points_home=('won', lambda x: calculate_points(x, agg_goals_before_last_day.loc[x.index, 'year'], 1)),
    match_count_home=('home_team', 'count')
).reset_index()

# %%
display(home_games.head())
# Out:
#    year    stage home_team  goals_scored  goals_conceded  points_home  \
# 0  1984  Group 1   Belgium             2               0            2
# 1  1984  Group 1   Denmark             5               0            2
# 2  1984  Group 1    France             6               0            4
# 3  1984  Group 2  Portugal             1               1            1
# 4  1984  Group 2   Romania             1               1            1
#
#    match_count_home
# 0                 1
# 1                 1
# 2                 2
# 3                 1
# 4                 1

# %%
# Filter for year == 2021 and stage == 'Group F'
group_f_2021 = home_games[(home_games['year'] == 2021) & (home_games['stage'] == 'Group F')]
group_f_2021
# Out:
#      year    stage home_team  goals_scored  goals_conceded  points_home  \
# 115  2021  Group F    France             1               0            3
# 116  2021  Group F   Hungary             1               4            1
# 117  2021  Group F  Portugal             2               4            0
#
#      match_count_home
# 115                 1
# 116                 2
# 117                 1

# %%
# Step 2: Away games aggregation with match count and conditional points based on year
away_games = agg_goals_before_last_day.groupby(['year', 'stage', 'away_team']).agg(
    goals_scored=('goals_away', 'sum'),
    goals_conceded=('goals_home', 'sum'),
    points_away=('won', lambda x: calculate_points(x, agg_goals_before_last_day.loc[x.index, 'year'], -1)),
    match_count_away=('away_team', 'count')
).reset_index()

# %%
display(away_games.head())
# Out:
#    year    stage   away_team  goals_scored  goals_conceded  points_away  \
# 0  1984  Group 1     Belgium             0               5            0
# 1  1984  Group 1     Denmark             0               1            0
# 2  1984  Group 1  Yugoslavia             0               7            0
# 3  1984  Group 2     Romania             1               2            0
# 4  1984  Group 2       Spain             2               2            2
#
#    match_count_away
# 0                 1
# 1                 1
# 2                 2
# 3                 1
# 4                 2

# %% [markdown]
# ## aggregate data after first two matches following

# %% [markdown]
# ### UEFA criteria (first h2h, then aggregate)

# %%
def uefa_before_last(home_games, away_games, agg_goals_before_last_day):
    # Step 1: Merge home_games and away_games on year, stage, and home_team with away_team
    all_games_before_last = pd.merge(
        home_games,
        away_games,
        left_on=['year', 'stage', 'home_team'],
        right_on=['year', 'stage', 'away_team'],
        how='outer',
        suffixes=('_home', '_away')
    )

    # Step 2: For teams that only appear in home_games, assign home_team to team and copy relevant columns
    all_games_before_last['team'] = all_games_before_last['home_team'].fillna(all_games_before_last['away_team'])

    # Step 3: For goals_scored, goals_conceded, and points, handle missing values
    all_games_before_last['goals_scored'] = all_games_before_last['goals_scored_home'].fillna(0) + all_games_before_last['goals_scored_away'].fillna(0)
    all_games_before_last['goals_conceded'] = all_games_before_last['goals_conceded_home'].fillna(0) + all_games_before_last['goals_conceded_away'].fillna(0)
    all_games_before_last['points'] = all_games_before_last['points_home'].fillna(0) + all_games_before_last['points_away'].fillna(0)

    # Step 4: Add goals_difference column
    all_games_before_last['goals_difference'] = all_games_before_last['goals_scored'] - all_games_before_last['goals_conceded']

    # Step 5: Sum match_count_home and match_count_away to get total match count for each team
    all_games_before_last['total_matches'] = all_games_before_last['match_count_home'].fillna(0) + all_games_before_last['match_count_away'].fillna(0)

    # Step 6: Adjust points if total_matches is 1 (indicating a likely 0-0 draw)
    all_games_before_last.loc[all_games_before_last['total_matches'] == 1, 'points'] += 1

    # Step 7: Drop unnecessary columns used in the merge process
    all_games_before_last = all_games_before_last[['year', 'stage', 'team', 'goals_scored', 'goals_conceded', 'points', 'goals_difference', 'total_matches']]

    # Step 8: Initial sort by year, stage, and points
    all_games_before_last = all_games_before_last.sort_values(
        by=['year', 'stage', 'points'],
        ascending=[True, True, False]
    ).reset_index(drop=True)

    # Step 9: Initialize a new column for tie-break results, which will store either the tie-break result or 'no need'
    all_games_before_last['tiebreaker'] = 'no need'

    # Step 10: Define the function to check the tie-breaker
    def check_tiebreaker(row1, row2, agg_data):
        """
        Check the tie-breaker based on the head-to-head match result from agg_goals_before_last_day.
        Return the team that won (if any) or 'tie'.
        """
        match = agg_data[((agg_data['home_team'] == row1['team']) & (agg_data['away_team'] == row2['team'])) |
                         ((agg_data['home_team'] == row2['team']) & (agg_data['away_team'] == row1['team']))]

        if not match.empty:
            if match.iloc[0]['won'] == 1:
                return row1['team']  # Home team won
            elif match.iloc[0]['won'] == -1:
                return row2['team']  # Away team won
            else:
                return 'tie'  # It's a draw
        else:
            return 'no result'  # No match found

    # Step 11: Apply the tie-breaker and if still tied, check goals_difference and goals_scored
    for i in range(len(all_games_before_last) - 1):
        row1 = all_games_before_last.iloc[i]
        row2 = all_games_before_last.iloc[i + 1]

        # Get the year and stage for the current comparison
        year = row1['year']
        stage = row1['stage']

        # Check if the two rows have identical values for points
        if row1['points'] == row2['points']:
            print(f"Tie in {year}, Stage: {stage}, between {row1['team']} and {row2['team']} (Points: {row1['points']})")

            # Apply the tie-breaker by checking the head-to-head match result
            tiebreak_result = check_tiebreaker(row1, row2, agg_goals_before_last_day)

            if tiebreak_result != 'tie' and tiebreak_result != 'no result':
                print(f"Tie resolved by head-to-head: {tiebreak_result} won in {year}, Stage: {stage}")
                all_games_before_last.at[i, 'tiebreaker'] = tiebreak_result
                all_games_before_last.at[i + 1, 'tiebreaker'] = tiebreak_result
            else:
                # If still tied after the tiebreaker, check goals_difference and goals_scored
                if row1['goals_difference'] > row2['goals_difference']:
                    print(f"Tie resolved by goals difference: {row1['team']} favored in {year}, Stage: {stage}")
                    all_games_before_last.at[i, 'tiebreaker'] = row1['team']
                    all_games_before_last.at[i + 1, 'tiebreaker'] = row1['team']
                elif row1['goals_difference'] < row2['goals_difference']:
                    print(f"Tie resolved by goals difference: {row2['team']} favored in {year}, Stage: {stage}")
                    all_games_before_last.at[i, 'tiebreaker'] = row2['team']
                    all_games_before_last.at[i + 1, 'tiebreaker'] = row2['team']
                elif row1['goals_scored'] > row2['goals_scored']:
                    print(f"Tie resolved by goals scored: {row1['team']} favored in {year}, Stage: {stage}")
                    all_games_before_last.at[i, 'tiebreaker'] = row1['team']
                    all_games_before_last.at[i + 1, 'tiebreaker'] = row1['team']
                else:
                    print(f"Tie resolved by goals scored: {row2['team']} favored in {year}, Stage: {stage}")
                    all_games_before_last.at[i, 'tiebreaker'] = row2['team']
                    all_games_before_last.at[i + 1, 'tiebreaker'] = row2['team']

    # Step 12: Add group standing by ranking teams within each stage based on points, goals_difference, and goals_scored
    all_games_before_last['standing'] = all_games_before_last.groupby(['year', 'stage']).apply(
        lambda x: x.sort_values(by=['points', 'goals_difference', 'goals_scored'], ascending=[False, False, False])
    ).reset_index(drop=True).groupby(['year', 'stage']).cumcount() + 1

    # Convert goals_scored, goals_conceded, points, goals_difference, and total_matches to integers
    all_games_before_last[['goals_scored', 'goals_conceded', 'points', 'goals_difference', 'total_matches']] = all_games_before_last[
        ['goals_scored', 'goals_conceded', 'points', 'goals_difference', 'total_matches']].astype(int)

    return all_games_before_last

# %%
# Applying the fifa_before_last function to the mock data
all_games_before_last = uefa_before_last(home_games, away_games, agg_goals_before_last_day)
# Out:
# Tie in 1984, Stage: Group 1, between Belgium and Denmark (Points: 2.0)
# Tie resolved by head-to-head: Denmark won in 1984, Stage: Group 1
# Tie in 1984, Stage: Group 2, between Portugal and Spain (Points: 2.0)
# Tie resolved by goals scored: Spain favored in 1984, Stage: Group 2
# Tie in 1988, Stage: Group 1, between Italy and West Germany (Points: 3.0)
# Tie resolved by goals difference: West Germany favored in 1988, Stage: Group 1
# Tie in 1988, Stage: Group 2, between Republic of Ireland and Soviet Union (Points: 3.0)
# Tie resolved by goals scored: Soviet Union favored in 1988, Stage: Group 2
# Tie in 1992, Stage: Group 2, between Germany and Netherlands (Points: 3.0)
# Tie resolved by goals difference: Germany favored in 1992, Stage: Group 2
# Tie in 1996, Stage: Group A, between England and Netherlands (Points: 4.0)
# Tie resolved by head-to-head: Netherlands won in 1996, Stage: Group A
# Tie in 1996, Stage: Group A, between Scotland and Switzerland (Points: 1.0)
# Tie resolved by goals scored: Switzerland favored in 1996, Stage: Group A
# Tie in 1996, Stage: Group B, between Bulgaria and France (Points: 4.0)
# Tie resolved by goals scored: France favored in 1996, Stage: Group B
# Tie in 1996, Stage: Group C, between Czech Republic and Italy (Points: 3.0)
# Tie resolved by head-to-head: Czech Republic won in 1996, Stage: Group C
# Tie in 2000, Stage: Group A, between Germany and Romania (Points: 1.0)
# Tie resolved by goals scored: Romania favored in 2000, Stage: Group A
# Tie in 2000, Stage: Group B, between Sweden and Turkey (Points: 1.0)
# Tie resolved by goals scored: Turkey favored in 2000, Stage: Group B
# Tie in 2000, Stage: Group C, between Norway and Spain (Points: 3.0)
# Tie resolved by head-to-head: Spain won in 2000, Stage: Group C
# Tie in 2000, Stage: Group D, between France and Netherlands (Points: 6.0)
# Tie resolved by head-to-head: France won in 2000, Stage: Group D
# Tie in 2000, Stage: Group D, between Czech Republic and Denmark (Points: 0.0)
# Tie resolved by goals difference: Czech Republic favored in 2000, Stage: Group D
# Tie in 2004, Stage: Group A, between Greece and Spain (Points: 4.0)
# Tie resolved by goals scored: Greece favored in 2004, Stage: Group A
# Tie in 2004, Stage: Group C, between Denmark and Sweden (Points: 4.0)
# Tie resolved by head-to-head: Denmark won in 2004, Stage: Group C
# Tie in 2004, Stage: Group D, between Latvia and Netherlands (Points: 1.0)
# Tie resolved by goals scored: Netherlands favored in 2004, Stage: Group D
# Tie in 2008, Stage: Group A, between Czech Republic and Turkey (Points: 3.0)
# Tie resolved by goals scored: Turkey favored in 2008, Stage: Group A
# Tie in 2008, Stage: Group B, between Austria and Poland (Points: 1.0)
# Tie resolved by goals difference: Austria favored in 2008, Stage: Group B
# Tie in 2008, Stage: Group C, between France and Italy (Points: 1.0)
# Tie resolved by goals scored: Italy favored in 2008, Stage: Group C
# Tie in 2008, Stage: Group D, between Russia and Sweden (Points: 3.0)
# Tie resolved by goals difference: Sweden favored in 2008, Stage: Group D
# Tie in 2012, Stage: Group B, between Denmark and Portugal (Points: 3.0)
# Tie resolved by goals scored: Portugal favored in 2012, Stage: Group B
# Tie in 2012, Stage: Group C, between Croatia and Spain (Points: 4.0)
# Tie resolved by head-to-head: Croatia won in 2012, Stage: Group C
# Tie in 2012, Stage: Group D, between England and France (Points: 4.0)
# Tie resolved by head-to-head: England won in 2012, Stage: Group D
# Tie in 2016, Stage: Group B, between Slovakia and Wales (Points: 3.0)
# Tie resolved by head-to-head: Slovakia won in 2016, Stage: Group B
# Tie in 2016, Stage: Group C, between Germany and Poland (Points: 4.0)
# Tie resolved by head-to-head: Germany won in 2016, Stage: Group C
# Tie in 2016, Stage: Group E, between Republic of Ireland and Sweden (Points: 1.0)
# Tie resolved by goals difference: Sweden favored in 2016, Stage: Group E
# Tie in 2016, Stage: Group F, between Iceland and Portugal (Points: 2.0)
# Tie resolved by goals scored: Iceland favored in 2016, Stage: Group F
# Tie in 2021, Stage: Group B, between Finland and Russia (Points: 3.0)
# Tie resolved by head-to-head: Russia won in 2021, Stage: Group B
# Tie in 2021, Stage: Group C, between Austria and Ukraine (Points: 3.0)
# Tie resolved by goals scored: Ukraine favored in 2021, Stage: Group C
# Tie in 2021, Stage: Group D, between Czech Republic and England (Points: 4.0)
# Tie resolved by goals difference: Czech Republic favored in 2021, Stage: Group D
# Tie in 2021, Stage: Group D, between Croatia and Scotland (Points: 1.0)
# Tie resolved by goals difference: Croatia favored in 2021, Stage: Group D
# Tie in 2021, Stage: Group F, between Germany and Portugal (Points: 3.0)
# Tie resolved by head-to-head: Germany won in 2021, Stage: Group F
# Tie in 2024, Stage: Group B, between Albania and Croatia (Points: 1.0)
# Tie resolved by goals difference: Albania favored in 2024, Stage: Group B
# Tie in 2024, Stage: Group C, between Denmark and Slovenia (Points: 2.0)
# Tie resolved by goals scored: Slovenia favored in 2024, Stage: Group C
# Tie in 2024, Stage: Group D, between France and Netherlands (Points: 4.0)
# Tie resolved by head-to-head: France won in 2024, Stage: Group D
# Tie in 2024, Stage: Group E, between Romania and Ukraine (Points: 3.0)
# Tie resolved by head-to-head: Romania won in 2024, Stage: Group E
# Tie in 2024, Stage: Group F, between Czech Republic and Georgia (Points: 1.0)
# Tie resolved by goals difference: Czech Republic favored in 2024, Stage: Group F
# C:\Users\aldi\AppData\Local\Temp\ipykernel_24640\1437520468.py:100: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   all_games_before_last['standing'] = all_games_before_last.groupby(['year', 'stage']).apply(

# %% [markdown]
# # Recreate league table after last match day

# %% [markdown]
# ### uefa criteria

# %%
def uefa_final_euro(year, stage, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day):
    # Step 1: Filter the data for the specific year and stage
    group_goals_tracking = all_games_before_last[
        (all_games_before_last['year'] == year) & 
        (all_games_before_last['stage'] == stage)
    ].copy()

    group_goals_last_day = goals_last_day_sorted[
        (goals_last_day_sorted['year'] == year) & 
        (goals_last_day_sorted['stage'] == stage)
    ]

    # Step 2: Initialize columns for tracking team performance
    group_goals_tracking['before_last_game_goals_scored'] = group_goals_tracking['goals_scored']
    group_goals_tracking['before_last_game_goals_conceded'] = group_goals_tracking['goals_conceded']
    group_goals_tracking['before_last_game_standing'] = group_goals_tracking['standing']
    group_goals_tracking['before_last_game_points'] = group_goals_tracking['points']

    group_goals_tracking['last_game_goals_scored'] = 0
    group_goals_tracking['last_game_goals_conceded'] = 0
    group_goals_tracking['total_goals_scored'] = group_goals_tracking['before_last_game_goals_scored']
    group_goals_tracking['total_goals_conceded'] = group_goals_tracking['before_last_game_goals_conceded']
    group_goals_tracking['total_goal_difference'] = group_goals_tracking['total_goals_scored'] - group_goals_tracking['total_goals_conceded']
    group_goals_tracking['last_game_points'] = 0
    group_goals_tracking['total_points'] = group_goals_tracking['before_last_game_points']
    group_goals_tracking['last_game_standing'] = 0
    group_goals_tracking['1st'] = 0
    group_goals_tracking['2nd'] = 0
    group_goals_tracking['3rd'] = 0
    group_goals_tracking['4th'] = 0
    group_goals_tracking['changes'] = 0  # Initialize this but will be redefined later as the sum of 1st, 2nd, 3rd, 4th
    group_goals_tracking['tied'] = False  # Initialize a flag to track tied teams
    group_goals_tracking['tied_won'] = 0  # Initialize to track if the team won a tie-breaker match

    # Step 3: Sort group_goals_last_day by goal_minute in ascending order
    group_goals_last_day = group_goals_last_day.sort_values(by='goal_minute', ascending=True)

    # Print the year, stage, and standings before starting the loop for last match goals
    print(f"\n=== Initial Standings for Year {year}, {stage} Before Last Match Goals ===\n")
    display_columns = ['team', 'total_points', 'total_goals_scored', 'total_goals_conceded', 
                       'total_goal_difference', 'before_last_game_points', 'before_last_game_standing']
    print(group_goals_tracking[display_columns].to_string(index=False))
    print("\n====================================================\n")

    # Step 4: Iterate through the sorted and filtered last match goals and update the goals_tracking table
    previous_standings = group_goals_tracking['last_game_standing'].copy()
    first_iteration = True  # Variable to track the first iteration

    for _, goal in group_goals_last_day.iterrows():
        home_team = goal['home_team']
        away_team = goal['away_team']
        player_team = goal['scorer_nationality']

        # Print goal information for each goal
        print(f"Analyzing goal: {goal['goal_minute']} minute, Player team: {player_team}, Home: {home_team}, Away: {away_team}")

        # Update the goals based on who scored the goal
        if player_team == home_team:
            # Home team scored, update home scored and away conceded
            group_goals_tracking.loc[group_goals_tracking['team'] == home_team, 'last_game_goals_scored'] += 1
            group_goals_tracking.loc[group_goals_tracking['team'] == away_team, 'last_game_goals_conceded'] += 1
        elif player_team == away_team:
            # Away team scored, update away scored and home conceded
            group_goals_tracking.loc[group_goals_tracking['team'] == away_team, 'last_game_goals_scored'] += 1
            group_goals_tracking.loc[group_goals_tracking['team'] == home_team, 'last_game_goals_conceded'] += 1

        # Step 5: Update total_goals_scored, total_goals_conceded, and total_goal_difference
        group_goals_tracking['total_goals_scored'] = group_goals_tracking['before_last_game_goals_scored'] + group_goals_tracking['last_game_goals_scored']
        group_goals_tracking['total_goals_conceded'] = group_goals_tracking['before_last_game_goals_conceded'] + group_goals_tracking['last_game_goals_conceded']
        group_goals_tracking['total_goal_difference'] = group_goals_tracking['total_goals_scored'] - group_goals_tracking['total_goals_conceded']

        # Step 6: Assign points for the last game dynamically after each goal
        for i, row in group_goals_tracking.iterrows():
            if row['last_game_goals_scored'] > row['last_game_goals_conceded']:
                # Check if the year is <= 1992, award 2 points for a win, else award 3 points
                if row['year'] <= 1992:
                    group_goals_tracking.loc[i, 'last_game_points'] = 2  # Win before or during 1992
                else:
                    group_goals_tracking.loc[i, 'last_game_points'] = 3  # Win after 1992
            elif row['last_game_goals_scored'] == row['last_game_goals_conceded']:
                group_goals_tracking.loc[i, 'last_game_points'] = 1  # Draw
            else:
                group_goals_tracking.loc[i, 'last_game_points'] = 0  # Loss

        # Step 7: Update total points
        group_goals_tracking['total_points'] = group_goals_tracking['before_last_game_points'] + group_goals_tracking['last_game_points']

        # Step 8: Mark teams that are tied
        group_goals_tracking['tied'] = group_goals_tracking.duplicated(subset=['total_points'], keep=False)

        # Reset `tied_won` to 0 for all teams
        group_goals_tracking['tied_won'] = 0

        # Step 8b: Calculate tied_won only for tied teams
        tied_teams = group_goals_tracking[group_goals_tracking['tied']]

        if not tied_teams.empty:
            # Iterate over tied teams to resolve standings using head-to-head results
            for index, row in tied_teams.iterrows():
                team1 = row['team']
                team1_index = index

                # Look for other teams tied with this team
                for other_index, other_row in tied_teams[tied_teams.index != index].iterrows():
                    team2 = other_row['team']
                    team2_index = other_index

                    # Check if these two teams played against each other in agg_goals_before_last_day
                    match = agg_goals_before_last_day[
                        ((agg_goals_before_last_day['home_team'] == team1) & (agg_goals_before_last_day['away_team'] == team2)) |
                        ((agg_goals_before_last_day['home_team'] == team2) & (agg_goals_before_last_day['away_team'] == team1))
                    ]

                    if not match.empty:
                        match_result = match.iloc[0]['won']  # Assume the 'won' column holds 1 for home win, -1 for away win, 0 for draw

                        # Resolve the tie using the match result
                        if match_result == 1:
                            # Home team won
                            if match.iloc[0]['home_team'] == team1:
                                group_goals_tracking.loc[group_goals_tracking['team'] == team1, 'tied_won'] = 1
                            else:
                                group_goals_tracking.loc[group_goals_tracking['team'] == team2, 'tied_won'] = 1
                        elif match_result == -1:
                            # Away team won
                            if match.iloc[0]['away_team'] == team1:
                                group_goals_tracking.loc[group_goals_tracking['team'] == team1, 'tied_won'] = 1
                            else:
                                group_goals_tracking.loc[group_goals_tracking['team'] == team2, 'tied_won'] = 1
                        elif match_result == 0:
                            # Draw, both teams get the same standing
                            group_goals_tracking.loc[group_goals_tracking['team'] == team1, 'tied_won'] = 0
                            group_goals_tracking.loc[group_goals_tracking['team'] == team2, 'tied_won'] = 0

        # Step 8c: Sort teams by total points, tied_won, goal difference, and goals scored
        group_goals_tracking = group_goals_tracking.sort_values(by=['total_points', 'tied_won', 'total_goal_difference', 'total_goals_scored'],
                                                                ascending=[False, False, False, False])

        # Step 9: Assign standings based on the sorting and tie resolution
        group_goals_tracking['last_game_standing'] = group_goals_tracking.reset_index(drop=True).index + 1

        # Step 10: Track changes and update standing positions after each goal is processed
        for i, row in group_goals_tracking.iterrows():
            team = row['team']

            if first_iteration:
                # Skip the update if the standing did not change
                if row['before_last_game_standing'] == row['last_game_standing']:
                    continue  # Skip updating the counters
                else:
                    # Update the position counters since standing has changed
                    if row['last_game_standing'] == 1:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '1st'] += 1
                    elif row['last_game_standing'] == 2:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '2nd'] += 1
                    elif row['last_game_standing'] == 3:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '3rd'] += 1
                    elif row['last_game_standing'] == 4:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '4th'] += 1

                # Disable first iteration flag after the first goal
                first_iteration = False
            else:
                # Track the standing position counters only if the position differs from the previous state
                if row['last_game_standing'] != previous_standings[i]:  
                    if row['last_game_standing'] == 1:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '1st'] += 1
                    elif row['last_game_standing'] == 2:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '2nd'] += 1
                    elif row['last_game_standing'] == 3:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '3rd'] += 1
                    elif row['last_game_standing'] == 4:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '4th'] += 1

        # Update previous standings after each goal
        previous_standings = group_goals_tracking['last_game_standing'].copy()

        # Step 11: Calculate changes as the sum of 1st, 2nd, 3rd, and 4th
        group_goals_tracking['changes'] = group_goals_tracking[['1st', '2nd', '3rd', '4th']].sum(axis=1)

        # Step 12: Print the updated group_goals_tracking after processing each goal
        print("\n=== Updated Standings After This Goal ===\n")
        display_columns = ['team', 'total_points', 'total_goals_scored', 'total_goals_conceded', 
                           'total_goal_difference', 'last_game_points', 'last_game_standing', 
                           'changes', '1st', '2nd', '3rd', '4th', 'tied', 'tied_won']
        print(group_goals_tracking[display_columns].to_string(index=False))
        print("\n========================================\n")

    # Step 13: Return the final DataFrame
    return group_goals_tracking

# %%
# Initialize an empty list to store the results for each pair
all_results = []

# Get unique pairs of year and stage
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    stage = row['stage']
    
    # Apply the function to the current pair
    result = uefa_final_euro(year, stage, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)

    
    # Append the result to the list
    all_results.append(result)

# Concatenate all the results into a single DataFrame
changes_df_euro = pd.concat(all_results)

# Keep only the specified columns
changes_df_euro = changes_df_euro[['year', 'stage', 'team', '1st', '2nd', '3rd', '4th', 'changes']]
# Out:
# === Initial Standings for Year 1984, Group 1 Before Last Match Goals ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#     France             4                   6                     0                      6                        4                          1
#    Belgium             2                   2                     5                     -3                        2                          2
#    Denmark             2                   5                     1                      4                        2                          3
# Yugoslavia             0                   0                     7                     -7                        0                          4
#
# ====================================================
#
# Analyzing goal: 26 minute, Player team: Belgium, Home: Denmark, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             5                   6                     0                      6                 1                   1        0    0    0    0    0 False         0
#    Belgium             4                   3                     5                     -2                 2                   2        0    0    0    0    0 False         0
#    Denmark             2                   5                     2                      3                 0                   3        0    0    0    0    0 False         0
# Yugoslavia             1                   0                     7                     -7                 1                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing goal: 32 minute, Player team: Yugoslavia, Home: France, Away: Yugoslavia
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             4                   6                     1                      5                 0                   1        0    0    0    0    0  True         1
#    Belgium             4                   3                     5                     -2                 2                   2        0    0    0    0    0  True         1
#    Denmark             2                   5                     2                      3                 0                   3        0    0    0    0    0  True         1
# Yugoslavia             2                   1                     7                     -6                 2                   4        0    0    0    0    0  True         0
#
# ========================================
#
# Analyzing goal: 39 minute, Player team: Belgium, Home: Denmark, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             4                   6                     1                      5                 0                   1        0    0    0    0    0  True         1
#    Belgium             4                   4                     5                     -1                 2                   2        0    0    0    0    0  True         1
#    Denmark             2                   5                     3                      2                 0                   3        0    0    0    0    0  True         1
# Yugoslavia             2                   1                     7                     -6                 2                   4        0    0    0    0    0  True         0
#
# ========================================
#
# Analyzing goal: 41 minute, Player team: Denmark, Home: Denmark, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             4                   6                     1                      5                 0                   1        0    0    0    0    0  True         1
#    Belgium             4                   4                     6                     -2                 2                   2        0    0    0    0    0  True         1
#    Denmark             2                   6                     3                      3                 0                   3        0    0    0    0    0  True         1
# Yugoslavia             2                   1                     7                     -6                 2                   4        0    0    0    0    0  True         0
#
# ========================================
#
# Analyzing goal: 59 minute, Player team: France, Home: France, Away: Yugoslavia
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             5                   7                     1                      6                 1                   1        0    0    0    0    0 False         0
#    Belgium             4                   4                     6                     -2                 2                   2        0    0    0    0    0 False         0
#    Denmark             2                   6                     3                      3                 0                   3        0    0    0    0    0 False         0
# Yugoslavia             1                   1                     8                     -7                 1                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing goal: 60 minute, Player team: Denmark, Home: Denmark, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             5                   7                     1                      6                 1                   1        0    0    0    0    0 False         0
#    Belgium             3                   4                     7                     -3                 1                   2        0    0    0    0    0  True         1
#    Denmark             3                   7                     3                      4                 1                   3        0    0    0    0    0  True         0
# Yugoslavia             1                   1                     8                     -7                 1                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing goal: 62 minute, Player team: France, Home: France, Away: Yugoslavia
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             6                   8                     1                      7                 2                   1        0    0    0    0    0 False         0
#    Belgium             3                   4                     7                     -3                 1                   2        0    0    0    0    0  True         1
#    Denmark             3                   7                     3                      4                 1                   3        0    0    0    0    0  True         0
# Yugoslavia             0                   1                     9                     -8                 0                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing goal: 77 minute, Player team: France, Home: France, Away: Yugoslavia
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             6                   9                     1                      8                 2                   1        0    0    0    0    0 False         0
#    Belgium             3                   4                     7                     -3                 1                   2        0    0    0    0    0  True         1
#    Denmark             3                   7                     3                      4                 1                   3        0    0    0    0    0  True         0
# Yugoslavia             0                   1                    10                     -9                 0                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing goal: 84 minute, Player team: Yugoslavia, Home: France, Away: Yugoslavia
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             6                   9                     2                      7                 2                   1        0    0    0    0    0 False         0
#    Belgium             3                   4                     7                     -3                 1                   2        0    0    0    0    0  True         1
#    Denmark             3                   7                     3                      4                 1                   3        0    0    0    0    0  True         0
# Yugoslavia             0                   2                    10                     -8                 0                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing goal: 84 minute, Player team: Denmark, Home: Denmark, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             6                   9                     2                      7                 2                   1        0    0    0    0    0 False         0
#    Denmark             4                   8                     3                      5                 2                   2        1    0    1    0    0 False         0
#    Belgium             2                   4                     8                     -4                 0                   3        1    0    0    1    0 False         0
# Yugoslavia             0                   2                    10                     -8                 0                   4        0    0    0    0    0 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1984, Group 2 Before Last Match Goals ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# West Germany             3                   2                     1                      1                        3                          1
#     Portugal             2                   1                     1                      0                        2                          2
#        Spain             2                   2                     2                      0                        2                          3
#      Romania             1                   2                     3                     -1                        1                          4
#
# ====================================================
#
# Analyzing goal: 81 minute, Player team: Portugal, Home: Portugal, Away: Romania
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# West Germany             4                   2                     1                      1                 1                   1        0    0    0    0    0  True         0
#     Portugal             4                   2                     1                      1                 2                   2        0    0    0    0    0  True         0
#        Spain             3                   2                     2                      0                 1                   3        0    0    0    0    0 False         0
#      Romania             1                   2                     4                     -2                 0                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing goal: 90 minute, Player team: Spain, Home: West Germany, Away: Spain
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#        Spain             4                   3                     2                      1                 2                   1        1    1    0    0    0  True         0
#     Portugal             4                   2                     1                      1                 2                   2        0    0    0    0    0  True         0
# West Germany             3                   2                     2                      0                 0                   3        1    0    0    1    0 False         0
#      Romania             1                   2                     4                     -2                 0                   4        0    0    0    0    0 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1988, Group 1 Before Last Match Goals ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#        Italy             3                   2                     1                      1                        3                          1
# West Germany             3                   3                     1                      2                        3                          2
#        Spain             2                   3                     3                      0                        2                          3
#      Denmark             0                   2                     5                     -3                        0                          4
#
# ====================================================
#
# Analyzing goal: 29 minute, Player team: West Germany, Home: West Germany, Away: Spain
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# West Germany             5                   4                     1                      3                 2                   1        1    1    0    0    0 False         0
#        Italy             4                   2                     1                      1                 1                   2        1    0    1    0    0 False         0
#        Spain             2                   3                     4                     -1                 0                   3        1    0    0    1    0 False         0
#      Denmark             1                   2                     5                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 51 minute, Player team: West Germany, Home: West Germany, Away: Spain
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# West Germany             5                   5                     1                      4                 2                   1        1    1    0    0    0 False         0
#        Italy             4                   2                     1                      1                 1                   2        1    0    1    0    0 False         0
#        Spain             2                   3                     5                     -2                 0                   3        1    0    0    1    0 False         0
#      Denmark             1                   2                     5                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 67 minute, Player team: Italy, Home: Italy, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# West Germany             5                   5                     1                      4                 2                   1        1    1    0    0    0  True         0
#        Italy             5                   3                     1                      2                 2                   2        1    0    1    0    0  True         0
#        Spain             2                   3                     5                     -2                 0                   3        1    0    0    1    0 False         0
#      Denmark             0                   2                     6                     -4                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 87 minute, Player team: Italy, Home: Italy, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# West Germany             5                   5                     1                      4                 2                   1        1    1    0    0    0  True         0
#        Italy             5                   4                     1                      3                 2                   2        1    0    1    0    0  True         0
#        Spain             2                   3                     5                     -2                 0                   3        1    0    0    1    0 False         0
#      Denmark             0                   2                     7                     -5                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1988, Group 2 Before Last Match Goals ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# Republic of Ireland             3                   2                     1                      1                        3                          1
#        Soviet Union             3                   2                     1                      1                        3                          2
#         Netherlands             2                   3                     2                      1                        2                          3
#             England             0                   1                     4                     -3                        0                          4
#
# ====================================================
#
# Analyzing goal: 3 minute, Player team: Soviet Union, Home: England, Away: Soviet Union
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#        Soviet Union             5                   3                     1                      2                 2                   1        1    1    0    0    0 False         0
# Republic of Ireland             4                   2                     1                      1                 1                   2        1    0    1    0    0 False         0
#         Netherlands             3                   3                     2                      1                 1                   3        1    0    0    1    0 False         0
#             England             0                   1                     5                     -4                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 16 minute, Player team: England, Home: England, Away: Soviet Union
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#        Soviet Union             4                   3                     2                      1                 1                   1        1    1    0    0    0  True         0
# Republic of Ireland             4                   2                     1                      1                 1                   2        1    0    1    0    0  True         0
#         Netherlands             3                   3                     2                      1                 1                   3        1    0    0    1    0 False         0
#             England             1                   2                     5                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 28 minute, Player team: Soviet Union, Home: England, Away: Soviet Union
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#        Soviet Union             5                   4                     2                      2                 2                   1        1    1    0    0    0 False         0
# Republic of Ireland             4                   2                     1                      1                 1                   2        1    0    1    0    0 False         0
#         Netherlands             3                   3                     2                      1                 1                   3        1    0    0    1    0 False         0
#             England             0                   2                     6                     -4                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 73 minute, Player team: Soviet Union, Home: England, Away: Soviet Union
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#        Soviet Union             5                   5                     2                      3                 2                   1        1    1    0    0    0 False         0
# Republic of Ireland             4                   2                     1                      1                 1                   2        1    0    1    0    0 False         0
#         Netherlands             3                   3                     2                      1                 1                   3        1    0    0    1    0 False         0
#             England             0                   2                     7                     -5                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 82 minute, Player team: Netherlands, Home: Republic of Ireland, Away: Netherlands
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#        Soviet Union             5                   5                     2                      3                 2                   1        1    1    0    0    0 False         0
#         Netherlands             4                   4                     2                      2                 2                   2        2    0    1    1    0 False         0
# Republic of Ireland             3                   2                     2                      0                 0                   3        2    0    1    1    0 False         0
#             England             0                   2                     7                     -5                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1992, Group 1 Before Last Match Goals ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#  Sweden             3                   2                     1                      1                        3                          1
#  France             2                   1                     1                      0                        2                          2
# Denmark             1                   0                     1                     -1                        1                          3
#
# ====================================================
#
# Analyzing goal: 4 minute, Player team: England, Home: Sweden, Away: England
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             3                   2                     2                      0                 0                   1        0    0    0    0    0  True         0
#  France             3                   1                     1                      0                 1                   2        0    0    0    0    0  True         0
# Denmark             2                   0                     1                     -1                 1                   3        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing goal: 8 minute, Player team: Denmark, Home: France, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             3                   2                     2                      0                 0                   1        0    0    0    0    0  True         1
# Denmark             3                   1                     1                      0                 2                   2        1    0    1    0    0  True         0
#  France             2                   1                     2                     -1                 0                   3        1    0    0    1    0 False         0
#
# ========================================
#
# Analyzing goal: 51 minute, Player team: Sweden, Home: Sweden, Away: England
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             4                   3                     2                      1                 1                   1        0    0    0    0    0 False         0
# Denmark             3                   1                     1                      0                 2                   2        1    0    1    0    0 False         0
#  France             2                   1                     2                     -1                 0                   3        1    0    0    1    0 False         0
#
# ========================================
#
# Analyzing goal: 60 minute, Player team: France, Home: France, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             4                   3                     2                      1                 1                   1        0    0    0    0    0 False         0
#  France             3                   2                     2                      0                 1                   2        2    0    1    1    0 False         0
# Denmark             2                   1                     2                     -1                 1                   3        2    0    1    1    0 False         0
#
# ========================================
#
# Analyzing goal: 78 minute, Player team: Denmark, Home: France, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             4                   3                     2                      1                 1                   1        0    0    0    0    0 False         0
# Denmark             3                   2                     2                      0                 2                   2        3    0    2    1    0 False         0
#  France             2                   2                     3                     -1                 0                   3        3    0    1    2    0 False         0
#
# ========================================
#
# Analyzing goal: 82 minute, Player team: Sweden, Home: Sweden, Away: England
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             5                   4                     2                      2                 2                   1        0    0    0    0    0 False         0
# Denmark             3                   2                     2                      0                 2                   2        3    0    2    1    0 False         0
#  France             2                   2                     3                     -1                 0                   3        3    0    1    2    0 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1992, Group 2 Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#     Germany             3                   3                     1                      2                        3                          1
# Netherlands             3                   1                     0                      1                        3                          2
#         CIS             2                   1                     1                      0                        2                          3
#    Scotland             0                   0                     3                     -3                        0                          4
#
# ====================================================
#
# Analyzing goal: 4 minute, Player team: Netherlands, Home: Netherlands, Away: Germany
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   2                     0                      2                 2                   1        1    1    0    0    0 False         0
#     Germany             3                   3                     2                      1                 0                   2        1    0    1    0    0  True         0
#         CIS             3                   1                     1                      0                 1                   3        1    0    0    1    0  True         0
#    Scotland             1                   0                     3                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 7 minute, Player team: Scotland, Home: Scotland, Away: CIS
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   2                     0                      2                 2                   1        1    1    0    0    0 False         0
#     Germany             3                   3                     2                      1                 0                   2        1    0    1    0    0 False         0
#         CIS             2                   1                     2                     -1                 0                   3        1    0    0    1    0  True         0
#    Scotland             2                   1                     3                     -2                 2                   4        1    0    0    0    1  True         0
#
# ========================================
#
# Analyzing goal: 15 minute, Player team: Netherlands, Home: Netherlands, Away: Germany
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   3                     0                      3                 2                   1        1    1    0    0    0 False         0
#     Germany             3                   3                     3                      0                 0                   2        1    0    1    0    0 False         0
#         CIS             2                   1                     2                     -1                 0                   3        1    0    0    1    0  True         0
#    Scotland             2                   1                     3                     -2                 2                   4        1    0    0    0    1  True         0
#
# ========================================
#
# Analyzing goal: 16 minute, Player team: Scotland, Home: Scotland, Away: CIS
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   3                     0                      3                 2                   1        1    1    0    0    0 False         0
#     Germany             3                   3                     3                      0                 0                   2        1    0    1    0    0 False         0
#    Scotland             2                   2                     3                     -1                 2                   3        2    0    0    1    1  True         0
#         CIS             2                   1                     3                     -2                 0                   4        2    0    0    1    1  True         0
#
# ========================================
#
# Analyzing goal: 53 minute, Player team: Germany, Home: Netherlands, Away: Germany
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   3                     1                      2                 2                   1        1    1    0    0    0 False         0
#     Germany             3                   4                     3                      1                 0                   2        1    0    1    0    0 False         0
#    Scotland             2                   2                     3                     -1                 2                   3        2    0    0    1    1  True         0
#         CIS             2                   1                     3                     -2                 0                   4        2    0    0    1    1  True         0
#
# ========================================
#
# Analyzing goal: 72 minute, Player team: Netherlands, Home: Netherlands, Away: Germany
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   4                     1                      3                 2                   1        1    1    0    0    0 False         0
#     Germany             3                   4                     4                      0                 0                   2        1    0    1    0    0 False         0
#    Scotland             2                   2                     3                     -1                 2                   3        2    0    0    1    1  True         0
#         CIS             2                   1                     3                     -2                 0                   4        2    0    0    1    1  True         0
#
# ========================================
#
# Analyzing goal: 84 minute, Player team: Scotland, Home: Scotland, Away: CIS
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   4                     1                      3                 2                   1        1    1    0    0    0 False         0
#     Germany             3                   4                     4                      0                 0                   2        1    0    1    0    0 False         0
#    Scotland             2                   3                     3                      0                 2                   3        2    0    0    1    1  True         0
#         CIS             2                   1                     4                     -3                 0                   4        2    0    0    1    1  True         0
#
# ========================================
#
#
# === Initial Standings for Year 1996, Group A Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#     England             4                   3                     1                      2                        4                          1
# Netherlands             4                   2                     0                      2                        4                          2
#    Scotland             1                   0                     2                     -2                        1                          3
# Switzerland             1                   1                     3                     -2                        1                          4
#
# ====================================================
#
# Analyzing goal: 23 minute, Player team: England, Home: Netherlands, Away: England
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     England             7                   4                     1                      3                 3                   1        0    0    0    0    0 False         0
# Netherlands             4                   2                     1                      1                 0                   2        0    0    0    0    0 False         0
# Switzerland             2                   1                     3                     -2                 1                   3        1    0    0    1    0  True         0
#    Scotland             2                   0                     2                     -2                 1                   4        1    0    0    0    1  True         0
#
# ========================================
#
# Analyzing goal: 36 minute, Player team: Scotland, Home: Scotland, Away: Switzerland
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     England             7                   4                     1                      3                 3                   1        0    0    0    0    0 False         0
# Netherlands             4                   2                     1                      1                 0                   2        0    0    0    0    0  True         1
#    Scotland             4                   1                     2                     -1                 3                   3        2    0    0    1    1  True         0
# Switzerland             1                   1                     4                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing goal: 51 minute, Player team: England, Home: Netherlands, Away: England
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     England             7                   5                     1                      4                 3                   1        0    0    0    0    0 False         0
# Netherlands             4                   2                     2                      0                 0                   2        0    0    0    0    0  True         1
#    Scotland             4                   1                     2                     -1                 3                   3        2    0    0    1    1  True         0
# Switzerland             1                   1                     4                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing goal: 57 minute, Player team: England, Home: Netherlands, Away: England
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     England             7                   6                     1                      5                 3                   1        0    0    0    0    0 False         0
# Netherlands             4                   2                     3                     -1                 0                   2        0    0    0    0    0  True         1
#    Scotland             4                   1                     2                     -1                 3                   3        2    0    0    1    1  True         0
# Switzerland             1                   1                     4                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing goal: 62 minute, Player team: England, Home: Netherlands, Away: England
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     England             7                   7                     1                      6                 3                   1        0    0    0    0    0 False         0
# Netherlands             4                   2                     4                     -2                 0                   2        0    0    0    0    0  True         1
#    Scotland             4                   1                     2                     -1                 3                   3        2    0    0    1    1  True         0
# Switzerland             1                   1                     4                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing goal: 78 minute, Player team: Netherlands, Home: Netherlands, Away: England
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     England             7                   7                     2                      5                 3                   1        0    0    0    0    0 False         0
# Netherlands             4                   3                     4                     -1                 0                   2        0    0    0    0    0  True         1
#    Scotland             4                   1                     2                     -1                 3                   3        2    0    0    1    1  True         0
# Switzerland             1                   1                     4                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1996, Group B Before Last Match Goals ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# Bulgaria             4                   2                     1                      1                        4                          1
#   France             4                   2                     1                      1                        4                          2
#    Spain             2                   2                     2                      0                        2                          3
#  Romania             0                   0                     2                     -2                        0                          4
#
# ====================================================
#
# Analyzing goal: 11 minute, Player team: Spain, Home: Romania, Away: Spain
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#    Spain             5                   3                     2                      1                 3                   1        1    1    0    0    0  True         0
# Bulgaria             5                   2                     1                      1                 1                   2        1    0    1    0    0  True         0
#   France             5                   2                     1                      1                 1                   3        1    0    0    1    0  True         0
# ...
#     Austria             6                   4                     2                      2                 3                   1        1    1    0    0    0 False         0
#      France             5                   1                     0                      1                 1                   2        1    0    1    0    0 False         0
# Netherlands             4                   2                     2                      0                 0                   3        1    0    0    1    0 False         0
#      Poland             1                   2                     5                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 47 minute, Player team: Netherlands, Home: Netherlands, Away: Austria
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   3                     2                      1                 1                   1        2    1    0    1    0  True         1
#      France             5                   1                     0                      1                 1                   2        1    0    1    0    0  True         0
#     Austria             4                   4                     3                      1                 1                   3        2    1    0    1    0 False         0
#      Poland             1                   2                     5                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 56 minute, Player team: France, Home: France, Away: Poland
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      France             7                   2                     0                      2                 3                   1        2    1    1    0    0 False         0
# Netherlands             5                   3                     2                      1                 1                   2        3    1    1    1    0 False         0
#     Austria             4                   4                     3                      1                 1                   3        2    1    0    1    0 False         0
#      Poland             0                   2                     6                     -4                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 59 minute, Player team: Austria, Home: Netherlands, Away: Austria
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      France             7                   2                     0                      2                 3                   1        2    1    1    0    0 False         0
#     Austria             6                   5                     3                      2                 3                   2        3    1    1    1    0 False         0
# Netherlands             4                   3                     3                      0                 0                   3        4    1    1    2    0 False         0
#      Poland             0                   2                     6                     -4                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 75 minute, Player team: Netherlands, Home: Netherlands, Away: Austria
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      France             7                   2                     0                      2                 3                   1        2    1    1    0    0 False         0
# Netherlands             5                   4                     3                      1                 1                   2        5    1    2    2    0 False         0
#     Austria             4                   5                     4                      1                 1                   3        4    1    1    2    0 False         0
#      Poland             0                   2                     6                     -4                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 79 minute, Player team: Poland, Home: France, Away: Poland
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   4                     3                      1                 1                   1        6    2    2    2    0  True         1
#      France             5                   2                     1                      1                 1                   2        3    1    2    0    0  True         0
#     Austria             4                   5                     4                      1                 1                   3        4    1    1    2    0 False         0
#      Poland             1                   3                     6                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 80 minute, Player team: Austria, Home: Netherlands, Away: Austria
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     Austria             6                   6                     4                      2                 3                   1        5    2    1    2    0 False         0
#      France             5                   2                     1                      1                 1                   2        3    1    2    0    0 False         0
# Netherlands             4                   4                     4                      0                 0                   3        7    2    2    3    0 False         0
#      Poland             1                   3                     6                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2024, Group E Before Last Match Goals ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#  Belgium             4                   2                     0                      2                        4                          1
#  Romania             3                   3                     2                      1                        3                          2
#  Ukraine             3                   2                     4                     -2                        3                          3
# Slovakia             1                   1                     2                     -1                        1                          4
#
# ====================================================
#
# Analyzing goal: 24 minute, Player team: Slovakia, Home: Slovakia, Away: Romania
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Belgium             5                   2                     0                      2                 1                   1        0    0    0    0    0 False         0
#  Ukraine             4                   2                     4                     -2                 1                   2        1    0    1    0    0  True         1
# Slovakia             4                   2                     2                      0                 3                   3        1    0    0    1    0  True         0
#  Romania             3                   3                     3                      0                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 37 minute, Player team: Romania, Home: Slovakia, Away: Romania
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Belgium             5                   2                     0                      2                 1                   1        0    0    0    0    0 False         0
#  Romania             4                   4                     3                      1                 1                   2        2    0    1    0    1  True         1
#  Ukraine             4                   2                     4                     -2                 1                   3        2    0    1    1    0  True         0
# Slovakia             2                   2                     3                     -1                 1                   4        2    0    0    1    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2024, Group F Before Last Match Goals ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#       Portugal             6                   5                     1                      4                        6                          1
#         Turkey             3                   3                     4                     -1                        3                          2
# Czech Republic             1                   2                     3                     -1                        1                          3
#        Georgia             1                   2                     4                     -2                        1                          4
#
# ====================================================
#
# Analyzing goal: 2 minute, Player team: Georgia, Home: Georgia, Away: Portugal
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#       Portugal             6                   5                     2                      3                 0                   1        0    0    0    0    0 False         0
#         Turkey             4                   3                     4                     -1                 1                   2        0    0    0    0    0  True         1
#        Georgia             4                   3                     4                     -1                 3                   3        1    0    0    1    0  True         0
# Czech Republic             2                   2                     3                     -1                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 51 minute, Player team: Turkey, Home: Czech Republic, Away: Turkey
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#       Portugal             6                   5                     2                      3                 0                   1        0    0    0    0    0  True         1
#         Turkey             6                   4                     4                      0                 3                   2        0    0    0    0    0  True         0
#        Georgia             4                   3                     4                     -1                 3                   3        1    0    0    1    0 False         0
# Czech Republic             1                   2                     4                     -2                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 57 minute, Player team: Georgia, Home: Georgia, Away: Portugal
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#       Portugal             6                   5                     3                      2                 0                   1        0    0    0    0    0  True         1
#         Turkey             6                   4                     4                      0                 3                   2        0    0    0    0    0  True         0
#        Georgia             4                   4                     4                      0                 3                   3        1    0    0    1    0 False         0
# Czech Republic             1                   2                     4                     -2                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 66 minute, Player team: Czech Republic, Home: Czech Republic, Away: Turkey
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#       Portugal             6                   5                     3                      2                 0                   1        0    0    0    0    0 False         0
#         Turkey             4                   4                     5                     -1                 1                   2        0    0    0    0    0  True         1
#        Georgia             4                   4                     4                      0                 3                   3        1    0    0    1    0  True         0
# Czech Republic             2                   3                     4                     -1                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing goal: 94 minute, Player team: Turkey, Home: Czech Republic, Away: Turkey
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#       Portugal             6                   5                     3                      2                 0                   1        0    0    0    0    0  True         1
#         Turkey             6                   5                     5                      0                 3                   2        0    0    0    0    0  True         0
#        Georgia             4                   4                     4                      0                 3                   3        1    0    0    1    0 False         0
# Czech Republic             1                   3                     5                     -2                 0                   4        1    0    0    0    1 False         0
#
# ========================================

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\tb_euro_uefa.xlsx'
changes_df_euro.to_excel(file_path, index=False)

# %% [markdown]
# # group composition tracking

# %%
def track_composition_changes(year, stage, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day):
    # Step 1: Filter the data for the specific year and stage
    group_goals_tracking = all_games_before_last[
        (all_games_before_last['year'] == year) & 
        (all_games_before_last['stage'] == stage)
    ].copy()

    group_goals_last_day = goals_last_day_sorted[
        (goals_last_day_sorted['year'] == year) & 
        (goals_last_day_sorted['stage'] == stage)
    ]

    # Initialize columns for team performance and standings
    group_goals_tracking['before_last_game_goals_scored'] = group_goals_tracking['goals_scored']
    group_goals_tracking['before_last_game_goals_conceded'] = group_goals_tracking['goals_conceded']
    group_goals_tracking['before_last_game_standing'] = group_goals_tracking['standing']
    group_goals_tracking['before_last_game_points'] = group_goals_tracking['points']
    group_goals_tracking['last_game_goals_scored'] = 0
    group_goals_tracking['last_game_goals_conceded'] = 0
    group_goals_tracking['total_goals_scored'] = group_goals_tracking['before_last_game_goals_scored']
    group_goals_tracking['total_goals_conceded'] = group_goals_tracking['before_last_game_goals_conceded']
    group_goals_tracking['total_goal_difference'] = group_goals_tracking['total_goals_scored'] - group_goals_tracking['total_goals_conceded']
    group_goals_tracking['last_game_points'] = 0
    group_goals_tracking['total_points'] = group_goals_tracking['before_last_game_points']
    group_goals_tracking['last_game_standing'] = 0
    group_goals_tracking['tied_won'] = 0  # Initialize tied_won for tiebreak resolution

    # Define top standings limit based on the year
    top_standings_limit = 3 if year <= 1994 else 2

    # Determine the initial standings for 1st, 2nd, 3rd, and third-placed teams
    sorted_initial = group_goals_tracking.sort_values(by=['before_last_game_points', 'total_goal_difference', 'before_last_game_goals_scored'], ascending=[False, False, False])
    first_place_team = sorted_initial.iloc[0]['team'] if len(sorted_initial) > 0 else None
    second_place_team = sorted_initial.iloc[1]['team'] if len(sorted_initial) > 1 else None
    third_place_team = sorted_initial.iloc[2]['team'] if len(sorted_initial) > 2 else None

    # Identify third-place teams by group
    third_place_teams = []
    for group, group_data in group_goals_tracking.groupby('stage'):
        sorted_group = group_data.sort_values(by=['before_last_game_points', 'total_goal_difference', 'before_last_game_goals_scored'], ascending=[False, False, False])
        if len(sorted_group) >= 3:
            third_place_teams.append(sorted_group.iloc[2]['team'])

    # Determine if the third-placed team is among the top 4 third-placed teams initially
    third_place_df = group_goals_tracking[group_goals_tracking['team'].isin(third_place_teams)]
    top4_third_place_teams = third_place_df.sort_values(
        by=['before_last_game_points', 'total_goal_difference', 'before_last_game_goals_scored'], 
        ascending=[False, False, False]
    ).head(4)['team'].tolist()
    is_top4_third_place_initial = 1 if third_place_team in top4_third_place_teams else 0

    # Step 2: Initialize composition tracking with initial composition (change_num = 0)
    initial_top_teams = set(sorted_initial.nsmallest(top_standings_limit, 'before_last_game_standing')['team'])
    composition_changes = [{
        'year': year,
        'stage': stage,
        'change_num': 0,
        'goal_time': 'initial',
        'home_team': None,
        'away_team': None,
        'scorer_team': None,
        'new_top_teams': list(initial_top_teams),
        'third_place_teams_list': third_place_teams,
        'top4_third_place': is_top4_third_place_initial,
        '1st': first_place_team,
        '2nd': second_place_team,
        '3rd': third_place_team
    }]
    change_counter = 0  # Counter for the number of composition changes

    # Step 3: Sort goals by regulation time
    group_goals_last_day = group_goals_last_day.sort_values(by=['goal_minute'])

    # Step 4: Iterate through each goal and track changes in composition
    for _, goal in group_goals_last_day.iterrows():
        home_team = goal['home_team']
        away_team = goal['away_team']
        scorer_team = goal['scorer_nationality']

        # Update scores based on who scored the goal
        if scorer_team == home_team:
            group_goals_tracking.loc[group_goals_tracking['team'] == home_team, 'last_game_goals_scored'] += 1
            group_goals_tracking.loc[group_goals_tracking['team'] == away_team, 'last_game_goals_conceded'] += 1
        elif scorer_team == away_team:
            group_goals_tracking.loc[group_goals_tracking['team'] == away_team, 'last_game_goals_scored'] += 1
            group_goals_tracking.loc[group_goals_tracking['team'] == home_team, 'last_game_goals_conceded'] += 1

        # Update total goals, goal difference, and total points
        group_goals_tracking['total_goals_scored'] = group_goals_tracking['before_last_game_goals_scored'] + group_goals_tracking['last_game_goals_scored']
        group_goals_tracking['total_goals_conceded'] = group_goals_tracking['before_last_game_goals_conceded'] + group_goals_tracking['last_game_goals_conceded']
        group_goals_tracking['total_goal_difference'] = group_goals_tracking['total_goals_scored'] - group_goals_tracking['total_goals_conceded']

        # Step 5: Calculate tied_won for tied teams based on head-to-head results
        group_goals_tracking['tied'] = group_goals_tracking.duplicated(subset=['total_points'], keep=False)
        group_goals_tracking['tied_won'] = 0  # Reset tied_won for all teams

        tied_teams = group_goals_tracking[group_goals_tracking['tied']]
        if not tied_teams.empty:
            for index, row in tied_teams.iterrows():
                team1 = row['team']
                for _, other_row in tied_teams[tied_teams.index != index].iterrows():
                    team2 = other_row['team']
                    match = agg_goals_before_last_day[
                        ((agg_goals_before_last_day['home_team'] == team1) & (agg_goals_before_last_day['away_team'] == team2)) |
                        ((agg_goals_before_last_day['home_team'] == team2) & (agg_goals_before_last_day['away_team'] == team1))
                    ]

                    if not match.empty:
                        match_result = match.iloc[0]['won']
                        if match_result == 1:
                            if match.iloc[0]['home_team'] == team1:
                                group_goals_tracking.loc[group_goals_tracking['team'] == team1, 'tied_won'] = 1
                            else:
                                group_goals_tracking.loc[group_goals_tracking['team'] == team2, 'tied_won'] = 1
                        elif match_result == -1:
                            if match.iloc[0]['away_team'] == team1:
                                group_goals_tracking.loc[group_goals_tracking['team'] == team1, 'tied_won'] = 1
                            else:
                                group_goals_tracking.loc[group_goals_tracking['team'] == team2, 'tied_won'] = 1

        # Calculate points and update standings as needed
        group_goals_tracking['total_points'] = group_goals_tracking['before_last_game_points'] + group_goals_tracking['last_game_points']
        group_goals_tracking = group_goals_tracking.sort_values(by=['total_points', 'tied_won', 'total_goal_difference', 'total_goals_scored'], ascending=[False, False, False, False])
        group_goals_tracking['last_game_standing'] = group_goals_tracking.reset_index(drop=True).index + 1

        # Track 1st, 2nd, and 3rd teams
        top_teams = group_goals_tracking[group_goals_tracking['last_game_standing'] <= 3]
        first_place_team = top_teams.iloc[0]['team'] if len(top_teams) > 0 else None
        second_place_team = top_teams.iloc[1]['team'] if len(top_teams) > 1 else None
        third_place_team = top_teams.iloc[2]['team'] if len(top_teams) > 2 else None

        # Determine changes
        current_top_teams = set(group_goals_tracking.nsmallest(top_standings_limit, 'last_game_standing')['team'])
        if current_top_teams != initial_top_teams:
            change_counter += 1
            initial_top_teams = current_top_teams
            composition_changes.append({
                'year': year,
                'stage': stage,
                'change_num': change_counter,
                'goal_time': goal['goal_minute'],
                'home_team': home_team,
                'away_team': away_team,
                'scorer_nationality': scorer_team,
                'new_top_teams': list(current_top_teams),
                'top4_third_place': 1 if third_place_team in top4_third_place_teams else 0,
                '1st': first_place_team,
                '2nd': second_place_team,
                '3rd': third_place_team
            })

    return pd.DataFrame(composition_changes)

# %%
# Initialize an empty list to store the results for each pair
all_composition_changes = []

# Get unique pairs of year and stage
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    stage = row['stage']
    
    # Apply the function to the current pair
    composition_changes_df = track_composition_changes(year, stage, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_composition_changes.append(composition_changes_df)

# Concatenate all the results into a single DataFrame
final_composition_changes_df = pd.concat(all_composition_changes, ignore_index=True)

# Display the final DataFrame
display(final_composition_changes_df)
# Out:
#     year    stage  change_num goal_time home_team       away_team scorer_team  \
# 0   1984  Group 1           0   initial      None            None        None
# 1   1984  Group 2           0   initial      None            None        None
# 2   1988  Group 1           0   initial      None            None        None
# 3   1988  Group 2           0   initial      None            None        None
# 4   1992  Group 1           0   initial      None            None        None
# 5   1992  Group 2           0   initial      None            None        None
# 6   1996  Group A           0   initial      None            None        None
# 7   1996  Group B           0   initial      None            None        None
# 8   1996  Group C           0   initial      None            None        None
# 9   1996  Group D           0   initial      None            None        None
# 10  2000  Group A           0   initial      None            None        None
# 11  2000  Group B           0   initial      None            None        None
# 12  2000  Group C           0   initial      None            None        None
# 13  2000  Group D           0   initial      None            None        None
# 14  2004  Group A           0   initial      None            None        None
# 15  2004  Group B           0   initial      None            None        None
# 16  2004  Group C           0   initial      None            None        None
# 17  2004  Group D           0   initial      None            None        None
# 18  2008  Group A           0   initial      None            None         NaN
# 19  2008  Group A           1        89    Turkey  Czech Republic         NaN
# 20  2008  Group B           0   initial      None            None        None
# 21  2008  Group C           0   initial      None            None        None
# 22  2008  Group D           0   initial      None            None         NaN
# 23  2008  Group D           1        24    Russia          Sweden         NaN
# 24  2008  Group D           2        50    Russia          Sweden         NaN
# 25  2012  Group A           0   initial      None            None        None
# 26  2012  Group B           0   initial      None            None         NaN
# 27  2012  Group B           1        74  Portugal     Netherlands         NaN
# 28  2012  Group C           0   initial      None            None        None
# 29  2012  Group D           0   initial      None            None        None
# 30  2016  Group A           0   initial      None            None        None
# 31  2016  Group B           0   initial      None            None         NaN
# 32  2016  Group B           1        11    Russia           Wales         NaN
# 33  2016  Group C           0   initial      None            None        None
# 34  2016  Group D           0   initial      None            None        None
# 35  2016  Group E           0   initial      None            None        None
# 36  2016  Group F           0   initial      None            None         NaN
# 37  2016  Group F           1        62   Hungary        Portugal         NaN
# 38  2016  Group F           2        94   Iceland         Austria         NaN
# 39  2021  Group A           0   initial      None            None        None
# 40  2021  Group B           0   initial      None            None         NaN
# 41  2021  Group B           1        38    Russia         Denmark         NaN
# 42  2021  Group C           0   initial      None            None        None
# 43  2021  Group D           0   initial      None            None        None
# 44  2021  Group E           0   initial      None            None        None
# 45  2021  Group F           0   initial      None            None        None
# 46  2024  Group A           0   initial      None            None        None
# 47  2024  Group B           0   initial      None            None        None
# 48  2024  Group C           0   initial      None            None         NaN
# 49  2024  Group C           1        18   Denmark         England         NaN
# 50  2024  Group C           2        34   Denmark         England         NaN
# 51  2024  Group C           3        69  Slovenia          Serbia         NaN
# 52  2024  Group D           0   initial      None            None        None
# 53  2024  Group E           0   initial      None            None        None
# 54  2024  Group F           0   initial      None            None        None
#
#                                        new_top_teams third_place_teams_list  \
# 0                         [France, Belgium, Denmark]              [Belgium]
# 1                    [Spain, West Germany, Portugal]             [Portugal]
# 2                       [Italy, West Germany, Spain]                [Spain]
# 3   [Netherlands, Soviet Union, Republic of Ireland]          [Netherlands]
# 4                          [Sweden, France, Denmark]              [Denmark]
# 5                        [Netherlands, CIS, Germany]                  [CIS]
# 6                             [Netherlands, England]          [Switzerland]
# 7                                 [France, Bulgaria]                [Spain]
# 8                          [Czech Republic, Germany]       [Czech Republic]
# 9                                [Croatia, Portugal]              [Denmark]
# 10                               [Portugal, England]              [Germany]
# 11                                  [Belgium, Italy]               [Sweden]
# 12                           [FR Yugoslavia, Norway]               [Norway]
# 13                             [France, Netherlands]       [Czech Republic]
# 14                                   [Greece, Spain]             [Portugal]
# 15                                 [France, England]              [Croatia]
# 16                                 [Denmark, Sweden]                [Italy]
# 17                         [Czech Republic, Germany]          [Netherlands]
# 18                        [Czech Republic, Portugal]               [Turkey]
# 19                                [Portugal, Turkey]                    NaN
# 20                                [Croatia, Germany]              [Austria]
# 21                            [Netherlands, Romania]               [France]
# 22                                   [Russia, Spain]               [Russia]
# 23                                   [Sweden, Spain]                    NaN
# 24                                   [Russia, Spain]                    NaN
# 25                          [Czech Republic, Russia]               [Poland]
# 26                                [Denmark, Germany]             [Portugal]
# 27                               [Portugal, Germany]                    NaN
# 28                                  [Croatia, Spain]                [Italy]
# 29                                 [France, England]              [Ukraine]
# 30                             [France, Switzerland]              [Romania]
# 31                               [Slovakia, England]                [Wales]
# 32                                  [Wales, England]                    NaN
# 33                                 [Poland, Germany]     [Northern Ireland]
# 34                                  [Croatia, Spain]       [Czech Republic]
# 35                                  [Belgium, Italy]               [Sweden]
# 36                                [Iceland, Hungary]             [Portugal]
# 37                               [Hungary, Portugal]                    NaN
# 38                                [Iceland, Hungary]                    NaN
# 39                                    [Wales, Italy]          [Switzerland]
# 40                                [Belgium, Finland]               [Russia]
# 41                                 [Belgium, Russia]                    NaN
# 42                            [Netherlands, Austria]              [Austria]
# 43                         [Czech Republic, England]              [Croatia]
# 44                                [Sweden, Slovakia]                [Spain]
# 45                                 [France, Germany]              [Germany]
# 46                            [Switzerland, Germany]             [Scotland]
# 47                                    [Italy, Spain]              [Albania]
# 48                                [Denmark, England]             [Slovenia]
# 49                               [Slovenia, England]                    NaN
# 50                                [Denmark, England]                    NaN
# 51                               [Slovenia, England]                    NaN
# 52                             [France, Netherlands]              [Austria]
# 53                                [Belgium, Romania]              [Ukraine]
# 54                                [Portugal, Turkey]       [Czech Republic]
#
#     top4_third_place                  1st             2nd               3rd  \
# 0                  1               France         Denmark           Belgium
# 1                  1         West Germany           Spain          Portugal
# 2                  1         West Germany           Italy             Spain
# 3                  1  Republic of Ireland    Soviet Union       Netherlands
# 4                  1               Sweden          France           Denmark
# 5                  1              Germany     Netherlands               CIS
# 6                  1              England     Netherlands       Switzerland
# 7                  1             Bulgaria          France             Spain
# 8                  1              Germany           Italy    Czech Republic
# 9                  1              Croatia        Portugal           Denmark
# 10                 1             Portugal         England           Germany
# 11                 1                Italy         Belgium            Sweden
# 12                 1        FR Yugoslavia           Spain            Norway
# 13                 1               France     Netherlands    Czech Republic
# 14                 1               Greece           Spain          Portugal
# 15                 1               France         England           Croatia
# 16                 1               Sweden         Denmark             Italy
# 17                 1       Czech Republic         Germany       Netherlands
# 18                 1             Portugal  Czech Republic            Turkey
# 19                 0             Portugal          Turkey    Czech Republic
# 20                 1              Croatia         Germany           Austria
# 21                 1          Netherlands         Romania            France
# 22                 1                Spain          Sweden            Russia
# 23                 1                Spain          Sweden            Russia
# 24                 0                Spain          Russia            Sweden
# 25                 1               Russia  Czech Republic            Poland
# 26                 1              Germany         Denmark          Portugal
# 27                 0              Germany        Portugal           Denmark
# 28                 1                Spain         Croatia             Italy
# 29                 1               France         England           Ukraine
# 30                 1               France     Switzerland           Romania
# 31                 1              England        Slovakia             Wales
# 32                 0              England           Wales          Slovakia
# 33                 1              Germany          Poland  Northern Ireland
# 34                 1                Spain         Croatia    Czech Republic
# 35                 1                Italy         Belgium            Sweden
# 36                 1              Hungary         Iceland          Portugal
# 37                 0              Hungary        Portugal           Iceland
# 38                 1              Hungary         Iceland          Portugal
# 39                 1                Italy           Wales       Switzerland
# 40                 1              Belgium         Finland            Russia
# 41                 0              Belgium          Russia           Finland
# 42                 1          Netherlands         Ukraine           Austria
# 43                 1       Czech Republic         England           Croatia
# 44                 1               Sweden        Slovakia             Spain
# 45                 1               France        Portugal           Germany
# 46                 1              Germany     Switzerland          Scotland
# 47                 1                Spain           Italy           Albania
# 48                 1              England         Denmark          Slovenia
# 49                 0              England        Slovenia           Denmark
# 50                 1              England         Denmark          Slovenia
# 51                 0              England        Slovenia           Denmark
# 52                 1          Netherlands          France           Austria
# 53                 1              Belgium         Romania           Ukraine
# 54                 1             Portugal          Turkey    Czech Republic
#
#    scorer_nationality
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19             Turkey
# 20                NaN
# 21                NaN
# 22                NaN
# 23             Russia
# 24             Russia
# 25                NaN
# 26                NaN
# 27           Portugal
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32              Wales
# 33                NaN
# 34                NaN
# 35                NaN
# 36                NaN
# 37           Portugal
# 38            Iceland
# 39                NaN
# 40                NaN
# 41            Denmark
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# 46                NaN
# 47                NaN
# 48                NaN
# 49            England
# 50            Denmark
# 51           Slovenia
# 52                NaN
# 53                NaN
# 54                NaN

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\standings_euro_eufa.xlsx'
final_composition_changes_df.to_excel(file_path, index=False)

# %% [markdown]
# # best four third placed

# %%
def best_four_third_placed(goals_last_day_sorted, all_games_before_last, agg_goals_before_last_day):
    # Apply filter to process only years <= 2024
    all_games_before_last = all_games_before_last[all_games_before_last['year'] >= 2016].copy()

    # Initialize a list to store data for each year that will be appended into the final DataFrame
    all_years_data = []

    # Group data by year and process year-by-year
    for year, year_data in all_games_before_last.groupby('year'):
        print(f"\n--- Processing Year: {year} ---")
        year_data = year_data.copy()

        # Initialize dictionaries to track third-placed teams and top 4 counts for the current year
        third_teams_count = {}
        top4_count = {}

        # Step 1: Initialize columns for tracking team performance before and after goals
        year_data.loc[:, 'before_last_game_goals_scored'] = year_data['goals_scored']
        year_data.loc[:, 'before_last_game_goals_conceded'] = year_data['goals_conceded']
        year_data.loc[:, 'before_last_game_points'] = year_data['points']

        year_data.loc[:, 'last_game_goals_scored'] = 0
        year_data.loc[:, 'last_game_goals_conceded'] = 0
        year_data.loc[:, 'last_game_points'] = 0
        year_data.loc[:, 'total_goals_scored'] = year_data['before_last_game_goals_scored'] + year_data['last_game_goals_scored']
        year_data.loc[:, 'total_goals_conceded'] = year_data['before_last_game_goals_conceded'] + year_data['last_game_goals_conceded']
        year_data.loc[:, 'total_goal_difference'] = year_data['total_goals_scored'] - year_data['total_goals_conceded']

        
        # Print the standings before any goal is processed
        print(f"\n=== Initial Standings for Year {year} Before Processing Any Goals ===\n")
        display_columns = ['team', 'stage', 'before_last_game_points', 'before_last_game_goals_scored', 'before_last_game_goals_conceded', 'total_goal_difference']
        print(year_data[display_columns].sort_values(by=['stage', 'before_last_game_points', 'total_goal_difference', 'before_last_game_goals_scored'], ascending=[True, False, False, False]).to_string(index=False))
        print("\n===============================================================\n")

        # Process each goal from the sorted last-day goals for the current year
        goals_last_day_year = goals_last_day_sorted[goals_last_day_sorted['year'] == year]

        for i, goal in goals_last_day_year.iterrows():
            print(f"\n--- Analyzing Goal {i + 1} in {goal['stage']}: On date {goal['short_date']}, Minute {goal['goal_minute']} (Player Team: {goal['scorer_nationality']}, Home: {goal['home_team']}, Away: {goal['away_team']}) ---")

            home_team = goal['home_team']
            away_team = goal['away_team']
            player_team = goal['scorer_nationality']

            # Identify the opponent team
            opponent_team = home_team if player_team == away_team else away_team

            year_data.loc[year_data['team'] == player_team, 'last_game_goals_scored'] += 1
            year_data.loc[year_data['team'] == opponent_team, 'last_game_goals_conceded'] += 1

            # Update total goals scored, goals conceded, and goal difference
            year_data.loc[:, 'total_goals_scored'] = year_data['before_last_game_goals_scored'] + year_data['last_game_goals_scored']
            year_data.loc[:, 'total_goals_conceded'] = year_data['before_last_game_goals_conceded'] + year_data['last_game_goals_conceded']
            year_data.loc[:, 'total_goal_difference'] = year_data['total_goals_scored'] - year_data['total_goals_conceded']

            # Assign points for the last game dynamically
            year_data.loc[:, 'last_game_points'] = (year_data['last_game_goals_scored'] > year_data['last_game_goals_conceded']).astype(int) * 3 + \
                                                   (year_data['last_game_goals_scored'] == year_data['last_game_goals_conceded']).astype(int)

            # Update total points
            year_data.loc[:, 'total_points'] = year_data['before_last_game_points'] + year_data['last_game_points']

            # Reset third-placed teams after every goal
            third_teams_per_year = []

            # Recalculate standings after the goal
            for group, group_data in year_data.groupby('stage'):
                sorted_standings = group_data.sort_values(by=['total_points', 'total_goal_difference', 'total_goals_scored'], ascending=[False, False, False])

                # Identify the third-placed teams after each goal, **by group**
                if len(sorted_standings) >= 3:
                    third_placed_team = sorted_standings.iloc[2]
                    third_teams_per_year.append(third_placed_team['team'])

            # Update the count for third-placed teams after each goal
            for team in third_teams_per_year:
                if team not in third_teams_count:
                    third_teams_count[team] = 0
                third_teams_count[team] += 1

            # Create DataFrame of third-placed teams with additional stats
            third_teams_df = year_data[year_data['team'].isin(third_teams_per_year)][
                ['team', 'total_points', 'last_game_points', 'total_goal_difference', 'total_goals_scored']
            ]

            # Identify the best four third-placed teams after each goal
            top4_teams = third_teams_df['team'].value_counts().nlargest(4).index.tolist()

            # Print third-placed teams' additional statistics after each goal
            print(f"Top 4 third-placed teams after this goal: {top4_teams}")
            print(f"Third-placed teams DataFrame after this goal:\n{third_teams_df}\n")

            # Update the count for top 4 third-placed teams after each goal
            for team in top4_teams:
                if team not in top4_count:
                    top4_count[team] = 0
                top4_count[team] += 1

        # After processing all goals for the year, store the results in the final list
        for team, third_count in third_teams_count.items():
            top4_count_for_team = top4_count.get(team, 0)
            all_years_data.append({
                'team': team,
                'year': year,
                'third_place_count': third_count,
                'top4_third_place_count': top4_count_for_team
            })

    # Create a DataFrame from the list of all years' data
    final_df = pd.DataFrame(all_years_data)

    file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\third_teams_euro.xlsx'
    final_df.to_excel(file_path, index=False)
    
    return final_df

# %%
best_four_third_placed(goals_last_day_sorted, all_games_before_last, agg_goals_before_last_day)
# Out:
# --- Processing Year: 2016 ---
#
# === Initial Standings for Year 2016 Before Processing Any Goals ===
#
#                team   stage  before_last_game_points  before_last_game_goals_scored  before_last_game_goals_conceded  total_goal_difference
#              France Group A                        6                              4                                1                      3
#         Switzerland Group A                        4                              2                                1                      1
#             Romania Group A                        1                              2                                3                     -1
#             Albania Group A                        0                              0                                3                     -3
#             England Group B                        4                              3                                2                      1
#            Slovakia Group B                        3                              3                                3                      0
#               Wales Group B                        3                              3                                3                      0
#              Russia Group B                        1                              2                                3                     -1
#             Germany Group C                        4                              2                                0                      2
#              Poland Group C                        4                              1                                0                      1
#    Northern Ireland Group C                        3                              2                                1                      1
#             Ukraine Group C                        0                              0                                4                     -4
#               Spain Group D                        6                              4                                0                      4
#             Croatia Group D                        4                              3                                2                      1
#      Czech Republic Group D                        1                              2                                3                     -1
#              Turkey Group D                        0                              0                                4                     -4
#               Italy Group E                        6                              3                                0                      3
#             Belgium Group E                        3                              3                                2                      1
#              Sweden Group E                        1                              1                                2                     -1
# Republic of Ireland Group E                        1                              1                                4                     -3
#             Hungary Group F                        4                              3                                1                      2
#             Iceland Group F                        2                              2                                2                      0
#            Portugal Group F                        2                              1                                1                      0
#             Austria Group F                        1                              0                                2                     -2
#
# ===============================================================
#
#
# --- Analyzing Goal 146 in Group A: On date 2016-06-19 00:00:00, Minute 43 (Player Team: Albania, Home: Romania, Away: Albania) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Wales', 'Northern Ireland', 'Czech Republic']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 109             Wales             4                 1                      0
# 113  Northern Ireland             4                 1                      1
# 117    Czech Republic             2                 1                     -1
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 109                   3
# 113                   2
# 117                   2
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 147 in Group B: On date 2016-06-20 00:00:00, Minute 11 (Player Team: Wales, Home: Russia, Away: Wales) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Czech Republic']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             4                 1                      1
# 117    Czech Republic             2                 1                     -1
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 117                   2
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 148 in Group B: On date 2016-06-20 00:00:00, Minute 20 (Player Team: Wales, Home: Russia, Away: Wales) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Czech Republic']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             4                 1                      1
# 117    Czech Republic             2                 1                     -1
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 117                   2
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 149 in Group B: On date 2016-06-20 00:00:00, Minute 67 (Player Team: Wales, Home: Russia, Away: Wales) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Czech Republic']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             4                 1                      1
# 117    Czech Republic             2                 1                     -1
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 117                   2
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 156 in Group D: On date 2016-06-21 00:00:00, Minute 7 (Player Team: Spain, Home: Croatia, Away: Spain) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Czech Republic']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             4                 1                      1
# 117    Czech Republic             2                 1                     -1
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 117                   2
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 152 in Group D: On date 2016-06-21 00:00:00, Minute 10 (Player Team: Turkey, Home: Czech Republic, Away: Turkey) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             4                 1                      1
# 118            Turkey             3                 3                     -3
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   1
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 151 in Group C: On date 2016-06-21 00:00:00, Minute 30 (Player Team: Germany, Home: Northern Ireland, Away: Germany) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -3
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   1
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 154 in Group D: On date 2016-06-21 00:00:00, Minute 45 (Player Team: Croatia, Home: Croatia, Away: Spain) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -3
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   1
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 150 in Group C: On date 2016-06-21 00:00:00, Minute 54 (Player Team: Poland, Home: Ukraine, Away: Poland) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -3
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   1
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 153 in Group D: On date 2016-06-21 00:00:00, Minute 65 (Player Team: Turkey, Home: Czech Republic, Away: Turkey) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -2
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   2
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 155 in Group D: On date 2016-06-21 00:00:00, Minute 87 (Player Team: Croatia, Home: Croatia, Away: Spain) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -2
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   2
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 159 in Group F: On date 2016-06-22 00:00:00, Minute 18 (Player Team: Iceland, Home: Iceland, Away: Austria) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -2
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   2
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 162 in Group F: On date 2016-06-22 00:00:00, Minute 19 (Player Team: Hungary, Home: Hungary, Away: Portugal) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -2
# 122            Sweden             2                 1                     -1
# 125          Portugal             2                 0                     -1
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   2
# 122                   1
# 125                   1
#
#
# --- Analyzing Goal 165 in Group F: On date 2016-06-22 00:00:00, Minute 42 (Player Team: Portugal, Home: Hungary, Away: Portugal) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -2
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   2
# 122                   1
# 125                   2
#
#
# --- Analyzing Goal 163 in Group F: On date 2016-06-22 00:00:00, Minute 47 (Player Team: Hungary, Home: Hungary, Away: Portugal) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -2
# 122            Sweden             2                 1                     -1
# 125          Portugal             2                 0                     -1
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   2
# 122                   1
# 125                   2
#
#
# --- Analyzing Goal 166 in Group F: On date 2016-06-22 00:00:00, Minute 50 (Player Team: Portugal, Home: Hungary, Away: Portugal) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -2
# 122            Sweden             2                 1                     -1
# 125          Portugal             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   2
# 122                   1
# 125                   3
#
#
# --- Analyzing Goal 164 in Group F: On date 2016-06-22 00:00:00, Minute 55 (Player Team: Hungary, Home: Hungary, Away: Portugal) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -2
# 122            Sweden             2                 1                     -1
# 125          Portugal             2                 0                     -1
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   2
# 122                   1
# 125                   3
#
#
# --- Analyzing Goal 161 in Group F: On date 2016-06-22 00:00:00, Minute 60 (Player Team: Austria, Home: Iceland, Away: Austria) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -2
# 122            Sweden             2                 1                     -1
# 125          Portugal             2                 0                     -1
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   2
# 122                   1
# 125                   3
#
#
# --- Analyzing Goal 167 in Group F: On date 2016-06-22 00:00:00, Minute 62 (Player Team: Portugal, Home: Hungary, Away: Portugal) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                  team  total_points  last_game_points  total_goal_difference  \
# 106           Albania             3                 3                     -2
# 108          Slovakia             4                 1                      0
# 113  Northern Ireland             3                 0                      0
# 118            Turkey             3                 3                     -2
# 122            Sweden             2                 1                     -1
# 124           Iceland             3                 1                      0
#
#      total_goals_scored
# 106                   1
# 108                   3
# 113                   2
# 118                   2
# 122                   1
# 124                   3
#
#
# --- Analyzing Goal 158 in Group E: On date 2016-06-22 00:00:00, Minute 84 (Player Team: Belgium, Home: Sweden, Away: Belgium) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                     team  total_points  last_game_points  \
# 106              Albania             3                 3
# 108             Slovakia             4                 1
# 113     Northern Ireland             3                 0
# 118               Turkey             3                 3
# 121  Republic of Ireland             2                 1
# 124              Iceland             3                 1
#
#      total_goal_difference  total_goals_scored
# 106                     -2                   1
# 108                      0                   3
# 113                      0                   2
# 118                     -2                   2
# 121                     -3                   1
# 124                      0                   3
#
#
# --- Analyzing Goal 157 in Group E: On date 2016-06-22 00:00:00, Minute 85 (Player Team: Republic of Ireland, Home: Italy, Away: Republic of Ireland) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                     team  total_points  last_game_points  \
# 106              Albania             3                 3
# 108             Slovakia             4                 1
# 113     Northern Ireland             3                 0
# 118               Turkey             3                 3
# 121  Republic of Ireland             4                 3
# 124              Iceland             3                 1
#
#      total_goal_difference  total_goals_scored
# 106                     -2                   1
# 108                      0                   3
# 113                      0                   2
# 118                     -2                   2
# 121                     -2                   2
# 124                      0                   3
#
#
# --- Analyzing Goal 160 in Group F: On date 2016-06-22 00:00:00, Minute 94 (Player Team: Iceland, Home: Iceland, Away: Austria) ---
# Top 4 third-placed teams after this goal: ['Albania', 'Slovakia', 'Northern Ireland', 'Turkey']
# Third-placed teams DataFrame after this goal:
#                     team  total_points  last_game_points  \
# 106              Albania             3                 3
# 108             Slovakia             4                 1
# 113     Northern Ireland             3                 0
# 118               Turkey             3                 3
# 121  Republic of Ireland             4                 3
# 125             Portugal             3                 1
#
#      total_goal_difference  total_goals_scored
# 106                     -2                   1
# 108                      0                   3
# 113                      0                   2
# 118                     -2                   2
# 121                     -2                   2
# 125                      0                   4
#
#
# --- Processing Year: 2021 ---
#
# === Initial Standings for Year 2021 Before Processing Any Goals ===
#
#            team   stage  before_last_game_points  before_last_game_goals_scored  before_last_game_goals_conceded  total_goal_difference
#           Italy Group A                        6                              6                                0                      6
#           Wales Group A                        4                              3                                1                      2
#     Switzerland Group A                        1                              1                                4                     -3
#          Turkey Group A                        0                              0                                5                     -5
#         Belgium Group B                        6                              5                                1                      4
#         Finland Group B                        3                              1                                1                      0
#          Russia Group B                        3                              1                                3                     -2
#         Denmark Group B                        0                              1                                3                     -2
#     Netherlands Group C                        6                              5                                2                      3
#         Ukraine Group C                        3                              4                                4                      0
#         Austria Group C                        3                              3                                3                      0
# North Macedonia Group C                        0                              2                                5                     -3
#  Czech Republic Group D                        4                              3                                1                      2
#         England Group D                        4                              1                                0                      1
#         Croatia Group D                        1                              1                                2                     -1
#        Scotland Group D                        1                              0                                2                     -2
#          Sweden Group E                        4                              1                                0                      1
#        Slovakia Group E                        3                              2                                2                      0
#           Spain Group E                        2                              1                                1                      0
#          Poland Group E                        1                              2                                3                     -1
#          France Group F                        4                              2                                1                      1
#        Portugal Group F                        3                              5                                4                      1
#         Germany Group F                        3                              4                                3                      1
#         Hungary Group F                        1                              1                                4                     -3
#
# ===============================================================
#
#
# --- Analyzing Goal 168 in Group A: On date 2021-06-20 00:00:00, Minute 6 (Player Team: Switzerland, Home: Switzerland, Away: Turkey) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'Austria', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -2
# 133       Russia             4                 1                     -2
# 136      Austria             4                 1                      0
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   2
# 133                   1
# 136                   3
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 169 in Group A: On date 2021-06-20 00:00:00, Minute 26 (Player Team: Switzerland, Home: Switzerland, Away: Turkey) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'Austria', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 133       Russia             4                 1                     -2
# 136      Austria             4                 1                      0
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   3
# 133                   1
# 136                   3
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 172 in Group A: On date 2021-06-20 00:00:00, Minute 39 (Player Team: Italy, Home: Italy, Away: Wales) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'Austria', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 133       Russia             4                 1                     -2
# 136      Austria             4                 1                      0
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   3
# 133                   1
# 136                   3
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 171 in Group A: On date 2021-06-20 00:00:00, Minute 62 (Player Team: Turkey, Home: Switzerland, Away: Turkey) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'Austria', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -2
# 133       Russia             4                 1                     -2
# 136      Austria             4                 1                      0
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   3
# 133                   1
# 136                   3
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 170 in Group A: On date 2021-06-20 00:00:00, Minute 68 (Player Team: Switzerland, Home: Switzerland, Away: Turkey) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'Austria', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 133       Russia             4                 1                     -2
# 136      Austria             4                 1                      0
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 133                   1
# 136                   3
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 183 in Group C: On date 2021-06-21 00:00:00, Minute 21 (Player Team: Austria, Home: Ukraine, Away: Austria) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 133       Russia             4                 1                     -2
# 137      Ukraine             3                 0                     -1
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 133                   1
# 137                   4
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 180 in Group C: On date 2021-06-21 00:00:00, Minute 24 (Player Team: Netherlands, Home: North Macedonia, Away: Netherlands) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 133       Russia             4                 1                     -2
# 137      Ukraine             3                 0                     -1
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 133                   1
# 137                   4
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 174 in Group B: On date 2021-06-21 00:00:00, Minute 38 (Player Team: Denmark, Home: Russia, Away: Denmark) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Denmark', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 134      Denmark             3                 3                     -1
# 137      Ukraine             3                 0                     -1
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 134                   2
# 137                   4
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 181 in Group C: On date 2021-06-21 00:00:00, Minute 50 (Player Team: Netherlands, Home: North Macedonia, Away: Netherlands) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Denmark', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 134      Denmark             3                 3                     -1
# 137      Ukraine             3                 0                     -1
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 134                   2
# 137                   4
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 182 in Group C: On date 2021-06-21 00:00:00, Minute 58 (Player Team: Netherlands, Home: North Macedonia, Away: Netherlands) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Denmark', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 134      Denmark             3                 3                     -1
# 137      Ukraine             3                 0                     -1
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 134                   2
# 137                   4
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 175 in Group B: On date 2021-06-21 00:00:00, Minute 59 (Player Team: Denmark, Home: Russia, Away: Denmark) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Denmark', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 134      Denmark             3                 3                      0
# 137      Ukraine             3                 0                     -1
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 134                   3
# 137                   4
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 173 in Group B: On date 2021-06-21 00:00:00, Minute 70 (Player Team: Russia, Home: Russia, Away: Denmark) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Denmark', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 134      Denmark             3                 3                     -1
# 137      Ukraine             3                 0                     -1
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 134                   3
# 137                   4
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 178 in Group B: On date 2021-06-21 00:00:00, Minute 74 (Player Team: Belgium, Home: Finland, Away: Belgium) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Finland', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 132      Finland             3                 0                     -1
# 137      Ukraine             3                 0                     -1
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 132                   1
# 137                   4
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 176 in Group B: On date 2021-06-21 00:00:00, Minute 79 (Player Team: Denmark, Home: Russia, Away: Denmark) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Finland', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 132      Finland             3                 0                     -1
# 137      Ukraine             3                 0                     -1
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 132                   1
# 137                   4
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 179 in Group B: On date 2021-06-21 00:00:00, Minute 81 (Player Team: Belgium, Home: Finland, Away: Belgium) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Finland', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 132      Finland             3                 0                     -2
# 137      Ukraine             3                 0                     -1
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 132                   1
# 137                   4
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 177 in Group B: On date 2021-06-21 00:00:00, Minute 82 (Player Team: Denmark, Home: Russia, Away: Denmark) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Finland', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 132      Finland             3                 0                     -2
# 137      Ukraine             3                 0                     -1
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 132                   1
# 137                   4
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 188 in Group D: On date 2021-06-22 00:00:00, Minute 12 (Player Team: England, Home: Czech Republic, Away: England) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Finland', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 132      Finland             3                 0                     -2
# 137      Ukraine             3                 0                     -1
# 141      Croatia             2                 1                     -1
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 132                   1
# 137                   4
# 141                   1
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 184 in Group D: On date 2021-06-22 00:00:00, Minute 17 (Player Team: Croatia, Home: Croatia, Away: Scotland) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Finland', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 132      Finland             3                 0                     -2
# 137      Ukraine             3                 0                     -1
# 141      Croatia             4                 3                      0
# 145        Spain             3                 1                      0
# 148      Germany             4                 1                      1
#
#      total_goals_scored
# 129                   4
# 132                   1
# 137                   4
# 141                   2
# 145                   1
# 148                   4
#
#
# --- Analyzing Goal 187 in Group D: On date 2021-06-22 00:00:00, Minute 42 (Player Team: Scotland, Home: Croatia, Away: Scotland) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Finland', 'Ukraine', 'Croatia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 129  Switzerland             4                 3                     -1
# 132      Finland             3                 0                     -2
# 137      Ukraine             3                 0                     -1
# ...
# 164     Netherlands             4                 0                      0
# 169         Ukraine             4                 1                     -2
# 173  Czech Republic             2                 1                     -1
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 164                   2
# 169                   2
# 173                   2
#
#
# --- Analyzing Goal 217 in Group D: On date 2024-06-25 00:00:00, Minute 47 (Player Team: Netherlands, Home: Netherlands, Away: Austria) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Austria']
# Third-placed teams DataFrame after this goal:
#                team  total_points  last_game_points  total_goal_difference  \
# 154         Hungary             3                 3                     -3
# 158         Croatia             2                 1                     -3
# 161        Slovenia             3                 1                      0
# 165         Austria             4                 1                      1
# 169         Ukraine             4                 1                     -2
# 173  Czech Republic             2                 1                     -1
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 165                   4
# 169                   2
# 173                   2
#
#
# --- Analyzing Goal 222 in Group D: On date 2024-06-25 00:00:00, Minute 56 (Player Team: France, Home: France, Away: Poland) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Austria']
# Third-placed teams DataFrame after this goal:
#                team  total_points  last_game_points  total_goal_difference  \
# 154         Hungary             3                 3                     -3
# 158         Croatia             2                 1                     -3
# 161        Slovenia             3                 1                      0
# 165         Austria             4                 1                      1
# 169         Ukraine             4                 1                     -2
# 173  Czech Republic             2                 1                     -1
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 165                   4
# 169                   2
# 173                   2
#
#
# --- Analyzing Goal 220 in Group D: On date 2024-06-25 00:00:00, Minute 59 (Player Team: Austria, Home: Netherlands, Away: Austria) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Netherlands']
# Third-placed teams DataFrame after this goal:
#                team  total_points  last_game_points  total_goal_difference  \
# 154         Hungary             3                 3                     -3
# 158         Croatia             2                 1                     -3
# 161        Slovenia             3                 1                      0
# 164     Netherlands             4                 0                      0
# 169         Ukraine             4                 1                     -2
# 173  Czech Republic             2                 1                     -1
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 164                   3
# 169                   2
# 173                   2
#
#
# --- Analyzing Goal 218 in Group D: On date 2024-06-25 00:00:00, Minute 75 (Player Team: Netherlands, Home: Netherlands, Away: Austria) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Austria']
# Third-placed teams DataFrame after this goal:
#                team  total_points  last_game_points  total_goal_difference  \
# 154         Hungary             3                 3                     -3
# 158         Croatia             2                 1                     -3
# 161        Slovenia             3                 1                      0
# 165         Austria             4                 1                      1
# 169         Ukraine             4                 1                     -2
# 173  Czech Republic             2                 1                     -1
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 165                   5
# 169                   2
# 173                   2
#
#
# --- Analyzing Goal 223 in Group D: On date 2024-06-25 00:00:00, Minute 79 (Player Team: Poland, Home: France, Away: Poland) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Austria']
# Third-placed teams DataFrame after this goal:
#                team  total_points  last_game_points  total_goal_difference  \
# 154         Hungary             3                 3                     -3
# 158         Croatia             2                 1                     -3
# 161        Slovenia             3                 1                      0
# 165         Austria             4                 1                      1
# 169         Ukraine             4                 1                     -2
# 173  Czech Republic             2                 1                     -1
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 165                   5
# 169                   2
# 173                   2
#
#
# --- Analyzing Goal 221 in Group D: On date 2024-06-25 00:00:00, Minute 80 (Player Team: Austria, Home: Netherlands, Away: Austria) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Netherlands']
# Third-placed teams DataFrame after this goal:
#                team  total_points  last_game_points  total_goal_difference  \
# 154         Hungary             3                 3                     -3
# 158         Croatia             2                 1                     -3
# 161        Slovenia             3                 1                      0
# 164     Netherlands             4                 0                      0
# 169         Ukraine             4                 1                     -2
# 173  Czech Republic             2                 1                     -1
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 164                   4
# 169                   2
# 173                   2
#
#
# --- Analyzing Goal 226 in Group F: On date 2024-06-26 00:00:00, Minute 2 (Player Team: Georgia, Home: Georgia, Away: Portugal) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Netherlands']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 154      Hungary             3                 3                     -3
# 158      Croatia             2                 1                     -3
# 161     Slovenia             3                 1                      0
# 164  Netherlands             4                 0                      0
# 169      Ukraine             4                 1                     -2
# 174      Georgia             4                 3                     -1
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 164                   4
# 169                   2
# 174                   3
#
#
# --- Analyzing Goal 224 in Group E: On date 2024-06-26 00:00:00, Minute 24 (Player Team: Slovakia, Home: Slovakia, Away: Romania) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Netherlands']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 154      Hungary             3                 3                     -3
# 158      Croatia             2                 1                     -3
# 161     Slovenia             3                 1                      0
# 164  Netherlands             4                 0                      0
# 169      Ukraine             4                 1                     -2
# 174      Georgia             4                 3                     -1
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 164                   4
# 169                   2
# 174                   3
#
#
# --- Analyzing Goal 225 in Group E: On date 2024-06-26 00:00:00, Minute 37 (Player Team: Romania, Home: Slovakia, Away: Romania) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Netherlands']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 154      Hungary             3                 3                     -3
# 158      Croatia             2                 1                     -3
# 161     Slovenia             3                 1                      0
# 164  Netherlands             4                 0                      0
# 169      Ukraine             4                 1                     -2
# 174      Georgia             4                 3                     -1
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 164                   4
# 169                   2
# 174                   3
#
#
# --- Analyzing Goal 229 in Group F: On date 2024-06-26 00:00:00, Minute 51 (Player Team: Turkey, Home: Czech Republic, Away: Turkey) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Netherlands']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 154      Hungary             3                 3                     -3
# 158      Croatia             2                 1                     -3
# 161     Slovenia             3                 1                      0
# 164  Netherlands             4                 0                      0
# 169      Ukraine             4                 1                     -2
# 174      Georgia             4                 3                     -1
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 164                   4
# 169                   2
# 174                   3
#
#
# --- Analyzing Goal 227 in Group F: On date 2024-06-26 00:00:00, Minute 57 (Player Team: Georgia, Home: Georgia, Away: Portugal) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Netherlands']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 154      Hungary             3                 3                     -3
# 158      Croatia             2                 1                     -3
# 161     Slovenia             3                 1                      0
# 164  Netherlands             4                 0                      0
# 169      Ukraine             4                 1                     -2
# 174      Georgia             4                 3                      0
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 164                   4
# 169                   2
# 174                   4
#
#
# --- Analyzing Goal 228 in Group F: On date 2024-06-26 00:00:00, Minute 66 (Player Team: Czech Republic, Home: Czech Republic, Away: Turkey) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Netherlands']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 154      Hungary             3                 3                     -3
# 158      Croatia             2                 1                     -3
# 161     Slovenia             3                 1                      0
# 164  Netherlands             4                 0                      0
# 169      Ukraine             4                 1                     -2
# 172       Turkey             4                 1                     -1
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 164                   4
# 169                   2
# 172                   4
#
#
# --- Analyzing Goal 230 in Group F: On date 2024-06-26 00:00:00, Minute 94 (Player Team: Turkey, Home: Czech Republic, Away: Turkey) ---
# Top 4 third-placed teams after this goal: ['Hungary', 'Croatia', 'Slovenia', 'Netherlands']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 154      Hungary             3                 3                     -3
# 158      Croatia             2                 1                     -3
# 161     Slovenia             3                 1                      0
# 164  Netherlands             4                 0                      0
# 169      Ukraine             4                 1                     -2
# 174      Georgia             4                 3                      0
#
#      total_goals_scored
# 154                   2
# 158                   3
# 161                   2
# 164                   4
# 169                   2
# 174                   4
#                    team  year  third_place_count  top4_third_place_count
# 0               Albania  2016                 22                      22
# 1                 Wales  2016                  1                       1
# 2      Northern Ireland  2016                 22                      22
# 3        Czech Republic  2016                  5                       5
# 4                Sweden  2016                 19                       0
# 5              Portugal  2016                 19                       0
# 6              Slovakia  2016                 21                      21
# 7                Turkey  2016                 17                      17
# 8               Iceland  2016                  3                       0
# 9   Republic of Ireland  2016                  3                       0
# 10          Switzerland  2021                 38                      38
# 11               Russia  2021                  7                       7
# 12              Austria  2021                  5                       5
# 13              Croatia  2021                 20                      20
# 14                Spain  2021                 23                       0
# 15              Germany  2021                 22                       0
# 16              Ukraine  2021                 33                      33
# 17              Denmark  2021                  5                       5
# 18              Finland  2021                 26                      26
# 19       Czech Republic  2021                 18                      18
# 20              Hungary  2021                 12                       0
# 21             Slovakia  2021                 15                       0
# 22               France  2021                  4                       0
# 23             Scotland  2024                  6                       6
# 24              Albania  2024                  7                       7
# 25              Denmark  2024                  2                       2
# 26              Austria  2024                 14                      14
# 27              Ukraine  2024                 24                       0
# 28       Czech Republic  2024                 17                       0
# 29             Slovenia  2024                 22                      22
# 30              Hungary  2024                 18                      18
# 31              Croatia  2024                 16                      16
# 32                Italy  2024                  1                       1
# 33          Netherlands  2024                 10                      10
# 34              Georgia  2024                  6                       0
# 35               Turkey  2024                  1                       0

# %%
# Count the number of observations where the year is 2016
count_2016 = goals_last_day_sorted[goals_last_day_sorted['year'] == 2016].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 2016: {count_2016}")

# Count the number of observations where the year is 2021
count_2020 = goals_last_day_sorted[goals_last_day_sorted['year'] == 2021].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 2020: {count_2020}")

# Count the number of observations where the year is 2024
count_2024 = goals_last_day_sorted[goals_last_day_sorted['year'] == 2024].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 2024: {count_2024}")
# Out:
# Number of observations in goals_last_day_sorted for the year 2016: 22
# Number of observations in goals_last_day_sorted for the year 2020: 38
# Number of observations in goals_last_day_sorted for the year 2024: 24
