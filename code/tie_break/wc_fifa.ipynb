# %% [markdown]
# # Libraries

# %%
import pandas as pd
from getpass import getuser
from collections import defaultdict

# %% [markdown]
# # Load and inspect dataset

# %%
# Get the current user's name
user = getuser()

# Path to the dataset
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\fifa.csv'

# Read the dataset with a different encoding
df = pd.read_csv(data_path, encoding='ISO-8859-1')

# %% [markdown]
# # Extract relevant columns

# %%
# First, let's extract the year from the 'tournament_id' column and create a new column 'year'
df['year'] = df['tournament_id'].str.extract(r'WC-(\d{4})').astype(int)

# Now, filter the data for tournaments after 1986
filtered_df = df[df['year'] > 1984]

# Extract relevant columns for goal events and match results
goals_df = filtered_df[['year', 'group_name','match_name', 'match_id', 'player_team_name','match_date', 'minute_regulation', 'minute_stoppage', 
               'team_id', 'own_goal']]

# Remove all observations where group_name is "not applicable"
goals_df = goals_df[goals_df['group_name'] != 'not applicable']

# Convert 'match_date' to datetime format
goals_df['match_date'] = pd.to_datetime(goals_df['match_date'], format='%m/%d/%Y')

# Sort the dataset by 'match_date' in ascending order (oldest first) and 'minute_regulation'
goals_df = goals_df.sort_values(by=['match_date', 'minute_regulation'], ascending=[True, True])

# Display the first few rows to confirm the sorting
goals_df.head()
# Out:
#       year group_name              match_name   match_id player_team_name  \
# 1196  1986    Group A        Bulgaria v Italy  M-1986-01            Italy
# 1197  1986    Group A        Bulgaria v Italy  M-1986-01         Bulgaria
# 1198  1986    Group D          Spain v Brazil  M-1986-02           Brazil
# 1199  1986    Group C         Canada v France  M-1986-03           France
# 1204  1986    Group C  Soviet Union v Hungary  M-1986-05     Soviet Union
#
#      match_date  minute_regulation  minute_stoppage team_id  own_goal
# 1196 1986-05-31                 44                0    T-39         0
# 1197 1986-05-31                 85                0    T-10         0
# 1198 1986-06-01                 62                0    T-09         0
# 1199 1986-06-01                 79                0    T-28         0
# 1204 1986-06-02                  2                0    T-70         0

# %% [markdown]
# # Recreate Leauge Table after first two matchdays

# %% [markdown]
# ### Filter out the matches from the last match day in the goals_df DataFrame.

# %%
# Step 1: Find the last match date for each tournament and group
last_dates = goals_df.groupby(['year', 'group_name'])['match_date'].max().reset_index()

# Step 2: Create the dataset with all games excluding the last match day (goals_before_last_day)
goals_before_last_day = goals_df.merge(last_dates, on=['year', 'group_name', 'match_date'], how='outer', indicator=True)
goals_before_last_day = goals_before_last_day[goals_before_last_day['_merge'] == 'left_only'].drop(columns=['_merge'])

# Step 3: Create the dataset with only the last match day games (goals_last_day)
goals_last_day = goals_df.merge(last_dates, on=['year', 'group_name', 'match_date'])

# Step 4: Split match_name into home and away teams and remove match_name column for both datasets

# For goals_before_last_day
goals_before_last_day[['home', 'away']] = goals_before_last_day['match_name'].str.split(' v ', expand=True)
goals_before_last_day = goals_before_last_day.drop(columns=['match_name'])

# For goals_last_day
goals_last_day[['home', 'away']] = goals_last_day['match_name'].str.split(' v ', expand=True)
goals_last_day = goals_last_day.drop(columns=['match_name'])

# Sort the DataFrame by 'match_date,'minute_regulation' and 'minute_stoppage'
goals_last_day_sorted = goals_last_day.sort_values(by=['match_date', 'minute_regulation', 'minute_stoppage'], ascending=[True, True, True])

# %% [markdown]
# ## create df  of aggregate data for each match

# %%
# Initialize an empty list to store the results
results = []

# Iterate over each match in the dataset
for match_id, group in goals_before_last_day.groupby(['year', 'group_name', 'match_id', 'home', 'away']):
    # Initialize goals_home and goals_away for each match
    goals_home = 0
    goals_away = 0
    
    # Loop through each row in the group
    for _, row in group.iterrows():
        # Check if the team is the home team and no own goal
        if row['home'] == row['player_team_name'] and row['own_goal'] == 0:
            goals_home += 1
        # If the team is the away team and no own goal, increment goals_away
        elif row['away'] == row['player_team_name'] and row['own_goal'] == 0:
            goals_away += 1

    # Append the results to the list, keeping home and away columns
    results.append({
        'year': match_id[0],
        'group_name': match_id[1],
        'match_id': match_id[2],
        'home': match_id[3],
        'away': match_id[4],
        'goals_home': goals_home,
        'goals_away': goals_away
    })

# Convert the list into a DataFrame
agg_goals_before_last_day = pd.DataFrame(results)

# Add a new column 'won' based on the comparison of goals_home and goals_away
agg_goals_before_last_day['won'] = agg_goals_before_last_day.apply(
    lambda row: 1 if row['goals_home'] > row['goals_away'] else (-1 if row['goals_home'] < row['goals_away'] else 0), 
    axis=1
)

# Display the updated DataFrame (use print if outside of Jupyter)
display(agg_goals_before_last_day)
# Out:
#      year group_name   match_id         home         away  goals_home  \
# 0    1986    Group A  M-1986-01     Bulgaria        Italy           1
# 1    1986    Group A  M-1986-04    Argentina  South Korea           3
# 2    1986    Group A  M-1986-13        Italy    Argentina           1
# 3    1986    Group A  M-1986-15  South Korea     Bulgaria           1
# 4    1986    Group B  M-1986-07      Belgium       Mexico           1
# ..    ...        ...        ...          ...          ...         ...
# 266  2022    Group G  M-2022-29     Cameroon       Serbia           3
# 267  2022    Group G  M-2022-31       Brazil  Switzerland           1
# 268  2022    Group H  M-2022-15     Portugal        Ghana           3
# 269  2022    Group H  M-2022-30  South Korea        Ghana           2
# 270  2022    Group H  M-2022-32     Portugal      Uruguay           2
#
#      goals_away  won
# 0             1    0
# 1             1    1
# 2             1    0
# 3             1    0
# 4             2   -1
# ..          ...  ...
# 266           3    0
# 267           0    1
# 268           2    1
# 269           3   -1
# 270           0    1
#
# [271 rows x 8 columns]

# %% [markdown]
# ## aggregate data for home and away games

# %%
home_games = agg_goals_before_last_day.groupby(['year', 'group_name', 'home']).agg(
    goals_scored=('goals_home', 'sum'),     # Sum of goals scored by the home team
    goals_conceded=('goals_away', 'sum'),   # Sum of goals conceded by the home team (i.e., goals scored by the away team)
    points_home=('won', lambda x: sum(3 if result == 1 and year > 1994 else (2 if result == 1 else (1 if result == 0 else 0)) for result, year in zip(x, agg_goals_before_last_day['year']))),
    match_count_home=('match_id', 'count')  # Count the number of matches at home
).reset_index()

away_games = agg_goals_before_last_day.groupby(['year', 'group_name', 'away']).agg(
    goals_scored=('goals_away', 'sum'),     # Sum of goals scored by the away team
    goals_conceded=('goals_home', 'sum'),   # Sum of goals conceded by the away team (i.e., goals scored by the home team)
    points_away=('won', lambda x: sum(3 if result == -1 and year > 1994 else (2 if result == -1 else (1 if result == 0 else 0)) for result, year in zip(x, agg_goals_before_last_day['year']))),
    match_count_away=('match_id', 'count')  # Count the number of matches away
).reset_index()

# %% [markdown]
# ## aggregate data after first two matches

# %%
# Step 1: Merge home_games and away_games on year, group_name, and home with away
all_games_before_last = pd.merge(
    home_games,
    away_games,
    left_on=['year', 'group_name', 'home'],
    right_on=['year', 'group_name', 'away'],
    how='outer',
    suffixes=('_home', '_away')
)

# Step 2: For teams that only appear in home_games, assign home to team and copy relevant columns
all_games_before_last['team'] = all_games_before_last['home'].fillna(all_games_before_last['away'])

# Step 3: For goals_scored, goals_conceded, and points, handle missing values
all_games_before_last['goals_scored'] = all_games_before_last['goals_scored_home'].fillna(0) + all_games_before_last['goals_scored_away'].fillna(0)
all_games_before_last['goals_conceded'] = all_games_before_last['goals_conceded_home'].fillna(0) + all_games_before_last['goals_conceded_away'].fillna(0)
all_games_before_last['points'] = all_games_before_last['points_home'].fillna(0) + all_games_before_last['points_away'].fillna(0)

# Step 4: Add goals_difference column
all_games_before_last['goals_difference'] = all_games_before_last['goals_scored'] - all_games_before_last['goals_conceded']

# Step 5: Sum match_count_home and match_count_away to get total match count for each team
all_games_before_last['total_matches'] = all_games_before_last['match_count_home'].fillna(0) + all_games_before_last['match_count_away'].fillna(0)

# Step 6: Adjust points if total_matches is 1 (indicating a likely 0-0 draw)
# If total_matches == 1, assume the second match ended 0-0, so add 1 point
all_games_before_last.loc[all_games_before_last['total_matches'] == 1, 'points'] += 1

# Step 7: Drop unnecessary columns used in the merge process
all_games_before_last = all_games_before_last[['year', 'group_name', 'team', 'goals_scored', 'goals_conceded', 'points', 'goals_difference', 'total_matches']]

# Step 8: Initial sort by points, goals_difference, and goals_scored within each tournament and group
all_games_before_last = all_games_before_last.sort_values(
    by=['year', 'group_name', 'points', 'goals_difference', 'goals_scored'],
    ascending=[True, True, False, False, False]
).reset_index(drop=True)

# Step 9: Initialize a new column for tie-break results, which will store either the tie-break result or 'no need'
all_games_before_last['tiebreaker'] = 'no need'

# Step 10: Identify rows with tied points, goals_difference, and goals_scored and apply the tie-breaker
def check_tiebreaker(row1, row2, agg_data):
    """
    Check the tie-breaker based on the head-to-head match result from agg_goals_before_last_day.
    Return the team that won (if any) or 'tie'.
    """
    # Look for the head-to-head match between the two teams in agg_goals_before_last_day
    match = agg_data[((agg_data['home'] == row1['team']) & (agg_data['away'] == row2['team'])) |
                     ((agg_data['home'] == row2['team']) & (agg_data['away'] == row1['team']))]
    
    if not match.empty:
        if match.iloc[0]['won'] == 1:
            return row1['team']  # Home team won
        elif match.iloc[0]['won'] == -1:
            return row2['team']  # Away team won
        else:
            return 'tie'  # It's a draw
    else:
        return 'no result'  # No match found

# Step 11: Loop through the sorted dataframe and apply the tie-breaker if needed
for i in range(len(all_games_before_last) - 1):
    row1 = all_games_before_last.iloc[i]
    row2 = all_games_before_last.iloc[i + 1]
    
    # Check if the two rows have identical values for points, goal difference, and goals scored
    if (row1['points'] == row2['points'] and
        row1['goals_difference'] == row2['goals_difference'] and
        row1['goals_scored'] == row2['goals_scored']):
        
        # Apply the tie-breaker by checking the head-to-head match result
        tiebreak_result = check_tiebreaker(row1, row2, agg_goals_before_last_day)
        
        # Store the tie-breaker result for both teams involved
        all_games_before_last.at[i, 'tiebreaker'] = tiebreak_result
        all_games_before_last.at[i + 1, 'tiebreaker'] = tiebreak_result

# Step 12: Add group standing by ranking teams within each group based on points, goal difference, and goals scored
all_games_before_last['standing'] = all_games_before_last.groupby(['year', 'group_name']).apply(
    lambda x: x.sort_values(by=['points', 'goals_difference', 'goals_scored'], ascending=[False, False, False])
).reset_index(drop=True).groupby(['year', 'group_name']).cumcount() + 1

# Convert goals_scored, goals_conceded, points, goals_difference, and total_matches to integers
all_games_before_last[['goals_scored', 'goals_conceded', 'points', 'goals_difference', 'total_matches']] = all_games_before_last[
    ['goals_scored', 'goals_conceded', 'points', 'goals_difference', 'total_matches']].astype(int)
# Out:
# C:\Users\aldi\AppData\Local\Temp\ipykernel_23332\3335180476.py:79: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   all_games_before_last['standing'] = all_games_before_last.groupby(['year', 'group_name']).apply(

# %%
display(all_games_before_last)
# Out:
#      year group_name         team  goals_scored  goals_conceded  points  \
# 0    1986    Group A    Argentina             4               2       3
# 1    1986    Group A     Bulgaria             2               2       2
# 2    1986    Group A        Italy             2               2       2
# 3    1986    Group A  South Korea             2               4       1
# 4    1986    Group B       Mexico             3               2       3
# ..    ...        ...          ...           ...             ...     ...
# 289  2022    Group G       Serbia             3               5       1
# 290  2022    Group H     Portugal             5               2       4
# 291  2022    Group H        Ghana             5               5       2
# 292  2022    Group H  South Korea             2               3       1
# 293  2022    Group H      Uruguay             0               2       1
#
#      goals_difference  total_matches tiebreaker  standing
# 0                   2              2    no need         1
# 1                   0              2        tie         2
# 2                   0              2        tie         3
# 3                  -2              2    no need         4
# 4                   1              2    no need         1
# ..                ...            ...        ...       ...
# 289                -2              2    no need         4
# 290                 3              2    no need         1
# 291                 0              2    no need         2
# 292                -1              1    no need         3
# 293                -2              1    no need         4
#
# [294 rows x 10 columns]

# %% [markdown]
# # Recreate league table after last match day

# %%
def process_goals_for_group_specific(year, group_name, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day):
    # Step 1: Filter the data for the specific year and group_name
    group_goals_tracking = all_games_before_last[
        (all_games_before_last['year'] == year) & 
        (all_games_before_last['group_name'] == group_name)
    ].copy()

    group_goals_last_day = goals_last_day_sorted[
        (goals_last_day_sorted['year'] == year) & 
        (goals_last_day_sorted['group_name'] == group_name)
    ]

    # Step 2: Initialize columns for tracking team performance
    group_goals_tracking['before_last_game_goals_scored'] = group_goals_tracking['goals_scored']
    group_goals_tracking['before_last_game_goals_conceded'] = group_goals_tracking['goals_conceded']
    group_goals_tracking['before_last_game_standing'] = group_goals_tracking['standing']
    group_goals_tracking['before_last_game_points'] = group_goals_tracking['points']

    group_goals_tracking['last_game_goals_scored'] = 0
    group_goals_tracking['last_game_goals_conceded'] = 0
    group_goals_tracking['total_goals_scored'] = group_goals_tracking['before_last_game_goals_scored']
    group_goals_tracking['total_goals_conceded'] = group_goals_tracking['before_last_game_goals_conceded']
    group_goals_tracking['total_goal_difference'] = group_goals_tracking['total_goals_scored'] - group_goals_tracking['total_goals_conceded']
    group_goals_tracking['last_game_points'] = 0
    group_goals_tracking['total_points'] = group_goals_tracking['before_last_game_points']
    group_goals_tracking['last_game_standing'] = 0
    group_goals_tracking['1st'] = 0
    group_goals_tracking['2nd'] = 0
    group_goals_tracking['3rd'] = 0
    group_goals_tracking['4th'] = 0
    group_goals_tracking['changes'] = 0  # Initialize this but we will redefine it later as the sum of 1st, 2nd, 3rd, 4th
    group_goals_tracking['tied'] = False  # Initialize a flag to track tied teams
    group_goals_tracking['tied_won'] = 0  # Initialize to track if the team won a tie-breaker match

    # Step 3: Sort group_goals_last_day by minute_regulation in ascending order
    group_goals_last_day = group_goals_last_day.sort_values(by=['minute_regulation', 'minute_stoppage'], ascending=[True, True])

    # Print the year, group_name, and standings before starting the loop for last match goals
    print(f"\n=== Initial Standings for Year {year}, Group {group_name} Before Last Match Goals ===\n")
    display_columns = ['team', 'total_points', 'total_goals_scored', 'total_goals_conceded', 
                       'total_goal_difference', 'before_last_game_points', 'before_last_game_standing']
    print(group_goals_tracking[display_columns].to_string(index=False))
    print("\n====================================================\n")


    # Step 4: Iterate through the sorted and filtered last match goals and update the goals_tracking table
    previous_standings = group_goals_tracking['last_game_standing'].copy()
    first_iteration = True  # Variable to track the first iteration

    for _, goal in group_goals_last_day.iterrows():
        home_team = goal['home']
        away_team = goal['away']
        player_team = goal['player_team_name']
        own_goal = goal['own_goal']

        # Print goal information for each goal
        print(f"Analyzing {goal['group_name']}, year {goal['year']}, goal: {goal['minute_regulation']} minute, {goal['minute_stoppage']} extra time, Player team: {player_team}, Home: {home_team}, Away: {away_team}, Own goal: {own_goal}")

        # Update the goals based on who scored the goal (own goal or normal goal)
        if own_goal == 0:  # Normal goal
            if player_team == home_team:
                # Home team scored, update home scored and away conceded
                group_goals_tracking.loc[group_goals_tracking['team'] == home_team, 'last_game_goals_scored'] += 1
                group_goals_tracking.loc[group_goals_tracking['team'] == away_team, 'last_game_goals_conceded'] += 1
            elif player_team == away_team:
                # Away team scored, update away scored and home conceded
                group_goals_tracking.loc[group_goals_tracking['team'] == away_team, 'last_game_goals_scored'] += 1
                group_goals_tracking.loc[group_goals_tracking['team'] == home_team, 'last_game_goals_conceded'] += 1
        elif own_goal == 1:  # Own goal
            if player_team == home_team:
                # Own goal by home team, away team scores
                group_goals_tracking.loc[group_goals_tracking['team'] == away_team, 'last_game_goals_scored'] += 1
                group_goals_tracking.loc[group_goals_tracking['team'] == home_team, 'last_game_goals_conceded'] += 1
            elif player_team == away_team:
                # Own goal by away team, home team scores
                group_goals_tracking.loc[group_goals_tracking['team'] == home_team, 'last_game_goals_scored'] += 1
                group_goals_tracking.loc[group_goals_tracking['team'] == away_team, 'last_game_goals_conceded'] += 1

        # Step 5: Update total_goals_scored, total_goals_conceded, and total_goal_difference
        group_goals_tracking['total_goals_scored'] = group_goals_tracking['before_last_game_goals_scored'] + group_goals_tracking['last_game_goals_scored']
        group_goals_tracking['total_goals_conceded'] = group_goals_tracking['before_last_game_goals_conceded'] + group_goals_tracking['last_game_goals_conceded']
        group_goals_tracking['total_goal_difference'] = group_goals_tracking['total_goals_scored'] - group_goals_tracking['total_goals_conceded']

        # Step 6: Assign points for the last game dynamically after each goal
        for i, row in group_goals_tracking.iterrows():
            if row['last_game_goals_scored'] > row['last_game_goals_conceded']:
                # Check the year and assign 3 or 2 points based on the year
                if year > 1994:
                    group_goals_tracking.loc[i, 'last_game_points'] = 3  # Win after 1994
                else:
                    group_goals_tracking.loc[i, 'last_game_points'] = 2  # Win before or during 1994
            elif row['last_game_goals_scored'] == row['last_game_goals_conceded']:
                group_goals_tracking.loc[i, 'last_game_points'] = 1  # Draw
            else:
                group_goals_tracking.loc[i, 'last_game_points'] = 0  # Loss


        # Step 7: Update total points
        group_goals_tracking['total_points'] = group_goals_tracking['before_last_game_points'] + group_goals_tracking['last_game_points']

        # Step 8: Mark teams that are tied
        group_goals_tracking['tied'] = group_goals_tracking.duplicated(subset=['total_points', 'total_goal_difference', 'total_goals_scored'], keep=False)

        # Reset `tied_won` to 0 for all teams
        group_goals_tracking['tied_won'] = 0

        # Step 8b: Calculate tied_won only for tied teams
        tied_teams = group_goals_tracking[group_goals_tracking['tied']]

        if not tied_teams.empty:
            # Iterate over tied teams to resolve standings using head-to-head results
            for index, row in tied_teams.iterrows():
                team1 = row['team']
                team1_index = index

                # Look for other teams tied with this team
                for other_index, other_row in tied_teams[tied_teams.index != index].iterrows():
                    team2 = other_row['team']
                    team2_index = other_index

                    # Check if these two teams played against each other in agg_goals_before_last_day
                    match = agg_goals_before_last_day[
                        ((agg_goals_before_last_day['home'] == team1) & (agg_goals_before_last_day['away'] == team2)) |
                        ((agg_goals_before_last_day['home'] == team2) & (agg_goals_before_last_day['away'] == team1))
                    ]

                    if not match.empty:
                        match_result = match.iloc[0]['won']  # Assume the 'won' column holds 1 for home win, -1 for away win, 0 for draw

                        # Resolve the tie using the match result
                        if match_result == 1:
                            # Home team won
                            if match.iloc[0]['home'] == team1:
                                group_goals_tracking.loc[group_goals_tracking['team'] == team1, 'tied_won'] = 1
                            else:
                                group_goals_tracking.loc[group_goals_tracking['team'] == team2, 'tied_won'] = 1
                        elif match_result == -1:
                            # Away team won
                            if match.iloc[0]['away'] == team1:
                                group_goals_tracking.loc[group_goals_tracking['team'] == team1, 'tied_won'] = 1
                            else:
                                group_goals_tracking.loc[group_goals_tracking['team'] == team2, 'tied_won'] = 1
                        elif match_result == 0:
                            # Draw, both teams get the same standing
                            group_goals_tracking.loc[group_goals_tracking['team'] == team1, 'tied_won'] = 0
                            group_goals_tracking.loc[group_goals_tracking['team'] == team2, 'tied_won'] = 0

        # Step 8c: Sort teams by total points, goal difference, goals scored, and tied_won
        group_goals_tracking = group_goals_tracking.sort_values(by=['total_points', 'total_goal_difference', 'total_goals_scored', 'tied_won'],
                                                                ascending=[False, False, False, False])

        # Step 9: Assign standings based on the sorting and tie resolution
        group_goals_tracking['last_game_standing'] = group_goals_tracking.reset_index(drop=True).index + 1

        # Step 10: Track changes and update standing positions after each goal is processed
        for i, row in group_goals_tracking.iterrows():
            team = row['team']

            if first_iteration:
                # Skip the update if the standing did not change
                if row['before_last_game_standing'] == row['last_game_standing']:
                    continue  # Skip updating the counters
                else:
                    # Update the position counters since standing has changed
                    if row['last_game_standing'] == 1:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '1st'] += 1
                    elif row['last_game_standing'] == 2:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '2nd'] += 1
                    elif row['last_game_standing'] == 3:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '3rd'] += 1
                    elif row['last_game_standing'] == 4:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '4th'] += 1

                # Disable first iteration flag after the first goal
                first_iteration = False
            else:
                # Track the standing position counters only if the position differs from the previous state
                if row['last_game_standing'] != previous_standings[i]:  
                    if row['last_game_standing'] == 1:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '1st'] += 1
                    elif row['last_game_standing'] == 2:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '2nd'] += 1
                    elif row['last_game_standing'] == 3:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '3rd'] += 1
                    elif row['last_game_standing'] == 4:
                        group_goals_tracking.loc[group_goals_tracking['team'] == team, '4th'] += 1

        # Update previous standings after each goal
        previous_standings = group_goals_tracking['last_game_standing'].copy()

        # Step 11: Calculate changes as the sum of 1st, 2nd, 3rd, and 4th
        group_goals_tracking['changes'] = group_goals_tracking[['1st', '2nd', '3rd', '4th']].sum(axis=1)

        # Step 12: Print the updated group_goals_tracking after processing each goal
        print("\n=== Updated Standings After This Goal ===\n")
        display_columns = ['team', 'total_points', 'total_goals_scored', 'total_goals_conceded', 
                           'total_goal_difference', 'last_game_points', 'last_game_standing', 
                           'changes', '1st', '2nd', '3rd', '4th', 'tied', 'tied_won']
        print(group_goals_tracking[display_columns].to_string(index=False))
        print("\n========================================\n")

    # Step 13: Return the final DataFrame
    return group_goals_tracking

# %%
# Initialize an empty list to store the results for each pair
all_results = []

# Get unique pairs of year and group_name
unique_pairs = all_games_before_last[['year', 'group_name']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    group_name = row['group_name']
    
    # Apply the function to the current pair
    result = process_goals_for_group_specific(year, group_name, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_results.append(result)

# Concatenate all the results into a single DataFrame
changes_df_wc = pd.concat(all_results)


# Keep only the specified columns
changes_df_wc = changes_df_wc[['year', 'group_name', 'team', '1st', '2nd', '3rd', '4th', 'changes']]

# Display the final DataFrame
display(changes_df_wc)
# Out:
# === Initial Standings for Year 1986, Group Group A Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#   Argentina             3                   4                     2                      2                        3                          1
#    Bulgaria             2                   2                     2                      0                        2                          2
#       Italy             2                   2                     2                      0                        2                          3
# South Korea             1                   2                     4                     -2                        1                          4
#
# ====================================================
#
# Analyzing Group A, year 1986, goal: 4 minute, 0 extra time, Player team: Argentina, Home: Argentina, Away: Bulgaria, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   5                     2                      3                 2                   1        0    0    0    0    0 False         0
#       Italy             3                   2                     2                      0                 1                   2        1    0    1    0    0 False         0
#    Bulgaria             2                   2                     3                     -1                 0                   3        1    0    0    1    0 False         0
# South Korea             2                   2                     4                     -2                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1986, goal: 17 minute, 0 extra time, Player team: Italy, Home: South Korea, Away: Italy, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   5                     2                      3                 2                   1        0    0    0    0    0 False         0
#       Italy             4                   3                     2                      1                 2                   2        1    0    1    0    0 False         0
#    Bulgaria             2                   2                     3                     -1                 0                   3        1    0    0    1    0 False         0
# South Korea             1                   2                     5                     -3                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1986, goal: 62 minute, 0 extra time, Player team: South Korea, Home: South Korea, Away: Italy, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   5                     2                      3                 2                   1        0    0    0    0    0 False         0
#       Italy             3                   3                     3                      0                 1                   2        1    0    1    0    0 False         0
#    Bulgaria             2                   2                     3                     -1                 0                   3        1    0    0    1    0 False         0
# South Korea             2                   3                     5                     -2                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1986, goal: 73 minute, 0 extra time, Player team: Italy, Home: South Korea, Away: Italy, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   5                     2                      3                 2                   1        0    0    0    0    0 False         0
#       Italy             4                   4                     3                      1                 2                   2        1    0    1    0    0 False         0
#    Bulgaria             2                   2                     3                     -1                 0                   3        1    0    0    1    0 False         0
# South Korea             1                   3                     6                     -3                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1986, goal: 77 minute, 0 extra time, Player team: Argentina, Home: Argentina, Away: Bulgaria, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   6                     2                      4                 2                   1        0    0    0    0    0 False         0
#       Italy             4                   4                     3                      1                 2                   2        1    0    1    0    0 False         0
#    Bulgaria             2                   2                     4                     -2                 0                   3        1    0    0    1    0 False         0
# South Korea             1                   3                     6                     -3                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1986, goal: 82 minute, 0 extra time, Player team: South Korea, Home: South Korea, Away: Italy, Own goal: 1
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   6                     2                      4                 2                   1        0    0    0    0    0 False         0
#       Italy             4                   5                     3                      2                 2                   2        1    0    1    0    0 False         0
#    Bulgaria             2                   2                     4                     -2                 0                   3        1    0    0    1    0 False         0
# South Korea             1                   3                     7                     -4                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1986, goal: 83 minute, 0 extra time, Player team: South Korea, Home: South Korea, Away: Italy, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   6                     2                      4                 2                   1        0    0    0    0    0 False         0
#       Italy             4                   5                     4                      1                 2                   2        1    0    1    0    0 False         0
#    Bulgaria             2                   2                     4                     -2                 0                   3        1    0    0    1    0 False         0
# South Korea             1                   4                     7                     -3                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group Group B Before Last Match Goals ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#   Mexico             3                   3                     2                      1                        3                          1
# Paraguay             3                   2                     1                      1                        3                          2
#  Belgium             2                   3                     3                      0                        2                          3
#     Iraq             0                   1                     3                     -2                        0                          4
#
# ====================================================
#
# Analyzing Group B, year 1986, goal: 30 minute, 0 extra time, Player team: Belgium, Home: Paraguay, Away: Belgium, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Belgium             4                   4                     3                      1                 2                   1        1    1    0    0    0 False         0
#   Mexico             4                   3                     2                      1                 1                   2        1    0    1    0    0 False         0
# Paraguay             3                   2                     2                      0                 0                   3        1    0    0    1    0 False         0
#     Iraq             1                   1                     3                     -2                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 1986, goal: 50 minute, 0 extra time, Player team: Paraguay, Home: Paraguay, Away: Belgium, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Mexico             4                   3                     2                      1                 1                   1        2    1    1    0    0  True         0
# Paraguay             4                   3                     2                      1                 1                   2        2    0    1    1    0  True         0
#  Belgium             3                   4                     4                      0                 1                   3        2    1    0    1    0 False         0
#     Iraq             1                   1                     3                     -2                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 1986, goal: 54 minute, 0 extra time, Player team: Mexico, Home: Iraq, Away: Mexico, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Mexico             5                   4                     2                      2                 2                   1        2    1    1    0    0 False         0
# Paraguay             4                   3                     2                      1                 1                   2        2    0    1    1    0 False         0
#  Belgium             3                   4                     4                      0                 1                   3        2    1    0    1    0 False         0
#     Iraq             0                   1                     4                     -3                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 1986, goal: 59 minute, 0 extra time, Player team: Belgium, Home: Paraguay, Away: Belgium, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Mexico             5                   4                     2                      2                 2                   1        2    1    1    0    0 False         0
#  Belgium             4                   5                     4                      1                 2                   2        3    1    1    1    0 False         0
# Paraguay             3                   3                     3                      0                 0                   3        3    0    1    2    0 False         0
#     Iraq             0                   1                     4                     -3                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 1986, goal: 76 minute, 0 extra time, Player team: Paraguay, Home: Paraguay, Away: Belgium, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Mexico             5                   4                     2                      2                 2                   1        2    1    1    0    0 False         0
# Paraguay             4                   4                     3                      1                 1                   2        4    0    2    2    0 False         0
#  Belgium             3                   5                     5                      0                 1                   3        4    1    1    2    0 False         0
#     Iraq             0                   1                     4                     -3                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group Group C Before Last Match Goals ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# Soviet Union             3                   6                     1                      5                        3                          1
#       France             3                   2                     1                      1                        3                          2
#      Hungary             2                   2                     5                     -3                        2                          3
#       Canada             0                   0                     3                     -3                        0                          4
#
# ====================================================
#
# Analyzing Group C, year 1986, goal: 29 minute, 0 extra time, Player team: France, Home: Hungary, Away: France, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#       France             5                   3                     1                      2                 2                   1        1    1    0    0    0 False         0
# Soviet Union             4                   6                     1                      5                 1                   2        1    0    1    0    0 False         0
#      Hungary             2                   2                     6                     -4                 0                   3        1    0    0    1    0 False         0
#       Canada             1                   0                     3                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group C, year 1986, goal: 58 minute, 0 extra time, Player team: Soviet Union, Home: Soviet Union, Away: Canada, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Soviet Union             5                   7                     1                      6                 2                   1        2    1    1    0    0 False         0
#       France             5                   3                     1                      2                 2                   2        2    1    1    0    0 False         0
#      Hungary             2                   2                     6                     -4                 0                   3        1    0    0    1    0 False         0
#       Canada             0                   0                     4                     -4                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group C, year 1986, goal: 62 minute, 0 extra time, Player team: France, Home: Hungary, Away: France, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Soviet Union             5                   7                     1                      6                 2                   1        2    1    1    0    0 False         0
#       France             5                   4                     1                      3                 2                   2        2    1    1    0    0 False         0
#      Hungary             2                   2                     7                     -5                 0                   3        1    0    0    1    0 False         0
#       Canada             0                   0                     4                     -4                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group C, year 1986, goal: 74 minute, 0 extra time, Player team: Soviet Union, Home: Soviet Union, Away: Canada, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Soviet Union             5                   8                     1                      7                 2                   1        2    1    1    0    0 False         0
#       France             5                   4                     1                      3                 2                   2        2    1    1    0    0 False         0
#      Hungary             2                   2                     7                     -5                 0                   3        1    0    0    1    0 False         0
#       Canada             0                   0                     5                     -5                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group C, year 1986, goal: 84 minute, 0 extra time, Player team: France, Home: Hungary, Away: France, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Soviet Union             5                   8                     1                      7                 2                   1        2    1    1    0    0 False         0
#       France             5                   5                     1                      4                 2                   2        2    1    1    0    0 False         0
#      Hungary             2                   2                     8                     -6                 0                   3        1    0    0    1    0 False         0
#       Canada             0                   0                     5                     -5                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group Group D Before Last Match Goals ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#           Brazil             4                   2                     0                      2                        4                          1
#            Spain             2                   2                     2                      0                        2                          2
# Northern Ireland             1                   2                     3                     -1                        1                          3
#          Algeria             1                   1                     2                     -1                        1                          4
#
# ====================================================
#
# Analyzing Group D, year 1986, goal: 15 minute, 0 extra time, Player team: Spain, Home: Algeria, Away: Spain, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#           Brazil             5                   2                     0                      2                 1                   1        0    0    0    0    0 False         0
#            Spain             4                   3                     2                      1                 2                   2        0    0    0    0    0 False         0
# Northern Ireland             2                   2                     3                     -1                 1                   3        0    0    0    0    0 False         0
#          Algeria             1                   1                     3                     -2                 0                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing Group D, year 1986, goal: 15 minute, 0 extra time, Player team: Brazil, Home: Northern Ireland, Away: Brazil, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#           Brazil             6                   3                     0                      3                 2                   1        0    0    0    0    0 False         0
#            Spain             4                   3                     2                      1                 2                   2        0    0    0    0    0 False         0
# Northern Ireland             1                   2                     4                     -2                 0                   3        0    0    0    0    0 False         0
#          Algeria             1                   1                     3                     -2                 0                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing Group D, year 1986, goal: 42 minute, 0 extra time, Player team: Brazil, Home: Northern Ireland, Away: Brazil, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#           Brazil             6                   4                     0                      4                 2                   1        0    0    0    0    0 False         0
#            Spain             4                   3                     2                      1                 2                   2        0    0    0    0    0 False         0
#          Algeria             1                   1                     3                     -2                 0                   3        1    0    0    1    0 False         0
# Northern Ireland             1                   2                     5                     -3                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group D, year 1986, goal: 68 minute, 0 extra time, Player team: Spain, Home: Algeria, Away: Spain, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#           Brazil             6                   4                     0                      4                 2                   1        0    0    0    0    0 False         0
#            Spain             4                   4                     2                      2                 2                   2        0    0    0    0    0 False         0
# Northern Ireland             1                   2                     5                     -3                 0                   3        2    0    0    1    1 False         0
#          Algeria             1                   1                     4                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group D, year 1986, goal: 70 minute, 0 extra time, Player team: Spain, Home: Algeria, Away: Spain, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#           Brazil             6                   4                     0                      4                 2                   1        0    0    0    0    0 False         0
#            Spain             4                   5                     2                      3                 2                   2        0    0    0    0    0 False         0
# Northern Ireland             1                   2                     5                     -3                 0                   3        2    0    0    1    1 False         0
#          Algeria             1                   1                     5                     -4                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group D, year 1986, goal: 87 minute, 0 extra time, Player team: Brazil, Home: Northern Ireland, Away: Brazil, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#           Brazil             6                   5                     0                      5                 2                   1        0    0    0    0    0 False         0
#            Spain             4                   5                     2                      3                 2                   2        0    0    0    0    0 False         0
# Northern Ireland             1                   2                     6                     -4                 0                   3        2    0    0    1    1 False         0
#          Algeria             1                   1                     5                     -4                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group Group E Before Last Match Goals ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#      Denmark             4                   7                     1                      6                        4                          1
# West Germany             3                   3                     2                      1                        3                          2
#      Uruguay             1                   2                     7                     -5                        1                          3
#     Scotland             0                   1                     3                     -2                        0                          4
#
# ====================================================
#
# Analyzing Group E, year 1986, goal: 43 minute, 0 extra time, Player team: Denmark, Home: Denmark, Away: West Germany, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Denmark             6                   8                     1                      7                 2                   1        0    0    0    0    0 False         0
# West Germany             3                   3                     3                      0                 0                   2        0    0    0    0    0 False         0
#      Uruguay             2                   2                     7                     -5                 1                   3        0    0    0    0    0 False         0
#     Scotland             1                   1                     3                     -2                 1                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing Group E, year 1986, goal: 62 minute, 0 extra time, Player team: Denmark, Home: Denmark, Away: West Germany, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Denmark             6                   9                     1                      8                 2                   1        0    0    0    0    0 False         0
# West Germany             3                   3                     4                     -1                 0                   2        0    0    0    0    0 False         0
#      Uruguay             2                   2                     7                     -5                 1                   3        0    0    0    0    0 False         0
#     Scotland             1                   1                     3                     -2                 1                   4        0    0    0    0    0 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group Group F Before Last Match Goals ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#   Poland             3                   1                     0                      1                        3                          1
# Portugal             2                   1                     1                      0                        2                          2
#  England             1                   0                     1                     -1                        1                          3
#
# ====================================================
#
# Analyzing Group F, year 1986, goal: 9 minute, 0 extra time, Player team: England, Home: England, Away: Poland, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Poland             3                   1                     1                      0                 0                   1        0    0    0    0    0  True         1
# Portugal             3                   1                     1                      0                 1                   2        0    0    0    0    0  True         1
#  England             3                   1                     1                      0                 2                   3        0    0    0    0    0  True         0
#
# ========================================
#
# Analyzing Group F, year 1986, goal: 14 minute, 0 extra time, Player team: England, Home: England, Away: Poland, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  England             3                   2                     1                      1                 2                   1        1    1    0    0    0 False         0
# Portugal             3                   1                     1                      0                 1                   2        0    0    0    0    0 False         0
#   Poland             3                   1                     2                     -1                 0                   3        1    0    0    1    0 False         0
#
# ========================================
#
# Analyzing Group F, year 1986, goal: 19 minute, 0 extra time, Player team: Morocco, Home: Portugal, Away: Morocco, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  England             3                   2                     1                      1                 2                   1        1    1    0    0    0 False         0
#   Poland             3                   1                     2                     -1                 0                   2        2    0    1    1    0 False         0
# Portugal             2                   1                     2                     -1                 0                   3        1    0    0    1    0 False         0
#
# ========================================
#
# Analyzing Group F, year 1986, goal: 26 minute, 0 extra time, Player team: Morocco, Home: Portugal, Away: Morocco, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  England             3                   2                     1                      1                 2                   1        1    1    0    0    0 False         0
#   Poland             3                   1                     2                     -1                 0                   2        2    0    1    1    0 False         0
# Portugal             2                   1                     3                     -2                 0                   3        1    0    0    1    0 False         0
#
# ========================================
#
# Analyzing Group F, year 1986, goal: 34 minute, 0 extra time, Player team: England, Home: England, Away: Poland, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  England             3                   3                     1                      2                 2                   1        1    1    0    0    0 False         0
#   Poland             3                   1                     3                     -2                 0                   2        2    0    1    1    0 False         0
# Portugal             2                   1                     3                     -2                 0                   3        1    0    0    1    0 False         0
#
# ========================================
#
# Analyzing Group F, year 1986, goal: 62 minute, 0 extra time, Player team: Morocco, Home: Portugal, Away: Morocco, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  England             3                   3                     1                      2                 2                   1        1    1    0    0    0 False         0
#   Poland             3                   1                     3                     -2                 0                   2        2    0    1    1    0 False         0
# Portugal             2                   1                     4                     -3                 0                   3        1    0    0    1    0 False         0
#
# ========================================
#
# Analyzing Group F, year 1986, goal: 80 minute, 0 extra time, Player team: Portugal, Home: Portugal, Away: Morocco, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  England             3                   3                     1                      2                 2                   1        1    1    0    0    0 False         0
#   Poland             3                   1                     3                     -2                 0                   2        2    0    1    1    0 False         0
# Portugal             2                   2                     4                     -2                 0                   3        1    0    0    1    0 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1990, Group Group A Before Last Match Goals ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# Czechoslovakia             4                   6                     1                      5                        4                          1
#          Italy             4                   2                     0                      2                        4                          2
#        Austria             0                   0                     2                     -2                        0                          3
#  United States             0                   1                     6                     -5                        0                          4
#
# ====================================================
#
# Analyzing Group A, year 1990, goal: 9 minute, 0 extra time, Player team: Italy, Home: Italy, Away: Czechoslovakia, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#          Italy             6                   3                     0                      3                 2                   1        1    1    0    0    0 False         0
# Czechoslovakia             4                   6                     2                      4                 0                   2        1    0    1    0    0 False         0
#        Austria             1                   0                     2                     -2                 1                   3        1    0    0    1    0 False         0
#  United States             1                   1                     6                     -5                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1990, goal: 49 minute, 0 extra time, Player team: Austria, Home: Austria, Away: United States, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#          Italy             6                   3                     0                      3                 2                   1        1    1    0    0    0 False         0
# Czechoslovakia             4                   6                     2                      4                 0                   2        1    0    1    0    0 False         0
#        Austria             2                   1                     2                     -1                 2                   3        1    0    0    1    0 False         0
#  United States             0                   1                     7                     -6                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1990, goal: 63 minute, 0 extra time, Player team: Austria, Home: Austria, Away: United States, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#          Italy             6                   3                     0                      3                 2                   1        1    1    0    0    0 False         0
# Czechoslovakia             4                   6                     2                      4                 0                   2        1    0    1    0    0 False         0
#        Austria             2                   2                     2                      0                 2                   3        1    0    0    1    0 False         0
#  United States             0                   1                     8                     -7                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1990, goal: 78 minute, 0 extra time, Player team: Italy, Home: Italy, Away: Czechoslovakia, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#          Italy             6                   4                     0                      4                 2                   1        1    1    0    0    0 False         0
# Czechoslovakia             4                   6                     3                      3                 0                   2        1    0    1    0    0 False         0
#        Austria             2                   2                     2                      0                 2                   3        1    0    0    1    0 False         0
#  United States             0                   1                     8                     -7                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1990, goal: 83 minute, 0 extra time, Player team: United States, Home: Austria, Away: United States, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#          Italy             6                   4                     0                      4                 2                   1        1    1    0    0    0 False         0
# Czechoslovakia             4                   6                     3                      3                 0                   2        1    0    1    0    0 False         0
#        Austria             2                   2                     3                     -1                 2                   3        1    0    0    1    0 False         0
#  United States             0                   2                     8                     -6                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1990, Group Group B Before Last Match Goals ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#     Cameroon             4                   3                     1                      2                        4                          1
#      Romania             2                   3                     2                      1                        2                          2
#    Argentina             2                   2                     1                      1                        2                          3
# Soviet Union             0                   0                     4                     -4                        0                          4
#
# ====================================================
#
# Analyzing Group B, year 1990, goal: 20 minute, 0 extra time, Player team: Soviet Union, Home: Cameroon, Away: Soviet Union, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     Cameroon             4                   3                     2                      1                 0                   1        0    0    0    0    0 False         0
#      Romania             3                   3                     2                      1                 1                   2        0    0    0    0    0 False         0
#    Argentina             3                   2                     1                      1                 1                   3        0    0    0    0    0 False         0
# Soviet Union             2                   1                     4                     -3                 2                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing Group B, year 1990, goal: 29 minute, 0 extra time, Player team: Soviet Union, Home: Cameroon, Away: Soviet Union, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     Cameroon             4                   3                     3                      0                 0                   1        0    0    0    0    0 False         0
#      Romania             3                   3                     2                      1                 1                   2        0    0    0    0    0 False         0
#    Argentina             3                   2                     1                      1                 1                   3        0    0    0    0    0 False         0
# Soviet Union             2                   2                     4                     -2                 2                   4        0    0    0    0    0 False         0
#
# ========================================
#
# ...
# Belgium             3                   1                     2                     -1                 1                   3        1    0    0    1    0 False         0
#  Canada             0                   1                     7                     -6                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group F, year 2022, goal: 40 minute, 0 extra time, Player team: Morocco, Home: Canada, Away: Morocco, Own goal: 1
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Morocco             6                   4                     1                      3                 3                   1        1    1    0    0    0 False         0
# Croatia             4                   4                     1                      3                 1                   2        1    0    1    0    0 False         0
# Belgium             3                   1                     2                     -1                 1                   3        1    0    0    1    0 False         0
#  Canada             0                   2                     7                     -5                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2022, Group Group G Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#      Brazil             4                   3                     0                      3                        4                          1
# Switzerland             2                   1                     1                      0                        2                          2
#    Cameroon             1                   3                     4                     -1                        1                          3
#      Serbia             1                   3                     5                     -2                        1                          4
#
# ====================================================
#
# Analyzing Group G, year 2022, goal: 20 minute, 0 extra time, Player team: Switzerland, Home: Serbia, Away: Switzerland, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Brazil             5                   3                     0                      3                 1                   1        0    0    0    0    0 False         0
# Switzerland             5                   2                     1                      1                 3                   2        0    0    0    0    0 False         0
#    Cameroon             2                   3                     4                     -1                 1                   3        0    0    0    0    0 False         0
#      Serbia             1                   3                     6                     -3                 0                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing Group G, year 2022, goal: 26 minute, 0 extra time, Player team: Serbia, Home: Serbia, Away: Switzerland, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Brazil             5                   3                     0                      3                 1                   1        0    0    0    0    0 False         0
# Switzerland             3                   2                     2                      0                 1                   2        0    0    0    0    0 False         0
#    Cameroon             2                   3                     4                     -1                 1                   3        0    0    0    0    0 False         0
#      Serbia             2                   4                     6                     -2                 1                   4        0    0    0    0    0 False         0
#
# ========================================
#
# Analyzing Group G, year 2022, goal: 35 minute, 0 extra time, Player team: Serbia, Home: Serbia, Away: Switzerland, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Brazil             5                   3                     0                      3                 1                   1        0    0    0    0    0 False         0
#      Serbia             4                   5                     6                     -1                 3                   2        1    0    1    0    0 False         0
#    Cameroon             2                   3                     4                     -1                 1                   3        0    0    0    0    0 False         0
# Switzerland             2                   2                     3                     -1                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group G, year 2022, goal: 44 minute, 0 extra time, Player team: Switzerland, Home: Serbia, Away: Switzerland, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Brazil             5                   3                     0                      3                 1                   1        0    0    0    0    0 False         0
# Switzerland             3                   3                     3                      0                 1                   2        2    0    1    0    1 False         0
#    Cameroon             2                   3                     4                     -1                 1                   3        0    0    0    0    0 False         0
#      Serbia             2                   5                     7                     -2                 1                   4        2    0    1    0    1 False         0
#
# ========================================
#
# Analyzing Group G, year 2022, goal: 48 minute, 0 extra time, Player team: Switzerland, Home: Serbia, Away: Switzerland, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Brazil             5                   3                     0                      3                 1                   1        0    0    0    0    0 False         0
# Switzerland             5                   4                     3                      1                 3                   2        2    0    1    0    1 False         0
#    Cameroon             2                   3                     4                     -1                 1                   3        0    0    0    0    0 False         0
#      Serbia             1                   5                     8                     -3                 0                   4        2    0    1    0    1 False         0
#
# ========================================
#
# Analyzing Group G, year 2022, goal: 90 minute, 2 extra time, Player team: Cameroon, Home: Cameroon, Away: Brazil, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Switzerland             5                   4                     3                      1                 3                   1        3    1    1    0    1 False         0
#      Brazil             4                   3                     1                      2                 0                   2        1    0    1    0    0 False         0
#    Cameroon             4                   4                     4                      0                 3                   3        0    0    0    0    0 False         0
#      Serbia             1                   5                     8                     -3                 0                   4        2    0    1    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2022, Group Group H Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#    Portugal             4                   5                     2                      3                        4                          1
#       Ghana             2                   5                     5                      0                        2                          2
# South Korea             1                   2                     3                     -1                        1                          3
#     Uruguay             1                   0                     2                     -2                        1                          4
#
# ====================================================
#
# Analyzing Group H, year 2022, goal: 5 minute, 0 extra time, Player team: Portugal, Home: South Korea, Away: Portugal, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#    Portugal             7                   6                     2                      4                 3                   1        0    0    0    0    0 False         0
#       Ghana             3                   5                     5                      0                 1                   2        0    0    0    0    0 False         0
#     Uruguay             2                   0                     2                     -2                 1                   3        1    0    0    1    0 False         0
# South Korea             1                   2                     4                     -2                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group H, year 2022, goal: 26 minute, 0 extra time, Player team: Uruguay, Home: Ghana, Away: Uruguay, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#    Portugal             7                   6                     2                      4                 3                   1        0    0    0    0    0 False         0
#     Uruguay             4                   1                     2                     -1                 3                   2        2    0    1    1    0 False         0
#       Ghana             2                   5                     6                     -1                 0                   3        1    0    0    1    0 False         0
# South Korea             1                   2                     4                     -2                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group H, year 2022, goal: 27 minute, 0 extra time, Player team: South Korea, Home: South Korea, Away: Portugal, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#    Portugal             5                   6                     3                      3                 1                   1        0    0    0    0    0 False         0
#     Uruguay             4                   1                     2                     -1                 3                   2        2    0    1    1    0 False         0
#       Ghana             2                   5                     6                     -1                 0                   3        1    0    0    1    0 False         0
# South Korea             2                   3                     4                     -1                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group H, year 2022, goal: 32 minute, 0 extra time, Player team: Uruguay, Home: Ghana, Away: Uruguay, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#    Portugal             5                   6                     3                      3                 1                   1        0    0    0    0    0 False         0
#     Uruguay             4                   2                     2                      0                 3                   2        2    0    1    1    0 False         0
# South Korea             2                   3                     4                     -1                 1                   3        2    0    0    1    1 False         0
#       Ghana             2                   5                     7                     -2                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group H, year 2022, goal: 90 minute, 1 extra time, Player team: South Korea, Home: South Korea, Away: Portugal, Own goal: 0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#    Portugal             4                   6                     4                      2                 0                   1        0    0    0    0    0 False         0
# South Korea             4                   4                     4                      0                 3                   2        3    0    1    1    1 False         0
#     Uruguay             4                   2                     2                      0                 3                   3        3    0    1    2    0 False         0
#       Ghana             2                   5                     7                     -2                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#      year group_name         team  1st  2nd  3rd  4th  changes
# 0    1986    Group A    Argentina    0    0    0    0        0
# 2    1986    Group A        Italy    0    1    0    0        1
# 1    1986    Group A     Bulgaria    0    0    1    0        1
# 3    1986    Group A  South Korea    0    0    0    1        1
# 4    1986    Group B       Mexico    1    1    0    0        2
# ..    ...        ...          ...  ...  ...  ...  ...      ...
# 289  2022    Group G       Serbia    0    1    0    1        2
# 290  2022    Group H     Portugal    0    0    0    0        0
# 292  2022    Group H  South Korea    0    1    1    1        3
# 293  2022    Group H      Uruguay    0    1    2    0        3
# 291  2022    Group H        Ghana    0    0    1    1        2
#
# [294 rows x 8 columns]

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\tb_wc_fifa.xlsx'
changes_df_wc.to_excel(file_path, index=False)

# %% [markdown]
# # best four third placed

# %%
def best_four_third_placed(goals_last_day_sorted, all_games_before_last, agg_goals_before_last_day):
    # Apply filter to process only years <= 1994
    all_games_before_last = all_games_before_last[all_games_before_last['year'] <= 1994].copy()

    # Initialize a list to store data for each year that will be appended into the final DataFrame
    all_years_data = []

    # Group data by year and process year-by-year
    for year, year_data in all_games_before_last.groupby('year'):
        print(f"\n--- Processing Year: {year} ---")
        year_data = year_data.copy()

        # Initialize dictionaries to track third-placed teams and top 4 counts for the current year
        third_teams_count = {}
        top4_count = {}

        # Step 1: Initialize columns for tracking team performance before and after goals
        year_data.loc[:, 'before_last_game_goals_scored'] = year_data['goals_scored']
        year_data.loc[:, 'before_last_game_goals_conceded'] = year_data['goals_conceded']
        year_data.loc[:, 'before_last_game_points'] = year_data['points']

        year_data.loc[:, 'last_game_goals_scored'] = 0
        year_data.loc[:, 'last_game_goals_conceded'] = 0
        year_data.loc[:, 'last_game_points'] = 0
        year_data.loc[:, 'total_goals_scored'] = year_data['before_last_game_goals_scored'] + year_data['last_game_goals_scored']
        year_data.loc[:, 'total_goals_conceded'] = year_data['before_last_game_goals_conceded'] + year_data['last_game_goals_conceded']
        year_data.loc[:, 'total_goal_difference'] = year_data['total_goals_scored'] - year_data['total_goals_conceded']

        # Print the standings before any goal is processed
        print(f"\n=== Initial Standings for Year {year} Before Processing Any Goals ===\n")
        display_columns = ['team', 'group_name', 'before_last_game_points', 'before_last_game_goals_scored', 'before_last_game_goals_conceded', 'total_goal_difference']
        print(year_data[display_columns].sort_values(by=['group_name', 'before_last_game_points', 'total_goal_difference', 'before_last_game_goals_scored'], ascending=[True, False, False, False]).to_string(index=False))
        print("\n===============================================================\n")

        # Process each goal from the sorted last-day goals for the current year
        goals_last_day_year = goals_last_day_sorted[goals_last_day_sorted['year'] == year]

        for i, goal in goals_last_day_year.iterrows():
            print(f"\n--- Analyzing Goal {i + 1} in {goal['group_name']}: On date {goal['match_date']}, Minute {goal['minute_regulation']} (Player Team: {goal['player_team_name']}, Home: {goal['home']}, Away: {goal['away']}, Own Goal: {goal['own_goal']}) ---")

            home_team = goal['home']
            away_team = goal['away']
            player_team = goal['player_team_name']
            own_goal = goal['own_goal']

            # Identify the opponent team
            opponent_team = home_team if player_team == away_team else away_team

            # Update goals based on who scored (own goal or normal goal)
            if own_goal == 0:  # Normal goal
                year_data.loc[year_data['team'] == player_team, 'last_game_goals_scored'] += 1
                year_data.loc[year_data['team'] == opponent_team, 'last_game_goals_conceded'] += 1
            else:  # Own goal
                year_data.loc[year_data['team'] == opponent_team, 'last_game_goals_scored'] += 1
                year_data.loc[year_data['team'] == player_team, 'last_game_goals_conceded'] += 1

            # Update total goals scored, goals conceded, and goal difference
            year_data.loc[:, 'total_goals_scored'] = year_data['before_last_game_goals_scored'] + year_data['last_game_goals_scored']
            year_data.loc[:, 'total_goals_conceded'] = year_data['before_last_game_goals_conceded'] + year_data['last_game_goals_conceded']
            year_data.loc[:, 'total_goal_difference'] = year_data['total_goals_scored'] - year_data['total_goals_conceded']

            # Assign points for the last game dynamically
            year_data.loc[:, 'last_game_points'] = (year_data['last_game_goals_scored'] > year_data['last_game_goals_conceded']).astype(int) * 3 + \
                                                   (year_data['last_game_goals_scored'] == year_data['last_game_goals_conceded']).astype(int)

            # Update total points
            year_data.loc[:, 'total_points'] = year_data['before_last_game_points'] + year_data['last_game_points']

            # Reset third-placed teams after every goal
            third_teams_per_year = []

            # Recalculate standings after the goal
            for group, group_data in year_data.groupby('group_name'):
                sorted_standings = group_data.sort_values(by=['total_points', 'total_goal_difference', 'total_goals_scored'], ascending=[False, False, False])

                # Identify the third-placed teams after each goal, **by group**
                if len(sorted_standings) >= 3:
                    third_placed_team = sorted_standings.iloc[2]
                    third_teams_per_year.append(third_placed_team['team'])

            # Update the count for third-placed teams after each goal
            for team in third_teams_per_year:
                if team not in third_teams_count:
                    third_teams_count[team] = 0
                third_teams_count[team] += 1

            # Create DataFrame of third-placed teams with additional stats
            third_teams_df = year_data[year_data['team'].isin(third_teams_per_year)][
                ['team', 'total_points', 'last_game_points', 'total_goal_difference', 'total_goals_scored']
            ]

            # Identify the best four third-placed teams after each goal
            top4_teams = third_teams_df['team'].value_counts().nlargest(4).index.tolist()

            # Print third-placed teams' additional statistics after each goal
            print(f"Top 4 third-placed teams after this goal: {top4_teams}")
            print(f"Third-placed teams DataFrame after this goal:\n{third_teams_df}\n")

            # Update the count for top 4 third-placed teams after each goal
            for team in top4_teams:
                if team not in top4_count:
                    top4_count[team] = 0
                top4_count[team] += 1

        # After processing all goals for the year, store the results in the final list
        for team, third_count in third_teams_count.items():
            top4_count_for_team = top4_count.get(team, 0)
            all_years_data.append({
                'team': team,
                'year': year,
                'third_place_count': third_count,
                'top4_third_place_count': top4_count_for_team
            })

    # Create a DataFrame from the list of all years' data
    final_df = pd.DataFrame(all_years_data)

    file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\third_teams_fifa.xlsx'
    final_df.to_excel(file_path, index=False)
    
    return final_df

# %%
best_four_third_placed(goals_last_day_sorted, all_games_before_last, agg_goals_before_last_day)
# Out:
# --- Processing Year: 1986 ---
#
# === Initial Standings for Year 1986 Before Processing Any Goals ===
#
#             team group_name  before_last_game_points  before_last_game_goals_scored  before_last_game_goals_conceded  total_goal_difference
#        Argentina    Group A                        3                              4                                2                      2
#         Bulgaria    Group A                        2                              2                                2                      0
#            Italy    Group A                        2                              2                                2                      0
#      South Korea    Group A                        1                              2                                4                     -2
#           Mexico    Group B                        3                              3                                2                      1
#         Paraguay    Group B                        3                              2                                1                      1
#          Belgium    Group B                        2                              3                                3                      0
#             Iraq    Group B                        0                              1                                3                     -2
#     Soviet Union    Group C                        3                              6                                1                      5
#           France    Group C                        3                              2                                1                      1
#          Hungary    Group C                        2                              2                                5                     -3
#           Canada    Group C                        0                              0                                3                     -3
#           Brazil    Group D                        4                              2                                0                      2
#            Spain    Group D                        2                              2                                2                      0
# Northern Ireland    Group D                        1                              2                                3                     -1
#          Algeria    Group D                        1                              1                                2                     -1
#          Denmark    Group E                        4                              7                                1                      6
#     West Germany    Group E                        3                              3                                2                      1
#          Uruguay    Group E                        1                              2                                7                     -5
#         Scotland    Group E                        0                              1                                3                     -2
#           Poland    Group F                        3                              1                                0                      1
#         Portugal    Group F                        2                              1                                1                      0
#          England    Group F                        1                              0                                1                     -1
#
# ===============================================================
#
#
# --- Analyzing Goal 1 in Group C: On date 1986-06-09 00:00:00, Minute 29 (Player Team: France, Home: Hungary, Away: France, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Italy', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 2              Italy             3                 1                      0
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -4
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 2                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 2 in Group C: On date 1986-06-09 00:00:00, Minute 58 (Player Team: Soviet Union, Home: Soviet Union, Away: Canada, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Italy', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 2              Italy             3                 1                      0
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -4
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 2                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 3 in Group C: On date 1986-06-09 00:00:00, Minute 62 (Player Team: France, Home: Hungary, Away: France, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Italy', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 2              Italy             3                 1                      0
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -5
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 2                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 4 in Group C: On date 1986-06-09 00:00:00, Minute 74 (Player Team: Soviet Union, Home: Soviet Union, Away: Canada, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Italy', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 2              Italy             3                 1                      0
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -5
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 2                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 5 in Group C: On date 1986-06-09 00:00:00, Minute 84 (Player Team: France, Home: Hungary, Away: France, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Italy', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 2              Italy             3                 1                      0
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 2                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 6 in Group A: On date 1986-06-10 00:00:00, Minute 4 (Player Team: Argentina, Home: Argentina, Away: Bulgaria, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -1
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 7 in Group A: On date 1986-06-10 00:00:00, Minute 17 (Player Team: Italy, Home: South Korea, Away: Italy, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -1
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 8 in Group A: On date 1986-06-10 00:00:00, Minute 62 (Player Team: South Korea, Home: South Korea, Away: Italy, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -1
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 9 in Group A: On date 1986-06-10 00:00:00, Minute 73 (Player Team: Italy, Home: South Korea, Away: Italy, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -1
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 10 in Group A: On date 1986-06-10 00:00:00, Minute 77 (Player Team: Argentina, Home: Argentina, Away: Bulgaria, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 11 in Group A: On date 1986-06-10 00:00:00, Minute 82 (Player Team: South Korea, Home: South Korea, Away: Italy, Own Goal: 1) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 12 in Group A: On date 1986-06-10 00:00:00, Minute 83 (Player Team: South Korea, Home: South Korea, Away: Italy, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 13 in Group F: On date 1986-06-11 00:00:00, Minute 9 (Player Team: England, Home: England, Away: Poland, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             3                 1                      0
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 14 in Group F: On date 1986-06-11 00:00:00, Minute 14 (Player Team: England, Home: England, Away: Poland, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 20            Poland             3                 0                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 20                   1
#
#
# --- Analyzing Goal 15 in Group F: On date 1986-06-11 00:00:00, Minute 19 (Player Team: Morocco, Home: Portugal, Away: Morocco, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 16 in Group F: On date 1986-06-11 00:00:00, Minute 26 (Player Team: Morocco, Home: Portugal, Away: Morocco, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 17 in Group B: On date 1986-06-11 00:00:00, Minute 30 (Player Team: Belgium, Home: Paraguay, Away: Belgium, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Paraguay', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 5           Paraguay             3                 0                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 5                    2
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 18 in Group F: On date 1986-06-11 00:00:00, Minute 34 (Player Team: England, Home: England, Away: Poland, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Paraguay', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 5           Paraguay             3                 0                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 5                    2
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 19 in Group B: On date 1986-06-11 00:00:00, Minute 50 (Player Team: Paraguay, Home: Paraguay, Away: Belgium, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    4
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 20 in Group B: On date 1986-06-11 00:00:00, Minute 54 (Player Team: Mexico, Home: Iraq, Away: Mexico, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    4
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 21 in Group B: On date 1986-06-11 00:00:00, Minute 59 (Player Team: Belgium, Home: Paraguay, Away: Belgium, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Paraguay', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 5           Paraguay             3                 0                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 5                    3
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 22 in Group F: On date 1986-06-11 00:00:00, Minute 62 (Player Team: Morocco, Home: Portugal, Away: Morocco, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Paraguay', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 5           Paraguay             3                 0                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -3
#
#     total_goals_scored
# 1                    2
# 5                    3
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 23 in Group B: On date 1986-06-11 00:00:00, Minute 76 (Player Team: Paraguay, Home: Paraguay, Away: Belgium, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -3
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 24 in Group F: On date 1986-06-11 00:00:00, Minute 80 (Player Team: Portugal, Home: Portugal, Away: Morocco, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 25 in Group D: On date 1986-06-12 00:00:00, Minute 15 (Player Team: Spain, Home: Algeria, Away: Spain, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 26 in Group D: On date 1986-06-12 00:00:00, Minute 15 (Player Team: Brazil, Home: Northern Ireland, Away: Brazil, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             1                 0                     -2
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 27 in Group D: On date 1986-06-12 00:00:00, Minute 42 (Player Team: Brazil, Home: Northern Ireland, Away: Brazil, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Algeria']
# Third-placed teams DataFrame after this goal:
#         team  total_points  last_game_points  total_goal_difference  \
# 1   Bulgaria             2                 0                     -2
# 6    Belgium             3                 1                      0
# 10   Hungary             2                 0                     -6
# 15   Algeria             1                 0                     -2
# 18   Uruguay             2                 1                     -5
# 21  Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 15                   1
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 28 in Group D: On date 1986-06-12 00:00:00, Minute 68 (Player Team: Spain, Home: Algeria, Away: Spain, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             1                 0                     -3
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 29 in Group D: On date 1986-06-12 00:00:00, Minute 70 (Player Team: Spain, Home: Algeria, Away: Spain, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             1                 0                     -3
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 30 in Group D: On date 1986-06-12 00:00:00, Minute 87 (Player Team: Brazil, Home: Northern Ireland, Away: Brazil, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             1                 0                     -4
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 31 in Group E: On date 1986-06-13 00:00:00, Minute 43 (Player Team: Denmark, Home: Denmark, Away: West Germany, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             1                 0                     -4
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 32 in Group E: On date 1986-06-13 00:00:00, Minute 62 (Player Team: Denmark, Home: Denmark, Away: West Germany, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             1                 0                     -4
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Processing Year: 1990 ---
#
# === Initial Standings for Year 1990 Before Processing Any Goals ===
#
#                 team group_name  before_last_game_points  before_last_game_goals_scored  before_last_game_goals_conceded  total_goal_difference
#       Czechoslovakia    Group A                        4                              6                                1                      5
#                Italy    Group A                        4                              2                                0                      2
#              Austria    Group A                        0                              0                                2                     -2
#        United States    Group A                        0                              1                                6                     -5
#             Cameroon    Group B                        4                              3                                1                      2
#              Romania    Group B                        2                              3                                2                      1
#            Argentina    Group B                        2                              2                                1                      1
#         Soviet Union    Group B                        0                              0                                4                     -4
#               Brazil    Group C                        4                              3                                1                      2
#             Scotland    Group C                        2                              2                                2                      0
#           Costa Rica    Group C                        2                              1                                1                      0
#               Sweden    Group C                        0                              2                                4                     -2
#         West Germany    Group D                        4                              9                                2                      7
#             Colombia    Group D                        2                              2                                1                      1
#           Yugoslavia    Group D                        2                              2                                4                     -2
# United Arab Emirates    Group D                        0                              1                                7                     -6
#              Belgium    Group E                        4                              5                                1                      4
#                Spain    Group E                        3                              3                                1                      2
#              Uruguay    Group E                        1                              1                                3                     -2
#          South Korea    Group E                        0                              1                                5                     -4
#                Egypt    Group F                        2                              1                                1                      0
#              England    Group F                        2                              1                                1                      0
#          Netherlands    Group F                        2                              1                                1                      0
#  Republic of Ireland    Group F                        2                              1                                1                      0
#
# ===============================================================
#
#
# --- Analyzing Goal 33 in Group B: On date 1990-06-18 00:00:00, Minute 20 (Player Team: Soviet Union, Home: Cameroon, Away: Soviet Union, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Austria', 'Argentina', 'Costa Rica', 'Yugoslavia']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 25      Austria             1                 1                     -2
# 29    Argentina             3                 1                      1
# 33   Costa Rica             3                 1                      0
# 37   Yugoslavia             3                 1                     -2
# 41      Uruguay             2                 1                     -2
# 45  Netherlands             3                 1                      0
#
#     total_goals_scored
# 25                   0
# 29                   2
# 33                   1
# 37                   2
# 41                   1
# 45                   1
#
#
# --- Analyzing Goal 34 in Group B: On date 1990-06-18 00:00:00, Minute 29 (Player Team: Soviet Union, Home: Cameroon, Away: Soviet Union, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Austria', 'Argentina', 'Costa Rica', 'Yugoslavia']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 25      Austria             1                 1                     -2
# 29    Argentina             3                 1                      1
# 33   Costa Rica             3                 1                      0
# 37   Yugoslavia             3                 1                     -2
# 41      Uruguay             2                 1                     -2
# 45  Netherlands             3                 1                      0
#
#     total_goals_scored
# 25                   0
# 29                   2
# 33                   1
# 37                   2
# 41                   1
# 45                   1
#
#
# --- Analyzing Goal 35 in Group B: On date 1990-06-18 00:00:00, Minute 52 (Player Team: Soviet Union, Home: Cameroon, Away: Soviet Union, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Austria', 'Argentina', 'Costa Rica', 'Yugoslavia']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 25      Austria             1                 1                     -2
# 29    Argentina             3                 1                      1
# 33   Costa Rica             3                 1                      0
# 37   Yugoslavia             3                 1                     -2
# 41      Uruguay             2                 1                     -2
# 45  Netherlands             3                 1                      0
#
#     total_goals_scored
# 25                   0
# 29                   2
# 33                   1
# 37                   2
# 41                   1
# 45                   1
#
#
# --- Analyzing Goal 36 in Group B: On date 1990-06-18 00:00:00, Minute 62 (Player Team: Argentina, Home: Argentina, Away: Romania, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Austria', 'Soviet Union', 'Costa Rica', 'Yugoslavia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 25       Austria             1                 1                     -2
# 30  Soviet Union             3                 3                     -1
# 33    Costa Rica             3                 1                      0
# 37    Yugoslavia             3                 1                     -2
# 41       Uruguay             2                 1                     -2
# 45   Netherlands             3                 1                      0
#
#     total_goals_scored
# 25                   0
# 30                   3
# 33                   1
# 37                   2
# 41                   1
# 45                   1
#
#
# --- Analyzing Goal 37 in Group B: On date 1990-06-18 00:00:00, Minute 63 (Player Team: Soviet Union, Home: Cameroon, Away: Soviet Union, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Austria', 'Soviet Union', 'Costa Rica', 'Yugoslavia']
# Third-placed teams DataFrame after this goal:
#             team  total_points  last_game_points  total_goal_difference  \
# 25       Austria             1                 1                     -2
# 30  Soviet Union             3                 3                      0
# 33    Costa Rica             3                 1                      0
# 37    Yugoslavia             3                 1                     -2
# 41       Uruguay             2                 1                     -2
# 45   Netherlands             3                 1                      0
#
#     total_goals_scored
# 25                   0
# 30                   4
# 33                   1
# 37                   2
# 41                   1
# 45                   1
#
#
# --- Analyzing Goal 38 in Group B: On date 1990-06-18 00:00:00, Minute 68 (Player Team: Romania, Home: Argentina, Away: Romania, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Austria', 'Argentina', 'Costa Rica', 'Yugoslavia']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 25      Austria             1                 1                     -2
# 29    Argentina             3                 1                      1
# 33   Costa Rica             3                 1                      0
# 37   Yugoslavia             3                 1                     -2
# 41      Uruguay             2                 1                     -2
# 45  Netherlands             3                 1                      0
#
#     total_goals_scored
# 25                   0
# 29                   3
# 33                   1
# 37                   2
# 41                   1
# 45                   1
#
#
# --- Analyzing Goal 39 in Group D: On date 1990-06-19 00:00:00, Minute 5 (Player Team: Yugoslavia, Home: Yugoslavia, Away: United Arab Emirates, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Austria', 'Argentina', 'Costa Rica', 'Colombia']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 25      Austria             1                 1                     -2
# 29    Argentina             3                 1                      1
# 33   Costa Rica             3                 1                      0
# 36     Colombia             3                 1                      1
# 41      Uruguay             2                 1                     -2
# 45  Netherlands             3                 1                      0
#
#     total_goals_scored
# 25                   0
# 29                   3
# 33                   1
# 36                   2
# 41                   1
# 45                   1
#
#
# --- Analyzing Goal 40 in Group D: On date 1990-06-19 00:00:00, Minute 9 (Player Team: Yugoslavia, Home: Yugoslavia, Away: United Arab Emirates, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Austria', 'Argentina', 'Costa Rica', 'Colombia']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 25      Austria             1                 1                     -2
# 29    Argentina             3                 1                      1
# 33   Costa Rica             3                 1                      0
# 36     Colombia             3                 1                      1
# 41      Uruguay             2                 1                     -2
# 45  Netherlands             3                 1                      0
#
#     total_goals_scored
# 25                   0
# 29                   3
# 33                   1
# 36                   2
# 41                   1
# 45                   1
#
#
# --- Analyzing Goal 41 in Group A: On date 1990-06-19 00:00:00, Minute 9 (Player Team: Italy, Home: Italy, Away: Czechoslovakia, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Austria', 'Argentina', 'Costa Rica', 'Colombia']
# ...
# 54       Russia             3                 3                     -2
# 57  South Korea             2                 0                     -1
# 61     Bulgaria             3                 1                      1
# 65        Italy             3                 1                      0
# 69  Netherlands             3                 1                      0
#
#     total_goals_scored
# 47                   5
# 54                   4
# 57                   4
# 61                   4
# 65                   1
# 69                   2
#
#
# --- Analyzing Goal 80 in Group E: On date 1994-06-28 00:00:00, Minute 48 (Player Team: Italy, Home: Italy, Away: Mexico, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Bulgaria']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                     -2
# 57  South Korea             2                 0                     -1
# 61     Bulgaria             3                 1                      1
# 66       Norway             3                 1                      0
# 69  Netherlands             3                 1                      0
#
#     total_goals_scored
# 47                   5
# 54                   4
# 57                   4
# 61                   4
# 66                   1
# 69                   2
#
#
# --- Analyzing Goal 81 in Group E: On date 1994-06-28 00:00:00, Minute 57 (Player Team: Mexico, Home: Italy, Away: Mexico, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Bulgaria']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                     -2
# 57  South Korea             2                 0                     -1
# 61     Bulgaria             3                 1                      1
# 65        Italy             3                 1                      0
# 69  Netherlands             3                 1                      0
#
#     total_goals_scored
# 47                   5
# 54                   4
# 57                   4
# 61                   4
# 65                   2
# 69                   2
#
#
# --- Analyzing Goal 82 in Group B: On date 1994-06-28 00:00:00, Minute 72 (Player Team: Russia, Home: Russia, Away: Cameroon, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Bulgaria']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                     -1
# 57  South Korea             2                 0                     -1
# 61     Bulgaria             3                 1                      1
# 65        Italy             3                 1                      0
# 69  Netherlands             3                 1                      0
#
#     total_goals_scored
# 47                   5
# 54                   5
# 57                   4
# 61                   4
# 65                   2
# 69                   2
#
#
# --- Analyzing Goal 83 in Group B: On date 1994-06-28 00:00:00, Minute 75 (Player Team: Russia, Home: Russia, Away: Cameroon, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Bulgaria']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                      0
# 57  South Korea             2                 0                     -1
# 61     Bulgaria             3                 1                      1
# 65        Italy             3                 1                      0
# 69  Netherlands             3                 1                      0
#
#     total_goals_scored
# 47                   5
# 54                   6
# 57                   4
# 61                   4
# 65                   2
# 69                   2
#
#
# --- Analyzing Goal 84 in Group B: On date 1994-06-28 00:00:00, Minute 81 (Player Team: Russia, Home: Russia, Away: Cameroon, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Bulgaria']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                      1
# 57  South Korea             2                 0                     -1
# 61     Bulgaria             3                 1                      1
# 65        Italy             3                 1                      0
# 69  Netherlands             3                 1                      0
#
#     total_goals_scored
# 47                   5
# 54                   7
# 57                   4
# 61                   4
# 65                   2
# 69                   2
#
#
# --- Analyzing Goal 85 in Group F: On date 1994-06-29 00:00:00, Minute 5 (Player Team: Saudi Arabia, Home: Belgium, Away: Saudi Arabia, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Bulgaria']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                      1
# 57  South Korea             2                 0                     -1
# 61     Bulgaria             3                 1                      1
# 65        Italy             3                 1                      0
# 69  Netherlands             3                 1                      0
#
#     total_goals_scored
# 47                   5
# 54                   7
# 57                   4
# 61                   4
# 65                   2
# 69                   2
#
#
# --- Analyzing Goal 86 in Group F: On date 1994-06-29 00:00:00, Minute 43 (Player Team: Netherlands, Home: Morocco, Away: Netherlands, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Bulgaria']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                      1
# 57  South Korea             2                 0                     -1
# 61     Bulgaria             3                 1                      1
# 65        Italy             3                 1                      0
# 67      Belgium             4                 0                      1
#
#     total_goals_scored
# 47                   5
# 54                   7
# 57                   4
# 61                   4
# 65                   2
# 67                   2
#
#
# --- Analyzing Goal 87 in Group F: On date 1994-06-29 00:00:00, Minute 47 (Player Team: Morocco, Home: Morocco, Away: Netherlands, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Bulgaria']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                      1
# 57  South Korea             2                 0                     -1
# 61     Bulgaria             3                 1                      1
# 65        Italy             3                 1                      0
# 69  Netherlands             3                 1                      0
#
#     total_goals_scored
# 47                   5
# 54                   7
# 57                   4
# 61                   4
# 65                   2
# 69                   3
#
#
# --- Analyzing Goal 88 in Group F: On date 1994-06-29 00:00:00, Minute 77 (Player Team: Netherlands, Home: Morocco, Away: Netherlands, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Bulgaria']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                      1
# 57  South Korea             2                 0                     -1
# 61     Bulgaria             3                 1                      1
# 65        Italy             3                 1                      0
# 67      Belgium             4                 0                      1
#
#     total_goals_scored
# 47                   5
# 54                   7
# 57                   4
# 61                   4
# 65                   2
# 67                   2
#
#
# --- Analyzing Goal 89 in Group D: On date 1994-06-30 00:00:00, Minute 45 (Player Team: Nigeria, Home: Greece, Away: Nigeria, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Bulgaria']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                      1
# 57  South Korea             2                 0                     -1
# 61     Bulgaria             3                 1                      1
# 65        Italy             3                 1                      0
# 67      Belgium             4                 0                      1
#
#     total_goals_scored
# 47                   5
# 54                   7
# 57                   4
# 61                   4
# 65                   2
# 67                   2
#
#
# --- Analyzing Goal 90 in Group D: On date 1994-06-30 00:00:00, Minute 61 (Player Team: Bulgaria, Home: Argentina, Away: Bulgaria, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Argentina']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                      1
# 57  South Korea             2                 0                     -1
# 59    Argentina             4                 0                      4
# 65        Italy             3                 1                      0
# 67      Belgium             4                 0                      1
#
#     total_goals_scored
# 47                   5
# 54                   7
# 57                   4
# 59                   6
# 65                   2
# 67                   2
#
#
# --- Analyzing Goal 91 in Group D: On date 1994-06-30 00:00:00, Minute 90 (Player Team: Bulgaria, Home: Argentina, Away: Bulgaria, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Argentina']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                      1
# 57  South Korea             2                 0                     -1
# 59    Argentina             4                 0                      3
# 65        Italy             3                 1                      0
# 67      Belgium             4                 0                      1
#
#     total_goals_scored
# 47                   5
# 54                   7
# 57                   4
# 59                   6
# 65                   2
# 67                   2
#
#
# --- Analyzing Goal 92 in Group D: On date 1994-06-30 00:00:00, Minute 90 (Player Team: Nigeria, Home: Greece, Away: Nigeria, Own Goal: 0) ---
# Top 4 third-placed teams after this goal: ['Switzerland', 'Russia', 'South Korea', 'Argentina']
# Third-placed teams DataFrame after this goal:
#            team  total_points  last_game_points  total_goal_difference  \
# 47  Switzerland             3                 0                      1
# 54       Russia             3                 3                      1
# 57  South Korea             2                 0                     -1
# 59    Argentina             4                 0                      3
# 65        Italy             3                 1                      0
# 67      Belgium             4                 0                      1
#
#     total_goals_scored
# 47                   5
# 54                   7
# 57                   4
# 59                   6
# 65                   2
# 67                   2
#                    team  year  third_place_count  top4_third_place_count
# 0                 Italy  1986                  5                       5
# 1               Belgium  1986                 28                      28
# 2               Hungary  1986                 32                      32
# 3      Northern Ireland  1986                 31                      31
# 4               Uruguay  1986                 32                       0
# 5               England  1986                 12                       0
# 6              Bulgaria  1986                 27                      27
# 7              Portugal  1986                 19                       0
# 8                Poland  1986                  1                       0
# 9              Paraguay  1986                  4                       4
# 10              Algeria  1986                  1                       1
# 11              Austria  1990                 29                      29
# 12            Argentina  1990                 27                      27
# 13           Costa Rica  1990                 19                      19
# 14           Yugoslavia  1990                  6                       6
# 15              Uruguay  1990                 29                       0
# 16          Netherlands  1990                 22                       0
# 17         Soviet Union  1990                  2                       2
# 18             Colombia  1990                 23                      23
# 19               Sweden  1990                  1                       1
# 20             Scotland  1990                  9                       9
# 21              England  1990                  4                       0
# 22                Egypt  1990                  1                       0
# 23  Republic of Ireland  1990                  2                       0
# 24        United States  1994                  1                       1
# 25             Cameroon  1994                 12                      12
# 26          South Korea  1994                 31                      31
# 27             Bulgaria  1994                 28                      28
# 28                Italy  1994                 30                       0
# 29          Netherlands  1994                 25                       0
# 30          Switzerland  1994                 30                      30
# 31               Russia  1994                 19                      19
# 32               Norway  1994                  1                       0
# 33              Belgium  1994                  6                       0
# 34            Argentina  1994                  3                       3

# %%
# Count the number of observations where the year is 1986
count_1986 = goals_last_day_sorted[goals_last_day_sorted['year'] == 1986].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 1986: {count_1986}")

# Count the number of observations where the year is 1990
count_1990 = goals_last_day_sorted[goals_last_day_sorted['year'] == 1990].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 1990: {count_1990}")

# Count the number of observations where the year is 1994
count_1994 = goals_last_day_sorted[goals_last_day_sorted['year'] == 1994].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 1994: {count_1994}")
# Out:
# Number of observations in goals_last_day_sorted for the year 1986: 32
# Number of observations in goals_last_day_sorted for the year 1990: 29
# Number of observations in goals_last_day_sorted for the year 1994: 31
