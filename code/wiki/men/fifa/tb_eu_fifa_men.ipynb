# %% [markdown]
# # Libraries

# %%
import pandas as pd
from getpass import getuser
from collections import defaultdict
from datetime import datetime, timedelta

# %% [markdown]
# # Load and inspect dataset

# %%
# Get the current user's name
user = getuser()

# Construct the path using the user's name
function_path = f"C:/Users/{user}/Documents/GitHub/tiebreak_wc/code/wiki/functions_fifa.ipynb"

# Run the notebook
# %run $function_path

# %%
# Path to the dataset
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\eu_goals_men.xlsx'

# Read the dataset with a different encoding
df = pd.read_excel(data_path)

# Now, filter the data for tournaments after 1984
df = df[df['year'] >= 1984]

display(df.head())
# Out:
#       stage  year   time home_team   away_team score           stadium_name  \
# 93  Group 1  1984  20:30    France     Denmark   1–0       Parc des Princes
# 94  Group 1  1984  20:30   Belgium  Yugoslavia   2–0   Stade Félix-Bollaert
# 95  Group 1  1984  20:30   Belgium  Yugoslavia   2–0   Stade Félix-Bollaert
# 96  Group 1  1984  17:15    France     Belgium   5–0  Stade de la Beaujoire
# 97  Group 1  1984  17:15    France     Belgium   5–0  Stade de la Beaujoire
#
#    stadium_city  stadium_attendance      referee_name  ... goal_minute  \
# 93        Paris               47570       Volker Roth  ...          78
# 94         Lens               41525  Erik Fredriksson  ...          28
# 95         Lens               41525  Erik Fredriksson  ...          45
# 96       Nantes               51359     Bob Valentine  ...           4
# 97       Nantes               51359     Bob Valentine  ...          74
#
#    extra_time goals_home  goals_away  own_goal  penalty  goal_minute_et  \
# 93          0          1           0         0        0               0
# 94          0          2           0         0        0               0
# 95          0          2           0         0        0               0
# 96          0          5           0         0        0               0
# 97          0          5           0         0        1               0
#
#     goal_et  short_date     long_date
# 93        0  1984-06-12  12 June 1984
# 94        0  1984-06-13  13 June 1984
# 95        0  1984-06-13  13 June 1984
# 96        0  1984-06-16  16 June 1984
# 97        0  1984-06-16  16 June 1984
#
# [5 rows x 23 columns]

# %% [markdown]
# # Clean, transfrom, create variables

# %% [markdown]
# ## time

# %%
# Step 1: Clean time variable by removing any letters (e.g., EEST, PST) if they exist
df['time_cleaned'] = df['time'].str.replace(r'[A-Za-z]+', '', regex=True).str.strip()

# Step 2: Split time where there are parentheses into local time and UTC offset
df['local_time'] = df['time_cleaned'].str.extract(r'(\d{2}:\d{2})')  # extract the part before parentheses
df['utc_time_offset'] = df['time_cleaned'].str.extract(r'\((.*?)\)')  # extract the part inside parentheses

# %% [markdown]
# ## date

# %%
# Step 1: Remove any commas before the year in 'long_date'
df['long_date'] = df['long_date'].str.replace(r',\s*(\d{4})', r' \1', regex=True)

# Step 2: Convert 'long_date' to 'short_date' where 'short_date' is missing
df['short_date'] = df['short_date'].fillna(pd.to_datetime(df['long_date'], errors='coerce').dt.strftime('%Y-%m-%d'))

# %% [markdown]
# # Extract relevant columns

# %%
# Filter out the knockout stages
df = df[~df['stage'].isin(['Quarter-finals', 'Round of 16', 'Semi-finals', 'Final'])]

# Extract relevant columns for goal events and match results
goals_df = df[['year', 'stage', 'home_team', 'away_team', 'scorer_nationality', 'goal_minute', 'short_date','local_time', 'score']]

# Remove duplicates
goals_df = goals_df.drop_duplicates()

display(goals_df.head())
# Out:
#     year    stage home_team   away_team scorer_nationality  goal_minute  \
# 93  1984  Group 1    France     Denmark             France           78
# 94  1984  Group 1   Belgium  Yugoslavia            Belgium           28
# 95  1984  Group 1   Belgium  Yugoslavia            Belgium           45
# 96  1984  Group 1    France     Belgium             France            4
# 97  1984  Group 1    France     Belgium             France           74
#
#     short_date local_time score
# 93  1984-06-12      20:30   1–0
# 94  1984-06-13      20:30   2–0
# 95  1984-06-13      20:30   2–0
# 96  1984-06-16      17:15   5–0
# 97  1984-06-16      17:15   5–0

# %% [markdown]
# # team counts

# %%
# Calculate the number of unique teams per stage and year using home_team and away_team
team_counts = (
    df.groupby(['year', 'stage'])
    .apply(lambda x: pd.concat([x['home_team'], x['away_team']]).unique())
)

# Convert the resulting series to a DataFrame
team_counts = team_counts.reset_index()  # Reset index without 'name' argument
team_counts = team_counts.rename(columns={0: 'team_list'})  # Rename the column appropriately

# Convert team list into counts
team_counts['team_count'] = team_counts['team_list'].apply(len)

# Filter stages where the number of teams is not equal to 4
invalid_groups = team_counts[team_counts['team_count'] != 4]

# Display the invalid groups
display(invalid_groups)
# Out:
# Empty DataFrame
# Columns: [year, stage, team_list, team_count]
# Index: []

# %% [markdown]
# # Recreate Leauge Table after first two matchdays

# %%
# Assuming goals_df is your original dataset
agg_goals_before_last_day, goals_last_day_sorted = process_goals_data(goals_df)

# %%
home_games, away_games = aggregate_home_away_points(agg_goals_before_last_day)

# %%
# Filter for year == 2022 and stage == 'Group E'
home1992 = home_games[(home_games['year'] == 1992) & (home_games['stage'] == 'Group 1')]
home1992
# Out:
#     year    stage home_team  goals_scored  goals_conceded  points_home  \
# 12  1992  Group 1    Sweden             2               1            3
#
#     match_count_home
# 12                 2

# %%
# Filter for year == 2022 and stage == 'Group E'
away1992 = away_games[(away_games['year'] == 1992) & (away_games['stage'] == 'Group 1')]
away1992
# Out:
#     year    stage away_team  goals_scored  goals_conceded  points_away  \
# 11  1992  Group 1   Denmark             0               1            0
# 12  1992  Group 1    France             1               1            1
#
#     match_count_away
# 11                 1
# 12                 1

# %% [markdown]
# ## aggregate data after first two match days

# %%
# Applying the fifa_before_last function to the mock data
all_games_before_last = fifa_before_last(home_games, away_games, agg_goals_before_last_day, team_counts)

# %%
# Group by 'year' and 'stage' and calculate unique teams for each group
unique_teams_per_stage = (
    all_games_before_last.groupby(['year', 'stage'])['team']
    .apply(lambda x: x.unique())
    .reset_index()
    .rename(columns={'team': 'unique_teams'})
)

# Calculate the number of unique teams in each group
unique_teams_per_stage['team_count'] = unique_teams_per_stage['unique_teams'].apply(len)

# Filter rows where the number of unique teams is not 4
invalid_groups = unique_teams_per_stage[unique_teams_per_stage['team_count'] != 4]

# Display the invalid groups
display(invalid_groups)
# Out:
# Empty DataFrame
# Columns: [year, stage, unique_teams, team_count]
# Index: []

# %%
# Filtering all_games_before_last for the year 2022 and stage 'Group E'
group1992 = all_games_before_last[
    (all_games_before_last['year'] == 1992) & 
    (all_games_before_last['stage'] == 'Group 1')
]

display(group1992)
# Out:
#     year    stage     team  goals_scored  goals_conceded  points  \
# 16  1992  Group 1   Sweden             2               1       3
# 17  1992  Group 1   France             1               1       2
# 18  1992  Group 1  England             0               0       2
# 19  1992  Group 1  Denmark             0               1       1
#
#     goals_difference  total_matches tiebreaker  standing
# 16                 1              2    no need         1
# 17                 0              2    no need         2
# 18                 0              2    no need         3
# 19                -1              2    no need         4

# %% [markdown]
# # Recreate league table after last match day

# %%
# Initialize an empty list to store the results for each pair
all_results = []

# Get unique pairs of year and group_name
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    group_name = row['stage']
    
    # Apply the function to the current pair
    result = fifa_final_wc(year, group_name, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_results.append(result)

# Concatenate all the results into a single DataFrame
changes_df_wc = pd.concat(all_results)

# Keep only the specified columns
changes_df_wc = changes_df_wc[['year', 'stage', 'team', '1st', '2nd', '3rd', '4th', 'changes']]

# Display the final DataFrame
display(changes_df_wc)
# Out:
# === Initial Standings for Year 1984, Group Group 1 Before Last Match Goals ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#     France             4                   6                     0                      6                        4                          1
#    Denmark             2                   5                     1                      4                        2                          2
#    Belgium             2                   2                     5                     -3                        2                          3
# Yugoslavia             0                   0                     7                     -7                        0                          4
#
# ====================================================
#
# Analyzing Group 1, year 1984, goal: 26 minute, Player team: Belgium, Home: Denmark, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             5                   6                     0                      6                 1                   1        1    1    0    0    0 False         0
#    Belgium             4                   3                     5                     -2                 2                   2        2    0    1    1    0 False         0
#    Denmark             2                   5                     2                      3                 0                   3        2    0    1    1    0 False         0
# Yugoslavia             1                   0                     7                     -7                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 1, year 1984, goal: 32 minute, Player team: Yugoslavia, Home: France, Away: Yugoslavia
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             4                   6                     1                      5                 0                   1        1    1    0    0    0 False         0
#    Belgium             4                   3                     5                     -2                 2                   2        2    0    1    1    0 False         0
#    Denmark             2                   5                     2                      3                 0                   3        2    0    1    1    0 False         0
# Yugoslavia             2                   1                     7                     -6                 2                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 1, year 1984, goal: 39 minute, Player team: Belgium, Home: Denmark, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             4                   6                     1                      5                 0                   1        1    1    0    0    0 False         0
#    Belgium             4                   4                     5                     -1                 2                   2        2    0    1    1    0 False         0
#    Denmark             2                   5                     3                      2                 0                   3        2    0    1    1    0 False         0
# Yugoslavia             2                   1                     7                     -6                 2                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 1, year 1984, goal: 41 minute, Player team: Denmark, Home: Denmark, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             4                   6                     1                      5                 0                   1        1    1    0    0    0 False         0
#    Belgium             4                   4                     6                     -2                 2                   2        2    0    1    1    0 False         0
#    Denmark             2                   6                     3                      3                 0                   3        2    0    1    1    0 False         0
# Yugoslavia             2                   1                     7                     -6                 2                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 1, year 1984, goal: 59 minute, Player team: France, Home: France, Away: Yugoslavia
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             5                   7                     1                      6                 1                   1        1    1    0    0    0 False         0
#    Belgium             4                   4                     6                     -2                 2                   2        2    0    1    1    0 False         0
#    Denmark             2                   6                     3                      3                 0                   3        2    0    1    1    0 False         0
# Yugoslavia             1                   1                     8                     -7                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 1, year 1984, goal: 60 minute, Player team: Denmark, Home: Denmark, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             5                   7                     1                      6                 1                   1        1    1    0    0    0 False         0
#    Denmark             3                   7                     3                      4                 1                   2        3    0    2    1    0 False         0
#    Belgium             3                   4                     7                     -3                 1                   3        3    0    1    2    0 False         0
# Yugoslavia             1                   1                     8                     -7                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 1, year 1984, goal: 62 minute, Player team: France, Home: France, Away: Yugoslavia
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             6                   8                     1                      7                 2                   1        1    1    0    0    0 False         0
#    Denmark             3                   7                     3                      4                 1                   2        3    0    2    1    0 False         0
#    Belgium             3                   4                     7                     -3                 1                   3        3    0    1    2    0 False         0
# Yugoslavia             0                   1                     9                     -8                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 1, year 1984, goal: 77 minute, Player team: France, Home: France, Away: Yugoslavia
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             6                   9                     1                      8                 2                   1        1    1    0    0    0 False         0
#    Denmark             3                   7                     3                      4                 1                   2        3    0    2    1    0 False         0
#    Belgium             3                   4                     7                     -3                 1                   3        3    0    1    2    0 False         0
# Yugoslavia             0                   1                    10                     -9                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 1, year 1984, goal: 84 minute, Player team: Yugoslavia, Home: France, Away: Yugoslavia
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             6                   9                     2                      7                 2                   1        1    1    0    0    0 False         0
#    Denmark             3                   7                     3                      4                 1                   2        3    0    2    1    0 False         0
#    Belgium             3                   4                     7                     -3                 1                   3        3    0    1    2    0 False         0
# Yugoslavia             0                   2                    10                     -8                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 1, year 1984, goal: 84 minute, Player team: Denmark, Home: Denmark, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#       team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     France             6                   9                     2                      7                 2                   1        1    1    0    0    0 False         0
#    Denmark             4                   8                     3                      5                 2                   2        3    0    2    1    0 False         0
#    Belgium             2                   4                     8                     -4                 0                   3        3    0    1    2    0 False         0
# Yugoslavia             0                   2                    10                     -8                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1984, Group Group 2 Before Last Match Goals ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# West Germany             3                   2                     1                      1                        3                          1
#        Spain             2                   2                     2                      0                        2                          2
#     Portugal             2                   1                     1                      0                        2                          3
#      Romania             1                   2                     3                     -1                        1                          4
#
# ====================================================
#
# Analyzing Group 2, year 1984, goal: 81 minute, Player team: Portugal, Home: Portugal, Away: Romania
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# West Germany             4                   2                     1                      1                 1                   1        1    1    0    0    0  True         0
#     Portugal             4                   2                     1                      1                 2                   2        2    0    1    1    0  True         0
#        Spain             3                   2                     2                      0                 1                   3        2    0    1    1    0 False         0
#      Romania             1                   2                     4                     -2                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 2, year 1984, goal: 90 minute, Player team: Spain, Home: West Germany, Away: Spain
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#        Spain             4                   3                     2                      1                 2                   1        3    1    1    1    0 False         0
#     Portugal             4                   2                     1                      1                 2                   2        2    0    1    1    0 False         0
# West Germany             3                   2                     2                      0                 0                   3        2    1    0    1    0 False         0
#      Romania             1                   2                     4                     -2                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1988, Group Group 1 Before Last Match Goals ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# West Germany             3                   3                     1                      2                        3                          1
#        Italy             3                   2                     1                      1                        3                          2
#        Spain             2                   3                     3                      0                        2                          3
#      Denmark             0                   2                     5                     -3                        0                          4
#
# ====================================================
#
# Analyzing Group 1, year 1988, goal: 29 minute, Player team: West Germany, Home: West Germany, Away: Spain
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# West Germany             5                   4                     1                      3                 2                   1        1    1    0    0    0 False         0
#        Italy             4                   2                     1                      1                 1                   2        1    0    1    0    0 False         0
#        Spain             2                   3                     4                     -1                 0                   3        1    0    0    1    0 False         0
#      Denmark             1                   2                     5                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group 1, year 1988, goal: 51 minute, Player team: West Germany, Home: West Germany, Away: Spain
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# West Germany             5                   5                     1                      4                 2                   1        1    1    0    0    0 False         0
#        Italy             4                   2                     1                      1                 1                   2        1    0    1    0    0 False         0
#        Spain             2                   3                     5                     -2                 0                   3        1    0    0    1    0 False         0
#      Denmark             1                   2                     5                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group 1, year 1988, goal: 67 minute, Player team: Italy, Home: Italy, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# West Germany             5                   5                     1                      4                 2                   1        1    1    0    0    0 False         0
#        Italy             5                   3                     1                      2                 2                   2        1    0    1    0    0 False         0
#        Spain             2                   3                     5                     -2                 0                   3        1    0    0    1    0 False         0
#      Denmark             0                   2                     6                     -4                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group 1, year 1988, goal: 87 minute, Player team: Italy, Home: Italy, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# West Germany             5                   5                     1                      4                 2                   1        1    1    0    0    0 False         0
#        Italy             5                   4                     1                      3                 2                   2        1    0    1    0    0 False         0
#        Spain             2                   3                     5                     -2                 0                   3        1    0    0    1    0 False         0
#      Denmark             0                   2                     7                     -5                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1988, Group Group 2 Before Last Match Goals ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# Republic of Ireland             3                   2                     1                      1                        3                          1
#        Soviet Union             3                   2                     1                      1                        3                          2
#         Netherlands             2                   3                     2                      1                        2                          3
#             England             0                   1                     4                     -3                        0                          4
#
# ====================================================
#
# Analyzing Group 2, year 1988, goal: 3 minute, Player team: Soviet Union, Home: England, Away: Soviet Union
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#        Soviet Union             5                   3                     1                      2                 2                   1        2    1    1    0    0 False         0
# Republic of Ireland             4                   2                     1                      1                 1                   2        2    1    1    0    0 False         0
#         Netherlands             3                   3                     2                      1                 1                   3        2    0    0    2    0 False         0
#             England             0                   1                     5                     -4                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 2, year 1988, goal: 16 minute, Player team: England, Home: England, Away: Soviet Union
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#        Soviet Union             4                   3                     2                      1                 1                   1        2    1    1    0    0 False         0
# Republic of Ireland             4                   2                     1                      1                 1                   2        2    1    1    0    0 False         0
#         Netherlands             3                   3                     2                      1                 1                   3        2    0    0    2    0 False         0
#             England             1                   2                     5                     -3                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 2, year 1988, goal: 28 minute, Player team: Soviet Union, Home: England, Away: Soviet Union
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#        Soviet Union             5                   4                     2                      2                 2                   1        2    1    1    0    0 False         0
# Republic of Ireland             4                   2                     1                      1                 1                   2        2    1    1    0    0 False         0
#         Netherlands             3                   3                     2                      1                 1                   3        2    0    0    2    0 False         0
#             England             0                   2                     6                     -4                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 2, year 1988, goal: 73 minute, Player team: Soviet Union, Home: England, Away: Soviet Union
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#        Soviet Union             5                   5                     2                      3                 2                   1        2    1    1    0    0 False         0
# Republic of Ireland             4                   2                     1                      1                 1                   2        2    1    1    0    0 False         0
#         Netherlands             3                   3                     2                      1                 1                   3        2    0    0    2    0 False         0
#             England             0                   2                     7                     -5                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 2, year 1988, goal: 82 minute, Player team: Netherlands, Home: Republic of Ireland, Away: Netherlands
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#        Soviet Union             5                   5                     2                      3                 2                   1        2    1    1    0    0 False         0
#         Netherlands             4                   4                     2                      2                 2                   2        3    0    1    2    0 False         0
# Republic of Ireland             3                   2                     2                      0                 0                   3        3    1    1    1    0 False         0
#             England             0                   2                     7                     -5                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1992, Group Group 1 Before Last Match Goals ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#  Sweden             3                   2                     1                      1                        3                          1
#  France             2                   1                     1                      0                        2                          2
# England             2                   0                     0                      0                        2                          3
# Denmark             1                   0                     1                     -1                        1                          4
#
# ====================================================
#
# Analyzing Group 1, year 1992, goal: 4 minute, Player team: England, Home: Sweden, Away: England
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# England             4                   1                     0                      1                 2                   1        2    1    0    1    0 False         0
#  Sweden             3                   2                     2                      0                 0                   2        2    1    1    0    0 False         0
#  France             3                   1                     1                      0                 1                   3        2    0    1    1    0 False         0
# Denmark             2                   0                     1                     -1                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 1, year 1992, goal: 8 minute, Player team: Denmark, Home: France, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# England             4                   1                     0                      1                 2                   1        2    1    0    1    0 False         0
#  Sweden             3                   2                     2                      0                 0                   2        2    1    1    0    0 False         0
# Denmark             3                   1                     1                      0                 2                   3        3    0    0    1    2 False         0
#  France             2                   1                     2                     -1                 0                   4        3    0    1    1    1 False         0
#
# ========================================
#
# Analyzing Group 1, year 1992, goal: 51 minute, Player team: Sweden, Home: Sweden, Away: England
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             4                   3                     2                      1                 1                   1        3    2    1    0    0 False         0
# England             3                   1                     1                      0                 1                   2        3    1    1    1    0  True         0
# Denmark             3                   1                     1                      0                 2                   3        3    0    0    1    2  True         0
#  France             2                   1                     2                     -1                 0                   4        3    0    1    1    1 False         0
#
# ========================================
#
# Analyzing Group 1, year 1992, goal: 60 minute, Player team: France, Home: France, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             4                   3                     2                      1                 1                   1        3    2    1    0    0 False         0
#  France             3                   2                     2                      0                 1                   2        4    0    2    1    1 False         0
# England             3                   1                     1                      0                 1                   3        4    1    1    2    0 False         0
# Denmark             2                   1                     2                     -1                 1                   4        4    0    0    1    3 False         0
#
# ========================================
#
# Analyzing Group 1, year 1992, goal: 78 minute, Player team: Denmark, Home: France, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             4                   3                     2                      1                 1                   1        3    2    1    0    0 False         0
# Denmark             3                   2                     2                      0                 2                   2        5    0    1    1    3 False         0
# England             3                   1                     1                      0                 1                   3        4    1    1    2    0 False         0
#  France             2                   2                     3                     -1                 0                   4        5    0    2    1    2 False         0
#
# ========================================
#
# Analyzing Group 1, year 1992, goal: 82 minute, Player team: Sweden, Home: Sweden, Away: England
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             5                   4                     2                      2                 2                   1        3    2    1    0    0 False         0
# Denmark             3                   2                     2                      0                 2                   2        5    0    1    1    3 False         0
#  France             2                   2                     3                     -1                 0                   3        6    0    2    2    2 False         0
# England             2                   1                     2                     -1                 0                   4        5    1    1    2    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1992, Group Group 2 Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#     Germany             3                   3                     1                      2                        3                          1
# Netherlands             3                   1                     0                      1                        3                          2
#         CIS             2                   1                     1                      0                        2                          3
#    Scotland             0                   0                     3                     -3                        0                          4
#
# ====================================================
#
# Analyzing Group 2, year 1992, goal: 4 minute, Player team: Netherlands, Home: Netherlands, Away: Germany
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   2                     0                      2                 2                   1        2    1    1    0    0 False         0
#     Germany             3                   3                     2                      1                 0                   2        2    1    1    0    0 False         0
#         CIS             3                   1                     1                      0                 1                   3        2    0    0    2    0 False         0
#    Scotland             1                   0                     3                     -3                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 2, year 1992, goal: 7 minute, Player team: Scotland, Home: Scotland, Away: CIS
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   2                     0                      2                 2                   1        2    1    1    0    0 False         0
#     Germany             3                   3                     2                      1                 0                   2        2    1    1    0    0 False         0
#         CIS             2                   1                     2                     -1                 0                   3        2    0    0    2    0 False         0
#    Scotland             2                   1                     3                     -2                 2                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 2, year 1992, goal: 15 minute, Player team: Netherlands, Home: Netherlands, Away: Germany
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   3                     0                      3                 2                   1        2    1    1    0    0 False         0
#     Germany             3                   3                     3                      0                 0                   2        2    1    1    0    0 False         0
#         CIS             2                   1                     2                     -1                 0                   3        2    0    0    2    0 False         0
#    Scotland             2                   1                     3                     -2                 2                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group 2, year 1992, goal: 16 minute, Player team: Scotland, Home: Scotland, Away: CIS
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   3                     0                      3                 2                   1        2    1    1    0    0 False         0
#     Germany             3                   3                     3                      0                 0                   2        2    1    1    0    0 False         0
#    Scotland             2                   2                     3                     -1                 2                   3        3    0    0    1    2 False         0
#         CIS             2                   1                     3                     -2                 0                   4        3    0    0    2    1 False         0
#
# ========================================
#
# Analyzing Group 2, year 1992, goal: 53 minute, Player team: Germany, Home: Netherlands, Away: Germany
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   3                     1                      2                 2                   1        2    1    1    0    0 False         0
#     Germany             3                   4                     3                      1                 0                   2        2    1    1    0    0 False         0
#    Scotland             2                   2                     3                     -1                 2                   3        3    0    0    1    2 False         0
#         CIS             2                   1                     3                     -2                 0                   4        3    0    0    2    1 False         0
#
# ========================================
#
# Analyzing Group 2, year 1992, goal: 72 minute, Player team: Netherlands, Home: Netherlands, Away: Germany
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   4                     1                      3                 2                   1        2    1    1    0    0 False         0
#     Germany             3                   4                     4                      0                 0                   2        2    1    1    0    0 False         0
#    Scotland             2                   2                     3                     -1                 2                   3        3    0    0    1    2 False         0
#         CIS             2                   1                     3                     -2                 0                   4        3    0    0    2    1 False         0
#
# ========================================
#
# Analyzing Group 2, year 1992, goal: 84 minute, Player team: Scotland, Home: Scotland, Away: CIS
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   4                     1                      3                 2                   1        2    1    1    0    0 False         0
#     Germany             3                   4                     4                      0                 0                   2        2    1    1    0    0 False         0
#    Scotland             2                   3                     3                      0                 2                   3        3    0    0    1    2 False         0
#         CIS             2                   1                     4                     -3                 0                   4        3    0    0    2    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1996, Group Group A Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#     England             4                   3                     1                      2                        4                          1
# Netherlands             4                   2                     0                      2                        4                          2
# Switzerland             1                   1                     3                     -2                        1                          3
#    Scotland             1                   0                     2                     -2                        1                          4
#
# ====================================================
#
# Analyzing Group A, year 1996, goal: 23 minute, Player team: England, Home: Netherlands, Away: England
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     England             7                   4                     1                      3                 3                   1        1    1    0    0    0 False         0
# Netherlands             4                   2                     1                      1                 0                   2        1    0    1    0    0 False         0
# Switzerland             2                   1                     3                     -2                 1                   3        1    0    0    1    0 False         0
#    Scotland             2                   0                     2                     -2                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1996, goal: 36 minute, Player team: Scotland, Home: Scotland, Away: Switzerland
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     England             7                   4                     1                      3                 3                   1        1    1    0    0    0 False         0
# Netherlands             4                   2                     1                      1                 0                   2        1    0    1    0    0 False         0
#    Scotland             4                   1                     2                     -1                 3                   3        2    0    0    1    1 False         0
# Switzerland             1                   1                     4                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1996, goal: 51 minute, Player team: England, Home: Netherlands, Away: England
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     England             7                   5                     1                      4                 3                   1        1    1    0    0    0 False         0
# Netherlands             4                   2                     2                      0                 0                   2        1    0    1    0    0 False         0
#    Scotland             4                   1                     2                     -1                 3                   3        2    0    0    1    1 False         0
# Switzerland             1                   1                     4                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1996, goal: 57 minute, Player team: England, Home: Netherlands, Away: England
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     England             7                   6                     1                      5                 3                   1        1    1    0    0    0 False         0
# Netherlands             4                   2                     3                     -1                 0                   2        1    0    1    0    0 False         0
#    Scotland             4                   1                     2                     -1                 3                   3        2    0    0    1    1 False         0
# Switzerland             1                   1                     4                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1996, goal: 62 minute, Player team: England, Home: Netherlands, Away: England
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     England             7                   7                     1                      6                 3                   1        1    1    0    0    0 False         0
#    Scotland             4                   1                     2                     -1                 3                   2        3    0    1    1    1 False         0
# Netherlands             4                   2                     4                     -2                 0                   3        2    0    1    1    0 False         0
# Switzerland             1                   1                     4                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1996, goal: 78 minute, Player team: Netherlands, Home: Netherlands, Away: England
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     England             7                   7                     2                      5                 3                   1        1    1    0    0    0 False         0
# Netherlands             4                   3                     4                     -1                 0                   2        3    0    2    1    0 False         0
# ...
# Netherlands             5                   3                     2                      1                 1                   1        3    2    0    1    0 False         0
#      France             5                   1                     0                      1                 1                   2        2    0    2    0    0 False         0
#     Austria             4                   4                     3                      1                 1                   3        3    1    0    2    0 False         0
#      Poland             1                   2                     5                     -3                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group D, year 2024, goal: 56 minute, Player team: France, Home: France, Away: Poland
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      France             7                   2                     0                      2                 3                   1        3    1    2    0    0 False         0
# Netherlands             5                   3                     2                      1                 1                   2        4    2    1    1    0 False         0
#     Austria             4                   4                     3                      1                 1                   3        3    1    0    2    0 False         0
#      Poland             0                   2                     6                     -4                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group D, year 2024, goal: 59 minute, Player team: Austria, Home: Netherlands, Away: Austria
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      France             7                   2                     0                      2                 3                   1        3    1    2    0    0 False         0
#     Austria             6                   5                     3                      2                 3                   2        4    1    1    2    0 False         0
# Netherlands             4                   3                     3                      0                 0                   3        5    2    1    2    0 False         0
#      Poland             0                   2                     6                     -4                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group D, year 2024, goal: 75 minute, Player team: Netherlands, Home: Netherlands, Away: Austria
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      France             7                   2                     0                      2                 3                   1        3    1    2    0    0 False         0
# Netherlands             5                   4                     3                      1                 1                   2        6    2    2    2    0 False         0
#     Austria             4                   5                     4                      1                 1                   3        5    1    1    3    0 False         0
#      Poland             0                   2                     6                     -4                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group D, year 2024, goal: 79 minute, Player team: Poland, Home: France, Away: Poland
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             5                   4                     3                      1                 1                   1        7    3    2    2    0 False         0
#      France             5                   2                     1                      1                 1                   2        4    1    3    0    0 False         0
#     Austria             4                   5                     4                      1                 1                   3        5    1    1    3    0 False         0
#      Poland             1                   3                     6                     -3                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group D, year 2024, goal: 80 minute, Player team: Austria, Home: Netherlands, Away: Austria
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     Austria             6                   6                     4                      2                 3                   1        6    2    1    3    0 False         0
#      France             5                   2                     1                      1                 1                   2        4    1    3    0    0 False         0
# Netherlands             4                   4                     4                      0                 0                   3        8    3    2    3    0 False         0
#      Poland             1                   3                     6                     -3                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2024, Group Group E Before Last Match Goals ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#  Romania             3                   3                     2                      1                        3                          1
#  Belgium             3                   2                     1                      1                        3                          2
# Slovakia             3                   2                     2                      0                        3                          3
#  Ukraine             3                   2                     4                     -2                        3                          4
#
# ====================================================
#
# Analyzing Group E, year 2024, goal: 24 minute, Player team: Slovakia, Home: Slovakia, Away: Romania
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Slovakia             6                   3                     2                      1                 3                   1        2    1    0    1    0 False         0
#  Belgium             4                   2                     1                      1                 1                   2        2    0    2    0    0 False         0
#  Ukraine             4                   2                     4                     -2                 1                   3        2    0    0    1    1 False         0
#  Romania             3                   3                     3                      0                 0                   4        2    1    0    0    1 False         0
#
# ========================================
#
# Analyzing Group E, year 2024, goal: 37 minute, Player team: Romania, Home: Slovakia, Away: Romania
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Romania             4                   4                     3                      1                 1                   1        3    2    0    0    1 False         0
#  Belgium             4                   2                     1                      1                 1                   2        2    0    2    0    0 False         0
# Slovakia             4                   3                     3                      0                 1                   3        3    1    0    2    0 False         0
#  Ukraine             4                   2                     4                     -2                 1                   4        3    0    0    1    2 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2024, Group Group F Before Last Match Goals ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#       Portugal             6                   5                     1                      4                        6                          1
#         Turkey             3                   3                     4                     -1                        3                          2
# Czech Republic             1                   2                     3                     -1                        1                          3
#        Georgia             1                   2                     4                     -2                        1                          4
#
# ====================================================
#
# Analyzing Group F, year 2024, goal: 2 minute, Player team: Georgia, Home: Georgia, Away: Portugal
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#       Portugal             6                   5                     2                      3                 0                   1        1    1    0    0    0 False         0
#         Turkey             4                   3                     4                     -1                 1                   2        1    0    1    0    0  True         1
#        Georgia             4                   3                     4                     -1                 3                   3        2    0    0    1    1  True         0
# Czech Republic             2                   2                     3                     -1                 1                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group F, year 2024, goal: 51 minute, Player team: Turkey, Home: Czech Republic, Away: Turkey
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#       Portugal             6                   5                     2                      3                 0                   1        1    1    0    0    0 False         0
#         Turkey             6                   4                     4                      0                 3                   2        1    0    1    0    0 False         0
#        Georgia             4                   3                     4                     -1                 3                   3        2    0    0    1    1 False         0
# Czech Republic             1                   2                     4                     -2                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group F, year 2024, goal: 57 minute, Player team: Georgia, Home: Georgia, Away: Portugal
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#       Portugal             6                   5                     3                      2                 0                   1        1    1    0    0    0 False         0
#         Turkey             6                   4                     4                      0                 3                   2        1    0    1    0    0 False         0
#        Georgia             4                   4                     4                      0                 3                   3        2    0    0    1    1 False         0
# Czech Republic             1                   2                     4                     -2                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group F, year 2024, goal: 66 minute, Player team: Czech Republic, Home: Czech Republic, Away: Turkey
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#       Portugal             6                   5                     3                      2                 0                   1        1    1    0    0    0 False         0
#        Georgia             4                   4                     4                      0                 3                   2        3    0    1    1    1 False         0
#         Turkey             4                   4                     5                     -1                 1                   3        2    0    1    1    0 False         0
# Czech Republic             2                   3                     4                     -1                 1                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group F, year 2024, goal: 94 minute, Player team: Turkey, Home: Czech Republic, Away: Turkey
#
# === Updated Standings After This Goal ===
#
#           team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#       Portugal             6                   5                     3                      2                 0                   1        1    1    0    0    0 False         0
#         Turkey             6                   5                     5                      0                 3                   2        3    0    2    1    0 False         0
#        Georgia             4                   4                     4                      0                 3                   3        4    0    1    2    1 False         0
# Czech Republic             1                   3                     5                     -2                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#      year    stage            team  1st  2nd  3rd  4th  changes
# 0    1984  Group 1          France    1    0    0    0        1
# 1    1984  Group 1         Denmark    0    2    1    0        3
# 2    1984  Group 1         Belgium    0    1    2    0        3
# 3    1984  Group 1      Yugoslavia    0    0    0    2        2
# 5    1984  Group 2           Spain    1    1    1    0        3
# ..    ...      ...             ...  ...  ...  ...  ...      ...
# 171  2024  Group E         Ukraine    0    0    1    2        3
# 172  2024  Group F        Portugal    1    0    0    0        1
# 173  2024  Group F          Turkey    0    2    1    0        3
# 175  2024  Group F         Georgia    0    1    2    1        4
# 174  2024  Group F  Czech Republic    0    0    1    1        2
#
# [176 rows x 8 columns]

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\eu\tb_eu_fifa_men.xlsx'
changes_df_wc.to_excel(file_path, index=False)

# %% [markdown]
# # group composition tracking

# %%
# Initialize an empty list to store the results for each pair
all_composition_changes = []

# Get unique pairs of year, stage, and men
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    stage = row['stage']
    
    # Apply the function to the current pair
    composition_changes_df = track_composition_changes(year, stage, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_composition_changes.append(composition_changes_df)

# Concatenate all the results into a single DataFrame
final_composition_changes_df = pd.concat(all_composition_changes, ignore_index=True)

# Rename 'player_team' column to 'scorer_team'
final_composition_changes_df.rename(columns={'player_team': 'scorer_nationality'}, inplace=True)

# %%
# Initialize an empty list to store the results for each pair
all_composition_changes = []

# Get unique pairs of year and group_name
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    group_name = row['stage']
    
    # Apply the function to the current pair
    composition_changes_df = track_composition_changes(year, group_name, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_composition_changes.append(composition_changes_df)

# Concatenate all the results into a single DataFrame
final_composition_changes_df = pd.concat(all_composition_changes, ignore_index=True)

# Rename 'player_team' column to 'scorer_team'
final_composition_changes_df.rename(columns={'player_team': 'scorer_nationality'}, inplace=True)

# Display the final DataFrame
display(final_composition_changes_df)
# Out:
#      year    stage  change_num goal_time       home_team away_team  \
# 0    1984  Group 1           0   initial            None      None
# 1    1984  Group 2           0   initial            None      None
# 2    1988  Group 1           0   initial            None      None
# 3    1988  Group 2           0   initial            None      None
# 4    1992  Group 1           0   initial            None      None
# ..    ...      ...         ...       ...             ...       ...
# 96   2024  Group E           1        24        Slovakia   Romania
# 97   2024  Group E           2        37        Slovakia   Romania
# 98   2024  Group F           0   initial            None      None
# 99   2024  Group F           1        66  Czech Republic    Turkey
# 100  2024  Group F           2        94  Czech Republic    Turkey
#
#     scorer_nationality                                     new_top_teams  \
# 0                 None                        [France, Denmark, Belgium]
# 1                 None                   [Spain, West Germany, Portugal]
# 2                 None                      [Spain, Italy, West Germany]
# 3                 None  [Netherlands, Republic of Ireland, Soviet Union]
# 4                 None                         [France, England, Sweden]
# ..                 ...                                               ...
# 96            Slovakia                               [Slovakia, Belgium]
# 97             Romania                                [Romania, Belgium]
# 98                None                                [Turkey, Portugal]
# 99      Czech Republic                               [Georgia, Portugal]
# 100             Turkey                                [Turkey, Portugal]
#
#     third_place_teams_list  top4_third_place                  1st  \
# 0                [Belgium]                 1               France
# 1               [Portugal]                 1         West Germany
# 2                  [Spain]                 1         West Germany
# 3            [Netherlands]                 1  Republic of Ireland
# 4                [England]                 1               Sweden
# ..                     ...               ...                  ...
# 96               [Ukraine]                 1             Slovakia
# 97              [Slovakia]                 1              Romania
# 98        [Czech Republic]                 1             Portugal
# 99                [Turkey]                 1             Portugal
# 100              [Georgia]                 1             Portugal
#
#               2nd             3rd
# 0         Denmark         Belgium
# 1           Spain        Portugal
# 2           Italy           Spain
# 3    Soviet Union     Netherlands
# 4          France         England
# ..            ...             ...
# 96        Belgium         Ukraine
# 97        Belgium        Slovakia
# 98         Turkey  Czech Republic
# 99        Georgia          Turkey
# 100        Turkey         Georgia
#
# [101 rows x 13 columns]

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\eu\standings_eu_fifa_men.xlsx'
final_composition_changes_df.to_excel(file_path, index=False)

# %% [markdown]
# # best four third placed

# %%
# Call the function to get the DataFrame
final_df = best_four_third_placed_eu_men(goals_last_day_sorted, all_games_before_last)

# Define the file path and save to Excel
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\eu\third_teams_eu_fifa_men.xlsx'
final_df.to_excel(file_path, index=False)
# Out:
# --- Processing Year: 2016 ---
#
# --- Processing Year: 2021 ---
#
# --- Processing Year: 2024 ---

# %%
# Count the number of observations where the year is 2016
count_2016 = goals_last_day_sorted[goals_last_day_sorted['year'] == 2016].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 2016: {count_2016}")

# Count the number of observations where the year is 2021
count_2021 = goals_last_day_sorted[goals_last_day_sorted['year'] == 2021].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 2021: {count_2021}")

# Count the number of observations where the year is 2024
count_2024 = goals_last_day_sorted[goals_last_day_sorted['year'] == 2024].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 2024: {count_2024}")
# Out:
# Number of observations in goals_last_day_sorted for the year 2016: 22
# Number of observations in goals_last_day_sorted for the year 2021: 38
# Number of observations in goals_last_day_sorted for the year 2024: 24
