# %% [markdown]
# # Libraries

# %%
import pandas as pd
from getpass import getuser
from collections import defaultdict
from datetime import datetime, timedelta
import re

# %% [markdown]
# # Load and inspect dataset

# %%
# Get the current user's name
user = getuser()

# Construct the path using the user's name
function_path = f"C:/Users/{user}/Documents/GitHub/tiebreak_wc/code/wiki/functions_fifa.ipynb"

# Run the notebook
# %run $function_path

# %%
# Path to the dataset
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\wc_goals_men.xlsx'

# Read the dataset with a different encoding
df = pd.read_excel(data_path)

# Now, filter the data for tournaments after 1984
df = df[df['year'] > 1984]

display(df.head())
# Out:
#      stage  year      time  home_team    away_team score  \
# 0  Group A  1986  12:00CST   Bulgaria        Italy   1–1
# 1  Group A  1986  12:00CST   Bulgaria        Italy   1–1
# 2  Group A  1986  12:00CST  Argentina  South Korea   3–1
# 3  Group A  1986  12:00CST  Argentina  South Korea   3–1
# 4  Group A  1986  12:00CST  Argentina  South Korea   3–1
#
#                      stadium_name stadium_city  stadium_attendance  \
# 0                  Estadio Azteca  Mexico City               96000
# 1                  Estadio Azteca  Mexico City               96000
# 2  Estadio Olímpico Universitario  Mexico City               60000
# 3  Estadio Olímpico Universitario  Mexico City               60000
# 4  Estadio Olímpico Universitario  Mexico City               60000
#
#                  referee_name  ... goal_minute extra_time goals_home  \
# 0            Erik Fredriksson  ...          85          0          1
# 1            Erik Fredriksson  ...          44          0          1
# 2  Victoriano Sánchez Arminio  ...           6          0          3
# 3  Victoriano Sánchez Arminio  ...          46          0          3
# 4  Victoriano Sánchez Arminio  ...          18          0          3
#
#    goals_away  own_goal  penalty  goal_minute_et  goal_et  short_date  \
# 0           1         0        0               0        0         NaN
# 1           1         0        0               0        0         NaN
# 2           1         0        0               0        0         NaN
# 3           1         0        0               0        0         NaN
# 4           1         0        0               0        0         NaN
#
#      long_date
# 0  31 May 1986
# 1  31 May 1986
# 2  2 June 1986
# 3  2 June 1986
# 4  2 June 1986
#
# [5 rows x 23 columns]

# %% [markdown]
# # Clean, transfrom, create variables

# %% [markdown]
# ## time

# %%
# Apply the conversion function
df[['local_time', 'utc_time']] = df.apply(lambda row: pd.Series(convert_time(row)), axis=1)

# %% [markdown]
# ## date

# %%
# Step 1: Remove any commas before the year in 'long_date'
df['long_date'] = df['long_date'].str.replace(r',\s*(\d{4})', r' \1', regex=True)

# Step 2: Convert 'long_date' to 'short_date' where 'short_date' is missing
df['short_date'] = df['short_date'].fillna(pd.to_datetime(df['long_date'], errors='coerce').dt.strftime('%Y-%m-%d'))

# %% [markdown]
# # Extract relevant columns

# %%
# Filter out the knockout stages
df = df[~df['stage'].isin(['Quarter-finals', 'Round of 16', 'Semi-finals', 'Final'])]

# Extract relevant columns for goal events and match results
goals_df = df[['year', 'stage', 'home_team', 'away_team', 'scorer_nationality', 'goal_minute', 'short_date','local_time', 'score']]

# Remove duplicates
goals_df = goals_df.drop_duplicates()

display(goals_df.head())
# Out:
#    year    stage  home_team    away_team scorer_nationality  goal_minute  \
# 0  1986  Group A   Bulgaria        Italy           Bulgaria           85
# 1  1986  Group A   Bulgaria        Italy              Italy           44
# 2  1986  Group A  Argentina  South Korea          Argentina            6
# 3  1986  Group A  Argentina  South Korea          Argentina           46
# 4  1986  Group A  Argentina  South Korea          Argentina           18
#
#    short_date local_time score
# 0  1986-05-31      18:00   1–1
# 1  1986-05-31      18:00   1–1
# 2  1986-06-02      18:00   3–1
# 3  1986-06-02      18:00   3–1
# 4  1986-06-02      18:00   3–1

# %% [markdown]
# # manually insert missing 0-0

# %%
# Define new observations as a list of dictionaries
new_observations = [
    {
        'year': 1986,
        'stage': 'Group E',
        'home_team': 'Scotland',
        'away_team': 'Uruguay',
        'scorer_nationality': 'none',
        'goal_minute': 0,
        'short_date': '1986-06-13',
        'local_time': '12:00',
        'score': '0-0'
    },
   
    
]

# Convert the new observations into a DataFrame
new_observations_df = pd.DataFrame(new_observations)

# Append the new observations to the existing DataFrame
goals_df = pd.concat([goals_df, new_observations_df], ignore_index=True)

# %% [markdown]
# # Recreate Leauge Table after first two matchdays

# %%
# Assuming goals_df is your original dataset
agg_goals_before_last_day, goals_last_day_sorted = before_last(goals_df)

# %%
home_games, away_games = aggregate_home_away_points(agg_goals_before_last_day)

# %%
# Filter for year == 2022 and stage == 'Group E'
home2022e = home_games[(home_games['year'] == 2022) & (home_games['stage'] == 'Group E')]
home2022e
# Out:
#      year    stage home_team  goals_scored  goals_conceded  points_home  \
# 171  2022  Group E   Germany             1               2            0
# 172  2022  Group E     Japan             0               1            0
# 173  2022  Group E     Spain             8               1            4
#
#      match_count_home
# 171                 1
# 172                 1
# 173                 2

# %%
# Filter for year == 2022 and stage == 'Group E'
away2022e = away_games[(away_games['year'] == 2022) & (away_games['stage'] == 'Group E')]
away2022e
# Out:
#      year    stage   away_team  goals_scored  goals_conceded  points_away  \
# 167  2022  Group E  Costa Rica             1               7            3
# 168  2022  Group E     Germany             1               1            1
# 169  2022  Group E       Japan             2               1            3
#
#      match_count_away
# 167                 2
# 168                 1
# 169                 1

# %% [markdown]
# ## aggregate data after first two match days

# %%
# Applying the fifa_before_last function to the mock data
all_games_before_last = fifa_before_last(home_games, away_games, agg_goals_before_last_day, team_counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 # Applying the fifa_before_last function to the mock data
# ----> 2 all_games_before_last = fifa_before_last(home_games, away_games, agg_goals_before_last_day, team_counts)
#
# NameError: name 'team_counts' is not defined

# %%
# Filtering all_games_before_last for the year 2022 and stage 'Group E'
group2022e = all_games_before_last[
    (all_games_before_last['year'] == 2022) & 
    (all_games_before_last['stage'] == 'Group E')
]

display(group2022e)
# Out:
#      year    stage        team  goals_scored  goals_conceded  points  \
# 234  2022  Group E       Spain             8               1       4
# 235  2022  Group E       Japan             2               2       3
# 236  2022  Group E  Costa Rica             1               7       3
# 237  2022  Group E     Germany             2               3       1
#
#      goals_difference  total_matches tiebreaker  standing
# 234                 7              2    no need         1
# 235                 0              2    no need         2
# 236                -6              2    no need         3
# 237                -1              2    no need         4

# %% [markdown]
# # Recreate league table after last match day

# %%
# Initialize an empty list to store the results for each pair
all_results = []

# Get unique pairs of year and group_name
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    group_name = row['stage']
    
    # Apply the function to the current pair
    result = fifa_final_wc(year, group_name, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_results.append(result)

# Concatenate all the results into a single DataFrame
changes_df_wc = pd.concat(all_results)


# Keep only the specified columns
changes_df_wc = changes_df_wc[['year', 'stage', 'team', '1st', '2nd', '3rd', '4th', 'changes']]

# Display the final DataFrame
display(changes_df_wc)
# Out:
# === Initial Standings for Year 1986, Group Group A Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#   Argentina             3                   4                     2                      2                        3                          1
#    Bulgaria             2                   2                     2                      0                        2                          2
#       Italy             2                   2                     2                      0                        2                          3
# South Korea             1                   2                     4                     -2                        1                          4
#
# ====================================================
#
# Analyzing Group A, year 1986, goal: 4 minute, Player team: Argentina, Home: Argentina, Away: Bulgaria
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   5                     2                      3                 2                   1        1    1    0    0    0 False         0
#       Italy             3                   2                     2                      0                 1                   2        2    0    1    1    0 False         0
#    Bulgaria             2                   2                     3                     -1                 0                   3        2    0    1    1    0 False         0
# South Korea             2                   2                     4                     -2                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group A, year 1986, goal: 17 minute, Player team: Italy, Home: South Korea, Away: Italy
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   5                     2                      3                 2                   1        1    1    0    0    0 False         0
#       Italy             4                   3                     2                      1                 2                   2        2    0    1    1    0 False         0
#    Bulgaria             2                   2                     3                     -1                 0                   3        2    0    1    1    0 False         0
# South Korea             1                   2                     5                     -3                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group A, year 1986, goal: 62 minute, Player team: South Korea, Home: South Korea, Away: Italy
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   5                     2                      3                 2                   1        1    1    0    0    0 False         0
#       Italy             3                   3                     3                      0                 1                   2        2    0    1    1    0 False         0
#    Bulgaria             2                   2                     3                     -1                 0                   3        2    0    1    1    0 False         0
# South Korea             2                   3                     5                     -2                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group A, year 1986, goal: 73 minute, Player team: Italy, Home: South Korea, Away: Italy
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   5                     2                      3                 2                   1        1    1    0    0    0 False         0
#       Italy             4                   4                     3                      1                 2                   2        2    0    1    1    0 False         0
#    Bulgaria             2                   2                     3                     -1                 0                   3        2    0    1    1    0 False         0
# South Korea             1                   3                     6                     -3                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group A, year 1986, goal: 77 minute, Player team: Argentina, Home: Argentina, Away: Bulgaria
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   6                     2                      4                 2                   1        1    1    0    0    0 False         0
#       Italy             4                   4                     3                      1                 2                   2        2    0    1    1    0 False         0
#    Bulgaria             2                   2                     4                     -2                 0                   3        2    0    1    1    0 False         0
# South Korea             1                   3                     6                     -3                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group A, year 1986, goal: 82 minute, Player team: Italy, Home: South Korea, Away: Italy
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   6                     2                      4                 2                   1        1    1    0    0    0 False         0
#       Italy             4                   5                     3                      2                 2                   2        2    0    1    1    0 False         0
#    Bulgaria             2                   2                     4                     -2                 0                   3        2    0    1    1    0 False         0
# South Korea             1                   3                     7                     -4                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group A, year 1986, goal: 83 minute, Player team: South Korea, Home: South Korea, Away: Italy
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Argentina             5                   6                     2                      4                 2                   1        1    1    0    0    0 False         0
#       Italy             4                   5                     4                      1                 2                   2        2    0    1    1    0 False         0
#    Bulgaria             2                   2                     4                     -2                 0                   3        2    0    1    1    0 False         0
# South Korea             1                   4                     7                     -3                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group Group B Before Last Match Goals ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#   Mexico             3                   3                     2                      1                        3                          1
# Paraguay             3                   2                     1                      1                        3                          2
#  Belgium             2                   3                     3                      0                        2                          3
#     Iraq             0                   1                     3                     -2                        0                          4
#
# ====================================================
#
# Analyzing Group B, year 1986, goal: 30 minute, Player team: Belgium, Home: Paraguay, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Belgium             4                   4                     3                      1                 2                   1        2    1    0    1    0 False         0
#   Mexico             4                   3                     2                      1                 1                   2        2    1    1    0    0 False         0
# Paraguay             3                   2                     2                      0                 0                   3        2    0    1    1    0 False         0
#     Iraq             1                   1                     3                     -2                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group B, year 1986, goal: 50 minute, Player team: Paraguay, Home: Paraguay, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Mexico             4                   3                     2                      1                 1                   1        3    2    1    0    0  True         0
# Paraguay             4                   3                     2                      1                 1                   2        3    0    2    1    0  True         0
#  Belgium             3                   4                     4                      0                 1                   3        3    1    0    2    0 False         0
#     Iraq             1                   1                     3                     -2                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group B, year 1986, goal: 54 minute, Player team: Mexico, Home: Iraq, Away: Mexico
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Mexico             5                   4                     2                      2                 2                   1        3    2    1    0    0 False         0
# Paraguay             4                   3                     2                      1                 1                   2        3    0    2    1    0 False         0
#  Belgium             3                   4                     4                      0                 1                   3        3    1    0    2    0 False         0
#     Iraq             0                   1                     4                     -3                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group B, year 1986, goal: 59 minute, Player team: Belgium, Home: Paraguay, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Mexico             5                   4                     2                      2                 2                   1        3    2    1    0    0 False         0
#  Belgium             4                   5                     4                      1                 2                   2        4    1    1    2    0 False         0
# Paraguay             3                   3                     3                      0                 0                   3        4    0    2    2    0 False         0
#     Iraq             0                   1                     4                     -3                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group B, year 1986, goal: 76 minute, Player team: Paraguay, Home: Paraguay, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Mexico             5                   4                     2                      2                 2                   1        3    2    1    0    0 False         0
# Paraguay             4                   4                     3                      1                 1                   2        5    0    3    2    0 False         0
#  Belgium             3                   5                     5                      0                 1                   3        5    1    1    3    0 False         0
#     Iraq             0                   1                     4                     -3                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group Group C Before Last Match Goals ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# Soviet Union             3                   7                     1                      6                        3                          1
#       France             3                   2                     1                      1                        3                          2
#      Hungary             2                   2                     6                     -4                        2                          3
#       Canada             0                   0                     3                     -3                        0                          4
#
# ====================================================
#
# Analyzing Group C, year 1986, goal: 29 minute, Player team: France, Home: Hungary, Away: France
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#       France             5                   3                     1                      2                 2                   1        2    1    1    0    0 False         0
# Soviet Union             4                   7                     1                      6                 1                   2        2    1    1    0    0 False         0
#      Hungary             2                   2                     7                     -5                 0                   3        2    0    0    2    0 False         0
#       Canada             1                   0                     3                     -3                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group C, year 1986, goal: 58 minute, Player team: Soviet Union, Home: Soviet Union, Away: Canada
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Soviet Union             5                   8                     1                      7                 2                   1        3    2    1    0    0 False         0
#       France             5                   3                     1                      2                 2                   2        3    1    2    0    0 False         0
#      Hungary             2                   2                     7                     -5                 0                   3        2    0    0    2    0 False         0
#       Canada             0                   0                     4                     -4                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group C, year 1986, goal: 62 minute, Player team: France, Home: Hungary, Away: France
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Soviet Union             5                   8                     1                      7                 2                   1        3    2    1    0    0 False         0
#       France             5                   4                     1                      3                 2                   2        3    1    2    0    0 False         0
#      Hungary             2                   2                     8                     -6                 0                   3        2    0    0    2    0 False         0
#       Canada             0                   0                     4                     -4                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group C, year 1986, goal: 74 minute, Player team: Soviet Union, Home: Soviet Union, Away: Canada
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Soviet Union             5                   9                     1                      8                 2                   1        3    2    1    0    0 False         0
#       France             5                   4                     1                      3                 2                   2        3    1    2    0    0 False         0
#      Hungary             2                   2                     8                     -6                 0                   3        2    0    0    2    0 False         0
#       Canada             0                   0                     5                     -5                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group C, year 1986, goal: 84 minute, Player team: France, Home: Hungary, Away: France
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Soviet Union             5                   9                     1                      8                 2                   1        3    2    1    0    0 False         0
#       France             5                   5                     1                      4                 2                   2        3    1    2    0    0 False         0
#      Hungary             2                   2                     9                     -7                 0                   3        2    0    0    2    0 False         0
#       Canada             0                   0                     5                     -5                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group Group D Before Last Match Goals ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#           Brazil             4                   2                     0                      2                        4                          1
#            Spain             2                   2                     2                      0                        2                          2
# Northern Ireland             1                   2                     3                     -1                        1                          3
#          Algeria             1                   1                     2                     -1                        1                          4
#
# ====================================================
#
# Analyzing Group D, year 1986, goal: 15 minute, Player team: Brazil, Home: Northern Ireland, Away: Brazil
#
# === Updated Standings After This Goal ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#           Brazil             6                   3                     0                      3                 2                   1        1    1    0    0    0 False         0
#            Spain             3                   2                     2                      0                 1                   2        1    0    1    0    0 False         0
#          Algeria             2                   1                     2                     -1                 1                   3        2    0    0    1    1 False         0
# Northern Ireland             1                   2                     4                     -2                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group D, year 1986, goal: 15 minute, Player team: Spain, Home: Algeria, Away: Spain
#
# === Updated Standings After This Goal ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#           Brazil             6                   3                     0                      3                 2                   1        1    1    0    0    0 False         0
#            Spain             4                   3                     2                      1                 2                   2        1    0    1    0    0 False         0
# Northern Ireland             1                   2                     4                     -2                 0                   3        3    0    0    2    1 False         0
#          Algeria             1                   1                     3                     -2                 0                   4        3    0    0    1    2 False         0
#
# ========================================
#
# Analyzing Group D, year 1986, goal: 42 minute, Player team: Brazil, Home: Northern Ireland, Away: Brazil
#
# === Updated Standings After This Goal ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#           Brazil             6                   4                     0                      4                 2                   1        1    1    0    0    0 False         0
#            Spain             4                   3                     2                      1                 2                   2        1    0    1    0    0 False         0
#          Algeria             1                   1                     3                     -2                 0                   3        4    0    0    2    2 False         0
# Northern Ireland             1                   2                     5                     -3                 0                   4        4    0    0    2    2 False         0
#
# ========================================
#
# Analyzing Group D, year 1986, goal: 68 minute, Player team: Spain, Home: Algeria, Away: Spain
#
# === Updated Standings After This Goal ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#           Brazil             6                   4                     0                      4                 2                   1        1    1    0    0    0 False         0
#            Spain             4                   4                     2                      2                 2                   2        1    0    1    0    0 False         0
# Northern Ireland             1                   2                     5                     -3                 0                   3        5    0    0    3    2 False         0
#          Algeria             1                   1                     4                     -3                 0                   4        5    0    0    2    3 False         0
#
# ========================================
#
# Analyzing Group D, year 1986, goal: 70 minute, Player team: Spain, Home: Algeria, Away: Spain
#
# === Updated Standings After This Goal ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#           Brazil             6                   4                     0                      4                 2                   1        1    1    0    0    0 False         0
#            Spain             4                   5                     2                      3                 2                   2        1    0    1    0    0 False         0
# Northern Ireland             1                   2                     5                     -3                 0                   3        5    0    0    3    2 False         0
#          Algeria             1                   1                     5                     -4                 0                   4        5    0    0    2    3 False         0
#
# ========================================
#
# Analyzing Group D, year 1986, goal: 87 minute, Player team: Brazil, Home: Northern Ireland, Away: Brazil
#
# === Updated Standings After This Goal ===
#
#             team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#           Brazil             6                   5                     0                      5                 2                   1        1    1    0    0    0 False         0
#            Spain             4                   5                     2                      3                 2                   2        1    0    1    0    0 False         0
# Northern Ireland             1                   2                     6                     -4                 0                   3        5    0    0    3    2 False         0
#          Algeria             1                   1                     5                     -4                 0                   4        5    0    0    2    3 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group Group E Before Last Match Goals ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#      Denmark             4                   7                     1                      6                        4                          1
# West Germany             3                   3                     2                      1                        3                          2
#      Uruguay             1                   2                     7                     -5                        1                          3
#     Scotland             0                   1                     3                     -2                        0                          4
#
# ====================================================
#
# Analyzing Group E, year 1986, goal: 43 minute, Player team: Denmark, Home: Denmark, Away: West Germany
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Denmark             6                   8                     1                      7                 2                   1        1    1    0    0    0 False         0
# West Germany             3                   3                     3                      0                 0                   2        1    0    1    0    0 False         0
#      Uruguay             2                   2                     7                     -5                 1                   3        1    0    0    1    0 False         0
#     Scotland             1                   1                     3                     -2                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group E, year 1986, goal: 62 minute, Player team: Denmark, Home: Denmark, Away: West Germany
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Denmark             6                   9                     1                      8                 2                   1        1    1    0    0    0 False         0
# West Germany             3                   3                     4                     -1                 0                   2        1    0    1    0    0 False         0
#      Uruguay             2                   2                     7                     -5                 1                   3        1    0    0    1    0 False         0
#     Scotland             1                   1                     3                     -2                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group Group F Before Last Match Goals ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#   Poland             3                   1                     0                      1                        3                          1
# Portugal             2                   1                     1                      0                        2                          2
#  England             1                   0                     1                     -1                        1                          3
#
# ====================================================
#
# Analyzing Group F, year 1986, goal: 9 minute, Player team: England, Home: England, Away: Poland
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Poland             3                   1                     1                      0                 0                   1        1    1    0    0    0  True         1
# Portugal             3                   1                     1                      0                 1                   2        1    0    1    0    0  True         1
#  England             3                   1                     1                      0                 2                   3        1    0    0    1    0  True         0
#
# ========================================
#
# Analyzing Group F, year 1986, goal: 14 minute, Player team: England, Home: England, Away: Poland
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  England             3                   2                     1                      1                 2                   1        2    1    0    1    0 False         0
# Portugal             3                   1                     1                      0                 1                   2        1    0    1    0    0 False         0
#   Poland             3                   1                     2                     -1                 0                   3        2    1    0    1    0 False         0
#
# ========================================
#
# Analyzing Group F, year 1986, goal: 19 minute, Player team: Morocco, Home: Portugal, Away: Morocco
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  England             3                   2                     1                      1                 2                   1        2    1    0    1    0 False         0
#   Poland             3                   1                     2                     -1                 0                   2        3    1    1    1    0 False         0
# Portugal             2                   1                     2                     -1                 0                   3        2    0    1    1    0 False         0
#
# ========================================
#
# Analyzing Group F, year 1986, goal: 26 minute, Player team: Morocco, Home: Portugal, Away: Morocco
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  England             3                   2                     1                      1                 2                   1        2    1    0    1    0 False         0
#   Poland             3                   1                     2                     -1                 0                   2        3    1    1    1    0 False         0
# Portugal             2                   1                     3                     -2                 0                   3        2    0    1    1    0 False         0
#
# ========================================
#
# Analyzing Group F, year 1986, goal: 34 minute, Player team: England, Home: England, Away: Poland
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  England             3                   3                     1                      2                 2                   1        2    1    0    1    0 False         0
#   Poland             3                   1                     3                     -2                 0                   2        3    1    1    1    0 False         0
# Portugal             2                   1                     3                     -2                 0                   3        2    0    1    1    0 False         0
#
# ========================================
#
# Analyzing Group F, year 1986, goal: 62 minute, Player team: Morocco, Home: Portugal, Away: Morocco
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  England             3                   3                     1                      2                 2                   1        2    1    0    1    0 False         0
#   Poland             3                   1                     3                     -2                 0                   2        3    1    1    1    0 False         0
# Portugal             2                   1                     4                     -3                 0                   3        2    0    1    1    0 False         0
#
# ========================================
#
# Analyzing Group F, year 1986, goal: 80 minute, Player team: Portugal, Home: Portugal, Away: Morocco
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  England             3                   3                     1                      2                 2                   1        2    1    0    1    0 False         0
#   Poland             3                   1                     3                     -2                 0                   2        3    1    1    1    0 False         0
# Portugal             2                   2                     4                     -2                 0                   3        2    0    1    1    0 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1990, Group Quarterfinals Before Last Match Goals ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#               Italy             3                   1                     0                      1                        3                          1
# Republic of Ireland             1                   0                     1                     -1                        1                          2
#
# ====================================================
#
# Analyzing Quarterfinals, year 1990, goal: 25 minute, Player team: West Germany, Home: Czechoslovakia, Away: West Germany
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#               Italy             4                   1                     0                      1                 1                   1        1    1    0    0    0 False         0
# Republic of Ireland             2                   0                     1                     -1                 1                   2        1    0    1    0    0 False         0
#
# ========================================
#
# Analyzing Quarterfinals, year 1990, goal: 25 minute, Player team: England, Home: Cameroon, Away: England
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#               Italy             4                   1                     0                      1                 1                   1        1    1    0    0    0 False         0
# Republic of Ireland             2                   0                     1                     -1                 1                   2        1    0    1    0    0 False         0
#
# ========================================
#
# Analyzing Quarterfinals, year 1990, goal: 61 minute, Player team: Cameroon, Home: Cameroon, Away: England
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#               Italy             4                   1                     0                      1                 1                   1        1    1    0    0    0 False         0
# Republic of Ireland             2                   0                     1                     -1                 1                   2        1    0    1    0    0 False         0
#
# ========================================
#
# Analyzing Quarterfinals, year 1990, goal: 65 minute, Player team: Cameroon, Home: Cameroon, Away: England
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#               Italy             4                   1                     0                      1                 1                   1        1    1    0    0    0 False         0
# Republic of Ireland             2                   0                     1                     -1                 1                   2        1    0    1    0    0 False         0
#
# ========================================
#
# Analyzing Quarterfinals, year 1990, goal: 83 minute, Player team: England, Home: Cameroon, Away: England
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#               Italy             4                   1                     0                      1                 1                   1        1    1    0    0    0 False         0
# Republic of Ireland             2                   0                     1                     -1                 1                   2        1    0    1    0    0 False         0
#
# ========================================
#
# Analyzing Quarterfinals, year 1990, goal: 105 minute, Player team: England, Home: Cameroon, Away: England
#
# === Updated Standings After This Goal ===
#
#                team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#               Italy             4                   1                     0                      1                 1                   1        1    1    0    0    0 False         0
# Republic of Ireland             2                   0                     1                     -1                 1                   2        1    0    1    0    0 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1990, Group Semifinals Before Last Match Goals ===
#
#      team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# Argentina             2                   1                     1                      0                        2                          1
#     Italy             2                   1                     1                      0                        2                          2
#
# ====================================================
#
# Analyzing Semifinals, year 1990, goal: 60 minute, Player team: West Germany, Home: West Germany, Away: England
#
# === Updated Standings After This Goal ===
#
#      team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Argentina             3                   1                     1                      0                 1                   1        1    1    0    0    0  True         0
#     Italy             3                   1                     1                      0                 1                   2        1    0    1    0    0  True         0
#
# ========================================
#
# Analyzing Semifinals, year 1990, goal: 80 minute, Player team: England, Home: West Germany, Away: England
#
# === Updated Standings After This Goal ===
#
#      team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Argentina             3                   1                     1                      0                 1                   1        1    1    0    0    0  True         0
#     Italy             3                   1                     1                      0                 1                   2        1    0    1    0    0  True         0
#
# ========================================
#
#
# === Initial Standings for Year 1998, Group Group A Before Last Match Goals ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#   Brazil             6                   5                     1                      4                        6                          1
#   Norway             2                   3                     3                      0                        2                          2
# Scotland             1                   2                     3                     -1                        1                          3
#  Morocco             1                   2                     5                     -3                        1                          4
#
# ====================================================
#
# Analyzing Group A, year 1998, goal: 23 minute, Player team: Morocco, Home: Scotland, Away: Morocco
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Brazil             7                   5                     1                      4                 1                   1        1    1    0    0    0 False         0
#  Morocco             4                   3                     5                     -2                 3                   2        2    0    1    0    1 False         0
#   Norway             3                   3                     3                      0                 1                   3        2    0    1    1    0 False         0
# Scotland             1                   2                     4                     -2                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1998, goal: 46 minute, Player team: Morocco, Home: Scotland, Away: Morocco
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Brazil             7                   5                     1                      4                 1                   1        1    1    0    0    0 False         0
#  Morocco             4                   4                     5                     -1                 3                   2        2    0    1    0    1 False         0
#   Norway             3                   3                     3                      0                 1                   3        2    0    1    1    0 False         0
# Scotland             1                   2                     5                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1998, goal: 78 minute, Player team: Brazil, Home: Brazil, Away: Norway
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# ...
# Morocco             7                   4                     0                      4                 3                   1        2    1    1    0    0 False         0
# Croatia             5                   4                     1                      3                 1                   2        2    1    1    0    0 False         0
# Belgium             4                   1                     2                     -1                 1                   3        2    0    0    2    0 False         0
#  Canada             0                   1                     7                     -6                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group F, year 2022, goal: 40 minute, Player team: Canada, Home: Canada, Away: Morocco
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Morocco             7                   4                     1                      3                 3                   1        2    1    1    0    0 False         0
# Croatia             5                   4                     1                      3                 1                   2        2    1    1    0    0 False         0
# Belgium             4                   1                     2                     -1                 1                   3        2    0    0    2    0 False         0
#  Canada             0                   2                     7                     -5                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2022, Group Group G Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#      Brazil             6                   3                     0                      3                        6                          1
# Switzerland             3                   1                     1                      0                        3                          2
#    Cameroon             1                   3                     4                     -1                        1                          3
#      Serbia             1                   3                     5                     -2                        1                          4
#
# ====================================================
#
# Analyzing Group G, year 2022, goal: 20 minute, Player team: Switzerland, Home: Serbia, Away: Switzerland
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Brazil             7                   3                     0                      3                 1                   1        1    1    0    0    0 False         0
# Switzerland             6                   2                     1                      1                 3                   2        1    0    1    0    0 False         0
#    Cameroon             2                   3                     4                     -1                 1                   3        1    0    0    1    0 False         0
#      Serbia             1                   3                     6                     -3                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group G, year 2022, goal: 26 minute, Player team: Serbia, Home: Serbia, Away: Switzerland
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Brazil             7                   3                     0                      3                 1                   1        1    1    0    0    0 False         0
# Switzerland             4                   2                     2                      0                 1                   2        1    0    1    0    0 False         0
#    Cameroon             2                   3                     4                     -1                 1                   3        1    0    0    1    0 False         0
#      Serbia             2                   4                     6                     -2                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group G, year 2022, goal: 35 minute, Player team: Serbia, Home: Serbia, Away: Switzerland
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Brazil             7                   3                     0                      3                 1                   1        1    1    0    0    0 False         0
#      Serbia             4                   5                     6                     -1                 3                   2        2    0    1    0    1 False         0
# Switzerland             3                   2                     3                     -1                 0                   3        2    0    1    1    0 False         0
#    Cameroon             2                   3                     4                     -1                 1                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group G, year 2022, goal: 44 minute, Player team: Switzerland, Home: Serbia, Away: Switzerland
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Brazil             7                   3                     0                      3                 1                   1        1    1    0    0    0 False         0
# Switzerland             4                   3                     3                      0                 1                   2        3    0    2    1    0 False         0
#    Cameroon             2                   3                     4                     -1                 1                   3        3    0    0    2    1 False         0
#      Serbia             2                   5                     7                     -2                 1                   4        3    0    1    0    2 False         0
#
# ========================================
#
# Analyzing Group G, year 2022, goal: 48 minute, Player team: Switzerland, Home: Serbia, Away: Switzerland
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Brazil             7                   3                     0                      3                 1                   1        1    1    0    0    0 False         0
# Switzerland             6                   4                     3                      1                 3                   2        3    0    2    1    0 False         0
#    Cameroon             2                   3                     4                     -1                 1                   3        3    0    0    2    1 False         0
#      Serbia             1                   5                     8                     -3                 0                   4        3    0    1    0    2 False         0
#
# ========================================
#
# Analyzing Group G, year 2022, goal: 92 minute, Player team: Cameroon, Home: Cameroon, Away: Brazil
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Brazil             6                   3                     1                      2                 0                   1        1    1    0    0    0 False         0
# Switzerland             6                   4                     3                      1                 3                   2        3    0    2    1    0 False         0
#    Cameroon             4                   4                     4                      0                 3                   3        3    0    0    2    1 False         0
#      Serbia             1                   5                     8                     -3                 0                   4        3    0    1    0    2 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2022, Group Group H Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#    Portugal             6                   5                     2                      3                        6                          1
#       Ghana             3                   5                     5                      0                        3                          2
# South Korea             1                   2                     3                     -1                        1                          3
#     Uruguay             1                   0                     2                     -2                        1                          4
#
# ====================================================
#
# Analyzing Group H, year 2022, goal: 5 minute, Player team: Portugal, Home: South Korea, Away: Portugal
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#    Portugal             9                   6                     2                      4                 3                   1        1    1    0    0    0 False         0
#       Ghana             4                   5                     5                      0                 1                   2        1    0    1    0    0 False         0
#     Uruguay             2                   0                     2                     -2                 1                   3        2    0    0    1    1 False         0
# South Korea             1                   2                     4                     -2                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group H, year 2022, goal: 26 minute, Player team: Uruguay, Home: Ghana, Away: Uruguay
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#    Portugal             9                   6                     2                      4                 3                   1        1    1    0    0    0 False         0
#     Uruguay             4                   1                     2                     -1                 3                   2        3    0    1    1    1 False         0
#       Ghana             3                   5                     6                     -1                 0                   3        2    0    1    1    0 False         0
# South Korea             1                   2                     4                     -2                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group H, year 2022, goal: 27 minute, Player team: South Korea, Home: South Korea, Away: Portugal
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#    Portugal             7                   6                     3                      3                 1                   1        1    1    0    0    0 False         0
#     Uruguay             4                   1                     2                     -1                 3                   2        3    0    1    1    1 False         0
#       Ghana             3                   5                     6                     -1                 0                   3        2    0    1    1    0 False         0
# South Korea             2                   3                     4                     -1                 1                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group H, year 2022, goal: 32 minute, Player team: Uruguay, Home: Ghana, Away: Uruguay
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#    Portugal             7                   6                     3                      3                 1                   1        1    1    0    0    0 False         0
#     Uruguay             4                   2                     2                      0                 3                   2        3    0    1    1    1 False         0
#       Ghana             3                   5                     7                     -2                 0                   3        2    0    1    1    0 False         0
# South Korea             2                   3                     4                     -1                 1                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group H, year 2022, goal: 91 minute, Player team: South Korea, Home: South Korea, Away: Portugal
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#    Portugal             6                   6                     4                      2                 0                   1        1    1    0    0    0 False         0
# South Korea             4                   4                     4                      0                 3                   2        3    0    1    1    1 False         0
#     Uruguay             4                   2                     2                      0                 3                   3        4    0    1    2    1 False         0
#       Ghana             3                   5                     7                     -2                 0                   4        3    0    1    1    1 False         0
#
# ========================================
#      year    stage         team  1st  2nd  3rd  4th  changes
# 0    1986  Group A    Argentina    1    0    0    0        1
# 2    1986  Group A        Italy    0    1    1    0        2
# 1    1986  Group A     Bulgaria    0    1    1    0        2
# 3    1986  Group A  South Korea    0    0    0    2        2
# 4    1986  Group B       Mexico    2    1    0    0        3
# ..    ...      ...          ...  ...  ...  ...  ...      ...
# 245  2022  Group G       Serbia    0    1    0    2        3
# 246  2022  Group H     Portugal    1    0    0    0        1
# 248  2022  Group H  South Korea    0    1    1    1        3
# 249  2022  Group H      Uruguay    0    1    2    1        4
# 247  2022  Group H        Ghana    0    1    1    1        3
#
# [250 rows x 8 columns]

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\tb_wc_fifa_men.xlsx'
changes_df_wc.to_excel(file_path, index=False)

# %% [markdown]
# # group composition tracking

# %%
# Initialize an empty list to store the results for each pair
all_composition_changes = []

# Get unique pairs of year, stage, and men
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    stage = row['stage']
    
    # Apply the function to the current pair
    composition_changes_df = track_composition_changes(year, stage, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_composition_changes.append(composition_changes_df)

# Concatenate all the results into a single DataFrame
final_composition_changes_df = pd.concat(all_composition_changes, ignore_index=True)

# Display the final DataFrame
display(final_composition_changes_df)
# Out:
#      year    stage  change_num goal_time         home_team    away_team  \
# 0    1986  Group A           0   initial              None         None
# 1    1986  Group B           0   initial              None         None
# 2    1986  Group C           0   initial              None         None
# 3    1986  Group D           0   initial              None         None
# 4    1986  Group D           1        15  Northern Ireland       Brazil
# ..    ...      ...         ...       ...               ...          ...
# 112  2022  Group G           1        35            Serbia  Switzerland
# 113  2022  Group G           2        44            Serbia  Switzerland
# 114  2022  Group H           0   initial              None         None
# 115  2022  Group H           1        26             Ghana      Uruguay
# 116  2022  Group H           2        91       South Korea     Portugal
#
#     scorer_nationality                      new_top_teams  \
# 0                 None       [Argentina, Bulgaria, Italy]
# 1                 None        [Belgium, Mexico, Paraguay]
# 2                 None    [Hungary, Soviet Union, France]
# 3                 None  [Spain, Northern Ireland, Brazil]
# 4               Brazil           [Spain, Algeria, Brazil]
# ..                 ...                                ...
# 112             Serbia                   [Serbia, Brazil]
# 113        Switzerland              [Brazil, Switzerland]
# 114               None                  [Ghana, Portugal]
# 115            Uruguay                [Portugal, Uruguay]
# 116        South Korea            [Portugal, South Korea]
#
#     third_place_teams_list  top4_third_place           1st          2nd  \
# 0                  [Italy]                 1     Argentina     Bulgaria
# 1                [Belgium]                 1        Mexico     Paraguay
# 2                [Hungary]                 1  Soviet Union       France
# 3       [Northern Ireland]                 1        Brazil        Spain
# 4                [Algeria]                 1        Brazil        Spain
# ..                     ...               ...           ...          ...
# 112          [Switzerland]                 1        Brazil       Serbia
# 113             [Cameroon]                 1        Brazil  Switzerland
# 114          [South Korea]                 1      Portugal        Ghana
# 115                [Ghana]                 1      Portugal      Uruguay
# 116              [Uruguay]                 1      Portugal  South Korea
#
#                   3rd
# 0               Italy
# 1             Belgium
# 2             Hungary
# 3    Northern Ireland
# 4             Algeria
# ..                ...
# 112       Switzerland
# 113          Cameroon
# 114       South Korea
# 115             Ghana
# 116           Uruguay
#
# [117 rows x 13 columns]

# %%
# Initialize an empty list to store the results for each pair
all_composition_changes = []

# Get unique pairs of year and group_name
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    group_name = row['stage']
    
    # Apply the function to the current pair
    composition_changes_df = track_composition_changes(year, group_name, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_composition_changes.append(composition_changes_df)

# Concatenate all the results into a single DataFrame
final_composition_changes_df = pd.concat(all_composition_changes, ignore_index=True)

# Rename 'player_team' column to 'scorer_team'
final_composition_changes_df.rename(columns={'player_team': 'scorer_team'}, inplace=True)

# Display the final DataFrame
display(final_composition_changes_df)
# Out:
#      year    stage  change_num goal_time         home_team    away_team  \
# 0    1986  Group A           0   initial              None         None
# 1    1986  Group B           0   initial              None         None
# 2    1986  Group C           0   initial              None         None
# 3    1986  Group D           0   initial              None         None
# 4    1986  Group D           1        15  Northern Ireland       Brazil
# ..    ...      ...         ...       ...               ...          ...
# 112  2022  Group G           1        35            Serbia  Switzerland
# 113  2022  Group G           2        44            Serbia  Switzerland
# 114  2022  Group H           0   initial              None         None
# 115  2022  Group H           1        26             Ghana      Uruguay
# 116  2022  Group H           2        91       South Korea     Portugal
#
#     scorer_nationality                      new_top_teams  \
# 0                 None       [Argentina, Bulgaria, Italy]
# 1                 None        [Belgium, Mexico, Paraguay]
# 2                 None    [Hungary, Soviet Union, France]
# 3                 None  [Spain, Northern Ireland, Brazil]
# 4               Brazil           [Spain, Algeria, Brazil]
# ..                 ...                                ...
# 112             Serbia                   [Serbia, Brazil]
# 113        Switzerland              [Brazil, Switzerland]
# 114               None                  [Ghana, Portugal]
# 115            Uruguay                [Portugal, Uruguay]
# 116        South Korea            [Portugal, South Korea]
#
#     third_place_teams_list  top4_third_place           1st          2nd  \
# 0                  [Italy]                 1     Argentina     Bulgaria
# 1                [Belgium]                 1        Mexico     Paraguay
# 2                [Hungary]                 1  Soviet Union       France
# 3       [Northern Ireland]                 1        Brazil        Spain
# 4                [Algeria]                 1        Brazil        Spain
# ..                     ...               ...           ...          ...
# 112          [Switzerland]                 1        Brazil       Serbia
# 113             [Cameroon]                 1        Brazil  Switzerland
# 114          [South Korea]                 1      Portugal        Ghana
# 115                [Ghana]                 1      Portugal      Uruguay
# 116              [Uruguay]                 1      Portugal  South Korea
#
#                   3rd
# 0               Italy
# 1             Belgium
# 2             Hungary
# 3    Northern Ireland
# 4             Algeria
# ..                ...
# 112       Switzerland
# 113          Cameroon
# 114       South Korea
# 115             Ghana
# 116           Uruguay
#
# [117 rows x 13 columns]

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\standings_wc_fifa_men.xlsx'
final_composition_changes_df.to_excel(file_path, index=False)

# %% [markdown]
# # best four third placed

# %%
# Call the function to get the DataFrame
final_df = best_four_third_placed_wc_men(goals_last_day_sorted, all_games_before_last, agg_goals_before_last_day)

# Define the file path and save to Excel
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\third_teams_wc_fifa_men.xlsx'
final_df.to_excel(file_path, index=False)
# Out:
# --- Processing Year: 1986 ---
#
# === Initial Standings for Year 1986 Before Processing Any Goals ===
#
#             team   stage  before_last_game_points  before_last_game_goals_scored  before_last_game_goals_conceded  total_goal_difference
#        Argentina Group A                        3                              4                                2                      2
#         Bulgaria Group A                        2                              2                                2                      0
#            Italy Group A                        2                              2                                2                      0
#      South Korea Group A                        1                              2                                4                     -2
#           Mexico Group B                        3                              3                                2                      1
#         Paraguay Group B                        3                              2                                1                      1
#          Belgium Group B                        2                              3                                3                      0
#             Iraq Group B                        0                              1                                3                     -2
#     Soviet Union Group C                        3                              7                                1                      6
#           France Group C                        3                              2                                1                      1
#          Hungary Group C                        2                              2                                6                     -4
#           Canada Group C                        0                              0                                3                     -3
#           Brazil Group D                        4                              2                                0                      2
#            Spain Group D                        2                              2                                2                      0
# Northern Ireland Group D                        1                              2                                3                     -1
#          Algeria Group D                        1                              1                                2                     -1
#          Denmark Group E                        4                              7                                1                      6
#     West Germany Group E                        3                              3                                2                      1
#          Uruguay Group E                        1                              2                                7                     -5
#         Scotland Group E                        0                              1                                3                     -2
#           Poland Group F                        3                              1                                0                      1
#         Portugal Group F                        2                              1                                1                      0
#          England Group F                        1                              0                                1                     -1
#
# ===============================================================
#
#
# --- Analyzing Goal 13 in Group C: On date 1986-06-09, Minute 29 (Player Team: France, Home: Hungary, Away: France) ---
# Top 4 third-placed teams after this goal: ['Italy', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 2              Italy             3                 1                      0
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -5
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 2                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 16 in Group C: On date 1986-06-09, Minute 58 (Player Team: Soviet Union, Home: Soviet Union, Away: Canada) ---
# Top 4 third-placed teams after this goal: ['Italy', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 2              Italy             3                 1                      0
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -5
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 2                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 14 in Group C: On date 1986-06-09, Minute 62 (Player Team: France, Home: Hungary, Away: France) ---
# Top 4 third-placed teams after this goal: ['Italy', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 2              Italy             3                 1                      0
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 2                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 17 in Group C: On date 1986-06-09, Minute 74 (Player Team: Soviet Union, Home: Soviet Union, Away: Canada) ---
# Top 4 third-placed teams after this goal: ['Italy', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 2              Italy             3                 1                      0
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -6
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 2                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 15 in Group C: On date 1986-06-09, Minute 84 (Player Team: France, Home: Hungary, Away: France) ---
# Top 4 third-placed teams after this goal: ['Italy', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 2              Italy             3                 1                      0
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 2                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 6 in Group A: On date 1986-06-10, Minute 4 (Player Team: Argentina, Home: Argentina, Away: Bulgaria) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -1
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 3 in Group A: On date 1986-06-10, Minute 17 (Player Team: Italy, Home: South Korea, Away: Italy) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -1
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 1 in Group A: On date 1986-06-10, Minute 62 (Player Team: South Korea, Home: South Korea, Away: Italy) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -1
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 4 in Group A: On date 1986-06-10, Minute 73 (Player Team: Italy, Home: South Korea, Away: Italy) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -1
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 7 in Group A: On date 1986-06-10, Minute 77 (Player Team: Argentina, Home: Argentina, Away: Bulgaria) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 5 in Group A: On date 1986-06-10, Minute 82 (Player Team: Italy, Home: South Korea, Away: Italy) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 2 in Group A: On date 1986-06-10, Minute 83 (Player Team: South Korea, Home: South Korea, Away: Italy) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 22           England             2                 1                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 22                   0
#
#
# --- Analyzing Goal 26 in Group F: On date 1986-06-11, Minute 9 (Player Team: England, Home: England, Away: Poland) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             3                 1                      0
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 27 in Group F: On date 1986-06-11, Minute 14 (Player Team: England, Home: England, Away: Poland) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 20            Poland             3                 0                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 20                   1
#
#
# --- Analyzing Goal 30 in Group F: On date 1986-06-11, Minute 19 (Player Team: Morocco, Home: Portugal, Away: Morocco) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -1
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 31 in Group F: On date 1986-06-11, Minute 26 (Player Team: Morocco, Home: Portugal, Away: Morocco) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    3
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 10 in Group B: On date 1986-06-11, Minute 30 (Player Team: Belgium, Home: Paraguay, Away: Belgium) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Paraguay', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 5           Paraguay             3                 0                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 5                    2
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 28 in Group F: On date 1986-06-11, Minute 34 (Player Team: England, Home: England, Away: Poland) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Paraguay', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 5           Paraguay             3                 0                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 5                    2
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 8 in Group B: On date 1986-06-11, Minute 50 (Player Team: Paraguay, Home: Paraguay, Away: Belgium) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    4
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 12 in Group B: On date 1986-06-11, Minute 54 (Player Team: Mexico, Home: Iraq, Away: Mexico) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    4
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 11 in Group B: On date 1986-06-11, Minute 59 (Player Team: Belgium, Home: Paraguay, Away: Belgium) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Paraguay', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 5           Paraguay             3                 0                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 5                    3
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 32 in Group F: On date 1986-06-11, Minute 62 (Player Team: Morocco, Home: Portugal, Away: Morocco) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Paraguay', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 5           Paraguay             3                 0                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -3
#
#     total_goals_scored
# 1                    2
# 5                    3
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 9 in Group B: On date 1986-06-11, Minute 76 (Player Team: Paraguay, Home: Paraguay, Away: Belgium) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -3
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   1
#
#
# --- Analyzing Goal 29 in Group F: On date 1986-06-11, Minute 80 (Player Team: Portugal, Home: Portugal, Away: Morocco) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             2                 1                     -1
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 18 in Group D: On date 1986-06-12, Minute 15 (Player Team: Brazil, Home: Northern Ireland, Away: Brazil) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Algeria']
# Third-placed teams DataFrame after this goal:
#         team  total_points  last_game_points  total_goal_difference  \
# 1   Bulgaria             2                 0                     -2
# 6    Belgium             3                 1                      0
# 10   Hungary             2                 0                     -7
# 15   Algeria             2                 1                     -1
# 18   Uruguay             2                 1                     -5
# 21  Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 15                   1
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 21 in Group D: On date 1986-06-12, Minute 15 (Player Team: Spain, Home: Algeria, Away: Spain) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             1                 0                     -2
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 20 in Group D: On date 1986-06-12, Minute 42 (Player Team: Brazil, Home: Northern Ireland, Away: Brazil) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Algeria']
# Third-placed teams DataFrame after this goal:
#         team  total_points  last_game_points  total_goal_difference  \
# 1   Bulgaria             2                 0                     -2
# 6    Belgium             3                 1                      0
# 10   Hungary             2                 0                     -7
# 15   Algeria             1                 0                     -2
# 18   Uruguay             2                 1                     -5
# 21  Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 15                   1
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 22 in Group D: On date 1986-06-12, Minute 68 (Player Team: Spain, Home: Algeria, Away: Spain) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             1                 0                     -3
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 23 in Group D: On date 1986-06-12, Minute 70 (Player Team: Spain, Home: Algeria, Away: Spain) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             1                 0                     -3
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 19 in Group D: On date 1986-06-12, Minute 87 (Player Team: Brazil, Home: Northern Ireland, Away: Brazil) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             1                 0                     -4
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 24 in Group E: On date 1986-06-13, Minute 43 (Player Team: Denmark, Home: Denmark, Away: West Germany) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             1                 0                     -4
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 25 in Group E: On date 1986-06-13, Minute 62 (Player Team: Denmark, Home: Denmark, Away: West Germany) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             1                 0                     -4
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    5
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 33 in Third place play-off: On date 1986-06-28, Minute 11 (Player Team: Belgium, Home: Belgium, Away: France) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Paraguay', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 5           Paraguay             4                 1                      1
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             1                 0                     -4
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 5                    4
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 35 in Third place play-off: On date 1986-06-28, Minute 27 (Player Team: France, Home: Belgium, Away: France) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             1                 0                     -4
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    6
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 36 in Third place play-off: On date 1986-06-28, Minute 43 (Player Team: France, Home: Belgium, Away: France) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             2                 0                     -1
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             1                 0                     -4
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    6
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 34 in Third place play-off: On date 1986-06-28, Minute 73 (Player Team: Belgium, Home: Belgium, Away: France) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             3                 1                      0
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             1                 0                     -4
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    7
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 37 in Third place play-off: On date 1986-06-28, Minute 104 (Player Team: France, Home: Belgium, Away: France) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             2                 0                     -1
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             1                 0                     -4
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    7
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Analyzing Goal 38 in Third place play-off: On date 1986-06-28, Minute 111 (Player Team: France, Home: Belgium, Away: France) ---
# Top 4 third-placed teams after this goal: ['Bulgaria', 'Belgium', 'Hungary', 'Northern Ireland']
# Third-placed teams DataFrame after this goal:
#                 team  total_points  last_game_points  total_goal_difference  \
# 1           Bulgaria             2                 0                     -2
# 6            Belgium             2                 0                     -2
# 10           Hungary             2                 0                     -7
# 14  Northern Ireland             1                 0                     -4
# 18           Uruguay             2                 1                     -5
# 21          Portugal             2                 0                     -2
#
#     total_goals_scored
# 1                    2
# 6                    7
# 10                   2
# 14                   2
# 18                   2
# 21                   2
#
#
# --- Processing Year: 1990 ---
#
# === Initial Standings for Year 1990 Before Processing Any Goals ===
#
#                team         stage  before_last_game_points  before_last_game_goals_scored  before_last_game_goals_conceded  total_goal_difference
#               Italy Quarterfinals                        3                              1                                0                      1
# Republic of Ireland Quarterfinals                        1                              0                                1                     -1
#           Argentina    Semifinals                        2                              1                                1                      0
#               Italy    Semifinals                        2                              1                                1                      0
#
# ===============================================================
#
#
# --- Analyzing Goal 39 in Quarterfinals: On date 1990-07-01, Minute 25 (Player Team: West Germany, Home: Czechoslovakia, Away: West Germany) ---
# Top 4 third-placed teams after this goal: []
# Third-placed teams DataFrame after this goal:
# Empty DataFrame
# Columns: [team, total_points, last_game_points, total_goal_difference, total_goals_scored]
# Index: []
#
#
# --- Analyzing Goal 42 in Quarterfinals: On date 1990-07-01, Minute 25 (Player Team: England, Home: Cameroon, Away: England) ---
# Top 4 third-placed teams after this goal: []
# Third-placed teams DataFrame after this goal:
# Empty DataFrame
# Columns: [team, total_points, last_game_points, total_goal_difference, total_goals_scored]
# Index: []
#
#
# --- Analyzing Goal 40 in Quarterfinals: On date 1990-07-01, Minute 61 (Player Team: Cameroon, Home: Cameroon, Away: England) ---
# Top 4 third-placed teams after this goal: []
# Third-placed teams DataFrame after this goal:
# Empty DataFrame
# Columns: [team, total_points, last_game_points, total_goal_difference, total_goals_scored]
# Index: []
#
#
# --- Analyzing Goal 41 in Quarterfinals: On date 1990-07-01, Minute 65 (Player Team: Cameroon, Home: Cameroon, Away: England) ---
# Top 4 third-placed teams after this goal: []
# Third-placed teams DataFrame after this goal:
# Empty DataFrame
# Columns: [team, total_points, last_game_points, total_goal_difference, total_goals_scored]
# Index: []
#
#
# --- Analyzing Goal 43 in Quarterfinals: On date 1990-07-01, Minute 83 (Player Team: England, Home: Cameroon, Away: England) ---
# Top 4 third-placed teams after this goal: []
# Third-placed teams DataFrame after this goal:
# Empty DataFrame
# Columns: [team, total_points, last_game_points, total_goal_difference, total_goals_scored]
# Index: []
#
#
# --- Analyzing Goal 44 in Quarterfinals: On date 1990-07-01, Minute 105 (Player Team: England, Home: Cameroon, Away: England) ---
# Top 4 third-placed teams after this goal: []
# Third-placed teams DataFrame after this goal:
# Empty DataFrame
# Columns: [team, total_points, last_game_points, total_goal_difference, total_goals_scored]
# Index: []
#
#
# --- Analyzing Goal 45 in Semifinals: On date 1990-07-04, Minute 60 (Player Team: West Germany, Home: West Germany, Away: England) ---
# Top 4 third-placed teams after this goal: []
# Third-placed teams DataFrame after this goal:
# Empty DataFrame
# Columns: [team, total_points, last_game_points, total_goal_difference, total_goals_scored]
# Index: []
#
#
# --- Analyzing Goal 46 in Semifinals: On date 1990-07-04, Minute 80 (Player Team: England, Home: West Germany, Away: England) ---
# Top 4 third-placed teams after this goal: []
# Third-placed teams DataFrame after this goal:
# Empty DataFrame
# Columns: [team, total_points, last_game_points, total_goal_difference, total_goals_scored]
# Index: []
#
#
# --- Analyzing Goal 47 in Third place play-off: On date 1990-07-07, Minute 71 (Player Team: Italy, Home: Italy, Away: England) ---
# Top 4 third-placed teams after this goal: []
# Third-placed teams DataFrame after this goal:
# Empty DataFrame
# Columns: [team, total_points, last_game_points, total_goal_difference, total_goals_scored]
# Index: []
#
#
# --- Analyzing Goal 49 in Third place play-off: On date 1990-07-07, Minute 81 (Player Team: England, Home: Italy, Away: England) ---
# Top 4 third-placed teams after this goal: []
# Third-placed teams DataFrame after this goal:
# Empty DataFrame
# Columns: [team, total_points, last_game_points, total_goal_difference, total_goals_scored]
# Index: []
#
#
# --- Analyzing Goal 48 in Third place play-off: On date 1990-07-07, Minute 86 (Player Team: Italy, Home: Italy, Away: England) ---
# Top 4 third-placed teams after this goal: []
# Third-placed teams DataFrame after this goal:
# Empty DataFrame
# Columns: [team, total_points, last_game_points, total_goal_difference, total_goals_scored]
# Index: []

# %%
# Count the number of observations where the year is 1986
count_1986 = goals_last_day_sorted[goals_last_day_sorted['year'] == 1986].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 1986: {count_1986}")

# Count the number of observations where the year is 1990
count_1990 = goals_last_day_sorted[goals_last_day_sorted['year'] == 1990].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 1990: {count_1990}")

# Count the number of observations where the year is 1994
count_1994 = goals_last_day_sorted[goals_last_day_sorted['year'] == 1994].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 1994: {count_1994}")
# Out:
# Number of observations in goals_last_day_sorted for the year 1986: 38
# Number of observations in goals_last_day_sorted for the year 1990: 11
# Number of observations in goals_last_day_sorted for the year 1994: 116
