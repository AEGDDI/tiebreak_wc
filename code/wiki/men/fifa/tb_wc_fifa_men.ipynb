# %% [markdown]
# # Libraries

# %%
import pandas as pd
from getpass import getuser
from collections import defaultdict
from datetime import datetime, timedelta
import re

# %% [markdown]
# # Load and inspect dataset

# %%
# Get the current user's name
user = getuser()

# Construct the path using the user's name
function_path = f"C:/Users/{user}/Documents/GitHub/tiebreak_wc/code/wiki/functions_fifa.ipynb"

# Run the notebook
# %run $function_path

# %%
# Path to the dataset
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\wc_goals_men.xlsx'

# Read the dataset with a different encoding
df = pd.read_excel(data_path)

# Now, filter the data for tournaments after 1984
df = df[df['year'] >= 1984]

display(df.head())
# Out:
#      stage  year  home_team    away_team score  half_time  \
# 0  Group A  1986   Bulgaria        Italy   1–1          2
# 1  Group A  1986   Bulgaria        Italy   1–1          1
# 2  Group A  1986  Argentina  South Korea   3–1          1
# 3  Group A  1986  Argentina  South Korea   3–1          2
# 4  Group A  1986  Argentina  South Korea   3–1          1
#
#                      stadium_name stadium_city  stadium_attendance  \
# 0                  Estadio Azteca  Mexico City             96000.0
# 1                  Estadio Azteca  Mexico City             96000.0
# 2  Estadio Olímpico Universitario  Mexico City             60000.0
# 3  Estadio Olímpico Universitario  Mexico City             60000.0
# 4  Estadio Olímpico Universitario  Mexico City             60000.0
#
#                  referee_name  ... goal_minute_et extra_time goals_home  \
# 0            Erik Fredriksson  ...              0          0          1
# 1            Erik Fredriksson  ...              0          0          1
# 2  Victoriano Sánchez Arminio  ...              0          0          3
# 3  Victoriano Sánchez Arminio  ...              0          0          3
# 4  Victoriano Sánchez Arminio  ...              0          0          3
#
#   goals_away  own_goal  penalty  goal_et  short_date    long_date  \
# 0          1         0        0        0         NaN  31 May 1986
# 1          1         0        0        0         NaN  31 May 1986
# 2          1         0        0        0         NaN  2 June 1986
# 3          1         0        0        0         NaN  2 June 1986
# 4          1         0        0        0         NaN  2 June 1986
#
#    referee_natinality
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 25 columns]

# %%
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\elo_wc.xlsx'
elo_wc = pd.read_excel(data_path)

# %%
# Dictionary of replacements for team names
replacements = {
    "Republic of Ireland": "Ireland",
    "CIS": "Commonwealth of Independent States",
    "FR Yugoslavia": "Yugoslavia"
}

# %%
# Prepare the Elo dataset for integration: rename columns for clarity
elo_wc = elo_wc.rename(columns={"team": "team_name", "elo_rating": "elo"})
elo_wc["team_name"] = elo_wc["team_name"].replace(replacements)

# %% [markdown]
# # Clean, transfrom, create variables

# %% [markdown]
# ## duplicates

# %%
# # Remove duplicates
# goals_df = goals_df.drop_duplicates()

# %%
# Columns to check for duplicates
columns_to_check = ['year', 'stage', 'home_team', 'scorer_nationality', 'long_date', 'half_time','time', 'goal_minute']

# Filter duplicates where both goals_home and goals_away are not 0
filtered_duplicates = df[
    (df.duplicated(subset=columns_to_check, keep=False)) &
    ~((df['goals_home'] == 0) & (df['goals_away'] == 0))
]

print("Filtered duplicates without both goals_home and goals_away being 0:")
display(filtered_duplicates)
# Out:
# Filtered duplicates without both goals_home and goals_away being 0:
# Empty DataFrame
# Columns: [stage, year, home_team, away_team, score, half_time, stadium_name, stadium_city, stadium_attendance, referee_name, referee_nationality, time, scorer_name, scorer_nationality, goal_minute, goal_minute_et, extra_time, goals_home, goals_away, own_goal, penalty, goal_et, short_date, long_date, referee_natinality]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ## time

# %%
# Apply the conversion function
df[['local_time', 'utc_time']] = df.apply(lambda row: pd.Series(convert_time(row)), axis=1)

# %% [markdown]
# ## date

# %%
# Step 1: Remove any commas before the year in 'long_date'
df['long_date'] = df['long_date'].str.replace(r',\s*(\d{4})', r' \1', regex=True)

# Step 2: Convert 'long_date' to 'short_date' where 'short_date' is missing
df['short_date'] = df['short_date'].fillna(pd.to_datetime(df['long_date'], errors='coerce').dt.strftime('%Y-%m-%d'))

# %%
# Step 1: Remove comma only for year 1994
df.loc[df['year'] == 1994, 'long_date'] = df.loc[df['year'] == 1994, 'long_date'].str.replace(',', '', regex=True)

# Step 2: Convert 'long_date' to 'short_date' where 'short_date' is missing
df.loc[df['year'] == 1994, 'short_date'] = df.loc[df['year'] == 1994, 'short_date'].fillna(
    pd.to_datetime(df.loc[df['year'] == 1994, 'long_date'], errors='coerce', format='%B %d %Y').dt.strftime('%Y-%m-%d')
)

# Step 3: Convert all other years normally
df.loc[df['year'] != 1994, 'short_date'] = df.loc[df['year'] != 1994, 'short_date'].fillna(
    pd.to_datetime(df.loc[df['year'] != 1994, 'long_date'], errors='coerce').dt.strftime('%Y-%m-%d')
)

# Step 4: Identify missing conversions again
missing_dates = df[df['short_date'].isna()]

if not missing_dates.empty:
    print("\n⚠️ WARNING: Some dates are still missing after format correction.")
    print(missing_dates[['year', 'long_date', 'short_date']])

# Step 5: Check specific cases for year 1994
missing_1994 = df[(df['year'] == 1994) & df['short_date'].isna()]
if not missing_1994.empty:
    print("\n🔍 DEBUG: Still missing short_date for year 1994:")
    print(missing_1994[['year', 'long_date', 'short_date']])

# %% [markdown]
# # stage

# %%
# Calculate the number of unique teams per stage and year using home_team and away_team
team_counts = (
    df.groupby(['year', 'stage'])
    .apply(lambda x: pd.concat([x['home_team'], x['away_team']]).unique())
)

# Convert the resulting series to a DataFrame
team_counts = team_counts.reset_index()  # Reset index without 'name' argument
team_counts = team_counts.rename(columns={0: 'team_list'})  # Rename the column appropriately

# Convert team list into counts
team_counts['team_count'] = team_counts['team_list'].apply(len)

# Filter stages where the number of teams is not equal to 4
invalid_groups = team_counts[team_counts['team_count'] != 4]

# Display the invalid groups
display(invalid_groups)
# Out:
# C:\Users\aldi\AppData\Local\Temp\ipykernel_19712\674411304.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: pd.concat([x['home_team'], x['away_team']]).unique())
#      year                 stage  \
# 0    1986                 Final
# 7    1986        Quarter-finals
# 8    1986           Round of 16
# 10   1986  Third place play-off
# 17   1990        Quarter-finals
# 18   1990           Round of 16
# 19   1990        not applicable
# 20   1994                 Final
# 27   1994         Quarterfinals
# 28   1994           Round of 16
# 30   1994   Third place playoff
# 31   1998                 Final
# 40   1998        Quarter-finals
# 41   1998           Round of 16
# 43   1998  Third place play-off
# 44   2002                 Final
# 53   2002        Quarter-finals
# 54   2002           Round of 16
# 56   2002  Third place play-off
# 57   2006                 Final
# 66   2006        Quarter-finals
# 67   2006           Round of 16
# 69   2006  Third place play-off
# 70   2010                 Final
# 79   2010        Quarter-finals
# 80   2010           Round of 16
# 82   2010  Third place play-off
# 83   2014                 Final
# 92   2014        Quarter-finals
# 93   2014           Round of 16
# 95   2014  Third place play-off
# 96   2018                 Final
# 105  2018        Quarter-finals
# 106  2018           Round of 16
# 108  2018  Third place play-off
# 109  2022                 Final
# 118  2022        Quarter-finals
# 119  2022           Round of 16
# 121  2022  Third place play-off
#
#                                              team_list  team_count
# 0                            [Argentina, West Germany]           2
# 7    [Brazil, West Germany, Argentina, Spain, Franc...           8
# 8    [Mexico, Soviet Union, Brazil, Argentina, Ital...          16
# 10                                   [Belgium, France]           2
# 17                             [Argentina, Yugoslavia]           2
# 18                      [Republic of Ireland, Romania]           2
# 19   [Cameroon, Czechoslovakia, Brazil, West German...          15
# 20                                     [Brazil, Italy]           2
# 27   [Italy, Netherlands, Bulgaria, Romania, Spain,...           8
# 28   [Germany, Spain, Saudi Arabia, Romania, Nether...          16
# 30                                  [Sweden, Bulgaria]           2
# 31                                    [Brazil, France]           2
# 40   [Italy, Brazil, Netherlands, Germany, France, ...           8
# 41   [Italy, Brazil, France, Nigeria, Germany, Neth...          16
# 43                              [Netherlands, Croatia]           2
# 44                                   [Germany, Brazil]           2
# 53   [England, Germany, Spain, Senegal, Brazil, Uni...           8
# 54   [Germany, Denmark, Sweden, Spain, Mexico, Braz...          16
# 56                               [South Korea, Turkey]           2
# 57                                     [Italy, France]           2
# 66   [Germany, Italy, England, Brazil, Argentina, U...           8
# 67   [Germany, Argentina, England, Portugal, Italy,...          16
# 69                                 [Germany, Portugal]           2
# 70                                [Netherlands, Spain]           2
# 79   [Netherlands, Uruguay, Argentina, Paraguay, Br...           8
# 80   [Uruguay, United States, Germany, Argentina, N...          16
# 82                                  [Uruguay, Germany]           2
# 83                                [Germany, Argentina]           2
# 92   [France, Brazil, Argentina, Netherlands, Germa...           8
# 93   [Brazil, Colombia, Netherlands, Costa Rica, Fr...          16
# 95                               [Brazil, Netherlands]           2
# 96                                   [France, Croatia]           2
# 105  [Uruguay, Brazil, Sweden, Russia, France, Belg...           8
# 106  [France, Uruguay, Spain, Croatia, Brazil, Belg...          16
# 108                                 [Belgium, England]           2
# 109                                [Argentina, France]           2
# 118  [Croatia, Netherlands, Morocco, England, Brazi...           8
# 119  [Netherlands, Argentina, France, England, Japa...          16
# 121                                 [Croatia, Morocco]           2

# %%
# Filter out the knockout stages
df = df[~df['stage'].isin(['Quarterfinals', 'Quarter-finals', 'Round of 16', 'Semi-finals', 'Semifinals','Final', 'Third place play-off', 'Third place playoff', 'not applicable'])]

# Extract relevant columns for goal events and match results
goals_df = df[['year', 'stage', 'home_team', 'away_team', 'scorer_nationality', 'goal_minute', 'half_time','short_date','local_time', 'score']]

#Sort goals_df by short_date, local_time, and goal_minute
goals_df = goals_df.sort_values(by=['short_date', 'local_time', 'goal_minute', 'half_time'], ascending=[True, True, True, True])

display(goals_df.head())
# Out:
#     year    stage home_team away_team scorer_nationality  goal_minute  \
# 1   1986  Group A  Bulgaria     Italy              Italy           44
# 0   1986  Group A  Bulgaria     Italy           Bulgaria           85
# 55  1986  Group D     Spain    Brazil                NaN            0
# 56  1986  Group D     Spain    Brazil             Brazil           62
# 34  1986  Group C    Canada    France                NaN            0
#
#     half_time  short_date local_time score
# 1           1  1986-05-31      18:00   1–1
# 0           2  1986-05-31      18:00   1–1
# 55          1  1986-06-01      18:00   0–1
# 56          2  1986-06-01      18:00   0–1
# 34          1  1986-06-01      22:00   0–1

# %%
df_missing = goals_df[(goals_df['year'] == 2006) & (goals_df['stage'] == 'Group C')]
df_missing
# Out:
#      year    stage              home_team              away_team  \
# 769  2006  Group C              Argentina            Ivory Coast
# 770  2006  Group C              Argentina            Ivory Coast
# 771  2006  Group C              Argentina            Ivory Coast
# 772  2006  Group C  Serbia and Montenegro            Netherlands
# 773  2006  Group C  Serbia and Montenegro            Netherlands
# 780  2006  Group C              Argentina  Serbia and Montenegro
# 774  2006  Group C              Argentina  Serbia and Montenegro
# 776  2006  Group C              Argentina  Serbia and Montenegro
# 775  2006  Group C              Argentina  Serbia and Montenegro
# 777  2006  Group C              Argentina  Serbia and Montenegro
# 778  2006  Group C              Argentina  Serbia and Montenegro
# 779  2006  Group C              Argentina  Serbia and Montenegro
# 781  2006  Group C            Netherlands            Ivory Coast
# 782  2006  Group C            Netherlands            Ivory Coast
# 783  2006  Group C            Netherlands            Ivory Coast
# 784  2006  Group C            Netherlands              Argentina
# 785  2006  Group C            Netherlands              Argentina
# 789  2006  Group C            Ivory Coast  Serbia and Montenegro
# 790  2006  Group C            Ivory Coast  Serbia and Montenegro
# 786  2006  Group C            Ivory Coast  Serbia and Montenegro
# 787  2006  Group C            Ivory Coast  Serbia and Montenegro
# 788  2006  Group C            Ivory Coast  Serbia and Montenegro
#
#         scorer_nationality  goal_minute  half_time  short_date local_time  \
# 769              Argentina           24          1  2006-06-10      21:00
# 770              Argentina           38          1  2006-06-10      21:00
# 771            Ivory Coast           82          2  2006-06-10      21:00
# 772                    NaN            0          1  2006-06-11      15:00
# 773            Netherlands           18          1  2006-06-11      15:00
# 780                    NaN            0          1  2006-06-16      15:00
# 774              Argentina            6          1  2006-06-16      15:00
# 776              Argentina           31          1  2006-06-16      15:00
# 775              Argentina           41          1  2006-06-16      15:00
# 777              Argentina           78          2  2006-06-16      15:00
# 778              Argentina           84          2  2006-06-16      15:00
# 779              Argentina           88          2  2006-06-16      15:00
# 781            Netherlands           23          1  2006-06-16      18:00
# 782            Netherlands           27          1  2006-06-16      18:00
# 783            Ivory Coast           38          1  2006-06-16      18:00
# 784                    NaN            0          1  2006-06-21      21:00
# 785                    NaN            0          1  2006-06-21      21:00
# 789  Serbia and Montenegro           10          1  2006-06-21      21:00
# 790  Serbia and Montenegro           20          1  2006-06-21      21:00
# 786            Ivory Coast           37          1  2006-06-21      21:00
# 787            Ivory Coast           67          2  2006-06-21      21:00
# 788            Ivory Coast           86          2  2006-06-21      21:00
#
#     score
# 769   2–1
# 770   2–1
# 771   2–1
# 772   0–1
# 773   0–1
# 780   6–0
# 774   6–0
# 776   6–0
# 775   6–0
# 777   6–0
# 778   6–0
# 779   6–0
# 781   2–1
# 782   2–1
# 783   2–1
# 784   0–0
# 785   0–0
# 789   3–2
# 790   3–2
# 786   3–2
# 787   3–2
# 788   3–2

# %% [markdown]
# # team counts

# %%
# Calculate the number of unique teams per stage and year using home_team and away_team
team_counts = (
    df.groupby(['year', 'stage'])
    .apply(lambda x: pd.concat([x['home_team'], x['away_team']]).unique())
)

# Convert the resulting series to a DataFrame
team_counts = team_counts.reset_index()  # Reset index without 'name' argument
team_counts = team_counts.rename(columns={0: 'team_list'})  # Rename the column appropriately

# Convert team list into counts
team_counts['team_count'] = team_counts['team_list'].apply(len)

# Filter stages where the number of teams is not equal to 4
invalid_groups = team_counts[team_counts['team_count'] != 4]

# Display the invalid groups
display(invalid_groups)
# Out:
# C:\Users\aldi\AppData\Local\Temp\ipykernel_19712\674411304.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: pd.concat([x['home_team'], x['away_team']]).unique())
# Empty DataFrame
# Columns: [year, stage, team_list, team_count]
# Index: []

# %% [markdown]
# # Recreate Leauge Table after first two matchdays

# %%
# Assuming goals_df is your original dataset
agg_goals_before_last_day, goals_last_day_sorted = before_last(goals_df)

# %%
home_games, away_games = aggregate_home_away_points(agg_goals_before_last_day)

# %%
# Filter for year == 2022 and stage == 'Group E'
home2022e = home_games[(home_games['year'] == 2022) & (home_games['stage'] == 'Group E')]
home2022e
# Out:
#      year    stage home_team  goals_scored  goals_conceded  points_home  \
# 216  2022  Group E   Germany             1               2            0
# 217  2022  Group E     Japan             0               1            0
# 218  2022  Group E     Spain             8               1            4
#
#      match_count_home
# 216                 1
# 217                 1
# 218                 2

# %%
# Filter for year == 2022 and stage == 'Group E'
away2022e = away_games[(away_games['year'] == 2022) & (away_games['stage'] == 'Group E')]
away2022e
# Out:
#      year    stage   away_team  goals_scored  goals_conceded  points_away  \
# 216  2022  Group E  Costa Rica             1               7            3
# 217  2022  Group E     Germany             1               1            1
# 218  2022  Group E       Japan             2               1            3
#
#      match_count_away
# 216                 2
# 217                 1
# 218                 1

# %% [markdown]
# ## aggregate data after first two match days

# %%
# Applying the fifa_before_last function to the mock data
all_games_before_last = fifa_before_last(home_games, away_games, agg_goals_before_last_day, team_counts)
# Out:
# No missing values in the specified columns.
# No observations where total_matches == 1.
# No observations where total_matches == 0.
#
# === Applying Tiebreaker ===
# Row1: year                       1986
# stage                   Group A
# team                   Bulgaria
# home_team              Bulgaria
# goals_scored_home           1.0
# goals_conceded_home         1.0
# points_home                 1.0
# match_count_home            1.0
# away_team              Bulgaria
# goals_scored_away           1.0
# goals_conceded_away         1.0
# points_away                 1.0
# match_count_away            1.0
# goals_scored                2.0
# goals_conceded              2.0
# points                      2.0
# total_matches               2.0
# goals_difference            0.0
# tiebreaker              no need
# tie_won                       0
# Name: 1, dtype: object
# Row2: year                      1986
# stage                  Group A
# team                     Italy
# home_team                Italy
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           1.0
# away_team                Italy
# goals_scored_away          1.0
# goals_conceded_away        1.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             2.0
# points                     2.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 2, dtype: object
#
# Goal difference: Bulgaria = 0.0, Italy = 0.0
# Goals scored: Bulgaria = 2.0, Italy = 2.0
# Head-to-head match found:
# year                      1986
# stage                  Group A
# home_team             Bulgaria
# away_team                Italy
# local_time               18:00
# short_date          2025-02-17
# goals_home                   1
# goals_away                   1
# original_score             1–1
# calculated_score           1-1
# score_match               True
# won                          0
# Name: 1, dtype: object
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                       1986
# stage                   Group B
# team                   Paraguay
# home_team              Paraguay
# goals_scored_home           1.0
# goals_conceded_home         0.0
# points_home                 2.0
# match_count_home            1.0
# away_team              Paraguay
# goals_scored_away           1.0
# goals_conceded_away         1.0
# points_away                 1.0
# match_count_away            1.0
# goals_scored                2.0
# goals_conceded              1.0
# points                      3.0
# total_matches               2.0
# goals_difference            1.0
# tiebreaker              no need
# tie_won                       0
# Name: 4, dtype: object
# Row2: year                      1986
# stage                  Group B
# team                    Mexico
# home_team               Mexico
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           1.0
# away_team               Mexico
# goals_scored_away          2.0
# goals_conceded_away        1.0
# points_away                2.0
# match_count_away           1.0
# goals_scored               3.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 5, dtype: object
#
# Goal difference: Paraguay = 1.0, Mexico = 1.0
# Goals scored: Paraguay = 2.0, Mexico = 3.0
# Goals scored result: Mexico wins
#
# === Applying Tiebreaker ===
# Row1: year                           1986
# stage                       Group C
# team                   Soviet Union
# home_team              Soviet Union
# goals_scored_home               6.0
# goals_conceded_home             0.0
# points_home                     2.0
# match_count_home                1.0
# away_team              Soviet Union
# goals_scored_away               1.0
# goals_conceded_away             1.0
# points_away                     1.0
# match_count_away                1.0
# goals_scored                    7.0
# goals_conceded                  1.0
# points                          3.0
# total_matches                   2.0
# goals_difference                6.0
# tiebreaker                  no need
# tie_won                           0
# Name: 8, dtype: object
# Row2: year                      1986
# stage                  Group C
# team                    France
# home_team               France
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           1.0
# away_team               France
# goals_scored_away          1.0
# goals_conceded_away        0.0
# points_away                2.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             1.0
# points                     3.0
# total_matches              2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 9, dtype: object
#
# Goal difference: Soviet Union = 6.0, France = 1.0
# Goal difference result: Soviet Union wins
#
# === Applying Tiebreaker ===
# Row1: year                      1986
# stage                  Group D
# team                   Algeria
# home_team              Algeria
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           1.0
# away_team              Algeria
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             2.0
# points                     1.0
# total_matches              2.0
# goals_difference          -1.0
# tiebreaker             no need
# tie_won                      0
# Name: 14, dtype: object
# Row2: year                               1986
# stage                           Group D
# team                   Northern Ireland
# home_team              Northern Ireland
# goals_scored_home                   1.0
# goals_conceded_home                 2.0
# points_home                         0.0
# match_count_home                    1.0
# away_team              Northern Ireland
# goals_scored_away                   1.0
# goals_conceded_away                 1.0
# points_away                         1.0
# match_count_away                    1.0
# goals_scored                        2.0
# goals_conceded                      3.0
# points                              1.0
# total_matches                       2.0
# goals_difference                   -1.0
# tiebreaker                      no need
# tie_won                               0
# Name: 15, dtype: object
#
# Goal difference: Algeria = -1.0, Northern Ireland = -1.0
# Goals scored: Algeria = 1.0, Northern Ireland = 2.0
# Goals scored result: Northern Ireland wins
#
# === Applying Tiebreaker ===
# Row1: year                      1986
# stage                  Group F
# team                   Morocco
# home_team              Morocco
# goals_scored_home          0.0
# goals_conceded_home        0.0
# points_home                1.0
# match_count_home           1.0
# away_team              Morocco
# goals_scored_away          0.0
# goals_conceded_away        0.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               0.0
# goals_conceded             0.0
# points                     2.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 21, dtype: object
# Row2: year                       1986
# stage                   Group F
# team                   Portugal
# home_team              Portugal
# goals_scored_home           1.0
# goals_conceded_home         0.0
# points_home                 2.0
# match_count_home            1.0
# away_team              Portugal
# goals_scored_away           0.0
# goals_conceded_away         1.0
# points_away                 0.0
# match_count_away            1.0
# goals_scored                1.0
# goals_conceded              1.0
# points                      2.0
# total_matches               2.0
# goals_difference            0.0
# tiebreaker              no need
# tie_won                       0
# Name: 22, dtype: object
#
# Goal difference: Morocco = 0.0, Portugal = 0.0
# Goals scored: Morocco = 0.0, Portugal = 1.0
# Goals scored result: Portugal wins
#
# === Applying Tiebreaker ===
# Row1: year                      1990
# stage                  Group A
# team                     Italy
# home_team                Italy
# goals_scored_home          2.0
# goals_conceded_home        0.0
# points_home                4.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               2.0
# goals_conceded             0.0
# points                     4.0
# total_matches              2.0
# goals_difference           2.0
# tiebreaker             no need
# tie_won                      0
# Name: 24, dtype: object
# Row2: year                             1990
# stage                         Group A
# team                   Czechoslovakia
# home_team                         NaN
# goals_scored_home                 NaN
# goals_conceded_home               NaN
# points_home                       NaN
# match_count_home                  NaN
# away_team              Czechoslovakia
# goals_scored_away                 6.0
# goals_conceded_away               1.0
# points_away                       4.0
# match_count_away                  2.0
# goals_scored                      6.0
# goals_conceded                    1.0
# points                            4.0
# total_matches                     2.0
# goals_difference                  5.0
# tiebreaker                    no need
# tie_won                             0
# Name: 25, dtype: object
#
# Goal difference: Italy = 2.0, Czechoslovakia = 5.0
# Goal difference result: Czechoslovakia wins
#
# === Applying Tiebreaker ===
# Row1: year                            1990
# stage                        Group A
# team                   United States
# home_team              United States
# goals_scored_home                1.0
# goals_conceded_home              5.0
# points_home                      0.0
# match_count_home                 1.0
# away_team              United States
# goals_scored_away                0.0
# goals_conceded_away              1.0
# points_away                      0.0
# match_count_away                 1.0
# goals_scored                     1.0
# goals_conceded                   6.0
# points                           0.0
# total_matches                    2.0
# goals_difference                -5.0
# tiebreaker                   no need
# tie_won                            0
# Name: 26, dtype: object
# Row2: year                      1990
# stage                  Group A
# team                   Austria
# home_team              Austria
# goals_scored_home          0.0
# goals_conceded_home        1.0
# points_home                0.0
# match_count_home           1.0
# away_team              Austria
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               0.0
# goals_conceded             2.0
# points                     0.0
# total_matches              2.0
# goals_difference          -2.0
# tiebreaker             no need
# tie_won                      0
# Name: 27, dtype: object
#
# Goal difference: United States = -5.0, Austria = -2.0
# Goal difference result: Austria wins
#
# === Applying Tiebreaker ===
# Row1: year                        1990
# stage                    Group B
# team                   Argentina
# home_team              Argentina
# goals_scored_home            2.0
# goals_conceded_home          1.0
# points_home                  2.0
# match_count_home             2.0
# away_team                    NaN
# goals_scored_away            NaN
# goals_conceded_away          NaN
# points_away                  NaN
# match_count_away             NaN
# goals_scored                 2.0
# goals_conceded               1.0
# points                       2.0
# total_matches                2.0
# goals_difference             1.0
# tiebreaker               no need
# tie_won                        0
# Name: 29, dtype: object
# Row2: year                      1990
# stage                  Group B
# team                   Romania
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Romania
# goals_scored_away          3.0
# goals_conceded_away        2.0
# points_away                2.0
# match_count_away           2.0
# goals_scored               3.0
# goals_conceded             2.0
# points                     2.0
# total_matches              2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 30, dtype: object
#
# Goal difference: Argentina = 1.0, Romania = 1.0
# Goals scored: Argentina = 2.0, Romania = 3.0
# Goals scored result: Romania wins
#
# === Applying Tiebreaker ===
# Row1: year                         1990
# stage                     Group C
# team                   Costa Rica
# home_team              Costa Rica
# goals_scored_home             1.0
# goals_conceded_home           0.0
# points_home                   2.0
# match_count_home              1.0
# away_team              Costa Rica
# goals_scored_away             0.0
# goals_conceded_away           1.0
# points_away                   0.0
# match_count_away              1.0
# goals_scored                  1.0
# goals_conceded                1.0
# points                        2.0
# total_matches                 2.0
# goals_difference              0.0
# tiebreaker                no need
# tie_won                         0
# Name: 33, dtype: object
# Row2: year                       1990
# stage                   Group C
# team                   Scotland
# home_team                   NaN
# goals_scored_home           NaN
# goals_conceded_home         NaN
# points_home                 NaN
# match_count_home            NaN
# away_team              Scotland
# goals_scored_away           2.0
# goals_conceded_away         2.0
# points_away                 2.0
# match_count_away            2.0
# goals_scored                2.0
# goals_conceded              2.0
# points                      2.0
# total_matches               2.0
# goals_difference            0.0
# tiebreaker              no need
# tie_won                       0
# Name: 34, dtype: object
#
# Goal difference: Costa Rica = 0.0, Scotland = 0.0
# Goals scored: Costa Rica = 1.0, Scotland = 2.0
# Goals scored result: Scotland wins
#
# === Applying Tiebreaker ===
# Row1: year                         1990
# stage                     Group D
# team                   Yugoslavia
# home_team              Yugoslavia
# goals_scored_home             1.0
# goals_conceded_home           0.0
# points_home                   2.0
# match_count_home              1.0
# away_team              Yugoslavia
# goals_scored_away             1.0
# goals_conceded_away           4.0
# points_away                   0.0
# match_count_away              1.0
# goals_scored                  2.0
# goals_conceded                4.0
# points                        2.0
# total_matches                 2.0
# goals_difference             -2.0
# tiebreaker                no need
# tie_won                         0
# Name: 37, dtype: object
# Row2: year                       1990
# stage                   Group D
# team                   Colombia
# home_team                   NaN
# goals_scored_home           NaN
# goals_conceded_home         NaN
# points_home                 NaN
# match_count_home            NaN
# away_team              Colombia
# goals_scored_away           2.0
# goals_conceded_away         1.0
# points_away                 2.0
# match_count_away            2.0
# goals_scored                2.0
# goals_conceded              1.0
# points                      2.0
# total_matches               2.0
# goals_difference            1.0
# tiebreaker              no need
# tie_won                       0
# Name: 38, dtype: object
#
# Goal difference: Yugoslavia = -2.0, Colombia = 1.0
# Goal difference result: Colombia wins
#
# === Applying Tiebreaker ===
# Row1: year                      1990
# stage                  Group F
# team                   England
# home_team              England
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                2.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               1.0
# goals_conceded             1.0
# points                     2.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 44, dtype: object
# Row2: year                          1990
# stage                      Group F
# team                   Netherlands
# home_team              Netherlands
# goals_scored_home              1.0
# goals_conceded_home            1.0
# points_home                    1.0
# match_count_home               1.0
# away_team              Netherlands
# goals_scored_away              0.0
# goals_conceded_away            0.0
# points_away                    1.0
# match_count_away               1.0
# goals_scored                   1.0
# goals_conceded                 1.0
# points                         2.0
# total_matches                  2.0
# goals_difference               0.0
# tiebreaker                 no need
# tie_won                          0
# Name: 45, dtype: object
#
# Goal difference: England = 0.0, Netherlands = 0.0
# Goals scored: England = 1.0, Netherlands = 1.0
# Head-to-head match found:
# year                       1990
# stage                   Group F
# home_team               England
# away_team           Netherlands
# local_time                17:00
# short_date           2025-02-17
# goals_home                    0
# goals_away                    0
# original_score              0–0
# calculated_score            0-0
# score_match                True
# won                           0
# Name: 44, dtype: object
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                          1990
# stage                      Group F
# team                   Netherlands
# home_team              Netherlands
# goals_scored_home              1.0
# goals_conceded_home            1.0
# points_home                    1.0
# match_count_home               1.0
# away_team              Netherlands
# goals_scored_away              0.0
# goals_conceded_away            0.0
# points_away                    1.0
# match_count_away               1.0
# goals_scored                   1.0
# goals_conceded                 1.0
# points                         2.0
# total_matches                  2.0
# goals_difference               0.0
# tiebreaker                 no need
# tie_won                          0
# Name: 45, dtype: object
# Row2: year                                  1990
# stage                              Group F
# team                   Republic of Ireland
# home_team              Republic of Ireland
# goals_scored_home                      0.0
# goals_conceded_home                    0.0
# points_home                            1.0
# match_count_home                       1.0
# away_team              Republic of Ireland
# goals_scored_away                      1.0
# goals_conceded_away                    1.0
# points_away                            1.0
# match_count_away                       1.0
# goals_scored                           1.0
# goals_conceded                         1.0
# points                                 2.0
# total_matches                          2.0
# goals_difference                       0.0
# tiebreaker                         no need
# tie_won                                  0
# Name: 46, dtype: object
#
# Goal difference: Netherlands = 0.0, Republic of Ireland = 0.0
# Goals scored: Netherlands = 1.0, Republic of Ireland = 1.0
# No head-to-head match found.
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                                  1990
# stage                              Group F
# team                   Republic of Ireland
# home_team              Republic of Ireland
# goals_scored_home                      0.0
# goals_conceded_home                    0.0
# points_home                            1.0
# match_count_home                       1.0
# away_team              Republic of Ireland
# goals_scored_away                      1.0
# goals_conceded_away                    1.0
# points_away                            1.0
# match_count_away                       1.0
# goals_scored                           1.0
# goals_conceded                         1.0
# points                                 2.0
# total_matches                          2.0
# goals_difference                       0.0
# tiebreaker                         no need
# tie_won                                  0
# Name: 46, dtype: object
# Row2: year                      1990
# stage                  Group F
# team                     Egypt
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team                Egypt
# goals_scored_away          1.0
# goals_conceded_away        1.0
# points_away                2.0
# match_count_away           2.0
# goals_scored               1.0
# goals_conceded             1.0
# points                     2.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 47, dtype: object
#
# Goal difference: Republic of Ireland = 0.0, Egypt = 0.0
# Goals scored: Republic of Ireland = 1.0, Egypt = 1.0
# Head-to-head match found:
# year                               1990
# stage                           Group F
# home_team           Republic of Ireland
# away_team                         Egypt
# local_time                        17:00
# short_date                   2025-02-17
# goals_home                            0
# goals_away                            0
# original_score                      0–0
# calculated_score                    0-0
# score_match                        True
# won                                   0
# Name: 47, dtype: object
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                            1994
# stage                        Group A
# team                   United States
# home_team              United States
# goals_scored_home                3.0
# goals_conceded_home              2.0
# points_home                      4.0
# match_count_home                 2.0
# away_team                        NaN
# goals_scored_away                NaN
# goals_conceded_away              NaN
# points_away                      NaN
# match_count_away                 NaN
# goals_scored                     3.0
# goals_conceded                   2.0
# points                           4.0
# total_matches                    2.0
# goals_difference                 1.0
# tiebreaker                   no need
# tie_won                            0
# Name: 48, dtype: object
# Row2: year                          1994
# stage                      Group A
# team                   Switzerland
# home_team                      NaN
# goals_scored_home              NaN
# goals_conceded_home            NaN
# points_home                    NaN
# match_count_home               NaN
# away_team              Switzerland
# goals_scored_away              5.0
# goals_conceded_away            2.0
# points_away                    4.0
# match_count_away               2.0
# goals_scored                   5.0
# goals_conceded                 2.0
# points                         4.0
# total_matches                  2.0
# goals_difference               3.0
# tiebreaker                 no need
# tie_won                          0
# Name: 49, dtype: object
#
# Goal difference: United States = 1.0, Switzerland = 3.0
# Goal difference result: Switzerland wins
#
# === Applying Tiebreaker ===
# Row1: year                      1994
# stage                  Group C
# team                     Spain
# home_team                Spain
# goals_scored_home          2.0
# goals_conceded_home        2.0
# points_home                1.0
# match_count_home           1.0
# away_team                Spain
# goals_scored_away          1.0
# goals_conceded_away        1.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               3.0
# goals_conceded             3.0
# points                     2.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 57, dtype: object
# Row2: year                          1994
# stage                      Group C
# team                   South Korea
# home_team              South Korea
# goals_scored_home              0.0
# goals_conceded_home            0.0
# points_home                    1.0
# match_count_home               1.0
# away_team              South Korea
# goals_scored_away              2.0
# goals_conceded_away            2.0
# points_away                    1.0
# match_count_away               1.0
# goals_scored                   2.0
# goals_conceded                 2.0
# points                         2.0
# total_matches                  2.0
# goals_difference               0.0
# tiebreaker                 no need
# tie_won                          0
# Name: 58, dtype: object
#
# Goal difference: Spain = 0.0, South Korea = 0.0
# Goals scored: Spain = 3.0, South Korea = 2.0
# Goals scored result: Spain wins
#
# === Applying Tiebreaker ===
# Row1: year                      1994
# stage                  Group D
# team                   Nigeria
# home_team              Nigeria
# goals_scored_home          3.0
# goals_conceded_home        0.0
# points_home                3.0
# match_count_home           1.0
# away_team              Nigeria
# goals_scored_away          1.0
# goals_conceded_away        2.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               4.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# goals_difference           2.0
# tiebreaker             no need
# tie_won                      0
# Name: 61, dtype: object
# Row2: year                       1994
# stage                   Group D
# team                   Bulgaria
# home_team              Bulgaria
# goals_scored_home           4.0
# goals_conceded_home         0.0
# points_home                 3.0
# match_count_home            1.0
# away_team              Bulgaria
# goals_scored_away           0.0
# goals_conceded_away         3.0
# points_away                 0.0
# match_count_away            1.0
# goals_scored                4.0
# goals_conceded              3.0
# points                      3.0
# total_matches               2.0
# goals_difference            1.0
# tiebreaker              no need
# tie_won                       0
# Name: 62, dtype: object
#
# Goal difference: Nigeria = 2.0, Bulgaria = 1.0
# Goal difference result: Nigeria wins
#
# === Applying Tiebreaker ===
# Row1: year                      1994
# stage                  Group E
# team                     Italy
# home_team                Italy
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                3.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               1.0
# goals_conceded             1.0
# points                     3.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 64, dtype: object
# Row2: year                      1994
# stage                  Group E
# team                    Norway
# home_team               Norway
# goals_scored_home          1.0
# goals_conceded_home        0.0
# points_home                3.0
# match_count_home           1.0
# away_team               Norway
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             1.0
# points                     3.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 65, dtype: object
#
# Goal difference: Italy = 0.0, Norway = 0.0
# Goals scored: Italy = 1.0, Norway = 1.0
# Head-to-head match found:
# year                      1994
# stage                  Group E
# home_team                Italy
# away_team               Norway
# local_time               16:00
# short_date          2025-02-17
# goals_home                   1
# goals_away                   0
# original_score             1–0
# calculated_score           1-0
# score_match               True
# won                          1
# Name: 64, dtype: object
# Head-to-head result: Italy wins
#
# === Applying Tiebreaker ===
# Row1: year                      1994
# stage                  Group E
# team                    Norway
# home_team               Norway
# goals_scored_home          1.0
# goals_conceded_home        0.0
# points_home                3.0
# match_count_home           1.0
# away_team               Norway
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             1.0
# points                     3.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker               Italy
# tie_won                      0
# Name: 65, dtype: object
# Row2: year                      1994
# stage                  Group E
# team                    Mexico
# home_team               Mexico
# goals_scored_home          2.0
# goals_conceded_home        1.0
# points_home                3.0
# match_count_home           1.0
# away_team               Mexico
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 66, dtype: object
#
# Goal difference: Norway = 0.0, Mexico = 0.0
# Goals scored: Norway = 1.0, Mexico = 2.0
# Goals scored result: Mexico wins
#
# === Applying Tiebreaker ===
# Row1: year                      1994
# stage                  Group E
# team                    Mexico
# home_team               Mexico
# goals_scored_home          2.0
# goals_conceded_home        1.0
# points_home                3.0
# match_count_home           1.0
# away_team               Mexico
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker              Mexico
# tie_won                      1
# Name: 66, dtype: object
# Row2: year                                  1994
# stage                              Group E
# team                   Republic of Ireland
# home_team                              NaN
# goals_scored_home                      NaN
# goals_conceded_home                    NaN
# points_home                            NaN
# match_count_home                       NaN
# away_team              Republic of Ireland
# goals_scored_away                      2.0
# goals_conceded_away                    2.0
# points_away                            3.0
# match_count_away                       2.0
# goals_scored                           2.0
# goals_conceded                         2.0
# points                                 3.0
# total_matches                          2.0
# goals_difference                       0.0
# tiebreaker                         no need
# tie_won                                  0
# Name: 67, dtype: object
#
# Goal difference: Mexico = 0.0, Republic of Ireland = 0.0
# Goals scored: Mexico = 2.0, Republic of Ireland = 2.0
# Head-to-head match found:
# year                               1994
# stage                           Group E
# home_team                        Mexico
# away_team           Republic of Ireland
# local_time                        12:30
# short_date                   2025-02-17
# goals_home                            2
# goals_away                            1
# original_score                      2–1
# calculated_score                    2-1
# score_match                        True
# won                                   1
# Name: 66, dtype: object
# Head-to-head result: Mexico wins
#
# === Applying Tiebreaker ===
# Row1: year                          1994
# stage                      Group F
# team                   Netherlands
# home_team              Netherlands
# goals_scored_home              2.0
# goals_conceded_home            1.0
# points_home                    3.0
# match_count_home               1.0
# away_team              Netherlands
# goals_scored_away              0.0
# goals_conceded_away            1.0
# points_away                    0.0
# match_count_away               1.0
# goals_scored                   2.0
# goals_conceded                 2.0
# points                         3.0
# total_matches                  2.0
# goals_difference               0.0
# tiebreaker                 no need
# tie_won                          0
# Name: 69, dtype: object
# Row2: year                           1994
# stage                       Group F
# team                   Saudi Arabia
# home_team              Saudi Arabia
# goals_scored_home               2.0
# goals_conceded_home             1.0
# points_home                     3.0
# match_count_home                1.0
# away_team              Saudi Arabia
# goals_scored_away               1.0
# goals_conceded_away             2.0
# points_away                     0.0
# match_count_away                1.0
# goals_scored                    3.0
# goals_conceded                  3.0
# points                          3.0
# total_matches                   2.0
# goals_difference                0.0
# tiebreaker                  no need
# tie_won                           0
# Name: 70, dtype: object
#
# Goal difference: Netherlands = 0.0, Saudi Arabia = 0.0
# Goals scored: Netherlands = 2.0, Saudi Arabia = 3.0
# Goals scored result: Saudi Arabia wins
#
# === Applying Tiebreaker ===
# Row1: year                      1998
# stage                  Group A
# team                   Morocco
# home_team              Morocco
# goals_scored_home          2.0
# goals_conceded_home        2.0
# points_home                1.0
# match_count_home           1.0
# away_team              Morocco
# goals_scored_away          0.0
# goals_conceded_away        3.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             5.0
# points                     1.0
# total_matches              2.0
# goals_difference          -3.0
# tiebreaker             no need
# tie_won                      0
# Name: 74, dtype: object
# Row2: year                       1998
# stage                   Group A
# team                   Scotland
# home_team              Scotland
# goals_scored_home           1.0
# goals_conceded_home         1.0
# points_home                 1.0
# match_count_home            1.0
# away_team              Scotland
# goals_scored_away           1.0
# goals_conceded_away         2.0
# points_away                 0.0
# match_count_away            1.0
# goals_scored                2.0
# goals_conceded              3.0
# points                      1.0
# total_matches               2.0
# goals_difference           -1.0
# tiebreaker              no need
# tie_won                       0
# Name: 75, dtype: object
#
# Goal difference: Morocco = -3.0, Scotland = -1.0
# Goal difference result: Scotland wins
#
# === Applying Tiebreaker ===
# Row1: year                      1998
# stage                  Group B
# team                     Chile
# home_team                Chile
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           1.0
# away_team                Chile
# goals_scored_away          2.0
# goals_conceded_away        2.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               3.0
# goals_conceded             3.0
# points                     2.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 77, dtype: object
# Row2: year                      1998
# stage                  Group B
# team                   Austria
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Austria
# goals_scored_away          2.0
# goals_conceded_away        2.0
# points_away                2.0
# match_count_away           2.0
# goals_scored               2.0
# goals_conceded             2.0
# points                     2.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 78, dtype: object
#
# Goal difference: Chile = 0.0, Austria = 0.0
# Goals scored: Chile = 3.0, Austria = 2.0
# Goals scored result: Chile wins
#
# === Applying Tiebreaker ===
# Row1: year                      1998
# stage                  Group D
# team                     Spain
# home_team                Spain
# goals_scored_home          2.0
# goals_conceded_home        3.0
# points_home                1.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               2.0
# goals_conceded             3.0
# points                     1.0
# total_matches              2.0
# goals_difference          -1.0
# tiebreaker             no need
# tie_won                      0
# Name: 86, dtype: object
# Row2: year                       1998
# stage                   Group D
# team                   Bulgaria
# home_team                   NaN
# goals_scored_home           NaN
# goals_conceded_home         NaN
# points_home                 NaN
# match_count_home            NaN
# away_team              Bulgaria
# goals_scored_away           0.0
# goals_conceded_away         1.0
# points_away                 1.0
# match_count_away            2.0
# goals_scored                0.0
# goals_conceded              1.0
# points                      1.0
# total_matches               2.0
# goals_difference           -1.0
# tiebreaker              no need
# tie_won                       0
# Name: 87, dtype: object
#
# Goal difference: Spain = -1.0, Bulgaria = -1.0
# Goals scored: Spain = 2.0, Bulgaria = 0.0
# Goals scored result: Spain wins
#
# === Applying Tiebreaker ===
# Row1: year                          1998
# stage                      Group E
# team                   Netherlands
# home_team              Netherlands
# goals_scored_home              5.0
# goals_conceded_home            0.0
# points_home                    4.0
# match_count_home               2.0
# away_team                      NaN
# goals_scored_away              NaN
# goals_conceded_away            NaN
# points_away                    NaN
# match_count_away               NaN
# goals_scored                   5.0
# goals_conceded                 0.0
# points                         4.0
# total_matches                  2.0
# goals_difference               5.0
# tiebreaker                 no need
# tie_won                          0
# Name: 88, dtype: object
# Row2: year                      1998
# stage                  Group E
# team                    Mexico
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team               Mexico
# goals_scored_away          5.0
# goals_conceded_away        3.0
# points_away                4.0
# match_count_away           2.0
# goals_scored               5.0
# goals_conceded             3.0
# points                     4.0
# total_matches              2.0
# goals_difference           2.0
# tiebreaker             no need
# tie_won                      0
# Name: 89, dtype: object
#
# Goal difference: Netherlands = 5.0, Mexico = 2.0
# Goal difference result: Netherlands wins
#
# === Applying Tiebreaker ===
# Row1: year                            1998
# stage                        Group F
# team                   FR Yugoslavia
# home_team              FR Yugoslavia
# goals_scored_home                1.0
# goals_conceded_home              0.0
# points_home                      3.0
# match_count_home                 1.0
# away_team              FR Yugoslavia
# goals_scored_away                2.0
# goals_conceded_away              2.0
# points_away                      1.0
# match_count_away                 1.0
# goals_scored                     3.0
# goals_conceded                   2.0
# points                           4.0
# total_matches                    2.0
# goals_difference                 1.0
# tiebreaker                   no need
# tie_won                            0
# Name: 92, dtype: object
# Row2: year                      1998
# stage                  Group F
# team                   Germany
# home_team              Germany
# goals_scored_home          4.0
# goals_conceded_home        2.0
# points_home                4.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               4.0
# goals_conceded             2.0
# points                     4.0
# total_matches              2.0
# goals_difference           2.0
# tiebreaker             no need
# tie_won                      0
# Name: 93, dtype: object
#
# Goal difference: FR Yugoslavia = 1.0, Germany = 2.0
# Goal difference result: Germany wins
#
# === Applying Tiebreaker ===
# Row1: year                      1998
# stage                  Group G
# team                   England
# home_team              England
# goals_scored_home          2.0
# goals_conceded_home        0.0
# points_home                3.0
# match_count_home           1.0
# away_team              England
# goals_scored_away          1.0
# goals_conceded_away        2.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               3.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 97, dtype: object
# Row2: year                       1998
# stage                   Group G
# team                   Colombia
# home_team              Colombia
# goals_scored_home           1.0
# goals_conceded_home         0.0
# points_home                 3.0
# match_count_home            1.0
# away_team              Colombia
# goals_scored_away           0.0
# goals_conceded_away         1.0
# points_away                 0.0
# match_count_away            1.0
# goals_scored                1.0
# goals_conceded              1.0
# points                      3.0
# total_matches               2.0
# goals_difference            0.0
# tiebreaker              no need
# tie_won                       0
# Name: 98, dtype: object
#
# Goal difference: England = 1.0, Colombia = 0.0
# Goal difference result: England wins
#
# === Applying Tiebreaker ===
# Row1: year                        1998
# stage                    Group H
# team                   Argentina
# home_team              Argentina
# goals_scored_home            6.0
# goals_conceded_home          0.0
# points_home                  6.0
# match_count_home             2.0
# away_team                    NaN
# goals_scored_away            NaN
# goals_conceded_away          NaN
# points_away                  NaN
# match_count_away             NaN
# goals_scored                 6.0
# goals_conceded               0.0
# points                       6.0
# total_matches                2.0
# goals_difference             6.0
# tiebreaker               no need
# tie_won                        0
# Name: 100, dtype: object
# Row2: year                      1998
# stage                  Group H
# team                   Croatia
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Croatia
# goals_scored_away          4.0
# goals_conceded_away        1.0
# points_away                6.0
# match_count_away           2.0
# goals_scored               4.0
# goals_conceded             1.0
# points                     6.0
# total_matches              2.0
# goals_difference           3.0
# tiebreaker             no need
# tie_won                      0
# Name: 101, dtype: object
#
# Goal difference: Argentina = 6.0, Croatia = 3.0
# Goal difference result: Argentina wins
#
# === Applying Tiebreaker ===
# Row1: year                      1998
# stage                  Group H
# team                   Jamaica
# home_team              Jamaica
# goals_scored_home          1.0
# goals_conceded_home        3.0
# points_home                0.0
# match_count_home           1.0
# away_team              Jamaica
# goals_scored_away          0.0
# goals_conceded_away        5.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             8.0
# points                     0.0
# total_matches              2.0
# goals_difference          -7.0
# tiebreaker             no need
# tie_won                      0
# Name: 102, dtype: object
# Row2: year                      1998
# stage                  Group H
# team                     Japan
# home_team                Japan
# goals_scored_home          0.0
# goals_conceded_home        1.0
# points_home                0.0
# match_count_home           1.0
# away_team                Japan
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               0.0
# goals_conceded             2.0
# points                     0.0
# total_matches              2.0
# goals_difference          -2.0
# tiebreaker             no need
# tie_won                      0
# Name: 103, dtype: object
#
# Goal difference: Jamaica = -7.0, Japan = -2.0
# Goal difference result: Japan wins
#
# === Applying Tiebreaker ===
# Row1: year                      2002
# stage                  Group A
# team                   Denmark
# home_team              Denmark
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           1.0
# away_team              Denmark
# goals_scored_away          2.0
# goals_conceded_away        1.0
# points_away                3.0
# match_count_away           1.0
# goals_scored               3.0
# goals_conceded             2.0
# points                     4.0
# total_matches              2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 104, dtype: object
# Row2: year                      2002
# stage                  Group A
# team                   Senegal
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Senegal
# goals_scored_away          2.0
# goals_conceded_away        1.0
# points_away                4.0
# match_count_away           2.0
# goals_scored               2.0
# goals_conceded             1.0
# points                     4.0
# total_matches              2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 105, dtype: object
#
# Goal difference: Denmark = 1.0, Senegal = 1.0
# Goals scored: Denmark = 3.0, Senegal = 2.0
# Goals scored result: Denmark wins
#
# === Applying Tiebreaker ===
# Row1: year                      2002
# stage                  Group A
# team                    France
# home_team               France
# goals_scored_home          0.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               0.0
# goals_conceded             1.0
# points                     1.0
# total_matches              2.0
# goals_difference          -1.0
# tiebreaker             no need
# tie_won                      0
# Name: 106, dtype: object
# Row2: year                      2002
# stage                  Group A
# team                   Uruguay
# home_team              Uruguay
# goals_scored_home          1.0
# goals_conceded_home        2.0
# points_home                0.0
# match_count_home           1.0
# away_team              Uruguay
# goals_scored_away          0.0
# goals_conceded_away        0.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             2.0
# points                     1.0
# ...
# stage                  Group F
# home_team              Germany
# away_team               Sweden
# local_time               18:00
# short_date          2025-02-17
# goals_home                   2
# goals_away                   1
# original_score             2–1
# calculated_score           2-1
# score_match               True
# won                          1
# Name: 253, dtype: object
# Head-to-head result: Germany wins
#
# === Applying Tiebreaker ===
# Row1: year                      2018
# stage                  Group G
# team                   Belgium
# home_team              Belgium
# goals_scored_home          8.0
# goals_conceded_home        2.0
# points_home                6.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               8.0
# goals_conceded             2.0
# points                     6.0
# total_matches              2.0
# goals_difference           6.0
# tiebreaker             no need
# tie_won                      0
# Name: 256, dtype: object
# Row2: year                      2018
# stage                  Group G
# team                   England
# home_team              England
# goals_scored_home          6.0
# goals_conceded_home        1.0
# points_home                3.0
# match_count_home           1.0
# away_team              England
# goals_scored_away          2.0
# goals_conceded_away        1.0
# points_away                3.0
# match_count_away           1.0
# goals_scored               8.0
# goals_conceded             2.0
# points                     6.0
# total_matches              2.0
# goals_difference           6.0
# tiebreaker             no need
# tie_won                      0
# Name: 257, dtype: object
#
# Goal difference: Belgium = 6.0, England = 6.0
# Goals scored: Belgium = 8.0, England = 8.0
# No head-to-head match found.
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                      2018
# stage                  Group G
# team                   Tunisia
# home_team              Tunisia
# goals_scored_home          1.0
# goals_conceded_home        2.0
# points_home                0.0
# match_count_home           1.0
# away_team              Tunisia
# goals_scored_away          2.0
# goals_conceded_away        5.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               3.0
# goals_conceded             7.0
# points                     0.0
# total_matches              2.0
# goals_difference          -4.0
# tiebreaker             no need
# tie_won                      0
# Name: 258, dtype: object
# Row2: year                      2018
# stage                  Group G
# team                    Panama
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team               Panama
# goals_scored_away          1.0
# goals_conceded_away        9.0
# points_away                0.0
# match_count_away           2.0
# goals_scored               1.0
# goals_conceded             9.0
# points                     0.0
# total_matches              2.0
# goals_difference          -8.0
# tiebreaker             no need
# tie_won                      0
# Name: 259, dtype: object
#
# Goal difference: Tunisia = -4.0, Panama = -8.0
# Goal difference result: Tunisia wins
#
# === Applying Tiebreaker ===
# Row1: year                      2018
# stage                  Group H
# team                     Japan
# home_team                Japan
# goals_scored_home          2.0
# goals_conceded_home        2.0
# points_home                1.0
# match_count_home           1.0
# away_team                Japan
# goals_scored_away          2.0
# goals_conceded_away        1.0
# points_away                3.0
# match_count_away           1.0
# goals_scored               4.0
# goals_conceded             3.0
# points                     4.0
# total_matches              2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 260, dtype: object
# Row2: year                      2018
# stage                  Group H
# team                   Senegal
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Senegal
# goals_scored_away          4.0
# goals_conceded_away        3.0
# points_away                4.0
# match_count_away           2.0
# goals_scored               4.0
# goals_conceded             3.0
# points                     4.0
# total_matches              2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 261, dtype: object
#
# Goal difference: Japan = 1.0, Senegal = 1.0
# Goals scored: Japan = 4.0, Senegal = 4.0
# Head-to-head match found:
# year                      2018
# stage                  Group H
# home_team                Japan
# away_team              Senegal
# local_time               15:00
# short_date          2025-02-17
# goals_home                   2
# goals_away                   2
# original_score             2–2
# calculated_score           2-2
# score_match               True
# won                          0
# Name: 261, dtype: object
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                          2022
# stage                      Group A
# team                   Netherlands
# home_team              Netherlands
# goals_scored_home              1.0
# goals_conceded_home            1.0
# points_home                    1.0
# match_count_home               1.0
# away_team              Netherlands
# goals_scored_away              2.0
# goals_conceded_away            0.0
# points_away                    3.0
# match_count_away               1.0
# goals_scored                   3.0
# goals_conceded                 1.0
# points                         4.0
# total_matches                  2.0
# goals_difference               2.0
# tiebreaker                 no need
# tie_won                          0
# Name: 264, dtype: object
# Row2: year                      2022
# stage                  Group A
# team                   Ecuador
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Ecuador
# goals_scored_away          3.0
# goals_conceded_away        1.0
# points_away                4.0
# match_count_away           2.0
# goals_scored               3.0
# goals_conceded             1.0
# points                     4.0
# total_matches              2.0
# goals_difference           2.0
# tiebreaker             no need
# tie_won                      0
# Name: 265, dtype: object
#
# Goal difference: Netherlands = 2.0, Ecuador = 2.0
# Goals scored: Netherlands = 3.0, Ecuador = 3.0
# Head-to-head match found:
# year                       2022
# stage                   Group A
# home_team           Netherlands
# away_team               Ecuador
# local_time                19:00
# short_date           2025-02-17
# goals_home                    1
# goals_away                    1
# original_score              1–1
# calculated_score            1-1
# score_match                True
# won                           0
# Name: 264, dtype: object
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                        2022
# stage                    Group C
# team                   Argentina
# home_team              Argentina
# goals_scored_home            3.0
# goals_conceded_home          2.0
# points_home                  3.0
# match_count_home             2.0
# away_team                    NaN
# goals_scored_away            NaN
# goals_conceded_away          NaN
# points_away                  NaN
# match_count_away             NaN
# goals_scored                 3.0
# goals_conceded               2.0
# points                       3.0
# total_matches                2.0
# goals_difference             1.0
# tiebreaker               no need
# tie_won                        0
# Name: 273, dtype: object
# Row2: year                           2022
# stage                       Group C
# team                   Saudi Arabia
# home_team                       NaN
# goals_scored_home               NaN
# goals_conceded_home             NaN
# points_home                     NaN
# match_count_home                NaN
# away_team              Saudi Arabia
# goals_scored_away               2.0
# goals_conceded_away             3.0
# points_away                     3.0
# match_count_away                2.0
# goals_scored                    2.0
# goals_conceded                  3.0
# points                          3.0
# total_matches                   2.0
# goals_difference               -1.0
# tiebreaker                  no need
# tie_won                           0
# Name: 274, dtype: object
#
# Goal difference: Argentina = 1.0, Saudi Arabia = -1.0
# Goal difference result: Argentina wins
#
# === Applying Tiebreaker ===
# Row1: year                      2022
# stage                  Group D
# team                   Denmark
# home_team              Denmark
# goals_scored_home          0.0
# goals_conceded_home        0.0
# points_home                1.0
# match_count_home           1.0
# away_team              Denmark
# goals_scored_away          1.0
# goals_conceded_away        2.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             2.0
# points                     1.0
# total_matches              2.0
# goals_difference          -1.0
# tiebreaker             no need
# tie_won                      0
# Name: 278, dtype: object
# Row2: year                      2022
# stage                  Group D
# team                   Tunisia
# home_team              Tunisia
# goals_scored_home          0.0
# goals_conceded_home        1.0
# points_home                0.0
# match_count_home           1.0
# away_team              Tunisia
# goals_scored_away          0.0
# goals_conceded_away        0.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               0.0
# goals_conceded             1.0
# points                     1.0
# total_matches              2.0
# goals_difference          -1.0
# tiebreaker             no need
# tie_won                      0
# Name: 279, dtype: object
#
# Goal difference: Denmark = -1.0, Tunisia = -1.0
# Goals scored: Denmark = 1.0, Tunisia = 0.0
# Goals scored result: Denmark wins
#
# === Applying Tiebreaker ===
# Row1: year                      2022
# stage                  Group E
# team                     Japan
# home_team                Japan
# goals_scored_home          0.0
# goals_conceded_home        1.0
# points_home                0.0
# match_count_home           1.0
# away_team                Japan
# goals_scored_away          2.0
# goals_conceded_away        1.0
# points_away                3.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 281, dtype: object
# Row2: year                         2022
# stage                     Group E
# team                   Costa Rica
# home_team                     NaN
# goals_scored_home             NaN
# goals_conceded_home           NaN
# points_home                   NaN
# match_count_home              NaN
# away_team              Costa Rica
# goals_scored_away             1.0
# goals_conceded_away           7.0
# points_away                   3.0
# match_count_away              2.0
# goals_scored                  1.0
# goals_conceded                7.0
# points                        3.0
# total_matches                 2.0
# goals_difference             -6.0
# tiebreaker                no need
# tie_won                         0
# Name: 282, dtype: object
#
# Goal difference: Japan = 0.0, Costa Rica = -6.0
# Goal difference result: Japan wins
#
# === Applying Tiebreaker ===
# Row1: year                      2022
# stage                  Group F
# team                   Morocco
# home_team              Morocco
# goals_scored_home          0.0
# goals_conceded_home        0.0
# points_home                1.0
# match_count_home           1.0
# away_team              Morocco
# goals_scored_away          2.0
# goals_conceded_away        0.0
# points_away                3.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             0.0
# points                     4.0
# total_matches              2.0
# goals_difference           2.0
# tiebreaker             no need
# tie_won                      0
# Name: 284, dtype: object
# Row2: year                      2022
# stage                  Group F
# team                   Croatia
# home_team              Croatia
# goals_scored_home          4.0
# goals_conceded_home        1.0
# points_home                3.0
# match_count_home           1.0
# away_team              Croatia
# goals_scored_away          0.0
# goals_conceded_away        0.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               4.0
# goals_conceded             1.0
# points                     4.0
# total_matches              2.0
# goals_difference           3.0
# tiebreaker             no need
# tie_won                      0
# Name: 285, dtype: object
#
# Goal difference: Morocco = 2.0, Croatia = 3.0
# Goal difference result: Croatia wins
#
# === Applying Tiebreaker ===
# Row1: year                       2022
# stage                   Group G
# team                   Cameroon
# home_team              Cameroon
# goals_scored_home           3.0
# goals_conceded_home         3.0
# points_home                 1.0
# match_count_home            1.0
# away_team              Cameroon
# goals_scored_away           0.0
# goals_conceded_away         1.0
# points_away                 0.0
# match_count_away            1.0
# goals_scored                3.0
# goals_conceded              4.0
# points                      1.0
# total_matches               2.0
# goals_difference           -1.0
# tiebreaker              no need
# tie_won                       0
# Name: 290, dtype: object
# Row2: year                      2022
# stage                  Group G
# team                    Serbia
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team               Serbia
# goals_scored_away          3.0
# goals_conceded_away        5.0
# points_away                1.0
# match_count_away           2.0
# goals_scored               3.0
# goals_conceded             5.0
# points                     1.0
# total_matches              2.0
# goals_difference          -2.0
# tiebreaker             no need
# tie_won                      0
# Name: 291, dtype: object
#
# Goal difference: Cameroon = -1.0, Serbia = -2.0
# Goal difference result: Cameroon wins
#
# === Applying Tiebreaker ===
# Row1: year                      2022
# stage                  Group H
# team                   Uruguay
# home_team              Uruguay
# goals_scored_home          0.0
# goals_conceded_home        0.0
# points_home                1.0
# match_count_home           1.0
# away_team              Uruguay
# goals_scored_away          0.0
# goals_conceded_away        2.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               0.0
# goals_conceded             2.0
# points                     1.0
# total_matches              2.0
# goals_difference          -2.0
# tiebreaker             no need
# tie_won                      0
# Name: 294, dtype: object
# Row2: year                          2022
# stage                      Group H
# team                   South Korea
# home_team              South Korea
# goals_scored_home              2.0
# goals_conceded_home            3.0
# points_home                    0.0
# match_count_home               1.0
# away_team              South Korea
# goals_scored_away              0.0
# goals_conceded_away            0.0
# points_away                    1.0
# match_count_away               1.0
# goals_scored                   2.0
# goals_conceded                 3.0
# points                         1.0
# total_matches                  2.0
# goals_difference              -1.0
# tiebreaker                 no need
# tie_won                          0
# Name: 295, dtype: object
#
# Goal difference: Uruguay = -2.0, South Korea = -1.0
# Goal difference result: South Korea wins

# %%
# Filtering all_games_before_last for the year 2022 and stage 'Group E'
group2022e = all_games_before_last[
    (all_games_before_last['year'] == 2022) & 
    (all_games_before_last['stage'] == 'Group E')
]

display(group2022e)
# Out:
#      year    stage        team  goals_scored  goals_conceded  points  \
# 280  2022  Group E       Spain             8               1       4
# 281  2022  Group E       Japan             2               2       3
# 282  2022  Group E  Costa Rica             1               7       3
# 283  2022  Group E     Germany             2               3       1
#
#      goals_difference  total_matches  standing tiebreaker  tie_won
# 280                 7              2         1    no need        0
# 281                 0              2         2      Japan        1
# 282                -6              2         3      Japan        0
# 283                -1              2         4    no need        0

# %% [markdown]
# # Recreate league table after last match day

# %%
# Initialize an empty list to store the results for each pair
all_results = []

# Get unique pairs of year and group_name
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    group_name = row['stage']
    
    # Apply the function to the current pair
    result = fifa_final_wc(year, group_name, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_results.append(result)

# Concatenate all the results into a single DataFrame
changes_df_wc = pd.concat(all_results)


# Keep only the specified columns
changes_df_wc = changes_df_wc[['year', 'stage', 'team', '1st', '2nd', '3rd', '4th', 'changes']]
# Out:
# === Initial Standings for Year 1986, Group A Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_points  before_last_game_standing
#   Argentina             4                   4                     2                       2                        3                          1
#    Bulgaria             3                   2                     2                       0                        2                          2
#       Italy             3                   2                     2                       0                        2                          3
# South Korea             2                   2                     4                      -2                        1                          4
#
# ====================================================
#
# Analyzing goal: 0 minute, 1 half time, Player team: nan, Home: Argentina, Away: Bulgaria
#
# === Teams with Identical Points (Tied Teams) ===
#
#        team  total_points
# 1  Bulgaria             3
# 2     Italy             3
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Bulgaria and Italy
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group A
# team                               Bulgaria
# tiebreaker                          no need
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           2
# before_last_game_standing                 2
# before_last_game_points                   2
# last_game_goals_scored                    0
# last_game_goals_conceded                  0
# total_goals_scored                        2
# total_goals_conceded                      2
# total_goals_difference                    0
# last_game_points                          1
# total_points                              3
# last_game_standing                        2
# 1st                                       0
# 2nd                                       1
# 3rd                                       0
# 4th                                       0
# changes                                   0
# tied                                   True
# Name: 1, dtype: object
# Row2: year                                  1986
# stage                              Group A
# team                                 Italy
# tiebreaker                         no need
# tie_won                                  0
# before_last_game_goals_scored            2
# before_last_game_goals_conceded          2
# before_last_game_standing                3
# before_last_game_points                  2
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       2
# total_goals_conceded                     2
# total_goals_difference                   0
# last_game_points                         1
# total_points                             3
# last_game_standing                       3
# 1st                                      0
# 2nd                                      0
# 3rd                                      1
# 4th                                      0
# changes                                  0
# tied                                  True
# Name: 2, dtype: object
#
# Goal difference: Bulgaria = 0, Italy = 0
# Goals scored: Bulgaria = 2, Italy = 2
# Head-to-head match found:
# year                      1986
# stage                  Group A
# home_team             Bulgaria
# away_team                Italy
# local_time               18:00
# short_date          2025-02-17
# goals_home                   1
# goals_away                   1
# original_score             1–1
# calculated_score           1-1
# score_match               True
# won                          0
# Name: 1, dtype: object
# All criteria tied. Result: tie
# No winner in tiebreak between Bulgaria and Italy
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             4                       2
# 1     Bulgaria                   2             3                       0
# 2        Italy                   3             3                       0
# 3  South Korea                   4             2                      -2
#
#    tie_won
# 0        0
# 1        0
# 2        0
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina             4                   4                     2                       2                 1                   1        1    1    0    0    0 False        0
#    Bulgaria             3                   2                     2                       0                 1                   2        1    0    1    0    0  True        0
#       Italy             3                   2                     2                       0                 1                   3        1    0    0    1    0  True        0
# South Korea             2                   2                     4                      -2                 1                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 4 minute, 1 half time, Player team: Argentina, Home: Argentina, Away: Bulgaria
#
# === Teams with Identical Points (Tied Teams) ===
#
#           team  total_points
# 1     Bulgaria             2
# 3  South Korea             2
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Bulgaria and South Korea
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group A
# team                               Bulgaria
# tiebreaker                          no need
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           2
# before_last_game_standing                 2
# before_last_game_points                   2
# last_game_goals_scored                    0
# last_game_goals_conceded                  1
# total_goals_scored                        2
# total_goals_conceded                      3
# total_goals_difference                   -1
# last_game_points                          0
# total_points                              2
# last_game_standing                        2
# 1st                                       0
# 2nd                                       1
# 3rd                                       0
# 4th                                       0
# changes                                   1
# tied                                   True
# Name: 1, dtype: object
# Row2: year                                      1986
# stage                                  Group A
# team                               South Korea
# tiebreaker                             no need
# tie_won                                      0
# before_last_game_goals_scored                2
# before_last_game_goals_conceded              4
# before_last_game_standing                    4
# before_last_game_points                      1
# last_game_goals_scored                       0
# last_game_goals_conceded                     0
# total_goals_scored                           2
# total_goals_conceded                         4
# total_goals_difference                      -2
# last_game_points                             1
# total_points                                 2
# last_game_standing                           4
# 1st                                          0
# 2nd                                          0
# 3rd                                          0
# 4th                                          1
# changes                                      1
# tied                                      True
# Name: 3, dtype: object
#
# Goal difference: Bulgaria = -1, South Korea = -2
# Goal difference result: Bulgaria wins
# Tiebreak Result: Winner is Bulgaria
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             5                       3
# 2        Italy                   2             3                       0
# 1     Bulgaria                   3             2                      -1
# 3  South Korea                   4             2                      -2
#
#    tie_won
# 0        0
# 2        0
# 1        1
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina             5                   5                     2                       3                 2                   1        1    1    0    0    0 False        0
#       Italy             3                   2                     2                       0                 1                   2        2    0    1    1    0 False        0
#    Bulgaria             2                   2                     3                      -1                 0                   3        2    0    1    1    0  True        1
# South Korea             2                   2                     4                      -2                 1                   4        1    0    0    0    1  True        0
#
# ========================================
#
# Analyzing goal: 17 minute, 1 half time, Player team: Italy, Home: South Korea, Away: Italy
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             5                       3
# 2        Italy                   2             4                       1
# 1     Bulgaria                   3             2                      -1
# 3  South Korea                   4             1                      -3
#
#    tie_won
# 0        0
# 2        0
# 1        0
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina             5                   5                     2                       3                 2                   1        1    1    0    0    0 False        0
#       Italy             4                   3                     2                       1                 2                   2        2    0    1    1    0 False        0
#    Bulgaria             2                   2                     3                      -1                 0                   3        2    0    1    1    0 False        0
# South Korea             1                   2                     5                      -3                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 62 minute, 2 half time, Player team: South Korea, Home: South Korea, Away: Italy
#
# === Teams with Identical Points (Tied Teams) ===
#
#           team  total_points
# 1     Bulgaria             2
# 3  South Korea             2
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Bulgaria and South Korea
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group A
# team                               Bulgaria
# tiebreaker                          no need
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           2
# before_last_game_standing                 2
# before_last_game_points                   2
# last_game_goals_scored                    0
# last_game_goals_conceded                  1
# total_goals_scored                        2
# total_goals_conceded                      3
# total_goals_difference                   -1
# last_game_points                          0
# total_points                              2
# last_game_standing                        3
# 1st                                       0
# 2nd                                       1
# 3rd                                       1
# 4th                                       0
# changes                                   2
# tied                                   True
# Name: 1, dtype: object
# Row2: year                                      1986
# stage                                  Group A
# team                               South Korea
# tiebreaker                             no need
# tie_won                                      0
# before_last_game_goals_scored                2
# before_last_game_goals_conceded              4
# before_last_game_standing                    4
# before_last_game_points                      1
# last_game_goals_scored                       1
# last_game_goals_conceded                     1
# total_goals_scored                           3
# total_goals_conceded                         5
# total_goals_difference                      -2
# last_game_points                             1
# total_points                                 2
# last_game_standing                           4
# 1st                                          0
# 2nd                                          0
# 3rd                                          0
# 4th                                          1
# changes                                      1
# tied                                      True
# Name: 3, dtype: object
#
# Goal difference: Bulgaria = -1, South Korea = -2
# Goal difference result: Bulgaria wins
# Tiebreak Result: Winner is Bulgaria
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             5                       3
# 2        Italy                   2             3                       0
# 1     Bulgaria                   3             2                      -1
# 3  South Korea                   4             2                      -2
#
#    tie_won
# 0        0
# 2        0
# 1        1
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina             5                   5                     2                       3                 2                   1        1    1    0    0    0 False        0
#       Italy             3                   3                     3                       0                 1                   2        2    0    1    1    0 False        0
#    Bulgaria             2                   2                     3                      -1                 0                   3        2    0    1    1    0  True        1
# South Korea             2                   3                     5                      -2                 1                   4        1    0    0    0    1  True        0
#
# ========================================
#
# Analyzing goal: 73 minute, 2 half time, Player team: Italy, Home: South Korea, Away: Italy
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             5                       3
# 2        Italy                   2             4                       1
# 1     Bulgaria                   3             2                      -1
# 3  South Korea                   4             1                      -3
#
#    tie_won
# 0        0
# 2        0
# 1        0
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina             5                   5                     2                       3                 2                   1        1    1    0    0    0 False        0
#       Italy             4                   4                     3                       1                 2                   2        2    0    1    1    0 False        0
#    Bulgaria             2                   2                     3                      -1                 0                   3        2    0    1    1    0 False        0
# South Korea             1                   3                     6                      -3                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 77 minute, 2 half time, Player team: Argentina, Home: Argentina, Away: Bulgaria
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             5                       4
# 2        Italy                   2             4                       1
# 1     Bulgaria                   3             2                      -2
# 3  South Korea                   4             1                      -3
#
#    tie_won
# 0        0
# 2        0
# 1        0
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina             5                   6                     2                       4                 2                   1        1    1    0    0    0 False        0
#       Italy             4                   4                     3                       1                 2                   2        2    0    1    1    0 False        0
#    Bulgaria             2                   2                     4                      -2                 0                   3        2    0    1    1    0 False        0
# South Korea             1                   3                     6                      -3                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 82 minute, 2 half time, Player team: Italy, Home: South Korea, Away: Italy
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             5                       4
# 2        Italy                   2             4                       2
# 1     Bulgaria                   3             2                      -2
# 3  South Korea                   4             1                      -4
#
#    tie_won
# 0        0
# 2        0
# 1        0
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina             5                   6                     2                       4                 2                   1        1    1    0    0    0 False        0
#       Italy             4                   5                     3                       2                 2                   2        2    0    1    1    0 False        0
#    Bulgaria             2                   2                     4                      -2                 0                   3        2    0    1    1    0 False        0
# South Korea             1                   3                     7                      -4                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 89 minute, 2 half time, Player team: South Korea, Home: South Korea, Away: Italy
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             5                       4
# 2        Italy                   2             4                       1
# 1     Bulgaria                   3             2                      -2
# 3  South Korea                   4             1                      -3
#
#    tie_won
# 0        0
# 2        0
# 1        0
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina             5                   6                     2                       4                 2                   1        1    1    0    0    0 False        0
#       Italy             4                   5                     4                       1                 2                   2        2    0    1    1    0 False        0
#    Bulgaria             2                   2                     4                      -2                 0                   3        2    0    1    1    0 False        0
# South Korea             1                   4                     7                      -3                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group B Before Last Match Goals ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_points  before_last_game_standing
#   Mexico             4                   3                     2                       1                        3                          1
# Paraguay             4                   2                     1                       1                        3                          2
#  Belgium             3                   3                     3                       0                        2                          3
#     Iraq             1                   1                     3                      -2                        0                          4
#
# ====================================================
#
# Analyzing goal: 0 minute, 1 half time, Player team: nan, Home: Iraq, Away: Mexico
#
# === Teams with Identical Points (Tied Teams) ===
#
#        team  total_points
# 4    Mexico             4
# 5  Paraguay             4
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Mexico and Paraguay
#
# === Applying Tiebreaker ===
# Row1: year                                  1986
# stage                              Group B
# team                                Mexico
# tiebreaker                          Mexico
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          2
# before_last_game_standing                1
# before_last_game_points                  3
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       3
# total_goals_conceded                     2
# total_goals_difference                   1
# last_game_points                         1
# total_points                             4
# last_game_standing                       1
# 1st                                      1
# 2nd                                      0
# 3rd                                      0
# 4th                                      0
# changes                                  0
# tied                                  True
# Name: 4, dtype: object
# Row2: year                                   1986
# stage                               Group B
# team                               Paraguay
# tiebreaker                           Mexico
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           1
# before_last_game_standing                 2
# before_last_game_points                   3
# last_game_goals_scored                    0
# last_game_goals_conceded                  0
# total_goals_scored                        2
# total_goals_conceded                      1
# total_goals_difference                    1
# last_game_points                          1
# total_points                              4
# last_game_standing                        2
# 1st                                       0
# 2nd                                       1
# 3rd                                       0
# 4th                                       0
# changes                                   0
# tied                                   True
# Name: 5, dtype: object
#
# Goal difference: Mexico = 1, Paraguay = 1
# Goals scored: Mexico = 3, Paraguay = 2
# Goals scored result: Mexico wins
# Tiebreak Result: Winner is Mexico
#
# === Updated Standings After Sorting and Tie Break ===
#
#        team  last_game_standing  total_points  total_goals_difference  tie_won
# 4    Mexico                   1             4                       1        1
# 5  Paraguay                   2             4                       1        0
# 6   Belgium                   3             3                       0        0
# 7      Iraq                   4             1                      -2        0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Mexico             4                   3                     2                       1                 1                   1        1    1    0    0    0  True        1
# Paraguay             4                   2                     1                       1                 1                   2        1    0    1    0    0  True        0
#  Belgium             3                   3                     3                       0                 1                   3        1    0    0    1    0 False        0
#     Iraq             1                   1                     3                      -2                 1                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 30 minute, 1 half time, Player team: Belgium, Home: Paraguay, Away: Belgium
#
# === Teams with Identical Points (Tied Teams) ===
#
#       team  total_points
# 4   Mexico             4
# 6  Belgium             4
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Mexico and Belgium
#
# === Applying Tiebreaker ===
# Row1: year                                  1986
# stage                              Group B
# team                                Mexico
# tiebreaker                          Mexico
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          2
# before_last_game_standing                1
# before_last_game_points                  3
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       3
# total_goals_conceded                     2
# total_goals_difference                   1
# last_game_points                         1
# total_points                             4
# last_game_standing                       1
# 1st                                      1
# 2nd                                      0
# 3rd                                      0
# 4th                                      0
# changes                                  1
# tied                                  True
# Name: 4, dtype: object
# Row2: year                                  1986
# stage                              Group B
# team                               Belgium
# tiebreaker                         no need
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          3
# before_last_game_standing                3
# before_last_game_points                  2
# last_game_goals_scored                   1
# last_game_goals_conceded                 0
# total_goals_scored                       4
# total_goals_conceded                     3
# total_goals_difference                   1
# last_game_points                         2
# total_points                             4
# last_game_standing                       3
# 1st                                      0
# 2nd                                      0
# 3rd                                      1
# 4th                                      0
# changes                                  1
# tied                                  True
# Name: 6, dtype: object
#
# Goal difference: Mexico = 1, Belgium = 1
# Goals scored: Mexico = 3, Belgium = 4
# Goals scored result: Belgium wins
# Tiebreak Result: Winner is Belgium
#
# === Updated Standings After Sorting and Tie Break ===
#
#        team  last_game_standing  total_points  total_goals_difference  tie_won
# 6   Belgium                   1             4                       1        1
# 4    Mexico                   2             4                       1        0
# 5  Paraguay                   3             3                       0        0
# 7      Iraq                   4             1                      -2        0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#  Belgium             4                   4                     3                       1                 2                   1        2    1    0    1    0  True        1
#   Mexico             4                   3                     2                       1                 1                   2        2    1    1    0    0  True        0
# Paraguay             3                   2                     2                       0                 0                   3        2    0    1    1    0 False        0
#     Iraq             1                   1                     3                      -2                 1                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 50 minute, 2 half time, Player team: Paraguay, Home: Paraguay, Away: Belgium
#
# === Teams with Identical Points (Tied Teams) ===
#
#        team  total_points
# 4    Mexico             4
# 5  Paraguay             4
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Mexico and Paraguay
#
# === Applying Tiebreaker ===
# Row1: year                                  1986
# stage                              Group B
# team                                Mexico
# tiebreaker                          Mexico
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          2
# before_last_game_standing                1
# before_last_game_points                  3
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       3
# total_goals_conceded                     2
# total_goals_difference                   1
# last_game_points                         1
# total_points                             4
# last_game_standing                       2
# 1st                                      1
# 2nd                                      1
# 3rd                                      0
# 4th                                      0
# changes                                  2
# tied                                  True
# Name: 4, dtype: object
# Row2: year                                   1986
# stage                               Group B
# team                               Paraguay
# tiebreaker                           Mexico
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           1
# before_last_game_standing                 2
# before_last_game_points                   3
# last_game_goals_scored                    1
# last_game_goals_conceded                  1
# total_goals_scored                        3
# total_goals_conceded                      2
# total_goals_difference                    1
# last_game_points                          1
# total_points                              4
# last_game_standing                        3
# 1st                                       0
# 2nd                                       1
# 3rd                                       1
# 4th                                       0
# changes                                   2
# tied                                   True
# Name: 5, dtype: object
#
# Goal difference: Mexico = 1, Paraguay = 1
# Goals scored: Mexico = 3, Paraguay = 3
# Head-to-head match found:
# year                      1986
# stage                  Group B
# home_team               Mexico
# away_team             Paraguay
# local_time               18:00
# short_date          2025-02-17
# goals_home                   1
# goals_away                   1
# original_score             1–1
# calculated_score           1-1
# score_match               True
# won                          0
# Name: 6, dtype: object
# All criteria tied. Result: tie
# No winner in tiebreak between Mexico and Paraguay
#
# === Updated Standings After Sorting and Tie Break ===
#
#        team  last_game_standing  total_points  total_goals_difference  tie_won
# 4    Mexico                   1             4                       1        0
# 5  Paraguay                   2             4                       1        0
# 6   Belgium                   3             3                       0        0
# 7      Iraq                   4             1                      -2        0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Mexico             4                   3                     2                       1                 1                   1        3    2    1    0    0  True        0
# Paraguay             4                   3                     2                       1                 1                   2        3    0    2    1    0  True        0
#  Belgium             3                   4                     4                       0                 1                   3        3    1    0    2    0 False        0
#     Iraq             1                   1                     3                      -2                 1                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 54 minute, 2 half time, Player team: Mexico, Home: Iraq, Away: Mexico
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#        team  last_game_standing  total_points  total_goals_difference  tie_won
# 4    Mexico                   1             5                       2        0
# 5  Paraguay                   2             4                       1        0
# 6   Belgium                   3             3                       0        0
# 7      Iraq                   4             0                      -3        0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Mexico             5                   4                     2                       2                 2                   1        3    2    1    0    0 False        0
# Paraguay             4                   3                     2                       1                 1                   2        3    0    2    1    0 False        0
#  Belgium             3                   4                     4                       0                 1                   3        3    1    0    2    0 False        0
#     Iraq             0                   1                     4                      -3                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 59 minute, 2 half time, Player team: Belgium, Home: Paraguay, Away: Belgium
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#        team  last_game_standing  total_points  total_goals_difference  tie_won
# 4    Mexico                   1             5                       2        0
# 6   Belgium                   2             4                       1        0
# 5  Paraguay                   3             3                       0        0
# 7      Iraq                   4             0                      -3        0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Mexico             5                   4                     2                       2                 2                   1        3    2    1    0    0 False        0
#  Belgium             4                   5                     4                       1                 2                   2        4    1    1    2    0 False        0
# Paraguay             3                   3                     3                       0                 0                   3        4    0    2    2    0 False        0
#     Iraq             0                   1                     4                      -3                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 76 minute, 2 half time, Player team: Paraguay, Home: Paraguay, Away: Belgium
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#        team  last_game_standing  total_points  total_goals_difference  tie_won
# 4    Mexico                   1             5                       2        0
# 5  Paraguay                   2             4                       1        0
# 6   Belgium                   3             3                       0        0
# 7      Iraq                   4             0                      -3        0
#
# === Updated Standings After This Goal ===
#
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Mexico             5                   4                     2                       2                 2                   1        3    2    1    0    0 False        0
# Paraguay             4                   4                     3                       1                 1                   2        5    0    3    2    0 False        0
#  Belgium             3                   5                     5                       0                 1                   3        5    1    1    3    0 False        0
#     Iraq             0                   1                     4                      -3                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group C Before Last Match Goals ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_points  before_last_game_standing
# Soviet Union             4                   7                     1                       6                        3                          1
#       France             4                   2                     1                       1                        3                          2
#      Hungary             3                   2                     6                      -4                        2                          3
#       Canada             1                   0                     3                      -3                        0                          4
#
# ====================================================
#
# Analyzing goal: 0 minute, 1 half time, Player team: nan, Home: Hungary, Away: France
#
# === Teams with Identical Points (Tied Teams) ===
#
#            team  total_points
# 8  Soviet Union             4
# 9        France             4
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Soviet Union and France
#
# === Applying Tiebreaker ===
# Row1: year                                       1986
# stage                                   Group C
# team                               Soviet Union
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 7
# before_last_game_goals_conceded               1
# before_last_game_standing                     1
# before_last_game_points                       3
# last_game_goals_scored                        0
# last_game_goals_conceded                      0
# total_goals_scored                            7
# total_goals_conceded                          1
# total_goals_difference                        6
# last_game_points                              1
# total_points                                  4
# last_game_standing                            1
# 1st                                           1
# 2nd                                           0
# 3rd                                           0
# 4th                                           0
# changes                                       0
# tied                                       True
# Name: 8, dtype: object
# Row2: year                                       1986
# stage                                   Group C
# team                                     France
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 2
# before_last_game_goals_conceded               1
# before_last_game_standing                     2
# before_last_game_points                       3
# last_game_goals_scored                        0
# last_game_goals_conceded                      0
# total_goals_scored                            2
# total_goals_conceded                          1
# total_goals_difference                        1
# last_game_points                              1
# total_points                                  4
# last_game_standing                            2
# 1st                                           0
# 2nd                                           1
# 3rd                                           0
# 4th                                           0
# changes                                       0
# tied                                       True
# Name: 9, dtype: object
#
# Goal difference: Soviet Union = 6, France = 1
# Goal difference result: Soviet Union wins
# Tiebreak Result: Winner is Soviet Union
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 8   Soviet Union                   1             4                       6
# 9         France                   2             4                       1
# 10       Hungary                   3             3                      -4
# 11        Canada                   4             1                      -3
#
#     tie_won
# 8         1
# 9         0
# 10        0
# 11        0
#
# === Updated Standings After This Goal ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
# Soviet Union             4                   7                     1                       6                 1                   1        1    1    0    0    0  True        1
#       France             4                   2                     1                       1                 1                   2        1    0    1    0    0  True        0
#      Hungary             3                   2                     6                      -4                 1                   3        1    0    0    1    0 False        0
#       Canada             1                   0                     3                      -3                 1                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 0 minute, 1 half time, Player team: nan, Home: Soviet Union, Away: Canada
#
# === Teams with Identical Points (Tied Teams) ===
#
#            team  total_points
# 8  Soviet Union             4
# 9        France             4
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Soviet Union and France
#
# === Applying Tiebreaker ===
# Row1: year                                       1986
# stage                                   Group C
# team                               Soviet Union
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 7
# before_last_game_goals_conceded               1
# before_last_game_standing                     1
# before_last_game_points                       3
# last_game_goals_scored                        0
# last_game_goals_conceded                      0
# total_goals_scored                            7
# total_goals_conceded                          1
# total_goals_difference                        6
# last_game_points                              1
# total_points                                  4
# last_game_standing                            1
# 1st                                           1
# 2nd                                           0
# 3rd                                           0
# 4th                                           0
# changes                                       1
# tied                                       True
# Name: 8, dtype: object
# Row2: year                                       1986
# stage                                   Group C
# team                                     France
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 2
# before_last_game_goals_conceded               1
# before_last_game_standing                     2
# before_last_game_points                       3
# last_game_goals_scored                        0
# last_game_goals_conceded                      0
# total_goals_scored                            2
# total_goals_conceded                          1
# total_goals_difference                        1
# last_game_points                              1
# total_points                                  4
# last_game_standing                            2
# 1st                                           0
# 2nd                                           1
# 3rd                                           0
# 4th                                           0
# changes                                       1
# tied                                       True
# Name: 9, dtype: object
#
# Goal difference: Soviet Union = 6, France = 1
# Goal difference result: Soviet Union wins
# Tiebreak Result: Winner is Soviet Union
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 8   Soviet Union                   1             4                       6
# 9         France                   2             4                       1
# 10       Hungary                   3             3                      -4
# 11        Canada                   4             1                      -3
#
#     tie_won
# 8         1
# 9         0
# 10        0
# 11        0
#
# === Updated Standings After This Goal ===
#
# ...
#
#
# === Initial Standings for Year 2022, Group H Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_points  before_last_game_standing
#    Portugal             7                   5                     2                       3                        6                          1
#       Ghana             4                   5                     5                       0                        3                          2
# South Korea             2                   2                     3                      -1                        1                          3
#     Uruguay             2                   0                     2                      -2                        1                          4
#
# ====================================================
#
# Analyzing goal: 0 minute, 1 half time, Player team: nan, Home: Ghana, Away: Uruguay
#
# === Teams with Identical Points (Tied Teams) ===
#
#             team  total_points
# 294  South Korea             2
# 295      Uruguay             2
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: South Korea and Uruguay
#
# === Applying Tiebreaker ===
# Row1: year                                      2022
# stage                                  Group H
# team                               South Korea
# tiebreaker                         South Korea
# tie_won                                      0
# before_last_game_goals_scored                2
# before_last_game_goals_conceded              3
# before_last_game_standing                    3
# before_last_game_points                      1
# last_game_goals_scored                       0
# last_game_goals_conceded                     0
# total_goals_scored                           2
# total_goals_conceded                         3
# total_goals_difference                      -1
# last_game_points                             1
# total_points                                 2
# last_game_standing                           3
# 1st                                          0
# 2nd                                          0
# 3rd                                          1
# 4th                                          0
# changes                                      0
# tied                                      True
# Name: 294, dtype: object
# Row2: year                                      2022
# stage                                  Group H
# team                                   Uruguay
# tiebreaker                         South Korea
# tie_won                                      0
# before_last_game_goals_scored                0
# before_last_game_goals_conceded              2
# before_last_game_standing                    4
# before_last_game_points                      1
# last_game_goals_scored                       0
# last_game_goals_conceded                     0
# total_goals_scored                           0
# total_goals_conceded                         2
# total_goals_difference                      -2
# last_game_points                             1
# total_points                                 2
# last_game_standing                           4
# 1st                                          0
# 2nd                                          0
# 3rd                                          0
# 4th                                          1
# changes                                      0
# tied                                      True
# Name: 295, dtype: object
#
# Goal difference: South Korea = -1, Uruguay = -2
# Goal difference result: South Korea wins
# Tiebreak Result: Winner is South Korea
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 292     Portugal                   1             7                       3
# 293        Ghana                   2             4                       0
# 294  South Korea                   3             2                      -1
# 295      Uruguay                   4             2                      -2
#
#      tie_won
# 292        0
# 293        0
# 294        1
# 295        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#    Portugal             7                   5                     2                       3                 1                   1        1    1    0    0    0 False        0
#       Ghana             4                   5                     5                       0                 1                   2        1    0    1    0    0 False        0
# South Korea             2                   2                     3                      -1                 1                   3        1    0    0    1    0  True        1
#     Uruguay             2                   0                     2                      -2                 1                   4        1    0    0    0    1  True        0
#
# ========================================
#
# Analyzing goal: 5 minute, 1 half time, Player team: Portugal, Home: South Korea, Away: Portugal
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 292     Portugal                   1             9                       4
# 293        Ghana                   2             4                       0
# 295      Uruguay                   3             2                      -2
# 294  South Korea                   4             1                      -2
#
#      tie_won
# 292        0
# 293        0
# 295        0
# 294        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#    Portugal             9                   6                     2                       4                 3                   1        1    1    0    0    0 False        0
#       Ghana             4                   5                     5                       0                 1                   2        1    0    1    0    0 False        0
#     Uruguay             2                   0                     2                      -2                 1                   3        2    0    0    1    1 False        0
# South Korea             1                   2                     4                      -2                 0                   4        2    0    0    1    1 False        0
#
# ========================================
#
# Analyzing goal: 26 minute, 1 half time, Player team: Uruguay, Home: Ghana, Away: Uruguay
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 292     Portugal                   1             9                       4
# 295      Uruguay                   2             4                      -1
# 293        Ghana                   3             3                      -1
# 294  South Korea                   4             1                      -2
#
#      tie_won
# 292        0
# 295        0
# 293        0
# 294        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#    Portugal             9                   6                     2                       4                 3                   1        1    1    0    0    0 False        0
#     Uruguay             4                   1                     2                      -1                 3                   2        3    0    1    1    1 False        0
#       Ghana             3                   5                     6                      -1                 0                   3        2    0    1    1    0 False        0
# South Korea             1                   2                     4                      -2                 0                   4        2    0    0    1    1 False        0
#
# ========================================
#
# Analyzing goal: 27 minute, 1 half time, Player team: South Korea, Home: South Korea, Away: Portugal
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 292     Portugal                   1             7                       3
# 295      Uruguay                   2             4                      -1
# 293        Ghana                   3             3                      -1
# 294  South Korea                   4             2                      -1
#
#      tie_won
# 292        0
# 295        0
# 293        0
# 294        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#    Portugal             7                   6                     3                       3                 1                   1        1    1    0    0    0 False        0
#     Uruguay             4                   1                     2                      -1                 3                   2        3    0    1    1    1 False        0
#       Ghana             3                   5                     6                      -1                 0                   3        2    0    1    1    0 False        0
# South Korea             2                   3                     4                      -1                 1                   4        2    0    0    1    1 False        0
#
# ========================================
#
# Analyzing goal: 32 minute, 1 half time, Player team: Uruguay, Home: Ghana, Away: Uruguay
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 292     Portugal                   1             7                       3
# 295      Uruguay                   2             4                       0
# 293        Ghana                   3             3                      -2
# 294  South Korea                   4             2                      -1
#
#      tie_won
# 292        0
# 295        0
# 293        0
# 294        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#    Portugal             7                   6                     3                       3                 1                   1        1    1    0    0    0 False        0
#     Uruguay             4                   2                     2                       0                 3                   2        3    0    1    1    1 False        0
#       Ghana             3                   5                     7                      -2                 0                   3        2    0    1    1    0 False        0
# South Korea             2                   3                     4                      -1                 1                   4        2    0    0    1    1 False        0
#
# ========================================
#
# Analyzing goal: 91 minute, 2 half time, Player team: South Korea, Home: South Korea, Away: Portugal
#
# === Teams with Identical Points (Tied Teams) ===
#
#             team  total_points
# 295      Uruguay             4
# 294  South Korea             4
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: South Korea and Uruguay
#
# === Applying Tiebreaker ===
# Row1: year                                      2022
# stage                                  Group H
# team                               South Korea
# tiebreaker                         South Korea
# tie_won                                      0
# before_last_game_goals_scored                2
# before_last_game_goals_conceded              3
# before_last_game_standing                    3
# before_last_game_points                      1
# last_game_goals_scored                       2
# last_game_goals_conceded                     1
# total_goals_scored                           4
# total_goals_conceded                         4
# total_goals_difference                       0
# last_game_points                             3
# total_points                                 4
# last_game_standing                           4
# 1st                                          0
# 2nd                                          0
# 3rd                                          1
# 4th                                          1
# changes                                      2
# tied                                      True
# Name: 294, dtype: object
# Row2: year                                      2022
# stage                                  Group H
# team                                   Uruguay
# tiebreaker                         South Korea
# tie_won                                      0
# before_last_game_goals_scored                0
# before_last_game_goals_conceded              2
# before_last_game_standing                    4
# before_last_game_points                      1
# last_game_goals_scored                       2
# last_game_goals_conceded                     0
# total_goals_scored                           2
# total_goals_conceded                         2
# total_goals_difference                       0
# last_game_points                             3
# total_points                                 4
# last_game_standing                           2
# 1st                                          0
# 2nd                                          1
# 3rd                                          1
# 4th                                          1
# changes                                      3
# tied                                      True
# Name: 295, dtype: object
#
# Goal difference: South Korea = 0, Uruguay = 0
# Goals scored: South Korea = 4, Uruguay = 2
# Goals scored result: South Korea wins
# Tiebreak Result: Winner is South Korea
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 292     Portugal                   1             6                       2
# 294  South Korea                   2             4                       0
# 295      Uruguay                   3             4                       0
# 293        Ghana                   4             3                      -2
#
#      tie_won
# 292        0
# 294        1
# 295        0
# 293        0
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#    Portugal             6                   6                     4                       2                 0                   1        1    1    0    0    0 False        0
# South Korea             4                   4                     4                       0                 3                   2        3    0    1    1    1  True        1
#     Uruguay             4                   2                     2                       0                 3                   3        4    0    1    2    1  True        0
#       Ghana             3                   5                     7                      -2                 0                   4        3    0    1    1    1 False        0
#
# ========================================

# %%
# # Exporting final df
# file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\tb_wc_fifa_men.xlsx'
# changes_df_wc.to_excel(file_path, index=False)

# %% [markdown]
# # group composition tracking

# %%
# Initialize an empty list to store the results for each pair
all_composition_changes = []

# Get unique pairs of year, stage, and men
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    stage = row['stage']
    
    # Apply the function to the current pair
    composition_changes_df, third_place_df = gap_composition(year, stage, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_composition_changes.append(composition_changes_df)

# Concatenate all the results into a single DataFrame
final_composition_changes_df = pd.concat(all_composition_changes, ignore_index=True)

# Define the desired column order
column_order = [
    'year', 'stage', 'date', 'time', 'change_num', 'goal_minute','half_time', 'home_team', 
    'away_team', 'scorer_team', 'new_top_teams', '1st', '2nd', '3rd', 
    'changed', 'points_diff', 'goals_diff', 'tiebreak_result'
]

# Reorder the columns
final_composition_changes_df = final_composition_changes_df[column_order]

# Identify rows where both 'date' and 'time' are NaN
mask = final_composition_changes_df['date'].isna() & final_composition_changes_df['time'].isna()

# Use .shift(-1) to get the values from the following row and fill in the NaN rows
final_composition_changes_df.loc[mask, ['date', 'time']] = final_composition_changes_df.loc[mask, ['date', 'time']].fillna(
    final_composition_changes_df[['date', 'time']].shift(-1)
)

# Ensure 'date' is in datetime format and handle errors
# final_composition_changes_df['date'] = pd.to_datetime(final_composition_changes_df['date'], errors='coerce')

# Ensure 'time' is in proper datetime.time format and handle errors
final_composition_changes_df['time'] = pd.to_datetime(final_composition_changes_df['time'], format='%H:%M', errors='coerce').dt.time

# Drop rows with missing or invalid 'date' or 'time'
final_composition_changes_df = final_composition_changes_df.dropna(subset=['date', 'time'])

# Combine 'date' and 'time' into a single datetime column for proper sorting
final_composition_changes_df['datetime'] = pd.to_datetime(
    final_composition_changes_df['date'].astype(str) + ' ' + final_composition_changes_df['time'].astype(str),
    errors='coerce'
)

# Drop rows with invalid datetime values
final_composition_changes_df = final_composition_changes_df.dropna(subset=['datetime'])

# Sort by year and the combined datetime column
final_composition_changes_df = final_composition_changes_df.sort_values(by=['year', 'datetime']).reset_index(drop=True)

# Drop the combined datetime column if not needed
final_composition_changes_df = final_composition_changes_df.drop(columns=['datetime'])
# Out:
# === STEP 1: Initial Standings for Group A, 1986 (Goal Time = 0) ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             4                   4                     2                       2                          1
#    Bulgaria             3                   2                     2                       0                          2
#       Italy             3                   2                     2                       0                          3
# South Korea             2                   2                     4                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 0 1 half time by nan in Group A, edition 1986 ===
# Number of tied teams: 2
#        team  total_points  total_goals_scored  total_goals_conceded  \
# 1  Bulgaria             3                   2                     2
# 2     Italy             3                   2                     2
#
#    total_goals_difference
# 1                       0
# 2                       0
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Checking ties for teams with 3 points ===
# Checking tie between: Bulgaria and Italy
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group A
# team                               Bulgaria
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           2
# before_last_game_standing                 2
# before_last_game_points                   2
# last_game_goals_scored                    0
# last_game_goals_conceded                  0
# total_goals_scored                        2
# total_goals_conceded                      2
# total_goals_difference                    0
# last_game_points                          1
# total_points                              3
# last_game_standing                        0
# three_tie                                 0
# tied                                   True
# Name: 1, dtype: object
# Row2: year                                  1986
# stage                              Group A
# team                                 Italy
# tie_won                                  0
# before_last_game_goals_scored            2
# before_last_game_goals_conceded          2
# before_last_game_standing                3
# before_last_game_points                  2
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       2
# total_goals_conceded                     2
# total_goals_difference                   0
# last_game_points                         1
# total_points                             3
# last_game_standing                       0
# three_tie                                0
# tied                                  True
# Name: 2, dtype: object
#
# Goal difference: Bulgaria = 0, Italy = 0
# Goals scored: Bulgaria = 2, Italy = 2
# Head-to-head match found:
# year                      1986
# stage                  Group A
# home_team             Bulgaria
# away_team                Italy
# local_time               18:00
# short_date          2025-02-17
# goals_home                   1
# goals_away                   1
# original_score             1–1
# calculated_score           1-1
# score_match               True
# won                          0
# Name: 1, dtype: object
# All criteria tied. Result: tie
# No winner in tiebreak between Bulgaria and Italy
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 0, Team: Italy, Points: 3, Goal Difference: 0, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 0, 'half_time': 1, 'third_team': 'Italy', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 0 1 half time by nan in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             4                   4                     2                       2                          1
#    Bulgaria             3                   2                     2                       0                          2
#       Italy             3                   2                     2                       0                          3
# South Korea             2                   2                     4                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 4 1 half time by Argentina in Group A, edition 1986 ===
# Number of tied teams: 2
#           team  total_points  total_goals_scored  total_goals_conceded  \
# 1     Bulgaria             2                   2                     3
# 3  South Korea             2                   2                     4
#
#    total_goals_difference
# 1                      -1
# 3                      -2
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Checking ties for teams with 2 points ===
# Checking tie between: Bulgaria and South Korea
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group A
# team                               Bulgaria
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           2
# before_last_game_standing                 2
# before_last_game_points                   2
# last_game_goals_scored                    0
# last_game_goals_conceded                  1
# total_goals_scored                        2
# total_goals_conceded                      3
# total_goals_difference                   -1
# last_game_points                          0
# total_points                              2
# last_game_standing                        2
# three_tie                                 0
# tied                                   True
# Name: 1, dtype: object
# Row2: year                                      1986
# stage                                  Group A
# team                               South Korea
# tie_won                                      0
# before_last_game_goals_scored                2
# before_last_game_goals_conceded              4
# before_last_game_standing                    4
# before_last_game_points                      1
# last_game_goals_scored                       0
# last_game_goals_conceded                     0
# total_goals_scored                           2
# total_goals_conceded                         4
# total_goals_difference                      -2
# last_game_points                             1
# total_points                                 2
# last_game_standing                           4
# three_tie                                    0
# tied                                      True
# Name: 3, dtype: object
#
# Goal difference: Bulgaria = -1, South Korea = -2
# Goal difference result: Bulgaria wins
# Tiebreak Result: Winner is Bulgaria
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 4, Team: Bulgaria, Points: 2, Goal Difference: -1, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 4, 'half_time': 1, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 4 1 half time by Argentina in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   5                     2                       3                          1
#       Italy             3                   2                     2                       0                          3
#    Bulgaria             2                   2                     3                      -1                          2
# South Korea             2                   2                     4                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 17 1 half time by Italy in Group A, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 17, Team: Bulgaria, Points: 2, Goal Difference: -1, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 17, 'half_time': 1, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 17 1 half time by Italy in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   5                     2                       3                          1
#       Italy             4                   3                     2                       1                          3
#    Bulgaria             2                   2                     3                      -1                          2
# South Korea             1                   2                     5                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 62 2 half time by South Korea in Group A, edition 1986 ===
# Number of tied teams: 2
#           team  total_points  total_goals_scored  total_goals_conceded  \
# 1     Bulgaria             2                   2                     3
# 3  South Korea             2                   3                     5
#
#    total_goals_difference
# 1                      -1
# 3                      -2
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Checking ties for teams with 2 points ===
# Checking tie between: Bulgaria and South Korea
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group A
# team                               Bulgaria
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           2
# before_last_game_standing                 2
# before_last_game_points                   2
# last_game_goals_scored                    0
# last_game_goals_conceded                  1
# total_goals_scored                        2
# total_goals_conceded                      3
# total_goals_difference                   -1
# last_game_points                          0
# total_points                              2
# last_game_standing                        3
# three_tie                                 0
# tied                                   True
# Name: 1, dtype: object
# Row2: year                                      1986
# stage                                  Group A
# team                               South Korea
# tie_won                                      0
# before_last_game_goals_scored                2
# before_last_game_goals_conceded              4
# before_last_game_standing                    4
# before_last_game_points                      1
# last_game_goals_scored                       1
# last_game_goals_conceded                     1
# total_goals_scored                           3
# total_goals_conceded                         5
# total_goals_difference                      -2
# last_game_points                             1
# total_points                                 2
# last_game_standing                           4
# three_tie                                    0
# tied                                      True
# Name: 3, dtype: object
#
# Goal difference: Bulgaria = -1, South Korea = -2
# Goal difference result: Bulgaria wins
# Tiebreak Result: Winner is Bulgaria
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 62, Team: Bulgaria, Points: 2, Goal Difference: -1, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 62, 'half_time': 2, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 62 2 half time by South Korea in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   5                     2                       3                          1
#       Italy             3                   3                     3                       0                          3
#    Bulgaria             2                   2                     3                      -1                          2
# South Korea             2                   3                     5                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 73 2 half time by Italy in Group A, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 73, Team: Bulgaria, Points: 2, Goal Difference: -1, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 73, 'half_time': 2, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 73 2 half time by Italy in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   5                     2                       3                          1
#       Italy             4                   4                     3                       1                          3
#    Bulgaria             2                   2                     3                      -1                          2
# South Korea             1                   3                     6                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 77 2 half time by Argentina in Group A, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 77, Team: Bulgaria, Points: 2, Goal Difference: -2, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 77, 'half_time': 2, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -2, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 77 2 half time by Argentina in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   6                     2                       4                          1
#       Italy             4                   4                     3                       1                          3
#    Bulgaria             2                   2                     4                      -2                          2
# South Korea             1                   3                     6                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 82 2 half time by Italy in Group A, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 82, Team: Bulgaria, Points: 2, Goal Difference: -2, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 82, 'half_time': 2, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -2, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 82 2 half time by Italy in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   6                     2                       4                          1
#       Italy             4                   5                     3                       2                          3
#    Bulgaria             2                   2                     4                      -2                          2
# South Korea             1                   3                     7                      -4                          4
#
# ========================================
#
#
# === Tied after goal at minute 89 2 half time by South Korea in Group A, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 89, Team: Bulgaria, Points: 2, Goal Difference: -2, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 89, 'half_time': 2, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -2, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 89 2 half time by South Korea in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   6                     2                       4                          1
#       Italy             4                   5                     4                       1                          3
#    Bulgaria             2                   2                     4                      -2                          2
# South Korea             1                   4                     7                      -3                          4
#
# ========================================
#
#
# === STEP 1: Initial Standings for Group B, 1986 (Goal Time = 0) ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Mexico             4                   3                     2                       1                          1
# Paraguay             4                   2                     1                       1                          2
#  Belgium             3                   3                     3                       0                          3
#     Iraq             1                   1                     3                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 0 1 half time by nan in Group B, edition 1986 ===
# Number of tied teams: 2
#        team  total_points  total_goals_scored  total_goals_conceded  \
# 4    Mexico             4                   3                     2
# 5  Paraguay             4                   2                     1
#
#    total_goals_difference
# 4                       1
# 5                       1
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Checking ties for teams with 4 points ===
# Checking tie between: Mexico and Paraguay
#
# === Applying Tiebreaker ===
# Row1: year                                  1986
# stage                              Group B
# team                                Mexico
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          2
# before_last_game_standing                1
# before_last_game_points                  3
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       3
# total_goals_conceded                     2
# total_goals_difference                   1
# last_game_points                         1
# total_points                             4
# last_game_standing                       0
# three_tie                                0
# tied                                  True
# Name: 4, dtype: object
# Row2: year                                   1986
# stage                               Group B
# team                               Paraguay
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           1
# before_last_game_standing                 2
# before_last_game_points                   3
# last_game_goals_scored                    0
# last_game_goals_conceded                  0
# total_goals_scored                        2
# total_goals_conceded                      1
# total_goals_difference                    1
# last_game_points                          1
# total_points                              4
# last_game_standing                        0
# three_tie                                 0
# tied                                   True
# Name: 5, dtype: object
#
# Goal difference: Mexico = 1, Paraguay = 1
# Goals scored: Mexico = 3, Paraguay = 2
# Goals scored result: Mexico wins
# Tiebreak Result: Winner is Mexico
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group B, Goal Minute: 0, Team: Belgium, Points: 3, Goal Difference: 0, Goals Scored: 3
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group B', 'goal_minute': 0, 'half_time': 1, 'third_team': 'Belgium', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 3}
#
# === STEP 3: Standings after goal at minute 0 1 half time by nan in Group B, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Mexico             4                   3                     2                       1                          1
# Paraguay             4                   2                     1                       1                          2
#  Belgium             3                   3                     3                       0                          3
#     Iraq             1                   1                     3                      -2                          4
#
# ========================================
#
#
# === STEP 4: Applying Potential Tiebreaker for 2nd and 3rd Place ===
#
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group B
# team                               Paraguay
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           1
# before_last_game_standing                 2
# before_last_game_points                   3
# last_game_goals_scored                    0
# last_game_goals_conceded                  0
# total_goals_scored                        2
# total_goals_conceded                      1
# total_goals_difference                    1
# last_game_points                          1
# total_points                              4
# last_game_standing                        2
# three_tie                                 0
# tied                                   True
# Name: 5, dtype: object
# Row2: year                                  1986
# stage                              Group B
# team                               Belgium
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          3
# before_last_game_standing                3
# before_last_game_points                  2
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       4
# total_goals_conceded                     3
# total_goals_difference                   1
# last_game_points                         1
# total_points                             3
# last_game_standing                       3
# three_tie                                0
# tied                                 False
# Name: 6, dtype: object
#
# Goal difference: Paraguay = 1, Belgium = 1
# Goals scored: Paraguay = 2, Belgium = 4
# Goals scored result: Belgium wins
#
# === Tied after goal at minute 30 1 half time by Belgium in Group B, edition 1986 ===
# Number of tied teams: 2
#       team  total_points  total_goals_scored  total_goals_conceded  \
# 4   Mexico             4                   3                     2
# 6  Belgium             4                   4                     3
#
#    total_goals_difference
# 4                       1
# 6                       1
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Checking ties for teams with 4 points ===
# Checking tie between: Mexico and Belgium
#
# === Applying Tiebreaker ===
# Row1: year                                  1986
# stage                              Group B
# team                                Mexico
# tie_won                                  1
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          2
# before_last_game_standing                1
# before_last_game_points                  3
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       3
# total_goals_conceded                     2
# total_goals_difference                   1
# last_game_points                         1
# total_points                             4
# last_game_standing                       1
# three_tie                                0
# tied                                  True
# Name: 4, dtype: object
# Row2: year                                  1986
# stage                              Group B
# team                               Belgium
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          3
# before_last_game_standing                3
# before_last_game_points                  2
# last_game_goals_scored                   1
# last_game_goals_conceded                 0
# total_goals_scored                       4
# total_goals_conceded                     3
# total_goals_difference                   1
# last_game_points                         2
# total_points                             4
# last_game_standing                       3
# three_tie                                0
# tied                                  True
# Name: 6, dtype: object
#
# Goal difference: Mexico = 1, Belgium = 1
# Goals scored: Mexico = 3, Belgium = 4
# Goals scored result: Belgium wins
# Tiebreak Result: Winner is Belgium
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group B, Goal Minute: 30, Team: Paraguay, Points: 3, Goal Difference: 0, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group B', 'goal_minute': 30, 'half_time': 1, 'third_team': 'Paraguay', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 30 1 half time by Belgium in Group B, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#  Belgium             4                   4                     3                       1                          3
#   Mexico             4                   3                     2                       1                          1
# Paraguay             3                   2                     2                       0                          2
#     Iraq             1                   1                     3                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 50 2 half time by Paraguay in Group B, edition 1986 ===
# Number of tied teams: 2
#        team  total_points  total_goals_scored  total_goals_conceded  \
# 4    Mexico             4                   3                     2
# 5  Paraguay             4                   3                     2
#
#    total_goals_difference
# 4                       1
# 5                       1
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Checking ties for teams with 4 points ===
# Checking tie between: Mexico and Paraguay
#
# === Applying Tiebreaker ===
# Row1: year                                  1986
# stage                              Group B
# team                                Mexico
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          2
# before_last_game_standing                1
# before_last_game_points                  3
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       3
# total_goals_conceded                     2
# total_goals_difference                   1
# last_game_points                         1
# total_points                             4
# last_game_standing                       2
# three_tie                                0
# tied                                  True
# Name: 4, dtype: object
# Row2: year                                   1986
# stage                               Group B
# team                               Paraguay
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           1
# before_last_game_standing                 2
# before_last_game_points                   3
# last_game_goals_scored                    1
# last_game_goals_conceded                  1
# total_goals_scored                        3
# total_goals_conceded                      2
# total_goals_difference                    1
# last_game_points                          1
# total_points                              4
# last_game_standing                        3
# three_tie                                 0
# tied                                   True
# Name: 5, dtype: object
#
# Goal difference: Mexico = 1, Paraguay = 1
# Goals scored: Mexico = 3, Paraguay = 3
# Head-to-head match found:
# year                      1986
# stage                  Group B
# home_team               Mexico
# away_team             Paraguay
# local_time               18:00
# short_date          2025-02-17
# goals_home                   1
# goals_away                   1
# original_score             1–1
# calculated_score           1-1
# score_match               True
# won                          0
# Name: 6, dtype: object
# All criteria tied. Result: tie
# No winner in tiebreak between Mexico and Paraguay
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group B, Goal Minute: 50, Team: Belgium, Points: 3, Goal Difference: 0, Goals Scored: 4
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group B', 'goal_minute': 50, 'half_time': 2, 'third_team': 'Belgium', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 4}
#
# === STEP 3: Standings after goal at minute 50 2 half time by Paraguay in Group B, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Mexico             4                   3                     2                       1                          1
# Paraguay             4                   3                     2                       1                          2
#  Belgium             3                   4                     4                       0                          3
#     Iraq             1                   1                     3                      -2                          4
#
# ========================================
#
#
# === STEP 4: Applying Potential Tiebreaker for 2nd and 3rd Place ===
#
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group B
# team                               Paraguay
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           1
# before_last_game_standing                 2
# before_last_game_points                   3
# last_game_goals_scored                    1
# last_game_goals_conceded                  1
# total_goals_scored                        3
# total_goals_conceded                      2
# total_goals_difference                    1
# last_game_points                          1
# total_points                              4
# last_game_standing                        2
# three_tie                                 0
# tied                                   True
# Name: 5, dtype: object
# Row2: year                                  1986
# stage                              Group B
# team                               Belgium
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          3
# before_last_game_standing                3
# before_last_game_points                  2
# last_game_goals_scored                   1
# last_game_goals_conceded                 1
# total_goals_scored                       5
# total_goals_conceded                     4
# total_goals_difference                   1
# last_game_points                         1
# total_points                             3
# last_game_standing                       3
# three_tie                                0
# tied                                 False
# Name: 6, dtype: object
#
# Goal difference: Paraguay = 1, Belgium = 1
# Goals scored: Paraguay = 3, Belgium = 5
# Goals scored result: Belgium wins
#
# === Tied after goal at minute 54 2 half time by Mexico in Group B, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group B, Goal Minute: 54, Team: Belgium, Points: 3, Goal Difference: 0, Goals Scored: 4
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group B', 'goal_minute': 54, 'half_time': 2, 'third_team': 'Belgium', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 4}
#
# === STEP 3: Standings after goal at minute 54 2 half time by Mexico in Group B, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Mexico             5                   4                     2                       2                          1
# Paraguay             4                   3                     2                       1                          2
#  Belgium             3                   4                     4                       0                          3
#     Iraq             0                   1                     4                      -3                          4
#
# ========================================
#
#
# === STEP 4: Applying Potential Tiebreaker for 2nd and 3rd Place ===
#
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group B
# team                               Paraguay
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           1
# before_last_game_standing                 2
# before_last_game_points                   3
# last_game_goals_scored                    1
# last_game_goals_conceded                  1
# total_goals_scored                        3
# total_goals_conceded                      2
# total_goals_difference                    1
# last_game_points                          1
# total_points                              4
# last_game_standing                        2
# three_tie                                 0
# tied                                  False
# Name: 5, dtype: object
# Row2: year                                  1986
# stage                              Group B
# team                               Belgium
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          3
# before_last_game_standing                3
# before_last_game_points                  2
# last_game_goals_scored                   1
# last_game_goals_conceded                 1
# total_goals_scored                       5
# total_goals_conceded                     4
# total_goals_difference                   1
# last_game_points                         1
# total_points                             3
# last_game_standing                       3
# three_tie                                0
# tied                                 False
# Name: 6, dtype: object
#
# Goal difference: Paraguay = 1, Belgium = 1
# Goals scored: Paraguay = 3, Belgium = 5
# Goals scored result: Belgium wins
#
# === Tied after goal at minute 59 2 half time by Belgium in Group B, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group B, Goal Minute: 59, Team: Paraguay, Points: 3, Goal Difference: 0, Goals Scored: 3
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group B', 'goal_minute': 59, 'half_time': 2, 'third_team': 'Paraguay', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 3}
#
# === STEP 3: Standings after goal at minute 59 2 half time by Belgium in Group B, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Mexico             5                   4                     2                       2                          1
#  Belgium             4                   5                     4                       1                          3
# Paraguay             3                   3                     3                       0                          2
#     Iraq             0                   1                     4                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 76 2 half time by Paraguay in Group B, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group B, Goal Minute: 76, Team: Belgium, Points: 3, Goal Difference: 0, Goals Scored: 5
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group B', 'goal_minute': 76, 'half_time': 2, 'third_team': 'Belgium', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 5}
#
# === STEP 3: Standings after goal at minute 76 2 half time by Paraguay in Group B, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Mexico             5                   4                     2                       2                          1
# Paraguay             4                   4                     3                       1                          2
#  Belgium             3                   5                     5                       0                          3
#     Iraq             0                   1                     4                      -3                          4
#
# ========================================
#
#
# === STEP 4: Applying Potential Tiebreaker for 2nd and 3rd Place ===
#
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group B
# team                               Paraguay
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           1
# before_last_game_standing                 2
# before_last_game_points                   3
# last_game_goals_scored                    2
# last_game_goals_conceded                  2
# total_goals_scored                        4
# total_goals_conceded                      3
# total_goals_difference                    1
# last_game_points                          1
# total_points                              4
# last_game_standing                        2
# three_tie                                 0
# tied                                  False
# Name: 5, dtype: object
# Row2: year                                  1986
# stage                              Group B
# team                               Belgium
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          3
# before_last_game_standing                3
# before_last_game_points                  2
# last_game_goals_scored                   2
# last_game_goals_conceded                 2
# total_goals_scored                       6
# total_goals_conceded                     5
# total_goals_difference                   1
# last_game_points                         1
# total_points                             3
# last_game_standing                       3
# three_tie                                0
# tied                                 False
# Name: 6, dtype: object
#
# Goal difference: Paraguay = 1, Belgium = 1
# Goals scored: Paraguay = 4, Belgium = 6
# Goals scored result: Belgium wins
#
# === STEP 1: Initial Standings for Group C, 1986 (Goal Time = 0) ===
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
# Soviet Union             4                   7                     1                       6                          1
#       France             4                   2                     1                       1                          2
#      Hungary             3                   2                     6                      -4                          3
#       Canada             1                   0                     3                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 0 1 half time by nan in Group C, edition 1986 ===
# Number of tied teams: 2
#            team  total_points  total_goals_scored  total_goals_conceded  \
# 8  Soviet Union             4                   7                     1
# 9        France             4                   2                     1
#
#    total_goals_difference
# 8                       6
# 9                       1
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Checking ties for teams with 4 points ===
# Checking tie between: Soviet Union and France
#
# === Applying Tiebreaker ===
# Row1: year                                       1986
# stage                                   Group C
# team                               Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 7
# before_last_game_goals_conceded               1
# before_last_game_standing                     1
# before_last_game_points                       3
# last_game_goals_scored                        0
# last_game_goals_conceded                      0
# total_goals_scored                            7
# total_goals_conceded                          1
# total_goals_difference                        6
# last_game_points                              1
# total_points                                  4
# last_game_standing                            0
# three_tie                                     0
# tied                                       True
# Name: 8, dtype: object
# Row2: year                                  1986
# stage                              Group C
# team                                France
# tie_won                                  0
# before_last_game_goals_scored            2
# before_last_game_goals_conceded          1
# before_last_game_standing                2
# before_last_game_points                  3
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       2
# total_goals_conceded                     1
# total_goals_difference                   1
# last_game_points                         1
# total_points                             4
# last_game_standing                       0
# three_tie                                0
# tied                                  True
# Name: 9, dtype: object
#
# Goal difference: Soviet Union = 6, France = 1
# Goal difference result: Soviet Union wins
# Tiebreak Result: Winner is Soviet Union
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group C, Goal Minute: 0, Team: Hungary, Points: 3, Goal Difference: -4, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group C', 'goal_minute': 0, 'half_time': 1, 'third_team': 'Hungary', 'total_points': 3, 'total_goals_difference': -4, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 0 1 half time by nan in Group C, edition 1986 ===
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
# Soviet Union             4                   7                     1                       6                          1
#       France             4                   2                     1                       1                          2
#      Hungary             3                   2                     6                      -4                          3
#       Canada             1                   0                     3                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 0 1 half time by nan in Group C, edition 1986 ===
# Number of tied teams: 2
#            team  total_points  total_goals_scored  total_goals_conceded  \
# 8  Soviet Union             4                   7                     1
# 9        France             4                   2                     1
#
#    total_goals_difference
# 8                       6
# 9                       1
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Checking ties for teams with 4 points ===
# Checking tie between: Soviet Union and France
#
# === Applying Tiebreaker ===
# Row1: year                                       1986
# stage                                   Group C
# team                               Soviet Union
# tie_won                                       1
# before_last_game_goals_scored                 7
# before_last_game_goals_conceded               1
# before_last_game_standing                     1
# before_last_game_points                       3
# last_game_goals_scored                        0
# last_game_goals_conceded                      0
# total_goals_scored                            7
# total_goals_conceded                          1
# total_goals_difference                        6
# last_game_points                              1
# total_points                                  4
# last_game_standing                            1
# three_tie                                     0
# tied                                       True
# Name: 8, dtype: object
# Row2: year                                  1986
# stage                              Group C
# team                                France
# tie_won                                  0
# before_last_game_goals_scored            2
# before_last_game_goals_conceded          1
# before_last_game_standing                2
# before_last_game_points                  3
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       2
# total_goals_conceded                     1
# total_goals_difference                   1
# last_game_points                         1
# total_points                             4
# last_game_standing                       2
# three_tie                                0
# tied                                  True
# Name: 9, dtype: object
#
# Goal difference: Soviet Union = 6, France = 1
# Goal difference result: Soviet Union wins
# Tiebreak Result: Winner is Soviet Union
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group C, Goal Minute: 0, Team: Hungary, Points: 3, Goal Difference: -4, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group C', 'goal_minute': 0, 'half_time': 1, 'third_team': 'Hungary', 'total_points': 3, 'total_goals_difference': -4, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 0 1 half time by nan in Group C, edition 1986 ===
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
# ...
#
#
# === Checking ties for teams with 6 points ===
# Checking tie between: Brazil and Switzerland
#
# === Applying Tiebreaker ===
# Row1: year                                  2022
# stage                              Group G
# team                                Brazil
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          0
# before_last_game_standing                1
# before_last_game_points                  6
# last_game_goals_scored                   0
# last_game_goals_conceded                 1
# total_goals_scored                       3
# total_goals_conceded                     1
# total_goals_difference                   2
# last_game_points                         0
# total_points                             6
# last_game_standing                       1
# three_tie                                0
# tied                                  True
# Name: 288, dtype: object
# Row2: year                                      2022
# stage                                  Group G
# team                               Switzerland
# tie_won                                      0
# before_last_game_goals_scored                1
# before_last_game_goals_conceded              1
# before_last_game_standing                    2
# before_last_game_points                      3
# last_game_goals_scored                       3
# last_game_goals_conceded                     2
# total_goals_scored                           4
# total_goals_conceded                         3
# total_goals_difference                       1
# last_game_points                             3
# total_points                                 6
# last_game_standing                           2
# three_tie                                    0
# tied                                      True
# Name: 289, dtype: object
#
# Goal difference: Brazil = 2, Switzerland = 1
# Goal difference result: Brazil wins
# Tiebreak Result: Winner is Brazil
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group G, Goal Minute: 92, Team: Cameroon, Points: 4, Goal Difference: 0, Goals Scored: 4
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group G', 'goal_minute': 92, 'half_time': 2, 'third_team': 'Cameroon', 'total_points': 4, 'total_goals_difference': 0, 'total_goals_scored': 4}
#
# === STEP 3: Standings after goal at minute 92 2 half time by Cameroon in Group G, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#      Brazil             6                   3                     1                       2                          1
# Switzerland             6                   4                     3                       1                          2
#    Cameroon             4                   4                     4                       0                          3
#      Serbia             1                   5                     8                      -3                          4
#
# ========================================
#
#
# === STEP 1: Initial Standings for Group H, 2022 (Goal Time = 0) ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#    Portugal             7                   5                     2                       3                          1
#       Ghana             4                   5                     5                       0                          2
# South Korea             2                   2                     3                      -1                          3
#     Uruguay             2                   0                     2                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 0 1 half time by nan in Group H, edition 2022 ===
# Number of tied teams: 2
#             team  total_points  total_goals_scored  total_goals_conceded  \
# 294  South Korea             2                   2                     3
# 295      Uruguay             2                   0                     2
#
#      total_goals_difference
# 294                      -1
# 295                      -2
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Checking ties for teams with 2 points ===
# Checking tie between: South Korea and Uruguay
#
# === Applying Tiebreaker ===
# Row1: year                                      2022
# stage                                  Group H
# team                               South Korea
# tie_won                                      0
# before_last_game_goals_scored                2
# before_last_game_goals_conceded              3
# before_last_game_standing                    3
# before_last_game_points                      1
# last_game_goals_scored                       0
# last_game_goals_conceded                     0
# total_goals_scored                           2
# total_goals_conceded                         3
# total_goals_difference                      -1
# last_game_points                             1
# total_points                                 2
# last_game_standing                           0
# three_tie                                    0
# tied                                      True
# Name: 294, dtype: object
# Row2: year                                  2022
# stage                              Group H
# team                               Uruguay
# tie_won                                  0
# before_last_game_goals_scored            0
# before_last_game_goals_conceded          2
# before_last_game_standing                4
# before_last_game_points                  1
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       0
# total_goals_conceded                     2
# total_goals_difference                  -2
# last_game_points                         1
# total_points                             2
# last_game_standing                       0
# three_tie                                0
# tied                                  True
# Name: 295, dtype: object
#
# Goal difference: South Korea = -1, Uruguay = -2
# Goal difference result: South Korea wins
# Tiebreak Result: Winner is South Korea
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group H, Goal Minute: 0, Team: South Korea, Points: 2, Goal Difference: -1, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group H', 'goal_minute': 0, 'half_time': 1, 'third_team': 'South Korea', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 0 1 half time by nan in Group H, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#    Portugal             7                   5                     2                       3                          1
#       Ghana             4                   5                     5                       0                          2
# South Korea             2                   2                     3                      -1                          3
#     Uruguay             2                   0                     2                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 5 1 half time by Portugal in Group H, edition 2022 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group H, Goal Minute: 5, Team: Uruguay, Points: 2, Goal Difference: -2, Goals Scored: 0
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group H', 'goal_minute': 5, 'half_time': 1, 'third_team': 'Uruguay', 'total_points': 2, 'total_goals_difference': -2, 'total_goals_scored': 0}
#
# === STEP 3: Standings after goal at minute 5 1 half time by Portugal in Group H, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#    Portugal             9                   6                     2                       4                          1
#       Ghana             4                   5                     5                       0                          2
#     Uruguay             2                   0                     2                      -2                          4
# South Korea             1                   2                     4                      -2                          3
#
# ========================================
#
#
# === Tied after goal at minute 26 1 half time by Uruguay in Group H, edition 2022 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group H, Goal Minute: 26, Team: Ghana, Points: 3, Goal Difference: -1, Goals Scored: 5
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group H', 'goal_minute': 26, 'half_time': 1, 'third_team': 'Ghana', 'total_points': 3, 'total_goals_difference': -1, 'total_goals_scored': 5}
#
# === STEP 3: Standings after goal at minute 26 1 half time by Uruguay in Group H, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#    Portugal             9                   6                     2                       4                          1
#     Uruguay             4                   1                     2                      -1                          4
#       Ghana             3                   5                     6                      -1                          2
# South Korea             1                   2                     4                      -2                          3
#
# ========================================
#
#
# === Tied after goal at minute 27 1 half time by South Korea in Group H, edition 2022 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group H, Goal Minute: 27, Team: Ghana, Points: 3, Goal Difference: -1, Goals Scored: 5
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group H', 'goal_minute': 27, 'half_time': 1, 'third_team': 'Ghana', 'total_points': 3, 'total_goals_difference': -1, 'total_goals_scored': 5}
#
# === STEP 3: Standings after goal at minute 27 1 half time by South Korea in Group H, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#    Portugal             7                   6                     3                       3                          1
#     Uruguay             4                   1                     2                      -1                          4
#       Ghana             3                   5                     6                      -1                          2
# South Korea             2                   3                     4                      -1                          3
#
# ========================================
#
#
# === Tied after goal at minute 32 1 half time by Uruguay in Group H, edition 2022 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group H, Goal Minute: 32, Team: Ghana, Points: 3, Goal Difference: -2, Goals Scored: 5
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group H', 'goal_minute': 32, 'half_time': 1, 'third_team': 'Ghana', 'total_points': 3, 'total_goals_difference': -2, 'total_goals_scored': 5}
#
# === STEP 3: Standings after goal at minute 32 1 half time by Uruguay in Group H, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#    Portugal             7                   6                     3                       3                          1
#     Uruguay             4                   2                     2                       0                          4
#       Ghana             3                   5                     7                      -2                          2
# South Korea             2                   3                     4                      -1                          3
#
# ========================================
#
#
# === Tied after goal at minute 91 2 half time by South Korea in Group H, edition 2022 ===
# Number of tied teams: 2
#             team  total_points  total_goals_scored  total_goals_conceded  \
# 295      Uruguay             4                   2                     2
# 294  South Korea             4                   4                     4
#
#      total_goals_difference
# 295                       0
# 294                       0
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Checking ties for teams with 4 points ===
# Checking tie between: South Korea and Uruguay
#
# === Applying Tiebreaker ===
# Row1: year                                      2022
# stage                                  Group H
# team                               South Korea
# tie_won                                      0
# before_last_game_goals_scored                2
# before_last_game_goals_conceded              3
# before_last_game_standing                    3
# before_last_game_points                      1
# last_game_goals_scored                       2
# last_game_goals_conceded                     1
# total_goals_scored                           4
# total_goals_conceded                         4
# total_goals_difference                       0
# last_game_points                             3
# total_points                                 4
# last_game_standing                           4
# three_tie                                    0
# tied                                      True
# Name: 294, dtype: object
# Row2: year                                  2022
# stage                              Group H
# team                               Uruguay
# tie_won                                  0
# before_last_game_goals_scored            0
# before_last_game_goals_conceded          2
# before_last_game_standing                4
# before_last_game_points                  1
# last_game_goals_scored                   2
# last_game_goals_conceded                 0
# total_goals_scored                       2
# total_goals_conceded                     2
# total_goals_difference                   0
# last_game_points                         3
# total_points                             4
# last_game_standing                       2
# three_tie                                0
# tied                                  True
# Name: 295, dtype: object
#
# Goal difference: South Korea = 0, Uruguay = 0
# Goals scored: South Korea = 4, Uruguay = 2
# Goals scored result: South Korea wins
# Tiebreak Result: Winner is South Korea
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group H, Goal Minute: 91, Team: Uruguay, Points: 4, Goal Difference: 0, Goals Scored: 2
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group H', 'goal_minute': 91, 'half_time': 2, 'third_team': 'Uruguay', 'total_points': 4, 'total_goals_difference': 0, 'total_goals_scored': 2}
#
# === STEP 3: Standings after goal at minute 91 2 half time by South Korea in Group H, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#    Portugal             6                   6                     4                       2                          1
# South Korea             4                   4                     4                       0                          3
#     Uruguay             4                   2                     2                       0                          4
#       Ghana             3                   5                     7                      -2                          2
#
# ========================================

# %% [markdown]
# ## manually modify order of tie teams by drawing of lots

# %%
mask = (final_composition_changes_df['year'] == 1990) & \
       (final_composition_changes_df['stage'] == "Group F") & \
       (final_composition_changes_df['goal_minute'] == 71)

final_composition_changes_df.loc[mask, ['2nd', '3rd']] = final_composition_changes_df.loc[mask, ['3rd', '2nd']].values

# %% [markdown]
# ## manually modify order of tie teams by fair play points

# %%
mask = (final_composition_changes_df['year'] == 2018) & \
       (final_composition_changes_df['stage'] == "Group H") & \
       (final_composition_changes_df['goal_minute'] == 74)

final_composition_changes_df.loc[mask, ['2nd', '3rd']] = final_composition_changes_df.loc[mask, ['3rd', '2nd']].values

# %% [markdown]
# # minute by minute dataframe

# %%
# Initialize an empty list to store the expanded rows
expanded_rows = []

# Iterate over rows grouped by date and time
for (date, time), group in final_composition_changes_df.groupby(["date", "time"]):
    group = group.sort_values(by="goal_minute").reset_index(drop=True)
    
    for i in range(len(group) - 1):
        current_row = group.iloc[i]
        next_row = group.iloc[i + 1]
        
        # Create the range of match_minute values between current and next row
        for match_minute in range(current_row["goal_minute"], next_row["goal_minute"] + 1):
            new_row = current_row.copy()
            new_row["match_minute"] = match_minute
            
            # Leave specific fields empty for interpolated rows
            if match_minute != current_row["goal_minute"]:
                new_row["goal_minute"] = None
                new_row["home_team"] = None
                new_row["away_team"] = None
                new_row["scorer_team"] = None
            
            expanded_rows.append(new_row)
    
    # Add the last row of the group as it is
    last_row = group.iloc[-1].copy()
    last_row["match_minute"] = last_row["goal_minute"]
    expanded_rows.append(last_row)
    
    # Ensure the match_minute reaches 90
    if last_row["goal_minute"] < 90:
        for match_minute in range(last_row["goal_minute"] + 1, 91):
            new_row = last_row.copy()
            new_row["match_minute"] = match_minute
            new_row["goal_minute"] = None
            new_row["home_team"] = None
            new_row["away_team"] = None
            new_row["scorer_team"] = None
            expanded_rows.append(new_row)

# Create a new DataFrame from the expanded rows
expanded_df = pd.DataFrame(expanded_rows)

# Reset the index for clarity
expanded_df = expanded_df.reset_index(drop=True)

# Define the desired column order
column_order = [
    'year', 'stage', 'date', 'time', 'match_minute','change_num', 'goal_minute', 'home_team', 
    'away_team', 'scorer_team', 'new_top_teams', '1st', '2nd', '3rd', 
    'changed', 'points_diff', 'goals_diff', 'tiebreak_result'
]

# Reorder the columns
expanded_df = expanded_df[column_order]

# Remove the columns 'change_num' and 'changed' from the DataFrame
expanded_df = expanded_df.drop(columns=['change_num', 'changed'], errors='ignore')

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\mbm_wc_fifa.xlsx'
expanded_df.to_excel(file_path, index=False)

# %% [markdown]
# # best four third placed

# %%
# Filter the dataset to include only years <= 1994
third_place_df = third_place_df[third_place_df['year'] <= 1994].copy()

third_place_df = ensure_goal_minute_zero(third_place_df, all_games_before_last)

# Remove duplicates
third_place_df = third_place_df.drop_duplicates()

# Define file path for saving
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\third_place_wc_fifa.xlsx'

# Export to Excel
# third_place_df.to_excel(file_path, index=False)

print(f"Filtered and deduplicated third-place data saved to {file_path}")
# Out:
# [INFO] Checking missing `goal_minute = 0` for each year and stage...
# [WARNING] Missing `goal_minute = 0` for Year: 1990, Stage: Group A. Adding it manually.
# [WARNING] Missing `goal_minute = 0` for Year: 1990, Stage: Group B. Adding it manually.
# [WARNING] Missing `goal_minute = 0` for Year: 1990, Stage: Group C. Adding it manually.
# [WARNING] Missing `goal_minute = 0` for Year: 1990, Stage: Group D. Adding it manually.
# [WARNING] Missing `goal_minute = 0` for Year: 1990, Stage: Group E. Adding it manually.
# [WARNING] Missing `goal_minute = 0` for Year: 1990, Stage: Group F. Adding it manually.
# [WARNING] Missing `goal_minute = 0` for Year: 1994, Stage: Group B. Adding it manually.
# [WARNING] Missing `goal_minute = 0` for Year: 1994, Stage: Group C. Adding it manually.
# [INFO] Adding 8 missing `goal_minute = 0` entries.
# [INFO] `goal_minute = 0` check complete. DataFrame updated.
# Filtered and deduplicated third-place data saved to C:\Users\aldi\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\third_place_wc_fifa.xlsx

# %% [markdown]
# ### resolving ties using yellow cards

# %%
team_priority = {
  
}

# %%
best_four_third_df = track_third_place_teams_with_top_four(third_place_df)

# Define output path and save
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\best_four_third_teams_wc_fifa.xlsx'
best_four_third_df.to_excel(file_path, index=False)

print(f"Data successfully saved to {file_path}")
# Out:
# Data successfully saved to C:\Users\aldi\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\best_four_third_teams_wc_fifa.xlsx

# %% [markdown]
# ### variable to track whether third teams qualifies or not

# %%
# Initialize third_qualify to 0
final_composition_changes_df['third_qualify'] = 0

# Process only years <= 1994
for index, row in final_composition_changes_df.iterrows():
    if row['year'] <= 1994:
        # Find matching row in best_four_third_df
        match = best_four_third_df[
            (best_four_third_df['year'] == row['year']) &
            (best_four_third_df['goal_minute'] == row['goal_minute'])
        ]

        if not match.empty:
            # Check if the 3rd place team is in the top four third-placed teams
            top_four_teams = match.iloc[0]['top_four_third_teams']
            if isinstance(top_four_teams, list) and row['3rd'] in top_four_teams:
                final_composition_changes_df.at[index, 'third_qualify'] = 1

# Create qualified_teams list: always includes 1st and 2nd, includes 3rd only if third_qualify == 1
final_composition_changes_df['qualified_teams'] = final_composition_changes_df.apply(
    lambda row: [row['1st'], row['2nd']] + ([row['3rd']] if row['third_qualify'] == 1 else []),
    axis=1
)

# Remove the columns 'change_num' and 'changed' from the DataFrame
final_composition_changes_df = final_composition_changes_df.drop(columns=['change_num', 'changed'], errors='ignore')

# %% [markdown]
# ### variables to track the composition of the teams qualifying

# %%
# Ensure goal_minute is numeric for sorting
final_composition_changes_df['goal_minute'] = pd.to_numeric(final_composition_changes_df['goal_minute'], errors='coerce')

# Sort by year, stage, and goal_minute to process in correct order
final_composition_changes_df = final_composition_changes_df.sort_values(by=['year', 'stage', 'goal_minute']).reset_index(drop=True)

# Initialize qual_changed and qual_count columns
final_composition_changes_df['qual_changed'] = 0
final_composition_changes_df['qual_count'] = 0

# Track changes per stage
qual_count_tracker = {}

# Loop through each year and stage to check for changes
for (year, stage), group in final_composition_changes_df.groupby(['year', 'stage']):
    previous_qualified = None
    qual_count = 0

    for index, row in group.iterrows():
        # Extract current qualified teams
        current_qualified = sorted(row['qualified_teams'])  # Sort to ignore order changes

        # Check if qualified_teams has changed from the previous row
        if previous_qualified is not None and current_qualified != previous_qualified:
            final_composition_changes_df.at[index, 'qual_changed'] = 1
            qual_count += 1

        # Update tracking
        previous_qualified = current_qualified
        final_composition_changes_df.at[index, 'qual_count'] = qual_count

# %%
final_composition_changes_df = integrate_elo_probabilities(final_composition_changes_df, elo_wc)

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\goals_wc_fifa_men.xlsx'
final_composition_changes_df.to_excel(file_path, index=False)
