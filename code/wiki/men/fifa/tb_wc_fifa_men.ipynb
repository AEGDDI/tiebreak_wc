# %% [markdown]
# # Libraries

# %%
import pandas as pd
from getpass import getuser
from collections import defaultdict
from datetime import datetime, timedelta
import re
import numpy as np
import math 
from scipy.stats import skellam

# %% [markdown]
# # Load and inspect dataset

# %%
# Get the current user's name
user = getuser()

# Construct the path using the user's name
function_path = f"C:/Users/{user}/Documents/GitHub/tiebreak_wc/code/wiki/functions_fifa.ipynb"

# Run the notebook
# %run $function_path

# %%
# Path to the dataset
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\wc_goals_men.xlsx'

# Read the dataset with a different encoding
df = pd.read_excel(data_path)

# Now, filter the data for tournaments after 1984
df = df[df['year'] >= 1984]

display(df.head())
# Out:
#      stage  year  home_team    away_team score  half_time  \
# 0  Group A  1986   Bulgaria        Italy   1–1          2
# 1  Group A  1986   Bulgaria        Italy   1–1          1
# 2  Group A  1986  Argentina  South Korea   3–1          1
# 3  Group A  1986  Argentina  South Korea   3–1          2
# 4  Group A  1986  Argentina  South Korea   3–1          1
#
#                      stadium_name stadium_city  stadium_attendance  \
# 0                  Estadio Azteca  Mexico City             96000.0
# 1                  Estadio Azteca  Mexico City             96000.0
# 2  Estadio Olímpico Universitario  Mexico City             60000.0
# 3  Estadio Olímpico Universitario  Mexico City             60000.0
# 4  Estadio Olímpico Universitario  Mexico City             60000.0
#
#                  referee_name  ... goal_minute_et extra_time goals_home  \
# 0            Erik Fredriksson  ...              0          0          1
# 1            Erik Fredriksson  ...              0          0          1
# 2  Victoriano Sánchez Arminio  ...              0          0          3
# 3  Victoriano Sánchez Arminio  ...              0          0          3
# 4  Victoriano Sánchez Arminio  ...              0          0          3
#
#   goals_away  own_goal  penalty  goal_et  short_date    long_date  \
# 0          1         0        0        0         NaN  31 May 1986
# 1          1         0        0        0         NaN  31 May 1986
# 2          1         0        0        0         NaN  2 June 1986
# 3          1         0        0        0         NaN  2 June 1986
# 4          1         0        0        0         NaN  2 June 1986
#
#    referee_natinality
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 25 columns]

# %%
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\elo_wc.xlsx'
elo_wc = pd.read_excel(data_path)

# %%
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\cards_subs_wc.xlsx'
cardsub_wc = pd.read_excel(data_path)

# %%
# Dictionary of replacements for team names
replacements = {
    "Republic of Ireland": "Ireland",
    "CIS": "Commonwealth of Independent States",
    "FR Yugoslavia": "Yugoslavia"
}

# %%
# Prepare the Elo dataset for integration: rename columns for clarity
elo_wc = elo_wc.rename(columns={"team": "team_name", "elo_rating": "elo"})
elo_wc["team_name"] = elo_wc["team_name"].replace(replacements)

# Apply replacements to the relevant columns
df[["home_team", "away_team", "scorer_nationality"]] = df[["home_team", "away_team", "scorer_nationality"]].replace(replacements)

# %% [markdown]
# # Clean, transfrom, create variables

# %%
# Columns to check for duplicates
columns_to_check = ['year', 'stage', 'home_team', 'scorer_nationality', 'long_date', 'half_time','time', 'goal_minute']

# Filter duplicates where both goals_home and goals_away are not 0
filtered_duplicates = df[
    (df.duplicated(subset=columns_to_check, keep=False)) &
    ~((df['goals_home'] == 0) & (df['goals_away'] == 0))
]

print("Filtered duplicates without both goals_home and goals_away being 0:")
display(filtered_duplicates)
# Out:
# Filtered duplicates without both goals_home and goals_away being 0:
# Empty DataFrame
# Columns: [stage, year, home_team, away_team, score, half_time, stadium_name, stadium_city, stadium_attendance, referee_name, referee_nationality, time, scorer_name, scorer_nationality, goal_minute, goal_minute_et, extra_time, goals_home, goals_away, own_goal, penalty, goal_et, short_date, long_date, referee_natinality]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ## time

# %%
# Apply the conversion function
df['local_time'] = df['time'].apply(convert_time_to_utc)
# Out:
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 16:00CST
# Extracted local time: 16:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 22:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 12:00CST
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CST, UTC Offset: -6
# Final UTC time: 18:00
#
# Original time string: 11:30 a.m.EDT(UTC-4)
# Extracted local time: 11:30
# Normalized 24-hour format: 11:30
# Final UTC time: 15:30
#
# Original time string: 11:30 a.m.EDT(UTC-4)
# Extracted local time: 11:30
# Normalized 24-hour format: 11:30
# Final UTC time: 15:30
#
# Original time string: 4:30 p.m.PDT(UTC-7)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Final UTC time: 23:30
#
# Original time string: 4:30 p.m.PDT(UTC-7)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Final UTC time: 23:30
#
# Original time string: 4:30 p.m.PDT(UTC-7)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Final UTC time: 23:30
#
# Original time string: 4:30 p.m.PDT(UTC-7)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Final UTC time: 23:30
#
# Original time string: 4:00 p.m.EDT(UTC-4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT(UTC-4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT(UTC-4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT(UTC-4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT(UTC-4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Final UTC time: 20:00
#
# Original time string: 4:30 p.m.PDT(UTC-7)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Final UTC time: 23:30
#
# Original time string: 4:30 p.m.PDT(UTC-7)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Final UTC time: 23:30
#
# Original time string: 4:30 p.m.PDT(UTC-7)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Final UTC time: 23:30
#
# Original time string: 1:00 p.m.PDT(UTC-7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC-7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC-7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC-7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC-7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Final UTC time: 20:00
#
# Original time string: 4:30 p.m.PDT(UTC–7)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 23:30
#
# Original time string: 4:30 p.m.PDT(UTC–7)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 23:30
#
# Original time string: 4:30 p.m.PDT(UTC–7)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 23:30
#
# Original time string: 4:30 p.m.PDT(UTC–7)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 23:30
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 7:30 p.m.EDT(UTC–4)
# Extracted local time: 07:30
# Normalized 24-hour format: 19:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 23:30
#
# Original time string: 7:30 p.m.EDT(UTC–4)
# Extracted local time: 07:30
# Normalized 24-hour format: 19:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 23:30
#
# Original time string: 7:30 p.m.EDT(UTC–4)
# Extracted local time: 07:30
# Normalized 24-hour format: 19:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 23:30
#
# Original time string: 7:30 p.m.EDT(UTC–4)
# Extracted local time: 07:30
# Normalized 24-hour format: 19:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 23:30
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 1:00 p.m.PDT(UTC–7)
# Extracted local time: 01:00
# Normalized 24-hour format: 13:00
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT(UTC–4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT(UTC–4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:00
#
# Original time string: 2:00 p.m.CDT
# Extracted local time: 02:00
# Normalized 24-hour format: 14:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 19:00
#
# Original time string: 2:00 p.m.CDT
# Extracted local time: 02:00
# Normalized 24-hour format: 14:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 19:00
#
# Original time string: 6:30 p.m.CDT
# Extracted local time: 06:30
# Normalized 24-hour format: 18:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 23:30
#
# Original time string: 6:30 p.m.CDT
# Extracted local time: 06:30
# Normalized 24-hour format: 18:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 23:30
#
# Original time string: 6:30 p.m.CDT
# Extracted local time: 06:30
# Normalized 24-hour format: 18:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 23:30
#
# Original time string: 6:30 p.m.CDT
# Extracted local time: 06:30
# Normalized 24-hour format: 18:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 23:30
#
# Original time string: 3:00 p.m.CDT
# Extracted local time: 03:00
# Normalized 24-hour format: 15:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 20:00
#
# Original time string: 3:00 p.m.CDT
# Extracted local time: 03:00
# Normalized 24-hour format: 15:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 20:00
#
# Original time string: 7:30 p.m.EDT
# Extracted local time: 07:30
# Normalized 24-hour format: 19:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 23:30
#
# Original time string: 7:30 p.m.EDT
# Extracted local time: 07:30
# Normalized 24-hour format: 19:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 23:30
#
# Original time string: 3:00 p.m.CDT
# Extracted local time: 03:00
# Normalized 24-hour format: 15:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 20:00
#
# Original time string: 3:00 p.m.CDT
# Extracted local time: 03:00
# Normalized 24-hour format: 15:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 20:00
#
# Original time string: 3:00 p.m.CDT
# Extracted local time: 03:00
# Normalized 24-hour format: 15:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 20:00
#
# Original time string: 3:00 p.m.CDT
# Extracted local time: 03:00
# Normalized 24-hour format: 15:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 20:00
#
# Original time string: 3:00 p.m.CDT
# Extracted local time: 03:00
# Normalized 24-hour format: 15:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 20:00
#
# Original time string: 3:00 p.m.CDT
# Extracted local time: 03:00
# Normalized 24-hour format: 15:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 20:00
#
# Original time string: 3:00 p.m.CDT
# Extracted local time: 03:00
# Normalized 24-hour format: 15:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 20:00
#
# Original time string: 3:00 p.m.CDT
# Extracted local time: 03:00
# Normalized 24-hour format: 15:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 20:00
#
# Original time string: 3:00 p.m.CDT
# Extracted local time: 03:00
# Normalized 24-hour format: 15:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 20:00
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 6:30 p.m.CDT
# Extracted local time: 06:30
# Normalized 24-hour format: 18:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 23:30
#
# Original time string: 6:30 p.m.CDT
# Extracted local time: 06:30
# Normalized 24-hour format: 18:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 23:30
#
# Original time string: 6:30 p.m.CDT
# Extracted local time: 06:30
# Normalized 24-hour format: 18:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 23:30
#
# Original time string: 6:30 p.m.CDT
# Extracted local time: 06:30
# Normalized 24-hour format: 18:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 23:30
#
# Original time string: 4:00 p.m.EDT
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:00
#
# Original time string: 11:30 a.m.CDT
# Extracted local time: 11:30
# Normalized 24-hour format: 11:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 16:30
#
# Original time string: 11:30 a.m.CDT
# Extracted local time: 11:30
# Normalized 24-hour format: 11:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 16:30
#
# Original time string: 11:30 a.m.CDT
# Extracted local time: 11:30
# Normalized 24-hour format: 11:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 16:30
#
# Original time string: 11:30 a.m.CDT
# Extracted local time: 11:30
# Normalized 24-hour format: 11:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 16:30
#
# Original time string: 11:30 a.m.CDT
# Extracted local time: 11:30
# Normalized 24-hour format: 11:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 16:30
#
# Original time string: 6:30 p.m.CDT
# Extracted local time: 06:30
# Normalized 24-hour format: 18:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 23:30
#
# Original time string: 6:30 p.m.CDT
# Extracted local time: 06:30
# Normalized 24-hour format: 18:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 23:30
#
# Original time string: 6:30 p.m.CDT
# Extracted local time: 06:30
# Normalized 24-hour format: 18:30
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 23:30
#
# Original time string: 7:30 p.m.EDT
# Extracted local time: 07:30
# Normalized 24-hour format: 19:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 23:30
#
# Original time string: 7:30 p.m.EDT
# Extracted local time: 07:30
# Normalized 24-hour format: 19:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 23:30
#
# Original time string: 7:30 p.m.EDT
# Extracted local time: 07:30
# Normalized 24-hour format: 19:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 23:30
#
# Original time string: 4:00 p.m.EDT(UTC–4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT(UTC–4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT(UTC–4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT(UTC–4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT(UTC–4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:00
#
# Original time string: 4:00 p.m.EDT(UTC–4)
# Extracted local time: 04:00
# Normalized 24-hour format: 16:00
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:00
#
# Original time string: 12:30 p.m.EDT(UTC–4)
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT(UTC–4)
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT(UTC–4)
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT(UTC–4)
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT(UTC–4)
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT(UTC–4)
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT(UTC–4)
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 7:30 p.m.EDT
# Extracted local time: 07:30
# Normalized 24-hour format: 19:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 23:30
#
# Original time string: 7:30 p.m.EDT
# Extracted local time: 07:30
# Normalized 24-hour format: 19:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 23:30
#
# Original time string: 7:30 p.m.EDT
# Extracted local time: 07:30
# Normalized 24-hour format: 19:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 23:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:30 p.m.EDT
# Extracted local time: 12:30
# Normalized 24-hour format: 12:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 16:30
#
# Original time string: 12:00 p.m.CDT(UTC–5)
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 17:00
#
# Original time string: 12:00 p.m.CDT(UTC–5)
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 17:00
#
# Original time string: 12:00 p.m.CDT(UTC–5)
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 17:00
#
# Original time string: 12:00 p.m.CDT(UTC–5)
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 17:00
#
# Original time string: 12:00 p.m.CDT(UTC–5)
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 17:00
#
# Original time string: 4:30 p.m.EDT(UTC–4)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:30
#
# Original time string: 4:30 p.m.EDT(UTC–4)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:30
#
# Original time string: 4:30 p.m.EDT(UTC–4)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:30
#
# Original time string: 4:30 p.m.EDT(UTC–4)
# Extracted local time: 04:30
# Normalized 24-hour format: 16:30
# Detected timezone acronym: EDT, UTC Offset: -4
# Final UTC time: 20:30
#
# Original time string: 12:00 p.m.CDT(UTC–5)
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 17:00
#
# Original time string: 12:00 p.m.CDT(UTC–5)
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 17:00
#
# Original time string: 12:00 p.m.CDT(UTC–5)
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 17:00
#
# Original time string: 12:00 p.m.CDT(UTC–5)
# Extracted local time: 12:00
# Normalized 24-hour format: 12:00
# Detected timezone acronym: CDT, UTC Offset: -5
# Final UTC time: 17:00
#
# Original time string: 1:30 p.m.PDT(UTC–7)
# Extracted local time: 01:30
# Normalized 24-hour format: 13:30
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:30
#
# Original time string: 1:30 p.m.PDT(UTC–7)
# Extracted local time: 01:30
# Normalized 24-hour format: 13:30
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:30
#
# Original time string: 1:30 p.m.PDT(UTC–7)
# Extracted local time: 01:30
# Normalized 24-hour format: 13:30
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:30
#
# Original time string: 1:30 p.m.PDT(UTC–7)
# Extracted local time: 01:30
# Normalized 24-hour format: 13:30
# Detected timezone acronym: PDT, UTC Offset: -7
# Final UTC time: 20:30
#
# ...
# No valid timezone found. Returning original time: 18:00
#
# Original time string: 18:00
# Extracted local time: 18:00
# Normalized 24-hour format: 18:00
# No valid timezone found. Returning original time: 18:00
#
# Original time string: 18:00
# Extracted local time: 18:00
# Normalized 24-hour format: 18:00
# No valid timezone found. Returning original time: 18:00
#
# Original time string: 18:00
# Extracted local time: 18:00
# Normalized 24-hour format: 18:00
# No valid timezone found. Returning original time: 18:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: 21:00
# Extracted local time: 21:00
# Normalized 24-hour format: 21:00
# No valid timezone found. Returning original time: 21:00
#
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: nan
# Invalid input (not a string or empty). Returning empty string.
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00
#
# Original time string: 17:00
# Extracted local time: 17:00
# Normalized 24-hour format: 17:00
# No valid timezone found. Returning original time: 17:00

# %%
df_filtered = df[(df['year'] == 2014) & (df['stage'] == "Group C")]

# Specify the columns you want to display
columns_to_display = ['year', 'stage', 'short_date','time', 'local_time', 'home_team', 'away_team']  # Replace with actual column names

# Print the selected columns
display(df_filtered[columns_to_display])
# Out:
#       year    stage short_date             time local_time    home_team  \
# 1161  2014  Group C        NaN  13:00BRT(UTC−3)      16:00     Colombia
# 1162  2014  Group C        NaN  13:00BRT(UTC−3)      16:00     Colombia
# 1163  2014  Group C        NaN  13:00BRT(UTC−3)      16:00     Colombia
# 1164  2014  Group C        NaN  13:00BRT(UTC−3)      16:00     Colombia
# 1165  2014  Group C        NaN  22:00BRT(UTC−3)      01:00  Ivory Coast
# 1166  2014  Group C        NaN  22:00BRT(UTC−3)      01:00  Ivory Coast
# 1167  2014  Group C        NaN  22:00BRT(UTC−3)      01:00  Ivory Coast
# 1168  2014  Group C        NaN  13:00BRT(UTC−3)      16:00     Colombia
# 1169  2014  Group C        NaN  13:00BRT(UTC−3)      16:00     Colombia
# 1170  2014  Group C        NaN  13:00BRT(UTC−3)      16:00     Colombia
# 1171  2014  Group C        NaN  19:00BRT(UTC−3)      22:00        Japan
# 1172  2014  Group C        NaN  19:00BRT(UTC−3)      22:00        Japan
# 1173  2014  Group C        NaN  16:00AMT(UTC−4)      20:00        Japan
# 1174  2014  Group C        NaN  16:00AMT(UTC−4)      20:00        Japan
# 1175  2014  Group C        NaN  16:00AMT(UTC−4)      20:00        Japan
# 1176  2014  Group C        NaN  16:00AMT(UTC−4)      20:00        Japan
# 1177  2014  Group C        NaN  16:00AMT(UTC−4)      20:00        Japan
# 1178  2014  Group C        NaN  17:00BRT(UTC−3)      20:00       Greece
# 1179  2014  Group C        NaN  17:00BRT(UTC−3)      20:00       Greece
# 1180  2014  Group C        NaN  17:00BRT(UTC−3)      20:00       Greece
#
#         away_team
# 1161       Greece
# 1162       Greece
# 1163       Greece
# 1164       Greece
# 1165        Japan
# 1166        Japan
# 1167        Japan
# 1168  Ivory Coast
# 1169  Ivory Coast
# 1170  Ivory Coast
# 1171       Greece
# 1172       Greece
# 1173     Colombia
# 1174     Colombia
# 1175     Colombia
# 1176     Colombia
# 1177     Colombia
# 1178  Ivory Coast
# 1179  Ivory Coast
# 1180  Ivory Coast

# %% [markdown]
# ## date

# %%
# Step 1: Remove any commas before the year in 'long_date'
df['long_date'] = df['long_date'].str.replace(r',\s*(\d{4})', r' \1', regex=True)

# Step 2: Convert 'long_date' to 'short_date' where 'short_date' is missing
df['short_date'] = df['short_date'].fillna(pd.to_datetime(df['long_date'], errors='coerce').dt.strftime('%Y-%m-%d'))

# %%
# Step 1: Remove comma only for year 1994
df.loc[df['year'] == 1994, 'long_date'] = df.loc[df['year'] == 1994, 'long_date'].str.replace(',', '', regex=True)

# Step 2: Convert 'long_date' to 'short_date' where 'short_date' is missing
df.loc[df['year'] == 1994, 'short_date'] = df.loc[df['year'] == 1994, 'short_date'].fillna(
    pd.to_datetime(df.loc[df['year'] == 1994, 'long_date'], errors='coerce', format='%B %d %Y').dt.strftime('%Y-%m-%d')
)

# Step 3: Convert all other years normally
df.loc[df['year'] != 1994, 'short_date'] = df.loc[df['year'] != 1994, 'short_date'].fillna(
    pd.to_datetime(df.loc[df['year'] != 1994, 'long_date'], errors='coerce').dt.strftime('%Y-%m-%d')
)

# Step 4: Identify missing conversions again
missing_dates = df[df['short_date'].isna()]

if not missing_dates.empty:
    print("\n⚠️ WARNING: Some dates are still missing after format correction.")
    print(missing_dates[['year', 'long_date', 'short_date']])

# Step 5: Check specific cases for year 1994
missing_1994 = df[(df['year'] == 1994) & df['short_date'].isna()]
if not missing_1994.empty:
    print("\n🔍 DEBUG: Still missing short_date for year 1994:")
    print(missing_1994[['year', 'long_date', 'short_date']])

# %% [markdown]
# # stage

# %%
# Calculate the number of unique teams per stage and year using home_team and away_team
team_counts = (
    df.groupby(['year', 'stage'])
    .apply(lambda x: pd.concat([x['home_team'], x['away_team']]).unique())
)

# Convert the resulting series to a DataFrame
team_counts = team_counts.reset_index()  # Reset index without 'name' argument
team_counts = team_counts.rename(columns={0: 'team_list'})  # Rename the column appropriately

# Convert team list into counts
team_counts['team_count'] = team_counts['team_list'].apply(len)

# Filter stages where the number of teams is not equal to 4
invalid_groups = team_counts[team_counts['team_count'] != 4]

# Display the invalid groups
display(invalid_groups)
# Out:
#      year                 stage  \
# 0    1986                 Final
# 7    1986        Quarter-finals
# 8    1986           Round of 16
# 10   1986  Third place play-off
# 17   1990        Quarter-finals
# 18   1990           Round of 16
# 19   1990        not applicable
# 20   1994                 Final
# 27   1994         Quarterfinals
# 28   1994           Round of 16
# 30   1994   Third place playoff
# 31   1998                 Final
# 40   1998        Quarter-finals
# 41   1998           Round of 16
# 43   1998  Third place play-off
# 44   2002                 Final
# 53   2002        Quarter-finals
# 54   2002           Round of 16
# 56   2002  Third place play-off
# 57   2006                 Final
# 66   2006        Quarter-finals
# 67   2006           Round of 16
# 69   2006  Third place play-off
# 70   2010                 Final
# 79   2010        Quarter-finals
# 80   2010           Round of 16
# 82   2010  Third place play-off
# 83   2014                 Final
# 92   2014        Quarter-finals
# 93   2014           Round of 16
# 95   2014  Third place play-off
# 96   2018                 Final
# 105  2018        Quarter-finals
# 106  2018           Round of 16
# 108  2018  Third place play-off
# 109  2022                 Final
# 118  2022        Quarter-finals
# 119  2022           Round of 16
# 121  2022  Third place play-off
#
#                                              team_list  team_count
# 0                            [Argentina, West Germany]           2
# 7    [Brazil, West Germany, Argentina, Spain, Franc...           8
# 8    [Mexico, Soviet Union, Brazil, Argentina, Ital...          16
# 10                                   [Belgium, France]           2
# 17                             [Argentina, Yugoslavia]           2
# 18                                  [Ireland, Romania]           2
# 19   [Cameroon, Czechoslovakia, Brazil, West German...          15
# 20                                     [Brazil, Italy]           2
# 27   [Italy, Netherlands, Bulgaria, Romania, Spain,...           8
# 28   [Germany, Spain, Saudi Arabia, Romania, Nether...          16
# 30                                  [Sweden, Bulgaria]           2
# 31                                    [Brazil, France]           2
# 40   [Italy, Brazil, Netherlands, Germany, France, ...           8
# 41   [Italy, Brazil, France, Nigeria, Germany, Neth...          16
# 43                              [Netherlands, Croatia]           2
# 44                                   [Germany, Brazil]           2
# 53   [England, Germany, Spain, Senegal, Brazil, Uni...           8
# 54   [Germany, Denmark, Sweden, Spain, Mexico, Braz...          16
# 56                               [South Korea, Turkey]           2
# 57                                     [Italy, France]           2
# 66   [Germany, Italy, England, Brazil, Argentina, U...           8
# 67   [Germany, Argentina, England, Portugal, Italy,...          16
# 69                                 [Germany, Portugal]           2
# 70                                [Netherlands, Spain]           2
# 79   [Netherlands, Uruguay, Argentina, Paraguay, Br...           8
# 80   [Uruguay, United States, Germany, Argentina, N...          16
# 82                                  [Uruguay, Germany]           2
# 83                                [Germany, Argentina]           2
# 92   [France, Brazil, Argentina, Netherlands, Germa...           8
# 93   [Brazil, Colombia, Netherlands, Costa Rica, Fr...          16
# 95                               [Brazil, Netherlands]           2
# 96                                   [France, Croatia]           2
# 105  [Uruguay, Brazil, Sweden, Russia, France, Belg...           8
# 106  [France, Uruguay, Spain, Croatia, Brazil, Belg...          16
# 108                                 [Belgium, England]           2
# 109                                [Argentina, France]           2
# 118  [Croatia, Netherlands, Morocco, England, Brazi...           8
# 119  [Netherlands, Argentina, France, England, Japa...          16
# 121                                 [Croatia, Morocco]           2

# %%
# Filter out the knockout stages
df = df[~df['stage'].isin(['Quarterfinals', 'Quarter-finals', 'Round of 16', 'Semi-finals', 'Semifinals','Final', 'Third place play-off', 'Third place playoff', 'not applicable'])]

# Extract relevant columns for goal events and match results
goals_df = df[['year', 'stage', 'home_team', 'away_team', 'scorer_nationality', 'goal_minute', 'half_time','short_date','local_time', 'score']]

#Sort goals_df by short_date, local_time, and goal_minute
goals_df = goals_df.sort_values(by=['short_date', 'local_time', 'goal_minute', 'half_time'], ascending=[True, True, True, True])

display(goals_df.head())
# Out:
#     year    stage home_team away_team scorer_nationality  goal_minute  \
# 1   1986  Group A  Bulgaria     Italy              Italy           44
# 0   1986  Group A  Bulgaria     Italy           Bulgaria           85
# 55  1986  Group D     Spain    Brazil                NaN            0
# 56  1986  Group D     Spain    Brazil             Brazil           62
# 34  1986  Group C    Canada    France                NaN            0
#
#     half_time  short_date local_time score
# 1           1  1986-05-31      18:00   1–1
# 0           2  1986-05-31      18:00   1–1
# 55          1  1986-06-01      18:00   0–1
# 56          2  1986-06-01      18:00   0–1
# 34          1  1986-06-01      22:00   0–1

# %%
df_missing = goals_df[(goals_df['year'] == 2006) & (goals_df['stage'] == 'Group C')]
df_missing
# Out:
#      year    stage              home_team              away_team  \
# 769  2006  Group C              Argentina            Ivory Coast
# 770  2006  Group C              Argentina            Ivory Coast
# 771  2006  Group C              Argentina            Ivory Coast
# 772  2006  Group C  Serbia and Montenegro            Netherlands
# 773  2006  Group C  Serbia and Montenegro            Netherlands
# 780  2006  Group C              Argentina  Serbia and Montenegro
# 774  2006  Group C              Argentina  Serbia and Montenegro
# 776  2006  Group C              Argentina  Serbia and Montenegro
# 775  2006  Group C              Argentina  Serbia and Montenegro
# 777  2006  Group C              Argentina  Serbia and Montenegro
# 778  2006  Group C              Argentina  Serbia and Montenegro
# 779  2006  Group C              Argentina  Serbia and Montenegro
# 781  2006  Group C            Netherlands            Ivory Coast
# 782  2006  Group C            Netherlands            Ivory Coast
# 783  2006  Group C            Netherlands            Ivory Coast
# 784  2006  Group C            Netherlands              Argentina
# 785  2006  Group C            Netherlands              Argentina
# 789  2006  Group C            Ivory Coast  Serbia and Montenegro
# 790  2006  Group C            Ivory Coast  Serbia and Montenegro
# 786  2006  Group C            Ivory Coast  Serbia and Montenegro
# 787  2006  Group C            Ivory Coast  Serbia and Montenegro
# 788  2006  Group C            Ivory Coast  Serbia and Montenegro
#
#         scorer_nationality  goal_minute  half_time  short_date local_time  \
# 769              Argentina           24          1  2006-06-10      21:00
# 770              Argentina           38          1  2006-06-10      21:00
# 771            Ivory Coast           82          2  2006-06-10      21:00
# 772                    NaN            0          1  2006-06-11      15:00
# 773            Netherlands           18          1  2006-06-11      15:00
# 780                    NaN            0          1  2006-06-16      15:00
# 774              Argentina            6          1  2006-06-16      15:00
# 776              Argentina           31          1  2006-06-16      15:00
# 775              Argentina           41          1  2006-06-16      15:00
# 777              Argentina           78          2  2006-06-16      15:00
# 778              Argentina           84          2  2006-06-16      15:00
# 779              Argentina           88          2  2006-06-16      15:00
# 781            Netherlands           23          1  2006-06-16      18:00
# 782            Netherlands           27          1  2006-06-16      18:00
# 783            Ivory Coast           38          1  2006-06-16      18:00
# 784                    NaN            0          1  2006-06-21      21:00
# 785                    NaN            0          1  2006-06-21      21:00
# 789  Serbia and Montenegro           10          1  2006-06-21      21:00
# 790  Serbia and Montenegro           20          1  2006-06-21      21:00
# 786            Ivory Coast           37          1  2006-06-21      21:00
# 787            Ivory Coast           67          2  2006-06-21      21:00
# 788            Ivory Coast           86          2  2006-06-21      21:00
#
#     score
# 769   2–1
# 770   2–1
# 771   2–1
# 772   0–1
# 773   0–1
# 780   6–0
# 774   6–0
# 776   6–0
# 775   6–0
# 777   6–0
# 778   6–0
# 779   6–0
# 781   2–1
# 782   2–1
# 783   2–1
# 784   0–0
# 785   0–0
# 789   3–2
# 790   3–2
# 786   3–2
# 787   3–2
# 788   3–2

# %% [markdown]
# # team counts

# %%
# Calculate the number of unique teams per stage and year using home_team and away_team
team_counts = (
    df.groupby(['year', 'stage'])
    .apply(lambda x: pd.concat([x['home_team'], x['away_team']]).unique())
)

# Convert the resulting series to a DataFrame
team_counts = team_counts.reset_index()  # Reset index without 'name' argument
team_counts = team_counts.rename(columns={0: 'team_list'})  # Rename the column appropriately

# Convert team list into counts
team_counts['team_count'] = team_counts['team_list'].apply(len)

# Filter stages where the number of teams is not equal to 4
invalid_groups = team_counts[team_counts['team_count'] != 4]

# Display the invalid groups
display(invalid_groups)
# Out:
# Empty DataFrame
# Columns: [year, stage, team_list, team_count]
# Index: []

# %% [markdown]
# # stage counts

# %%
# Group by year and collect unique values of stage in a list
stage_summary = df.groupby('year')['stage'].unique().reset_index()

# Rename column for clarity
stage_summary.rename(columns={'stage': 'unique_stages'}, inplace=True)

# Add a column for the number of unique stages
stage_summary['num_unique_stages'] = stage_summary['unique_stages'].apply(len)

# Display the summary
display(stage_summary)
# Out:
#    year                                      unique_stages  num_unique_stages
# 0  1986  [Group A, Group B, Group C, Group D, Group E, ...                  6
# 1  1990  [Group B, Group D, Group A, Group C, Group F, ...                  6
# 2  1994  [Group A, Group B, Group C, Group D, Group E, ...                  6
# 3  1998  [Group A, Group B, Group C, Group D, Group E, ...                  8
# 4  2002  [Group A, Group B, Group C, Group D, Group E, ...                  8
# 5  2006  [Group A, Group B, Group C, Group D, Group E, ...                  8
# 6  2010  [Group A, Group B, Group C, Group D, Group E, ...                  8
# 7  2014  [Group A, Group B, Group C, Group D, Group E, ...                  8
# 8  2018  [Group A, Group B, Group C, Group D, Group E, ...                  8
# 9  2022  [Group A, Group B, Group C, Group D, Group E, ...                  8

# %% [markdown]
# # Recreate Leauge Table after first two matchdays

# %%
# Assuming goals_df is your original dataset
agg_goals_before_last_day, goals_last_day_sorted = before_last(goals_df)

# %%
home_games, away_games = aggregate_home_away_points(agg_goals_before_last_day)

# %%
# Filter for year == 2022 and stage == 'Group E'
home2022e = home_games[(home_games['year'] == 2022) & (home_games['stage'] == 'Group E')]
home2022e
# Out:
#      year    stage home_team  goals_scored  goals_conceded  points_home  \
# 216  2022  Group E   Germany             1               2            0
# 217  2022  Group E     Japan             0               1            0
# 218  2022  Group E     Spain             8               1            4
#
#      match_count_home
# 216                 1
# 217                 1
# 218                 2

# %%
# Filter for year == 2022 and stage == 'Group E'
away2022e = away_games[(away_games['year'] == 2022) & (away_games['stage'] == 'Group E')]
away2022e
# Out:
#      year    stage   away_team  goals_scored  goals_conceded  points_away  \
# 216  2022  Group E  Costa Rica             1               7            3
# 217  2022  Group E     Germany             1               1            1
# 218  2022  Group E       Japan             2               1            3
#
#      match_count_away
# 216                 2
# 217                 1
# 218                 1

# %% [markdown]
# ## aggregate data after first two match days

# %%
# Applying the fifa_before_last function to the mock data
all_games_before_last = fifa_before_last(home_games, away_games, agg_goals_before_last_day, team_counts)
# Out:
# No missing values in the specified columns.
# No observations where total_matches == 1.
# No observations where total_matches == 0.
#
# === Applying Tiebreaker ===
# Row1: year                       1986
# stage                   Group A
# team                   Bulgaria
# home_team              Bulgaria
# goals_scored_home           1.0
# goals_conceded_home         1.0
# points_home                 1.0
# match_count_home            1.0
# away_team              Bulgaria
# goals_scored_away           1.0
# goals_conceded_away         1.0
# points_away                 1.0
# match_count_away            1.0
# goals_scored                2.0
# goals_conceded              2.0
# points                      2.0
# total_matches               2.0
# matches_flag                2.0
# goals_difference            0.0
# tiebreaker              no need
# tie_won                       0
# Name: 1, dtype: object
# Row2: year                      1986
# stage                  Group A
# team                     Italy
# home_team                Italy
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           1.0
# away_team                Italy
# goals_scored_away          1.0
# goals_conceded_away        1.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             2.0
# points                     2.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 2, dtype: object
#
# Goal difference: Bulgaria = 0.0, Italy = 0.0
# Goals scored: Bulgaria = 2.0, Italy = 2.0
# Head-to-head match found:
# year                      1986
# stage                  Group A
# home_team             Bulgaria
# away_team                Italy
# local_time               18:00
# short_date          2026-02-26
# goals_home                   1
# goals_away                   1
# original_score             1–1
# calculated_score           1-1
# score_match               True
# won                          0
# Name: 1, dtype: object
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                       1986
# stage                   Group B
# team                   Paraguay
# home_team              Paraguay
# goals_scored_home           1.0
# goals_conceded_home         0.0
# points_home                 2.0
# match_count_home            1.0
# away_team              Paraguay
# goals_scored_away           1.0
# goals_conceded_away         1.0
# points_away                 1.0
# match_count_away            1.0
# goals_scored                2.0
# goals_conceded              1.0
# points                      3.0
# total_matches               2.0
# matches_flag                2.0
# goals_difference            1.0
# tiebreaker              no need
# tie_won                       0
# Name: 4, dtype: object
# Row2: year                      1986
# stage                  Group B
# team                    Mexico
# home_team               Mexico
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           1.0
# away_team               Mexico
# goals_scored_away          2.0
# goals_conceded_away        1.0
# points_away                2.0
# match_count_away           1.0
# goals_scored               3.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 5, dtype: object
#
# Goal difference: Paraguay = 1.0, Mexico = 1.0
# Goals scored: Paraguay = 2.0, Mexico = 3.0
# Goals scored result: Mexico wins
#
# === Applying Tiebreaker ===
# Row1: year                           1986
# stage                       Group C
# team                   Soviet Union
# home_team              Soviet Union
# goals_scored_home               6.0
# goals_conceded_home             0.0
# points_home                     2.0
# match_count_home                1.0
# away_team              Soviet Union
# goals_scored_away               1.0
# goals_conceded_away             1.0
# points_away                     1.0
# match_count_away                1.0
# goals_scored                    7.0
# goals_conceded                  1.0
# points                          3.0
# total_matches                   2.0
# matches_flag                    2.0
# goals_difference                6.0
# tiebreaker                  no need
# tie_won                           0
# Name: 8, dtype: object
# Row2: year                      1986
# stage                  Group C
# team                    France
# home_team               France
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           1.0
# away_team               France
# goals_scored_away          1.0
# goals_conceded_away        0.0
# points_away                2.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             1.0
# points                     3.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 9, dtype: object
#
# Goal difference: Soviet Union = 6.0, France = 1.0
# Goal difference result: Soviet Union wins
#
# === Applying Tiebreaker ===
# Row1: year                      1986
# stage                  Group D
# team                   Algeria
# home_team              Algeria
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           1.0
# away_team              Algeria
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             2.0
# points                     1.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference          -1.0
# tiebreaker             no need
# tie_won                      0
# Name: 14, dtype: object
# Row2: year                               1986
# stage                           Group D
# team                   Northern Ireland
# home_team              Northern Ireland
# goals_scored_home                   1.0
# goals_conceded_home                 2.0
# points_home                         0.0
# match_count_home                    1.0
# away_team              Northern Ireland
# goals_scored_away                   1.0
# goals_conceded_away                 1.0
# points_away                         1.0
# match_count_away                    1.0
# goals_scored                        2.0
# goals_conceded                      3.0
# points                              1.0
# total_matches                       2.0
# matches_flag                        2.0
# goals_difference                   -1.0
# tiebreaker                      no need
# tie_won                               0
# Name: 15, dtype: object
#
# Goal difference: Algeria = -1.0, Northern Ireland = -1.0
# Goals scored: Algeria = 1.0, Northern Ireland = 2.0
# Goals scored result: Northern Ireland wins
#
# === Applying Tiebreaker ===
# Row1: year                      1986
# stage                  Group F
# team                   Morocco
# home_team              Morocco
# goals_scored_home          0.0
# goals_conceded_home        0.0
# points_home                1.0
# match_count_home           1.0
# away_team              Morocco
# goals_scored_away          0.0
# goals_conceded_away        0.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               0.0
# goals_conceded             0.0
# points                     2.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 21, dtype: object
# Row2: year                       1986
# stage                   Group F
# team                   Portugal
# home_team              Portugal
# goals_scored_home           1.0
# goals_conceded_home         0.0
# points_home                 2.0
# match_count_home            1.0
# away_team              Portugal
# goals_scored_away           0.0
# goals_conceded_away         1.0
# points_away                 0.0
# match_count_away            1.0
# goals_scored                1.0
# goals_conceded              1.0
# points                      2.0
# total_matches               2.0
# matches_flag                2.0
# goals_difference            0.0
# tiebreaker              no need
# tie_won                       0
# Name: 22, dtype: object
#
# Goal difference: Morocco = 0.0, Portugal = 0.0
# Goals scored: Morocco = 0.0, Portugal = 1.0
# Goals scored result: Portugal wins
#
# === Applying Tiebreaker ===
# Row1: year                      1990
# stage                  Group A
# team                     Italy
# home_team                Italy
# goals_scored_home          2.0
# goals_conceded_home        0.0
# points_home                4.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               2.0
# goals_conceded             0.0
# points                     4.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           2.0
# tiebreaker             no need
# tie_won                      0
# Name: 24, dtype: object
# Row2: year                             1990
# stage                         Group A
# team                   Czechoslovakia
# home_team                         NaN
# goals_scored_home                 NaN
# goals_conceded_home               NaN
# points_home                       NaN
# match_count_home                  NaN
# away_team              Czechoslovakia
# goals_scored_away                 6.0
# goals_conceded_away               1.0
# points_away                       4.0
# match_count_away                  2.0
# goals_scored                      6.0
# goals_conceded                    1.0
# points                            4.0
# total_matches                     2.0
# matches_flag                      2.0
# goals_difference                  5.0
# tiebreaker                    no need
# tie_won                             0
# Name: 25, dtype: object
#
# Goal difference: Italy = 2.0, Czechoslovakia = 5.0
# Goal difference result: Czechoslovakia wins
#
# === Applying Tiebreaker ===
# Row1: year                            1990
# stage                        Group A
# team                   United States
# home_team              United States
# goals_scored_home                1.0
# goals_conceded_home              5.0
# points_home                      0.0
# match_count_home                 1.0
# away_team              United States
# goals_scored_away                0.0
# goals_conceded_away              1.0
# points_away                      0.0
# match_count_away                 1.0
# goals_scored                     1.0
# goals_conceded                   6.0
# points                           0.0
# total_matches                    2.0
# matches_flag                     2.0
# goals_difference                -5.0
# tiebreaker                   no need
# tie_won                            0
# Name: 26, dtype: object
# Row2: year                      1990
# stage                  Group A
# team                   Austria
# home_team              Austria
# goals_scored_home          0.0
# goals_conceded_home        1.0
# points_home                0.0
# match_count_home           1.0
# away_team              Austria
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               0.0
# goals_conceded             2.0
# points                     0.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference          -2.0
# tiebreaker             no need
# tie_won                      0
# Name: 27, dtype: object
#
# Goal difference: United States = -5.0, Austria = -2.0
# Goal difference result: Austria wins
#
# === Applying Tiebreaker ===
# Row1: year                        1990
# stage                    Group B
# team                   Argentina
# home_team              Argentina
# goals_scored_home            2.0
# goals_conceded_home          1.0
# points_home                  2.0
# match_count_home             2.0
# away_team                    NaN
# goals_scored_away            NaN
# goals_conceded_away          NaN
# points_away                  NaN
# match_count_away             NaN
# goals_scored                 2.0
# goals_conceded               1.0
# points                       2.0
# total_matches                2.0
# matches_flag                 2.0
# goals_difference             1.0
# tiebreaker               no need
# tie_won                        0
# Name: 29, dtype: object
# Row2: year                      1990
# stage                  Group B
# team                   Romania
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Romania
# goals_scored_away          3.0
# goals_conceded_away        2.0
# points_away                2.0
# match_count_away           2.0
# goals_scored               3.0
# goals_conceded             2.0
# points                     2.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 30, dtype: object
#
# Goal difference: Argentina = 1.0, Romania = 1.0
# Goals scored: Argentina = 2.0, Romania = 3.0
# Goals scored result: Romania wins
#
# === Applying Tiebreaker ===
# Row1: year                         1990
# stage                     Group C
# team                   Costa Rica
# home_team              Costa Rica
# goals_scored_home             1.0
# goals_conceded_home           0.0
# points_home                   2.0
# match_count_home              1.0
# away_team              Costa Rica
# goals_scored_away             0.0
# goals_conceded_away           1.0
# points_away                   0.0
# match_count_away              1.0
# goals_scored                  1.0
# goals_conceded                1.0
# points                        2.0
# total_matches                 2.0
# matches_flag                  2.0
# goals_difference              0.0
# tiebreaker                no need
# tie_won                         0
# Name: 33, dtype: object
# Row2: year                       1990
# stage                   Group C
# team                   Scotland
# home_team                   NaN
# goals_scored_home           NaN
# goals_conceded_home         NaN
# points_home                 NaN
# match_count_home            NaN
# away_team              Scotland
# goals_scored_away           2.0
# goals_conceded_away         2.0
# points_away                 2.0
# match_count_away            2.0
# goals_scored                2.0
# goals_conceded              2.0
# points                      2.0
# total_matches               2.0
# matches_flag                2.0
# goals_difference            0.0
# tiebreaker              no need
# tie_won                       0
# Name: 34, dtype: object
#
# Goal difference: Costa Rica = 0.0, Scotland = 0.0
# Goals scored: Costa Rica = 1.0, Scotland = 2.0
# Goals scored result: Scotland wins
#
# === Applying Tiebreaker ===
# Row1: year                         1990
# stage                     Group D
# team                   Yugoslavia
# home_team              Yugoslavia
# goals_scored_home             1.0
# goals_conceded_home           0.0
# points_home                   2.0
# match_count_home              1.0
# away_team              Yugoslavia
# goals_scored_away             1.0
# goals_conceded_away           4.0
# points_away                   0.0
# match_count_away              1.0
# goals_scored                  2.0
# goals_conceded                4.0
# points                        2.0
# total_matches                 2.0
# matches_flag                  2.0
# goals_difference             -2.0
# tiebreaker                no need
# tie_won                         0
# Name: 37, dtype: object
# Row2: year                       1990
# stage                   Group D
# team                   Colombia
# home_team                   NaN
# goals_scored_home           NaN
# goals_conceded_home         NaN
# points_home                 NaN
# match_count_home            NaN
# away_team              Colombia
# goals_scored_away           2.0
# goals_conceded_away         1.0
# points_away                 2.0
# match_count_away            2.0
# goals_scored                2.0
# goals_conceded              1.0
# points                      2.0
# total_matches               2.0
# matches_flag                2.0
# goals_difference            1.0
# tiebreaker              no need
# tie_won                       0
# Name: 38, dtype: object
#
# Goal difference: Yugoslavia = -2.0, Colombia = 1.0
# Goal difference result: Colombia wins
#
# === Applying Tiebreaker ===
# Row1: year                      1990
# stage                  Group F
# team                   England
# home_team              England
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                2.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               1.0
# goals_conceded             1.0
# points                     2.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 44, dtype: object
# Row2: year                          1990
# stage                      Group F
# team                   Netherlands
# home_team              Netherlands
# goals_scored_home              1.0
# goals_conceded_home            1.0
# points_home                    1.0
# match_count_home               1.0
# away_team              Netherlands
# goals_scored_away              0.0
# goals_conceded_away            0.0
# points_away                    1.0
# match_count_away               1.0
# goals_scored                   1.0
# goals_conceded                 1.0
# points                         2.0
# total_matches                  2.0
# matches_flag                   2.0
# goals_difference               0.0
# tiebreaker                 no need
# tie_won                          0
# Name: 45, dtype: object
#
# Goal difference: England = 0.0, Netherlands = 0.0
# Goals scored: England = 1.0, Netherlands = 1.0
# Head-to-head match found:
# year                       1990
# stage                   Group F
# home_team               England
# away_team           Netherlands
# local_time                17:00
# short_date           2026-02-26
# goals_home                    0
# goals_away                    0
# original_score              0–0
# calculated_score            0-0
# score_match                True
# won                           0
# Name: 45, dtype: object
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                          1990
# stage                      Group F
# team                   Netherlands
# home_team              Netherlands
# goals_scored_home              1.0
# goals_conceded_home            1.0
# points_home                    1.0
# match_count_home               1.0
# away_team              Netherlands
# goals_scored_away              0.0
# goals_conceded_away            0.0
# points_away                    1.0
# match_count_away               1.0
# goals_scored                   1.0
# goals_conceded                 1.0
# points                         2.0
# total_matches                  2.0
# matches_flag                   2.0
# goals_difference               0.0
# tiebreaker                 no need
# tie_won                          0
# Name: 45, dtype: object
# Row2: year                      1990
# stage                  Group F
# team                   Ireland
# home_team              Ireland
# goals_scored_home          0.0
# goals_conceded_home        0.0
# points_home                1.0
# match_count_home           1.0
# away_team              Ireland
# goals_scored_away          1.0
# goals_conceded_away        1.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             1.0
# points                     2.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 46, dtype: object
#
# Goal difference: Netherlands = 0.0, Ireland = 0.0
# Goals scored: Netherlands = 1.0, Ireland = 1.0
# No head-to-head match found.
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                      1990
# stage                  Group F
# team                   Ireland
# home_team              Ireland
# goals_scored_home          0.0
# goals_conceded_home        0.0
# points_home                1.0
# match_count_home           1.0
# away_team              Ireland
# goals_scored_away          1.0
# goals_conceded_away        1.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             1.0
# points                     2.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 46, dtype: object
# Row2: year                      1990
# stage                  Group F
# team                     Egypt
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team                Egypt
# goals_scored_away          1.0
# goals_conceded_away        1.0
# points_away                2.0
# match_count_away           2.0
# goals_scored               1.0
# goals_conceded             1.0
# points                     2.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 47, dtype: object
#
# Goal difference: Ireland = 0.0, Egypt = 0.0
# Goals scored: Ireland = 1.0, Egypt = 1.0
# Head-to-head match found:
# year                      1990
# stage                  Group F
# home_team              Ireland
# away_team                Egypt
# local_time               17:00
# short_date          2026-02-26
# goals_home                   0
# goals_away                   0
# original_score             0–0
# calculated_score           0-0
# score_match               True
# won                          0
# Name: 46, dtype: object
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                            1994
# stage                        Group A
# team                   United States
# home_team              United States
# goals_scored_home                3.0
# goals_conceded_home              2.0
# points_home                      4.0
# match_count_home                 2.0
# away_team                        NaN
# goals_scored_away                NaN
# goals_conceded_away              NaN
# points_away                      NaN
# match_count_away                 NaN
# goals_scored                     3.0
# goals_conceded                   2.0
# points                           4.0
# total_matches                    2.0
# matches_flag                     2.0
# goals_difference                 1.0
# tiebreaker                   no need
# tie_won                            0
# Name: 48, dtype: object
# Row2: year                          1994
# stage                      Group A
# team                   Switzerland
# home_team                      NaN
# goals_scored_home              NaN
# goals_conceded_home            NaN
# points_home                    NaN
# match_count_home               NaN
# away_team              Switzerland
# goals_scored_away              5.0
# goals_conceded_away            2.0
# points_away                    4.0
# match_count_away               2.0
# goals_scored                   5.0
# goals_conceded                 2.0
# points                         4.0
# total_matches                  2.0
# matches_flag                   2.0
# goals_difference               3.0
# tiebreaker                 no need
# tie_won                          0
# Name: 49, dtype: object
#
# Goal difference: United States = 1.0, Switzerland = 3.0
# Goal difference result: Switzerland wins
#
# === Applying Tiebreaker ===
# Row1: year                      1994
# stage                  Group C
# team                     Spain
# home_team                Spain
# goals_scored_home          2.0
# goals_conceded_home        2.0
# points_home                1.0
# match_count_home           1.0
# away_team                Spain
# goals_scored_away          1.0
# goals_conceded_away        1.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               3.0
# goals_conceded             3.0
# points                     2.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 57, dtype: object
# Row2: year                          1994
# stage                      Group C
# team                   South Korea
# home_team              South Korea
# goals_scored_home              0.0
# goals_conceded_home            0.0
# points_home                    1.0
# match_count_home               1.0
# away_team              South Korea
# goals_scored_away              2.0
# goals_conceded_away            2.0
# points_away                    1.0
# match_count_away               1.0
# goals_scored                   2.0
# goals_conceded                 2.0
# points                         2.0
# total_matches                  2.0
# matches_flag                   2.0
# goals_difference               0.0
# tiebreaker                 no need
# tie_won                          0
# Name: 58, dtype: object
#
# Goal difference: Spain = 0.0, South Korea = 0.0
# Goals scored: Spain = 3.0, South Korea = 2.0
# Goals scored result: Spain wins
#
# === Applying Tiebreaker ===
# Row1: year                      1994
# stage                  Group D
# team                   Nigeria
# home_team              Nigeria
# goals_scored_home          3.0
# goals_conceded_home        0.0
# points_home                3.0
# match_count_home           1.0
# away_team              Nigeria
# goals_scored_away          1.0
# goals_conceded_away        2.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               4.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           2.0
# tiebreaker             no need
# tie_won                      0
# Name: 61, dtype: object
# Row2: year                       1994
# stage                   Group D
# team                   Bulgaria
# home_team              Bulgaria
# goals_scored_home           4.0
# goals_conceded_home         0.0
# points_home                 3.0
# match_count_home            1.0
# away_team              Bulgaria
# goals_scored_away           0.0
# goals_conceded_away         3.0
# points_away                 0.0
# match_count_away            1.0
# goals_scored                4.0
# goals_conceded              3.0
# points                      3.0
# total_matches               2.0
# matches_flag                2.0
# goals_difference            1.0
# tiebreaker              no need
# tie_won                       0
# Name: 62, dtype: object
#
# Goal difference: Nigeria = 2.0, Bulgaria = 1.0
# Goal difference result: Nigeria wins
#
# === Applying Tiebreaker ===
# Row1: year                      1994
# stage                  Group E
# team                     Italy
# home_team                Italy
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                3.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               1.0
# goals_conceded             1.0
# points                     3.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 64, dtype: object
# Row2: year                      1994
# stage                  Group E
# team                    Norway
# home_team               Norway
# goals_scored_home          1.0
# goals_conceded_home        0.0
# points_home                3.0
# match_count_home           1.0
# away_team               Norway
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             1.0
# points                     3.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 65, dtype: object
#
# Goal difference: Italy = 0.0, Norway = 0.0
# Goals scored: Italy = 1.0, Norway = 1.0
# Head-to-head match found:
# year                      1994
# stage                  Group E
# home_team                Italy
# away_team               Norway
# local_time               20:00
# short_date          2026-02-26
# goals_home                   1
# goals_away                   0
# original_score             1–0
# calculated_score           1-0
# score_match               True
# won                          1
# Name: 65, dtype: object
# Head-to-head result: Italy wins
#
# === Applying Tiebreaker ===
# Row1: year                      1994
# stage                  Group E
# team                    Norway
# home_team               Norway
# goals_scored_home          1.0
# goals_conceded_home        0.0
# points_home                3.0
# match_count_home           1.0
# away_team               Norway
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             1.0
# points                     3.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker               Italy
# tie_won                      0
# Name: 65, dtype: object
# Row2: year                      1994
# stage                  Group E
# team                    Mexico
# home_team               Mexico
# goals_scored_home          2.0
# goals_conceded_home        1.0
# points_home                3.0
# match_count_home           1.0
# away_team               Mexico
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 66, dtype: object
#
# Goal difference: Norway = 0.0, Mexico = 0.0
# Goals scored: Norway = 1.0, Mexico = 2.0
# Goals scored result: Mexico wins
#
# === Applying Tiebreaker ===
# Row1: year                      1994
# stage                  Group E
# team                    Mexico
# home_team               Mexico
# goals_scored_home          2.0
# goals_conceded_home        1.0
# points_home                3.0
# match_count_home           1.0
# away_team               Mexico
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker              Mexico
# tie_won                      1
# Name: 66, dtype: object
# Row2: year                      1994
# stage                  Group E
# team                   Ireland
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Ireland
# goals_scored_away          2.0
# goals_conceded_away        2.0
# points_away                3.0
# match_count_away           2.0
# goals_scored               2.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 67, dtype: object
#
# Goal difference: Mexico = 0.0, Ireland = 0.0
# Goals scored: Mexico = 2.0, Ireland = 2.0
# Head-to-head match found:
# year                      1994
# stage                  Group E
# home_team               Mexico
# away_team              Ireland
# local_time               16:30
# short_date          2026-02-26
# goals_home                   2
# goals_away                   1
# original_score             2–1
# calculated_score           2-1
# score_match               True
# won                          1
# Name: 66, dtype: object
# Head-to-head result: Mexico wins
#
# === Applying Tiebreaker ===
# Row1: year                          1994
# stage                      Group F
# team                   Netherlands
# home_team              Netherlands
# goals_scored_home              2.0
# goals_conceded_home            1.0
# points_home                    3.0
# match_count_home               1.0
# away_team              Netherlands
# goals_scored_away              0.0
# goals_conceded_away            1.0
# points_away                    0.0
# match_count_away               1.0
# goals_scored                   2.0
# goals_conceded                 2.0
# points                         3.0
# total_matches                  2.0
# matches_flag                   2.0
# goals_difference               0.0
# tiebreaker                 no need
# tie_won                          0
# Name: 69, dtype: object
# Row2: year                           1994
# stage                       Group F
# team                   Saudi Arabia
# home_team              Saudi Arabia
# goals_scored_home               2.0
# goals_conceded_home             1.0
# points_home                     3.0
# match_count_home                1.0
# away_team              Saudi Arabia
# goals_scored_away               1.0
# goals_conceded_away             2.0
# points_away                     0.0
# match_count_away                1.0
# goals_scored                    3.0
# goals_conceded                  3.0
# points                          3.0
# total_matches                   2.0
# matches_flag                    2.0
# goals_difference                0.0
# tiebreaker                  no need
# tie_won                           0
# Name: 70, dtype: object
#
# Goal difference: Netherlands = 0.0, Saudi Arabia = 0.0
# Goals scored: Netherlands = 2.0, Saudi Arabia = 3.0
# Goals scored result: Saudi Arabia wins
#
# === Applying Tiebreaker ===
# Row1: year                      1998
# stage                  Group A
# team                   Morocco
# home_team              Morocco
# goals_scored_home          2.0
# goals_conceded_home        2.0
# points_home                1.0
# match_count_home           1.0
# away_team              Morocco
# goals_scored_away          0.0
# goals_conceded_away        3.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             5.0
# points                     1.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference          -3.0
# tiebreaker             no need
# tie_won                      0
# Name: 74, dtype: object
# Row2: year                       1998
# stage                   Group A
# team                   Scotland
# home_team              Scotland
# goals_scored_home           1.0
# goals_conceded_home         1.0
# points_home                 1.0
# match_count_home            1.0
# away_team              Scotland
# goals_scored_away           1.0
# goals_conceded_away         2.0
# points_away                 0.0
# match_count_away            1.0
# goals_scored                2.0
# goals_conceded              3.0
# points                      1.0
# total_matches               2.0
# matches_flag                2.0
# goals_difference           -1.0
# tiebreaker              no need
# tie_won                       0
# Name: 75, dtype: object
#
# Goal difference: Morocco = -3.0, Scotland = -1.0
# Goal difference result: Scotland wins
#
# === Applying Tiebreaker ===
# Row1: year                      1998
# stage                  Group B
# team                     Chile
# home_team                Chile
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           1.0
# away_team                Chile
# goals_scored_away          2.0
# goals_conceded_away        2.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               3.0
# goals_conceded             3.0
# points                     2.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 77, dtype: object
# Row2: year                      1998
# stage                  Group B
# team                   Austria
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Austria
# goals_scored_away          2.0
# goals_conceded_away        2.0
# points_away                2.0
# match_count_away           2.0
# goals_scored               2.0
# goals_conceded             2.0
# points                     2.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 78, dtype: object
#
# Goal difference: Chile = 0.0, Austria = 0.0
# Goals scored: Chile = 3.0, Austria = 2.0
# Goals scored result: Chile wins
#
# === Applying Tiebreaker ===
# Row1: year                      1998
# stage                  Group D
# team                     Spain
# home_team                Spain
# goals_scored_home          2.0
# goals_conceded_home        3.0
# points_home                1.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               2.0
# goals_conceded             3.0
# points                     1.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference          -1.0
# tiebreaker             no need
# tie_won                      0
# Name: 86, dtype: object
# Row2: year                       1998
# stage                   Group D
# team                   Bulgaria
# home_team                   NaN
# goals_scored_home           NaN
# goals_conceded_home         NaN
# points_home                 NaN
# match_count_home            NaN
# away_team              Bulgaria
# goals_scored_away           0.0
# goals_conceded_away         1.0
# points_away                 1.0
# match_count_away            2.0
# goals_scored                0.0
# goals_conceded              1.0
# points                      1.0
# total_matches               2.0
# matches_flag                2.0
# goals_difference           -1.0
# tiebreaker              no need
# tie_won                       0
# Name: 87, dtype: object
#
# Goal difference: Spain = -1.0, Bulgaria = -1.0
# Goals scored: Spain = 2.0, Bulgaria = 0.0
# Goals scored result: Spain wins
#
# === Applying Tiebreaker ===
# Row1: year                          1998
# stage                      Group E
# team                   Netherlands
# home_team              Netherlands
# goals_scored_home              5.0
# goals_conceded_home            0.0
# points_home                    4.0
# match_count_home               2.0
# away_team                      NaN
# goals_scored_away              NaN
# goals_conceded_away            NaN
# points_away                    NaN
# match_count_away               NaN
# goals_scored                   5.0
# goals_conceded                 0.0
# points                         4.0
# total_matches                  2.0
# matches_flag                   2.0
# goals_difference               5.0
# tiebreaker                 no need
# tie_won                          0
# Name: 88, dtype: object
# Row2: year                      1998
# stage                  Group E
# team                    Mexico
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team               Mexico
# goals_scored_away          5.0
# goals_conceded_away        3.0
# points_away                4.0
# match_count_away           2.0
# goals_scored               5.0
# goals_conceded             3.0
# points                     4.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           2.0
# tiebreaker             no need
# tie_won                      0
# Name: 89, dtype: object
#
# Goal difference: Netherlands = 5.0, Mexico = 2.0
# Goal difference result: Netherlands wins
#
# === Applying Tiebreaker ===
# Row1: year                         1998
# stage                     Group F
# team                   Yugoslavia
# home_team              Yugoslavia
# goals_scored_home             1.0
# goals_conceded_home           0.0
# points_home                   3.0
# match_count_home              1.0
# away_team              Yugoslavia
# goals_scored_away             2.0
# goals_conceded_away           2.0
# points_away                   1.0
# match_count_away              1.0
# goals_scored                  3.0
# goals_conceded                2.0
# points                        4.0
# total_matches                 2.0
# matches_flag                  2.0
# goals_difference              1.0
# tiebreaker                no need
# tie_won                         0
# Name: 92, dtype: object
# Row2: year                      1998
# stage                  Group F
# team                   Germany
# home_team              Germany
# goals_scored_home          4.0
# goals_conceded_home        2.0
# points_home                4.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               4.0
# goals_conceded             2.0
# points                     4.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           2.0
# tiebreaker             no need
# tie_won                      0
# Name: 93, dtype: object
#
# Goal difference: Yugoslavia = 1.0, Germany = 2.0
# Goal difference result: Germany wins
#
# === Applying Tiebreaker ===
# Row1: year                      1998
# stage                  Group G
# team                   England
# home_team              England
# goals_scored_home          2.0
# goals_conceded_home        0.0
# points_home                3.0
# match_count_home           1.0
# away_team              England
# goals_scored_away          1.0
# goals_conceded_away        2.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               3.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 97, dtype: object
# Row2: year                       1998
# stage                   Group G
# team                   Colombia
# home_team              Colombia
# goals_scored_home           1.0
# goals_conceded_home         0.0
# points_home                 3.0
# match_count_home            1.0
# away_team              Colombia
# goals_scored_away           0.0
# goals_conceded_away         1.0
# points_away                 0.0
# match_count_away            1.0
# goals_scored                1.0
# goals_conceded              1.0
# points                      3.0
# total_matches               2.0
# matches_flag                2.0
# goals_difference            0.0
# tiebreaker              no need
# tie_won                       0
# Name: 98, dtype: object
#
# Goal difference: England = 1.0, Colombia = 0.0
# Goal difference result: England wins
#
# === Applying Tiebreaker ===
# Row1: year                        1998
# stage                    Group H
# team                   Argentina
# home_team              Argentina
# goals_scored_home            6.0
# goals_conceded_home          0.0
# points_home                  6.0
# match_count_home             2.0
# away_team                    NaN
# goals_scored_away            NaN
# goals_conceded_away          NaN
# points_away                  NaN
# match_count_away             NaN
# goals_scored                 6.0
# goals_conceded               0.0
# points                       6.0
# total_matches                2.0
# matches_flag                 2.0
# goals_difference             6.0
# tiebreaker               no need
# tie_won                        0
# Name: 100, dtype: object
# Row2: year                      1998
# stage                  Group H
# team                   Croatia
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Croatia
# goals_scored_away          4.0
# goals_conceded_away        1.0
# points_away                6.0
# match_count_away           2.0
# goals_scored               4.0
# goals_conceded             1.0
# points                     6.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           3.0
# tiebreaker             no need
# tie_won                      0
# Name: 101, dtype: object
#
# Goal difference: Argentina = 6.0, Croatia = 3.0
# Goal difference result: Argentina wins
#
# === Applying Tiebreaker ===
# Row1: year                      1998
# stage                  Group H
# team                   Jamaica
# home_team              Jamaica
# goals_scored_home          1.0
# goals_conceded_home        3.0
# points_home                0.0
# match_count_home           1.0
# away_team              Jamaica
# goals_scored_away          0.0
# goals_conceded_away        5.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             8.0
# points                     0.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference          -7.0
# tiebreaker             no need
# tie_won                      0
# Name: 102, dtype: object
# Row2: year                      1998
# stage                  Group H
# team                     Japan
# home_team                Japan
# goals_scored_home          0.0
# goals_conceded_home        1.0
# points_home                0.0
# match_count_home           1.0
# away_team                Japan
# goals_scored_away          0.0
# goals_conceded_away        1.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               0.0
# goals_conceded             2.0
# points                     0.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference          -2.0
# tiebreaker             no need
# tie_won                      0
# Name: 103, dtype: object
#
# Goal difference: Jamaica = -7.0, Japan = -2.0
# Goal difference result: Japan wins
#
# === Applying Tiebreaker ===
# Row1: year                      2002
# stage                  Group A
# team                   Denmark
# home_team              Denmark
# goals_scored_home          1.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           1.0
# away_team              Denmark
# goals_scored_away          2.0
# goals_conceded_away        1.0
# points_away                3.0
# match_count_away           1.0
# goals_scored               3.0
# goals_conceded             2.0
# points                     4.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 104, dtype: object
# Row2: year                      2002
# stage                  Group A
# team                   Senegal
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Senegal
# goals_scored_away          2.0
# goals_conceded_away        1.0
# points_away                4.0
# match_count_away           2.0
# goals_scored               2.0
# goals_conceded             1.0
# points                     4.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 105, dtype: object
#
# Goal difference: Denmark = 1.0, Senegal = 1.0
# Goals scored: Denmark = 3.0, Senegal = 2.0
# Goals scored result: Denmark wins
#
# === Applying Tiebreaker ===
# Row1: year                      2002
# stage                  Group A
# team                    France
# home_team               France
# goals_scored_home          0.0
# goals_conceded_home        1.0
# points_home                1.0
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# ...
# match_count_home           2.0
# away_team                  NaN
# goals_scored_away          NaN
# goals_conceded_away        NaN
# points_away                NaN
# match_count_away           NaN
# goals_scored               8.0
# goals_conceded             2.0
# points                     6.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           6.0
# tiebreaker             no need
# tie_won                      0
# Name: 256, dtype: object
# Row2: year                      2018
# stage                  Group G
# team                   England
# home_team              England
# goals_scored_home          6.0
# goals_conceded_home        1.0
# points_home                3.0
# match_count_home           1.0
# away_team              England
# goals_scored_away          2.0
# goals_conceded_away        1.0
# points_away                3.0
# match_count_away           1.0
# goals_scored               8.0
# goals_conceded             2.0
# points                     6.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           6.0
# tiebreaker             no need
# tie_won                      0
# Name: 257, dtype: object
#
# Goal difference: Belgium = 6.0, England = 6.0
# Goals scored: Belgium = 8.0, England = 8.0
# No head-to-head match found.
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                      2018
# stage                  Group G
# team                   Tunisia
# home_team              Tunisia
# goals_scored_home          1.0
# goals_conceded_home        2.0
# points_home                0.0
# match_count_home           1.0
# away_team              Tunisia
# goals_scored_away          2.0
# goals_conceded_away        5.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               3.0
# goals_conceded             7.0
# points                     0.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference          -4.0
# tiebreaker             no need
# tie_won                      0
# Name: 258, dtype: object
# Row2: year                      2018
# stage                  Group G
# team                    Panama
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team               Panama
# goals_scored_away          1.0
# goals_conceded_away        9.0
# points_away                0.0
# match_count_away           2.0
# goals_scored               1.0
# goals_conceded             9.0
# points                     0.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference          -8.0
# tiebreaker             no need
# tie_won                      0
# Name: 259, dtype: object
#
# Goal difference: Tunisia = -4.0, Panama = -8.0
# Goal difference result: Tunisia wins
#
# === Applying Tiebreaker ===
# Row1: year                      2018
# stage                  Group H
# team                     Japan
# home_team                Japan
# goals_scored_home          2.0
# goals_conceded_home        2.0
# points_home                1.0
# match_count_home           1.0
# away_team                Japan
# goals_scored_away          2.0
# goals_conceded_away        1.0
# points_away                3.0
# match_count_away           1.0
# goals_scored               4.0
# goals_conceded             3.0
# points                     4.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 260, dtype: object
# Row2: year                      2018
# stage                  Group H
# team                   Senegal
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Senegal
# goals_scored_away          4.0
# goals_conceded_away        3.0
# points_away                4.0
# match_count_away           2.0
# goals_scored               4.0
# goals_conceded             3.0
# points                     4.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           1.0
# tiebreaker             no need
# tie_won                      0
# Name: 261, dtype: object
#
# Goal difference: Japan = 1.0, Senegal = 1.0
# Goals scored: Japan = 4.0, Senegal = 4.0
# Head-to-head match found:
# year                      2018
# stage                  Group H
# home_team                Japan
# away_team              Senegal
# local_time               15:00
# short_date          2026-02-26
# goals_home                   2
# goals_away                   2
# original_score             2–2
# calculated_score           2-2
# score_match               True
# won                          0
# Name: 261, dtype: object
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                          2022
# stage                      Group A
# team                   Netherlands
# home_team              Netherlands
# goals_scored_home              1.0
# goals_conceded_home            1.0
# points_home                    1.0
# match_count_home               1.0
# away_team              Netherlands
# goals_scored_away              2.0
# goals_conceded_away            0.0
# points_away                    3.0
# match_count_away               1.0
# goals_scored                   3.0
# goals_conceded                 1.0
# points                         4.0
# total_matches                  2.0
# matches_flag                   2.0
# goals_difference               2.0
# tiebreaker                 no need
# tie_won                          0
# Name: 264, dtype: object
# Row2: year                      2022
# stage                  Group A
# team                   Ecuador
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team              Ecuador
# goals_scored_away          3.0
# goals_conceded_away        1.0
# points_away                4.0
# match_count_away           2.0
# goals_scored               3.0
# goals_conceded             1.0
# points                     4.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           2.0
# tiebreaker             no need
# tie_won                      0
# Name: 265, dtype: object
#
# Goal difference: Netherlands = 2.0, Ecuador = 2.0
# Goals scored: Netherlands = 3.0, Ecuador = 3.0
# Head-to-head match found:
# year                       2022
# stage                   Group A
# home_team           Netherlands
# away_team               Ecuador
# local_time                19:00
# short_date           2026-02-26
# goals_home                    1
# goals_away                    1
# original_score              1–1
# calculated_score            1-1
# score_match                True
# won                           0
# Name: 264, dtype: object
# All criteria tied. Result: tie
#
# === Applying Tiebreaker ===
# Row1: year                        2022
# stage                    Group C
# team                   Argentina
# home_team              Argentina
# goals_scored_home            3.0
# goals_conceded_home          2.0
# points_home                  3.0
# match_count_home             2.0
# away_team                    NaN
# goals_scored_away            NaN
# goals_conceded_away          NaN
# points_away                  NaN
# match_count_away             NaN
# goals_scored                 3.0
# goals_conceded               2.0
# points                       3.0
# total_matches                2.0
# matches_flag                 2.0
# goals_difference             1.0
# tiebreaker               no need
# tie_won                        0
# Name: 273, dtype: object
# Row2: year                           2022
# stage                       Group C
# team                   Saudi Arabia
# home_team                       NaN
# goals_scored_home               NaN
# goals_conceded_home             NaN
# points_home                     NaN
# match_count_home                NaN
# away_team              Saudi Arabia
# goals_scored_away               2.0
# goals_conceded_away             3.0
# points_away                     3.0
# match_count_away                2.0
# goals_scored                    2.0
# goals_conceded                  3.0
# points                          3.0
# total_matches                   2.0
# matches_flag                    2.0
# goals_difference               -1.0
# tiebreaker                  no need
# tie_won                           0
# Name: 274, dtype: object
#
# Goal difference: Argentina = 1.0, Saudi Arabia = -1.0
# Goal difference result: Argentina wins
#
# === Applying Tiebreaker ===
# Row1: year                      2022
# stage                  Group D
# team                   Denmark
# home_team              Denmark
# goals_scored_home          0.0
# goals_conceded_home        0.0
# points_home                1.0
# match_count_home           1.0
# away_team              Denmark
# goals_scored_away          1.0
# goals_conceded_away        2.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               1.0
# goals_conceded             2.0
# points                     1.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference          -1.0
# tiebreaker             no need
# tie_won                      0
# Name: 278, dtype: object
# Row2: year                      2022
# stage                  Group D
# team                   Tunisia
# home_team              Tunisia
# goals_scored_home          0.0
# goals_conceded_home        1.0
# points_home                0.0
# match_count_home           1.0
# away_team              Tunisia
# goals_scored_away          0.0
# goals_conceded_away        0.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               0.0
# goals_conceded             1.0
# points                     1.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference          -1.0
# tiebreaker             no need
# tie_won                      0
# Name: 279, dtype: object
#
# Goal difference: Denmark = -1.0, Tunisia = -1.0
# Goals scored: Denmark = 1.0, Tunisia = 0.0
# Goals scored result: Denmark wins
#
# === Applying Tiebreaker ===
# Row1: year                      2022
# stage                  Group E
# team                     Japan
# home_team                Japan
# goals_scored_home          0.0
# goals_conceded_home        1.0
# points_home                0.0
# match_count_home           1.0
# away_team                Japan
# goals_scored_away          2.0
# goals_conceded_away        1.0
# points_away                3.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             2.0
# points                     3.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           0.0
# tiebreaker             no need
# tie_won                      0
# Name: 281, dtype: object
# Row2: year                         2022
# stage                     Group E
# team                   Costa Rica
# home_team                     NaN
# goals_scored_home             NaN
# goals_conceded_home           NaN
# points_home                   NaN
# match_count_home              NaN
# away_team              Costa Rica
# goals_scored_away             1.0
# goals_conceded_away           7.0
# points_away                   3.0
# match_count_away              2.0
# goals_scored                  1.0
# goals_conceded                7.0
# points                        3.0
# total_matches                 2.0
# matches_flag                  2.0
# goals_difference             -6.0
# tiebreaker                no need
# tie_won                         0
# Name: 282, dtype: object
#
# Goal difference: Japan = 0.0, Costa Rica = -6.0
# Goal difference result: Japan wins
#
# === Applying Tiebreaker ===
# Row1: year                      2022
# stage                  Group F
# team                   Morocco
# home_team              Morocco
# goals_scored_home          0.0
# goals_conceded_home        0.0
# points_home                1.0
# match_count_home           1.0
# away_team              Morocco
# goals_scored_away          2.0
# goals_conceded_away        0.0
# points_away                3.0
# match_count_away           1.0
# goals_scored               2.0
# goals_conceded             0.0
# points                     4.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           2.0
# tiebreaker             no need
# tie_won                      0
# Name: 284, dtype: object
# Row2: year                      2022
# stage                  Group F
# team                   Croatia
# home_team              Croatia
# goals_scored_home          4.0
# goals_conceded_home        1.0
# points_home                3.0
# match_count_home           1.0
# away_team              Croatia
# goals_scored_away          0.0
# goals_conceded_away        0.0
# points_away                1.0
# match_count_away           1.0
# goals_scored               4.0
# goals_conceded             1.0
# points                     4.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference           3.0
# tiebreaker             no need
# tie_won                      0
# Name: 285, dtype: object
#
# Goal difference: Morocco = 2.0, Croatia = 3.0
# Goal difference result: Croatia wins
#
# === Applying Tiebreaker ===
# Row1: year                       2022
# stage                   Group G
# team                   Cameroon
# home_team              Cameroon
# goals_scored_home           3.0
# goals_conceded_home         3.0
# points_home                 1.0
# match_count_home            1.0
# away_team              Cameroon
# goals_scored_away           0.0
# goals_conceded_away         1.0
# points_away                 0.0
# match_count_away            1.0
# goals_scored                3.0
# goals_conceded              4.0
# points                      1.0
# total_matches               2.0
# matches_flag                2.0
# goals_difference           -1.0
# tiebreaker              no need
# tie_won                       0
# Name: 290, dtype: object
# Row2: year                      2022
# stage                  Group G
# team                    Serbia
# home_team                  NaN
# goals_scored_home          NaN
# goals_conceded_home        NaN
# points_home                NaN
# match_count_home           NaN
# away_team               Serbia
# goals_scored_away          3.0
# goals_conceded_away        5.0
# points_away                1.0
# match_count_away           2.0
# goals_scored               3.0
# goals_conceded             5.0
# points                     1.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference          -2.0
# tiebreaker             no need
# tie_won                      0
# Name: 291, dtype: object
#
# Goal difference: Cameroon = -1.0, Serbia = -2.0
# Goal difference result: Cameroon wins
#
# === Applying Tiebreaker ===
# Row1: year                      2022
# stage                  Group H
# team                   Uruguay
# home_team              Uruguay
# goals_scored_home          0.0
# goals_conceded_home        0.0
# points_home                1.0
# match_count_home           1.0
# away_team              Uruguay
# goals_scored_away          0.0
# goals_conceded_away        2.0
# points_away                0.0
# match_count_away           1.0
# goals_scored               0.0
# goals_conceded             2.0
# points                     1.0
# total_matches              2.0
# matches_flag               2.0
# goals_difference          -2.0
# tiebreaker             no need
# tie_won                      0
# Name: 294, dtype: object
# Row2: year                          2022
# stage                      Group H
# team                   South Korea
# home_team              South Korea
# goals_scored_home              2.0
# goals_conceded_home            3.0
# points_home                    0.0
# match_count_home               1.0
# away_team              South Korea
# goals_scored_away              0.0
# goals_conceded_away            0.0
# points_away                    1.0
# match_count_away               1.0
# goals_scored                   2.0
# goals_conceded                 3.0
# points                         1.0
# total_matches                  2.0
# matches_flag                   2.0
# goals_difference              -1.0
# tiebreaker                 no need
# tie_won                          0
# Name: 295, dtype: object
#
# Goal difference: Uruguay = -2.0, South Korea = -1.0
# Goal difference result: South Korea wins

# %%
# Filtering all_games_before_last for the year 2022 and stage 'Group E'
group2022e = all_games_before_last[
    (all_games_before_last['year'] == 2022) & 
    (all_games_before_last['stage'] == 'Group E')
]

display(group2022e)
# Out:
#      year    stage        team  standing  points  goals_scored  \
# 280  2022  Group E       Spain         1       4             8
# 281  2022  Group E       Japan         2       3             2
# 282  2022  Group E  Costa Rica         3       3             1
# 283  2022  Group E     Germany         4       1             2
#
#      goals_conceded  goals_difference  total_matches tiebreaker  tie_won
# 280               1                 7              2    no need        0
# 281               2                 0              2      Japan        1
# 282               7                -6              2      Japan        0
# 283               3                -1              2    no need        0

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\before_last_wc_fifa.xlsx'
all_games_before_last.to_excel(file_path, index=False)

# %% [markdown]
# # Recreate league table after last match day

# %%
# Define unique pairs and ensure correct order based on goals_last_day_sorted
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Merge with goals_last_day_sorted to get the correct order
unique_pairs = unique_pairs.merge(
    goals_last_day_sorted[['year', 'stage', 'short_date','local_time']].drop_duplicates(),
    how='left',
    on=['year', 'stage']
).sort_values(by=['year', 'short_date','local_time', 'stage']).reset_index(drop=True)

# Initialize an empty list to store the results for each pair
all_results = []

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    stage = row['stage']
    
    # Apply the function to the current pair
    result = fifa_final_wc(year, stage, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_results.append(result)

# Concatenate all the results into a single DataFrame
changes_df_wc = pd.concat(all_results)

# Keep only the specified columns
changes_df_wc = changes_df_wc[[ 'year', 'stage', 'team', '1st', '2nd', '3rd', '4th', 'changes']]
# Out:
# === Initial Standings for Year 1986, Group C Before Last Match Goals ===
#
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_points  before_last_game_standing
# Soviet Union             4                   7                     1                       6                        3                          1
#       France             4                   2                     1                       1                        3                          2
#      Hungary             3                   2                     6                      -4                        2                          3
#       Canada             1                   0                     3                      -3                        0                          4
#
# ====================================================
#
# Analyzing goal: 0 minute, 1 half time, Player team: nan, Home: Hungary, Away: France
#
# === Teams with Identical Points (Tied Teams) ===
#
#            team  total_points
# 8  Soviet Union             4
# 9        France             4
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Soviet Union and France
#
# === Applying Tiebreaker ===
# Row1: year                                       1986
# stage                                   Group C
# team                               Soviet Union
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 7
# before_last_game_goals_conceded               1
# before_last_game_standing                     1
# before_last_game_points                       3
# date                                       None
# time                                       None
# last_game_goals_scored                        0
# last_game_goals_conceded                      0
# total_goals_scored                            7
# total_goals_conceded                          1
# total_goals_difference                        6
# last_game_points                              1
# total_points                                  4
# last_game_standing                            1
# 1st                                           1
# 2nd                                           0
# 3rd                                           0
# 4th                                           0
# changes                                       0
# tied                                       True
# Name: 8, dtype: object
# Row2: year                                       1986
# stage                                   Group C
# team                                     France
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 2
# before_last_game_goals_conceded               1
# before_last_game_standing                     2
# before_last_game_points                       3
# date                                       None
# time                                       None
# last_game_goals_scored                        0
# last_game_goals_conceded                      0
# total_goals_scored                            2
# total_goals_conceded                          1
# total_goals_difference                        1
# last_game_points                              1
# total_points                                  4
# last_game_standing                            2
# 1st                                           0
# 2nd                                           1
# 3rd                                           0
# 4th                                           0
# changes                                       0
# tied                                       True
# Name: 9, dtype: object
#
# Goal difference: Soviet Union = 6, France = 1
# Goal difference result: Soviet Union wins
# Tiebreak Result: Winner is Soviet Union
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 8   Soviet Union                   1             4                       6
# 9         France                   2             4                       1
# 10       Hungary                   3             3                      -4
# 11        Canada                   4             1                      -3
#
#     tie_won
# 8         1
# 9         0
# 10        0
# 11        0
#
# === Updated Standings After This Goal ===
#
#         team date time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
# Soviet Union None None             4                   7                     1                       6                 1                   1        1    1    0    0    0  True        1
#       France None None             4                   2                     1                       1                 1                   2        1    0    1    0    0  True        0
#      Hungary None None             3                   2                     6                      -4                 1                   3        1    0    0    1    0 False        0
#       Canada None None             1                   0                     3                      -3                 1                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 0 minute, 1 half time, Player team: nan, Home: Soviet Union, Away: Canada
#
# === Teams with Identical Points (Tied Teams) ===
#
#            team  total_points
# 8  Soviet Union             4
# 9        France             4
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Soviet Union and France
#
# === Applying Tiebreaker ===
# Row1: year                                       1986
# stage                                   Group C
# team                               Soviet Union
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 7
# before_last_game_goals_conceded               1
# before_last_game_standing                     1
# before_last_game_points                       3
# date                                       None
# time                                       None
# last_game_goals_scored                        0
# last_game_goals_conceded                      0
# total_goals_scored                            7
# total_goals_conceded                          1
# total_goals_difference                        6
# last_game_points                              1
# total_points                                  4
# last_game_standing                            1
# 1st                                           1
# 2nd                                           0
# 3rd                                           0
# 4th                                           0
# changes                                       1
# tied                                       True
# Name: 8, dtype: object
# Row2: year                                       1986
# stage                                   Group C
# team                                     France
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 2
# before_last_game_goals_conceded               1
# before_last_game_standing                     2
# before_last_game_points                       3
# date                                       None
# time                                       None
# last_game_goals_scored                        0
# last_game_goals_conceded                      0
# total_goals_scored                            2
# total_goals_conceded                          1
# total_goals_difference                        1
# last_game_points                              1
# total_points                                  4
# last_game_standing                            2
# 1st                                           0
# 2nd                                           1
# 3rd                                           0
# 4th                                           0
# changes                                       1
# tied                                       True
# Name: 9, dtype: object
#
# Goal difference: Soviet Union = 6, France = 1
# Goal difference result: Soviet Union wins
# Tiebreak Result: Winner is Soviet Union
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 8   Soviet Union                   1             4                       6
# 9         France                   2             4                       1
# 10       Hungary                   3             3                      -4
# 11        Canada                   4             1                      -3
#
#     tie_won
# 8         1
# 9         0
# 10        0
# 11        0
#
# === Updated Standings After This Goal ===
#
#         team date time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
# Soviet Union None None             4                   7                     1                       6                 1                   1        1    1    0    0    0  True        1
#       France None None             4                   2                     1                       1                 1                   2        1    0    1    0    0  True        0
#      Hungary None None             3                   2                     6                      -4                 1                   3        1    0    0    1    0 False        0
#       Canada None None             1                   0                     3                      -3                 1                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 29 minute, 1 half time, Player team: France, Home: Hungary, Away: France
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 9         France                   1             5                       2
# 8   Soviet Union                   2             4                       6
# 10       Hungary                   3             2                      -5
# 11        Canada                   4             1                      -3
#
#     tie_won
# 9         0
# 8         0
# 10        0
# 11        0
#
# === Updated Standings After This Goal ===
#
#         team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#       France 1986-06-09 18:00             5                   3                     1                       2                 2                   1        2    1    1    0    0 False        0
# Soviet Union       None  None             4                   7                     1                       6                 1                   2        2    1    1    0    0 False        0
#      Hungary       None  None             2                   2                     7                      -5                 0                   3        1    0    0    1    0 False        0
#       Canada       None  None             1                   0                     3                      -3                 1                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 58 minute, 2 half time, Player team: Soviet Union, Home: Soviet Union, Away: Canada
#
# === Teams with Identical Points (Tied Teams) ===
#
#            team  total_points
# 9        France             5
# 8  Soviet Union             5
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Soviet Union and France
#
# === Applying Tiebreaker ===
# Row1: year                                       1986
# stage                                   Group C
# team                               Soviet Union
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 7
# before_last_game_goals_conceded               1
# before_last_game_standing                     1
# before_last_game_points                       3
# date                                 1986-06-09
# time                                      18:00
# last_game_goals_scored                        1
# last_game_goals_conceded                      0
# total_goals_scored                            8
# total_goals_conceded                          1
# total_goals_difference                        7
# last_game_points                              2
# total_points                                  5
# last_game_standing                            2
# 1st                                           1
# 2nd                                           1
# 3rd                                           0
# 4th                                           0
# changes                                       2
# tied                                       True
# Name: 8, dtype: object
# Row2: year                                       1986
# stage                                   Group C
# team                                     France
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 2
# before_last_game_goals_conceded               1
# before_last_game_standing                     2
# before_last_game_points                       3
# date                                 1986-06-09
# time                                      18:00
# last_game_goals_scored                        1
# last_game_goals_conceded                      0
# total_goals_scored                            3
# total_goals_conceded                          1
# total_goals_difference                        2
# last_game_points                              2
# total_points                                  5
# last_game_standing                            1
# 1st                                           1
# 2nd                                           1
# 3rd                                           0
# 4th                                           0
# changes                                       2
# tied                                       True
# Name: 9, dtype: object
#
# Goal difference: Soviet Union = 7, France = 2
# Goal difference result: Soviet Union wins
# Tiebreak Result: Winner is Soviet Union
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 8   Soviet Union                   1             5                       7
# 9         France                   2             5                       2
# 10       Hungary                   3             2                      -5
# 11        Canada                   4             0                      -4
#
#     tie_won
# 8         1
# 9         0
# 10        0
# 11        0
#
# === Updated Standings After This Goal ===
#
#         team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
# Soviet Union 1986-06-09 18:00             5                   8                     1                       7                 2                   1        3    2    1    0    0  True        1
#       France 1986-06-09 18:00             5                   3                     1                       2                 2                   2        3    1    2    0    0  True        0
#      Hungary       None  None             2                   2                     7                      -5                 0                   3        1    0    0    1    0 False        0
#       Canada       None  None             0                   0                     4                      -4                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 62 minute, 2 half time, Player team: France, Home: Hungary, Away: France
#
# === Teams with Identical Points (Tied Teams) ===
#
#            team  total_points
# 8  Soviet Union             5
# 9        France             5
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Soviet Union and France
#
# === Applying Tiebreaker ===
# Row1: year                                       1986
# stage                                   Group C
# team                               Soviet Union
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 7
# before_last_game_goals_conceded               1
# before_last_game_standing                     1
# before_last_game_points                       3
# date                                 1986-06-09
# time                                      18:00
# last_game_goals_scored                        1
# last_game_goals_conceded                      0
# total_goals_scored                            8
# total_goals_conceded                          1
# total_goals_difference                        7
# last_game_points                              2
# total_points                                  5
# last_game_standing                            1
# 1st                                           2
# 2nd                                           1
# 3rd                                           0
# 4th                                           0
# changes                                       3
# tied                                       True
# Name: 8, dtype: object
# Row2: year                                       1986
# stage                                   Group C
# team                                     France
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 2
# before_last_game_goals_conceded               1
# before_last_game_standing                     2
# before_last_game_points                       3
# date                                 1986-06-09
# time                                      18:00
# last_game_goals_scored                        2
# last_game_goals_conceded                      0
# total_goals_scored                            4
# total_goals_conceded                          1
# total_goals_difference                        3
# last_game_points                              2
# total_points                                  5
# last_game_standing                            2
# 1st                                           1
# 2nd                                           2
# 3rd                                           0
# 4th                                           0
# changes                                       3
# tied                                       True
# Name: 9, dtype: object
#
# Goal difference: Soviet Union = 7, France = 3
# Goal difference result: Soviet Union wins
# Tiebreak Result: Winner is Soviet Union
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 8   Soviet Union                   1             5                       7
# 9         France                   2             5                       3
# 10       Hungary                   3             2                      -6
# 11        Canada                   4             0                      -4
#
#     tie_won
# 8         1
# 9         0
# 10        0
# 11        0
#
# === Updated Standings After This Goal ===
#
#         team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
# Soviet Union 1986-06-09 18:00             5                   8                     1                       7                 2                   1        3    2    1    0    0  True        1
#       France 1986-06-09 18:00             5                   4                     1                       3                 2                   2        3    1    2    0    0  True        0
#      Hungary       None  None             2                   2                     8                      -6                 0                   3        1    0    0    1    0 False        0
#       Canada       None  None             0                   0                     4                      -4                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 74 minute, 2 half time, Player team: Soviet Union, Home: Soviet Union, Away: Canada
#
# === Teams with Identical Points (Tied Teams) ===
#
#            team  total_points
# 8  Soviet Union             5
# 9        France             5
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Soviet Union and France
#
# === Applying Tiebreaker ===
# Row1: year                                       1986
# stage                                   Group C
# team                               Soviet Union
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 7
# before_last_game_goals_conceded               1
# before_last_game_standing                     1
# before_last_game_points                       3
# date                                 1986-06-09
# time                                      18:00
# last_game_goals_scored                        2
# last_game_goals_conceded                      0
# total_goals_scored                            9
# total_goals_conceded                          1
# total_goals_difference                        8
# last_game_points                              2
# total_points                                  5
# last_game_standing                            1
# 1st                                           2
# 2nd                                           1
# 3rd                                           0
# 4th                                           0
# changes                                       3
# tied                                       True
# Name: 8, dtype: object
# Row2: year                                       1986
# stage                                   Group C
# team                                     France
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 2
# before_last_game_goals_conceded               1
# before_last_game_standing                     2
# before_last_game_points                       3
# date                                 1986-06-09
# time                                      18:00
# last_game_goals_scored                        2
# last_game_goals_conceded                      0
# total_goals_scored                            4
# total_goals_conceded                          1
# total_goals_difference                        3
# last_game_points                              2
# total_points                                  5
# last_game_standing                            2
# 1st                                           1
# 2nd                                           2
# 3rd                                           0
# 4th                                           0
# changes                                       3
# tied                                       True
# Name: 9, dtype: object
#
# Goal difference: Soviet Union = 8, France = 3
# Goal difference result: Soviet Union wins
# Tiebreak Result: Winner is Soviet Union
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 8   Soviet Union                   1             5                       8
# 9         France                   2             5                       3
# 10       Hungary                   3             2                      -6
# 11        Canada                   4             0                      -5
#
#     tie_won
# 8         1
# 9         0
# 10        0
# 11        0
#
# === Updated Standings After This Goal ===
#
#         team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
# Soviet Union 1986-06-09 18:00             5                   9                     1                       8                 2                   1        3    2    1    0    0  True        1
#       France 1986-06-09 18:00             5                   4                     1                       3                 2                   2        3    1    2    0    0  True        0
#      Hungary       None  None             2                   2                     8                      -6                 0                   3        1    0    0    1    0 False        0
#       Canada       None  None             0                   0                     5                      -5                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 84 minute, 2 half time, Player team: France, Home: Hungary, Away: France
#
# === Teams with Identical Points (Tied Teams) ===
#
#            team  total_points
# 8  Soviet Union             5
# 9        France             5
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Soviet Union and France
#
# === Applying Tiebreaker ===
# Row1: year                                       1986
# stage                                   Group C
# team                               Soviet Union
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 7
# before_last_game_goals_conceded               1
# before_last_game_standing                     1
# before_last_game_points                       3
# date                                 1986-06-09
# time                                      18:00
# last_game_goals_scored                        2
# last_game_goals_conceded                      0
# total_goals_scored                            9
# total_goals_conceded                          1
# total_goals_difference                        8
# last_game_points                              2
# total_points                                  5
# last_game_standing                            1
# 1st                                           2
# 2nd                                           1
# 3rd                                           0
# 4th                                           0
# changes                                       3
# tied                                       True
# Name: 8, dtype: object
# Row2: year                                       1986
# stage                                   Group C
# team                                     France
# tiebreaker                         Soviet Union
# tie_won                                       0
# before_last_game_goals_scored                 2
# before_last_game_goals_conceded               1
# before_last_game_standing                     2
# before_last_game_points                       3
# date                                 1986-06-09
# time                                      18:00
# last_game_goals_scored                        3
# last_game_goals_conceded                      0
# total_goals_scored                            5
# total_goals_conceded                          1
# total_goals_difference                        4
# last_game_points                              2
# total_points                                  5
# last_game_standing                            2
# 1st                                           1
# 2nd                                           2
# 3rd                                           0
# 4th                                           0
# changes                                       3
# tied                                       True
# Name: 9, dtype: object
#
# Goal difference: Soviet Union = 8, France = 4
# Goal difference result: Soviet Union wins
# Tiebreak Result: Winner is Soviet Union
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 8   Soviet Union                   1             5                       8
# 9         France                   2             5                       4
# 10       Hungary                   3             2                      -7
# 11        Canada                   4             0                      -5
#
#     tie_won
# 8         1
# 9         0
# 10        0
# 11        0
#
# === Updated Standings After This Goal ===
#
#         team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
# Soviet Union 1986-06-09 18:00             5                   9                     1                       8                 2                   1        3    2    1    0    0  True        1
#       France 1986-06-09 18:00             5                   5                     1                       4                 2                   2        3    1    2    0    0  True        0
#      Hungary       None  None             2                   2                     9                      -7                 0                   3        1    0    0    1    0 False        0
#       Canada       None  None             0                   0                     5                      -5                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
#
# === Initial Standings for Year 1986, Group A Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_points  before_last_game_standing
#   Argentina             4                   4                     2                       2                        3                          1
#    Bulgaria             3                   2                     2                       0                        2                          2
#       Italy             3                   2                     2                       0                        2                          3
# South Korea             2                   2                     4                      -2                        1                          4
#
# ====================================================
#
# Analyzing goal: 0 minute, 1 half time, Player team: nan, Home: Argentina, Away: Bulgaria
#
# === Teams with Identical Points (Tied Teams) ===
#
#        team  total_points
# 1  Bulgaria             3
# 2     Italy             3
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Bulgaria and Italy
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group A
# team                               Bulgaria
# tiebreaker                          no need
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           2
# before_last_game_standing                 2
# before_last_game_points                   2
# date                                   None
# time                                   None
# last_game_goals_scored                    0
# last_game_goals_conceded                  0
# total_goals_scored                        2
# total_goals_conceded                      2
# total_goals_difference                    0
# last_game_points                          1
# total_points                              3
# last_game_standing                        2
# 1st                                       0
# 2nd                                       1
# 3rd                                       0
# 4th                                       0
# changes                                   0
# tied                                   True
# Name: 1, dtype: object
# Row2: year                                  1986
# stage                              Group A
# team                                 Italy
# tiebreaker                         no need
# tie_won                                  0
# before_last_game_goals_scored            2
# before_last_game_goals_conceded          2
# before_last_game_standing                3
# before_last_game_points                  2
# date                                  None
# time                                  None
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       2
# total_goals_conceded                     2
# total_goals_difference                   0
# last_game_points                         1
# total_points                             3
# last_game_standing                       3
# 1st                                      0
# 2nd                                      0
# 3rd                                      1
# 4th                                      0
# changes                                  0
# tied                                  True
# Name: 2, dtype: object
#
# Goal difference: Bulgaria = 0, Italy = 0
# Goals scored: Bulgaria = 2, Italy = 2
# Head-to-head match found:
# year                      1986
# stage                  Group A
# home_team             Bulgaria
# away_team                Italy
# local_time               18:00
# short_date          2026-02-26
# goals_home                   1
# goals_away                   1
# original_score             1–1
# calculated_score           1-1
# score_match               True
# won                          0
# Name: 1, dtype: object
# All criteria tied. Result: tie
# No winner in tiebreak between Bulgaria and Italy
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             4                       2
# 1     Bulgaria                   2             3                       0
# 2        Italy                   3             3                       0
# 3  South Korea                   4             2                      -2
#
#    tie_won
# 0        0
# 1        0
# 2        0
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team date time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina None None             4                   4                     2                       2                 1                   1        1    1    0    0    0 False        0
#    Bulgaria None None             3                   2                     2                       0                 1                   2        1    0    1    0    0  True        0
#       Italy None None             3                   2                     2                       0                 1                   3        1    0    0    1    0  True        0
# South Korea None None             2                   2                     4                      -2                 1                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 4 minute, 1 half time, Player team: Argentina, Home: Argentina, Away: Bulgaria
#
# === Teams with Identical Points (Tied Teams) ===
#
#           team  total_points
# 1     Bulgaria             2
# 3  South Korea             2
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Bulgaria and South Korea
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group A
# team                               Bulgaria
# tiebreaker                          no need
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           2
# before_last_game_standing                 2
# before_last_game_points                   2
# date                                   None
# time                                   None
# last_game_goals_scored                    0
# last_game_goals_conceded                  1
# total_goals_scored                        2
# total_goals_conceded                      3
# total_goals_difference                   -1
# last_game_points                          0
# total_points                              2
# last_game_standing                        2
# 1st                                       0
# 2nd                                       1
# 3rd                                       0
# 4th                                       0
# changes                                   1
# tied                                   True
# Name: 1, dtype: object
# Row2: year                                      1986
# stage                                  Group A
# team                               South Korea
# tiebreaker                             no need
# tie_won                                      0
# before_last_game_goals_scored                2
# before_last_game_goals_conceded              4
# before_last_game_standing                    4
# before_last_game_points                      1
# date                                      None
# time                                      None
# last_game_goals_scored                       0
# last_game_goals_conceded                     0
# total_goals_scored                           2
# total_goals_conceded                         4
# total_goals_difference                      -2
# last_game_points                             1
# total_points                                 2
# last_game_standing                           4
# 1st                                          0
# 2nd                                          0
# 3rd                                          0
# 4th                                          1
# changes                                      1
# tied                                      True
# Name: 3, dtype: object
#
# Goal difference: Bulgaria = -1, South Korea = -2
# Goal difference result: Bulgaria wins
# Tiebreak Result: Winner is Bulgaria
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             5                       3
# 2        Italy                   2             3                       0
# 1     Bulgaria                   3             2                      -1
# 3  South Korea                   4             2                      -2
#
#    tie_won
# 0        0
# 2        0
# 1        1
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina 1986-06-10 18:00             5                   5                     2                       3                 2                   1        1    1    0    0    0 False        0
#       Italy       None  None             3                   2                     2                       0                 1                   2        2    0    1    1    0 False        0
#    Bulgaria       None  None             2                   2                     3                      -1                 0                   3        2    0    1    1    0  True        1
# South Korea       None  None             2                   2                     4                      -2                 1                   4        1    0    0    0    1  True        0
#
# ========================================
#
# Analyzing goal: 17 minute, 1 half time, Player team: Italy, Home: South Korea, Away: Italy
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             5                       3
# 2        Italy                   2             4                       1
# 1     Bulgaria                   3             2                      -1
# 3  South Korea                   4             1                      -3
#
#    tie_won
# 0        0
# 2        0
# 1        0
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina 1986-06-10 18:00             5                   5                     2                       3                 2                   1        1    1    0    0    0 False        0
#       Italy 1986-06-10 18:00             4                   3                     2                       1                 2                   2        2    0    1    1    0 False        0
#    Bulgaria       None  None             2                   2                     3                      -1                 0                   3        2    0    1    1    0 False        0
# South Korea       None  None             1                   2                     5                      -3                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 62 minute, 2 half time, Player team: South Korea, Home: South Korea, Away: Italy
#
# === Teams with Identical Points (Tied Teams) ===
#
#           team  total_points
# 1     Bulgaria             2
# 3  South Korea             2
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Bulgaria and South Korea
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group A
# team                               Bulgaria
# tiebreaker                          no need
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           2
# before_last_game_standing                 2
# before_last_game_points                   2
# date                                   None
# time                                   None
# last_game_goals_scored                    0
# last_game_goals_conceded                  1
# total_goals_scored                        2
# total_goals_conceded                      3
# total_goals_difference                   -1
# last_game_points                          0
# total_points                              2
# last_game_standing                        3
# 1st                                       0
# 2nd                                       1
# 3rd                                       1
# 4th                                       0
# changes                                   2
# tied                                   True
# Name: 1, dtype: object
# Row2: year                                      1986
# stage                                  Group A
# team                               South Korea
# tiebreaker                             no need
# tie_won                                      0
# before_last_game_goals_scored                2
# before_last_game_goals_conceded              4
# before_last_game_standing                    4
# before_last_game_points                      1
# date                                1986-06-10
# time                                     18:00
# last_game_goals_scored                       1
# last_game_goals_conceded                     1
# total_goals_scored                           3
# total_goals_conceded                         5
# total_goals_difference                      -2
# last_game_points                             1
# total_points                                 2
# last_game_standing                           4
# 1st                                          0
# 2nd                                          0
# 3rd                                          0
# 4th                                          1
# changes                                      1
# tied                                      True
# Name: 3, dtype: object
#
# Goal difference: Bulgaria = -1, South Korea = -2
# Goal difference result: Bulgaria wins
# Tiebreak Result: Winner is Bulgaria
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             5                       3
# 2        Italy                   2             3                       0
# 1     Bulgaria                   3             2                      -1
# 3  South Korea                   4             2                      -2
#
#    tie_won
# 0        0
# 2        0
# 1        1
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina 1986-06-10 18:00             5                   5                     2                       3                 2                   1        1    1    0    0    0 False        0
#       Italy 1986-06-10 18:00             3                   3                     3                       0                 1                   2        2    0    1    1    0 False        0
#    Bulgaria       None  None             2                   2                     3                      -1                 0                   3        2    0    1    1    0  True        1
# South Korea 1986-06-10 18:00             2                   3                     5                      -2                 1                   4        1    0    0    0    1  True        0
#
# ========================================
#
# Analyzing goal: 73 minute, 2 half time, Player team: Italy, Home: South Korea, Away: Italy
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             5                       3
# 2        Italy                   2             4                       1
# 1     Bulgaria                   3             2                      -1
# 3  South Korea                   4             1                      -3
#
#    tie_won
# 0        0
# 2        0
# 1        0
# 3        0
#
# === Updated Standings After This Goal ===
#
#        team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#   Argentina 1986-06-10 18:00             5                   5                     2                       3                 2                   1        1    1    0    0    0 False        0
#       Italy 1986-06-10 18:00             4                   4                     3                       1                 2                   2        2    0    1    1    0 False        0
#    Bulgaria       None  None             2                   2                     3                      -1                 0                   3        2    0    1    1    0 False        0
# South Korea 1986-06-10 18:00             1                   3                     6                      -3                 0                   4        1    0    0    0    1 False        0
#
# ========================================
#
# Analyzing goal: 77 minute, 2 half time, Player team: Argentina, Home: Argentina, Away: Bulgaria
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#           team  last_game_standing  total_points  total_goals_difference  \
# 0    Argentina                   1             5                       4
# 2        Italy                   2             4                       1
# 1     Bulgaria                   3             2                      -2
# 3  South Korea                   4             1                      -3
#
#    tie_won
# 0        0
# 2        0
# 1        0
# ...
# before_last_game_goals_scored             3
# before_last_game_goals_conceded           4
# before_last_game_standing                 3
# before_last_game_points                   1
# date                                   None
# time                                   None
# last_game_goals_scored                    0
# last_game_goals_conceded                  0
# total_goals_scored                        3
# total_goals_conceded                      4
# total_goals_difference                   -1
# last_game_points                          1
# total_points                              2
# last_game_standing                        3
# 1st                                       0
# 2nd                                       0
# 3rd                                       1
# 4th                                       0
# changes                                   1
# tied                                   True
# Name: 290, dtype: object
# Row2: year                                     2022
# stage                                 Group G
# team                                   Serbia
# tiebreaker                           Cameroon
# tie_won                                     0
# before_last_game_goals_scored               3
# before_last_game_goals_conceded             5
# before_last_game_standing                   4
# before_last_game_points                     1
# date                               2022-12-02
# time                                    22:00
# last_game_goals_scored                      1
# last_game_goals_conceded                    1
# total_goals_scored                          4
# total_goals_conceded                        6
# total_goals_difference                     -2
# last_game_points                            1
# total_points                                2
# last_game_standing                          4
# 1st                                         0
# 2nd                                         0
# 3rd                                         0
# 4th                                         1
# changes                                     1
# tied                                     True
# Name: 291, dtype: object
#
# Goal difference: Cameroon = -1, Serbia = -2
# Goal difference result: Cameroon wins
# Tiebreak Result: Winner is Cameroon
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 288       Brazil                   1             7                       3
# 289  Switzerland                   2             4                       0
# 290     Cameroon                   3             2                      -1
# 291       Serbia                   4             2                      -2
#
#      tie_won
# 288        0
# 289        0
# 290        1
# 291        0
#
# === Updated Standings After This Goal ===
#
#        team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#      Brazil       None  None             7                   3                     0                       3                 1                   1        1    1    0    0    0 False        0
# Switzerland 2022-12-02 22:00             4                   2                     2                       0                 1                   2        1    0    1    0    0 False        0
#    Cameroon       None  None             2                   3                     4                      -1                 1                   3        1    0    0    1    0  True        1
#      Serbia 2022-12-02 22:00             2                   4                     6                      -2                 1                   4        1    0    0    0    1  True        0
#
# ========================================
#
# Analyzing goal: 35 minute, 1 half time, Player team: Serbia, Home: Serbia, Away: Switzerland
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 288       Brazil                   1             7                       3
# 291       Serbia                   2             4                      -1
# 289  Switzerland                   3             3                      -1
# 290     Cameroon                   4             2                      -1
#
#      tie_won
# 288        0
# 291        0
# 289        0
# 290        0
#
# === Updated Standings After This Goal ===
#
#        team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#      Brazil       None  None             7                   3                     0                       3                 1                   1        1    1    0    0    0 False        0
#      Serbia 2022-12-02 22:00             4                   5                     6                      -1                 3                   2        2    0    1    0    1 False        0
# Switzerland 2022-12-02 22:00             3                   2                     3                      -1                 0                   3        2    0    1    1    0 False        0
#    Cameroon       None  None             2                   3                     4                      -1                 1                   4        2    0    0    1    1 False        0
#
# ========================================
#
# Analyzing goal: 44 minute, 1 half time, Player team: Switzerland, Home: Serbia, Away: Switzerland
#
# === Teams with Identical Points (Tied Teams) ===
#
#          team  total_points
# 291    Serbia             2
# 290  Cameroon             2
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Cameroon and Serbia
#
# === Applying Tiebreaker ===
# Row1: year                                   2022
# stage                               Group G
# team                               Cameroon
# tiebreaker                         Cameroon
# tie_won                                   0
# before_last_game_goals_scored             3
# before_last_game_goals_conceded           4
# before_last_game_standing                 3
# before_last_game_points                   1
# date                                   None
# time                                   None
# last_game_goals_scored                    0
# last_game_goals_conceded                  0
# total_goals_scored                        3
# total_goals_conceded                      4
# total_goals_difference                   -1
# last_game_points                          1
# total_points                              2
# last_game_standing                        4
# 1st                                       0
# 2nd                                       0
# 3rd                                       1
# 4th                                       1
# changes                                   2
# tied                                   True
# Name: 290, dtype: object
# Row2: year                                     2022
# stage                                 Group G
# team                                   Serbia
# tiebreaker                           Cameroon
# tie_won                                     0
# before_last_game_goals_scored               3
# before_last_game_goals_conceded             5
# before_last_game_standing                   4
# before_last_game_points                     1
# date                               2022-12-02
# time                                    22:00
# last_game_goals_scored                      2
# last_game_goals_conceded                    2
# total_goals_scored                          5
# total_goals_conceded                        7
# total_goals_difference                     -2
# last_game_points                            1
# total_points                                2
# last_game_standing                          2
# 1st                                         0
# 2nd                                         1
# 3rd                                         0
# 4th                                         1
# changes                                     2
# tied                                     True
# Name: 291, dtype: object
#
# Goal difference: Cameroon = -1, Serbia = -2
# Goal difference result: Cameroon wins
# Tiebreak Result: Winner is Cameroon
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 288       Brazil                   1             7                       3
# 289  Switzerland                   2             4                       0
# 290     Cameroon                   3             2                      -1
# 291       Serbia                   4             2                      -2
#
#      tie_won
# 288        0
# 289        0
# 290        1
# 291        0
#
# === Updated Standings After This Goal ===
#
#        team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#      Brazil       None  None             7                   3                     0                       3                 1                   1        1    1    0    0    0 False        0
# Switzerland 2022-12-02 22:00             4                   3                     3                       0                 1                   2        3    0    2    1    0 False        0
#    Cameroon       None  None             2                   3                     4                      -1                 1                   3        3    0    0    2    1  True        1
#      Serbia 2022-12-02 22:00             2                   5                     7                      -2                 1                   4        3    0    1    0    2  True        0
#
# ========================================
#
# Analyzing goal: 48 minute, 2 half time, Player team: Switzerland, Home: Serbia, Away: Switzerland
#
# === Teams with Identical Points (Tied Teams) ===
#
# Empty DataFrame
# Columns: [team, total_points]
# Index: []
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 288       Brazil                   1             7                       3
# 289  Switzerland                   2             6                       1
# 290     Cameroon                   3             2                      -1
# 291       Serbia                   4             1                      -3
#
#      tie_won
# 288        0
# 289        0
# 290        0
# 291        0
#
# === Updated Standings After This Goal ===
#
#        team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#      Brazil       None  None             7                   3                     0                       3                 1                   1        1    1    0    0    0 False        0
# Switzerland 2022-12-02 22:00             6                   4                     3                       1                 3                   2        3    0    2    1    0 False        0
#    Cameroon       None  None             2                   3                     4                      -1                 1                   3        3    0    0    2    1 False        0
#      Serbia 2022-12-02 22:00             1                   5                     8                      -3                 0                   4        3    0    1    0    2 False        0
#
# ========================================
#
# Analyzing goal: 92 minute, 2 half time, Player team: Cameroon, Home: Cameroon, Away: Brazil
#
# === Teams with Identical Points (Tied Teams) ===
#
#             team  total_points
# 288       Brazil             6
# 289  Switzerland             6
#
# === Evaluating Head-to-Head for Tied Teams ===
#
# Checking tie between: Brazil and Switzerland
#
# === Applying Tiebreaker ===
# Row1: year                                  2022
# stage                              Group G
# team                                Brazil
# tiebreaker                         no need
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          0
# before_last_game_standing                1
# before_last_game_points                  6
# date                                  None
# time                                  None
# last_game_goals_scored                   0
# last_game_goals_conceded                 1
# total_goals_scored                       3
# total_goals_conceded                     1
# total_goals_difference                   2
# last_game_points                         0
# total_points                             6
# last_game_standing                       1
# 1st                                      1
# 2nd                                      0
# 3rd                                      0
# 4th                                      0
# changes                                  1
# tied                                  True
# Name: 288, dtype: object
# Row2: year                                      2022
# stage                                  Group G
# team                               Switzerland
# tiebreaker                             no need
# tie_won                                      0
# before_last_game_goals_scored                1
# before_last_game_goals_conceded              1
# before_last_game_standing                    2
# before_last_game_points                      3
# date                                2022-12-02
# time                                     22:00
# last_game_goals_scored                       3
# last_game_goals_conceded                     2
# total_goals_scored                           4
# total_goals_conceded                         3
# total_goals_difference                       1
# last_game_points                             3
# total_points                                 6
# last_game_standing                           2
# 1st                                          0
# 2nd                                          2
# 3rd                                          1
# 4th                                          0
# changes                                      3
# tied                                      True
# Name: 289, dtype: object
#
# Goal difference: Brazil = 2, Switzerland = 1
# Goal difference result: Brazil wins
# Tiebreak Result: Winner is Brazil
#
# === Updated Standings After Sorting and Tie Break ===
#
#             team  last_game_standing  total_points  total_goals_difference  \
# 288       Brazil                   1             6                       2
# 289  Switzerland                   2             6                       1
# 290     Cameroon                   3             4                       0
# 291       Serbia                   4             1                      -3
#
#      tie_won
# 288        1
# 289        0
# 290        0
# 291        0
#
# === Updated Standings After This Goal ===
#
#        team       date  time  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tie_won
#      Brazil       None  None             6                   3                     1                       2                 0                   1        1    1    0    0    0  True        1
# Switzerland 2022-12-02 22:00             6                   4                     3                       1                 3                   2        3    0    2    1    0  True        0
#    Cameroon 2022-12-02 22:00             4                   4                     4                       0                 3                   3        3    0    0    2    1 False        0
#      Serbia 2022-12-02 22:00             1                   5                     8                      -3                 0                   4        3    0    1    0    2 False        0
#
# ========================================

# %%
# # Exporting final df
# file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\tb_wc_fifa_men.xlsx'
# changes_df_wc.to_excel(file_path, index=False)

# %% [markdown]
# # group composition tracking

# %%
unique_pairs.groupby('year').count()
# Out:
#       stage  short_date  local_time
# year
# 1986      6           6           6
# 1990      6           6           6
# 1994      6           6           6
# 1998      8           8           8
# 2002      8           8           8
# 2006      8           8           8
# 2010      8           8           8
# 2014      8           8           8
# 2018      8           8           8
# 2022      8           8           8

# %%
# Group by 'year', 'stage', and 'short_date' and count unique values of 'local_time'
unique_pairs_grouped = unique_pairs.groupby(['year', 'stage', 'short_date'])['local_time'].nunique().reset_index()

# Rename the column for clarity
unique_pairs_grouped.rename(columns={'local_time': 'unique_local_times'}, inplace=True)

# Filter the DataFrame to highlight rows where unique_local_times > 1
highlighted_rows = unique_pairs_grouped[unique_pairs_grouped['unique_local_times'] > 1]
highlighted_rows
# Out:
# Empty DataFrame
# Columns: [year, stage, short_date, unique_local_times]
# Index: []

# %%
# Initialize an empty list to store the results for each pair
all_composition_changes = []

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    stage = row['stage']
    
    # Apply the function to the current pair
    composition_changes_df, third_place_df = gap_composition(year, stage, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day, competition = "WC")
    
    # Append the result to the list
    all_composition_changes.append(composition_changes_df)

# Concatenate all the results into a single DataFrame
final_composition_changes_df = pd.concat(all_composition_changes, ignore_index=True)
# Out:
# [INFO] Using competition filter: WC
#
# === STEP 1: Initial Standings for Group C, 1986 (Goal Time = 0) ===
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
# Soviet Union             4                   7                     1                       6                          1
#       France             4                   2                     1                       1                          2
#      Hungary             3                   2                     6                      -4                          3
#       Canada             1                   0                     3                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 0 1 half time by nan in Group C, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group C, Goal Minute: 0, Team: Hungary, Points: 3, Goal Difference: -4, Goals Scored: 2, Date: 1986-06-09, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group C', 'goal_minute': 0, 'half_time': 1, 'third_team': 'Hungary', 'total_points': 3, 'total_goals_difference': -4, 'total_goals_scored': 2, 'date': '1986-06-09', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 0 1 half time by nan in Group C, edition 1986 ===
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
# Soviet Union             4                   7                     1                       6                          1
#       France             4                   2                     1                       1                          2
#      Hungary             3                   2                     6                      -4                          3
#       Canada             1                   0                     3                      -3                          4
#
# ========================================
#
#
# === STEP 4: Applying Potential Tiebreaker for 3nd and 4th Place ===
#
#
# === Applying Tiebreaker ===
# Row1: year                                  1986
# stage                              Group C
# team                               Hungary
# tie_won                                  0
# before_last_game_goals_scored            2
# before_last_game_goals_conceded          6
# before_last_game_standing                3
# before_last_game_points                  2
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       2
# total_goals_conceded                     6
# total_goals_difference                  -4
# last_game_points                         1
# total_points                             3
# last_game_standing                       3
# three_tie                                0
# four_tie                                 0
# tied                                 False
# Name: 10, dtype: object
# Row2: year                                  1986
# stage                              Group C
# team                                Canada
# tie_won                                  0
# before_last_game_goals_scored            0
# before_last_game_goals_conceded          3
# before_last_game_standing                4
# before_last_game_points                  0
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       1
# total_goals_conceded                     3
# total_goals_difference                  -2
# last_game_points                         1
# total_points                             1
# last_game_standing                       4
# three_tie                                0
# four_tie                                 0
# tied                                 False
# Name: 11, dtype: object
#
# Goal difference: Hungary = -4, Canada = -2
# Goal difference result: Canada wins
#
# === Tied after goal at minute 0 1 half time by nan in Group C, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group C, Goal Minute: 0, Team: Hungary, Points: 3, Goal Difference: -4, Goals Scored: 2, Date: 1986-06-09, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group C', 'goal_minute': 0, 'half_time': 1, 'third_team': 'Hungary', 'total_points': 3, 'total_goals_difference': -4, 'total_goals_scored': 2, 'date': '1986-06-09', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 0 1 half time by nan in Group C, edition 1986 ===
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
# Soviet Union             4                   7                     1                       6                          1
#       France             4                   2                     1                       1                          2
#      Hungary             3                   2                     6                      -4                          3
#       Canada             1                   0                     3                      -3                          4
#
# ========================================
#
#
# === STEP 4: Applying Potential Tiebreaker for 3nd and 4th Place ===
#
#
# === Applying Tiebreaker ===
# Row1: year                                  1986
# stage                              Group C
# team                               Hungary
# tie_won                                  0
# before_last_game_goals_scored            2
# before_last_game_goals_conceded          6
# before_last_game_standing                3
# before_last_game_points                  2
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       2
# total_goals_conceded                     6
# total_goals_difference                  -4
# last_game_points                         1
# total_points                             3
# last_game_standing                       3
# three_tie                                0
# four_tie                                 0
# tied                                 False
# Name: 10, dtype: object
# Row2: year                                  1986
# stage                              Group C
# team                                Canada
# tie_won                                  0
# before_last_game_goals_scored            0
# before_last_game_goals_conceded          3
# before_last_game_standing                4
# before_last_game_points                  0
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       1
# total_goals_conceded                     3
# total_goals_difference                  -2
# last_game_points                         1
# total_points                             1
# last_game_standing                       4
# three_tie                                0
# four_tie                                 0
# tied                                 False
# Name: 11, dtype: object
#
# Goal difference: Hungary = -4, Canada = -2
# Goal difference result: Canada wins
#
# === Tied after goal at minute 29 1 half time by France in Group C, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group C, Goal Minute: 29, Team: Hungary, Points: 2, Goal Difference: -5, Goals Scored: 2, Date: 1986-06-09, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group C', 'goal_minute': 29, 'half_time': 1, 'third_team': 'Hungary', 'total_points': 2, 'total_goals_difference': -5, 'total_goals_scored': 2, 'date': '1986-06-09', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 29 1 half time by France in Group C, edition 1986 ===
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#       France             5                   3                     1                       2                          2
# Soviet Union             4                   7                     1                       6                          1
#      Hungary             2                   2                     7                      -5                          3
#       Canada             1                   0                     3                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 58 2 half time by Soviet Union in Group C, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group C, Goal Minute: 58, Team: Hungary, Points: 2, Goal Difference: -5, Goals Scored: 2, Date: 1986-06-09, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group C', 'goal_minute': 58, 'half_time': 2, 'third_team': 'Hungary', 'total_points': 2, 'total_goals_difference': -5, 'total_goals_scored': 2, 'date': '1986-06-09', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 58 2 half time by Soviet Union in Group C, edition 1986 ===
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
# Soviet Union             5                   8                     1                       7                          1
#       France             5                   3                     1                       2                          2
#      Hungary             2                   2                     7                      -5                          3
#       Canada             0                   0                     4                      -4                          4
#
# ========================================
#
#
# === Tied after goal at minute 62 2 half time by France in Group C, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group C, Goal Minute: 62, Team: Hungary, Points: 2, Goal Difference: -6, Goals Scored: 2, Date: 1986-06-09, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group C', 'goal_minute': 62, 'half_time': 2, 'third_team': 'Hungary', 'total_points': 2, 'total_goals_difference': -6, 'total_goals_scored': 2, 'date': '1986-06-09', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 62 2 half time by France in Group C, edition 1986 ===
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
# Soviet Union             5                   8                     1                       7                          1
#       France             5                   4                     1                       3                          2
#      Hungary             2                   2                     8                      -6                          3
#       Canada             0                   0                     4                      -4                          4
#
# ========================================
#
#
# === Tied after goal at minute 74 2 half time by Soviet Union in Group C, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group C, Goal Minute: 74, Team: Hungary, Points: 2, Goal Difference: -6, Goals Scored: 2, Date: 1986-06-09, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group C', 'goal_minute': 74, 'half_time': 2, 'third_team': 'Hungary', 'total_points': 2, 'total_goals_difference': -6, 'total_goals_scored': 2, 'date': '1986-06-09', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 74 2 half time by Soviet Union in Group C, edition 1986 ===
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
# Soviet Union             5                   9                     1                       8                          1
#       France             5                   4                     1                       3                          2
#      Hungary             2                   2                     8                      -6                          3
#       Canada             0                   0                     5                      -5                          4
#
# ========================================
#
#
# === Tied after goal at minute 84 2 half time by France in Group C, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group C, Goal Minute: 84, Team: Hungary, Points: 2, Goal Difference: -7, Goals Scored: 2, Date: 1986-06-09, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group C', 'goal_minute': 84, 'half_time': 2, 'third_team': 'Hungary', 'total_points': 2, 'total_goals_difference': -7, 'total_goals_scored': 2, 'date': '1986-06-09', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 84 2 half time by France in Group C, edition 1986 ===
#         team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
# Soviet Union             5                   9                     1                       8                          1
#       France             5                   5                     1                       4                          2
#      Hungary             2                   2                     9                      -7                          3
#       Canada             0                   0                     5                      -5                          4
#
# ========================================
#
# [INFO] Using competition filter: WC
#
# === STEP 1: Initial Standings for Group A, 1986 (Goal Time = 0) ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             4                   4                     2                       2                          1
#    Bulgaria             3                   2                     2                       0                          2
#       Italy             3                   2                     2                       0                          3
# South Korea             2                   2                     4                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 0 1 half time by nan in Group A, edition 1986 ===
# Number of tied teams: 2
#        team  total_points  total_goals_scored  total_goals_conceded  \
# 1  Bulgaria             3                   2                     2
# 2     Italy             3                   2                     2
#
#    total_goals_difference
# 1                       0
# 2                       0
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Checking ties for teams with 3 points ===
# Checking tie between: Bulgaria and Italy
#
# === Applying Tiebreaker ===
# Row1: year                                   1986
# stage                               Group A
# team                               Bulgaria
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           2
# before_last_game_standing                 2
# before_last_game_points                   2
# last_game_goals_scored                    0
# last_game_goals_conceded                  0
# total_goals_scored                        2
# total_goals_conceded                      2
# total_goals_difference                    0
# last_game_points                          1
# total_points                              3
# last_game_standing                        0
# three_tie                                 0
# four_tie                                  0
# tied                                   True
# Name: 1, dtype: object
# Row2: year                                  1986
# stage                              Group A
# team                                 Italy
# tie_won                                  0
# before_last_game_goals_scored            2
# before_last_game_goals_conceded          2
# before_last_game_standing                3
# before_last_game_points                  2
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       2
# total_goals_conceded                     2
# total_goals_difference                   0
# last_game_points                         1
# total_points                             3
# last_game_standing                       0
# three_tie                                0
# four_tie                                 0
# tied                                  True
# Name: 2, dtype: object
#
# Goal difference: Bulgaria = 0, Italy = 0
# Goals scored: Bulgaria = 2, Italy = 2
# Head-to-head match found:
# year                      1986
# stage                  Group A
# home_team             Bulgaria
# away_team                Italy
# local_time               18:00
# short_date          2026-02-26
# goals_home                   1
# goals_away                   1
# original_score             1–1
# calculated_score           1-1
# score_match               True
# won                          0
# Name: 1, dtype: object
# All criteria tied. Result: tie
# No winner in tiebreak between Bulgaria and Italy
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 0, Team: Italy, Points: 3, Goal Difference: 0, Goals Scored: 2, Date: 1986-06-10, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 0, 'half_time': 1, 'third_team': 'Italy', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 2, 'date': '1986-06-10', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 0 1 half time by nan in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             4                   4                     2                       2                          1
#    Bulgaria             3                   2                     2                       0                          2
#       Italy             3                   2                     2                       0                          3
# South Korea             2                   2                     4                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 4 1 half time by Argentina in Group A, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 4, Team: Bulgaria, Points: 2, Goal Difference: -1, Goals Scored: 2, Date: 1986-06-10, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 4, 'half_time': 1, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 2, 'date': '1986-06-10', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 4 1 half time by Argentina in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   5                     2                       3                          1
#       Italy             3                   2                     2                       0                          3
#    Bulgaria             2                   2                     3                      -1                          2
# South Korea             2                   2                     4                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 17 1 half time by Italy in Group A, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 17, Team: Bulgaria, Points: 2, Goal Difference: -1, Goals Scored: 2, Date: 1986-06-10, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 17, 'half_time': 1, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 2, 'date': '1986-06-10', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 17 1 half time by Italy in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   5                     2                       3                          1
#       Italy             4                   3                     2                       1                          3
#    Bulgaria             2                   2                     3                      -1                          2
# South Korea             1                   2                     5                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 62 2 half time by South Korea in Group A, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 62, Team: Bulgaria, Points: 2, Goal Difference: -1, Goals Scored: 2, Date: 1986-06-10, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 62, 'half_time': 2, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 2, 'date': '1986-06-10', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 62 2 half time by South Korea in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   5                     2                       3                          1
#       Italy             3                   3                     3                       0                          3
#    Bulgaria             2                   2                     3                      -1                          2
# South Korea             2                   3                     5                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 73 2 half time by Italy in Group A, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 73, Team: Bulgaria, Points: 2, Goal Difference: -1, Goals Scored: 2, Date: 1986-06-10, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 73, 'half_time': 2, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 2, 'date': '1986-06-10', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 73 2 half time by Italy in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   5                     2                       3                          1
#       Italy             4                   4                     3                       1                          3
#    Bulgaria             2                   2                     3                      -1                          2
# South Korea             1                   3                     6                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 77 2 half time by Argentina in Group A, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 77, Team: Bulgaria, Points: 2, Goal Difference: -2, Goals Scored: 2, Date: 1986-06-10, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 77, 'half_time': 2, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -2, 'total_goals_scored': 2, 'date': '1986-06-10', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 77 2 half time by Argentina in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   6                     2                       4                          1
#       Italy             4                   4                     3                       1                          3
#    Bulgaria             2                   2                     4                      -2                          2
# South Korea             1                   3                     6                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 82 2 half time by Italy in Group A, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 82, Team: Bulgaria, Points: 2, Goal Difference: -2, Goals Scored: 2, Date: 1986-06-10, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 82, 'half_time': 2, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -2, 'total_goals_scored': 2, 'date': '1986-06-10', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 82 2 half time by Italy in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   6                     2                       4                          1
#       Italy             4                   5                     3                       2                          3
#    Bulgaria             2                   2                     4                      -2                          2
# South Korea             1                   3                     7                      -4                          4
#
# ========================================
#
#
# === Tied after goal at minute 89 2 half time by South Korea in Group A, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group A, Goal Minute: 89, Team: Bulgaria, Points: 2, Goal Difference: -2, Goals Scored: 2, Date: 1986-06-10, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group A', 'goal_minute': 89, 'half_time': 2, 'third_team': 'Bulgaria', 'total_points': 2, 'total_goals_difference': -2, 'total_goals_scored': 2, 'date': '1986-06-10', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 89 2 half time by South Korea in Group A, edition 1986 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Argentina             5                   6                     2                       4                          1
#       Italy             4                   5                     4                       1                          3
#    Bulgaria             2                   2                     4                      -2                          2
# South Korea             1                   4                     7                      -3                          4
#
# ========================================
#
# [INFO] Using competition filter: WC
#
# === STEP 1: Initial Standings for Group B, 1986 (Goal Time = 0) ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Mexico             4                   3                     2                       1                          1
# Paraguay             4                   2                     1                       1                          2
#  Belgium             3                   3                     3                       0                          3
#     Iraq             1                   1                     3                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 0 1 half time by nan in Group B, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group B, Goal Minute: 0, Team: Belgium, Points: 3, Goal Difference: 0, Goals Scored: 3, Date: 1986-06-11, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group B', 'goal_minute': 0, 'half_time': 1, 'third_team': 'Belgium', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 3, 'date': '1986-06-11', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 0 1 half time by nan in Group B, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Mexico             4                   3                     2                       1                          1
# Paraguay             4                   2                     1                       1                          2
#  Belgium             3                   3                     3                       0                          3
#     Iraq             1                   1                     3                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 30 1 half time by Belgium in Group B, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group B, Goal Minute: 30, Team: Paraguay, Points: 3, Goal Difference: 0, Goals Scored: 2, Date: 1986-06-11, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group B', 'goal_minute': 30, 'half_time': 1, 'third_team': 'Paraguay', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 2, 'date': '1986-06-11', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 30 1 half time by Belgium in Group B, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#  Belgium             4                   4                     3                       1                          3
#   Mexico             4                   3                     2                       1                          1
# Paraguay             3                   2                     2                       0                          2
#     Iraq             1                   1                     3                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 50 2 half time by Paraguay in Group B, edition 1986 ===
# Number of tied teams: 2
#        team  total_points  total_goals_scored  total_goals_conceded  \
# 4    Mexico             4                   3                     2
# 5  Paraguay             4                   3                     2
#
#    total_goals_difference
# 4                       1
# 5                       1
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Checking ties for teams with 4 points ===
# Checking tie between: Mexico and Paraguay
#
# === Applying Tiebreaker ===
# Row1: year                                  1986
# stage                              Group B
# team                                Mexico
# tie_won                                  0
# before_last_game_goals_scored            3
# before_last_game_goals_conceded          2
# before_last_game_standing                1
# before_last_game_points                  3
# last_game_goals_scored                   0
# last_game_goals_conceded                 0
# total_goals_scored                       3
# total_goals_conceded                     2
# total_goals_difference                   1
# last_game_points                         1
# total_points                             4
# last_game_standing                       2
# three_tie                                0
# four_tie                                 0
# tied                                  True
# Name: 4, dtype: object
# Row2: year                                   1986
# stage                               Group B
# team                               Paraguay
# tie_won                                   0
# before_last_game_goals_scored             2
# before_last_game_goals_conceded           1
# before_last_game_standing                 2
# before_last_game_points                   3
# last_game_goals_scored                    1
# last_game_goals_conceded                  1
# total_goals_scored                        3
# total_goals_conceded                      2
# total_goals_difference                    1
# last_game_points                          1
# total_points                              4
# last_game_standing                        3
# three_tie                                 0
# four_tie                                  0
# tied                                   True
# Name: 5, dtype: object
#
# Goal difference: Mexico = 1, Paraguay = 1
# Goals scored: Mexico = 3, Paraguay = 3
# Head-to-head match found:
# year                      1986
# stage                  Group B
# home_team               Mexico
# away_team             Paraguay
# local_time               18:00
# short_date          2026-02-26
# goals_home                   1
# goals_away                   1
# original_score             1–1
# calculated_score           1-1
# score_match               True
# won                          0
# Name: 6, dtype: object
# All criteria tied. Result: tie
# No winner in tiebreak between Mexico and Paraguay
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group B, Goal Minute: 50, Team: Belgium, Points: 3, Goal Difference: 0, Goals Scored: 4, Date: 1986-06-11, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group B', 'goal_minute': 50, 'half_time': 2, 'third_team': 'Belgium', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 4, 'date': '1986-06-11', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 50 2 half time by Paraguay in Group B, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Mexico             4                   3                     2                       1                          1
# Paraguay             4                   3                     2                       1                          2
#  Belgium             3                   4                     4                       0                          3
#     Iraq             1                   1                     3                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 54 2 half time by Mexico in Group B, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group B, Goal Minute: 54, Team: Belgium, Points: 3, Goal Difference: 0, Goals Scored: 4, Date: 1986-06-11, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group B', 'goal_minute': 54, 'half_time': 2, 'third_team': 'Belgium', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 4, 'date': '1986-06-11', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 54 2 half time by Mexico in Group B, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Mexico             5                   4                     2                       2                          1
# Paraguay             4                   3                     2                       1                          2
#  Belgium             3                   4                     4                       0                          3
#     Iraq             0                   1                     4                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 59 2 half time by Belgium in Group B, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group B, Goal Minute: 59, Team: Paraguay, Points: 3, Goal Difference: 0, Goals Scored: 3, Date: 1986-06-11, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group B', 'goal_minute': 59, 'half_time': 2, 'third_team': 'Paraguay', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 3, 'date': '1986-06-11', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 59 2 half time by Belgium in Group B, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Mexico             5                   4                     2                       2                          1
#  Belgium             4                   5                     4                       1                          3
# Paraguay             3                   3                     3                       0                          2
#     Iraq             0                   1                     4                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 76 2 half time by Paraguay in Group B, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group B, Goal Minute: 76, Team: Belgium, Points: 3, Goal Difference: 0, Goals Scored: 5, Date: 1986-06-11, Time: 18:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group B', 'goal_minute': 76, 'half_time': 2, 'third_team': 'Belgium', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 5, 'date': '1986-06-11', 'time': '18:00'}
#
# === STEP 3: Standings after goal at minute 76 2 half time by Paraguay in Group B, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Mexico             5                   4                     2                       2                          1
# Paraguay             4                   4                     3                       1                          2
#  Belgium             3                   5                     5                       0                          3
#     Iraq             0                   1                     4                      -3                          4
#
# ========================================
#
# [INFO] Using competition filter: WC
#
# === STEP 1: Initial Standings for Group F, 1986 (Goal Time = 0) ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Poland             4                   1                     0                       1                          1
# Portugal             3                   1                     1                       0                          2
#  Morocco             3                   0                     0                       0                          3
#  England             2                   0                     1                      -1                          4
#
# ========================================
#
#
# === Tied after goal at minute 0 1 half time by nan in Group F, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group F, Goal Minute: 0, Team: Morocco, Points: 3, Goal Difference: 0, Goals Scored: 0, Date: 1986-06-11, Time: 22:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group F', 'goal_minute': 0, 'half_time': 1, 'third_team': 'Morocco', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 0, 'date': '1986-06-11', 'time': '22:00'}
#
# === STEP 3: Standings after goal at minute 0 1 half time by nan in Group F, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#   Poland             4                   1                     0                       1                          1
# Portugal             3                   1                     1                       0                          2
#  Morocco             3                   0                     0                       0                          3
#  England             2                   0                     1                      -1                          4
#
# ========================================
#
#
# === Tied after goal at minute 8 1 half time by England in Group F, edition 1986 ===
# Number of tied teams: 3
#         team  total_points  total_goals_scored  total_goals_conceded  \
# 20    Poland             3                   1                     1
# 21  Portugal             3                   1                     1
# 23   England             3                   1                     1
#
#     total_goals_difference
# 20                       0
# 21                       0
# 23                       0
#
# === STEP 2: Evaluating Head-to-Head for Tied Teams ===
#
#
# === Resolving Three-Way Tie for 3 points ===
#
# === Resolving Three-Way Tie for Teams: ['Poland', 'Portugal', 'England'] ===
#    Poland => GD: 0, GS: 1
#    Portugal => GD: 0, GS: 1
#    England => GD: 0, GS: 1
#
# 🔹 Resolving Tie Between Poland and Portugal:
#
# 🔹 Resolving Tie Between Poland and England:
#
# 🔹 Resolving Tie Between Portugal and Poland:
#
# ✅ Final Resolved Three-Way Ranking:
#    1. Portugal (GD: 0, GS: 1, Total GS in Group: 1)
#    2. Poland (GD: 0, GS: 1, Total GS in Group: 1)
#    3. England (GD: 0, GS: 1, Total GS in Group: 1)
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group F, Goal Minute: 8, Team: Portugal, Points: 3, Goal Difference: 0, Goals Scored: 1, Date: 1986-06-11, Time: 22:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group F', 'goal_minute': 8, 'half_time': 1, 'third_team': 'Portugal', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 1, 'date': '1986-06-11', 'time': '22:00'}
#
# === STEP 3: Standings after goal at minute 8 1 half time by England in Group F, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#  England             3                   1                     1                       0                          4
#   Poland             3                   1                     1                       0                          1
# Portugal             3                   1                     1                       0                          2
#  Morocco             3                   0                     0                       0                          3
#
# ========================================
#
#
# === Tied after goal at minute 14 1 half time by England in Group F, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group F, Goal Minute: 14, Team: Morocco, Points: 3, Goal Difference: 0, Goals Scored: 0, Date: 1986-06-11, Time: 22:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group F', 'goal_minute': 14, 'half_time': 1, 'third_team': 'Morocco', 'total_points': 3, 'total_goals_difference': 0, 'total_goals_scored': 0, 'date': '1986-06-11', 'time': '22:00'}
#
# === STEP 3: Standings after goal at minute 14 1 half time by England in Group F, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#  England             3                   2                     1                       1                          4
# Portugal             3                   1                     1                       0                          2
#  Morocco             3                   0                     0                       0                          3
#   Poland             3                   1                     2                      -1                          1
#
# ========================================
#
#
# === Tied after goal at minute 19 1 half time by Morocco in Group F, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group F, Goal Minute: 19, Team: Poland, Points: 3, Goal Difference: -1, Goals Scored: 1, Date: 1986-06-11, Time: 22:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group F', 'goal_minute': 19, 'half_time': 1, 'third_team': 'Poland', 'total_points': 3, 'total_goals_difference': -1, 'total_goals_scored': 1, 'date': '1986-06-11', 'time': '22:00'}
#
# === STEP 3: Standings after goal at minute 19 1 half time by Morocco in Group F, edition 1986 ===
#     team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#  Morocco             4                   1                     0                       1                          3
#  England             3                   2                     1                       1                          4
#   Poland             3                   1                     2                      -1                          1
# Portugal             2                   1                     2                      -1                          2
#
# ========================================
#
#
# === Tied after goal at minute 27 1 half time by Morocco in Group F, edition 1986 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 1986, Stage: Group F, Goal Minute: 27, Team: Poland, Points: 3, Goal Difference: -1, Goals Scored: 1, Date: 1986-06-11, Time: 22:00
# [DEBUG] Third Place Tracking Updated: {'year': 1986, 'stage': 'Group F', 'goal_minute': 27, 'half_time': 1, 'third_team': 'Poland', 'total_points': 3, 'total_goals_difference': -1, 'total_goals_scored': 1, 'date': '1986-06-11', 'time': '22:00'}
#
# === STEP 3: Standings after goal at minute 27 1 half time by Morocco in Group F, edition 1986 ===
# ...
#      Serbia             2                   3                     5                      -2                          4
#
# ========================================
#
#
# === Tied after goal at minute 0 1 half time by nan in Group G, edition 2022 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group G, Goal Minute: 0, Team: Cameroon, Points: 2, Goal Difference: -1, Goals Scored: 3, Date: 2022-12-02, Time: 22:00
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group G', 'goal_minute': 0, 'half_time': 1, 'third_team': 'Cameroon', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 3, 'date': '2022-12-02', 'time': '22:00'}
#
# === STEP 3: Standings after goal at minute 0 1 half time by nan in Group G, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#      Brazil             7                   3                     0                       3                          1
# Switzerland             4                   1                     1                       0                          2
#    Cameroon             2                   3                     4                      -1                          3
#      Serbia             2                   3                     5                      -2                          4
#
# ========================================
#
#
# === STEP 4: Applying Potential Tiebreaker for 2nd and 3rd Place ===
#
#
# === Applying Tiebreaker ===
# Row1: year                                      2022
# stage                                  Group G
# team                               Switzerland
# tie_won                                      0
# before_last_game_goals_scored                1
# before_last_game_goals_conceded              1
# before_last_game_standing                    2
# before_last_game_points                      3
# last_game_goals_scored                       0
# last_game_goals_conceded                     0
# total_goals_scored                           1
# total_goals_conceded                         1
# total_goals_difference                       0
# last_game_points                             1
# total_points                                 4
# last_game_standing                           2
# three_tie                                    0
# four_tie                                     0
# tied                                     False
# Name: 289, dtype: object
# Row2: year                                   2022
# stage                               Group G
# team                               Cameroon
# tie_won                                   0
# before_last_game_goals_scored             3
# before_last_game_goals_conceded           4
# before_last_game_standing                 3
# before_last_game_points                   1
# last_game_goals_scored                    0
# last_game_goals_conceded                  0
# total_goals_scored                        4
# total_goals_conceded                      4
# total_goals_difference                    0
# last_game_points                          1
# total_points                              2
# last_game_standing                        3
# three_tie                                 0
# four_tie                                  0
# tied                                  False
# Name: 290, dtype: object
#
# Goal difference: Switzerland = 0, Cameroon = 0
# Goals scored: Switzerland = 1, Cameroon = 4
# Goals scored result: Cameroon wins
#
# === Tied after goal at minute 20 1 half time by Switzerland in Group G, edition 2022 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group G, Goal Minute: 20, Team: Cameroon, Points: 2, Goal Difference: -1, Goals Scored: 3, Date: 2022-12-02, Time: 22:00
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group G', 'goal_minute': 20, 'half_time': 1, 'third_team': 'Cameroon', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 3, 'date': '2022-12-02', 'time': '22:00'}
#
# === STEP 3: Standings after goal at minute 20 1 half time by Switzerland in Group G, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#      Brazil             7                   3                     0                       3                          1
# Switzerland             6                   2                     1                       1                          2
#    Cameroon             2                   3                     4                      -1                          3
#      Serbia             1                   3                     6                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 26 1 half time by Serbia in Group G, edition 2022 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group G, Goal Minute: 26, Team: Cameroon, Points: 2, Goal Difference: -1, Goals Scored: 3, Date: 2022-12-02, Time: 22:00
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group G', 'goal_minute': 26, 'half_time': 1, 'third_team': 'Cameroon', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 3, 'date': '2022-12-02', 'time': '22:00'}
#
# === STEP 3: Standings after goal at minute 26 1 half time by Serbia in Group G, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#      Brazil             7                   3                     0                       3                          1
# Switzerland             4                   2                     2                       0                          2
#    Cameroon             2                   3                     4                      -1                          3
#      Serbia             2                   4                     6                      -2                          4
#
# ========================================
#
#
# === STEP 4: Applying Potential Tiebreaker for 2nd and 3rd Place ===
#
#
# === Applying Tiebreaker ===
# Row1: year                                      2022
# stage                                  Group G
# team                               Switzerland
# tie_won                                      0
# before_last_game_goals_scored                1
# before_last_game_goals_conceded              1
# before_last_game_standing                    2
# before_last_game_points                      3
# last_game_goals_scored                       1
# last_game_goals_conceded                     1
# total_goals_scored                           2
# total_goals_conceded                         2
# total_goals_difference                       0
# last_game_points                             1
# total_points                                 4
# last_game_standing                           2
# three_tie                                    0
# four_tie                                     0
# tied                                     False
# Name: 289, dtype: object
# Row2: year                                   2022
# stage                               Group G
# team                               Cameroon
# tie_won                                   0
# before_last_game_goals_scored             3
# before_last_game_goals_conceded           4
# before_last_game_standing                 3
# before_last_game_points                   1
# last_game_goals_scored                    0
# last_game_goals_conceded                  0
# total_goals_scored                        4
# total_goals_conceded                      4
# total_goals_difference                    0
# last_game_points                          1
# total_points                              2
# last_game_standing                        3
# three_tie                                 0
# four_tie                                  0
# tied                                  False
# Name: 290, dtype: object
#
# Goal difference: Switzerland = 0, Cameroon = 0
# Goals scored: Switzerland = 2, Cameroon = 4
# Goals scored result: Cameroon wins
#
# === Tied after goal at minute 35 1 half time by Serbia in Group G, edition 2022 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group G, Goal Minute: 35, Team: Switzerland, Points: 3, Goal Difference: -1, Goals Scored: 2, Date: 2022-12-02, Time: 22:00
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group G', 'goal_minute': 35, 'half_time': 1, 'third_team': 'Switzerland', 'total_points': 3, 'total_goals_difference': -1, 'total_goals_scored': 2, 'date': '2022-12-02', 'time': '22:00'}
#
# === STEP 3: Standings after goal at minute 35 1 half time by Serbia in Group G, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#      Brazil             7                   3                     0                       3                          1
#      Serbia             4                   5                     6                      -1                          4
# Switzerland             3                   2                     3                      -1                          2
#    Cameroon             2                   3                     4                      -1                          3
#
# ========================================
#
#
# === Tied after goal at minute 44 1 half time by Switzerland in Group G, edition 2022 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group G, Goal Minute: 44, Team: Cameroon, Points: 2, Goal Difference: -1, Goals Scored: 3, Date: 2022-12-02, Time: 22:00
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group G', 'goal_minute': 44, 'half_time': 1, 'third_team': 'Cameroon', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 3, 'date': '2022-12-02', 'time': '22:00'}
#
# === STEP 3: Standings after goal at minute 44 1 half time by Switzerland in Group G, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#      Brazil             7                   3                     0                       3                          1
# Switzerland             4                   3                     3                       0                          2
#    Cameroon             2                   3                     4                      -1                          3
#      Serbia             2                   5                     7                      -2                          4
#
# ========================================
#
#
# === STEP 4: Applying Potential Tiebreaker for 2nd and 3rd Place ===
#
#
# === Applying Tiebreaker ===
# Row1: year                                      2022
# stage                                  Group G
# team                               Switzerland
# tie_won                                      0
# before_last_game_goals_scored                1
# before_last_game_goals_conceded              1
# before_last_game_standing                    2
# before_last_game_points                      3
# last_game_goals_scored                       2
# last_game_goals_conceded                     2
# total_goals_scored                           3
# total_goals_conceded                         3
# total_goals_difference                       0
# last_game_points                             1
# total_points                                 4
# last_game_standing                           2
# three_tie                                    0
# four_tie                                     0
# tied                                     False
# Name: 289, dtype: object
# Row2: year                                   2022
# stage                               Group G
# team                               Cameroon
# tie_won                                   0
# before_last_game_goals_scored             3
# before_last_game_goals_conceded           4
# before_last_game_standing                 3
# before_last_game_points                   1
# last_game_goals_scored                    0
# last_game_goals_conceded                  0
# total_goals_scored                        4
# total_goals_conceded                      4
# total_goals_difference                    0
# last_game_points                          1
# total_points                              2
# last_game_standing                        3
# three_tie                                 0
# four_tie                                  0
# tied                                  False
# Name: 290, dtype: object
#
# Goal difference: Switzerland = 0, Cameroon = 0
# Goals scored: Switzerland = 3, Cameroon = 4
# Goals scored result: Cameroon wins
#
# === Tied after goal at minute 48 2 half time by Switzerland in Group G, edition 2022 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group G, Goal Minute: 48, Team: Cameroon, Points: 2, Goal Difference: -1, Goals Scored: 3, Date: 2022-12-02, Time: 22:00
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group G', 'goal_minute': 48, 'half_time': 2, 'third_team': 'Cameroon', 'total_points': 2, 'total_goals_difference': -1, 'total_goals_scored': 3, 'date': '2022-12-02', 'time': '22:00'}
#
# === STEP 3: Standings after goal at minute 48 2 half time by Switzerland in Group G, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#      Brazil             7                   3                     0                       3                          1
# Switzerland             6                   4                     3                       1                          2
#    Cameroon             2                   3                     4                      -1                          3
#      Serbia             1                   5                     8                      -3                          4
#
# ========================================
#
#
# === Tied after goal at minute 92 2 half time by Cameroon in Group G, edition 2022 ===
# Number of tied teams: 0
# Empty DataFrame
# Columns: [team, total_points, total_goals_scored, total_goals_conceded, total_goals_difference]
# Index: []
# [DEBUG] Saving Third Team - Year: 2022, Stage: Group G, Goal Minute: 92, Team: Cameroon, Points: 4, Goal Difference: 0, Goals Scored: 4, Date: 2022-12-02, Time: 22:00
# [DEBUG] Third Place Tracking Updated: {'year': 2022, 'stage': 'Group G', 'goal_minute': 92, 'half_time': 2, 'third_team': 'Cameroon', 'total_points': 4, 'total_goals_difference': 0, 'total_goals_scored': 4, 'date': '2022-12-02', 'time': '22:00'}
#
# === STEP 3: Standings after goal at minute 92 2 half time by Cameroon in Group G, edition 2022 ===
#        team  total_points  total_goals_scored  total_goals_conceded  total_goals_difference  before_last_game_standing
#      Brazil             6                   3                     1                       2                          1
# Switzerland             6                   4                     3                       1                          2
#    Cameroon             4                   4                     4                       0                          3
#      Serbia             1                   5                     8                      -3                          4
#
# ========================================

# %% [markdown]
# ## manually modify order of tie teams by drawing of lots

# %%
mask = (final_composition_changes_df['year'] == 1990) & \
       (final_composition_changes_df['stage'] == "Group F") & \
       (final_composition_changes_df['goal_minute'] == 71)

final_composition_changes_df.loc[mask, ['2nd', '3rd']] = final_composition_changes_df.loc[mask, ['3rd', '2nd']].values

# %% [markdown]
# ## manually modify order of tie teams by fair play points

# %%
mask = (final_composition_changes_df['year'] == 2018) & \
       (final_composition_changes_df['stage'] == "Group H") & \
       (final_composition_changes_df['goal_minute'] == 74)

final_composition_changes_df.loc[mask, ['2nd', '3rd']] = final_composition_changes_df.loc[mask, ['3rd', '2nd']].values

# %% [markdown]
# # best four third placed

# %%
# Filter the dataset to include only years <= 1994
third_place_df = third_place_df[third_place_df['year'] <= 1994].copy()

# Remove all observations with goal_minute == 0
third_place_df = third_place_df[third_place_df['goal_minute'] != 0]

# Remove duplicates
third_place_df = third_place_df.drop_duplicates()


third_place_df = ensure_goal_minute_zero(third_place_df, all_games_before_last, add_initial_draw_point=True, competition="WC")


# Fill missing 'date' and 'time' with the next row's value (backward fill)
third_place_df[['date', 'time']] = third_place_df[['date', 'time']].fillna(method='bfill')
# Out:
# [INFO] Removing existing `goal_minute = 0` entries...
# [INFO] Using competition filter: WC
# [INFO] Years included: [1986, 1990, 1994]
# [INFO] Creating `goal_minute = 0` entries from `all_games_before_last`
# [INFO] Adding 18 new `goal_minute = 0` entries.
# [INFO] `goal_minute = 0` entries updated successfully.

# %%
# # Exporting final df
# file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\third_place_df.xlsx'
# third_place_df.to_excel(file_path, index=False)

# %% [markdown]
# ### resolving ties using yellow cards

# %%
team_priority = {
  
}

# %%
initial_third_teams_df = initial_third_teams(third_place_df, add_initial_draw_point=False)

# %%
initial_third_teams_df
# Out:
#    year  goal_minute        date   time  change_flag  change_count  \
# 0  1986            0  1986-06-09  18:00            0             0
# 1  1990            0  1990-06-18  21:00            0             0
# 2  1994            0  1994-06-26  20:00            0             0
#
#                                             top_four  \
# 0  [[Belgium, 3, 0, 3], [Italy, 3, 0, 2], [Morocc...
# 1  [[Argentina, 3, 1, 2], [Costa Rica, 3, 0, 1], ...
# 2  [[Bulgaria, 4, 1, 4], [Netherlands, 4, 0, 2], ...
#
#                                             last_two              tied_team  \
# 0  [[Northern Ireland, 2, -1, 2], [Uruguay, 2, -5...                     []
# 1         [[Uruguay, 2, -2, 1], [Austria, 1, -2, 0]]  [Ireland, Costa Rica]
# 2     [[South Korea, 3, 0, 2], [Cameroon, 2, -3, 2]]                     []
#
#                 Group B              Group A                 Group F  \
# 0    [Belgium, 3, 0, 3]     [Italy, 3, 0, 2]      [Morocco, 3, 0, 0]
# 1  [Argentina, 3, 1, 2]  [Austria, 1, -2, 0]      [Ireland, 3, 0, 1]
# 2  [Cameroon, 2, -3, 2]  [Romania, 4, -1, 4]  [Netherlands, 4, 0, 2]
#
#                   Group C                       Group D              Group E
# 0     [Hungary, 3, -4, 2]  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]
# 1   [Costa Rica, 3, 0, 1]        [Yugoslavia, 3, -2, 2]  [Uruguay, 2, -2, 1]
# 2  [South Korea, 3, 0, 2]           [Bulgaria, 4, 1, 4]     [Italy, 4, 0, 1]

# %%
third_teams_df = third_teams(third_place_df, initial_third_teams_df, team_priority)

# %%
third_teams_df = third_track(third_teams_df)

# %%
# Define output path and save
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\third_teams_wc_fifa.xlsx'
third_teams_df.to_excel(file_path, index=False)

print(f"Data successfully saved to {file_path}")
# Out:
# Data successfully saved to C:\Users\aldi\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\third_teams_wc_fifa.xlsx

# %% [markdown]
# ### variable to track whether third teams qualifies or not

# %%
# Apply to final_composition_changes_df
final_composition_changes_df = format_time_column(final_composition_changes_df, 'time')

# %%
# Convert 'time' to proper format (HH:MM), handling NaN values
final_composition_changes_df["time"] = pd.to_datetime(final_composition_changes_df["time"], errors='coerce').dt.strftime('%H:%M')

# Step 1: Order the dataset by 'year', 'stage', 'half_time', and 'goal_minute', 
# ensuring that goal_minute == 0 is ranked at the top
final_composition_changes_df = final_composition_changes_df.sort_values(
    by=["year", "stage", "half_time", "goal_minute"], ascending=[True, True, True, True]
).reset_index(drop=True)

# Step 2: Fill 'time' and 'date' forward within each 'stage'
final_composition_changes_df["time"] = final_composition_changes_df.groupby("stage")["time"].fillna(method="ffill")
final_composition_changes_df["date"] = final_composition_changes_df.groupby("stage")["date"].fillna(method="ffill")

# %%
# Initialize third_qualify to 0
final_composition_changes_df['third_qualify'] = 0

# Process only years <= 1994
for index, row in final_composition_changes_df.iterrows():
    if row['year'] <= 1994:
        # Print debugging information for each condition
        year_match = third_teams_df['year'] == row['year']
        goal_minute_match = third_teams_df['goal_minute'] == row['goal_minute']
        date_match = third_teams_df['date'] == row['date']
        time_match = third_teams_df['time'] == row['time']
        stage_match = third_teams_df['stage'] == row['stage']

        # Find matching rows
        match = third_teams_df[year_match & goal_minute_match & date_match & time_match & stage_match]

        # Print which conditions do not hold
        if match.empty:
            print(f"\n⚠️ No match for index {index} | year: {row['year']} | goal_minute: {row['goal_minute']}")

            if not year_match.any():
                print(f" ❌ Year {row['year']} not found in third_teams_df")

            if not goal_minute_match.any():
                print(f" ❌ Goal_minute {row['goal_minute']} not found in third_teams_df | Unique values: {third_teams_df['goal_minute'].unique()}")

            if not date_match.any():
                print(f" ❌ Date {row['date']} not found in third_teams_df | Unique values: {third_teams_df['date'].unique()[:10]}")

            if not time_match.any():
                print(f" ❌ Time {row['time']} not found in third_teams_df | Unique values: {third_teams_df['time'].unique()[:10]}")

            if not stage_match.any():
                print(f" ❌ Stage {row['stage']} not found in third_teams_df | Unique values: {third_teams_df['stage'].unique()[:10]}")

        else:
            print(f"\n✅ Match found for index {index}:\n{match}")

            # Check if the 3rd place team is in the top four third-placed teams
            top_four_teams = match.iloc[0]['top_four']
            print(f"Index {index} | top_four_teams: {top_four_teams} (type: {type(top_four_teams)})")

            # Convert top_four_teams if stored as a string
            import ast
            if isinstance(top_four_teams, str):
                top_four_teams = ast.literal_eval(top_four_teams)

            # Check if the 3rd place team is in the top four
            if row['3rd'] not in top_four_teams:
                print(f"⚠️ Third-place team {row['3rd']} NOT in top_four_teams {top_four_teams}")
            else:
                final_composition_changes_df.at[index, 'third_qualify'] = 1

# Create qualified_teams list: always includes 1st and 2nd, includes 3rd only if third_qualify == 1
final_composition_changes_df['qualified_teams'] = final_composition_changes_df.apply(
    lambda row: [row['1st'], row['2nd']] + ([row['3rd']] if row['third_qualify'] == 1 else []),
    axis=1
)

# Remove the columns 'change_num' and 'changed' from the DataFrame
final_composition_changes_df = final_composition_changes_df.drop(columns=['change_num', 'changed'], errors='ignore')
# Out:
# ✅ Match found for index 0:
#    year        date   time  goal_minute  half_time    stage           Group A  \
# 6  1986  1986-06-10  18:00            0          1  Group A  [Italy, 3, 0, 2]
#
#               Group B              Group C                       Group D  \
# 6  [Belgium, 3, 0, 3]  [Hungary, 2, -7, 2]  [Northern Ireland, 2, -1, 2]
#
#                Group E             Group F  \
# 6  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                       top_four            last_two tied_teams  \
# 6  [Belgium, Italy, Morocco, Northern Ireland]  [Uruguay, Hungary]         []
#
#    change_flag  change_count
# 6            0             1
# Index 0 | top_four_teams: ['Belgium', 'Italy', 'Morocco', 'Northern Ireland'] (type: <class 'list'>)
#
# ✅ Match found for index 1:
#    year        date   time  goal_minute  half_time    stage  \
# 7  1986  1986-06-10  18:00            4          1  Group A
#
#                 Group A             Group B              Group C  \
# 7  [Bulgaria, 2, -1, 2]  [Belgium, 3, 0, 3]  [Hungary, 2, -7, 2]
#
#                         Group D              Group E             Group F  \
# 7  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                          top_four            last_two  \
# 7  [Belgium, Morocco, Bulgaria, Northern Ireland]  [Uruguay, Hungary]
#
#                      tied_teams  change_flag  change_count
# 7  [Bulgaria, Northern Ireland]            1             2
# Index 1 | top_four_teams: ['Belgium', 'Morocco', 'Bulgaria', 'Northern Ireland'] (type: <class 'list'>)
#
# ✅ Match found for index 2:
#    year        date   time  goal_minute  half_time    stage  \
# 8  1986  1986-06-10  18:00           17          1  Group A
#
#                 Group A             Group B              Group C  \
# 8  [Bulgaria, 2, -1, 2]  [Belgium, 3, 0, 3]  [Hungary, 2, -7, 2]
#
#                         Group D              Group E             Group F  \
# 8  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                          top_four            last_two  \
# 8  [Belgium, Morocco, Bulgaria, Northern Ireland]  [Uruguay, Hungary]
#
#                      tied_teams  change_flag  change_count
# 8  [Bulgaria, Northern Ireland]            0             2
# Index 2 | top_four_teams: ['Belgium', 'Morocco', 'Bulgaria', 'Northern Ireland'] (type: <class 'list'>)
#
# ✅ Match found for index 3:
#    year        date   time  goal_minute  half_time    stage  \
# 9  1986  1986-06-10  18:00           62          2  Group A
#
#                 Group A             Group B              Group C  \
# 9  [Bulgaria, 2, -1, 2]  [Belgium, 3, 0, 3]  [Hungary, 2, -7, 2]
#
#                         Group D              Group E             Group F  \
# 9  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                          top_four            last_two  \
# 9  [Belgium, Morocco, Bulgaria, Northern Ireland]  [Uruguay, Hungary]
#
#                      tied_teams  change_flag  change_count
# 9  [Bulgaria, Northern Ireland]            0             2
# Index 3 | top_four_teams: ['Belgium', 'Morocco', 'Bulgaria', 'Northern Ireland'] (type: <class 'list'>)
#
# ✅ Match found for index 4:
#     year        date   time  goal_minute  half_time    stage  \
# 10  1986  1986-06-10  18:00           73          2  Group A
#
#                  Group A             Group B              Group C  \
# 10  [Bulgaria, 2, -1, 2]  [Belgium, 3, 0, 3]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 10  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                           top_four            last_two  \
# 10  [Belgium, Morocco, Bulgaria, Northern Ireland]  [Uruguay, Hungary]
#
#                       tied_teams  change_flag  change_count
# 10  [Bulgaria, Northern Ireland]            0             2
# Index 4 | top_four_teams: ['Belgium', 'Morocco', 'Bulgaria', 'Northern Ireland'] (type: <class 'list'>)
#
# ✅ Match found for index 5:
#     year        date   time  goal_minute  half_time    stage  \
# 11  1986  1986-06-10  18:00           77          2  Group A
#
#                  Group A             Group B              Group C  \
# 11  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 3]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 11  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                           top_four            last_two  \
# 11  [Belgium, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 11         []            0             2
# Index 5 | top_four_teams: ['Belgium', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 6:
#     year        date   time  goal_minute  half_time    stage  \
# 12  1986  1986-06-10  18:00           82          2  Group A
#
#                  Group A             Group B              Group C  \
# 12  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 3]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 12  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                           top_four            last_two  \
# 12  [Belgium, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 12         []            0             2
# Index 6 | top_four_teams: ['Belgium', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 7:
#     year        date   time  goal_minute  half_time    stage  \
# 13  1986  1986-06-10  18:00           89          2  Group A
#
#                  Group A             Group B              Group C  \
# 13  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 3]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 13  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                           top_four            last_two  \
# 13  [Belgium, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 13         []            0             2
# Index 7 | top_four_teams: ['Belgium', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 8:
#    year        date   time  goal_minute  half_time    stage           Group A  \
# 6  1986  1986-06-10  18:00            0          1  Group A  [Italy, 3, 0, 2]
#
#               Group B              Group C                       Group D  \
# 6  [Belgium, 3, 0, 3]  [Hungary, 2, -7, 2]  [Northern Ireland, 2, -1, 2]
#
#                Group E             Group F  \
# 6  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                       top_four            last_two tied_teams  \
# 6  [Belgium, Italy, Morocco, Northern Ireland]  [Uruguay, Hungary]         []
#
#    change_flag  change_count
# 6            0             1
# Index 8 | top_four_teams: ['Belgium', 'Italy', 'Morocco', 'Northern Ireland'] (type: <class 'list'>)
#
# ✅ Match found for index 9:
#     year        date   time  goal_minute  half_time    stage  \
# 14  1986  1986-06-11  18:00            0          1  Group B
#
#                  Group A             Group B              Group C  \
# 14  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 3]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 14  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                           top_four            last_two  \
# 14  [Belgium, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 14         []            0             2
# Index 9 | top_four_teams: ['Belgium', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 10:
#     year        date   time  goal_minute  half_time    stage  \
# 15  1986  1986-06-11  18:00           30          1  Group B
#
#                  Group A              Group B              Group C  \
# 15  [Bulgaria, 2, -2, 2]  [Paraguay, 3, 0, 2]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 15  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                            top_four            last_two  \
# 15  [Paraguay, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 15         []            1             3
# Index 10 | top_four_teams: ['Paraguay', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 11:
#     year        date   time  goal_minute  half_time    stage  \
# 16  1986  1986-06-11  18:00           50          2  Group B
#
#                  Group A             Group B              Group C  \
# 16  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 4]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 16  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                           top_four            last_two  \
# 16  [Belgium, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 16         []            1             4
# Index 11 | top_four_teams: ['Belgium', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 12:
#     year        date   time  goal_minute  half_time    stage  \
# 17  1986  1986-06-11  18:00           54          2  Group B
#
#                  Group A             Group B              Group C  \
# 17  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 4]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 17  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                           top_four            last_two  \
# 17  [Belgium, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 17         []            0             4
# Index 12 | top_four_teams: ['Belgium', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 13:
#     year        date   time  goal_minute  half_time    stage  \
# 18  1986  1986-06-11  18:00           59          2  Group B
#
#                  Group A              Group B              Group C  \
# 18  [Bulgaria, 2, -2, 2]  [Paraguay, 3, 0, 3]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 18  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                            top_four            last_two  \
# 18  [Paraguay, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 18         []            1             5
# Index 13 | top_four_teams: ['Paraguay', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 14:
#     year        date   time  goal_minute  half_time    stage  \
# 19  1986  1986-06-11  18:00           76          2  Group B
#
#                  Group A             Group B              Group C  \
# 19  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 19  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                           top_four            last_two  \
# 19  [Belgium, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 19         []            1             6
# Index 14 | top_four_teams: ['Belgium', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 15:
#     year        date   time  goal_minute  half_time    stage  \
# 14  1986  1986-06-11  18:00            0          1  Group B
#
#                  Group A             Group B              Group C  \
# 14  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 3]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 14  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                           top_four            last_two  \
# 14  [Belgium, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 14         []            0             2
# Index 15 | top_four_teams: ['Belgium', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 16:
#    year        date   time  goal_minute  half_time    stage           Group A  \
# 0  1986  1986-06-09  18:00            0          1  Group C  [Italy, 3, 0, 2]
#
#               Group B              Group C                       Group D  \
# 0  [Belgium, 3, 0, 3]  [Hungary, 3, -4, 2]  [Northern Ireland, 2, -1, 2]
#
#                Group E             Group F  \
# 0  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                              top_four                     last_two tied_teams  \
# 0  [Belgium, Italy, Morocco, Hungary]  [Northern Ireland, Uruguay]         []
#
#    change_flag  change_count
# 0            0             0
# Index 16 | top_four_teams: ['Belgium', 'Italy', 'Morocco', 'Hungary'] (type: <class 'list'>)
#
# ✅ Match found for index 17:
#    year        date   time  goal_minute  half_time    stage           Group A  \
# 0  1986  1986-06-09  18:00            0          1  Group C  [Italy, 3, 0, 2]
#
#               Group B              Group C                       Group D  \
# 0  [Belgium, 3, 0, 3]  [Hungary, 3, -4, 2]  [Northern Ireland, 2, -1, 2]
#
#                Group E             Group F  \
# 0  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                              top_four                     last_two tied_teams  \
# 0  [Belgium, Italy, Morocco, Hungary]  [Northern Ireland, Uruguay]         []
#
#    change_flag  change_count
# 0            0             0
# Index 17 | top_four_teams: ['Belgium', 'Italy', 'Morocco', 'Hungary'] (type: <class 'list'>)
#
# ✅ Match found for index 18:
#    year        date   time  goal_minute  half_time    stage           Group A  \
# 1  1986  1986-06-09  18:00           29          1  Group C  [Italy, 3, 0, 2]
#
#               Group B              Group C                       Group D  \
# 1  [Belgium, 3, 0, 3]  [Hungary, 2, -5, 2]  [Northern Ireland, 2, -1, 2]
#
#                Group E             Group F  \
# 1  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                       top_four            last_two  \
# 1  [Belgium, Italy, Morocco, Northern Ireland]  [Hungary, Uruguay]
#
#            tied_teams  change_flag  change_count
# 1  [Hungary, Uruguay]            1             1
# Index 18 | top_four_teams: ['Belgium', 'Italy', 'Morocco', 'Northern Ireland'] (type: <class 'list'>)
# ⚠️ Third-place team Hungary NOT in top_four_teams ['Belgium', 'Italy', 'Morocco', 'Northern Ireland']
#
# ✅ Match found for index 19:
#    year        date   time  goal_minute  half_time    stage           Group A  \
# 2  1986  1986-06-09  18:00           58          2  Group C  [Italy, 3, 0, 2]
#
#               Group B              Group C                       Group D  \
# 2  [Belgium, 3, 0, 3]  [Hungary, 2, -5, 2]  [Northern Ireland, 2, -1, 2]
#
#                Group E             Group F  \
# 2  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                       top_four            last_two  \
# 2  [Belgium, Italy, Morocco, Northern Ireland]  [Hungary, Uruguay]
#
#            tied_teams  change_flag  change_count
# 2  [Hungary, Uruguay]            0             1
# Index 19 | top_four_teams: ['Belgium', 'Italy', 'Morocco', 'Northern Ireland'] (type: <class 'list'>)
# ⚠️ Third-place team Hungary NOT in top_four_teams ['Belgium', 'Italy', 'Morocco', 'Northern Ireland']
#
# ✅ Match found for index 20:
#    year        date   time  goal_minute  half_time    stage           Group A  \
# 3  1986  1986-06-09  18:00           62          2  Group C  [Italy, 3, 0, 2]
#
#               Group B              Group C                       Group D  \
# 3  [Belgium, 3, 0, 3]  [Hungary, 2, -6, 2]  [Northern Ireland, 2, -1, 2]
#
#                Group E             Group F  \
# 3  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                       top_four            last_two tied_teams  \
# 3  [Belgium, Italy, Morocco, Northern Ireland]  [Uruguay, Hungary]         []
#
#    change_flag  change_count
# 3            0             1
# Index 20 | top_four_teams: ['Belgium', 'Italy', 'Morocco', 'Northern Ireland'] (type: <class 'list'>)
# ⚠️ Third-place team Hungary NOT in top_four_teams ['Belgium', 'Italy', 'Morocco', 'Northern Ireland']
#
# ✅ Match found for index 21:
#    year        date   time  goal_minute  half_time    stage           Group A  \
# 4  1986  1986-06-09  18:00           74          2  Group C  [Italy, 3, 0, 2]
#
#               Group B              Group C                       Group D  \
# 4  [Belgium, 3, 0, 3]  [Hungary, 2, -6, 2]  [Northern Ireland, 2, -1, 2]
#
#                Group E             Group F  \
# 4  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                       top_four            last_two tied_teams  \
# 4  [Belgium, Italy, Morocco, Northern Ireland]  [Uruguay, Hungary]         []
#
#    change_flag  change_count
# 4            0             1
# Index 21 | top_four_teams: ['Belgium', 'Italy', 'Morocco', 'Northern Ireland'] (type: <class 'list'>)
# ⚠️ Third-place team Hungary NOT in top_four_teams ['Belgium', 'Italy', 'Morocco', 'Northern Ireland']
#
# ✅ Match found for index 22:
#    year        date   time  goal_minute  half_time    stage           Group A  \
# 5  1986  1986-06-09  18:00           84          2  Group C  [Italy, 3, 0, 2]
#
#               Group B              Group C                       Group D  \
# 5  [Belgium, 3, 0, 3]  [Hungary, 2, -7, 2]  [Northern Ireland, 2, -1, 2]
#
#                Group E             Group F  \
# 5  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                       top_four            last_two tied_teams  \
# 5  [Belgium, Italy, Morocco, Northern Ireland]  [Uruguay, Hungary]         []
#
#    change_flag  change_count
# 5            0             1
# Index 22 | top_four_teams: ['Belgium', 'Italy', 'Morocco', 'Northern Ireland'] (type: <class 'list'>)
# ⚠️ Third-place team Hungary NOT in top_four_teams ['Belgium', 'Italy', 'Morocco', 'Northern Ireland']
#
# ✅ Match found for index 23:
#    year        date   time  goal_minute  half_time    stage           Group A  \
# 0  1986  1986-06-09  18:00            0          1  Group C  [Italy, 3, 0, 2]
#
#               Group B              Group C                       Group D  \
# 0  [Belgium, 3, 0, 3]  [Hungary, 3, -4, 2]  [Northern Ireland, 2, -1, 2]
#
#                Group E             Group F  \
# 0  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                              top_four                     last_two tied_teams  \
# 0  [Belgium, Italy, Morocco, Hungary]  [Northern Ireland, Uruguay]         []
#
#    change_flag  change_count
# 0            0             0
# Index 23 | top_four_teams: ['Belgium', 'Italy', 'Morocco', 'Hungary'] (type: <class 'list'>)
#
# ✅ Match found for index 24:
#     year        date   time  goal_minute  half_time    stage  \
# 28  1986  1986-06-12  18:00            0          1  Group D
#
#                  Group A             Group B              Group C  \
# 28  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 28  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                          top_four            last_two  \
# 28  [Belgium, Poland, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 28         []            0             9
# Index 24 | top_four_teams: ['Belgium', 'Poland', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 25:
#     year        date   time  goal_minute  half_time    stage  \
# 28  1986  1986-06-12  18:00            0          1  Group D
#
#                  Group A             Group B              Group C  \
# 28  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 28  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                          top_four            last_two  \
# 28  [Belgium, Poland, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 28         []            0             9
# Index 25 | top_four_teams: ['Belgium', 'Poland', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 26:
#     year        date   time  goal_minute  half_time    stage  \
# 29  1986  1986-06-12  18:00           15          1  Group D
# 30  1986  1986-06-12  18:00           15          1  Group D
#
#                  Group A             Group B              Group C  \
# 29  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
# 30  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 29           [Algeria, 2, -1, 1]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
# 30  [Northern Ireland, 1, -2, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                 top_four                     last_two  \
# 29  [Belgium, Poland, Algeria, Bulgaria]           [Uruguay, Hungary]
# 30  [Belgium, Poland, Bulgaria, Uruguay]  [Hungary, Northern Ireland]
#
#    tied_teams  change_flag  change_count
# 29         []            1            10
# 30         []            1            11
# Index 26 | top_four_teams: ['Belgium', 'Poland', 'Algeria', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 27:
#     year        date   time  goal_minute  half_time    stage  \
# 29  1986  1986-06-12  18:00           15          1  Group D
# 30  1986  1986-06-12  18:00           15          1  Group D
#
#                  Group A             Group B              Group C  \
# 29  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
# 30  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 29           [Algeria, 2, -1, 1]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
# 30  [Northern Ireland, 1, -2, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                 top_four                     last_two  \
# 29  [Belgium, Poland, Algeria, Bulgaria]           [Uruguay, Hungary]
# 30  [Belgium, Poland, Bulgaria, Uruguay]  [Hungary, Northern Ireland]
#
#    tied_teams  change_flag  change_count
# 29         []            1            10
# 30         []            1            11
# Index 27 | top_four_teams: ['Belgium', 'Poland', 'Algeria', 'Bulgaria'] (type: <class 'list'>)
# ⚠️ Third-place team Northern Ireland NOT in top_four_teams ['Belgium', 'Poland', 'Algeria', 'Bulgaria']
#
# ✅ Match found for index 28:
#     year        date   time  goal_minute  half_time    stage  \
# 31  1986  1986-06-12  18:00           42          1  Group D
#
#                  Group A             Group B              Group C  \
# 31  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                 Group D              Group E             Group F  \
# 31  [Algeria, 1, -2, 1]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                 top_four            last_two tied_teams  \
# 31  [Belgium, Poland, Bulgaria, Uruguay]  [Hungary, Algeria]         []
#
#     change_flag  change_count
# 31            0            11
# Index 28 | top_four_teams: ['Belgium', 'Poland', 'Bulgaria', 'Uruguay'] (type: <class 'list'>)
# ⚠️ Third-place team Algeria NOT in top_four_teams ['Belgium', 'Poland', 'Bulgaria', 'Uruguay']
#
# ✅ Match found for index 29:
#     year        date   time  goal_minute  half_time    stage  \
# 32  1986  1986-06-12  18:00           68          2  Group D
#
#                  Group A             Group B              Group C  \
# 32  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 32  [Northern Ireland, 1, -3, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                 top_four                     last_two  \
# 32  [Belgium, Poland, Bulgaria, Uruguay]  [Hungary, Northern Ireland]
#
#    tied_teams  change_flag  change_count
# 32         []            0            11
# Index 29 | top_four_teams: ['Belgium', 'Poland', 'Bulgaria', 'Uruguay'] (type: <class 'list'>)
# ⚠️ Third-place team Northern Ireland NOT in top_four_teams ['Belgium', 'Poland', 'Bulgaria', 'Uruguay']
#
# ✅ Match found for index 30:
#     year        date   time  goal_minute  half_time    stage  \
# 33  1986  1986-06-12  18:00           70          2  Group D
#
#                  Group A             Group B              Group C  \
# 33  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 33  [Northern Ireland, 1, -3, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                 top_four                     last_two  \
# 33  [Belgium, Poland, Bulgaria, Uruguay]  [Hungary, Northern Ireland]
#
#    tied_teams  change_flag  change_count
# 33         []            0            11
# Index 30 | top_four_teams: ['Belgium', 'Poland', 'Bulgaria', 'Uruguay'] (type: <class 'list'>)
# ⚠️ Third-place team Northern Ireland NOT in top_four_teams ['Belgium', 'Poland', 'Bulgaria', 'Uruguay']
#
# ✅ Match found for index 31:
#     year        date   time  goal_minute  half_time    stage  \
# 34  1986  1986-06-12  18:00           87          2  Group D
#
#                  Group A             Group B              Group C  \
# 34  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 34  [Northern Ireland, 1, -4, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                 top_four                     last_two  \
# 34  [Belgium, Poland, Bulgaria, Uruguay]  [Hungary, Northern Ireland]
#
#    tied_teams  change_flag  change_count
# 34         []            0            11
# Index 31 | top_four_teams: ['Belgium', 'Poland', 'Bulgaria', 'Uruguay'] (type: <class 'list'>)
# ⚠️ Third-place team Northern Ireland NOT in top_four_teams ['Belgium', 'Poland', 'Bulgaria', 'Uruguay']
#
# ✅ Match found for index 32:
#     year        date   time  goal_minute  half_time    stage  \
# 28  1986  1986-06-12  18:00            0          1  Group D
#
#                  Group A             Group B              Group C  \
# 28  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 28  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                          top_four            last_two  \
# 28  [Belgium, Poland, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 28         []            0             9
# Index 32 | top_four_teams: ['Belgium', 'Poland', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 33:
#     year        date   time  goal_minute  half_time    stage  \
# 35  1986  1986-06-13  18:00            0          1  Group E
#
#                  Group A             Group B              Group C  \
# 35  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 35  [Northern Ireland, 1, -4, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                 top_four                     last_two  \
# 35  [Belgium, Poland, Bulgaria, Uruguay]  [Hungary, Northern Ireland]
#
#    tied_teams  change_flag  change_count
# 35         []            0            11
# Index 33 | top_four_teams: ['Belgium', 'Poland', 'Bulgaria', 'Uruguay'] (type: <class 'list'>)
#
# ✅ Match found for index 34:
#     year        date   time  goal_minute  half_time    stage  \
# 35  1986  1986-06-13  18:00            0          1  Group E
#
#                  Group A             Group B              Group C  \
# 35  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 35  [Northern Ireland, 1, -4, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                 top_four                     last_two  \
# 35  [Belgium, Poland, Bulgaria, Uruguay]  [Hungary, Northern Ireland]
#
#    tied_teams  change_flag  change_count
# 35         []            0            11
# Index 34 | top_four_teams: ['Belgium', 'Poland', 'Bulgaria', 'Uruguay'] (type: <class 'list'>)
#
# ✅ Match found for index 35:
#     year        date   time  goal_minute  half_time    stage  \
# 36  1986  1986-06-13  18:00           43          1  Group E
#
#                  Group A             Group B              Group C  \
# 36  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 36  [Northern Ireland, 1, -4, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                 top_four                     last_two  \
# 36  [Belgium, Poland, Bulgaria, Uruguay]  [Hungary, Northern Ireland]
#
#    tied_teams  change_flag  change_count
# 36         []            0            11
# Index 35 | top_four_teams: ['Belgium', 'Poland', 'Bulgaria', 'Uruguay'] (type: <class 'list'>)
#
# ✅ Match found for index 36:
#     year        date   time  goal_minute  half_time    stage  \
# 37  1986  1986-06-13  18:00           62          2  Group E
#
#                  Group A             Group B              Group C  \
# 37  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 37  [Northern Ireland, 1, -4, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                 top_four                     last_two  \
# 37  [Belgium, Poland, Bulgaria, Uruguay]  [Hungary, Northern Ireland]
#
#    tied_teams  change_flag  change_count
# 37         []            0            11
# Index 36 | top_four_teams: ['Belgium', 'Poland', 'Bulgaria', 'Uruguay'] (type: <class 'list'>)
#
# ✅ Match found for index 37:
#     year        date   time  goal_minute  half_time    stage  \
# 35  1986  1986-06-13  18:00            0          1  Group E
#
#                  Group A             Group B              Group C  \
# 35  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 35  [Northern Ireland, 1, -4, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                 top_four                     last_two  \
# 35  [Belgium, Poland, Bulgaria, Uruguay]  [Hungary, Northern Ireland]
#
#    tied_teams  change_flag  change_count
# 35         []            0            11
# Index 37 | top_four_teams: ['Belgium', 'Poland', 'Bulgaria', 'Uruguay'] (type: <class 'list'>)
#
# ✅ Match found for index 38:
#     year        date   time  goal_minute  half_time    stage  \
# 20  1986  1986-06-11  22:00            0          1  Group F
#
#                  Group A             Group B              Group C  \
# 20  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 20  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                           top_four            last_two  \
# 20  [Belgium, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 20         []            0             6
# Index 38 | top_four_teams: ['Belgium', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 39:
#     year        date   time  goal_minute  half_time    stage  \
# 21  1986  1986-06-11  22:00            8          1  Group F
#
#                  Group A             Group B              Group C  \
# 21  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E              Group F  \
# 21  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Portugal, 3, 0, 1]
#
#                                            top_four            last_two  \
# 21  [Belgium, Portugal, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 21         []            1             7
# Index 39 | top_four_teams: ['Belgium', 'Portugal', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 40:
#     year        date   time  goal_minute  half_time    stage  \
# 22  1986  1986-06-11  22:00           14          1  Group F
#
#                  Group A             Group B              Group C  \
# 22  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 22  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                           top_four            last_two  \
# 22  [Belgium, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 22         []            1             8
# Index 40 | top_four_teams: ['Belgium', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 41:
#     year        date   time  goal_minute  half_time    stage  \
# 23  1986  1986-06-11  22:00           19          1  Group F
#
#                  Group A             Group B              Group C  \
# 23  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 23  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -1, 1]
#
#                                          top_four            last_two  \
# 23  [Belgium, Poland, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 23         []            1             9
# Index 41 | top_four_teams: ['Belgium', 'Poland', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 42:
#     year        date   time  goal_minute  half_time    stage  \
# 24  1986  1986-06-11  22:00           27          1  Group F
#
#                  Group A             Group B              Group C  \
# 24  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 24  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -1, 1]
#
#                                          top_four            last_two  \
# 24  [Belgium, Poland, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 24         []            0             9
# Index 42 | top_four_teams: ['Belgium', 'Poland', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 43:
#     year        date   time  goal_minute  half_time    stage  \
# 25  1986  1986-06-11  22:00           36          1  Group F
#
#                  Group A             Group B              Group C  \
# 25  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 25  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                          top_four            last_two  \
# 25  [Belgium, Poland, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 25         []            0             9
# Index 43 | top_four_teams: ['Belgium', 'Poland', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 44:
#     year        date   time  goal_minute  half_time    stage  \
# 26  1986  1986-06-11  22:00           62          2  Group F
#
#                  Group A             Group B              Group C  \
# 26  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 26  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                          top_four            last_two  \
# 26  [Belgium, Poland, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 26         []            0             9
# Index 44 | top_four_teams: ['Belgium', 'Poland', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 45:
#     year        date   time  goal_minute  half_time    stage  \
# 27  1986  1986-06-11  22:00           80          2  Group F
#
#                  Group A             Group B              Group C  \
# 27  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 27  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Poland, 3, -2, 1]
#
#                                          top_four            last_two  \
# 27  [Belgium, Poland, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 27         []            0             9
# Index 45 | top_four_teams: ['Belgium', 'Poland', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 46:
#     year        date   time  goal_minute  half_time    stage  \
# 20  1986  1986-06-11  22:00            0          1  Group F
#
#                  Group A             Group B              Group C  \
# 20  [Bulgaria, 2, -2, 2]  [Belgium, 3, 0, 5]  [Hungary, 2, -7, 2]
#
#                          Group D              Group E             Group F  \
# 20  [Northern Ireland, 2, -1, 2]  [Uruguay, 2, -5, 2]  [Morocco, 3, 0, 0]
#
#                                           top_four            last_two  \
# 20  [Belgium, Morocco, Northern Ireland, Bulgaria]  [Uruguay, Hungary]
#
#    tied_teams  change_flag  change_count
# 20         []            0             6
# Index 46 | top_four_teams: ['Belgium', 'Morocco', 'Northern Ireland', 'Bulgaria'] (type: <class 'list'>)
#
# ✅ Match found for index 47:
#     year        date   time  goal_minute  half_time    stage  \
# 53  1990  1990-06-19  21:00            9          1  Group A
#
#                 Group A               Group B                Group C  \
# 53  [Austria, 1, -2, 0]  [Argentina, 3, 1, 3]  [Costa Rica, 3, 0, 1]
#
#                 Group D              Group E             Group F  \
# 53  [Colombia, 3, 1, 3]  [Uruguay, 2, -2, 1]  [Ireland, 3, 0, 1]
#
#                                       top_four            last_two  \
# 53  [Argentina, Colombia, Costa Rica, Ireland]  [Uruguay, Austria]
#
#                                     tied_teams  change_flag  change_count
# 53  [Argentina, Colombia, Costa Rica, Ireland]            0             4
# Index 47 | top_four_teams: ['Argentina', 'Colombia', 'Costa Rica', 'Ireland'] (type: <class 'list'>)
# ⚠️ Third-place team Austria NOT in top_four_teams ['Argentina', 'Colombia', 'Costa Rica', 'Ireland']
#
# ✅ Match found for index 48:
#     year        date   time  goal_minute  half_time    stage  \
# 54  1990  1990-06-19  21:00           49          2  Group A
#
#                 Group A               Group B                Group C  \
# 54  [Austria, 2, -1, 1]  [Argentina, 3, 1, 3]  [Costa Rica, 3, 0, 1]
#
#                 Group D              Group E             Group F  \
# 54  [Colombia, 3, 1, 3]  [Uruguay, 2, -2, 1]  [Ireland, 3, 0, 1]
#
#                                       top_four            last_two  \
# 54  [Argentina, Colombia, Costa Rica, Ireland]  [Austria, Uruguay]
#
#                                     tied_teams  change_flag  change_count
# 54  [Argentina, Colombia, Costa Rica, Ireland]            0             4
# Index 48 | top_four_teams: ['Argentina', 'Colombia', 'Costa Rica', 'Ireland'] (type: <class 'list'>)
# ⚠️ Third-place team Austria NOT in top_four_teams ['Argentina', 'Colombia', 'Costa Rica', 'Ireland']
#
# ✅ Match found for index 49:
#     year        date   time  goal_minute  half_time    stage  \
# 55  1990  1990-06-19  21:00           63          2  Group A
#
#                Group A               Group B                Group C  \
# 55  [Austria, 2, 0, 2]  [Argentina, 3, 1, 3]  [Costa Rica, 3, 0, 1]
#
#                 Group D              Group E             Group F  \
# 55  [Colombia, 3, 1, 3]  [Uruguay, 2, -2, 1]  [Ireland, 3, 0, 1]
#
#                                       top_four            last_two  \
# 55  [Argentina, Colombia, Costa Rica, Ireland]  [Austria, Uruguay]
#
#                                     tied_teams  change_flag  change_count
# 55  [Argentina, Colombia, Costa Rica, Ireland]            0             4
# Index 49 | top_four_teams: ['Argentina', 'Colombia', 'Costa Rica', 'Ireland'] (type: <class 'list'>)
# ⚠️ Third-place team Austria NOT in top_four_teams ['Argentina', 'Colombia', 'Costa Rica', 'Ireland']
#
# ✅ Match found for index 50:
#     year        date   time  goal_minute  half_time    stage  \
# 56  1990  1990-06-19  21:00           78          2  Group A
#
#                Group A               Group B                Group C  \
# 56  [Austria, 2, 0, 2]  [Argentina, 3, 1, 3]  [Costa Rica, 3, 0, 1]
#
#                 Group D              Group E             Group F  \
# 56  [Colombia, 3, 1, 3]  [Uruguay, 2, -2, 1]  [Ireland, 3, 0, 1]
#
#                                       top_four            last_two  \
# 56  [Argentina, Colombia, Costa Rica, Ireland]  [Austria, Uruguay]
#
#                                     tied_teams  change_flag  change_count
# 56  [Argentina, Colombia, Costa Rica, Ireland]            0             4
# Index 50 | top_four_teams: ['Argentina', 'Colombia', 'Costa Rica', 'Ireland'] (type: <class 'list'>)
# ⚠️ Third-place team Austria NOT in top_four_teams ['Argentina', 'Colombia', 'Costa Rica', 'Ireland']
#
# ✅ Match found for index 51:
#     year        date   time  goal_minute  half_time    stage  \
# 57  1990  1990-06-19  21:00           83          2  Group A
#
#                 Group A               Group B                Group C  \
# 57  [Austria, 2, -1, 2]  [Argentina, 3, 1, 3]  [Costa Rica, 3, 0, 1]
#
#                 Group D              Group E             Group F  \
# 57  [Colombia, 3, 1, 3]  [Uruguay, 2, -2, 1]  [Ireland, 3, 0, 1]
#
#                                       top_four            last_two  \
# 57  [Argentina, Colombia, Costa Rica, Ireland]  [Austria, Uruguay]
#
#                                     tied_teams  change_flag  change_count
# 57  [Argentina, Colombia, Costa Rica, Ireland]            0             4
# Index 51 | top_four_teams: ['Argentina', 'Colombia', 'Costa Rica', 'Ireland'] (type: <class 'list'>)
# ⚠️ Third-place team Austria NOT in top_four_teams ['Argentina', 'Colombia', 'Costa Rica', 'Ireland']
#
# ✅ Match found for index 52:
#     year        date   time  goal_minute  half_time    stage  \
# 52  1990  1990-06-19  21:00            0          1  Group A
#
#                 Group A               Group B                Group C  \
# 52  [Austria, 1, -2, 0]  [Argentina, 3, 1, 3]  [Costa Rica, 3, 0, 1]
#
#                 Group D              Group E             Group F  \
# 52  [Colombia, 3, 1, 3]  [Uruguay, 2, -2, 1]  [Ireland, 3, 0, 1]
#
#                                       top_four            last_two  \
# 52  [Argentina, Colombia, Costa Rica, Ireland]  [Uruguay, Austria]
#
#                                     tied_teams  change_flag  change_count
# 52  [Argentina, Colombia, Costa Rica, Ireland]            0             4
# Index 52 | top_four_teams: ['Argentina', 'Colombia', 'Costa Rica', 'Ireland'] (type: <class 'list'>)
# ⚠️ Third-place team Austria NOT in top_four_teams ['Argentina', 'Colombia', 'Costa Rica', 'Ireland']
#
# ✅ Match found for index 53:
#     year        date   time  goal_minute  half_time    stage  \
# 39  1990  1990-06-18  21:00           20          1  Group B
#
#                 Group A               Group B                Group C  \
# 39  [Austria, 1, -2, 0]  [Argentina, 3, 1, 2]  [Costa Rica, 3, 0, 1]
#
#                    Group D              Group E             Group F  \
# 39  [Yugoslavia, 3, -2, 2]  [Uruguay, 2, -2, 1]  [Ireland, 3, 0, 1]
#
#                                         top_four            last_two  \
# 39  [Argentina, Costa Rica, Ireland, Yugoslavia]  [Uruguay, Austria]
#
#                tied_teams  change_flag  change_count
# 39  [Costa Rica, Ireland]            0             0
# Index 53 | top_four_teams: ['Argentina', 'Costa Rica', 'Ireland', 'Yugoslavia'] (type: <class 'list'>)
#
# ✅ Match found for index 54:
#     year        date   time  goal_minute  half_time    stage  \
# 40  1990  1990-06-18  21:00           29          1  Group B
#
#                 Group A               Group B                Group C  \
# 40  [Austria, 1, -2, 0]  [Argentina, 3, 1, 2]  [Costa Rica, 3, 0, 1]
#
#                    Group D              Group E             Group F  \
# 40  [Yugoslavia, 3, -2, 2]  [Uruguay, 2, -2, 1]  [Ireland, 3, 0, 1]
#
#                                         top_four            last_two  \
# 40  [Argentina, Costa Rica, Ireland, Yugoslavia]  [Uruguay, Austria]
#
#                tied_teams  change_flag  change_count
# 40  [Costa Rica, Ireland]            0             0
# Index 54 | top_four_teams: ['Argentina', 'Costa Rica', 'Ireland', 'Yugoslavia'] (type: <class 'list'>)
#
# ✅ Match found for index 55:
#     year        date   time  goal_minute  half_time    stage  \
# 41  1990  1990-06-18  21:00           52          2  Group B
#
#                 Group A               Group B                Group C  \
# 41  [Austria, 1, -2, 0]  [Argentina, 3, 1, 2]  [Costa Rica, 3, 0, 1]
#
#                    Group D              Group E             Group F  \
# 41  [Yugoslavia, 3, -2, 2]  [Uruguay, 2, -2, 1]  [Ireland, 3, 0, 1]
#
#                                         top_four            last_two  \
# 41  [Argentina, Costa Rica, Ireland, Yugoslavia]  [Uruguay, Austria]
#
#                tied_teams  change_flag  change_count
# 41  [Costa Rica, Ireland]            0             0
# Index 55 | top_four_teams: ['Argentina', 'Costa Rica', 'Ireland', 'Yugoslavia'] (type: <class 'list'>)
#
# ✅ Match found for index 56:
#     year        date   time  goal_minute  half_time    stage  \
# 42  1990  1990-06-18  21:00           62          2  Group B
#
#                 Group A             Group B                Group C  \
# 42  [Austria, 1, -2, 0]  [Romania, 2, 0, 3]  [Costa Rica, 3, 0, 1]
#
#                    Group D              Group E             Group F  \
# 42  [Yugoslavia, 3, -2, 2]  [Uruguay, 2, -2, 1]  [Ireland, 3, 0, 1]
#
#                                       top_four            last_two  \
# 42  [Costa Rica, Ireland, Yugoslavia, Romania]  [Uruguay, Austria]
#
#                tied_teams  change_flag  change_count
# 42  [Costa Rica, Ireland]            1             1
# Index 56 | top_four_teams: ['Costa Rica', 'Ireland', 'Yugoslavia', 'Romania'] (type: <class 'list'>)
#
# ✅ Match found for index 57:
#     year        date   time  goal_minute  half_time    stage  \
# 43  1990  1990-06-18  21:00           63          2  Group B
#
#                 Group A                  Group B                Group C  \
# 43  [Austria, 1, -2, 0]  [Soviet Union, 2, 0, 4]  [Costa Rica, 3, 0, 1]
#
#                    Group D              Group E             Group F  \
# 43  [Yugoslavia, 3, -2, 2]  [Uruguay, 2, -2, 1]  [Ireland, 3, 0, 1]
#
#                                            top_four            last_two  \
# 43  [Costa Rica, Ireland, Yugoslavia, Soviet Union]  [Uruguay, Austria]
#
# ...
# 84  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 1]  [Netherlands, 4, 0, 2]
#
#                                          top_four                 last_two  \
# 84  [Bulgaria, United States, Netherlands, Italy]  [South Korea, Cameroon]
#
#    tied_teams  change_flag  change_count
# 84         []            0             1
# Index 105 | top_four_teams: ['Bulgaria', 'United States', 'Netherlands', 'Italy'] (type: <class 'list'>)
# ⚠️ Third-place team South Korea NOT in top_four_teams ['Bulgaria', 'United States', 'Netherlands', 'Italy']
#
# ✅ Match found for index 106:
#     year        date   time  goal_minute  half_time    stage  \
# 85  1994  1994-06-27  20:00           70          2  Group C
#
#                      Group A               Group B                  Group C  \
# 85  [United States, 4, 0, 3]  [Cameroon, 2, -3, 2]  [South Korea, 2, -1, 4]
#
#                 Group D           Group E                 Group F  \
# 85  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 1]  [Netherlands, 4, 0, 2]
#
#                                          top_four                 last_two  \
# 85  [Bulgaria, United States, Netherlands, Italy]  [South Korea, Cameroon]
#
#    tied_teams  change_flag  change_count
# 85         []            0             1
# Index 106 | top_four_teams: ['Bulgaria', 'United States', 'Netherlands', 'Italy'] (type: <class 'list'>)
# ⚠️ Third-place team South Korea NOT in top_four_teams ['Bulgaria', 'United States', 'Netherlands', 'Italy']
#
# ✅ Match found for index 107:
#     year        date   time  goal_minute  half_time    stage  \
# 76  1994  1994-06-27  20:00            0          1  Group C
#
#                      Group A               Group B                 Group C  \
# 76  [United States, 4, 0, 3]  [Cameroon, 2, -3, 2]  [South Korea, 3, 0, 2]
#
#                 Group D           Group E                 Group F  \
# 76  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 1]  [Netherlands, 4, 0, 2]
#
#                                          top_four                 last_two  \
# 76  [Bulgaria, United States, Netherlands, Italy]  [South Korea, Cameroon]
#
#    tied_teams  change_flag  change_count
# 76         []            0             1
# Index 107 | top_four_teams: ['Bulgaria', 'United States', 'Netherlands', 'Italy'] (type: <class 'list'>)
# ⚠️ Third-place team South Korea NOT in top_four_teams ['Bulgaria', 'United States', 'Netherlands', 'Italy']
#
# ✅ Match found for index 108:
#      year        date   time  goal_minute  half_time    stage  \
# 104  1994  1994-06-30  23:30            0          1  Group D
#
#                       Group A            Group B                  Group C  \
# 104  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                  Group D           Group E             Group F  \
# 104  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 2]  [Belgium, 6, 1, 2]
#
#                                       top_four               last_two  \
# 104  [Belgium, Bulgaria, United States, Italy]  [Russia, South Korea]
#
#     tied_teams  change_flag  change_count
# 104         []            0             6
# Index 108 | top_four_teams: ['Belgium', 'Bulgaria', 'United States', 'Italy'] (type: <class 'list'>)
#
# ✅ Match found for index 109:
#      year        date   time  goal_minute  half_time    stage  \
# 104  1994  1994-06-30  23:30            0          1  Group D
#
#                       Group A            Group B                  Group C  \
# 104  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                  Group D           Group E             Group F  \
# 104  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 2]  [Belgium, 6, 1, 2]
#
#                                       top_four               last_two  \
# 104  [Belgium, Bulgaria, United States, Italy]  [Russia, South Korea]
#
#     tied_teams  change_flag  change_count
# 104         []            0             6
# Index 109 | top_four_teams: ['Belgium', 'Bulgaria', 'United States', 'Italy'] (type: <class 'list'>)
#
# ✅ Match found for index 110:
#      year        date   time  goal_minute  half_time    stage  \
# 105  1994  1994-06-30  23:30           47          1  Group D
#
#                       Group A            Group B                  Group C  \
# 105  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                  Group D           Group E             Group F  \
# 105  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 2]  [Belgium, 6, 1, 2]
#
#                                       top_four               last_two  \
# 105  [Belgium, Bulgaria, United States, Italy]  [Russia, South Korea]
#
#     tied_teams  change_flag  change_count
# 105         []            0             6
# Index 110 | top_four_teams: ['Belgium', 'Bulgaria', 'United States', 'Italy'] (type: <class 'list'>)
#
# ✅ Match found for index 111:
#      year        date   time  goal_minute  half_time    stage  \
# 106  1994  1994-06-30  23:30           61          2  Group D
#
#                       Group A            Group B                  Group C  \
# 106  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                  Group D           Group E             Group F  \
# 106  [Bulgaria, 6, 2, 5]  [Italy, 4, 0, 2]  [Belgium, 6, 1, 2]
#
#                                       top_four               last_two  \
# 106  [Bulgaria, Belgium, United States, Italy]  [Russia, South Korea]
#
#     tied_teams  change_flag  change_count
# 106         []            0             6
# Index 111 | top_four_teams: ['Bulgaria', 'Belgium', 'United States', 'Italy'] (type: <class 'list'>)
#
# ✅ Match found for index 112:
#      year        date   time  goal_minute  half_time    stage  \
# 107  1994  1994-06-30  23:30           93          2  Group D
#
#                       Group A            Group B                  Group C  \
# 107  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                 Group D           Group E             Group F  \
# 107  [Nigeria, 6, 3, 5]  [Italy, 4, 0, 2]  [Belgium, 6, 1, 2]
#
#                                      top_four               last_two  \
# 107  [Nigeria, Belgium, United States, Italy]  [Russia, South Korea]
#
#     tied_teams  change_flag  change_count
# 107         []            1             7
# Index 112 | top_four_teams: ['Nigeria', 'Belgium', 'United States', 'Italy'] (type: <class 'list'>)
#
# ✅ Match found for index 113:
#      year        date   time  goal_minute  half_time    stage  \
# 108  1994  1994-06-30  23:30           95          2  Group D
#
#                       Group A            Group B                  Group C  \
# 108  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                   Group D           Group E             Group F  \
# 108  [Argentina, 6, 3, 6]  [Italy, 4, 0, 2]  [Belgium, 6, 1, 2]
#
#                                        top_four               last_two  \
# 108  [Argentina, Belgium, United States, Italy]  [Russia, South Korea]
#
#     tied_teams  change_flag  change_count
# 108         []            1             8
# Index 113 | top_four_teams: ['Argentina', 'Belgium', 'United States', 'Italy'] (type: <class 'list'>)
#
# ✅ Match found for index 114:
#      year        date   time  goal_minute  half_time    stage  \
# 104  1994  1994-06-30  23:30            0          1  Group D
#
#                       Group A            Group B                  Group C  \
# 104  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                  Group D           Group E             Group F  \
# 104  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 2]  [Belgium, 6, 1, 2]
#
#                                       top_four               last_two  \
# 104  [Belgium, Bulgaria, United States, Italy]  [Russia, South Korea]
#
#     tied_teams  change_flag  change_count
# 104         []            0             6
# Index 114 | top_four_teams: ['Belgium', 'Bulgaria', 'United States', 'Italy'] (type: <class 'list'>)
#
# ✅ Match found for index 115:
#     year        date   time  goal_minute  half_time    stage  \
# 86  1994  1994-06-28  16:30            0          1  Group E
#
#                      Group A               Group B                  Group C  \
# 86  [United States, 4, 0, 3]  [Cameroon, 2, -3, 2]  [South Korea, 2, -1, 4]
#
#                 Group D           Group E                 Group F  \
# 86  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 1]  [Netherlands, 4, 0, 2]
#
#                                          top_four                 last_two  \
# 86  [Bulgaria, United States, Netherlands, Italy]  [South Korea, Cameroon]
#
#    tied_teams  change_flag  change_count
# 86         []            0             1
# Index 115 | top_four_teams: ['Bulgaria', 'United States', 'Netherlands', 'Italy'] (type: <class 'list'>)
#
# ✅ Match found for index 116:
#     year        date   time  goal_minute  half_time    stage  \
# 87  1994  1994-06-28  16:30           48          2  Group E
#
#                      Group A               Group B                  Group C  \
# 87  [United States, 4, 0, 3]  [Cameroon, 2, -3, 2]  [South Korea, 2, -1, 4]
#
#                 Group D            Group E                 Group F  \
# 87  [Bulgaria, 4, 1, 4]  [Norway, 4, 0, 1]  [Netherlands, 4, 0, 2]
#
#                                           top_four                 last_two  \
# 87  [Bulgaria, United States, Netherlands, Norway]  [South Korea, Cameroon]
#
#    tied_teams  change_flag  change_count
# 87         []            1             2
# Index 116 | top_four_teams: ['Bulgaria', 'United States', 'Netherlands', 'Norway'] (type: <class 'list'>)
#
# ✅ Match found for index 117:
#     year        date   time  goal_minute  half_time    stage  \
# 88  1994  1994-06-28  16:30           57          2  Group E
#
#                      Group A               Group B                  Group C  \
# 88  [United States, 4, 0, 3]  [Cameroon, 2, -3, 2]  [South Korea, 2, -1, 4]
#
#                 Group D           Group E                 Group F  \
# 88  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 2]  [Netherlands, 4, 0, 2]
#
#                                          top_four                 last_two  \
# 88  [Bulgaria, United States, Italy, Netherlands]  [South Korea, Cameroon]
#
#               tied_teams  change_flag  change_count
# 88  [Italy, Netherlands]            1             3
# Index 117 | top_four_teams: ['Bulgaria', 'United States', 'Italy', 'Netherlands'] (type: <class 'list'>)
#
# ✅ Match found for index 118:
#     year        date   time  goal_minute  half_time    stage  \
# 86  1994  1994-06-28  16:30            0          1  Group E
#
#                      Group A               Group B                  Group C  \
# 86  [United States, 4, 0, 3]  [Cameroon, 2, -3, 2]  [South Korea, 2, -1, 4]
#
#                 Group D           Group E                 Group F  \
# 86  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 1]  [Netherlands, 4, 0, 2]
#
#                                          top_four                 last_two  \
# 86  [Bulgaria, United States, Netherlands, Italy]  [South Korea, Cameroon]
#
#    tied_teams  change_flag  change_count
# 86         []            0             1
# Index 118 | top_four_teams: ['Bulgaria', 'United States', 'Netherlands', 'Italy'] (type: <class 'list'>)
#
# ✅ Match found for index 119:
#     year        date   time  goal_minute  half_time    stage  \
# 99  1994  1994-06-29  16:30            0          1  Group F
#
#                      Group A            Group B                  Group C  \
# 99  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                 Group D           Group E                 Group F  \
# 99  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 2]  [Netherlands, 4, 0, 2]
#
#                                          top_four               last_two  \
# 99  [Bulgaria, United States, Italy, Netherlands]  [Russia, South Korea]
#
#               tied_teams  change_flag  change_count
# 99  [Italy, Netherlands]            0             3
# Index 119 | top_four_teams: ['Bulgaria', 'United States', 'Italy', 'Netherlands'] (type: <class 'list'>)
#
# ✅ Match found for index 120:
#      year        date   time  goal_minute  half_time    stage  \
# 100  1994  1994-06-29  16:30            5          1  Group F
#
#                       Group A            Group B                  Group C  \
# 100  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                  Group D           Group E                 Group F  \
# 100  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 2]  [Netherlands, 4, 0, 2]
#
#                                           top_four               last_two  \
# 100  [Bulgaria, United States, Italy, Netherlands]  [Russia, South Korea]
#
#                tied_teams  change_flag  change_count
# 100  [Italy, Netherlands]            0             3
# Index 120 | top_four_teams: ['Bulgaria', 'United States', 'Italy', 'Netherlands'] (type: <class 'list'>)
#
# ✅ Match found for index 121:
#      year        date   time  goal_minute  half_time    stage  \
# 101  1994  1994-06-29  16:30           43          1  Group F
#
#                       Group A            Group B                  Group C  \
# 101  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                  Group D           Group E             Group F  \
# 101  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 2]  [Belgium, 6, 1, 2]
#
#                                       top_four               last_two  \
# 101  [Belgium, Bulgaria, United States, Italy]  [Russia, South Korea]
#
#     tied_teams  change_flag  change_count
# 101         []            1             4
# Index 121 | top_four_teams: ['Belgium', 'Bulgaria', 'United States', 'Italy'] (type: <class 'list'>)
#
# ✅ Match found for index 122:
#      year        date   time  goal_minute  half_time    stage  \
# 102  1994  1994-06-29  16:30           47          2  Group F
#
#                       Group A            Group B                  Group C  \
# 102  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                  Group D           Group E                 Group F  \
# 102  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 2]  [Netherlands, 4, 0, 3]
#
#                                           top_four               last_two  \
# 102  [Bulgaria, United States, Netherlands, Italy]  [Russia, South Korea]
#
#                        tied_teams  change_flag  change_count
# 102  [Netherlands, United States]            1             5
# Index 122 | top_four_teams: ['Bulgaria', 'United States', 'Netherlands', 'Italy'] (type: <class 'list'>)
#
# ✅ Match found for index 123:
#      year        date   time  goal_minute  half_time    stage  \
# 103  1994  1994-06-29  16:30           77          2  Group F
#
#                       Group A            Group B                  Group C  \
# 103  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                  Group D           Group E             Group F  \
# 103  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 2]  [Belgium, 6, 1, 2]
#
#                                       top_four               last_two  \
# 103  [Belgium, Bulgaria, United States, Italy]  [Russia, South Korea]
#
#     tied_teams  change_flag  change_count
# 103         []            1             6
# Index 123 | top_four_teams: ['Belgium', 'Bulgaria', 'United States', 'Italy'] (type: <class 'list'>)
#
# ✅ Match found for index 124:
#     year        date   time  goal_minute  half_time    stage  \
# 99  1994  1994-06-29  16:30            0          1  Group F
#
#                      Group A            Group B                  Group C  \
# 99  [United States, 4, 0, 3]  [Russia, 3, 1, 7]  [South Korea, 2, -1, 4]
#
#                 Group D           Group E                 Group F  \
# 99  [Bulgaria, 4, 1, 4]  [Italy, 4, 0, 2]  [Netherlands, 4, 0, 2]
#
#                                          top_four               last_two  \
# 99  [Bulgaria, United States, Italy, Netherlands]  [Russia, South Korea]
#
#               tied_teams  change_flag  change_count
# 99  [Italy, Netherlands]            0             3
# Index 124 | top_four_teams: ['Bulgaria', 'United States', 'Italy', 'Netherlands'] (type: <class 'list'>)

# %% [markdown]
# ### variables to track the composition of the teams qualifying

# %%
# Sort the dataset by 'year', 'date', and 'time'
final_composition_changes_df = final_composition_changes_df.sort_values(by=['year', 'date', 'time', 'half_time', 'goal_minute', 'stage'], na_position='first').reset_index(drop=True)

# %%
# Ensure goal_minute is numeric for sorting
final_composition_changes_df['goal_minute'] = pd.to_numeric(final_composition_changes_df['goal_minute'], errors='coerce')

# Sort by year, stage, and goal_minute to process in correct order
final_composition_changes_df = final_composition_changes_df.sort_values(by=['year', 'stage', 'goal_minute']).reset_index(drop=True)

# Initialize qual_changed and qual_count columns
final_composition_changes_df['qual_changed'] = 0
final_composition_changes_df['qual_count'] = 0

# Track changes per stage
qual_count_tracker = {}

# Loop through each year and stage to check for changes
for (year, stage), group in final_composition_changes_df.groupby(['year', 'stage']):
    previous_qualified = None
    qual_count = 0

    for index, row in group.iterrows():
        # Extract current qualified teams
        current_qualified = sorted(row['qualified_teams'])  # Sort to ignore order changes

        # Check if qualified_teams has changed from the previous row
        if previous_qualified is not None and current_qualified != previous_qualified:
            final_composition_changes_df.at[index, 'qual_changed'] = 1
            qual_count += 1

        # Update tracking
        previous_qualified = current_qualified
        final_composition_changes_df.at[index, 'qual_count'] = qual_count

# %%
final_composition_changes_df = integrate_elo_probabilities(final_composition_changes_df, elo_wc)

# %%
# Define pt_diff and gl_diff based on third_qualify condition
final_composition_changes_df['pts_diff'] = final_composition_changes_df.apply(
    lambda row: row['3rd_points'] - row['2nd_points']
    if row['third_qualify'] == 0 else row['4th_points'] - row['3rd_points'], axis=1
)

final_composition_changes_df['gls_diff'] = final_composition_changes_df.apply(
    lambda row: row['3rd_goals_diff'] - row['2nd_goals_diff']
    if row['third_qualify'] == 0 else row['4th_goals_diff'] - row['3rd_goals_diff'], axis=1
)

# %%
# Drop unnecessary columns
final_composition_changes_df = final_composition_changes_df.drop(columns=['points_diff', 'goals_diff', 'tiebreak_result'], errors='ignore')

# %%
# Define the desired column order
column_order = [
    'year', 'stage', 'date', 'time', 'goal_minute', 'half_time', 'home_team', 
    'away_team', 'scorer_team', 'new_top_teams', 
    '1st', '1st_points', '1st_goals_diff', '1st_goals_scored', '1st_last_game_points', '1st_last_game_goals_diff',
    '2nd', '2nd_points', '2nd_goals_diff', '2nd_goals_scored','2nd_last_game_points', '2nd_last_game_goals_diff',
    '3rd', '3rd_points', '3rd_goals_diff', '3rd_goals_scored','3rd_last_game_points', '3rd_last_game_goals_diff',
    '4th', '4th_points', '4th_goals_diff', '4th_goals_scored','4th_last_game_points', '4th_last_game_goals_diff',
    'third_qualify', 'qualified_teams', 'qual_changed', 'qual_count', 
    'pts_diff', 'gls_diff', 'elo_home', 'elo_away'
]

# Reorder the columns
final_composition_changes_df = final_composition_changes_df[column_order]

# %%
# Remove rows where goal_minute == 0 and both home_team and away_team have values
filtered_df = final_composition_changes_df[
    ~((final_composition_changes_df["goal_minute"] == 0) & 
      final_composition_changes_df["home_team"].notna() & 
      final_composition_changes_df["away_team"].notna())
]

# Reset index after filtering
filtered_df = filtered_df.reset_index(drop=True)

# Update the original DataFrame with the filtered version
final_composition_changes_df = filtered_df

# %% [markdown]
# # suspense

# %% [markdown]
# ## h2h variable

# %%
final_composition_changes_df = (
    final_composition_changes_df
    .groupby(["year", "stage"], group_keys=False)
    .apply(assign_h2h_per_row)
)

# %%
final_composition_changes_df = assign_lagging_won(final_composition_changes_df, goals_df)

# %%
# # Apply the function to compute suspense for each row
final_composition_changes_df['suspense'] = final_composition_changes_df.apply(calculate_suspense, axis=1)

# %%
final_composition_changes_df.loc[
    (final_composition_changes_df["year"] == 2002) &
    (final_composition_changes_df["stage"] == "Group G") &
    (final_composition_changes_df["goal_minute"] == 48)
]
# Out:
#    year    stage        date   time  goal_minute  half_time home_team  \
# 2  2002  Group G  2002-06-13  11:30           48        2.0   Ecuador
#
#   away_team scorer_team    new_top_teams  ... qual_count  pts_diff  gls_diff  \
# 2   Croatia     Ecuador  [Mexico, Italy]  ...          2         0        -1
#
#    elo_home  elo_away  h2h lagging_team  leading_team  lagging_won  suspense
# 2    1727.0    1882.0    0      Croatia         Italy          1.0         1
#
# [1 rows x 47 columns]

# %%
final_composition_changes_df = update_suspense(final_composition_changes_df, debug=True)
# Out:
# ==========================================================================================
# Year 1990 | Stage Group F | Minute 58
# Lagging: Egypt | Leading: England | h2h=1
# BASE: pts_diff=-2 | gd_diff=-2 | gs_diff=-1
#
# Scenario S:
#   pts_diff=0.0 | gd_diff=0 | gs_diff=0 | full_tie_S=True
#
# Scenario C:
#   pts_diff=0.0 | gd_diff=0 | gs_diff=0 | full_tie_C=True
#
# => h2h_suspense = True
#
# ==========================================================================================
# Year 2002 | Stage Group A | Minute 0
# Lagging: Uruguay | Leading: Senegal | h2h=1
# BASE: pts_diff=-3 | gd_diff=-2 | gs_diff=-1
#
# Scenario S:
#   pts_diff=0.0 | gd_diff=0 | gs_diff=0 | full_tie_S=True
#
# Scenario C:
#   pts_diff=0.0 | gd_diff=0 | gs_diff=0 | full_tie_C=True
#
# => h2h_suspense = True
#
# ==========================================================================================
# Year 2002 | Stage Group A | Minute 88
# Lagging: Uruguay | Leading: Senegal | h2h=1
# BASE: pts_diff=-3 | gd_diff=-2 | gs_diff=-1
#
# Scenario S:
#   pts_diff=0.0 | gd_diff=0 | gs_diff=0 | full_tie_S=True
#
# Scenario C:
#   pts_diff=0.0 | gd_diff=0 | gs_diff=0 | full_tie_C=True
#
# => h2h_suspense = True
#
# ==========================================================================================
# Year 1994 | Stage Group F | Minute 0
# Lagging: Morocco | Leading: Netherlands | h2h=1
# BASE: pts_diff=-3 | gd_diff=-2 | gs_diff=-1
#
# Scenario S:
#   pts_diff=0.0 | gd_diff=0 | gs_diff=0 | full_tie_S=True
#
# Scenario C:
#   pts_diff=0.0 | gd_diff=0 | gs_diff=0 | full_tie_C=True
#
# => h2h_suspense = True
#
# ==========================================================================================
# Year 1994 | Stage Group F | Minute 5
# Lagging: Morocco | Leading: Netherlands | h2h=1
# BASE: pts_diff=-3 | gd_diff=-2 | gs_diff=-1
#
# Scenario S:
#   pts_diff=0.0 | gd_diff=0 | gs_diff=0 | full_tie_S=True
#
# Scenario C:
#   pts_diff=0.0 | gd_diff=0 | gs_diff=0 | full_tie_C=True
#
# => h2h_suspense = True
#
# ==========================================================================================
# Year 1994 | Stage Group F | Minute 47
# Lagging: Morocco | Leading: Netherlands | h2h=1
# BASE: pts_diff=-3 | gd_diff=-2 | gs_diff=-1
#
# Scenario S:
#   pts_diff=0.0 | gd_diff=0 | gs_diff=0 | full_tie_S=True
#
# Scenario C:
#   pts_diff=0.0 | gd_diff=0 | gs_diff=0 | full_tie_C=True
#
# => h2h_suspense = True
#
# 🧩 h2h_suspense=1 for 6 rows.

# %%
final_composition_changes_df = evaluate_lagging_losses_and_update_suspense(final_composition_changes_df, goals_df)
# Out:
# 🔍 Checking 6 h2h_suspense observations...
#
#
# 🔎 Year: 1990, Stage: Group F, Minute: 58
#    Pair under tie-break check: Egypt (lagging) vs England (leading) | h2h=1
#    ⏭️ Skipping: h2h==1 indicates current match. Not using final score to update suspense.
#
# 🔎 Year: 1994, Stage: Group F, Minute: 0
#    Pair under tie-break check: Morocco (lagging) vs Netherlands (leading) | h2h=1
#    ⏭️ Skipping: h2h==1 indicates current match. Not using final score to update suspense.
#
# 🔎 Year: 1994, Stage: Group F, Minute: 5
#    Pair under tie-break check: Morocco (lagging) vs Netherlands (leading) | h2h=1
#    ⏭️ Skipping: h2h==1 indicates current match. Not using final score to update suspense.
#
# 🔎 Year: 1994, Stage: Group F, Minute: 47
#    Pair under tie-break check: Morocco (lagging) vs Netherlands (leading) | h2h=1
#    ⏭️ Skipping: h2h==1 indicates current match. Not using final score to update suspense.
#
# 🔎 Year: 2002, Stage: Group A, Minute: 0
#    Pair under tie-break check: Uruguay (lagging) vs Senegal (leading) | h2h=1
#    ⏭️ Skipping: h2h==1 indicates current match. Not using final score to update suspense.
#
# 🔎 Year: 2002, Stage: Group A, Minute: 88
#    Pair under tie-break check: Uruguay (lagging) vs Senegal (leading) | h2h=1
#    ⏭️ Skipping: h2h==1 indicates current match. Not using final score to update suspense.
#
# ✅ Done.
#    Suspense set to 0 for 0 observations where lagging team lost (h2h==0 only).
#    Skipped 6 observations because h2h==1 (current match).
#    Skipped 0 observations because no match found in goals_df.

# %%
display(final_composition_changes_df[
    (final_composition_changes_df['h2h_suspense'] == 1) &
    (final_composition_changes_df['suspense'] == 0)
][['year', 'stage', 'goal_minute', 'lagging_team', 'leading_team', 'suspense']])
# Out:
# Empty DataFrame
# Columns: [year, stage, goal_minute, lagging_team, leading_team, suspense]
# Index: []

# %%
final_composition_changes_df.dtypes
# Out:
# year                          int64
# stage                        object
# date                         object
# time                         object
# goal_minute                   int64
# half_time                   float64
# home_team                    object
# away_team                    object
# scorer_team                  object
# new_top_teams                object
# 1st                          object
# 1st_points                    int64
# 1st_goals_diff                int32
# 1st_goals_scored              int32
# 1st_last_game_points          int64
# 1st_last_game_goals_diff      int64
# 2nd                          object
# 2nd_points                    int64
# 2nd_goals_diff                int32
# 2nd_goals_scored              int32
# 2nd_last_game_points          int64
# 2nd_last_game_goals_diff      int64
# 3rd                          object
# 3rd_points                    int64
# 3rd_goals_diff                int32
# 3rd_goals_scored              int32
# 3rd_last_game_points          int64
# 3rd_last_game_goals_diff      int64
# 4th                          object
# 4th_points                    int64
# 4th_goals_diff                int32
# 4th_goals_scored              int32
# 4th_last_game_points          int64
# 4th_last_game_goals_diff      int64
# third_qualify                 int64
# qualified_teams              object
# qual_changed                  int64
# qual_count                    int64
# pts_diff                      int64
# gls_diff                      int64
# elo_home                    float64
# elo_away                    float64
# h2h                           int64
# lagging_team                 object
# leading_team                 object
# lagging_won                 float64
# suspense                      int64
# h2h_suspense                  int64
# dtype: object

# %%
final_composition_changes_df = update_suspense_draw_lots(final_composition_changes_df)

# %%
 # Drop helper columns
final_composition_changes_df.drop(columns=['lagging_team', 'leading_team', 'h2h_suspense', 'lagging_won'], inplace=True, errors='ignore')

# %%
# Sort the dataset by 'year', 'date', and 'time'
final_composition_changes_df = final_composition_changes_df.sort_values(by=['year', 'date', 'time', 'half_time', 'goal_minute', 'stage'], na_position='first').reset_index(drop=True)

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\goals_wc_fifa.xlsx'
final_composition_changes_df.to_excel(file_path, index=False)

# %% [markdown]
# # minute by minute dataframe

# %%
# Initialize an empty list to store expanded rows
expanded_rows = []

# Iterate over rows grouped by date and time
for (date, time), group in final_composition_changes_df.groupby(["date", "time"]):
    group = group.sort_values(by="goal_minute").reset_index(drop=True)

    # Start match from minute 0
    min_minute = 0
    max_minute = max(90, group["goal_minute"].max(skipna=True)) if not group["goal_minute"].isna().all() else 90

    # Iterate over goal events and fill in missing match minutes
    for i in range(len(group) - 1):
        current_row = group.iloc[i]
        next_row = group.iloc[i + 1]

        for match_minute in range(int(current_row["goal_minute"]), int(next_row["goal_minute"])):
            new_row = current_row.copy()
            new_row["match_minute"] = match_minute

            # Only set goal_minute when it's an actual goal event
            if match_minute != current_row["goal_minute"]:
                new_row["goal_minute"] = None
                new_row["scorer_team"] = None  # Clear scorer team for non-goal minutes
            
            expanded_rows.append(new_row)

    # Add the last row of the group
    last_row = group.iloc[-1].copy()
    last_goal_minute = int(last_row["goal_minute"])
    
    for match_minute in range(last_goal_minute, max_minute + 1):
        new_row = last_row.copy()
        new_row["match_minute"] = match_minute
        new_row["goal_minute"] = None if match_minute > last_goal_minute else last_row["goal_minute"]
        new_row["scorer_team"] = None if match_minute > last_goal_minute else last_row["scorer_team"]
        expanded_rows.append(new_row)

# Create a new DataFrame from the expanded rows
expanded_df = pd.DataFrame(expanded_rows)

# Define the desired column order
column_order = [
    'year', 'stage', 'date', 'time', 'match_minute', 'goal_minute', 'half_time', 'home_team', 
    'away_team', 'scorer_team', 'new_top_teams', 
    '1st', '1st_points', '1st_goals_diff', '1st_goals_scored','1st_last_game_points', '1st_last_game_goals_diff',
    '2nd', '2nd_points', '2nd_goals_diff','2nd_goals_scored', '2nd_last_game_points', '2nd_last_game_goals_diff',
    '3rd', '3rd_points', '3rd_goals_diff', '3rd_goals_scored','3rd_last_game_points', '3rd_last_game_goals_diff',
    '4th', '4th_points', '4th_goals_diff', '4th_goals_scored','4th_last_game_points', '4th_last_game_goals_diff',
    'third_qualify', 'qualified_teams', 'qual_changed', 'qual_count', 
    'pts_diff', 'gls_diff', 'elo_home', 'elo_away', 'suspense', 'h2h'
]
# Ensure the expanded dataframe follows the defined column order
expanded_df = expanded_df[column_order]

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\mbm_wc_fifa.xlsx'
expanded_df.to_excel(file_path, index=False)

# %% [markdown]
# # add info of bookings and subs

# %%
# Create a working copy of the input data
goals_df = final_composition_changes_df.copy()
events_df = cardsub_wc.copy()


# Ensure numeric types
events_df['minute'] = pd.to_numeric(events_df['minute'], errors='coerce')
goals_df['goal_minute'] = pd.to_numeric(goals_df['goal_minute'], errors='coerce')

# Add result columns
goals_df['home_bookings'] = 0
goals_df['away_bookings'] = 0
goals_df['home_yellow_cards'] = 0
goals_df['away_yellow_cards'] = 0
goals_df['home_red_cards_straight'] = 0
goals_df['away_red_cards_straight'] = 0
goals_df['home_red_cards_second_yellow'] = 0
goals_df['away_red_cards_second_yellow'] = 0
goals_df['home_substitutions'] = 0
goals_df['away_substitutions'] = 0
goals_df['match_found'] = False
goals_df['reason_no_match'] = ""

# Iterate and debug
for idx, row in goals_df.iterrows():
    year, stage, ht, at, goal_min = row['year'], row['stage'], row['home_team'], row['away_team'], row['goal_minute']
    match_mask = (events_df['year'] == year) & (events_df['stage'] == stage)
    if not events_df[match_mask].shape[0]:
        goals_df.at[idx, 'reason_no_match'] = "No matching year/stage"
        continue

    same_order = (events_df['home_team'] == ht) & (events_df['away_team'] == at)
    reversed_order = (events_df['home_team'] == at) & (events_df['away_team'] == ht)
    match_mask &= (same_order | reversed_order)

    if not events_df[match_mask].shape[0]:
        goals_df.at[idx, 'reason_no_match'] = "Teams not found in correct or reversed order"
        continue

    match_mask &= (events_df['minute'] <= goal_min)

    match_events = events_df[match_mask]
    if match_events.empty:
        goals_df.at[idx, 'reason_no_match'] = "No events before goal minute"
        continue

    # Match found
    goals_df.at[idx, 'match_found'] = True
    goals_df.at[idx, 'reason_no_match'] = ""

    goals_df.at[idx, 'home_bookings'] = (
        (match_events['event_type'].isin(['Yellow card', 'Red card (straight)', 'Red card (second yellow)'])) &
        (match_events['team_side'] == 'home')
    ).sum()

    goals_df.at[idx, 'away_bookings'] = (
        (match_events['event_type'].isin(['Yellow card', 'Red card (straight)', 'Red card (second yellow)'])) &
        (match_events['team_side'] == 'away')
    ).sum()

    goals_df.at[idx, 'home_substitutions'] = (
        (match_events['event_type'] == 'Substitution') &
        (match_events['team_side'] == 'home')
    ).sum()

    goals_df.at[idx, 'away_substitutions'] = (
        (match_events['event_type'] == 'Substitution') &
        (match_events['team_side'] == 'away')
    ).sum()


    # Yellow cards
    goals_df.at[idx, 'home_yellow_cards'] = (
        (match_events['event_type'] == 'Yellow card') &
        (match_events['team_side'] == 'home')
    ).sum()

    goals_df.at[idx, 'away_yellow_cards'] = (
        (match_events['event_type'] == 'Yellow card') &
        (match_events['team_side'] == 'away')
    ).sum()

    # Red card (straight)
    goals_df.at[idx, 'home_red_cards_straight'] = (
        (match_events['event_type'] == 'Red card (straight)') &
        (match_events['team_side'] == 'home')
    ).sum()

    goals_df.at[idx, 'away_red_cards_straight'] = (
        (match_events['event_type'] == 'Red card (straight)') &
        (match_events['team_side'] == 'away')
    ).sum()

    # Red card (second yellow)
    goals_df.at[idx, 'home_red_cards_second_yellow'] = (
        (match_events['event_type'] == 'Red card (second yellow)') &
        (match_events['team_side'] == 'home')
    ).sum()

    goals_df.at[idx, 'away_red_cards_second_yellow'] = (
        (match_events['event_type'] == 'Red card (second yellow)') &
        (match_events['team_side'] == 'away')
    ).sum()

# %% [markdown]
# # surprise, shock, and suspense according to literature

# %%
goals_df['year'] = goals_df['year'].astype(int)
elo_wc['year'] = elo_wc['year'].astype(int)

# %%
# Get score for each team
goals_df['home_score'] = goals_df.apply(lambda row: get_team_score(row['home_team'], row), axis=1)
goals_df['away_score'] = goals_df.apply(lambda row: get_team_score(row['away_team'], row), axis=1)
goals_df['homeahead'] = (goals_df['home_score'] >= 2).astype(int)
goals_df['awayahead'] = (goals_df['away_score'] >= 2).astype(int)
goals_df['scoreeq'] = ((goals_df['home_score'] == 1) & (goals_df['away_score'] == 1)).astype(int)

# %%
# Your original (Elo-based) trajectory
prob_elo = compute_probabilities_on_goals_new(goals_df, method="elo")

# Csató Poisson–Skellam trajectory
prob_csato = compute_probabilities_on_goals_new(
    goals_df,
    method="csato",
    use_remaining_time_scaling=True,  # optional
    full_duration=100,
    home_adv=100.0
)

# %%
prob_elo = prob_elo[[
    'year', 'stage', 'home_team', 'away_team', 'minute',
    'score_home', 'score_away',
    'P_home', 'P_draw', 'P_away',
    'dP_home', 'dP_draw', 'dP_away',
    'shock', 'surprise', 'suspense',
    'event'
]]

# %%
prob_csato = prob_csato[[
    'year', 'stage', 'home_team', 'away_team', 'minute',
    'score_home', 'score_away',
    'P_home', 'P_draw', 'P_away',
    'dP_home', 'dP_draw', 'dP_away',
    'shock', 'surprise', 'suspense',
    'event'
]]

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\tab_prob_fifa_wc.xlsx'
prob_elo.to_excel(file_path, index=False)

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\men\fifa\wc\tab_prob_fifa_wc_csato.xlsx'
prob_csato.to_excel(file_path, index=False)
