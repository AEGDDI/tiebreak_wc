# %% [markdown]
# # Libraries

# %%
import pandas as pd
from getpass import getuser
from collections import defaultdict
from datetime import datetime, timedelta

# %% [markdown]
# # Load and inspect dataset

# %%
# Get the current user's name
user = getuser()

# Construct the path using the user's name
function_path = f"C:/Users/{user}/Documents/GitHub/tiebreak_wc/code/wiki/functions_fifa.ipynb"

# Run the notebook
# %run $function_path

# %%
# Get the current user's name
user = getuser()

# Path to the dataset
data_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\in\eu_goals_women.xlsx'

# Read the dataset with a different encoding
df = pd.read_excel(data_path)

# Now, filter the data for tournaments after 1984
df = df[df['year'] > 1984]

display(df.head())
# Out:
#    stage  year time home_team away_team score      stadium_name stadium_city  \
# 14   NaN  1987  NaN    Norway     Italy   2–0  Ullevaal Stadion         Oslo
# 15   NaN  1987  NaN    Norway     Italy   2–0  Ullevaal Stadion         Oslo
# 16   NaN  1987  NaN    Sweden   England   3–2    Melløs Stadion         Moss
# 17   NaN  1987  NaN    Sweden   England   3–2    Melløs Stadion         Moss
# 18   NaN  1987  NaN    Sweden   England   3–2    Melløs Stadion         Moss
#
#     stadium_attendance        referee_name  ... goal_minute extra_time  \
# 14                5154             Iceland  ...          40          0
# 15                5154             Iceland  ...          73          0
# 16                 300  Michał Listkiewicz  ...          32          1
# 17                 300  Michał Listkiewicz  ...          50          1
# 18                 300  Michał Listkiewicz  ...         100          1
#
#    goals_home  goals_away  own_goal  penalty  goal_minute_et  goal_et  \
# 14          2           0         0        0               0        0
# 15          2           0         0        0               0        0
# 16          3           2         0        0               0        0
# 17          3           2         0        0               0        0
# 18          3           2         0        0               0        1
#
#     short_date     long_date
# 14         NaN  11 June 1987
# 15         NaN  11 June 1987
# 16         NaN  11 June 1987
# 17         NaN  11 June 1987
# 18         NaN  11 June 1987
#
# [5 rows x 23 columns]

# %% [markdown]
# # Clean, transfrom, create variables

# %% [markdown]
# ## time

# %%
# Step 1: Clean time variable by removing any letters (e.g., EEST, PST) if they exist
df['time_cleaned'] = df['time'].str.replace(r'[A-Za-z]+', '', regex=True).str.strip()

# Step 2: Split time where there are parentheses into local time and UTC offset
df['local_time'] = df['time_cleaned'].str.extract(r'(\d{2}:\d{2})')  # extract the part before parentheses
df['utc_time_offset'] = df['time_cleaned'].str.extract(r'\((.*?)\)')  # extract the part inside parentheses

# %% [markdown]
# ## date

# %%
# Step 1: Remove any commas before the year in 'long_date'
df['long_date'] = df['long_date'].str.replace(r',\s*(\d{4})', r' \1', regex=True)

# Step 2: Convert 'long_date' to 'short_date' where 'short_date' is missing
df['short_date'] = df['short_date'].fillna(pd.to_datetime(df['long_date'], errors='coerce').dt.strftime('%Y-%m-%d'))

# %% [markdown]
# # Extract relevant columns

# %%
# Filter out the knockout stages
df = df[~df['stage'].isin(['Quarter-finals', 'Round of 16', 'Semi-finals', 'Final'])]

# Extract relevant columns for goal events and match results
goals_df = df[['year', 'stage', 'home_team', 'away_team', 'scorer_nationality', 'goal_minute', 'short_date','local_time', 'score']]

# Remove duplicates
goals_df = goals_df.drop_duplicates()

display(goals_df.head())
# Out:
#     year stage home_team away_team scorer_nationality  goal_minute  \
# 14  1987   NaN    Norway     Italy             Norway           40
# 15  1987   NaN    Norway     Italy             Norway           73
# 16  1987   NaN    Sweden   England             Sweden           32
# 17  1987   NaN    Sweden   England             Sweden           50
# 18  1987   NaN    Sweden   England             Sweden          100
#
#     short_date local_time score
# 14  1987-06-11        NaN   2–0
# 15  1987-06-11        NaN   2–0
# 16  1987-06-11        NaN   3–2
# 17  1987-06-11        NaN   3–2
# 18  1987-06-11        NaN   3–2

# %% [markdown]
# # Recreate Leauge Table after first two matchdays

# %%
# Assuming goals_df is your original dataset
agg_goals_before_last_day, goals_last_day_sorted = process_goals_data(goals_df)

# %%
home_games, away_games = aggregate_home_away_points(agg_goals_before_last_day)

# %%
# Filter for year == 2022 and stage == 'Group E'
home2017d = home_games[(home_games['year'] == 2017) & (home_games['stage'] == 'Group D')]
home2017d
# Out:
#     year    stage home_team  goals_scored  goals_conceded  points_home  \
# 48  2017  Group D   England             8               0            6
# 49  2017  Group D  Scotland             1               2            0
# 50  2017  Group D     Spain             2               0            3
#
#     match_count_home
# 48                 2
# 49                 1
# 50                 1

# %%
# Filter for year == 2022 and stage == 'Group E'
away2017d = away_games[(away_games['year'] == 2017) & (away_games['stage'] == 'Group D')]
away2017d
# Out:
#     year    stage away_team  goals_scored  goals_conceded  points_away  \
# 47  2017  Group D  Portugal             2               3            3
# 48  2017  Group D  Scotland             0               6            0
# 49  2017  Group D     Spain             0               2            0
#
#     match_count_away
# 47                 2
# 48                 1
# 49                 1

# %% [markdown]
# ## aggregate data after first two match days

# %%
# Applying the fifa_before_last function to the mock data
all_games_before_last = fifa_before_last(home_games, away_games, agg_goals_before_last_day)
# Out:
# C:\Users\aldi\AppData\Local\Temp\ipykernel_10488\3621940103.py:97: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   all_games_before_last['standing'] = all_games_before_last.groupby(['year', 'stage']).apply(

# %%
# Filtering all_games_before_last for the year 2022 and stage 'Group E'
group2017d = all_games_before_last[
    (all_games_before_last['year'] == 2017) & 
    (all_games_before_last['stage'] == 'Group D')
]

display(group2017d)
# Out:
#     year    stage      team  goals_scored  goals_conceded  points  \
# 66  2017  Group D   England             8               0       6
# 67  2017  Group D     Spain             2               2       3
# 68  2017  Group D  Portugal             2               3       3
# 69  2017  Group D  Scotland             1               8       0
#
#     goals_difference  total_matches tiebreaker  standing
# 66                 8              2    no need         1
# 67                 0              2    no need         2
# 68                -1              2    no need         3
# 69                -7              2    no need         4

# %% [markdown]
# # Recreate league table after last match day

# %%
# Initialize an empty list to store the results for each pair
all_results = []

# Get unique pairs of year and group_name
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    group_name = row['stage']
    
    # Apply the function to the current pair
    result = fifa_final_wc(year, group_name, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_results.append(result)

# Concatenate all the results into a single DataFrame
changes_df_wc = pd.concat(all_results)


# Keep only the specified columns
changes_df_wc = changes_df_wc[['year', 'stage', 'team', '1st', '2nd', '3rd', '4th', 'changes']]

# Display the final DataFrame
display(changes_df_wc)
# Out:
# === Initial Standings for Year 1993, Group Semifinals Before Last Match Goals ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#  Norway             4                   1                     0                      1                        4                          1
# Denmark             1                   0                     1                     -1                        1                          2
#
# ====================================================
#
# Analyzing Semifinals, year 1993, goal: 56 minute, Player team: Germany, Home: Italy, Away: Germany
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Norway             5                   1                     0                      1                 1                   1        1    1    0    0    0 False         0
# Denmark             2                   0                     1                     -1                 1                   2        1    0    1    0    0 False         0
#
# ========================================
#
# Analyzing Semifinals, year 1993, goal: 63 minute, Player team: Italy, Home: Italy, Away: Germany
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Norway             5                   1                     0                      1                 1                   1        1    1    0    0    0 False         0
# Denmark             2                   0                     1                     -1                 1                   2        1    0    1    0    0 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1995, Group Semifinals Before Last Match Goals ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# Germany             6                   6                     2                      4                        6                          1
#  Norway             4                   4                     3                      1                        4                          2
#  Sweden             1                   3                     4                     -1                        1                          3
# England             0                   2                     6                     -4                        0                          4
#
# ====================================================
#
# Analyzing Semifinals, year 1995, goal: 28 minute, Player team: Norway, Home: Sweden, Away: Norway
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   6                     2                      4                 1                   1        1    1    0    0    0 False         0
#  Norway             7                   5                     3                      2                 3                   2        1    0    1    0    0 False         0
#  Sweden             1                   3                     5                     -2                 0                   3        1    0    0    1    0 False         0
# England             1                   2                     6                     -4                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Semifinals, year 1995, goal: 53 minute, Player team: Sweden, Home: Sweden, Away: Norway
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   6                     2                      4                 1                   1        1    1    0    0    0 False         0
#  Norway             5                   5                     4                      1                 1                   2        1    0    1    0    0 False         0
#  Sweden             2                   4                     5                     -1                 1                   3        1    0    0    1    0 False         0
# England             1                   2                     6                     -4                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Semifinals, year 1995, goal: 59 minute, Player team: Sweden, Home: Sweden, Away: Norway
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   6                     2                      4                 1                   1        1    1    0    0    0 False         0
#  Norway             4                   5                     5                      0                 0                   2        1    0    1    0    0  True         1
#  Sweden             4                   5                     5                      0                 3                   3        1    0    0    1    0  True         0
# England             1                   2                     6                     -4                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Semifinals, year 1995, goal: 61 minute, Player team: Sweden, Home: Sweden, Away: Norway
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   6                     2                      4                 1                   1        1    1    0    0    0 False         0
#  Sweden             4                   6                     5                      1                 3                   2        2    0    1    1    0 False         0
#  Norway             4                   5                     6                     -1                 0                   3        2    0    1    1    0 False         0
# England             1                   2                     6                     -4                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Semifinals, year 1995, goal: 76 minute, Player team: Sweden, Home: Sweden, Away: Norway
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   6                     2                      4                 1                   1        1    1    0    0    0 False         0
#  Sweden             4                   7                     5                      2                 3                   2        2    0    1    1    0 False         0
#  Norway             4                   5                     7                     -2                 0                   3        2    0    1    1    0 False         0
# England             1                   2                     6                     -4                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1997, Group Group A Before Last Match Goals ===
#
#   team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# Sweden             6                   3                     1                      2                        6                          1
# France             4                   4                     2                      2                        4                          2
#  Spain             1                   1                     2                     -1                        1                          3
# Russia             0                   2                     5                     -3                        0                          4
#
# ====================================================
#
# Analyzing Group A, year 1997, goal: 18 minute, Player team: Sweden, Home: Sweden, Away: France
#
# === Updated Standings After This Goal ===
#
#   team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Sweden             9                   4                     1                      3                 3                   1        1    1    0    0    0 False         0
# France             4                   4                     3                      1                 0                   2        1    0    1    0    0 False         0
#  Spain             2                   1                     2                     -1                 1                   3        1    0    0    1    0 False         0
# Russia             1                   2                     5                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1997, goal: 22 minute, Player team: Sweden, Home: Sweden, Away: France
#
# === Updated Standings After This Goal ===
#
#   team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Sweden             9                   5                     1                      4                 3                   1        1    1    0    0    0 False         0
# France             4                   4                     4                      0                 0                   2        1    0    1    0    0 False         0
#  Spain             2                   1                     2                     -1                 1                   3        1    0    0    1    0 False         0
# Russia             1                   2                     5                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1997, goal: 45 minute, Player team: Sweden, Home: Sweden, Away: France
#
# === Updated Standings After This Goal ===
#
#   team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Sweden             9                   6                     1                      5                 3                   1        1    1    0    0    0 False         0
# France             4                   4                     5                     -1                 0                   2        1    0    1    0    0 False         0
#  Spain             2                   1                     2                     -1                 1                   3        1    0    0    1    0 False         0
# Russia             1                   2                     5                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 1997, goal: 67 minute, Player team: Spain, Home: Russia, Away: Spain
#
# === Updated Standings After This Goal ===
#
#   team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Sweden             9                   6                     1                      5                 3                   1        1    1    0    0    0 False         0
#  Spain             4                   2                     2                      0                 3                   2        2    0    1    1    0 False         0
# France             4                   4                     5                     -1                 0                   3        2    0    1    1    0 False         0
# Russia             0                   2                     6                     -4                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 1997, Group Group B Before Last Match Goals ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#  Norway             3                   5                     0                      5                        3                          1
#   Italy             2                   3                     3                      0                        2                          2
# Germany             1                   1                     1                      0                        1                          3
# Denmark             1                   2                     7                     -5                        1                          4
#
# ====================================================
#
# Analyzing Group B, year 1997, goal: 4 minute, Player team: Italy, Home: Norway, Away: Italy
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Italy             5                   4                     3                      1                 3                   1        2    1    1    0    0 False         0
#  Norway             3                   5                     1                      4                 0                   2        2    1    1    0    0 False         0
# Germany             2                   1                     1                      0                 1                   3        2    0    0    2    0 False         0
# Denmark             2                   2                     7                     -5                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group B, year 1997, goal: 82 minute, Player team: Germany, Home: Denmark, Away: Germany
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Italy             5                   4                     3                      1                 3                   1        2    1    1    0    0 False         0
# Germany             4                   2                     1                      1                 3                   2        3    0    1    2    0 False         0
#  Norway             3                   5                     1                      4                 0                   3        3    1    1    1    0 False         0
# Denmark             1                   2                     8                     -6                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group B, year 1997, goal: 90 minute, Player team: Germany, Home: Denmark, Away: Germany
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Italy             5                   4                     3                      1                 3                   1        2    1    1    0    0 False         0
# Germany             4                   3                     1                      2                 3                   2        3    0    1    2    0 False         0
#  Norway             3                   5                     1                      4                 0                   3        3    1    1    1    0 False         0
# Denmark             1                   2                     9                     -7                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group B, year 1997, goal: 92 minute, Player team: Italy, Home: Norway, Away: Italy
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#   Italy             5                   5                     3                      2                 3                   1        2    1    1    0    0 False         0
# Germany             4                   3                     1                      2                 3                   2        3    0    1    2    0 False         0
#  Norway             3                   5                     2                      3                 0                   3        3    1    1    1    0 False         0
# Denmark             1                   2                     9                     -7                 0                   4        2    0    0    0    2 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2001, Group Group A Before Last Match Goals ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# Germany             6                   8                     1                      7                        6                          1
#  Sweden             3                   5                     3                      2                        3                          2
# England             1                   1                     5                     -4                        1                          3
#  Russia             1                   1                     6                     -5                        1                          4
#
# ====================================================
#
# Analyzing Group A, year 2001, goal: 57 minute, Player team: Germany, Home: England, Away: Germany
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             9                   9                     1                      8                 3                   1        1    1    0    0    0 False         0
#  Sweden             4                   5                     3                      2                 1                   2        1    0    1    0    0 False         0
#  Russia             2                   1                     6                     -5                 1                   3        2    0    0    1    1 False         0
# England             1                   1                     6                     -5                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group A, year 2001, goal: 65 minute, Player team: Germany, Home: England, Away: Germany
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             9                  10                     1                      9                 3                   1        1    1    0    0    0 False         0
#  Sweden             4                   5                     3                      2                 1                   2        1    0    1    0    0 False         0
#  Russia             2                   1                     6                     -5                 1                   3        2    0    0    1    1 False         0
# England             1                   1                     7                     -6                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group A, year 2001, goal: 67 minute, Player team: Germany, Home: England, Away: Germany
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             9                  11                     1                     10                 3                   1        1    1    0    0    0 False         0
#  Sweden             4                   5                     3                      2                 1                   2        1    0    1    0    0 False         0
#  Russia             2                   1                     6                     -5                 1                   3        2    0    0    1    1 False         0
# England             1                   1                     8                     -7                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group A, year 2001, goal: 76 minute, Player team: Sweden, Home: Sweden, Away: Russia
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             9                  11                     1                     10                 3                   1        1    1    0    0    0 False         0
#  Sweden             6                   6                     3                      3                 3                   2        1    0    1    0    0 False         0
#  Russia             1                   1                     7                     -6                 0                   3        2    0    0    1    1 False         0
# England             1                   1                     8                     -7                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2001, Group Group B Before Last Match Goals ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#  Norway             4                   4                     1                      3                        4                          1
#   Italy             4                   3                     2                      1                        4                          2
# Denmark             3                   5                     5                      0                        3                          3
#  France             0                   3                     7                     -4                        0                          4
#
# ====================================================
#
# Analyzing Group B, year 2001, goal: 37 minute, Player team: France, Home: France, Away: Italy
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Norway             5                   4                     1                      3                 1                   1        1    1    0    0    0 False         0
# Denmark             4                   5                     5                      0                 1                   2        2    0    1    1    0 False         0
#   Italy             4                   3                     3                      0                 0                   3        2    0    1    1    0 False         0
#  France             3                   4                     7                     -3                 3                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group B, year 2001, goal: 74 minute, Player team: France, Home: France, Away: Italy
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Norway             5                   4                     1                      3                 1                   1        1    1    0    0    0 False         0
# Denmark             4                   5                     5                      0                 1                   2        2    0    1    1    0 False         0
#   Italy             4                   3                     4                     -1                 0                   3        2    0    1    1    0 False         0
#  France             3                   5                     7                     -2                 3                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group B, year 2001, goal: 85 minute, Player team: Denmark, Home: Denmark, Away: Norway
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Denmark             6                   6                     5                      1                 3                   1        3    1    1    1    0 False         0
#  Norway             4                   4                     2                      2                 0                   2        2    1    1    0    0 False         0
#   Italy             4                   3                     4                     -1                 0                   3        2    0    1    1    0 False         0
#  France             3                   5                     7                     -2                 3                   4        2    0    0    0    2 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2005, Group Group A Before Last Match Goals ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# Denmark             4                   3                     2                      1                        4                          1
# England             3                   4                     4                      0                        3                          2
#  Sweden             2                   1                     1                      0                        2                          3
# Finland             1                   2                     3                     -1                        1                          4
#
# ====================================================
#
# Analyzing Group A, year 2005, goal: 3 minute, Player team: Sweden, Home: England, Away: Sweden
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Denmark             5                   3                     2                      1                 1                   1        1    1    0    0    0 False         0
#  Sweden             5                   2                     1                      1                 3                   2        2    0    1    1    0 False         0
# England             3                   4                     5                     -1                 0                   3        2    0    1    1    0 False         0
# Finland             2                   2                     3                     -1                 1                   4        2    0    0    0    2 False         0
#
# ========================================
#
# Analyzing Group A, year 2005, goal: 6 minute, Player team: Finland, Home: Finland, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             5                   2                     1                      1                 3                   1        3    1    1    1    0 False         0
# Finland             4                   3                     3                      0                 3                   2        3    0    1    0    2  True         1
# Denmark             4                   3                     3                      0                 0                   3        2    1    0    1    0  True         0
# England             3                   4                     5                     -1                 0                   4        3    0    1    1    1 False         0
#
# ========================================
#
# Analyzing Group A, year 2005, goal: 16 minute, Player team: Finland, Home: Finland, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             5                   2                     1                      1                 3                   1        3    1    1    1    0 False         0
# Finland             4                   4                     3                      1                 3                   2        3    0    1    0    2 False         0
# Denmark             4                   3                     4                     -1                 0                   3        2    1    0    1    0 False         0
# England             3                   4                     5                     -1                 0                   4        3    0    1    1    1 False         0
#
# ========================================
#
# Analyzing Group A, year 2005, goal: 45 minute, Player team: Denmark, Home: Finland, Away: Denmark
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  Sweden             5                   2                     1                      1                 3                   1        3    1    1    1    0 False         0
# Finland             4                   4                     4                      0                 3                   2        3    0    1    0    2  True         1
# Denmark             4                   4                     4                      0                 0                   3        2    1    0    1    0  True         0
# England             3                   4                     5                     -1                 0                   4        3    0    1    1    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2005, Group Group B Before Last Match Goals ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
# Germany             6                   5                     0                      5                        6                          1
#  France             4                   4                     2                      2                        4                          2
#  Norway             1                   1                     2                     -1                        1                          3
#   Italy             0                   1                     7                     -6                        0                          4
#
# ====================================================
#
# Analyzing Group B, year 2005, goal: 7 minute, Player team: Norway, Home: Norway, Away: Italy
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   5                     0                      5                 1                   1        1    1    0    0    0 False         0
#  France             5                   4                     2                      2                 1                   2        1    0    1    0    0 False         0
#  Norway             4                   2                     2                      0                 3                   3        1    0    0    1    0 False         0
#   Italy             0                   1                     8                     -7                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 2005, goal: 8 minute, Player team: Italy, Home: Norway, Away: Italy
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   5                     0                      5                 1                   1        1    1    0    0    0 False         0
#  France             5                   4                     2                      2                 1                   2        1    0    1    0    0 False         0
#  Norway             2                   2                     3                     -1                 1                   3        1    0    0    1    0 False         0
#   Italy             1                   2                     8                     -6                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 2005, goal: 29 minute, Player team: Norway, Home: Norway, Away: Italy
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   5                     0                      5                 1                   1        1    1    0    0    0 False         0
#  France             5                   4                     2                      2                 1                   2        1    0    1    0    0 False         0
#  Norway             4                   3                     3                      0                 3                   3        1    0    0    1    0 False         0
#   Italy             0                   2                     9                     -7                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 2005, goal: 35 minute, Player team: Norway, Home: Norway, Away: Italy
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   5                     0                      5                 1                   1        1    1    0    0    0 False         0
#  France             5                   4                     2                      2                 1                   2        1    0    1    0    0 False         0
#  Norway             4                   4                     3                      1                 3                   3        1    0    0    1    0 False         0
#   Italy             0                   2                    10                     -8                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 2005, goal: 44 minute, Player team: Norway, Home: Norway, Away: Italy
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   5                     0                      5                 1                   1        1    1    0    0    0 False         0
#  France             5                   4                     2                      2                 1                   2        1    0    1    0    0 False         0
#  Norway             4                   5                     3                      2                 3                   3        1    0    0    1    0 False         0
#   Italy             0                   2                    11                     -9                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 2005, goal: 53 minute, Player team: Italy, Home: Norway, Away: Italy
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   5                     0                      5                 1                   1        1    1    0    0    0 False         0
#  France             5                   4                     2                      2                 1                   2        1    0    1    0    0 False         0
#  Norway             4                   5                     4                      1                 3                   3        1    0    0    1    0 False         0
#   Italy             0                   3                    11                     -8                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 2005, goal: 57 minute, Player team: Norway, Home: Norway, Away: Italy
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   5                     0                      5                 1                   1        1    1    0    0    0 False         0
#  France             5                   4                     2                      2                 1                   2        1    0    1    0    0 False         0
#  Norway             4                   6                     4                      2                 3                   3        1    0    0    1    0 False         0
#   Italy             0                   3                    12                     -9                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 2005, goal: 69 minute, Player team: Italy, Home: Norway, Away: Italy
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             7                   5                     0                      5                 1                   1        1    1    0    0    0 False         0
#  France             5                   4                     2                      2                 1                   2        1    0    1    0    0 False         0
#  Norway             4                   6                     5                      1                 3                   3        1    0    0    1    0 False         0
#   Italy             0                   4                    12                     -8                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 2005, goal: 72 minute, Player team: Germany, Home: France, Away: Germany
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             9                   6                     0                      6                 3                   1        1    1    0    0    0 False         0
#  Norway             4                   6                     5                      1                 3                   2        2    0    1    1    0 False         0
#  France             4                   4                     3                      1                 0                   3        2    0    1    1    0 False         0
#   Italy             0                   4                    12                     -8                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 2005, goal: 77 minute, Player team: Germany, Home: France, Away: Germany
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             9                   7                     0                      7                 3                   1        1    1    0    0    0 False         0
#  Norway             4                   6                     5                      1                 3                   2        2    0    1    1    0 False         0
#  France             4                   4                     4                      0                 0                   3        2    0    1    1    0 False         0
#   Italy             0                   4                    12                     -8                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group B, year 2005, goal: 83 minute, Player team: Germany, Home: France, Away: Germany
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Germany             9                   8                     0                      8                 3                   1        1    1    0    0    0 False         0
#  Norway             4                   6                     5                      1                 3                   2        2    0    1    1    0 False         0
#  France             4                   4                     5                     -1                 0                   3        2    0    1    1    0 False         0
#   Italy             0                   4                    12                     -8                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2009, Group Group A Before Last Match Goals ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#     Finland             6                   3                     1                      2                        6                          1
# Netherlands             3                   3                     2                      1                        3                          2
#     Denmark             3                   2                     2                      0                        3                          3
#     Ukraine             0                   1                     4                     -3                        0                          4
#
# ====================================================
#
# Analyzing Group A, year 2009, goal: 58 minute, Player team: Netherlands, Home: Denmark, Away: Netherlands
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     Finland             7                   3                     1                      2                 1                   1        1    1    0    0    0 False         0
# Netherlands             6                   4                     2                      2                 3                   2        1    0    1    0    0 False         0
#     Denmark             3                   2                     3                     -1                 0                   3        1    0    0    1    0 False         0
#     Ukraine             1                   1                     4                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 2009, goal: 66 minute, Player team: Netherlands, Home: Denmark, Away: Netherlands
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#     Finland             7                   3                     1                      2                 1                   1        1    1    0    0    0 False         0
# Netherlands             6                   5                     2                      3                 3                   2        1    0    1    0    0 False         0
#     Denmark             3                   2                     4                     -2                 0                   3        1    0    0    1    0 False         0
#     Ukraine             1                   1                     4                     -3                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group A, year 2009, goal: 69 minute, Player team: Ukraine, Home: Finland, Away: Ukraine
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
# Netherlands             6                   5                     2                      3                 3                   1        2    1    1    0    0 False         0
#     Finland             6                   3                     2                      1                 0                   2        2    1    1    0    0 False         0
#     Denmark             3                   2                     4                     -2                 0                   3        1    0    0    1    0  True         1
#     Ukraine             3                   2                     4                     -2                 3                   4        1    0    0    0    1  True         0
#
# ========================================
#
# ...
# Netherlands             4                   4                     3                      1                        4                          1
#      Sweden             4                   3                     2                      1                        4                          2
#    Portugal             1                   4                     5                     -1                        1                          3
# Switzerland             1                   3                     4                     -1                        1                          4
#
# ====================================================
#
# Analyzing Group C, year 2022, goal: 21 minute, Player team: Sweden, Home: Sweden, Away: Portugal
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Sweden             7                   4                     2                      2                 3                   1        2    1    1    0    0 False         0
# Netherlands             5                   4                     3                      1                 1                   2        2    1    1    0    0 False         0
# Switzerland             2                   3                     4                     -1                 1                   3        2    0    0    1    1 False         0
#    Portugal             1                   4                     6                     -2                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group C, year 2022, goal: 45 minute, Player team: Sweden, Home: Sweden, Away: Portugal
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Sweden             7                   5                     2                      3                 3                   1        2    1    1    0    0 False         0
# Netherlands             5                   4                     3                      1                 1                   2        2    1    1    0    0 False         0
# Switzerland             2                   3                     4                     -1                 1                   3        2    0    0    1    1 False         0
#    Portugal             1                   4                     7                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group C, year 2022, goal: 49 minute, Player team: Netherlands, Home: Switzerland, Away: Netherlands
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Sweden             7                   5                     2                      3                 3                   1        2    1    1    0    0 False         0
# Netherlands             7                   5                     3                      2                 3                   2        2    1    1    0    0 False         0
# Switzerland             1                   3                     5                     -2                 0                   3        2    0    0    1    1 False         0
#    Portugal             1                   4                     7                     -3                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group C, year 2022, goal: 52 minute, Player team: Sweden, Home: Sweden, Away: Portugal
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Sweden             7                   6                     2                      4                 3                   1        2    1    1    0    0 False         0
# Netherlands             7                   5                     3                      2                 3                   2        2    1    1    0    0 False         0
# Switzerland             1                   3                     5                     -2                 0                   3        2    0    0    1    1 False         0
#    Portugal             1                   4                     8                     -4                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group C, year 2022, goal: 53 minute, Player team: Switzerland, Home: Switzerland, Away: Netherlands
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Sweden             7                   6                     2                      4                 3                   1        2    1    1    0    0 False         0
# Netherlands             5                   5                     4                      1                 1                   2        2    1    1    0    0 False         0
# Switzerland             2                   4                     5                     -1                 1                   3        2    0    0    1    1 False         0
#    Portugal             1                   4                     8                     -4                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group C, year 2022, goal: 54 minute, Player team: Sweden, Home: Sweden, Away: Portugal
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Sweden             7                   7                     2                      5                 3                   1        2    1    1    0    0 False         0
# Netherlands             5                   5                     4                      1                 1                   2        2    1    1    0    0 False         0
# Switzerland             2                   4                     5                     -1                 1                   3        2    0    0    1    1 False         0
#    Portugal             1                   4                     9                     -5                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group C, year 2022, goal: 84 minute, Player team: Netherlands, Home: Switzerland, Away: Netherlands
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Sweden             7                   7                     2                      5                 3                   1        2    1    1    0    0 False         0
# Netherlands             7                   6                     4                      2                 3                   2        2    1    1    0    0 False         0
# Switzerland             1                   4                     6                     -2                 0                   3        2    0    0    1    1 False         0
#    Portugal             1                   4                     9                     -5                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group C, year 2022, goal: 89 minute, Player team: Netherlands, Home: Switzerland, Away: Netherlands
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Sweden             7                   7                     2                      5                 3                   1        2    1    1    0    0 False         0
# Netherlands             7                   7                     4                      3                 3                   2        2    1    1    0    0 False         0
# Switzerland             1                   4                     7                     -3                 0                   3        2    0    0    1    1 False         0
#    Portugal             1                   4                     9                     -5                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group C, year 2022, goal: 91 minute, Player team: Sweden, Home: Sweden, Away: Portugal
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Sweden             7                   8                     2                      6                 3                   1        2    1    1    0    0 False         0
# Netherlands             7                   7                     4                      3                 3                   2        2    1    1    0    0 False         0
# Switzerland             1                   4                     7                     -3                 0                   3        2    0    0    1    1 False         0
#    Portugal             1                   4                    10                     -6                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
# Analyzing Group C, year 2022, goal: 95 minute, Player team: Netherlands, Home: Switzerland, Away: Netherlands
#
# === Updated Standings After This Goal ===
#
#        team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#      Sweden             7                   8                     2                      6                 3                   1        2    1    1    0    0 False         0
# Netherlands             7                   8                     4                      4                 3                   2        2    1    1    0    0 False         0
# Switzerland             1                   4                     8                     -4                 0                   3        2    0    0    1    1 False         0
#    Portugal             1                   4                    10                     -6                 0                   4        2    0    0    1    1 False         0
#
# ========================================
#
#
# === Initial Standings for Year 2022, Group Group D Before Last Match Goals ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  before_last_game_points  before_last_game_standing
#  France             6                   7                     2                      5                        6                          1
# Iceland             2                   2                     2                      0                        2                          2
# Belgium             1                   2                     3                     -1                        1                          3
#   Italy             1                   2                     6                     -4                        1                          4
#
# ====================================================
#
# Analyzing Group D, year 2022, goal: 1 minute, Player team: France, Home: Iceland, Away: France
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  France             9                   8                     2                      6                 3                   1        1    1    0    0    0 False         0
# Iceland             2                   2                     3                     -1                 0                   2        1    0    1    0    0  True         0
# Belgium             2                   2                     3                     -1                 1                   3        1    0    0    1    0  True         0
#   Italy             2                   2                     6                     -4                 1                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group D, year 2022, goal: 49 minute, Player team: Belgium, Home: Italy, Away: Belgium
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  France             9                   8                     2                      6                 3                   1        1    1    0    0    0 False         0
# Belgium             4                   3                     3                      0                 3                   2        2    0    1    1    0 False         0
# Iceland             2                   2                     3                     -1                 0                   3        2    0    1    1    0 False         0
#   Italy             1                   2                     7                     -5                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#
# Analyzing Group D, year 2022, goal: 102 minute, Player team: Iceland, Home: Iceland, Away: France
#
# === Updated Standings After This Goal ===
#
#    team  total_points  total_goals_scored  total_goals_conceded  total_goal_difference  last_game_points  last_game_standing  changes  1st  2nd  3rd  4th  tied  tied_won
#  France             7                   8                     3                      5                 1                   1        1    1    0    0    0 False         0
# Belgium             4                   3                     3                      0                 3                   2        2    0    1    1    0 False         0
# Iceland             3                   3                     3                      0                 1                   3        2    0    1    1    0 False         0
#   Italy             1                   2                     7                     -5                 0                   4        1    0    0    0    1 False         0
#
# ========================================
#     year       stage      team  1st  2nd  3rd  4th  changes
# 0   1993  Semifinals    Norway    1    0    0    0        1
# 1   1993  Semifinals   Denmark    0    1    0    0        1
# 2   1995  Semifinals   Germany    1    0    0    0        1
# 4   1995  Semifinals    Sweden    0    1    1    0        2
# 3   1995  Semifinals    Norway    0    1    1    0        2
# ..   ...         ...       ...  ...  ...  ...  ...      ...
# 80  2022     Group C  Portugal    0    0    1    1        2
# 82  2022     Group D    France    1    0    0    0        1
# 84  2022     Group D   Belgium    0    1    1    0        2
# 83  2022     Group D   Iceland    0    1    1    0        2
# 85  2022     Group D     Italy    0    0    0    1        1
#
# [86 rows x 8 columns]

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\women\fifa\eu\tb_eu_fifa_women.xlsx'
changes_df_wc.to_excel(file_path, index=False)

# %% [markdown]
# # group composition tracking

# %%
# Initialize an empty list to store the results for each pair
all_composition_changes = []

# Get unique pairs of year, stage, and men
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    stage = row['stage']
    
    # Apply the function to the current pair
    composition_changes_df = track_composition_changes(year, stage, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_composition_changes.append(composition_changes_df)

# Concatenate all the results into a single DataFrame
final_composition_changes_df = pd.concat(all_composition_changes, ignore_index=True)

# Display the final DataFrame
display(final_composition_changes_df)
# Out:
#     year       stage  change_num goal_time    home_team away_team  \
# 0   1993  Semifinals           0   initial         None      None
# 1   1995  Semifinals           0   initial         None      None
# 2   1995  Semifinals           1        61       Sweden    Norway
# 3   1997     Group A           0   initial         None      None
# 4   1997     Group A           1        67       Russia     Spain
# 5   1997     Group B           0   initial         None      None
# 6   1997     Group B           1        82      Denmark   Germany
# 7   2001     Group A           0   initial         None      None
# 8   2001     Group B           0   initial         None      None
# 9   2001     Group B           1        37       France     Italy
# 10  2005     Group A           0   initial         None      None
# 11  2005     Group A           1         3      England    Sweden
# 12  2005     Group A           2        16      Finland   Denmark
# 13  2005     Group B           0   initial         None      None
# 14  2005     Group B           1        72       France   Germany
# 15  2009     Group A           0   initial         None      None
# 16  2009     Group B           0   initial         None      None
# 17  2009     Group B           1         4       Norway    France
# 18  2009     Group B           2        16       Norway    France
# 19  2009     Group C           0   initial         None      None
# 20  2009     Group C           1        77       Russia     Italy
# 21  2013     Group A           0   initial         None      None
# 22  2013     Group A           1        47       Sweden     Italy
# 23  2013     Group A           2        87      Denmark   Finland
# 24  2013     Group B           0   initial         None      None
# 25  2013     Group B           1        46      Germany    Norway
# 26  2013     Group C           0   initial         None      None
# 27  2017     Group A           0   initial         None      None
# 28  2017     Group A           1         5       Norway   Denmark
# 29  2017     Group B           0   initial         None      None
# 30  2017     Group B           1         4       Sweden     Italy
# 31  2017     Group B           2        10       Russia   Germany
# 32  2017     Group C           0   initial         None      None
# 33  2017     Group C           1        19  Switzerland    France
# 34  2017     Group C           2        76  Switzerland    France
# 35  2017     Group D           0   initial         None      None
# 36  2017     Group D           1        42     Scotland     Spain
# 37  2017     Group D           2        48     Portugal   England
# 38  2022     Group A           0   initial         None      None
# 39  2022     Group B           0   initial         None      None
# 40  2022     Group C           0   initial         None      None
# 41  2022     Group D           0   initial         None      None
# 42  2022     Group D           1        49        Italy   Belgium
#
#    scorer_nationality           new_top_teams third_place_teams_list  \
# 0                None       [Denmark, Norway]                     []
# 1                None       [Germany, Norway]               [Sweden]
# 2              Sweden       [Germany, Sweden]               [Norway]
# 3                None        [France, Sweden]                [Spain]
# 4               Spain         [Sweden, Spain]               [France]
# 5                None         [Norway, Italy]              [Germany]
# 6             Germany        [Germany, Italy]               [Norway]
# 7                None       [Germany, Sweden]              [England]
# 8                None         [Norway, Italy]              [Denmark]
# 9              France       [Denmark, Norway]                [Italy]
# 10               None      [Denmark, England]               [Sweden]
# 11             Sweden       [Denmark, Sweden]              [England]
# 12            Finland       [Finland, Sweden]              [Denmark]
# 13               None       [France, Germany]               [Norway]
# 14            Germany       [Germany, Norway]               [France]
# 15               None  [Finland, Netherlands]              [Denmark]
# 16               None       [France, Germany]               [Norway]
# 17             Norway       [Germany, Norway]               [France]
# 18             France       [France, Germany]               [Norway]
# 19               None       [England, Sweden]                [Italy]
# 20              Italy         [Sweden, Italy]              [England]
# 21               None         [Sweden, Italy]              [Denmark]
# 22             Sweden       [Denmark, Sweden]                [Italy]
# 23            Finland         [Sweden, Italy]              [Denmark]
# 24               None       [Germany, Norway]              [Iceland]
# 25             Norway       [Iceland, Norway]              [Germany]
# 26               None         [France, Spain]              [England]
# 27               None  [Belgium, Netherlands]              [Denmark]
# 28            Denmark  [Denmark, Netherlands]              [Belgium]
# 29               None       [Germany, Sweden]               [Russia]
# 30              Italy       [Germany, Russia]               [Sweden]
# 31            Germany       [Germany, Sweden]                [Italy]
# 32               None       [Austria, France]          [Switzerland]
# 33        Switzerland  [Austria, Switzerland]               [France]
# 34             France       [Austria, France]          [Switzerland]
# 35               None        [England, Spain]             [Portugal]
# 36           Scotland     [Portugal, England]                [Spain]
# 37            England        [England, Spain]             [Portugal]
# 38               None      [Austria, England]               [Norway]
# 39               None        [Germany, Spain]              [Denmark]
# 40               None   [Sweden, Netherlands]             [Portugal]
# 41               None       [France, Iceland]              [Belgium]
# 42            Belgium       [Belgium, France]              [Iceland]
#
#     top4_third_place          1st          2nd          3rd
# 0                  0       Norway      Denmark         None
# 1                  1      Germany       Norway       Sweden
# 2                  1      Germany       Sweden       Norway
# 3                  1       Sweden       France        Spain
# 4                  1       Sweden        Spain       France
# 5                  1       Norway        Italy      Germany
# 6                  1        Italy      Germany       Norway
# 7                  1      Germany       Sweden      England
# 8                  1       Norway        Italy      Denmark
# 9                  1       Norway      Denmark        Italy
# 10                 1      Denmark      England       Sweden
# 11                 1      Denmark       Sweden      England
# 12                 1       Sweden      Finland      Denmark
# 13                 1      Germany       France       Norway
# 14                 1      Germany       Norway       France
# 15                 1      Finland  Netherlands      Denmark
# 16                 1      Germany       France       Norway
# 17                 1      Germany       Norway       France
# 18                 1      Germany       France       Norway
# 19                 1       Sweden      England        Italy
# 20                 1       Sweden        Italy      England
# 21                 1       Sweden        Italy      Denmark
# 22                 1       Sweden      Denmark        Italy
# 23                 1       Sweden        Italy      Denmark
# 24                 1       Norway      Germany      Iceland
# 25                 1       Norway      Iceland      Germany
# 26                 1       France        Spain      England
# 27                 1  Netherlands      Belgium      Denmark
# 28                 1  Netherlands      Denmark      Belgium
# 29                 1       Sweden      Germany       Russia
# 30                 1      Germany       Russia       Sweden
# 31                 1      Germany       Sweden        Italy
# 32                 1      Austria       France  Switzerland
# 33                 1  Switzerland      Austria       France
# 34                 1      Austria       France  Switzerland
# 35                 1      England        Spain     Portugal
# 36                 1      England     Portugal        Spain
# 37                 1      England        Spain     Portugal
# 38                 1      England      Austria       Norway
# 39                 1      Germany        Spain      Denmark
# 40                 1  Netherlands       Sweden     Portugal
# 41                 1       France      Iceland      Belgium
# 42                 1       France      Belgium      Iceland

# %%
# Initialize an empty list to store the results for each pair
all_composition_changes = []

# Get unique pairs of year and group_name
unique_pairs = all_games_before_last[['year', 'stage']].drop_duplicates()

# Loop through each unique pair
for _, row in unique_pairs.iterrows():
    year = row['year']
    group_name = row['stage']
    
    # Apply the function to the current pair
    composition_changes_df = track_composition_changes(year, group_name, all_games_before_last, goals_last_day_sorted, agg_goals_before_last_day)
    
    # Append the result to the list
    all_composition_changes.append(composition_changes_df)

# Concatenate all the results into a single DataFrame
final_composition_changes_df = pd.concat(all_composition_changes, ignore_index=True)

# Rename 'player_team' column to 'scorer_team'
final_composition_changes_df.rename(columns={'player_team': 'scorer_team'}, inplace=True)

# Display the final DataFrame
display(final_composition_changes_df)
# Out:
#     year       stage  change_num goal_time    home_team away_team  \
# 0   1993  Semifinals           0   initial         None      None
# 1   1995  Semifinals           0   initial         None      None
# 2   1995  Semifinals           1        61       Sweden    Norway
# 3   1997     Group A           0   initial         None      None
# 4   1997     Group A           1        67       Russia     Spain
# 5   1997     Group B           0   initial         None      None
# 6   1997     Group B           1        82      Denmark   Germany
# 7   2001     Group A           0   initial         None      None
# 8   2001     Group B           0   initial         None      None
# 9   2001     Group B           1        37       France     Italy
# 10  2005     Group A           0   initial         None      None
# 11  2005     Group A           1         3      England    Sweden
# 12  2005     Group A           2        16      Finland   Denmark
# 13  2005     Group B           0   initial         None      None
# 14  2005     Group B           1        72       France   Germany
# 15  2009     Group A           0   initial         None      None
# 16  2009     Group B           0   initial         None      None
# 17  2009     Group B           1         4       Norway    France
# 18  2009     Group B           2        16       Norway    France
# 19  2009     Group C           0   initial         None      None
# 20  2009     Group C           1        77       Russia     Italy
# 21  2013     Group A           0   initial         None      None
# 22  2013     Group A           1        47       Sweden     Italy
# 23  2013     Group A           2        87      Denmark   Finland
# 24  2013     Group B           0   initial         None      None
# 25  2013     Group B           1        46      Germany    Norway
# 26  2013     Group C           0   initial         None      None
# 27  2017     Group A           0   initial         None      None
# 28  2017     Group A           1         5       Norway   Denmark
# 29  2017     Group B           0   initial         None      None
# 30  2017     Group B           1         4       Sweden     Italy
# 31  2017     Group B           2        10       Russia   Germany
# 32  2017     Group C           0   initial         None      None
# 33  2017     Group C           1        19  Switzerland    France
# 34  2017     Group C           2        76  Switzerland    France
# 35  2017     Group D           0   initial         None      None
# 36  2017     Group D           1        42     Scotland     Spain
# 37  2017     Group D           2        48     Portugal   England
# 38  2022     Group A           0   initial         None      None
# 39  2022     Group B           0   initial         None      None
# 40  2022     Group C           0   initial         None      None
# 41  2022     Group D           0   initial         None      None
# 42  2022     Group D           1        49        Italy   Belgium
#
#    scorer_nationality           new_top_teams third_place_teams_list  \
# 0                None       [Denmark, Norway]                     []
# 1                None       [Germany, Norway]               [Sweden]
# 2              Sweden       [Germany, Sweden]               [Norway]
# 3                None        [France, Sweden]                [Spain]
# 4               Spain         [Sweden, Spain]               [France]
# 5                None         [Norway, Italy]              [Germany]
# 6             Germany        [Germany, Italy]               [Norway]
# 7                None       [Germany, Sweden]              [England]
# 8                None         [Norway, Italy]              [Denmark]
# 9              France       [Denmark, Norway]                [Italy]
# 10               None      [Denmark, England]               [Sweden]
# 11             Sweden       [Denmark, Sweden]              [England]
# 12            Finland       [Finland, Sweden]              [Denmark]
# 13               None       [France, Germany]               [Norway]
# 14            Germany       [Germany, Norway]               [France]
# 15               None  [Finland, Netherlands]              [Denmark]
# 16               None       [France, Germany]               [Norway]
# 17             Norway       [Germany, Norway]               [France]
# 18             France       [France, Germany]               [Norway]
# 19               None       [England, Sweden]                [Italy]
# 20              Italy         [Sweden, Italy]              [England]
# 21               None         [Sweden, Italy]              [Denmark]
# 22             Sweden       [Denmark, Sweden]                [Italy]
# 23            Finland         [Sweden, Italy]              [Denmark]
# 24               None       [Germany, Norway]              [Iceland]
# 25             Norway       [Iceland, Norway]              [Germany]
# 26               None         [France, Spain]              [England]
# 27               None  [Belgium, Netherlands]              [Denmark]
# 28            Denmark  [Denmark, Netherlands]              [Belgium]
# 29               None       [Germany, Sweden]               [Russia]
# 30              Italy       [Germany, Russia]               [Sweden]
# 31            Germany       [Germany, Sweden]                [Italy]
# 32               None       [Austria, France]          [Switzerland]
# 33        Switzerland  [Austria, Switzerland]               [France]
# 34             France       [Austria, France]          [Switzerland]
# 35               None        [England, Spain]             [Portugal]
# 36           Scotland     [Portugal, England]                [Spain]
# 37            England        [England, Spain]             [Portugal]
# 38               None      [Austria, England]               [Norway]
# 39               None        [Germany, Spain]              [Denmark]
# 40               None   [Sweden, Netherlands]             [Portugal]
# 41               None       [France, Iceland]              [Belgium]
# 42            Belgium       [Belgium, France]              [Iceland]
#
#     top4_third_place          1st          2nd          3rd
# 0                  0       Norway      Denmark         None
# 1                  1      Germany       Norway       Sweden
# 2                  1      Germany       Sweden       Norway
# 3                  1       Sweden       France        Spain
# 4                  1       Sweden        Spain       France
# 5                  1       Norway        Italy      Germany
# 6                  1        Italy      Germany       Norway
# 7                  1      Germany       Sweden      England
# 8                  1       Norway        Italy      Denmark
# 9                  1       Norway      Denmark        Italy
# 10                 1      Denmark      England       Sweden
# 11                 1      Denmark       Sweden      England
# 12                 1       Sweden      Finland      Denmark
# 13                 1      Germany       France       Norway
# 14                 1      Germany       Norway       France
# 15                 1      Finland  Netherlands      Denmark
# 16                 1      Germany       France       Norway
# 17                 1      Germany       Norway       France
# 18                 1      Germany       France       Norway
# 19                 1       Sweden      England        Italy
# 20                 1       Sweden        Italy      England
# 21                 1       Sweden        Italy      Denmark
# 22                 1       Sweden      Denmark        Italy
# 23                 1       Sweden        Italy      Denmark
# 24                 1       Norway      Germany      Iceland
# 25                 1       Norway      Iceland      Germany
# 26                 1       France        Spain      England
# 27                 1  Netherlands      Belgium      Denmark
# 28                 1  Netherlands      Denmark      Belgium
# 29                 1       Sweden      Germany       Russia
# 30                 1      Germany       Russia       Sweden
# 31                 1      Germany       Sweden        Italy
# 32                 1      Austria       France  Switzerland
# 33                 1  Switzerland      Austria       France
# 34                 1      Austria       France  Switzerland
# 35                 1      England        Spain     Portugal
# 36                 1      England     Portugal        Spain
# 37                 1      England        Spain     Portugal
# 38                 1      England      Austria       Norway
# 39                 1      Germany        Spain      Denmark
# 40                 1  Netherlands       Sweden     Portugal
# 41                 1       France      Iceland      Belgium
# 42                 1       France      Belgium      Iceland

# %%
# Exporting final df
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\women\fifa\eu\standings_eu_fifa_women.xlsx'
final_composition_changes_df.to_excel(file_path, index=False)

# %% [markdown]
# # best four third placed

# %%
# Call the function to get the DataFrame
final_df = best_two_third_placed_eu_women(goals_last_day_sorted, all_games_before_last, agg_goals_before_last_day)

# Define the file path and save to Excel
file_path = rf'C:\Users\{user}\Documents\GitHub\tiebreak_wc\data\out\wiki\women\fifa\eu\third_teams_eu_fifa_women.xlsx'
final_df.to_excel(file_path, index=False)
# Out:
# --- Processing Year: 2009 ---
#
# === Initial Standings for Year 2009 Before Processing Any Goals ===
#
#        team   stage  before_last_game_points  before_last_game_goals_scored  before_last_game_goals_conceded  total_goal_difference
#     Finland Group A                        6                              3                                1                      2
# Netherlands Group A                        3                              3                                2                      1
#     Denmark Group A                        3                              2                                2                      0
#     Ukraine Group A                        0                              1                                4                     -3
#     Germany Group B                        6                              9                                1                      8
#      France Group B                        3                              4                                6                     -2
#      Norway Group B                        3                              1                                4                     -3
#     Iceland Group B                        0                              1                                4                     -3
#      Sweden Group C                        6                              5                                0                      5
#     England Group C                        3                              4                                4                      0
#       Italy Group C                        3                              2                                3                     -1
#      Russia Group C                        0                              2                                6                     -4
#
# ===============================================================
#
#
# --- Analyzing Goal 48 in Group A: On date 2009-08-29, Minute 58 (Player Team: Netherlands, Home: Denmark, Away: Netherlands) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Norway']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 32  Denmark             3                 0                     -1
# 36   Norway             4                 1                     -3
# 40    Italy             4                 1                     -1
#
#     total_goals_scored
# 32                   2
# 36                   1
# 40                   2
#
#
# --- Analyzing Goal 49 in Group A: On date 2009-08-29, Minute 66 (Player Team: Netherlands, Home: Denmark, Away: Netherlands) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Norway']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 32  Denmark             3                 0                     -2
# 36   Norway             4                 1                     -3
# 40    Italy             4                 1                     -1
#
#     total_goals_scored
# 32                   2
# 36                   1
# 40                   2
#
#
# --- Analyzing Goal 46 in Group A: On date 2009-08-29, Minute 69 (Player Team: Ukraine, Home: Finland, Away: Ukraine) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Norway']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 32  Denmark             3                 0                     -2
# 36   Norway             4                 1                     -3
# 40    Italy             4                 1                     -1
#
#     total_goals_scored
# 32                   2
# 36                   1
# 40                   2
#
#
# --- Analyzing Goal 47 in Group A: On date 2009-08-29, Minute 71 (Player Team: Denmark, Home: Denmark, Away: Netherlands) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Norway']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 32  Denmark             3                 0                     -1
# 36   Norway             4                 1                     -3
# 40    Italy             4                 1                     -1
#
#     total_goals_scored
# 32                   3
# 36                   1
# 40                   2
#
#
# --- Analyzing Goal 51 in Group B: On date 2009-08-30, Minute 4 (Player Team: Norway, Home: Norway, Away: France) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'France']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 32  Denmark             3                 0                     -1
# 35   France             3                 0                     -3
# 40    Italy             4                 1                     -1
#
#     total_goals_scored
# 32                   3
# 35                   4
# 40                   2
#
#
# --- Analyzing Goal 52 in Group B: On date 2009-08-30, Minute 16 (Player Team: France, Home: Norway, Away: France) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Norway']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 32  Denmark             3                 0                     -1
# 36   Norway             4                 1                     -3
# 40    Italy             4                 1                     -1
#
#     total_goals_scored
# 32                   3
# 36                   2
# 40                   2
#
#
# --- Analyzing Goal 50 in Group B: On date 2009-08-30, Minute 50 (Player Team: Germany, Home: Germany, Away: Iceland) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Norway']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 32  Denmark             3                 0                     -1
# 36   Norway             4                 1                     -3
# 40    Italy             4                 1                     -1
#
#     total_goals_scored
# 32                   3
# 36                   2
# 40                   2
#
#
# --- Analyzing Goal 56 in Group C: On date 2009-08-31, Minute 28 (Player Team: England, Home: Sweden, Away: England) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Norway']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 32  Denmark             3                 0                     -1
# 36   Norway             4                 1                     -3
# 40    Italy             4                 1                     -1
#
#     total_goals_scored
# 32                   3
# 36                   2
# 40                   2
#
#
# --- Analyzing Goal 55 in Group C: On date 2009-08-31, Minute 40 (Player Team: Sweden, Home: Sweden, Away: England) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Norway']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 32  Denmark             3                 0                     -1
# 36   Norway             4                 1                     -3
# 40    Italy             4                 1                     -1
#
#     total_goals_scored
# 32                   3
# 36                   2
# 40                   2
#
#
# --- Analyzing Goal 53 in Group C: On date 2009-08-31, Minute 77 (Player Team: Italy, Home: Russia, Away: Italy) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Norway']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 32  Denmark             3                 0                     -1
# 36   Norway             4                 1                     -3
# 39  England             4                 1                      0
#
#     total_goals_scored
# 32                   3
# 36                   2
# 39                   5
#
#
# --- Analyzing Goal 54 in Group C: On date 2009-08-31, Minute 93 (Player Team: Italy, Home: Russia, Away: Italy) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Norway']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 32  Denmark             3                 0                     -1
# 36   Norway             4                 1                     -3
# 39  England             4                 1                      0
#
#     total_goals_scored
# 32                   3
# 36                   2
# 39                   5
#
#
# --- Processing Year: 2013 ---
#
# === Initial Standings for Year 2013 Before Processing Any Goals ===
#
#        team   stage  before_last_game_points  before_last_game_goals_scored  before_last_game_goals_conceded  total_goal_difference
#      Sweden Group A                        4                              6                                1                      5
#       Italy Group A                        4                              2                                1                      1
#     Denmark Group A                        1                              2                                3                     -1
#     Finland Group A                        1                              0                                5                     -5
#      Norway Group B                        4                              2                                1                      1
#     Germany Group B                        3                              3                                0                      3
#     Iceland Group B                        1                              1                                4                     -3
# Netherlands Group B                        0                              0                                1                     -1
#      France Group C                        6                              4                                1                      3
#       Spain Group C                        3                              3                                3                      0
#     England Group C                        1                              3                                4                     -1
#      Russia Group C                        1                              2                                4                     -2
#
# ===============================================================
#
#
# --- Analyzing Goal 61 in Group A: On date 2013-07-16, Minute 29 (Player Team: Denmark, Home: Denmark, Away: Finland) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Iceland']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 44  Denmark             4                 3                      0
# 48  Iceland             2                 1                     -3
# 52  England             2                 1                     -1
#
#     total_goals_scored
# 44                   3
# 48                   1
# 52                   3
#
#
# --- Analyzing Goal 57 in Group A: On date 2013-07-16, Minute 47 (Player Team: Sweden, Home: Sweden, Away: Italy) ---
# Top 2 third-placed teams after this goal: ['Italy', 'Iceland']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 43    Italy             4                 0                      0
# 48  Iceland             2                 1                     -3
# 52  England             2                 1                     -1
#
#     total_goals_scored
# 43                   2
# 48                   1
# 52                   3
#
#
# --- Analyzing Goal 58 in Group A: On date 2013-07-16, Minute 49 (Player Team: Sweden, Home: Sweden, Away: Italy) ---
# Top 2 third-placed teams after this goal: ['Italy', 'Iceland']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 43    Italy             4                 0                     -1
# 48  Iceland             2                 1                     -3
# 52  England             2                 1                     -1
#
#     total_goals_scored
# 43                   2
# 48                   1
# 52                   3
#
#
# --- Analyzing Goal 59 in Group A: On date 2013-07-16, Minute 57 (Player Team: Sweden, Home: Sweden, Away: Italy) ---
# Top 2 third-placed teams after this goal: ['Italy', 'Iceland']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 43    Italy             4                 0                     -2
# 48  Iceland             2                 1                     -3
# 52  England             2                 1                     -1
#
#     total_goals_scored
# 43                   2
# 48                   1
# 52                   3
#
#
# --- Analyzing Goal 60 in Group A: On date 2013-07-16, Minute 78 (Player Team: Italy, Home: Sweden, Away: Italy) ---
# Top 2 third-placed teams after this goal: ['Italy', 'Iceland']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 43    Italy             4                 0                     -1
# 48  Iceland             2                 1                     -3
# 52  England             2                 1                     -1
#
#     total_goals_scored
# 43                   3
# 48                   1
# 52                   3
#
#
# --- Analyzing Goal 62 in Group A: On date 2013-07-16, Minute 87 (Player Team: Finland, Home: Denmark, Away: Finland) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Iceland']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 44  Denmark             2                 1                     -1
# 48  Iceland             2                 1                     -3
# 52  England             2                 1                     -1
#
#     total_goals_scored
# 44                   3
# 48                   1
# 52                   3
#
#
# --- Analyzing Goal 64 in Group B: On date 2013-07-17, Minute 30 (Player Team: Iceland, Home: Netherlands, Away: Iceland) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Iceland']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 44  Denmark             2                 1                     -1
# 48  Iceland             4                 3                     -2
# 52  England             2                 1                     -1
#
#     total_goals_scored
# 44                   3
# 48                   2
# 52                   3
#
#
# --- Analyzing Goal 63 in Group B: On date 2013-07-17, Minute 46 (Player Team: Norway, Home: Germany, Away: Norway) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Germany']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 44  Denmark             2                 1                     -1
# 47  Germany             3                 0                      2
# 52  England             2                 1                     -1
#
#     total_goals_scored
# 44                   3
# 47                   3
# 52                   3
#
#
# --- Analyzing Goal 65 in Group C: On date 2013-07-18, Minute 9 (Player Team: France, Home: France, Away: England) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Germany']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 44  Denmark             2                 1                     -1
# 47  Germany             3                 0                      2
# 53   Russia             2                 1                     -2
#
#     total_goals_scored
# 44                   3
# 47                   3
# 53                   2
#
#
# --- Analyzing Goal 69 in Group C: On date 2013-07-18, Minute 14 (Player Team: Spain, Home: Russia, Away: Spain) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Germany']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 44  Denmark             2                 1                     -1
# 47  Germany             3                 0                      2
# 52  England             1                 0                     -2
#
#     total_goals_scored
# 44                   3
# 47                   3
# 52                   3
#
#
# --- Analyzing Goal 68 in Group C: On date 2013-07-18, Minute 44 (Player Team: Russia, Home: Russia, Away: Spain) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Germany']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 44  Denmark             2                 1                     -1
# 47  Germany             3                 0                      2
# 53   Russia             2                 1                     -2
#
#     total_goals_scored
# 44                   3
# 47                   3
# 53                   3
#
#
# --- Analyzing Goal 66 in Group C: On date 2013-07-18, Minute 62 (Player Team: France, Home: France, Away: England) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Germany']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 44  Denmark             2                 1                     -1
# 47  Germany             3                 0                      2
# 53   Russia             2                 1                     -2
#
#     total_goals_scored
# 44                   3
# 47                   3
# 53                   3
#
#
# --- Analyzing Goal 67 in Group C: On date 2013-07-18, Minute 64 (Player Team: France, Home: France, Away: England) ---
# Top 2 third-placed teams after this goal: ['Denmark', 'Germany']
# Third-placed teams DataFrame after this goal:
#        team  total_points  last_game_points  total_goal_difference  \
# 44  Denmark             2                 1                     -1
# 47  Germany             3                 0                      2
# 53   Russia             2                 1                     -2
#
#     total_goals_scored
# 44                   3
# 47                   3
# 53                   3

# %%
# Count the number of observations where the year is 2013
count_2009 = goals_last_day_sorted[goals_last_day_sorted['year'] == 2009].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 2009: {count_2009}")

# Count the number of observations where the year is 201
count_2013 = goals_last_day_sorted[goals_last_day_sorted['year'] == 2013].shape[0]
print(f"Number of observations in goals_last_day_sorted for the year 2013: {count_2013}")
# Out:
# Number of observations in goals_last_day_sorted for the year 2009: 11
# Number of observations in goals_last_day_sorted for the year 2013: 13
